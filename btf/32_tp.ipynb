# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from itertools import pairwise

from depsurf import BuildVersion, FileLogger, check_diff, diff_dict

versions = BuildVersion.filter(flavor="generic", arch="amd64")

total_struct_only = 0
total_func_only = 0
total_both = 0

results = {}

for (v1, v2) in list(pairwise(versions)):
    print(f"Comparing {v1} and {v2}")

    tp1 = v1.img.tracepoints
    tp2 = v2.img.tracepoints
    with FileLogger(path=None):
        func_changed = check_diff(tp1.funcs, tp2.funcs).changed
        struct_changed = check_diff(tp1.events, tp2.events).changed

        struct_only, func_only, both = diff_dict(func_changed, struct_changed)

        total_struct_only += len(struct_only)
        total_func_only += len(func_only)
        total_both += len(both)

        for k in list(struct_only) + list(func_only) + list(both):
            results[k] = results.get(k, 0) + 1

    for (d, name) in [(struct_only, "Struct only"), (func_only, "Func only"), (both, "Both")]:
        print(f"\t{name}: {len(d)}")
        for k, v in d.items():
            print(f"\t\t{k}")
            if name == "Both":
                v1, v2 = v
                v1.print(nindent=3)
                v2.print(nindent=3)
            else:
                v.print(nindent=3)
# Out:
# Comparing 4.4.0-21-generic-amd64 and 4.8.0-22-generic-amd64
# 	Struct only: 16
# 		writeback_single_inode
# 			Field added          ==> Compiler error
# 				cgroup_ino              : unsigned int
# 			Field removed        ==> Compiler error
# 				__data_loc_cgroup       : u32
# 		writeback_single_inode_start
# 			Field added          ==> Compiler error
# 				cgroup_ino              : unsigned int
# 			Field removed        ==> Compiler error
# 				__data_loc_cgroup       : u32
# 		writeback_sb_inodes_requeue
# 			Field added          ==> Compiler error
# 				cgroup_ino              : unsigned int
# 			Field removed        ==> Compiler error
# 				__data_loc_cgroup       : u32
# 		balance_dirty_pages
# 			Field added          ==> Compiler error
# 				cgroup_ino              : unsigned int
# 			Field removed        ==> Compiler error
# 				__data_loc_cgroup       : u32
# 		bdi_dirty_ratelimit
# 			Field added          ==> Compiler error
# 				cgroup_ino              : unsigned int
# 			Field removed        ==> Compiler error
# 				__data_loc_cgroup       : u32
# 		writeback_queue_io
# 			Field added          ==> Compiler error
# 				cgroup_ino              : unsigned int
# 			Field removed        ==> Compiler error
# 				__data_loc_cgroup       : u32
# 		wbc_writepage
# 			Field added          ==> Compiler error
# 				cgroup_ino              : unsigned int
# 			Field removed        ==> Compiler error
# 				__data_loc_cgroup       : u32
# 		writeback_wake_background
# 			Field added          ==> Compiler error
# 				cgroup_ino              : unsigned int
# 			Field removed        ==> Compiler error
# 				__data_loc_cgroup       : u32
# 		writeback_nowork
# 			Field added          ==> Compiler error
# 				cgroup_ino              : unsigned int
# 			Field removed        ==> Compiler error
# 				__data_loc_cgroup       : u32
# 		writeback_wait
# 			Field added          ==> Compiler error
# 				cgroup_ino              : unsigned int
# 			Field removed        ==> Compiler error
# 				__data_loc_cgroup       : u32
# 		writeback_written
# 			Field added          ==> Compiler error
# 				cgroup_ino              : unsigned int
# 			Field removed        ==> Compiler error
# 				__data_loc_cgroup       : u32
# 		writeback_start
# 			Field added          ==> Compiler error
# 				cgroup_ino              : unsigned int
# 			Field removed        ==> Compiler error
# 				__data_loc_cgroup       : u32
# 		writeback_exec
# 			Field added          ==> Compiler error
# 				cgroup_ino              : unsigned int
# 			Field removed        ==> Compiler error
# 				__data_loc_cgroup       : u32
# 		writeback_queue
# 			Field added          ==> Compiler error
# 				cgroup_ino              : unsigned int
# 			Field removed        ==> Compiler error
# 				__data_loc_cgroup       : u32
# 		writeback_write_inode
# 			Field added          ==> Compiler error
# 				cgroup_ino              : unsigned int
# 			Field removed        ==> Compiler error
# 				__data_loc_cgroup       : u32
# 		writeback_write_inode_start
# 			Field added          ==> Compiler error
# 				cgroup_ino              : unsigned int
# 			Field removed        ==> Compiler error
# 				__data_loc_cgroup       : u32
# 	Func only: 1
# 		mm_vmscan_writepage
# 			Param removed        ==> Silent error
# 				reclaim_flags           : int
# 	Both: 10
# 		tick_stop
# 			Param added          ==> Silent error
# 				dependency              : int
# 			Param removed        ==> Silent error
# 				error_msg               : char *
# 			Field added          ==> Compiler error
# 				dependency              : int
# 			Field removed        ==> Compiler error
# 				__data_loc_msg          : u32
# 		mm_vmscan_lru_shrink_inactive
# 			Param added          ==> Silent error
# 				file                    : int
# 			Param removed        ==> Silent error
# 				zid                     : int
# 				reclaim_flags           : int
# 			Param reordered      ==> Silent error
# 				  ['__data', 'nid', 'zid', 'nr_scanned', 'nr_reclaimed', 'priority', 'reclaim_flags']
# 				->['__data', 'nid', 'nr_scanned', 'nr_reclaimed', 'priority', 'file']
# 			Field removed        ==> Compiler error
# 				zid                     : int
# 		mm_vmscan_memcg_isolate
# 			Param added          ==> Silent error
# 				classzone_idx           : int
# 			Param reordered      ==> Silent error
# 				  ['__data', 'order', 'nr_requested', 'nr_scanned', 'nr_taken', 'isolate_mode', 'file']
# 				->['__data', 'classzone_idx', 'order', 'nr_requested', 'nr_scanned', 'nr_taken', 'isolate_mode', 'file']
# 			Field added          ==> Compiler error
# 				classzone_idx           : int
# 		mm_vmscan_lru_isolate
# 			Param added          ==> Silent error
# 				classzone_idx           : int
# 			Param reordered      ==> Silent error
# 				  ['__data', 'order', 'nr_requested', 'nr_scanned', 'nr_taken', 'isolate_mode', 'file']
# 				->['__data', 'classzone_idx', 'order', 'nr_requested', 'nr_scanned', 'nr_taken', 'isolate_mode', 'file']
# 			Field added          ==> Compiler error
# 				classzone_idx           : int
# 		mm_vmscan_memcg_softlimit_reclaim_begin
# 			Param added          ==> Silent error
# 				classzone_idx           : int
# 			Field added          ==> Compiler error
# 				classzone_idx           : int
# 		mm_vmscan_memcg_reclaim_begin
# 			Param added          ==> Silent error
# 				classzone_idx           : int
# 			Field added          ==> Compiler error
# 				classzone_idx           : int
# 		mm_vmscan_direct_reclaim_begin
# 			Param added          ==> Silent error
# 				classzone_idx           : int
# 			Field added          ==> Compiler error
# 				classzone_idx           : int
# 		mm_vmscan_kswapd_wake
# 			Param added          ==> Silent error
# 				zid                     : int
# 			Param reordered      ==> Silent error
# 				  ['__data', 'nid', 'order']
# 				->['__data', 'nid', 'zid', 'order']
# 			Field added          ==> Compiler error
# 				zid                     : int
# 		mm_compaction_try_to_compact_pages
# 			Param added          ==> Silent error
# 				prio                    : int
# 			Param removed        ==> Silent error
# 				mode                    : enum migrate_mode
# 			Field added          ==> Compiler error
# 				prio                    : int
# 			Field removed        ==> Compiler error
# 				mode                    : enum migrate_mode
# 		napi_poll
# 			Param added          ==> Silent error
# 				work                    : int
# 				budget                  : int
# 			Field added          ==> Compiler error
# 				work                    : int
# 				budget                  : int
# Comparing 4.8.0-22-generic-amd64 and 4.10.0-19-generic-amd64
# 	Struct only: 15
# 		x86_fpu_xstate_check_failed
# 			Field removed        ==> Compiler error
# 				counter                 : int
# 		x86_fpu_copy_dst
# 			Field removed        ==> Compiler error
# 				counter                 : int
# 		x86_fpu_copy_src
# 			Field removed        ==> Compiler error
# 				counter                 : int
# 		x86_fpu_dropped
# 			Field removed        ==> Compiler error
# 				counter                 : int
# 		x86_fpu_init_state
# 			Field removed        ==> Compiler error
# 				counter                 : int
# 		x86_fpu_deactivate_state
# 			Field removed        ==> Compiler error
# 				counter                 : int
# 		x86_fpu_activate_state
# 			Field removed        ==> Compiler error
# 				counter                 : int
# 		x86_fpu_regs_deactivated
# 			Field removed        ==> Compiler error
# 				counter                 : int
# 		x86_fpu_regs_activated
# 			Field removed        ==> Compiler error
# 				counter                 : int
# 		x86_fpu_after_restore
# 			Field removed        ==> Compiler error
# 				counter                 : int
# 		x86_fpu_before_restore
# 			Field removed        ==> Compiler error
# 				counter                 : int
# 		x86_fpu_after_save
# 			Field removed        ==> Compiler error
# 				counter                 : int
# 		x86_fpu_before_save
# 			Field removed        ==> Compiler error
# 				counter                 : int
# 		x86_fpu_state
# 			Field removed        ==> Compiler error
# 				counter                 : int
# 		mce_record
# 			Field added          ==> Compiler error
# 				synd                    : u64
# 				ipid                    : u64
# 	Func only: 0
# 	Both: 2
# 		pstate_sample
# 			Param added          ==> Silent error
# 				io_boost                : u32
# 			Field added          ==> Compiler error
# 				io_boost                : u32
# 		swiotlb_bounced
# 			Param type changed   ==> Silent error
# 				swiotlb_force           : int  ->  enum swiotlb_force
# 			Field type changed   ==> Silent error
# 				swiotlb_force           : int  ->  enum swiotlb_force
# Comparing 4.10.0-19-generic-amd64 and 4.13.0-16-generic-amd64
# 	Struct only: 6
# 		ext4_da_release_space
# 			Field removed        ==> Compiler error
# 				reserved_meta_blocks    : int
# 				allocated_meta_blocks   : int
# 		ext4_da_reserve_space
# 			Field removed        ==> Compiler error
# 				reserved_meta_blocks    : int
# 		ext4_da_update_reserve_space
# 			Field removed        ==> Compiler error
# 				reserved_meta_blocks    : int
# 				allocated_meta_blocks   : int
# 		ext4_alloc_da_blocks
# 			Field removed        ==> Compiler error
# 				meta_blocks             : unsigned int
# 		block_rq_requeue
# 			Field removed        ==> Compiler error
# 				errors                  : int
# 		mdio_access
# 			Field type changed   ==> Silent error
# 				busid                   : char[17]  ->  char[61]
# 	Func only: 1
# 		sched_pi_setprio
# 			Param added          ==> Silent error
# 				pi_task                 : struct task_struct *
# 			Param removed        ==> Silent error
# 				newprio                 : int
# 	Both: 6
# 		itimer_expire
# 			Param type changed   ==> Silent error
# 				now                     : cputime_t  ->  long long unsigned int
# 			Field type changed   ==> Silent error
# 				now                     : cputime_t  ->  long long unsigned int
# 		itimer_state
# 			Param type changed   ==> Silent error
# 				expires                 : cputime_t  ->  long long unsigned int
# 			Field type changed   ==> Silent error
# 				expires                 : cputime_t  ->  long long unsigned int
# 		mm_vmscan_lru_shrink_inactive
# 			Param added          ==> Silent error
# 				nr_dirty                : long unsigned int
# 				nr_writeback            : long unsigned int
# 				nr_congested            : long unsigned int
# 				nr_immediate            : long unsigned int
# 				nr_activate             : long unsigned int
# 				nr_ref_keep             : long unsigned int
# 				nr_unmap_fail           : long unsigned int
# 			Param reordered      ==> Silent error
# 				  ['__data', 'nid', 'nr_scanned', 'nr_reclaimed', 'priority', 'file']
# 				->['__data', 'nid', 'nr_scanned', 'nr_reclaimed', 'nr_dirty', 'nr_writeback', 'nr_congested', 'nr_immediate', 'nr_activate', 'nr_ref_keep', 'nr_unmap_fail', 'priority', 'file']
# 			Field added          ==> Compiler error
# 				nr_dirty                : long unsigned int
# 				nr_writeback            : long unsigned int
# 				nr_congested            : long unsigned int
# 				nr_immediate            : long unsigned int
# 				nr_activate             : long unsigned int
# 				nr_ref_keep             : long unsigned int
# 				nr_unmap_fail           : long unsigned int
# 		mm_vmscan_lru_isolate
# 			Param added          ==> Silent error
# 				nr_skipped              : long unsigned int
# 				lru                     : int
# 			Param removed        ==> Silent error
# 				file                    : int
# 			Param reordered      ==> Silent error
# 				  ['__data', 'classzone_idx', 'order', 'nr_requested', 'nr_scanned', 'nr_taken', 'isolate_mode', 'file']
# 				->['__data', 'classzone_idx', 'order', 'nr_requested', 'nr_scanned', 'nr_skipped', 'nr_taken', 'isolate_mode', 'lru']
# 			Field added          ==> Compiler error
# 				nr_skipped              : long unsigned int
# 				lru                     : int
# 			Field removed        ==> Compiler error
# 				file                    : int
# 		block_rq_complete
# 			Param added          ==> Silent error
# 				error                   : int
# 			Param removed        ==> Silent error
# 				q                       : struct request_queue *
# 			Param reordered      ==> Silent error
# 				  ['__data', 'q', 'rq', 'nr_bytes']
# 				->['__data', 'rq', 'error', 'nr_bytes']
# 			Field added          ==> Compiler error
# 				error                   : int
# 			Field removed        ==> Compiler error
# 				errors                  : int
# 		thermal_power_devfreq_get_power
# 			Param added          ==> Silent error
# 				power                   : u32
# 			Field added          ==> Compiler error
# 				power                   : u32
# Comparing 4.13.0-16-generic-amd64 and 4.15.0-20-generic-amd64
# 	Struct only: 15
# 		x86_fpu_xstate_check_failed
# 			Field added          ==> Compiler error
# 				initialized             : bool
# 			Field removed        ==> Compiler error
# 				fpregs_active           : bool
# 				fpstate_active          : bool
# 		x86_fpu_copy_dst
# 			Field added          ==> Compiler error
# 				initialized             : bool
# 			Field removed        ==> Compiler error
# 				fpregs_active           : bool
# 				fpstate_active          : bool
# 		x86_fpu_copy_src
# 			Field added          ==> Compiler error
# 				initialized             : bool
# 			Field removed        ==> Compiler error
# 				fpregs_active           : bool
# 				fpstate_active          : bool
# 		x86_fpu_dropped
# 			Field added          ==> Compiler error
# 				initialized             : bool
# 			Field removed        ==> Compiler error
# 				fpregs_active           : bool
# 				fpstate_active          : bool
# 		x86_fpu_init_state
# 			Field added          ==> Compiler error
# 				initialized             : bool
# 			Field removed        ==> Compiler error
# 				fpregs_active           : bool
# 				fpstate_active          : bool
# 		x86_fpu_activate_state
# 			Field added          ==> Compiler error
# 				initialized             : bool
# 			Field removed        ==> Compiler error
# 				fpregs_active           : bool
# 				fpstate_active          : bool
# 		x86_fpu_regs_deactivated
# 			Field added          ==> Compiler error
# 				initialized             : bool
# 			Field removed        ==> Compiler error
# 				fpregs_active           : bool
# 				fpstate_active          : bool
# 		x86_fpu_regs_activated
# 			Field added          ==> Compiler error
# 				initialized             : bool
# 			Field removed        ==> Compiler error
# 				fpregs_active           : bool
# 				fpstate_active          : bool
# 		x86_fpu_after_restore
# 			Field added          ==> Compiler error
# 				initialized             : bool
# 			Field removed        ==> Compiler error
# 				fpregs_active           : bool
# 				fpstate_active          : bool
# 		x86_fpu_before_restore
# 			Field added          ==> Compiler error
# 				initialized             : bool
# 			Field removed        ==> Compiler error
# 				fpregs_active           : bool
# 				fpstate_active          : bool
# 		x86_fpu_after_save
# 			Field added          ==> Compiler error
# 				initialized             : bool
# 			Field removed        ==> Compiler error
# 				fpregs_active           : bool
# 				fpstate_active          : bool
# 		x86_fpu_before_save
# 			Field added          ==> Compiler error
# 				initialized             : bool
# 			Field removed        ==> Compiler error
# 				fpregs_active           : bool
# 				fpstate_active          : bool
# 		xdp_exception
# 			Field added          ==> Compiler error
# 				prog_id                 : int
# 				ifindex                 : int
# 			Field removed        ==> Compiler error
# 				__data_loc_name         : u32
# 				prog_tag                : u8[8]
# 		mmc_request_done
# 			Field added          ==> Compiler error
# 				tag                     : int
# 		mmc_request_start
# 			Field added          ==> Compiler error
# 				blk_addr                : unsigned int
# 				tag                     : int
# 	Func only: 1
# 		fib6_table_lookup
# 			Param added          ==> Silent error
# 				table                   : struct fib6_table *
# 			Param removed        ==> Silent error
# 				tb_id                   : u32
# 	Both: 1
# 		mm_page_free_batched
# 			Param removed        ==> Silent error
# 				cold                    : int
# 			Field removed        ==> Compiler error
# 				cold                    : int
# Comparing 4.15.0-20-generic-amd64 and 4.18.0-10-generic-amd64
# 	Struct only: 1
# 		xhci_free_virt_device
# 			Field added          ==> Compiler error
# 				fake_port               : u8
# 				real_port               : u8
# 				current_mel             : u16
# 			Field removed        ==> Compiler error
# 				devnum                  : int
# 				state                   : int
# 				speed                   : int
# 				portnum                 : u8
# 				level                   : u8
# 				slot_id                 : int
# 	Func only: 1
# 		mm_vmscan_lru_shrink_inactive
# 			Param added          ==> Silent error
# 				stat                    : struct reclaim_stat *
# 			Param removed        ==> Silent error
# 				nr_dirty                : long unsigned int
# 				nr_writeback            : long unsigned int
# 				nr_congested            : long unsigned int
# 				nr_immediate            : long unsigned int
# 				nr_activate             : long unsigned int
# 				nr_ref_keep             : long unsigned int
# 				nr_unmap_fail           : long unsigned int
# 			Param reordered      ==> Silent error
# 				  ['__data', 'nid', 'nr_scanned', 'nr_reclaimed', 'nr_dirty', 'nr_writeback', 'nr_congested', 'nr_immediate', 'nr_activate', 'nr_ref_keep', 'nr_unmap_fail', 'priority', 'file']
# 				->['__data', 'nid', 'nr_scanned', 'nr_reclaimed', 'stat', 'priority', 'file']
# 	Both: 8
# 		hrtimer_start
# 			Param added          ==> Silent error
# 				mode                    : enum hrtimer_mode
# 			Field added          ==> Compiler error
# 				mode                    : enum hrtimer_mode
# 		mm_shrink_slab_start
# 			Param added          ==> Silent error
# 				priority                : int
# 			Param removed        ==> Silent error
# 				pgs_scanned             : long unsigned int
# 				lru_pgs                 : long unsigned int
# 			Param reordered      ==> Silent error
# 				  ['__data', 'shr', 'sc', 'nr_objects_to_shrink', 'pgs_scanned', 'lru_pgs', 'cache_items', 'delta', 'total_scan']
# 				->['__data', 'shr', 'sc', 'nr_objects_to_shrink', 'cache_items', 'delta', 'total_scan', 'priority']
# 			Field added          ==> Compiler error
# 				priority                : int
# 			Field removed        ==> Compiler error
# 				pgs_scanned             : long unsigned int
# 				lru_pgs                 : long unsigned int
# 		mm_vmscan_wakeup_kswapd
# 			Param added          ==> Silent error
# 				gfp_flags               : gfp_t
# 			Field added          ==> Compiler error
# 				gfp_flags               : gfp_t
# 		aer_event
# 			Param added          ==> Silent error
# 				tlp_header_valid        : const (anon)
# 				tlp                     : struct aer_header_log_regs *
# 			Field added          ==> Compiler error
# 				tlp_header_valid        : u8
# 				tlp_header              : u32[4]
# 		fib6_table_lookup
# 			Param added          ==> Silent error
# 				f6i                     : const (anon) *
# 			Param removed        ==> Silent error
# 				rt                      : const (anon) *
# 			Field added          ==> Compiler error
# 				err                     : int
# 				sport                   : u16
# 				dport                   : u16
# 				proto                   : u8
# 				rt_type                 : u8
# 		fib_table_lookup
# 			Param added          ==> Silent error
# 				nh                      : const (anon) *
# 				err                     : int
# 			Field added          ==> Compiler error
# 				err                     : int
# 				gw                      : __u8[4]
# 				saddr                   : __u8[4]
# 				sport                   : u16
# 				dport                   : u16
# 				proto                   : u8
# 				__data_loc_name         : u32
# 		tcp_destroy_sock
# 			Param type changed   ==> Silent error
# 				sk                      : const (anon) *  ->  struct sock *
# 			Field added          ==> Compiler error
# 				sock_cookie             : __u64
# 		tcp_receive_reset
# 			Param type changed   ==> Silent error
# 				sk                      : const (anon) *  ->  struct sock *
# 			Field added          ==> Compiler error
# 				sock_cookie             : __u64
# Comparing 4.18.0-10-generic-amd64 and 5.0.0-13-generic-amd64
# 	Struct only: 11
# 		time_out_leases
# 			Field added          ==> Compiler error
# 				fl_blocker              : struct file_lock *
# 			Field removed        ==> Compiler error
# 				fl_next                 : struct file_lock *
# 		generic_delete_lease
# 			Field added          ==> Compiler error
# 				fl_blocker              : struct file_lock *
# 			Field removed        ==> Compiler error
# 				fl_next                 : struct file_lock *
# 		break_lease_unblock
# 			Field added          ==> Compiler error
# 				fl_blocker              : struct file_lock *
# 			Field removed        ==> Compiler error
# 				fl_next                 : struct file_lock *
# 		break_lease_block
# 			Field added          ==> Compiler error
# 				fl_blocker              : struct file_lock *
# 			Field removed        ==> Compiler error
# 				fl_next                 : struct file_lock *
# 		break_lease_noblock
# 			Field added          ==> Compiler error
# 				fl_blocker              : struct file_lock *
# 			Field removed        ==> Compiler error
# 				fl_next                 : struct file_lock *
# 		locks_remove_posix
# 			Field added          ==> Compiler error
# 				fl_blocker              : struct file_lock *
# 			Field removed        ==> Compiler error
# 				fl_next                 : struct file_lock *
# 		fcntl_setlk
# 			Field added          ==> Compiler error
# 				fl_blocker              : struct file_lock *
# 			Field removed        ==> Compiler error
# 				fl_next                 : struct file_lock *
# 		posix_lock_inode
# 			Field added          ==> Compiler error
# 				fl_blocker              : struct file_lock *
# 			Field removed        ==> Compiler error
# 				fl_next                 : struct file_lock *
# 		fib_table_lookup
# 		tcp_send_reset
# 			Field added          ==> Compiler error
# 				state                   : int
# 		tcp_retransmit_skb
# 			Field added          ==> Compiler error
# 				state                   : int
# 	Func only: 6
# 		signal_deliver
# 			Param type changed   ==> Silent error
# 				info                    : struct siginfo *  ->  struct kernel_siginfo *
# 		signal_generate
# 			Param type changed   ==> Silent error
# 				info                    : struct siginfo *  ->  struct kernel_siginfo *
# 		cgroup_rename
# 			Param added          ==> Silent error
# 				path                    : const (anon) *
# 		cgroup_release
# 			Param added          ==> Silent error
# 				path                    : const (anon) *
# 		cgroup_rmdir
# 			Param added          ==> Silent error
# 				path                    : const (anon) *
# 		cgroup_mkdir
# 			Param added          ==> Silent error
# 				path                    : const (anon) *
# 	Both: 6
# 		cgroup_transfer_tasks
# 			Param added          ==> Silent error
# 				path                    : const (anon) *
# 			Param reordered      ==> Silent error
# 				  ['__data', 'dst_cgrp', 'task', 'threadgroup']
# 				->['__data', 'dst_cgrp', 'path', 'task', 'threadgroup']
# 		cgroup_attach_task
# 			Param added          ==> Silent error
# 				path                    : const (anon) *
# 			Param reordered      ==> Silent error
# 				  ['__data', 'dst_cgrp', 'task', 'threadgroup']
# 				->['__data', 'dst_cgrp', 'path', 'task', 'threadgroup']
# 		ext4_ext_remove_space_done
# 			Param added          ==> Silent error
# 				pc                      : struct partial_cluster *
# 			Param removed        ==> Silent error
# 				partial                 : long long int
# 			Field added          ==> Compiler error
# 				pc_pclu                 : ext4_fsblk_t
# 				pc_lblk                 : ext4_lblk_t
# 				pc_state                : int
# 			Field removed        ==> Compiler error
# 				partial                 : long long int
# 		ext4_ext_rm_leaf
# 			Param added          ==> Silent error
# 				pc                      : struct partial_cluster *
# 			Param removed        ==> Silent error
# 				partial_cluster         : long long int
# 			Field added          ==> Compiler error
# 				pc_pclu                 : ext4_fsblk_t
# 				pc_lblk                 : ext4_lblk_t
# 				pc_state                : int
# 			Field removed        ==> Compiler error
# 				partial                 : long long int
# 		ext4_remove_blocks
# 			Param added          ==> Silent error
# 				pc                      : struct partial_cluster *
# 			Param removed        ==> Silent error
# 				partial_cluster         : long long int
# 			Field added          ==> Compiler error
# 				pc_pclu                 : ext4_fsblk_t
# 				pc_lblk                 : ext4_lblk_t
# 				pc_state                : int
# 			Field removed        ==> Compiler error
# 				partial                 : long long int
# 		sock_exceed_buf_limit
# 			Param added          ==> Silent error
# 				kind                    : int
# 			Field added          ==> Compiler error
# 				sysctl_wmem             : int
# 				wmem_alloc              : int
# 				wmem_queued             : int
# 				kind                    : int
# Comparing 5.0.0-13-generic-amd64 and 5.3.0-18-generic-amd64
# 	Struct only: 14
# 		x86_fpu_xstate_check_failed
# 			Field added          ==> Compiler error
# 				load_fpu                : bool
# 			Field removed        ==> Compiler error
# 				initialized             : bool
# 		x86_fpu_copy_dst
# 			Field added          ==> Compiler error
# 				load_fpu                : bool
# 			Field removed        ==> Compiler error
# 				initialized             : bool
# 		x86_fpu_copy_src
# 			Field added          ==> Compiler error
# 				load_fpu                : bool
# 			Field removed        ==> Compiler error
# 				initialized             : bool
# 		x86_fpu_dropped
# 			Field added          ==> Compiler error
# 				load_fpu                : bool
# 			Field removed        ==> Compiler error
# 				initialized             : bool
# 		x86_fpu_init_state
# 			Field added          ==> Compiler error
# 				load_fpu                : bool
# 			Field removed        ==> Compiler error
# 				initialized             : bool
# 		x86_fpu_regs_deactivated
# 			Field added          ==> Compiler error
# 				load_fpu                : bool
# 			Field removed        ==> Compiler error
# 				initialized             : bool
# 		x86_fpu_regs_activated
# 			Field added          ==> Compiler error
# 				load_fpu                : bool
# 			Field removed        ==> Compiler error
# 				initialized             : bool
# 		x86_fpu_after_restore
# 			Field added          ==> Compiler error
# 				load_fpu                : bool
# 			Field removed        ==> Compiler error
# 				initialized             : bool
# 		x86_fpu_before_restore
# 			Field added          ==> Compiler error
# 				load_fpu                : bool
# 			Field removed        ==> Compiler error
# 				initialized             : bool
# 		x86_fpu_after_save
# 			Field added          ==> Compiler error
# 				load_fpu                : bool
# 			Field removed        ==> Compiler error
# 				initialized             : bool
# 		x86_fpu_before_save
# 			Field added          ==> Compiler error
# 				load_fpu                : bool
# 			Field removed        ==> Compiler error
# 				initialized             : bool
# 		mm_vmscan_lru_shrink_inactive
# 			Field added          ==> Compiler error
# 				nr_activate0            : unsigned int
# 				nr_activate1            : unsigned int
# 			Field removed        ==> Compiler error
# 				nr_activate             : long unsigned int
# 		spi_transfer_stop
# 			Field added          ==> Compiler error
# 				__data_loc_rx_buf       : u32
# 				__data_loc_tx_buf       : u32
# 		spi_transfer_start
# 			Field added          ==> Compiler error
# 				__data_loc_rx_buf       : u32
# 				__data_loc_tx_buf       : u32
# 	Func only: 3
# 		smbus_reply
# 			Param added          ==> Silent error
# 				res                     : int
# 		non_standard_event
# 			Param type changed   ==> Silent error
# 				sec_type                : const (anon) *  ->  const (anon) *
# 				fru_id                  : const (anon) *  ->  const (anon) *
# 		fib6_table_lookup
# 			Param added          ==> Silent error
# 				res                     : const (anon) *
# 			Param removed        ==> Silent error
# 				f6i                     : const (anon) *
# 	Both: 7
# 		timer_expire_entry
# 			Param added          ==> Silent error
# 				baseclk                 : long unsigned int
# 			Field added          ==> Compiler error
# 				baseclk                 : long unsigned int
# 		mm_vmscan_memcg_softlimit_reclaim_begin
# 			Param removed        ==> Silent error
# 				may_writepage           : int
# 				classzone_idx           : int
# 			Param reordered      ==> Silent error
# 				  ['__data', 'order', 'may_writepage', 'gfp_flags', 'classzone_idx']
# 				->['__data', 'order', 'gfp_flags']
# 			Field removed        ==> Compiler error
# 				may_writepage           : int
# 				classzone_idx           : int
# 		mm_vmscan_memcg_reclaim_begin
# 			Param removed        ==> Silent error
# 				may_writepage           : int
# 				classzone_idx           : int
# 			Param reordered      ==> Silent error
# 				  ['__data', 'order', 'may_writepage', 'gfp_flags', 'classzone_idx']
# 				->['__data', 'order', 'gfp_flags']
# 			Field removed        ==> Compiler error
# 				may_writepage           : int
# 				classzone_idx           : int
# 		mm_vmscan_direct_reclaim_begin
# 			Param removed        ==> Silent error
# 				may_writepage           : int
# 				classzone_idx           : int
# 			Param reordered      ==> Silent error
# 				  ['__data', 'order', 'may_writepage', 'gfp_flags', 'classzone_idx']
# 				->['__data', 'order', 'gfp_flags']
# 			Field removed        ==> Compiler error
# 				may_writepage           : int
# 				classzone_idx           : int
# 		credit_entropy_bits
# 			Param removed        ==> Silent error
# 				entropy_total           : int
# 			Param reordered      ==> Silent error
# 				  ['__data', 'pool_name', 'bits', 'entropy_count', 'entropy_total', 'IP']
# 				->['__data', 'pool_name', 'bits', 'entropy_count', 'IP']
# 			Field removed        ==> Compiler error
# 				entropy_total           : int
# 		extlog_mem_event
# 			Param type changed   ==> Silent error
# 				fru_id                  : const (anon) *  ->  const (anon) *
# 			Field type changed   ==> Silent error
# 				fru_id                  : uuid_le  ->  guid_t
# 		fib_table_lookup
# 			Param added          ==> Silent error
# 				nhc                     : const (anon) *
# 			Param removed        ==> Silent error
# 				nh                      : const (anon) *
# 			Field added          ==> Compiler error
# 				gw4                     : __u8[4]
# 				gw6                     : __u8[16]
# 			Field removed        ==> Compiler error
# 				gw                      : __u8[4]
# 				saddr                   : __u8[4]
# Comparing 5.3.0-18-generic-amd64 and 5.4.0-26-generic-amd64
# 	Struct only: 1
# 		generic_add_lease
# 			Field added          ==> Compiler error
# 				rcount                  : int
# 			Field removed        ==> Compiler error
# 				dcount                  : int
# 	Func only: 0
# 	Both: 1
# 		mem_disconnect
# 			Param removed        ==> Silent error
# 				safe_to_remove          : bool
# 				force                   : bool
# 			Field removed        ==> Compiler error
# 				safe_to_remove          : bool
# 				force                   : bool
# 				disconnect_cnt          : int
# Comparing 5.4.0-26-generic-amd64 and 5.8.0-25-generic-amd64
# 	Struct only: 32
# 		sb_clear_inode_writeback
# 			Field type changed   ==> Silent error
# 				ino                     : long unsigned int  ->  ino_t
# 		sb_mark_inode_writeback
# 			Field type changed   ==> Silent error
# 				ino                     : long unsigned int  ->  ino_t
# 		writeback_dirty_inode_enqueue
# 			Field type changed   ==> Silent error
# 				ino                     : long unsigned int  ->  ino_t
# 		writeback_lazytime_iput
# 			Field type changed   ==> Silent error
# 				ino                     : long unsigned int  ->  ino_t
# 		writeback_lazytime
# 			Field type changed   ==> Silent error
# 				ino                     : long unsigned int  ->  ino_t
# 		writeback_single_inode
# 			Field type changed   ==> Silent error
# 				ino                     : long unsigned int  ->  ino_t
# 				cgroup_ino              : unsigned int  ->  ino_t
# 		writeback_single_inode_start
# 			Field type changed   ==> Silent error
# 				ino                     : long unsigned int  ->  ino_t
# 				cgroup_ino              : unsigned int  ->  ino_t
# 		writeback_sb_inodes_requeue
# 			Field type changed   ==> Silent error
# 				ino                     : long unsigned int  ->  ino_t
# 				cgroup_ino              : unsigned int  ->  ino_t
# 		balance_dirty_pages
# 			Field type changed   ==> Silent error
# 				cgroup_ino              : unsigned int  ->  ino_t
# 		bdi_dirty_ratelimit
# 			Field type changed   ==> Silent error
# 				cgroup_ino              : unsigned int  ->  ino_t
# 		global_dirty_state
# 			Field removed        ==> Compiler error
# 				nr_unstable             : long unsigned int
# 		wbc_writepage
# 			Field type changed   ==> Silent error
# 				cgroup_ino              : unsigned int  ->  ino_t
# 		writeback_wake_background
# 			Field type changed   ==> Silent error
# 				cgroup_ino              : unsigned int  ->  ino_t
# 		writeback_wait
# 			Field type changed   ==> Silent error
# 				cgroup_ino              : unsigned int  ->  ino_t
# 		writeback_written
# 			Field type changed   ==> Silent error
# 				cgroup_ino              : unsigned int  ->  ino_t
# 		writeback_start
# 			Field type changed   ==> Silent error
# 				cgroup_ino              : unsigned int  ->  ino_t
# 		writeback_exec
# 			Field type changed   ==> Silent error
# 				cgroup_ino              : unsigned int  ->  ino_t
# 		writeback_queue
# 			Field type changed   ==> Silent error
# 				cgroup_ino              : unsigned int  ->  ino_t
# 		writeback_write_inode
# 			Field type changed   ==> Silent error
# 				ino                     : long unsigned int  ->  ino_t
# 				cgroup_ino              : unsigned int  ->  ino_t
# 		writeback_write_inode_start
# 			Field type changed   ==> Silent error
# 				ino                     : long unsigned int  ->  ino_t
# 				cgroup_ino              : unsigned int  ->  ino_t
# 		flush_foreign
# 			Field type changed   ==> Silent error
# 				cgroup_ino              : unsigned int  ->  ino_t
# 		track_foreign_dirty
# 			Field type changed   ==> Silent error
# 				ino                     : long unsigned int  ->  ino_t
# 				cgroup_ino              : unsigned int  ->  ino_t
# 				page_cgroup_ino         : unsigned int  ->  ino_t
# 		inode_switch_wbs
# 			Field type changed   ==> Silent error
# 				ino                     : long unsigned int  ->  ino_t
# 				old_cgroup_ino          : unsigned int  ->  ino_t
# 				new_cgroup_ino          : unsigned int  ->  ino_t
# 		inode_foreign_history
# 			Field type changed   ==> Silent error
# 				ino                     : long unsigned int  ->  ino_t
# 				cgroup_ino              : unsigned int  ->  ino_t
# 		writeback_dirty_inode
# 			Field type changed   ==> Silent error
# 				ino                     : long unsigned int  ->  ino_t
# 		writeback_dirty_inode_start
# 			Field type changed   ==> Silent error
# 				ino                     : long unsigned int  ->  ino_t
# 		writeback_mark_inode_dirty
# 			Field type changed   ==> Silent error
# 				ino                     : long unsigned int  ->  ino_t
# 		wait_on_page_writeback
# 			Field type changed   ==> Silent error
# 				ino                     : long unsigned int  ->  ino_t
# 		writeback_dirty_page
# 			Field type changed   ==> Silent error
# 				ino                     : long unsigned int  ->  ino_t
# 		page_pool_state_hold
# 			Field added          ==> Compiler error
# 				pfn                     : long unsigned int
# 		page_pool_state_release
# 			Field added          ==> Compiler error
# 				pfn                     : long unsigned int
# 		inet_sock_set_state
# 			Field type changed   ==> Silent error
# 				protocol                : __u8  ->  __u16
# 	Func only: 6
# 		xdp_redirect_map_err
# 			Param added          ==> Silent error
# 				tgt                     : const (anon) *
# 				index                   : u32
# 			Param removed        ==> Silent error
# 				to_ifindex              : int
# 				map_index               : u32
# 		xdp_redirect_map
# 			Param added          ==> Silent error
# 				tgt                     : const (anon) *
# 				index                   : u32
# 			Param removed        ==> Silent error
# 				to_ifindex              : int
# 				map_index               : u32
# 		xdp_redirect_err
# 			Param added          ==> Silent error
# 				tgt                     : const (anon) *
# 				index                   : u32
# 			Param removed        ==> Silent error
# 				to_ifindex              : int
# 				map_index               : u32
# 		xdp_redirect
# 			Param added          ==> Silent error
# 				tgt                     : const (anon) *
# 				index                   : u32
# 			Param removed        ==> Silent error
# 				to_ifindex              : int
# 				map_index               : u32
# 		block_bio_complete
# 			Param removed        ==> Silent error
# 				error                   : int
# 		iocost_ioc_vrate_adj
# 			Param type changed   ==> Silent error
# 				missed_ppm              : u32[2] *  ->  u32 *
# 	Both: 15
# 		workqueue_execute_end
# 			Param added          ==> Silent error
# 				function                : work_func_t
# 			Field added          ==> Compiler error
# 				function                : void *
# 		sched_stick_numa
# 			Param added          ==> Silent error
# 				src_tsk                 : struct task_struct *
# 				dst_tsk                 : struct task_struct *
# 			Param removed        ==> Silent error
# 				tsk                     : struct task_struct *
# 			Param reordered      ==> Silent error
# 				  ['__data', 'tsk', 'src_cpu', 'dst_cpu']
# 				->['__data', 'src_tsk', 'src_cpu', 'dst_tsk', 'dst_cpu']
# 			Field added          ==> Compiler error
# 				src_pid                 : pid_t
# 				src_tgid                : pid_t
# 				src_ngid                : pid_t
# 				dst_pid                 : pid_t
# 				dst_tgid                : pid_t
# 				dst_ngid                : pid_t
# 			Field removed        ==> Compiler error
# 				pid                     : pid_t
# 				tgid                    : pid_t
# 				ngid                    : pid_t
# 		itimer_state
# 			Param type changed   ==> Silent error
# 				value                   : const (anon)  ->  const (anon)
# 			Field added          ==> Compiler error
# 				value_nsec              : long int
# 				interval_nsec           : long int
# 			Field removed        ==> Compiler error
# 				value_usec              : long int
# 				interval_usec           : long int
# 		pm_qos_remove_request
# 			Param removed        ==> Silent error
# 				pm_qos_class            : int
# 			Param reordered      ==> Silent error
# 				  ['__data', 'pm_qos_class', 'value']
# 				->['__data', 'value']
# 			Field removed        ==> Compiler error
# 				pm_qos_class            : int
# 		pm_qos_update_request
# 			Param removed        ==> Silent error
# 				pm_qos_class            : int
# 			Param reordered      ==> Silent error
# 				  ['__data', 'pm_qos_class', 'value']
# 				->['__data', 'value']
# 			Field removed        ==> Compiler error
# 				pm_qos_class            : int
# 		pm_qos_add_request
# 			Param removed        ==> Silent error
# 				pm_qos_class            : int
# 			Param reordered      ==> Silent error
# 				  ['__data', 'pm_qos_class', 'value']
# 				->['__data', 'value']
# 			Field removed        ==> Compiler error
# 				pm_qos_class            : int
# 		xdp_devmap_xmit
# 			Param removed        ==> Silent error
# 				map                     : const (anon) *
# 				map_index               : u32
# 			Param reordered      ==> Silent error
# 				  ['__data', 'map', 'map_index', 'sent', 'drops', 'from_dev', 'to_dev', 'err']
# 				->['__data', 'from_dev', 'to_dev', 'sent', 'drops', 'err']
# 			Field removed        ==> Compiler error
# 				map_id                  : int
# 				map_index               : u32
# 		mm_vmscan_lru_isolate
# 			Param added          ==> Silent error
# 				highest_zoneidx         : int
# 			Param removed        ==> Silent error
# 				classzone_idx           : int
# 			Field added          ==> Compiler error
# 				highest_zoneidx         : int
# 			Field removed        ==> Compiler error
# 				classzone_idx           : int
# 		mm_compaction_kcompactd_wake
# 			Param added          ==> Silent error
# 				highest_zoneidx         : enum zone_type
# 			Param removed        ==> Silent error
# 				classzone_idx           : enum zone_type
# 			Field added          ==> Compiler error
# 				highest_zoneidx         : enum zone_type
# 			Field removed        ==> Compiler error
# 				classzone_idx           : enum zone_type
# 		mm_compaction_wakeup_kcompactd
# 			Param added          ==> Silent error
# 				highest_zoneidx         : enum zone_type
# 			Param removed        ==> Silent error
# 				classzone_idx           : enum zone_type
# 			Field added          ==> Compiler error
# 				highest_zoneidx         : enum zone_type
# 			Field removed        ==> Compiler error
# 				classzone_idx           : enum zone_type
# 		writeback_queue_io
# 			Param added          ==> Silent error
# 				dirtied_before          : long unsigned int
# 			Param reordered      ==> Silent error
# 				  ['__data', 'wb', 'work', 'moved']
# 				->['__data', 'wb', 'work', 'dirtied_before', 'moved']
# 			Field type changed   ==> Silent error
# 				cgroup_ino              : unsigned int  ->  ino_t
# 		ext4_journal_start
# 			Param added          ==> Silent error
# 				revoke_creds            : int
# 			Param reordered      ==> Silent error
# 				  ['__data', 'sb', 'blocks', 'rsv_blocks', 'IP']
# 				->['__data', 'sb', 'blocks', 'rsv_blocks', 'revoke_creds', 'IP']
# 			Field added          ==> Compiler error
# 				revoke_creds            : int
# 		ext4_discard_preallocations
# 			Param added          ==> Silent error
# 				len                     : unsigned int
# 				needed                  : unsigned int
# 			Field added          ==> Compiler error
# 				len                     : unsigned int
# 				needed                  : unsigned int
# 		map_sg
# 			Param added          ==> Silent error
# 				index                   : int
# 				total                   : int
# 				sg                      : struct scatterlist *
# 			Param removed        ==> Silent error
# 				dev_addr                : dma_addr_t
# 				phys_addr               : phys_addr_t
# 				size                    : size_t
# 			Field added          ==> Compiler error
# 				index                   : int
# 				total                   : int
# 		br_fdb_update
# 			Param added          ==> Silent error
# 				flags                   : long unsigned int
# 			Param removed        ==> Silent error
# 				added_by_user           : bool
# 			Field added          ==> Compiler error
# 				flags                   : long unsigned int
# 			Field removed        ==> Compiler error
# 				added_by_user           : bool
# Comparing 5.8.0-25-generic-amd64 and 5.11.0-16-generic-amd64
# 	Struct only: 5
# 		iocost_iocg_activate
# 			Field removed        ==> Compiler error
# 				last_vtime              : u64
# 		regcache_sync
# 			Field removed        ==> Compiler error
# 				type                    : int
# 		cros_ec_request_done
# 			Field added          ==> Compiler error
# 				offset                  : uint32_t
# 				outsize                 : uint32_t
# 				insize                  : uint32_t
# 		cros_ec_request_start
# 			Field added          ==> Compiler error
# 				offset                  : uint32_t
# 				outsize                 : uint32_t
# 				insize                  : uint32_t
# 		extlog_mem_event
# 	Func only: 12
# 		ext4_load_inode
# 			Param added          ==> Silent error
# 				sb                      : struct super_block *
# 				ino                     : long unsigned int
# 			Param removed        ==> Silent error
# 				inode                   : struct inode *
# 		block_rq_remap
# 			Param removed        ==> Silent error
# 				q                       : struct request_queue *
# 			Param reordered      ==> Silent error
# 				  ['__data', 'q', 'rq', 'dev', 'from']
# 				->['__data', 'rq', 'dev', 'from']
# 		block_bio_remap
# 			Param removed        ==> Silent error
# 				q                       : struct request_queue *
# 			Param reordered      ==> Silent error
# 				  ['__data', 'q', 'bio', 'dev', 'from']
# 				->['__data', 'bio', 'dev', 'from']
# 		block_split
# 			Param removed        ==> Silent error
# 				q                       : struct request_queue *
# 			Param reordered      ==> Silent error
# 				  ['__data', 'q', 'bio', 'new_sector']
# 				->['__data', 'bio', 'new_sector']
# 		block_getrq
# 			Param removed        ==> Silent error
# 				q                       : struct request_queue *
# 				rw                      : int
# 			Param reordered      ==> Silent error
# 				  ['__data', 'q', 'bio', 'rw']
# 				->['__data', 'bio']
# 		block_bio_queue
# 			Param removed        ==> Silent error
# 				q                       : struct request_queue *
# 			Param reordered      ==> Silent error
# 				  ['__data', 'q', 'bio']
# 				->['__data', 'bio']
# 		block_bio_frontmerge
# 			Param removed        ==> Silent error
# 				q                       : struct request_queue *
# 				rq                      : struct request *
# 			Param reordered      ==> Silent error
# 				  ['__data', 'q', 'rq', 'bio']
# 				->['__data', 'bio']
# 		block_bio_backmerge
# 			Param removed        ==> Silent error
# 				q                       : struct request_queue *
# 				rq                      : struct request *
# 			Param reordered      ==> Silent error
# 				  ['__data', 'q', 'rq', 'bio']
# 				->['__data', 'bio']
# 		block_bio_bounce
# 			Param removed        ==> Silent error
# 				q                       : struct request_queue *
# 			Param reordered      ==> Silent error
# 				  ['__data', 'q', 'bio']
# 				->['__data', 'bio']
# 		block_rq_issue
# 			Param removed        ==> Silent error
# 				q                       : struct request_queue *
# 			Param reordered      ==> Silent error
# 				  ['__data', 'q', 'rq']
# 				->['__data', 'rq']
# 		block_rq_insert
# 			Param removed        ==> Silent error
# 				q                       : struct request_queue *
# 			Param reordered      ==> Silent error
# 				  ['__data', 'q', 'rq']
# 				->['__data', 'rq']
# 		block_rq_requeue
# 			Param removed        ==> Silent error
# 				q                       : struct request_queue *
# 			Param reordered      ==> Silent error
# 				  ['__data', 'q', 'rq']
# 				->['__data', 'rq']
# 	Both: 5
# 		xdp_cpumap_kthread
# 			Param added          ==> Silent error
# 				xdp_stats               : struct xdp_cpumap_stats *
# 			Field added          ==> Compiler error
# 				xdp_pass                : unsigned int
# 				xdp_drop                : unsigned int
# 				xdp_redirect            : unsigned int
# 		mm_migrate_pages
# 			Param added          ==> Silent error
# 				thp_succeeded           : long unsigned int
# 				thp_failed              : long unsigned int
# 				thp_split               : long unsigned int
# 			Param reordered      ==> Silent error
# 				  ['__data', 'succeeded', 'failed', 'mode', 'reason']
# 				->['__data', 'succeeded', 'failed', 'thp_succeeded', 'thp_failed', 'thp_split', 'mode', 'reason']
# 			Field added          ==> Compiler error
# 				thp_succeeded           : long unsigned int
# 				thp_failed              : long unsigned int
# 				thp_split               : long unsigned int
# 		ext4_read_block_bitmap_load
# 			Param added          ==> Silent error
# 				prefetch                : bool
# 			Field added          ==> Compiler error
# 				prefetch                : bool
# 		iocost_ioc_vrate_adj
# 			Param removed        ==> Silent error
# 				nr_surpluses            : int
# 			Field removed        ==> Compiler error
# 				nr_surpluses            : int
# 		thermal_power_devfreq_get_power
# 			Param removed        ==> Silent error
# 				dynamic_power           : u32
# 				static_power            : u32
# 			Param reordered      ==> Silent error
# 				  ['__data', 'cdev', 'status', 'freq', 'dynamic_power', 'static_power', 'power']
# 				->['__data', 'cdev', 'status', 'freq', 'power']
# 			Field added          ==> Compiler error
# 				busy_time               : u32
# 				total_time              : u32
# 			Field removed        ==> Compiler error
# 				load                    : u32
# 				dynamic_power           : u32
# 				static_power            : u32
# Comparing 5.11.0-16-generic-amd64 and 5.13.0-19-generic-amd64
# 	Struct only: 8
# 		workqueue_queue_work
# 			Field added          ==> Compiler error
# 				__data_loc_workqueue    : u32
# 			Field removed        ==> Compiler error
# 				workqueue               : void *
# 		tcp_probe
# 			Field added          ==> Compiler error
# 				family                  : __u16
# 		tcp_retransmit_synack
# 			Field added          ==> Compiler error
# 				family                  : __u16
# 		tcp_rcv_space_adjust
# 			Field added          ==> Compiler error
# 				family                  : __u16
# 		tcp_destroy_sock
# 			Field added          ==> Compiler error
# 				family                  : __u16
# 		tcp_receive_reset
# 			Field added          ==> Compiler error
# 				family                  : __u16
# 		tcp_send_reset
# 			Field added          ==> Compiler error
# 				family                  : __u16
# 		tcp_retransmit_skb
# 			Field added          ==> Compiler error
# 				family                  : __u16
# 	Func only: 4
# 		xdp_redirect_map_err
# 			Param added          ==> Silent error
# 				map_type                : enum bpf_map_type
# 				map_id                  : u32
# 			Param removed        ==> Silent error
# ...
# 				accounted               : bool
# 		kmalloc
# 			Param added          ==> Silent error
# 				node                    : int
# 			Field added          ==> Compiler error
# 				node                    : int
# 		jbd2_write_superblock
# 			Param added          ==> Silent error
# 				write_flags             : blk_opf_t
# 			Param removed        ==> Silent error
# 				write_op                : int
# 			Field added          ==> Compiler error
# 				write_flags             : blk_opf_t
# 			Field removed        ==> Compiler error
# 				write_op                : int
# 		jbd2_checkpoint_stats
# 			Param type changed   ==> Silent error
# 				tid                     : long unsigned int  ->  tid_t
# 			Field type changed   ==> Silent error
# 				tid                     : long unsigned int  ->  tid_t
# 		jbd2_run_stats
# 			Param type changed   ==> Silent error
# 				tid                     : long unsigned int  ->  tid_t
# 			Field type changed   ==> Silent error
# 				tid                     : long unsigned int  ->  tid_t
# 		jbd2_handle_stats
# 			Param type changed   ==> Silent error
# 				tid                     : long unsigned int  ->  tid_t
# 			Field type changed   ==> Silent error
# 				tid                     : long unsigned int  ->  tid_t
# 		jbd2_handle_extend
# 			Param type changed   ==> Silent error
# 				tid                     : long unsigned int  ->  tid_t
# 			Field type changed   ==> Silent error
# 				tid                     : long unsigned int  ->  tid_t
# 		jbd2_handle_restart
# 			Param type changed   ==> Silent error
# 				tid                     : long unsigned int  ->  tid_t
# 			Field type changed   ==> Silent error
# 				tid                     : long unsigned int  ->  tid_t
# 		jbd2_handle_start
# 			Param type changed   ==> Silent error
# 				tid                     : long unsigned int  ->  tid_t
# 			Field type changed   ==> Silent error
# 				tid                     : long unsigned int  ->  tid_t
# 		pwm_get
# 			Param added          ==> Silent error
# 				err                     : int
# 			Field added          ==> Compiler error
# 				err                     : int
# 		pwm_apply
# 			Param added          ==> Silent error
# 				err                     : int
# 			Field added          ==> Compiler error
# 				err                     : int
# Comparing 6.2.0-20-generic-amd64 and 6.5.0-9-generic-amd64
# 	Struct only: 38
# 		rseq_update
# 			Field added          ==> Compiler error
# 				node_id                 : s32
# 				mm_cid                  : s32
# 		scsi_dispatch_cmd_timeout
# 			Field added          ==> Compiler error
# 				sense_key               : u8
# 				asc                     : u8
# 				ascq                    : u8
# 		scsi_dispatch_cmd_done
# 			Field added          ==> Compiler error
# 				sense_key               : u8
# 				asc                     : u8
# 				ascq                    : u8
# 		xhci_ring_host_doorbell
# 			Field removed        ==> Compiler error
# 				__data_loc_str          : u32
# 		xhci_ring_ep_doorbell
# 			Field removed        ==> Compiler error
# 				__data_loc_str          : u32
# 		xhci_hub_status_data
# 			Field removed        ==> Compiler error
# 				__data_loc_str          : u32
# 		xhci_get_port_status
# 			Field removed        ==> Compiler error
# 				__data_loc_str          : u32
# 		xhci_handle_port_status
# 			Field removed        ==> Compiler error
# 				__data_loc_str          : u32
# 		xhci_inc_deq
# 			Field removed        ==> Compiler error
# 				num_trbs_free           : unsigned int
# 		xhci_inc_enq
# 			Field removed        ==> Compiler error
# 				num_trbs_free           : unsigned int
# 		xhci_ring_expansion
# 			Field removed        ==> Compiler error
# 				num_trbs_free           : unsigned int
# 		xhci_ring_free
# 			Field removed        ==> Compiler error
# 				num_trbs_free           : unsigned int
# 		xhci_ring_alloc
# 			Field removed        ==> Compiler error
# 				num_trbs_free           : unsigned int
# 		xhci_configure_endpoint_ctrl_ctx
# 			Field removed        ==> Compiler error
# 				__data_loc_str          : u32
# 		xhci_address_ctrl_ctx
# 			Field removed        ==> Compiler error
# 				__data_loc_str          : u32
# 		xhci_configure_endpoint
# 			Field removed        ==> Compiler error
# 				__data_loc_str          : u32
# 		xhci_handle_cmd_set_deq
# 			Field removed        ==> Compiler error
# 				__data_loc_str          : u32
# 		xhci_handle_cmd_reset_dev
# 			Field removed        ==> Compiler error
# 				__data_loc_str          : u32
# 		xhci_handle_cmd_addr_dev
# 			Field removed        ==> Compiler error
# 				__data_loc_str          : u32
# 		xhci_setup_device_slot
# 			Field removed        ==> Compiler error
# 				__data_loc_str          : u32
# 		xhci_discover_or_reset_device
# 			Field removed        ==> Compiler error
# 				__data_loc_str          : u32
# 		xhci_handle_cmd_disable_slot
# 			Field removed        ==> Compiler error
# 				__data_loc_str          : u32
# 		xhci_free_dev
# 			Field removed        ==> Compiler error
# 				__data_loc_str          : u32
# 		xhci_alloc_dev
# 			Field removed        ==> Compiler error
# 				__data_loc_str          : u32
# 		xhci_add_endpoint
# 			Field removed        ==> Compiler error
# 				__data_loc_str          : u32
# 		xhci_handle_cmd_config_ep
# 			Field removed        ==> Compiler error
# 				__data_loc_str          : u32
# 		xhci_handle_cmd_reset_ep
# 			Field removed        ==> Compiler error
# 				__data_loc_str          : u32
# 		xhci_handle_cmd_set_deq_ep
# 			Field removed        ==> Compiler error
# 				__data_loc_str          : u32
# 		xhci_handle_cmd_stop_ep
# 			Field removed        ==> Compiler error
# 				__data_loc_str          : u32
# 		xhci_dbc_gadget_ep_queue
# 			Field removed        ==> Compiler error
# 				__data_loc_str          : u32
# 		xhci_dbc_handle_transfer
# 			Field removed        ==> Compiler error
# 				__data_loc_str          : u32
# 		xhci_dbc_handle_event
# 			Field removed        ==> Compiler error
# 				__data_loc_str          : u32
# 		xhci_queue_trb
# 			Field removed        ==> Compiler error
# 				__data_loc_str          : u32
# 		xhci_handle_transfer
# 			Field removed        ==> Compiler error
# 				__data_loc_str          : u32
# 		xhci_handle_command
# 			Field removed        ==> Compiler error
# 				__data_loc_str          : u32
# 		xhci_handle_event
# 			Field removed        ==> Compiler error
# 				__data_loc_str          : u32
# 		xhci_address_ctx
# 			Field removed        ==> Compiler error
# 				slot_id                 : int
# 		tcp_cong_state_set
# 			Field added          ==> Compiler error
# 				family                  : __u16
# 	Func only: 0
# 	Both: 2
# 		jbd2_shrink_checkpoint_list
# 			Param removed        ==> Silent error
# 				nr_scanned              : long unsigned int
# 			Param reordered      ==> Silent error
# 				  ['__data', 'journal', 'first_tid', 'tid', 'last_tid', 'nr_freed', 'nr_scanned', 'next_tid']
# 				->['__data', 'journal', 'first_tid', 'tid', 'last_tid', 'nr_freed', 'next_tid']
# 			Field removed        ==> Compiler error
# 				nr_scanned              : long unsigned int
# 		consume_skb
# 			Param added          ==> Silent error
# 				location                : void *
# 			Field added          ==> Compiler error
# 				location                : void *
# Comparing 6.5.0-9-generic-amd64 and 6.8.0-22-generic-amd64
# 	Struct only: 0
# 	Func only: 3
# 		csd_function_exit
# 			Param type changed   ==> Silent error
# 				csd                     : struct __call_single_data *  ->  call_single_data_t *
# 		csd_function_entry
# 			Param type changed   ==> Silent error
# 				csd                     : struct __call_single_data *  ->  call_single_data_t *
# 		csd_queue_cpu
# 			Param type changed   ==> Silent error
# 				csd                     : struct __call_single_data *  ->  call_single_data_t *
# 	Both: 12
# 		xen_mc_issue
# 			Param type changed   ==> Silent error
# 				mode                    : enum paravirt_lazy_mode  ->  enum xen_lazy_mode
# 			Field type changed   ==> Silent error
# 				mode                    : enum paravirt_lazy_mode  ->  enum xen_lazy_mode
# 		xen_mc_batch
# 			Param type changed   ==> Silent error
# 				mode                    : enum paravirt_lazy_mode  ->  enum xen_lazy_mode
# 			Field type changed   ==> Silent error
# 				mode                    : enum paravirt_lazy_mode  ->  enum xen_lazy_mode
# 		sched_stat_runtime
# 			Param removed        ==> Silent error
# 				vruntime                : u64
# 			Field removed        ==> Compiler error
# 				vruntime                : u64
# 		timer_start
# 			Param added          ==> Silent error
# 				bucket_expiry           : long unsigned int
# 			Param removed        ==> Silent error
# 				expires                 : long unsigned int
# 				flags                   : unsigned int
# 			Field added          ==> Compiler error
# 				bucket_expiry           : long unsigned int
# 		mm_vmscan_lru_isolate
# 			Param removed        ==> Silent error
# 				isolate_mode            : isolate_mode_t
# 			Param reordered      ==> Silent error
# 				  ['__data', 'highest_zoneidx', 'order', 'nr_requested', 'nr_scanned', 'nr_skipped', 'nr_taken', 'isolate_mode', 'lru']
# 				->['__data', 'highest_zoneidx', 'order', 'nr_requested', 'nr_scanned', 'nr_skipped', 'nr_taken', 'lru']
# 			Field removed        ==> Compiler error
# 				isolate_mode            : unsigned int
# 		mm_migrate_pages
# 			Param added          ==> Silent error
# 				large_folio_split       : long unsigned int
# 			Param reordered      ==> Silent error
# 				  ['__data', 'succeeded', 'failed', 'thp_succeeded', 'thp_failed', 'thp_split', 'mode', 'reason']
# 				->['__data', 'succeeded', 'failed', 'thp_succeeded', 'thp_failed', 'thp_split', 'large_folio_split', 'mode', 'reason']
# 			Field added          ==> Compiler error
# 				large_folio_split       : long unsigned int
# 		hugepage_set_pmd
# 			Param added          ==> Silent error
# 				pte                     : long unsigned int
# 			Param removed        ==> Silent error
# 				pmd                     : long unsigned int
# 			Field added          ==> Compiler error
# 				pte                     : long unsigned int
# 			Field removed        ==> Compiler error
# 				pmd                     : long unsigned int
# 		ext4_discard_preallocations
# 			Param removed        ==> Silent error
# 				needed                  : unsigned int
# 			Field removed        ==> Compiler error
# 				needed                  : unsigned int
# 		xhci_hub_status_data
# 			Param added          ==> Silent error
# 				port                    : struct xhci_port *
# 			Param removed        ==> Silent error
# 				portnum                 : u32
# 			Field added          ==> Compiler error
# 				busnum                  : u32
# 		xhci_get_port_status
# 			Param added          ==> Silent error
# 				port                    : struct xhci_port *
# 			Param removed        ==> Silent error
# 				portnum                 : u32
# 			Field added          ==> Compiler error
# 				busnum                  : u32
# 		xhci_handle_port_status
# 			Param added          ==> Silent error
# 				port                    : struct xhci_port *
# 			Param removed        ==> Silent error
# 				portnum                 : u32
# 			Field added          ==> Compiler error
# 				busnum                  : u32
# 		thermal_power_allocator
# 			Param removed        ==> Silent error
# 				req_power               : u32 *
# 				granted_power           : u32 *
# 			Param reordered      ==> Silent error
# 				  ['__data', 'tz', 'req_power', 'total_req_power', 'granted_power', 'total_granted_power', 'num_actors', 'power_range', 'max_allocatable_power', 'current_temp', 'delta_temp']
# 				->['__data', 'tz', 'total_req_power', 'total_granted_power', 'num_actors', 'power_range', 'max_allocatable_power', 'current_temp', 'delta_temp']
# 			Param type changed   ==> Silent error
# 				num_actors              : size_t  ->  int
# 			Field removed        ==> Compiler error
# 				__data_loc_req_power    : u32
# 				__data_loc_granted_power: u32
# 55
# 234
# 124
# 	Struct only: 0
# 	Func only: 3
# 		csd_function_exit
# 			Param type changed   ==> Silent error
# 				csd                     : struct __call_single_data *  ->  call_single_data_t *
# 		csd_function_entry
# 			Param type changed   ==> Silent error
# 				csd                     : struct __call_single_data *  ->  call_single_data_t *
# 		csd_queue_cpu
# 			Param type changed   ==> Silent error
# 				csd                     : struct __call_single_data *  ->  call_single_data_t *
# 	Both: 12
# 		xen_mc_issue
# 			Param type changed   ==> Silent error
# 				mode                    : enum paravirt_lazy_mode  ->  enum xen_lazy_mode
# 			Field type changed   ==> Silent error
# 				mode                    : enum paravirt_lazy_mode  ->  enum xen_lazy_mode
# 		xen_mc_batch
# 			Param type changed   ==> Silent error
# 				mode                    : enum paravirt_lazy_mode  ->  enum xen_lazy_mode
# 			Field type changed   ==> Silent error
# 				mode                    : enum paravirt_lazy_mode  ->  enum xen_lazy_mode
# 		sched_stat_runtime
# 			Param removed        ==> Silent error
# 				vruntime                : u64
# 			Field removed        ==> Compiler error
# 				vruntime                : u64
# 		timer_start
# 			Param added          ==> Silent error
# 				bucket_expiry           : long unsigned int
# 			Param removed        ==> Silent error
# 				expires                 : long unsigned int
# 				flags                   : unsigned int
# 			Field added          ==> Compiler error
# 				bucket_expiry           : long unsigned int
# 		mm_vmscan_lru_isolate
# 			Param removed        ==> Silent error
# 				isolate_mode            : isolate_mode_t
# 			Param reordered      ==> Silent error
# 				  ['__data', 'highest_zoneidx', 'order', 'nr_requested', 'nr_scanned', 'nr_skipped', 'nr_taken', 'isolate_mode', 'lru']
# 				->['__data', 'highest_zoneidx', 'order', 'nr_requested', 'nr_scanned', 'nr_skipped', 'nr_taken', 'lru']
# 			Field removed        ==> Compiler error
# 				isolate_mode            : unsigned int
# 		mm_migrate_pages
# 			Param added          ==> Silent error
# 				large_folio_split       : long unsigned int
# 			Param reordered      ==> Silent error
# 				  ['__data', 'succeeded', 'failed', 'thp_succeeded', 'thp_failed', 'thp_split', 'mode', 'reason']
# 				->['__data', 'succeeded', 'failed', 'thp_succeeded', 'thp_failed', 'thp_split', 'large_folio_split', 'mode', 'reason']
# 			Field added          ==> Compiler error
# 				large_folio_split       : long unsigned int
# 		hugepage_set_pmd
# 			Param added          ==> Silent error
# 				pte                     : long unsigned int
# 			Param removed        ==> Silent error
# 				pmd                     : long unsigned int
# 			Field added          ==> Compiler error
# 				pte                     : long unsigned int
# 			Field removed        ==> Compiler error
# 				pmd                     : long unsigned int
# 		ext4_discard_preallocations
# 			Param removed        ==> Silent error
# 				needed                  : unsigned int
# 			Field removed        ==> Compiler error
# 				needed                  : unsigned int
# 		xhci_hub_status_data
# 			Param added          ==> Silent error
# 				port                    : struct xhci_port *
# 			Param removed        ==> Silent error
# 				portnum                 : u32
# 			Field added          ==> Compiler error
# 				busnum                  : u32
# 		xhci_get_port_status
# 			Param added          ==> Silent error
# 				port                    : struct xhci_port *
# 			Param removed        ==> Silent error
# 				portnum                 : u32
# 			Field added          ==> Compiler error
# 				busnum                  : u32
# 		xhci_handle_port_status
# 			Param added          ==> Silent error
# 				port                    : struct xhci_port *
# 			Param removed        ==> Silent error
# 				portnum                 : u32
# 			Field added          ==> Compiler error
# 				busnum                  : u32
# 		thermal_power_allocator
# 			Param removed        ==> Silent error
# 				req_power               : u32 *
# 				granted_power           : u32 *
# 			Param reordered      ==> Silent error
# 				  ['__data', 'tz', 'req_power', 'total_req_power', 'granted_power', 'total_granted_power', 'num_actors', 'power_range', 'max_allocatable_power', 'current_temp', 'delta_temp']
# 				->['__data', 'tz', 'total_req_power', 'total_granted_power', 'num_actors', 'power_range', 'max_allocatable_power', 'current_temp', 'delta_temp']
# 			Param type changed   ==> Silent error
# 				num_actors              : size_t  ->  int
# 			Field removed        ==> Compiler error
# 				__data_loc_req_power    : u32
# 				__data_loc_granted_power: u32
# 55
# 234
# 124

# %%
print(total_func_only)
print(total_struct_only)
print(total_both)
# Out:
# 55
# 234
# 124

# %%
for k, v in sorted(results.items(), key=lambda x: x[1], reverse=True):
    print(f"{k}: {v}")
# Out:
# mm_vmscan_lru_isolate: 5
# mm_vmscan_lru_shrink_inactive: 4
# fib6_table_lookup: 4
# fib_table_lookup: 4
# mm_vmscan_memcg_softlimit_reclaim_begin: 3
# mm_vmscan_memcg_reclaim_begin: 3
# mm_vmscan_direct_reclaim_begin: 3
# x86_fpu_xstate_check_failed: 3
# x86_fpu_copy_dst: 3
# x86_fpu_copy_src: 3
# x86_fpu_dropped: 3
# x86_fpu_init_state: 3
# x86_fpu_regs_deactivated: 3
# x86_fpu_regs_activated: 3
# x86_fpu_after_restore: 3
# x86_fpu_before_restore: 3
# x86_fpu_after_save: 3
# x86_fpu_before_save: 3
# io_uring_complete: 3
# xhci_hub_status_data: 3
# xhci_get_port_status: 3
# xhci_handle_port_status: 3
# io_uring_poll_arm: 3
# io_uring_submit_sqe: 3
# writeback_single_inode: 2
# writeback_single_inode_start: 2
# writeback_sb_inodes_requeue: 2
# balance_dirty_pages: 2
# bdi_dirty_ratelimit: 2
# writeback_queue_io: 2
# wbc_writepage: 2
# writeback_wake_background: 2
# writeback_wait: 2
# writeback_written: 2
# writeback_start: 2
# writeback_exec: 2
# writeback_queue: 2
# writeback_write_inode: 2
# writeback_write_inode_start: 2
# mm_compaction_try_to_compact_pages: 2
# x86_fpu_activate_state: 2
# swiotlb_bounced: 2
# block_rq_requeue: 2
# itimer_state: 2
# block_rq_complete: 2
# thermal_power_devfreq_get_power: 2
# mm_shrink_slab_start: 2
# mm_vmscan_wakeup_kswapd: 2
# tcp_destroy_sock: 2
# tcp_receive_reset: 2
# tcp_send_reset: 2
# tcp_retransmit_skb: 2
# cgroup_rename: 2
# cgroup_release: 2
# cgroup_rmdir: 2
# cgroup_mkdir: 2
# cgroup_transfer_tasks: 2
# cgroup_attach_task: 2
# sock_exceed_buf_limit: 2
# extlog_mem_event: 2
# track_foreign_dirty: 2
# xdp_redirect_map_err: 2
# xdp_redirect_map: 2
# xdp_redirect_err: 2
# xdp_redirect: 2
# iocost_ioc_vrate_adj: 2
# ext4_discard_preallocations: 2
# mm_migrate_pages: 2
# workqueue_queue_work: 2
# mm_lru_insertion: 2
# kmem_cache_free: 2
# xhci_ring_host_doorbell: 2
# xhci_ring_ep_doorbell: 2
# xhci_configure_endpoint_ctrl_ctx: 2
# xhci_address_ctrl_ctx: 2
# xhci_configure_endpoint: 2
# xhci_handle_cmd_set_deq: 2
# xhci_handle_cmd_reset_dev: 2
# xhci_handle_cmd_addr_dev: 2
# xhci_setup_device_slot: 2
# xhci_discover_or_reset_device: 2
# xhci_handle_cmd_disable_slot: 2
# xhci_free_dev: 2
# xhci_alloc_dev: 2
# xhci_add_endpoint: 2
# xhci_handle_cmd_config_ep: 2
# xhci_handle_cmd_reset_ep: 2
# xhci_handle_cmd_set_deq_ep: 2
# xhci_handle_cmd_stop_ep: 2
# xhci_dbc_gadget_ep_queue: 2
# xhci_dbc_handle_transfer: 2
# xhci_dbc_handle_event: 2
# xhci_queue_trb: 2
# xhci_handle_transfer: 2
# xhci_handle_command: 2
# xhci_handle_event: 2
# get_mapping_status: 2
# kmem_cache_alloc: 2
# kmalloc: 2
# ext4_fc_stats: 2
# io_uring_task_add: 2
# io_uring_fail_link: 2
# io_uring_defer: 2
# io_uring_queue_async_work: 2
# io_uring_file_get: 2
# scsi_dispatch_cmd_timeout: 2
# scsi_dispatch_cmd_done: 2
# writeback_nowork: 1
# mm_vmscan_writepage: 1
# tick_stop: 1
# mm_vmscan_memcg_isolate: 1
# mm_vmscan_kswapd_wake: 1
# napi_poll: 1
# x86_fpu_deactivate_state: 1
# x86_fpu_state: 1
# mce_record: 1
# pstate_sample: 1
# ext4_da_release_space: 1
# ext4_da_reserve_space: 1
# ext4_da_update_reserve_space: 1
# ext4_alloc_da_blocks: 1
# mdio_access: 1
# sched_pi_setprio: 1
# itimer_expire: 1
# xdp_exception: 1
# mmc_request_done: 1
# mmc_request_start: 1
# mm_page_free_batched: 1
# xhci_free_virt_device: 1
# hrtimer_start: 1
# aer_event: 1
# time_out_leases: 1
# generic_delete_lease: 1
# break_lease_unblock: 1
# break_lease_block: 1
# break_lease_noblock: 1
# locks_remove_posix: 1
# fcntl_setlk: 1
# posix_lock_inode: 1
# signal_deliver: 1
# signal_generate: 1
# ext4_ext_remove_space_done: 1
# ext4_ext_rm_leaf: 1
# ext4_remove_blocks: 1
# spi_transfer_stop: 1
# spi_transfer_start: 1
# smbus_reply: 1
# non_standard_event: 1
# timer_expire_entry: 1
# credit_entropy_bits: 1
# generic_add_lease: 1
# mem_disconnect: 1
# sb_clear_inode_writeback: 1
# sb_mark_inode_writeback: 1
# writeback_dirty_inode_enqueue: 1
# writeback_lazytime_iput: 1
# writeback_lazytime: 1
# global_dirty_state: 1
# flush_foreign: 1
# inode_switch_wbs: 1
# inode_foreign_history: 1
# writeback_dirty_inode: 1
# writeback_dirty_inode_start: 1
# writeback_mark_inode_dirty: 1
# wait_on_page_writeback: 1
# writeback_dirty_page: 1
# page_pool_state_hold: 1
# page_pool_state_release: 1
# inet_sock_set_state: 1
# block_bio_complete: 1
# workqueue_execute_end: 1
# sched_stick_numa: 1
# pm_qos_remove_request: 1
# pm_qos_update_request: 1
# pm_qos_add_request: 1
# xdp_devmap_xmit: 1
# mm_compaction_kcompactd_wake: 1
# mm_compaction_wakeup_kcompactd: 1
# ext4_journal_start: 1
# map_sg: 1
# br_fdb_update: 1
# iocost_iocg_activate: 1
# regcache_sync: 1
# cros_ec_request_done: 1
# cros_ec_request_start: 1
# ext4_load_inode: 1
# block_rq_remap: 1
# block_bio_remap: 1
# block_split: 1
# block_getrq: 1
# block_bio_queue: 1
# block_bio_frontmerge: 1
# block_bio_backmerge: 1
# block_bio_bounce: 1
# block_rq_issue: 1
# block_rq_insert: 1
# xdp_cpumap_kthread: 1
# ext4_read_block_bitmap_load: 1
# tcp_probe: 1
# tcp_retransmit_synack: 1
# tcp_rcv_space_adjust: 1
# sched_wakeup_new: 1
# sched_wakeup: 1
# sched_waking: 1
# cgroup_notify_frozen: 1
# cgroup_notify_populated: 1
# cgroup_unfreeze: 1
# cgroup_freeze: 1
# io_uring_task_run: 1
# iomap_dio_invalidate_fail: 1
# iomap_invalidatepage: 1
# iomap_releasepage: 1
# iomap_writepage: 1
# mm_vmscan_node_reclaim_begin: 1
# mm_page_alloc: 1
# kmem_cache_alloc_node: 1
# kmalloc_node: 1
# sched_switch: 1
# mm_compaction_end: 1
# mm_compaction_begin: 1
# mm_compaction_migratepages: 1
# mm_filemap_add_to_page_cache: 1
# mm_filemap_delete_from_page_cache: 1
# mm_lru_activate: 1
# percpu_alloc_percpu: 1
# mm_page_alloc_zone_locked: 1
# io_uring_register: 1
# ext4_fc_track_range: 1
# ext4_fc_track_inode: 1
# ext4_fc_track_unlink: 1
# ext4_fc_track_link: 1
# ext4_fc_track_create: 1
# ext4_fc_commit_stop: 1
# ext4_fc_commit_start: 1
# ext4_da_write_begin: 1
# ext4_write_begin: 1
# kfree_skb: 1
# jbd2_end_commit: 1
# jbd2_drop_transaction: 1
# jbd2_commit_logging: 1
# jbd2_commit_flushing: 1
# jbd2_commit_locking: 1
# jbd2_start_commit: 1
# scsi_dispatch_cmd_error: 1
# scsi_dispatch_cmd_start: 1
# devlink_trap_report: 1
# rss_stat: 1
# io_uring_req_failed: 1
# io_uring_link: 1
# jbd2_write_superblock: 1
# jbd2_checkpoint_stats: 1
# jbd2_run_stats: 1
# jbd2_handle_stats: 1
# jbd2_handle_extend: 1
# jbd2_handle_restart: 1
# jbd2_handle_start: 1
# pwm_get: 1
# pwm_apply: 1
# rseq_update: 1
# xhci_inc_deq: 1
# xhci_inc_enq: 1
# xhci_ring_expansion: 1
# xhci_ring_free: 1
# xhci_ring_alloc: 1
# xhci_address_ctx: 1
# tcp_cong_state_set: 1
# jbd2_shrink_checkpoint_list: 1
# consume_skb: 1
# csd_function_exit: 1
# csd_function_entry: 1
# csd_queue_cpu: 1
# xen_mc_issue: 1
# xen_mc_batch: 1
# sched_stat_runtime: 1
# timer_start: 1
# hugepage_set_pmd: 1
# thermal_power_allocator: 1
