# %%
from depsurf import get_section_info, DBGSYM_PATH

get_section_info(DBGSYM_PATH / "5.4.0-26-generic")
# Out:
#                      name          type  flags     offset       size  link  \
# 0                              SHT_NULL      0          0          0     0
# 1              .head.text  SHT_PROGBITS      6      65536       4096     0
# 2                   .text  SHT_PROGBITS      6      69632   13854216     0
# 3                 .rodata  SHT_PROGBITS      3   13959168    6235530     0
# 4                .modinfo  SHT_PROGBITS      2   20194698      70832     0
# 5          .init.eh_frame  SHT_PROGBITS      2   20265536       7264     0
# 6              .pci_fixup  SHT_PROGBITS      2   20272800       9280     0
# 7               __ksymtab  SHT_PROGBITS      2   20282080      63876     0
# 8           __ksymtab_gpl  SHT_PROGBITS      2   20345956      70836     0
# 9       __ksymtab_strings  SHT_PROGBITS      2   20416792     222317     0
# 10                __param  SHT_PROGBITS      2   20639112      12120     0
# ...

# %%
from depsurf import get_symbol_info, DBGSYM_PATH

symtab = get_symbol_info(DBGSYM_PATH / "6.5.0-27-generic")

symtab
# Out:
#                                               name     section        bind  \
# 0                                                    SHN_UNDEF   STB_LOCAL
# 1                                                        .text   STB_LOCAL
# 2                                                      .rodata   STB_LOCAL
# 3                                                   .pci_fixup   STB_LOCAL
# 4                                                   .tracedata   STB_LOCAL
# ...                                            ...         ...         ...
# 234895  __SCK__tp_func_ext4_begin_ordered_truncate       .data  STB_GLOBAL
# 234896                               umd_load_blob       .text  STB_GLOBAL
# 234897                            __ia32_sys_times       .text  STB_GLOBAL
# 234898                      osnoise_trace_irq_exit       .text  STB_GLOBAL
# 234899                      early_memtest_bad_size        .bss  STB_GLOBAL
#
#                type   visibility             value  size
# ...
