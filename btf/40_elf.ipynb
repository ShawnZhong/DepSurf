# %%
from depsurf import ObjectFile, DATA_PATH

file = ObjectFile(DATA_PATH / "vmlinux" / "5.4.0-26-generic-amd64")

file.get_section_info()
# Out:
#                      name          type  flags     offset       size  link  \
# 0                              SHT_NULL      0          0          0     0
# 1              .head.text  SHT_PROGBITS      6      65536       4096     0
# 2                   .text  SHT_PROGBITS      6      69632   13854216     0
# 3                 .rodata  SHT_PROGBITS      3   13959168    6235530     0
# 4                .modinfo  SHT_PROGBITS      2   20194698      70832     0
# 5          .init.eh_frame  SHT_PROGBITS      2   20265536       7264     0
# 6              .pci_fixup  SHT_PROGBITS      2   20272800       9280     0
# 7               __ksymtab  SHT_PROGBITS      2   20282080      63876     0
# 8           __ksymtab_gpl  SHT_PROGBITS      2   20345956      70836     0
# 9       __ksymtab_strings  SHT_PROGBITS      2   20416792     222317     0
# 10                __param  SHT_PROGBITS      2   20639112      12120     0
# ...

# %%
df = file.get_symbol_info()

# %%
from depsurf import setup_pandas

setup_pandas()

# %%
df[df.name.str.contains("kconfig")]
# Out:
# Empty DataFrame
# Columns: [name, section, bind, type, visibility, value, size]
# Index: []

# %%
df[df.name.str.startswith("kallsyms_")]
# Out:
#                                       name     section        bind  \
# 18618                        kallsyms_init  .init.text   STB_LOCAL
# 18638   kallsyms_expand_symbol.constprop.0       .text   STB_LOCAL
# 18646              kallsyms_lookup_buildid       .text   STB_LOCAL
# 18648                kallsyms_lookup_names       .text   STB_LOCAL
# 18657                        kallsyms_open       .text   STB_LOCAL
# 18672                    kallsyms_proc_ops     .rodata   STB_LOCAL
# 18673                          kallsyms_op     .rodata   STB_LOCAL
# 21583                    kallsyms_callback       .text   STB_LOCAL
# 258246                kallsyms_token_table     .rodata  STB_GLOBAL
# 260263         kallsyms_lookup_size_offset       .text  STB_GLOBAL
# 263264                      kallsyms_names     .rodata  STB_GLOBAL
# 264605                kallsyms_symbol_next       .text  STB_GLOBAL
# 265156                   kallsyms_num_syms     .rodata  STB_GLOBAL
# ...

# %%
from depsurf import ObjectFile, DBGSYM_PATH

symtab = ObjectFile(DBGSYM_PATH / "6.5.0-27-generic").get_symbol_info()

symtab
# Out:
#                                               name     section        bind  \
# 0                                                    SHN_UNDEF   STB_LOCAL
# 1                                                        .text   STB_LOCAL
# 2                                                      .rodata   STB_LOCAL
# 3                                                   .pci_fixup   STB_LOCAL
# 4                                                   .tracedata   STB_LOCAL
# ...                                            ...         ...         ...
# 234895  __SCK__tp_func_ext4_begin_ordered_truncate       .data  STB_GLOBAL
# 234896                               umd_load_blob       .text  STB_GLOBAL
# 234897                            __ia32_sys_times       .text  STB_GLOBAL
# 234898                      osnoise_trace_irq_exit       .text  STB_GLOBAL
# 234899                      early_memtest_bad_size        .bss  STB_GLOBAL
#
#                type   visibility             value  size
# ...
