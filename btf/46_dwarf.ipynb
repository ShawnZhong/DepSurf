# %%
from depsurf import DBGSYM_PATH

from elftools.elf.elffile import ELFFile

f = open(DBGSYM_PATH / "6.5.0-27-generic", "rb")
elffile = ELFFile(f)
dwarfinfo = elffile.get_dwarf_info()

# %%
from collections import defaultdict

from depsurf import reload_depsurf

reload_depsurf()

from depsurf import (
    DIEHandler,
    Traverser,
    disable_dwarf_cache,
    get_name,
    SubroutineEntry,
)
from elftools.dwarf.die import DIE


subroutine_info = {}


def filter_subprogram(die: DIE):
    assert die.tag == "DW_TAG_subprogram"

    # ignore declaration-only subprograms
    decl = die.attributes.get("DW_AT_declaration")
    if decl is not None and decl.value:
        return False

    # ignore inlined subprograms as they will be accounted at the call site
    aa = die.attributes.get("DW_AT_abstract_origin")
    if aa is not None:
        return False

    return True


def get_entry(die: DIE, traverser: Traverser):
    name = get_name(die)
    if name is None:
        return None, None

    info_dict = subroutine_info.get(name)
    if info_dict is None:
        info_dict = defaultdict(SubroutineEntry)
        subroutine_info[name] = info_dict

    extern = die.attributes.get("DW_AT_external")
    if extern is not None:
        assert extern.value
        info = info_dict[name]
        info.external = True
    else:
        location = traverser.get_die_location(die)
        info = info_dict[location]
        info.external = False
    return info, name


def handle_subprogram(die: DIE, traverser: Traverser):
    get_entry(die, traverser)


def resolve_abstract_origin(die: DIE):
    if "DW_AT_abstract_origin" not in die.attributes:
        return die

    return resolve_abstract_origin(die.get_DIE_from_attribute("DW_AT_abstract_origin"))


def handle_call_impl(die: DIE, traverser: Traverser, is_inline: bool):
    fn_die = resolve_abstract_origin(die)
    entry, name = get_entry(fn_die, traverser)
    if entry is None:
        return

    if name == "vfs_read" and is_inline:
        print("found vfs_read")

    caller = traverser.curr_subprogram
    assert caller is not None
    if is_inline:
        entry.caller_inline.append(caller)
    else:
        entry.caller_func.append(caller)


def handle_call_site(die: DIE, traverser: Traverser):
    handle_call_impl(die, traverser, is_inline=False)


def handle_inlined_subroutine(die: DIE, traverser: Traverser):
    handle_call_impl(die, traverser, is_inline=True)


handler_map = {
    "DW_TAG_compile_unit": DIEHandler(show=True, rec=True),
    "DW_TAG_subprogram": DIEHandler(
        show=True,
        rec=True,
        filter_fn=filter_subprogram,
        handle_fn=handle_subprogram,
    ),
    "DW_TAG_inlined_subroutine": DIEHandler(
        show=True,
        rec=True,
        handle_fn=handle_inlined_subroutine,
    ),
    "DW_TAG_GNU_call_site": DIEHandler(
        show=True,
        rec=False,
        handle_fn=handle_call_site,
    ),
    "DW_TAG_lexical_block": DIEHandler(show=False, rec=True),
}


Traverser.enable_show = True
cu = next(cu for cu in dwarfinfo.iter_CUs() if cu.get_top_DIE().get_full_path().endswith("main.c"))
Traverser(cu, handler_map).traverse()
# Out:
# compile_unit: /build/linux-hwe-6.5-jkqeMi/linux-hwe-6.5-6.5.0/init/main.c
#   subprogram: console_on_rootfs
#     inlined_subroutine: IS_ERR
#   subprogram: kernel_init
#     inlined_subroutine: exit_boot_config
#     inlined_subroutine: mark_readonly
#       inlined_subroutine: rodata_test
#     inlined_subroutine: try_to_run_init_process
#     inlined_subroutine: try_to_run_init_process
#     inlined_subroutine: try_to_run_init_process
#     inlined_subroutine: try_to_run_init_process
#   subprogram: free_initmem
#     inlined_subroutine: free_initmem_default
#   subprogram: mark_readonly (Not declared inline but inlined by the compiler)
#   subprogram: set_debug_rodata
#   subprogram: arch_parse_debug_rodata (Declared inline and inlined by the compiler)
#   subprogram: kernel_init_freeable
#     inlined_subroutine: get_current
#     inlined_subroutine: task_pid
#     inlined_subroutine: get_pid
#       inlined_subroutine: refcount_inc
#         inlined_subroutine: __refcount_inc
#           inlined_subroutine: __refcount_add
#             inlined_subroutine: atomic_fetch_add_relaxed
#               inlined_subroutine: raw_atomic_fetch_add_relaxed
#                 inlined_subroutine: arch_atomic_fetch_add
#     inlined_subroutine: smp_prepare_cpus
#     inlined_subroutine: do_pre_smp_initcalls
#       inlined_subroutine: trace_initcall_level
#         inlined_subroutine: static_key_false
#           inlined_subroutine: arch_static_branch
#         inlined_subroutine: cpu_online
#           inlined_subroutine: cpumask_test_cpu
#             inlined_subroutine: _test_bit
#               inlined_subroutine: arch_test_bit
#                 inlined_subroutine: variable_test_bit
#         inlined_subroutine: __preempt_count_add
#         inlined_subroutine: trace_initcall_level
#           inlined_subroutine: __preempt_count_dec_and_test
#       inlined_subroutine: initcall_from_entry
#         inlined_subroutine: offset_to_ptr
#     inlined_subroutine: do_basic_setup
#   subprogram: try_to_run_init_process (Not declared inline but inlined by the compiler)
#   subprogram: run_init_process
#     inlined_subroutine: arch_static_branch
#     inlined_subroutine: arch_static_branch
#     inlined_subroutine: arch_static_branch
#     inlined_subroutine: arch_static_branch
#   subprogram: do_pre_smp_initcalls (Not declared inline but inlined by the compiler)
#   subprogram: do_basic_setup (Not declared inline but inlined by the compiler)
#   subprogram: do_initcalls
#     inlined_subroutine: do_initcall_level
#       inlined_subroutine: trace_initcall_level
#         inlined_subroutine: static_key_false
#           inlined_subroutine: arch_static_branch
#         inlined_subroutine: cpu_online
#           inlined_subroutine: cpumask_test_cpu
#             inlined_subroutine: _test_bit
#               inlined_subroutine: arch_test_bit
#                 inlined_subroutine: variable_test_bit
#         inlined_subroutine: __preempt_count_add
#         inlined_subroutine: trace_initcall_level
#           inlined_subroutine: __preempt_count_dec_and_test
#       inlined_subroutine: initcall_from_entry
#         inlined_subroutine: offset_to_ptr
#     inlined_subroutine: strcpy
#       inlined_subroutine: __fortify_strlen
#     inlined_subroutine: kzalloc
#       inlined_subroutine: kmalloc
#   subprogram: do_initcall_level (Not declared inline but inlined by the compiler)
#   subprogram: ignore_unknown_bootoption
#   subprogram: do_one_initcall
#     inlined_subroutine: arch_local_save_flags
#     inlined_subroutine: arch_irqs_disabled_flags
#     inlined_subroutine: preempt_count
#     inlined_subroutine: trace_initcall_start
#       inlined_subroutine: static_key_false
#         inlined_subroutine: arch_static_branch
#       inlined_subroutine: cpu_online
#         inlined_subroutine: cpumask_test_cpu
#           inlined_subroutine: _test_bit
#             inlined_subroutine: arch_test_bit
#               inlined_subroutine: variable_test_bit
#       inlined_subroutine: __preempt_count_add
#       inlined_subroutine: __preempt_count_dec_and_test
#     inlined_subroutine: trace_initcall_finish
#       inlined_subroutine: static_key_false
#         inlined_subroutine: arch_static_branch
#       inlined_subroutine: cpu_online
#         inlined_subroutine: cpumask_test_cpu
#           inlined_subroutine: _test_bit
#             inlined_subroutine: arch_test_bit
#               inlined_subroutine: variable_test_bit
#       inlined_subroutine: __preempt_count_add
#       inlined_subroutine: __preempt_count_dec_and_test
#     inlined_subroutine: preempt_count
#     inlined_subroutine: add_latent_entropy
#     inlined_subroutine: strlcat
#       inlined_subroutine: strnlen
#     inlined_subroutine: arch_local_irq_enable
#     inlined_subroutine: preempt_count_set
#   subprogram: trace_initcall_finish_cb
#     inlined_subroutine: ktime_us_delta
#       inlined_subroutine: ktime_to_us
#         inlined_subroutine: ktime_divns
#   subprogram: trace_initcall_start_cb
#     inlined_subroutine: get_current
#     inlined_subroutine: task_pid_nr
#   subprogram: initcall_blacklisted
#     inlined_subroutine: arch_static_branch
#     inlined_subroutine: list_empty
#   subprogram: initcall_blacklist
#     inlined_subroutine: arch_static_branch
#     inlined_subroutine: memblock_alloc
#     inlined_subroutine: __fortify_strlen
#     inlined_subroutine: memblock_alloc
#     inlined_subroutine: strcpy
#     inlined_subroutine: list_add
#       inlined_subroutine: __list_add
#     inlined_subroutine: __fortify_strlen
#   subprogram: do_ctors (Not declared inline but inlined by the compiler)
#   subprogram: print_unknown_bootoptions
#     inlined_subroutine: __fortify_strlen
#     inlined_subroutine: __fortify_strlen
#     inlined_subroutine: memblock_alloc
#   subprogram: early_randomize_kstack_offset
#   subprogram: initcall_debug_enable (Not declared inline but inlined by the compiler)
#   subprogram: trap_init
#   subprogram: thread_stack_cache_init
#   subprogram: smp_setup_processor_id
#   subprogram: arch_post_acpi_subsys_init
#   subprogram: do_early_param
#   subprogram: setup_command_line
#     inlined_subroutine: __fortify_strlen
#     inlined_subroutine: __fortify_strlen
#     inlined_subroutine: __fortify_strlen
#       inlined_subroutine: strnlen
#     inlined_subroutine: memblock_alloc
#     inlined_subroutine: memblock_alloc
#     inlined_subroutine: strcpy
#       inlined_subroutine: __fortify_strlen
#         inlined_subroutine: strnlen
#     inlined_subroutine: strcpy
#     inlined_subroutine: strcpy
#     inlined_subroutine: strcpy
#       inlined_subroutine: __fortify_strlen
#         inlined_subroutine: strnlen
#     inlined_subroutine: __fortify_strlen
#     inlined_subroutine: strcpy
#     inlined_subroutine: strcpy
#     inlined_subroutine: __fortify_strlen
#     inlined_subroutine: strcpy
#     inlined_subroutine: strcpy
#   subprogram: rdinit_setup
#   subprogram: init_setup
#   subprogram: unknown_bootoption
#     inlined_subroutine: __fortify_strlen
#     inlined_subroutine: obsolete_checksetup
#       inlined_subroutine: __fortify_strlen
#   subprogram: set_init_arg
#   subprogram: repair_env_string
#     inlined_subroutine: __fortify_strlen
#     inlined_subroutine: __fortify_strlen
#   subprogram: exit_boot_config (Not declared inline but inlined by the compiler)
#   subprogram: setup_boot_config
#     inlined_subroutine: get_boot_config_from_initrd
#       inlined_subroutine: memcmp
#       inlined_subroutine: xbc_calc_checksum
#     inlined_subroutine: strscpy
#       inlined_subroutine: strnlen
#     inlined_subroutine: IS_ERR
#   subprogram: warn_bootconfig
#   subprogram: bootconfig_params
#   subprogram: xbc_make_cmdline
#     inlined_subroutine: xbc_find_node
#     inlined_subroutine: memblock_alloc
#   subprogram: xbc_snprint_cmdline
#   subprogram: get_boot_config_from_initrd (Not declared inline but inlined by the compiler)
#   subprogram: loglevel
#   subprogram: quiet_kernel
#   subprogram: debug_kernel
#   subprogram: obsolete_checksetup (Not declared inline but inlined by the compiler)
#   subprogram: set_reset_devices
#   subprogram: kunit_run_all_tests (Declared inline and inlined by the compiler)
#   subprogram: __bpf_trace_initcall_finish
#   subprogram: __bpf_trace_initcall_start
#   subprogram: __bpf_trace_initcall_level
#   subprogram: perf_trace_initcall_finish
#     inlined_subroutine: trace_event_get_offsets_initcall_finish
#     inlined_subroutine: bpf_prog_array_valid
#     inlined_subroutine: perf_fetch_caller_regs
#     inlined_subroutine: hlist_empty
#   subprogram: perf_trace_initcall_start
#     inlined_subroutine: trace_event_get_offsets_initcall_start
#     inlined_subroutine: bpf_prog_array_valid
#     inlined_subroutine: perf_fetch_caller_regs
#     inlined_subroutine: hlist_empty
#   subprogram: perf_trace_initcall_level
#     inlined_subroutine: trace_event_get_offsets_initcall_level
#       inlined_subroutine: __fortify_strlen
#     inlined_subroutine: bpf_prog_array_valid
#     inlined_subroutine: perf_fetch_caller_regs
#     inlined_subroutine: strcpy
#     inlined_subroutine: hlist_empty
#   subprogram: trace_event_raw_event_initcall_finish
#     inlined_subroutine: trace_trigger_soft_disabled
#     inlined_subroutine: trace_event_get_offsets_initcall_finish
#   subprogram: trace_event_raw_event_initcall_start
#     inlined_subroutine: trace_trigger_soft_disabled
#     inlined_subroutine: trace_event_get_offsets_initcall_start
#   subprogram: trace_event_raw_event_initcall_level
#     inlined_subroutine: trace_trigger_soft_disabled
#     inlined_subroutine: trace_event_get_offsets_initcall_level
#       inlined_subroutine: __fortify_strlen
#     inlined_subroutine: strcpy
#   subprogram: trace_event_get_offsets_initcall_finish (Declared inline and inlined by the compiler)
#   subprogram: trace_event_get_offsets_initcall_start (Declared inline and inlined by the compiler)
#   subprogram: trace_event_get_offsets_initcall_level (Declared inline and inlined by the compiler)
#   subprogram: trace_raw_output_initcall_finish
#   subprogram: trace_raw_output_initcall_start
#   subprogram: trace_raw_output_initcall_level
#   subprogram: __probestub_initcall_finish
#   subprogram: __traceiter_initcall_finish
#   subprogram: __probestub_initcall_start
#   subprogram: __traceiter_initcall_start
#   subprogram: __probestub_initcall_level
#   subprogram: __traceiter_initcall_level
#   subprogram: register_trace_initcall_finish (Declared inline and inlined by the compiler)
#   subprogram: trace_initcall_finish (Declared inline and inlined by the compiler)
#   subprogram: register_trace_initcall_start (Declared inline and inlined by the compiler)
#   subprogram: trace_initcall_start (Declared inline and inlined by the compiler)
#   subprogram: trace_initcall_level (Declared inline and inlined by the compiler)
#   subprogram: rodata_test (Declared inline and inlined by the compiler)
#   subprogram: context_tracking_init (Declared inline and inlined by the compiler)
#   subprogram: efi_enabled (Declared inline and inlined by the compiler)
#   subprogram: set_mems_allowed
#     inlined_subroutine: get_current
#     inlined_subroutine: task_lock
#       inlined_subroutine: spin_lock
#     inlined_subroutine: arch_local_irq_save
#       inlined_subroutine: arch_local_save_flags
#       inlined_subroutine: arch_local_irq_disable
#     inlined_subroutine: get_current
#     inlined_subroutine: do_write_seqcount_begin
#       inlined_subroutine: do_write_seqcount_begin_nested
#         inlined_subroutine: do_raw_write_seqcount_begin
#     inlined_subroutine: get_current
#     inlined_subroutine: get_current
#     inlined_subroutine: do_write_seqcount_end
#       inlined_subroutine: do_raw_write_seqcount_end
#     inlined_subroutine: arch_local_irq_restore
#       inlined_subroutine: arch_irqs_disabled_flags
#       inlined_subroutine: arch_local_irq_enable
#     inlined_subroutine: get_current
#     inlined_subroutine: task_unlock
#       inlined_subroutine: spin_unlock
#   subprogram: rest_init
#     inlined_subroutine: rcu_read_lock
#     inlined_subroutine: get_cpu_mask
#     inlined_subroutine: rcu_read_unlock
#     inlined_subroutine: rcu_read_lock
#     inlined_subroutine: rcu_read_unlock
#   subprogram: arch_call_rest_init
#   subprogram: start_kernel
#     inlined_subroutine: arch_local_save_flags
#     inlined_subroutine: arch_irqs_disabled_flags
#     inlined_subroutine: arch_local_save_flags
#     inlined_subroutine: arch_irqs_disabled_flags
#     inlined_subroutine: arch_local_irq_disable
#     inlined_subroutine: smp_prepare_boot_cpu
#     inlined_subroutine: IS_ERR_OR_NULL
#     inlined_subroutine: boot_init_stack_canary
#       inlined_subroutine: get_random_canary
#         inlined_subroutine: get_random_long
#       inlined_subroutine: get_current
#     inlined_subroutine: arch_local_irq_enable
#     inlined_subroutine: efi_enabled
#       inlined_subroutine: _test_bit
#         inlined_subroutine: arch_test_bit
#           inlined_subroutine: constant_test_bit
#     inlined_subroutine: initcall_debug_enable
#       inlined_subroutine: register_trace_initcall_start
#       inlined_subroutine: register_trace_initcall_finish
#     inlined_subroutine: __phys_addr_nodebug
#     inlined_subroutine: arch_local_irq_disable
#   subprogram: xbc_get_embedded_bootconfig (Declared inline and inlined by the compiler)
#   subprogram: xbc_find_node (Declared inline and inlined by the compiler)
#   subprogram: xbc_calc_checksum (Declared inline and inlined by the compiler)
#   subprogram: memblock_alloc (Declared inline and inlined by the compiler)
#   subprogram: boot_init_stack_canary (Declared inline and inlined by the compiler)
#   subprogram: get_random_canary (Declared inline and inlined by the compiler)
#   subprogram: trace_trigger_soft_disabled (Declared inline and inlined by the compiler)
#   subprogram: bpf_prog_array_valid (Declared inline and inlined by the compiler)
#   subprogram: perf_fetch_caller_regs (Declared inline and inlined by the compiler)
#   subprogram: free_initmem_default (Declared inline and inlined by the compiler)
#   subprogram: pgtable_cache_init
#   subprogram: kzalloc (Declared inline and inlined by the compiler)
#   subprogram: kmalloc (Declared inline and inlined by the compiler)
#   subprogram: __kmalloc_index (Declared inline and inlined by the compiler)
#   subprogram: kmalloc_type (Declared inline and inlined by the compiler)
#   subprogram: task_unlock (Declared inline and inlined by the compiler)
#   subprogram: task_lock (Declared inline and inlined by the compiler)
#   subprogram: poking_init
#   subprogram: task_pid_nr (Declared inline and inlined by the compiler)
#   subprogram: task_pid (Declared inline and inlined by the compiler)
#   subprogram: kcsan_init (Declared inline and inlined by the compiler)
#   subprogram: get_pid (Declared inline and inlined by the compiler)
#   subprogram: get_random_long (Declared inline and inlined by the compiler)
#   subprogram: add_latent_entropy (Declared inline and inlined by the compiler)
#   subprogram: do_write_seqcount_end (Declared inline and inlined by the compiler)
#   subprogram: do_write_seqcount_begin (Declared inline and inlined by the compiler)
#   subprogram: do_write_seqcount_begin_nested (Declared inline and inlined by the compiler)
#   subprogram: do_raw_write_seqcount_end (Declared inline and inlined by the compiler)
#   subprogram: do_raw_write_seqcount_begin (Declared inline and inlined by the compiler)
#   subprogram: __seqprop_spinlock_assert (Declared inline and inlined by the compiler)
#   subprogram: __seqprop_spinlock_preemptible (Declared inline and inlined by the compiler)
#   subprogram: __seqprop_spinlock_ptr (Declared inline and inlined by the compiler)
#   subprogram: debug_objects_early_init (Declared inline and inlined by the compiler)
#   subprogram: ktime_us_delta (Declared inline and inlined by the compiler)
#   subprogram: ktime_to_us (Declared inline and inlined by the compiler)
#   subprogram: ktime_divns (Declared inline and inlined by the compiler)
#   subprogram: rcu_read_unlock (Declared inline and inlined by the compiler)
#   subprogram: rcu_read_lock (Declared inline and inlined by the compiler)
#   subprogram: rcu_init_nohz (Declared inline and inlined by the compiler)
#   subprogram: refcount_inc (Declared inline and inlined by the compiler)
#   subprogram: __refcount_inc (Declared inline and inlined by the compiler)
#   subprogram: __refcount_add (Declared inline and inlined by the compiler)
#   subprogram: spin_unlock (Declared inline and inlined by the compiler)
#   subprogram: spin_lock (Declared inline and inlined by the compiler)
#   subprogram: smp_prepare_cpus (Declared inline and inlined by the compiler)
#   subprogram: smp_prepare_boot_cpu (Declared inline and inlined by the compiler)
#   subprogram: __preempt_count_dec_and_test (Declared inline and inlined by the compiler)
#   subprogram: __preempt_count_add (Declared inline and inlined by the compiler)
#   subprogram: preempt_count_set (Declared inline and inlined by the compiler)
#   subprogram: preempt_count (Declared inline and inlined by the compiler)
#   subprogram: arch_local_irq_restore (Declared inline and inlined by the compiler)
#   subprogram: arch_irqs_disabled_flags (Declared inline and inlined by the compiler)
#   subprogram: __phys_addr_nodebug (Declared inline and inlined by the compiler)
#   subprogram: arch_local_irq_save (Declared inline and inlined by the compiler)
#   subprogram: arch_local_irq_enable (Declared inline and inlined by the compiler)
#   subprogram: arch_local_irq_disable (Declared inline and inlined by the compiler)
#   subprogram: arch_local_save_flags (Declared inline and inlined by the compiler)
#   subprogram: cpu_online (Declared inline and inlined by the compiler)
#   subprogram: get_cpu_mask (Declared inline and inlined by the compiler)
#   subprogram: cpumask_test_cpu (Declared inline and inlined by the compiler)
#   subprogram: cpumask_check (Declared inline and inlined by the compiler)
#   subprogram: cpu_max_bits_warn (Declared inline and inlined by the compiler)
#   subprogram: atomic_fetch_add_relaxed (Declared inline and inlined by the compiler)
#   subprogram: raw_atomic_fetch_add_relaxed (Declared inline and inlined by the compiler)
#   subprogram: arch_atomic_fetch_add (Declared inline and inlined by the compiler)
#   subprogram: strcpy (Declared inline and inlined by the compiler)
#   subprogram: memcmp (Declared inline and inlined by the compiler)
#   subprogram: fortify_memcpy_chk (Declared inline and inlined by the compiler)
#   subprogram: strlcat (Declared inline and inlined by the compiler)
#   subprogram: strscpy (Declared inline and inlined by the compiler)
#   subprogram: __fortify_strlen (Declared inline and inlined by the compiler)
#   subprogram: strnlen (Declared inline and inlined by the compiler)
#   subprogram: IS_ERR_OR_NULL (Declared inline and inlined by the compiler)
#   subprogram: IS_ERR (Declared inline and inlined by the compiler)
#   subprogram: get_current (Declared inline and inlined by the compiler)
#   subprogram: __this_cpu_preempt_check (Declared inline and inlined by the compiler)
#   subprogram: _test_bit (Declared inline and inlined by the compiler)
#   subprogram: instrument_atomic_read_write (Declared inline and inlined by the compiler)
#   subprogram: instrument_atomic_read (Declared inline and inlined by the compiler)
#   subprogram: arch_test_bit (Declared inline and inlined by the compiler)
#   subprogram: variable_test_bit (Declared inline and inlined by the compiler)
#   subprogram: constant_test_bit (Declared inline and inlined by the compiler)
#   subprogram: const_test_bit (Declared inline and inlined by the compiler)
#   subprogram: static_key_false (Declared inline and inlined by the compiler)
#   subprogram: arch_static_branch (Declared inline and inlined by the compiler)
#   subprogram: parse_early_options (Not declared inline but inlined by the compiler)
#   subprogram: parse_early_param
#     inlined_subroutine: strscpy
#       inlined_subroutine: strnlen
#     inlined_subroutine: parse_early_options
#   subprogram: initcall_from_entry (Declared inline and inlined by the compiler)
#   subprogram: hlist_empty (Declared inline and inlined by the compiler)
#   subprogram: list_empty (Declared inline and inlined by the compiler)
#   subprogram: list_add (Declared inline and inlined by the compiler)
#   subprogram: __list_add (Declared inline and inlined by the compiler)
#   subprogram: __list_add_valid (Declared inline and inlined by the compiler)
#   subprogram: kcsan_check_access
#   subprogram: kcsan_nestable_atomic_end (Declared inline and inlined by the compiler)
#   subprogram: kcsan_nestable_atomic_begin (Declared inline and inlined by the compiler)
#   subprogram: kasan_check_write
#   subprogram: kasan_check_read
#   subprogram: offset_to_ptr (Declared inline and inlined by the compiler)

# %%
from depsurf import disable_dwarf_cache

disable_dwarf_cache()

Traverser.enable_show = False
for cu in dwarfinfo.iter_CUs():
    Traverser(cu, handler_map).traverse()

# %%
import pickle

with open("subroutine_info.pkl", "wb") as f:
    pickle.dump(subroutine_info, f)
