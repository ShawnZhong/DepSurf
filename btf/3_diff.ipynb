# %%
# %%html
#
# <style>
# th {
#     text-align: left;
# }
# </style>
# Out:
# <style>
# th {
#     text-align: left;
# }
# </style>

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from utils import Kind, BTF

btf1 = BTF("data/20.04-x86/5.13.0-52-generic.jsonl")
btf2 = BTF("data/20.04-x86/5.15.0-92-generic.jsonl")
btf2.print()
# Out:
# File: data/20.04-x86/5.15.0-92-generic.jsonl
# Sample:
# 	INT       : {'kind': 'INT', 'name': 'long unsigned int'}
# 	CONST     : {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'INT', 'name': 'long unsigned int'}}
# 	VOLATILE  : {'kind': 'VOLATILE', 'name': '(anon)', 'type': {'kind': 'INT', 'name': 'long unsigned int'}}
# 	ARRAY     : {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 2, 'type': {'kind': 'INT', 'name': 'long unsigned int'}}
# 	PTR       : {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'INT', 'name': 'char'}}}
# 	TYPEDEF   : {'kind': 'TYPEDEF', 'name': '__s8', 'type': {'kind': 'INT', 'name': 'signed char'}}
# 	ENUM      : {'kind': 'ENUM', 'name': '(anon)', 'size': 4, 'values': [{'name': 'false', 'val': 0}, {'name': 'true', 'val': 1}]}
# 	FUNC_PROTO: {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}
# 	STRUCT    : {'kind': 'STRUCT', 'name': '(anon)', 'size': 4, 'members': [{'name': 'counter', 'bits_offset': 0, 'type': {'kind': 'INT', 'name': 'int'}}]}
# 	UNION     : {'kind': 'UNION', 'name': '(anon)', 'size': 4, 'members': [{'name': 'val', 'bits_offset': 0, 'type': {'kind': 'TYPEDEF', 'name': 'atomic_t'}}, {'name': '(anon)', 'bits_offset': 0, 'type': {'kind': 'STRUCT', 'name': '(anon)'}}, {'name': '(anon-1)', 'bits_offset': 0, 'type': {'kind': 'STRUCT', 'name': '(anon)'}}]}
# 	FWD       : {'kind': 'FWD', 'name': 'tick_device', 'fwd_kind': 'struct'}
# 	FUNC      : {'kind': 'FUNC', 'name': 'startup_64_setup_env', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': 'physbase', 'type': {'kind': 'INT', 'name': 'long unsigned int'}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
# 	FLOAT     : {'kind': 'FLOAT', 'name': 'double', 'size': 8}
# 	RESTRICT  : {'kind': 'RESTRICT', 'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'INT', 'name': 'char'}}}}
# Kinds: {'FUNC': 53335, 'FUNC_PROTO': 27938, 'PTR': 14488, 'STRUCT': 10313, 'ARRAY': 3479, 'CONST': 2946, 'ENUM': 2095, 'TYPEDEF': 2042, 'UNION': 1619, 'FWD': 194, 'VOLATILE': 28, 'INT': 15, 'FLOAT': 2, 'RESTRICT': 2}

# %%
# btf1.get(Kind.UNION, "intel_x86_pebs_dse")
# btf1.get(Kind.STRUCT, "task_struct")
# btf1.get(Kind.FUNC, "vfs_read")
btf1.get(Kind.ENUM, "nf_ip_hook_priorities")
# Out:
# {'kind': 'ENUM',
#  'name': 'nf_ip_hook_priorities',
#  'size': 4,
#  'values': [{'name': 'NF_IP_PRI_FIRST', 'val': -2147483648},
#   {'name': 'NF_IP_PRI_RAW_BEFORE_DEFRAG', 'val': -450},
#   {'name': 'NF_IP_PRI_CONNTRACK_DEFRAG', 'val': -400},
#   {'name': 'NF_IP_PRI_RAW', 'val': -300},
#   {'name': 'NF_IP_PRI_SELINUX_FIRST', 'val': -225},
#   {'name': 'NF_IP_PRI_CONNTRACK', 'val': -200},
#   {'name': 'NF_IP_PRI_MANGLE', 'val': -150},
#   {'name': 'NF_IP_PRI_NAT_DST', 'val': -100},
#   {'name': 'NF_IP_PRI_FILTER', 'val': 0},
#   {'name': 'NF_IP_PRI_SECURITY', 'val': 50},
#   {'name': 'NF_IP_PRI_NAT_SRC', 'val': 100},
#   {'name': 'NF_IP_PRI_SELINUX_LAST', 'val': 225},
#   {'name': 'NF_IP_PRI_CONNTRACK_HELPER', 'val': 300},
#   {'name': 'NF_IP_PRI_CONNTRACK_CONFIRM', 'val': 2147483647},
#   {'name': 'NF_IP_PRI_LAST', 'val': 2147483647}]}

# %%
from utils import check_diff_impl

# %%
from utils import diff_struct, StructChange

t = (Kind.STRUCT, "task_struct")
diff_struct(btf1.get(t), btf2.get(t))

# check_diff_impl(
#     btf1.filter(Kind.STRUCT),
#     btf2.filter(Kind.STRUCT),
#     Kind.STRUCT,
#     diff_struct,
#     StructChange,
# )
# Out:
# [(<StructChange.ADD: 'Field added'>,
#   ["__state             : {'kind': 'INT', 'name': 'unsigned int'}",
#    "core_node           : {'kind': 'STRUCT', 'name': 'rb_node'}",
#    "core_cookie         : {'kind': 'INT', 'name': 'long unsigned int'}",
#    "core_occupation     : {'kind': 'INT', 'name': 'unsigned int'}",
#    "stats               : {'kind': 'STRUCT', 'name': 'sched_statistics'}",
#    "user_cpus_ptr       : {'kind': 'PTR', 'type': {'kind': 'TYPEDEF', 'name': 'cpumask_t'}}",
#    "in_eventfd          : {'kind': 'INT', 'name': 'unsigned int'}",
#    "in_ubsan            : {'kind': 'INT', 'name': 'unsigned int'}",
#    "oom_reaper_timer    : {'kind': 'STRUCT', 'name': 'timer_list'}",
#    "bpf_ctx             : {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'bpf_run_ctx'}}",
#    "l1d_flush_kill      : {'kind': 'STRUCT', 'name': 'callback_head'}"]),
#  (<StructChange.REMOVE: 'Field removed'>,
#   ["state               : {'kind': 'VOLATILE', 'name': '(anon)', 'type': {'kind': 'INT', 'name': 'long int'}}"]),
#  (<StructChange.LAYOUT: 'Layout changed'>, [])]

# %%
t = (Kind.UNION, "security_list_options")
diff_struct(btf1.get(t), btf2.get(t))

# check_diff_impl(
#     btf1.filter(Kind.UNION),
#     btf2.filter(Kind.UNION),
#     Kind.UNION,
#     diff_struct,
#     StructChange,
# )
# Out:
# [(<StructChange.TYPE: 'Field type changed'>,
#   ["binder_set_context_mgr: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'task_struct'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}\n                    ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'cred'}}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}",
#    "binder_transaction  : {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'task_struct'}}}, {'name': '(anon-1)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'task_struct'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}\n                    ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'cred'}}}}, {'name': '(anon-1)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'cred'}}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}",
#    "binder_transfer_binder: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'task_struct'}}}, {'name': '(anon-1)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'task_struct'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}\n                    ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'cred'}}}}, {'name': '(anon-1)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'cred'}}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}",
#    "binder_transfer_file: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'task_struct'}}}, {'name': '(anon-1)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'task_struct'}}}, {'name': '(anon-2)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'file'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}\n                    ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'cred'}}}}, {'name': '(anon-1)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'cred'}}}}, {'name': '(anon-2)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'file'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}",
#    "xfrm_policy_lookup  : {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'xfrm_sec_ctx'}}}, {'name': '(anon-1)', 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}, {'name': '(anon-2)', 'type': {'kind': 'TYPEDEF', 'name': 'u8'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}\n                    ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'xfrm_sec_ctx'}}}, {'name': '(anon-1)', 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}"])]

# %%
from utils import diff_func, FuncChange

t = (Kind.FUNC, "do_syscall_64")
diff_func(btf1.get(t), btf2.get(t))

# check_diff_impl(
#     btf1.filter(Kind.FUNC),
#     btf2.filter(Kind.FUNC),
#     Kind.FUNC,
#     diff_func,
#     FuncChange,
# )
# Out:
# [(<FuncChange.REORDER: 'Param reordered'>,
#   ["                     ['nr', 'regs']\n                     ['regs', 'nr']"]),
#  (<FuncChange.TYPE: 'Param type changed'>,
#   ["nr                  : {'kind': 'INT', 'name': 'long unsigned int'}\n                    ->{'kind': 'INT', 'name': 'int'}"])]

# %%
from utils import diff_enum, EnumChange

t = (Kind.ENUM, "bpf_func_id")
diff_enum(btf1.get(t), btf2.get(t))


# check_diff_impl(
#     btf1.filter(Kind.ENUM),
#     btf2.filter(Kind.ENUM),
#     Kind.ENUM,
#     diff_enum,
#     EnumChange,
# )
# Out:
# [(<EnumChange.ADD: 'Elem added'>,
#   ['BPF_FUNC_sys_bpf                        : 166',
#    'BPF_FUNC_btf_find_by_name_kind          : 167',
#    'BPF_FUNC_sys_close                      : 168',
#    'BPF_FUNC_timer_init                     : 169',
#    'BPF_FUNC_timer_set_callback             : 170',
#    'BPF_FUNC_timer_start                    : 171',
#    'BPF_FUNC_timer_cancel                   : 172',
#    'BPF_FUNC_get_func_ip                    : 173',
#    'BPF_FUNC_get_attach_cookie              : 174',
#    'BPF_FUNC_task_pt_regs                   : 175']),
#  (<EnumChange.VALUE: 'Value changed'>,
#   ['__BPF_FUNC_MAX_ID                       : 166 -> 176'])]

# %%
from utils import FileLogger
    
        
def check_diff(dict1, dict2, kind, output_path):
    diff_fn = {
        Kind.STRUCT: diff_struct,
        Kind.UNION: diff_struct,
        Kind.FUNC: diff_func,
        Kind.ENUM: diff_enum,
    }[kind]
    all_reasons = {
        Kind.STRUCT: StructChange,
        Kind.UNION: StructChange,
        Kind.FUNC: FuncChange,
        Kind.ENUM: EnumChange,
    }[kind]
    with FileLogger(output_path):
        return check_diff_impl(dict1, dict2, kind, diff_fn, all_reasons)

# %%
def get_lsm(btf):
    return {
        f"security_{e['name']}"
        for e in btf.get(Kind.STRUCT, "security_hook_heads")["members"]
    }


len(get_lsm(btf1))
# Out:
# 239

# %%
import pandas as pd
from pathlib import Path

pd.set_option("display.max_rows", None)


def diff_btf(btf1, btf2, group, name):
    path = Path("output") / group / name
    print(f"Results saving to {path}")

    lsm_hooks = get_lsm(btf1) | get_lsm(btf2)

    results = {}
    for key, kind, filter in [
        ("trace_event", Kind.STRUCT, lambda k: k.startswith("trace_event_raw_")),
        ("raw_tp", Kind.FUNC, lambda k: k.startswith("perf_trace_")),
        ("lsm", Kind.FUNC, lambda k: k in lsm_hooks),
        ("func", Kind.FUNC, None),
        ("struct", Kind.STRUCT, None),
        ("union", Kind.UNION, None),
        ("enum", Kind.ENUM, None),
    ]:
        dict1 = btf1.filter(kind, filter)
        dict2 = btf2.filter(kind, filter)

        output_path = path / f"{key}.log"
        diff_result = check_diff(dict1, dict2, kind, output_path)
        results[(key, "Old")] = len(dict1)
        results[(key, "New")] = len(dict2)
        results[(key, "Common")] = len(diff_result.common)
        results[(key, "Added")] = len(diff_result.added)
        results[(key, "Removed")] = len(diff_result.removed)
        results[(key, "Changed")] = len(diff_result.changed)
        for k, v in diff_result.reasons.items():
            results[(key, f"- {k}")] = v

    df = pd.DataFrame(
        results.values(),
        index=pd.MultiIndex.from_tuples(results.keys()),
        columns=[name],
    )
    df.to_string(path / "summary.txt")
    df.to_pickle(path / "summary.pkl")
    return df


diff_btf(
    btf1,
    btf2,
    "20.04",
    "5.13->5.15",
)
# Out:
# Results saving to output/20.04/5.13->5.15
# Logging to output/20.04/5.13->5.15/trace_event.log
# Logging to output/20.04/5.13->5.15/raw_tp.log
# Logging to output/20.04/5.13->5.15/lsm.log
# Logging to output/20.04/5.13->5.15/func.log
# Logging to output/20.04/5.13->5.15/struct.log
# Logging to output/20.04/5.13->5.15/union.log
# Logging to output/20.04/5.13->5.15/enum.log
#                                    5.13->5.15
# trace_event Old                           523
#             New                           525
#             Common                        508
#             Added                          17
#             Removed                        15
#             Changed                        17
#             - Field added                   6
#             - Field removed                 2
#             - Field type changed           10
#             - Layout changed               14
# raw_tp      Old                           531
#             New                           533
#             Common                        516
#             Added                          17
#             Removed                        15
#             Changed                        10
#             - Param added                   4
#             - Param removed                 0
#             - Param type changed            6
#             - Param reordered               3
#             - Return type changed           0
# lsm         Old                           203
#             New                           203
#             Common                        203
#             Added                           0
#             Removed                         0
#             Changed                         5
#             - Param added                   0
#             - Param removed                 1
#             - Param type changed            4
#             - Param reordered               0
#             - Return type changed           0
# func        Old                         52337
#             New                         53335
#             Common                      51214
#             Added                        2121
#             Removed                      1123
#             Changed                       640
#             - Param added                 298
#             - Param removed               194
#             - Param type changed          214
#             - Param reordered             104
#             - Return type changed         111
# struct      Old                          9216
#             New                          9382
#             Common                       9099
#             Added                         283
#             Removed                       117
#             Changed                       656
#             - Field added                 365
#             - Field removed               163
#             - Field type changed          140
#             - Layout changed              605
# union       Old                           147
#             New                           150
#             Common                        147
#             Added                           3
#             Removed                         0
#             Changed                         4
#             - Field added                   1
#             - Field removed                 1
#             - Field type changed            1
#             - Layout changed                3
# enum        Old                          1361
#             New                          1390
#             Common                       1341
#             Added                          49
#             Removed                        20
#             Changed                        66
#             - Elem added                   60
#             - Elem removed                 13
#             - Value changed                35

# %%
def get_json_paths(path):
    return sorted(
        (file for file in path.glob("*.jsonl")),
        key=lambda name: tuple(map(int, name.stem.split("-")[0].split("."))),
    )


get_json_paths(Path("data/18.04-x86"))
# Out:
# [PosixPath('data/18.04-x86/4.15.0-213-generic.jsonl'),
#  PosixPath('data/18.04-x86/4.18.0-25-generic.jsonl'),
#  PosixPath('data/18.04-x86/5.0.0-65-generic.jsonl'),
#  PosixPath('data/18.04-x86/5.3.0-76-generic.jsonl'),
#  PosixPath('data/18.04-x86/5.4.0-91-generic.jsonl')]

# %%
def short_name(path):
    linux_version = path.name.split("-")[0]
    assert linux_version.endswith(".0")
    return linux_version[:-2]


short_name(Path("data/18.04-x86/4.15.0-213-generic.jsonl"))
# Out:
# '4.15'

# %%
from dataclasses import dataclass
from typing import Optional


@dataclass
class DiffPair:
    old: Path
    new: Path
    group: str
    name: Optional[str] = None

    def __post_init__(self):
        if not self.name:
            self.name = f"{short_name(self.old)}->{short_name(self.new)}"

    def diff(self):
        return diff_btf(BTF(self.old), BTF(self.new), self.group, self.name)


diff_pairs = []

for d in sorted(Path("data").glob("*")):
    if not d.is_dir():
        continue

    paths = get_json_paths(d)
    if len(paths) < 2:
        continue

    group = d.name.split("-")[0]

    for i in range(len(paths) - 1):
        diff_pairs.append(DiffPair(paths[i], paths[i + 1], group))

    diff_pairs.append(DiffPair(paths[0], paths[-1], group, "Total"))

diff_pairs.append(
    DiffPair(
        Path("data/20.04-x86/5.8.0-63-generic.jsonl"),
        Path("data/20.04-arm64/5.8.0-63-generic.jsonl"),
        group="20.04",
        name="x86->arm64",
    )
)

diff_pairs
# Out:
# [DiffPair(old=PosixPath('data/16.04-x86/4.4.0-210-generic.jsonl'), new=PosixPath('data/16.04-x86/4.8.0-58-generic.jsonl'), group='16.04', name='4.4->4.8'),
#  DiffPair(old=PosixPath('data/16.04-x86/4.8.0-58-generic.jsonl'), new=PosixPath('data/16.04-x86/4.10.0-42-generic.jsonl'), group='16.04', name='4.8->4.10'),
#  DiffPair(old=PosixPath('data/16.04-x86/4.10.0-42-generic.jsonl'), new=PosixPath('data/16.04-x86/4.13.0-45-generic.jsonl'), group='16.04', name='4.10->4.13'),
#  DiffPair(old=PosixPath('data/16.04-x86/4.13.0-45-generic.jsonl'), new=PosixPath('data/16.04-x86/4.15.0-142-generic.jsonl'), group='16.04', name='4.13->4.15'),
#  DiffPair(old=PosixPath('data/16.04-x86/4.4.0-210-generic.jsonl'), new=PosixPath('data/16.04-x86/4.15.0-142-generic.jsonl'), group='16.04', name='Total'),
#  DiffPair(old=PosixPath('data/18.04-x86/4.15.0-213-generic.jsonl'), new=PosixPath('data/18.04-x86/4.18.0-25-generic.jsonl'), group='18.04', name='4.15->4.18'),
#  DiffPair(old=PosixPath('data/18.04-x86/4.18.0-25-generic.jsonl'), new=PosixPath('data/18.04-x86/5.0.0-65-generic.jsonl'), group='18.04', name='4.18->5.0'),
#  DiffPair(old=PosixPath('data/18.04-x86/5.0.0-65-generic.jsonl'), new=PosixPath('data/18.04-x86/5.3.0-76-generic.jsonl'), group='18.04', name='5.0->5.3'),
#  DiffPair(old=PosixPath('data/18.04-x86/5.3.0-76-generic.jsonl'), new=PosixPath('data/18.04-x86/5.4.0-91-generic.jsonl'), group='18.04', name='5.3->5.4'),
#  DiffPair(old=PosixPath('data/18.04-x86/4.15.0-213-generic.jsonl'), new=PosixPath('data/18.04-x86/5.4.0-91-generic.jsonl'), group='18.04', name='Total'),
#  DiffPair(old=PosixPath('data/20.04-x86/5.4.0-170-generic.jsonl'), new=PosixPath('data/20.04-x86/5.8.0-63-generic.jsonl'), group='20.04', name='5.4->5.8'),
#  DiffPair(old=PosixPath('data/20.04-x86/5.8.0-63-generic.jsonl'), new=PosixPath('data/20.04-x86/5.11.0-46-generic.jsonl'), group='20.04', name='5.8->5.11'),
#  DiffPair(old=PosixPath('data/20.04-x86/5.11.0-46-generic.jsonl'), new=PosixPath('data/20.04-x86/5.13.0-52-generic.jsonl'), group='20.04', name='5.11->5.13'),
#  DiffPair(old=PosixPath('data/20.04-x86/5.13.0-52-generic.jsonl'), new=PosixPath('data/20.04-x86/5.15.0-92-generic.jsonl'), group='20.04', name='5.13->5.15'),
#  DiffPair(old=PosixPath('data/20.04-x86/5.4.0-170-generic.jsonl'), new=PosixPath('data/20.04-x86/5.15.0-92-generic.jsonl'), group='20.04', name='Total'),
#  DiffPair(old=PosixPath('data/20.04-x86/5.8.0-63-generic.jsonl'), new=PosixPath('data/20.04-arm64/5.8.0-63-generic.jsonl'), group='20.04', name='x86->arm64')]

# %%
results = {}

for pair in diff_pairs:
    results[(pair.group, pair.name)] = pair.diff()
# Out:
# Results saving to output/16.04/4.4->4.8
# Logging to output/16.04/4.4->4.8/trace_event.log
# Logging to output/16.04/4.4->4.8/raw_tp.log
# Logging to output/16.04/4.4->4.8/lsm.log
# Logging to output/16.04/4.4->4.8/func.log
# Logging to output/16.04/4.4->4.8/struct.log
# Logging to output/16.04/4.4->4.8/union.log
# Logging to output/16.04/4.4->4.8/enum.log
# Results saving to output/16.04/4.8->4.10
# Logging to output/16.04/4.8->4.10/trace_event.log
# Logging to output/16.04/4.8->4.10/raw_tp.log
# Logging to output/16.04/4.8->4.10/lsm.log
# Logging to output/16.04/4.8->4.10/func.log
# Logging to output/16.04/4.8->4.10/struct.log
# Logging to output/16.04/4.8->4.10/union.log
# Logging to output/16.04/4.8->4.10/enum.log
# Results saving to output/16.04/4.10->4.13
# Logging to output/16.04/4.10->4.13/trace_event.log
# Logging to output/16.04/4.10->4.13/raw_tp.log
# Logging to output/16.04/4.10->4.13/lsm.log
# Logging to output/16.04/4.10->4.13/func.log
# Logging to output/16.04/4.10->4.13/struct.log
# Logging to output/16.04/4.10->4.13/union.log
# Logging to output/16.04/4.10->4.13/enum.log
# Results saving to output/16.04/4.13->4.15
# Logging to output/16.04/4.13->4.15/trace_event.log
# Logging to output/16.04/4.13->4.15/raw_tp.log
# Logging to output/16.04/4.13->4.15/lsm.log
# Logging to output/16.04/4.13->4.15/func.log
# Logging to output/16.04/4.13->4.15/struct.log
# Logging to output/16.04/4.13->4.15/union.log
# Logging to output/16.04/4.13->4.15/enum.log
# Results saving to output/16.04/Total
# Logging to output/16.04/Total/trace_event.log
# Logging to output/16.04/Total/raw_tp.log
# Logging to output/16.04/Total/lsm.log
# Logging to output/16.04/Total/func.log
# Logging to output/16.04/Total/struct.log
# Logging to output/16.04/Total/union.log
# Logging to output/16.04/Total/enum.log
# Results saving to output/18.04/4.15->4.18
# Logging to output/18.04/4.15->4.18/trace_event.log
# Logging to output/18.04/4.15->4.18/raw_tp.log
# Logging to output/18.04/4.15->4.18/lsm.log
# Logging to output/18.04/4.15->4.18/func.log
# Logging to output/18.04/4.15->4.18/struct.log
# Logging to output/18.04/4.15->4.18/union.log
# Logging to output/18.04/4.15->4.18/enum.log
# Results saving to output/18.04/4.18->5.0
# Logging to output/18.04/4.18->5.0/trace_event.log
# Logging to output/18.04/4.18->5.0/raw_tp.log
# Logging to output/18.04/4.18->5.0/lsm.log
# Logging to output/18.04/4.18->5.0/func.log
# Logging to output/18.04/4.18->5.0/struct.log
# Logging to output/18.04/4.18->5.0/union.log
# Logging to output/18.04/4.18->5.0/enum.log
# Results saving to output/18.04/5.0->5.3
# Logging to output/18.04/5.0->5.3/trace_event.log
# Logging to output/18.04/5.0->5.3/raw_tp.log
# Logging to output/18.04/5.0->5.3/lsm.log
# Logging to output/18.04/5.0->5.3/func.log
# Logging to output/18.04/5.0->5.3/struct.log
# Logging to output/18.04/5.0->5.3/union.log
# Logging to output/18.04/5.0->5.3/enum.log
# Results saving to output/18.04/5.3->5.4
# Logging to output/18.04/5.3->5.4/trace_event.log
# Logging to output/18.04/5.3->5.4/raw_tp.log
# Logging to output/18.04/5.3->5.4/lsm.log
# Logging to output/18.04/5.3->5.4/func.log
# Logging to output/18.04/5.3->5.4/struct.log
# Logging to output/18.04/5.3->5.4/union.log
# Logging to output/18.04/5.3->5.4/enum.log
# Results saving to output/18.04/Total
# Logging to output/18.04/Total/trace_event.log
# Logging to output/18.04/Total/raw_tp.log
# Logging to output/18.04/Total/lsm.log
# Logging to output/18.04/Total/func.log
# Logging to output/18.04/Total/struct.log
# Logging to output/18.04/Total/union.log
# Logging to output/18.04/Total/enum.log
# Results saving to output/20.04/5.4->5.8
# Logging to output/20.04/5.4->5.8/trace_event.log
# Logging to output/20.04/5.4->5.8/raw_tp.log
# Logging to output/20.04/5.4->5.8/lsm.log
# Logging to output/20.04/5.4->5.8/func.log
# Logging to output/20.04/5.4->5.8/struct.log
# Logging to output/20.04/5.4->5.8/union.log
# Logging to output/20.04/5.4->5.8/enum.log
# Results saving to output/20.04/5.8->5.11
# Logging to output/20.04/5.8->5.11/trace_event.log
# Logging to output/20.04/5.8->5.11/raw_tp.log
# Logging to output/20.04/5.8->5.11/lsm.log
# Logging to output/20.04/5.8->5.11/func.log
# Logging to output/20.04/5.8->5.11/struct.log
# Logging to output/20.04/5.8->5.11/union.log
# Logging to output/20.04/5.8->5.11/enum.log
# Results saving to output/20.04/5.11->5.13
# Logging to output/20.04/5.11->5.13/trace_event.log
# Logging to output/20.04/5.11->5.13/raw_tp.log
# Logging to output/20.04/5.11->5.13/lsm.log
# Logging to output/20.04/5.11->5.13/func.log
# Logging to output/20.04/5.11->5.13/struct.log
# Logging to output/20.04/5.11->5.13/union.log
# Logging to output/20.04/5.11->5.13/enum.log
# Results saving to output/20.04/5.13->5.15
# Logging to output/20.04/5.13->5.15/trace_event.log
# Logging to output/20.04/5.13->5.15/raw_tp.log
# Logging to output/20.04/5.13->5.15/lsm.log
# Logging to output/20.04/5.13->5.15/func.log
# Logging to output/20.04/5.13->5.15/struct.log
# Logging to output/20.04/5.13->5.15/union.log
# Logging to output/20.04/5.13->5.15/enum.log
# Results saving to output/20.04/Total
# Logging to output/20.04/Total/trace_event.log
# Logging to output/20.04/Total/raw_tp.log
# Logging to output/20.04/Total/lsm.log
# Logging to output/20.04/Total/func.log
# Logging to output/20.04/Total/struct.log
# Logging to output/20.04/Total/union.log
# Logging to output/20.04/Total/enum.log
# Results saving to output/20.04/x86->arm64
# Logging to output/20.04/x86->arm64/trace_event.log
# Logging to output/20.04/x86->arm64/raw_tp.log
# Logging to output/20.04/x86->arm64/lsm.log
# Logging to output/20.04/x86->arm64/func.log
# Logging to output/20.04/x86->arm64/struct.log
# Logging to output/20.04/x86->arm64/union.log
# Logging to output/20.04/x86->arm64/enum.log

# %%
df = pd.concat(results, axis=1)
df.columns = df.columns.droplevel(2)
df = df.loc[(df != 0).any(axis=1)]
df.to_pickle("output/diff.pkl")

df
# Out:
#                                      16.04                                  \
#                                   4.4->4.8 4.8->4.10 4.10->4.13 4.13->4.15
# trace_event Old                        340       357        371        408
#             New                        357       371        408        429
#             Common                     338       355        364        397
#             Added                       19        16         44         32
#             Removed                      2         2          7         11
#             Changed                     16         4         10          5
#             - Field added               15         2          3          4
#             - Field removed             12         1          5          3
#             - Field type changed         0         1          3          0
#             - Layout changed            16         3          8          5
# raw_tp      Old                        345       363        377        414
#             New                        363       377        414        436
#             Common                     342       361        370        404
#             Added                       21        16         44         32
#             Removed                      3         2          7         10
#             Changed                      9         2          6          3
#             - Param added                7         1          4          2
#             - Param removed              5         0          2          2
#             - Param type changed         0         1          2          0
#             - Param reordered            4         0          2          1
# lsm         Old                        168       168        171        176
#             New                        168       171        176        177
#             Common                     165       168        170        174
#             Added                        3         3          6          3
#             Removed                      3         0          1          2
#             Changed                     16         0          3          1
#             - Param added                0         0          3          1
#             - Param removed              0         0          1          0
#             - Param type changed        16         0          1          0
#             - Param reordered            0         0          1          0
# func        Old                      36847     38123      39045      40833
#             New                      38123     39045      40833      42673
#             Common                   35475     37538      38096      40100
#             Added                     2648      1507       2737       2573
#             Removed                   1372       585        949        733
#             Changed                    802       386        840        769
#             - Param added              395       224        518        472
#             - Param removed            310       181        346        339
#             - Param type changed       213       105        167        281
#             - Param reordered          179        43        186        122
#             - Return type changed      121        51        116         77
# struct      Old                       6210      6482       6660       6966
#             New                       6482      6660       6966       7255
#             Common                    6072      6432       6582       6881
#             Added                      410       228        384        374
#             Removed                    138        50         78         85
#             Changed                    828       640        852        721
#             - Field added              404       247        381        339
#             - Field removed            286       113        199        164
#             - Field type changed       165       112        218        145
#             - Layout changed           775       592        757        668
# union       Old                         81        83         89         92
#             New                         83        89         92         96
#             Common                      80        82         88         92
#             Added                        3         7          4          4
#             Removed                      1         1          1          0
#             Changed                      2         4          9          5
#             - Field added                2         3          6          2
#             - Field removed              1         2          2          2
#             - Field type changed         1         0          1          1
#             - Layout changed             2         4          9          5
# enum        Old                        787       795        832        888
#             New                        795       832        888        963
#             Common                     740       783        819        879
#             Added                       55        49         69         84
#             Removed                     47        12         13          9
#             Changed                     83        42         69         75
#             - Elem added                69        40         66         64
#             - Elem removed              21        10         10         18
#             - Value changed             42        24         44         39
#
#                                               18.04                     \
#                                    Total 4.15->4.18 4.18->5.0 5.0->5.3
# trace_event Old                      340        417       433      445
#             New                      429        433       445      468
#             Common                   324        405       430      444
#             Added                    105         28        15       24
#             Removed                   16         12         3        1
#             Changed                   27          9         9        8
#             - Field added             19          7         7        5
#             - Field removed           18          1         5        5
#             - Field type changed       3          2         0        1
#             - Layout changed          24          8         9        7
# raw_tp      Old                      345        424       441      453
#             New                      436        441       453      476
#             Common                   328        412       438      452
#             Added                    108         29        15       24
#             Removed                   17         12         3        1
#             Changed                   15          9         8        8
#             - Param added             10          7         6        4
#             - Param removed            7          4         3        4
#             - Param type changed       3          1         2        2
#             - Param reordered          3          3         1        2
# lsm         Old                      168        177       182      182
#             New                      177        182       182      186
#             Common                   162        177       180      182
#             Added                     15          5         2        4
#             Removed                    6          0         2        0
#             Changed                   20         14         8        1
#             - Param added              4          1         5        0
#             - Param removed            1          4         4        1
#             - Param type changed      17         10         1        0
#             - Param reordered          1          2         2        0
# func        Old                    36847      42719     44531    45602
#             New                    42673      44531     45602    46910
#             Common                 34361      40918     43288    44821
#             Added                   8312       3613      2314     2089
#             Removed                 2486       1801      1243      781
#             Changed                 2009       1062      1074      478
#             - Param added           1176        545       696      250
#             - Param removed          863        393       604      193
#             - Param type changed     576        349       181      107
#             - Param reordered        378        225       105       92
#             - Return type changed    281        196       151       71
# struct      Old                     6210       7329      7619     7854
#             New                     7255       7619      7854     8194
#             Common                  5958       7193      7507     7762
#             Added                   1297        426       347      432
#             Removed                  252        136       112       92
#             Changed                 1391        785       813      655
#             - Field added            780        354       437      352
#             - Field removed          459        261       208      183
#             - Field type changed     428        189       184      112
#             - Layout changed        1263        715       749      612
# union       Old                       81         99       102      108
#             New                       96        102       108      113
#             Common                    79         96       100      106
#             Added                     17          6         8        7
#             Removed                    2          3         2        2
#             Changed                   11          4         3        5
#             - Field added              7          3         2        4
#             - Field removed            3          1         1        1
#             - Field type changed       1          1         1        2
#             - Layout changed          11          4         3        4
# enum        Old                      787        979      1015     1075
#             New                      963       1015      1075     1153
#             Common                   743        954      1004     1057
#             Added                    220         61        71       96
#             Removed                   44         25        11       18
#             Changed                  147         66        64       72
#             - Elem added             138         57        57       65
#             - Elem removed            31         23        13       14
#             - Value changed           79         25        37       36
#
#                                                      20.04            \
#                                   5.3->5.4  Total 5.4->5.8 5.8->5.11
# trace_event Old                        468    417      465       500
#             New                        477    477      500       525
#             Common                     468    402      449       494
#             Added                        9     75       51        31
#             Removed                      0     15       16         6
#             Changed                      3     25       36        14
#             - Field added                3     21        8        11
#             - Field removed              1     10        8         3
#             - Field type changed         0      3       25         0
#             - Layout changed             3     23       31        14
# raw_tp      Old                        476    424      473       508
#             New                        485    485      508       533
#             Common                     476    409      457       502
#             Added                        9     76       51        31
#             Removed                      0     15       16         6
#             Changed                      1     21       13        10
#             - Param added                1     15        6         3
#             - Param removed              0      7        6         8
#             - Param type changed         0      5        5         0
#             - Param reordered            1      4        2         7
# lsm         Old                        186    177      189       198
#             New                        189    189      198       199
#             Common                     186    175      188       198
#             Added                        3     14       10         1
#             Removed                      0      2        1         0
#             Changed                      0     16       18         5
#             - Param added                0      3       13         4
#             - Param removed              0      6       13         2
#             - Param type changed         0     11        6         1
#             - Param reordered            0      0        0         0
# func        Old                      46910  42719    48181     49745
#             New                      47961  47961    49745     51749
#             Common                   46561  39572    46181     48669
#             Added                     1400   8389     3564      3080
#             Removed                    349   3147     2000      1076
#             Changed                    338   1755      932      1176
#             - Param added              253    918      535       375
#             - Param removed            206    647      475       343
#             - Param type changed       146    414      208       623
#             - Param reordered           38    337      132       163
#             - Return type changed       32    382      130        82
# struct      Old                       8194   7329     8396      8722
#             New                       8439   8439     8722      9079
#             Common                    8160   7057     8193      8566
#             Added                      279   1382      529       513
#             Removed                     34    272      203       156
#             Changed                    369   1293      973       771
#             - Field added              193    779      485       439
#             - Field removed             88    451      315       232
#             - Field type changed        62    361      219       164
#             - Layout changed           350   1195      897       720
# union       Old                        113     99      125       127
#             New                        126    126      127       139
#             Common                     111     93      122       116
#             Added                       15     33        5        23
#             Removed                      2      6        3        11
#             Changed                      1      6        3         4
#             - Field added                1      5        3         4
#             - Field removed              0      1        1         1
#             - Field type changed         0      2        1         1
#             - Layout changed             1      5        3         4
# enum        Old                       1153    979     1188      1237
#             New                       1178   1178     1237      1317
#             Common                    1146    944     1164      1229
#             Added                       32    234       73        88
#             Removed                      7     35       24         8
#             Changed                     33    130      118       105
#             - Elem added                31    121       95        96
#             - Elem removed               2     34       34        15
#             - Value changed             19     65       69        55
#
#
#                                   5.11->5.13 5.13->5.15  Total x86->arm64
# trace_event Old                          525        523    465        500
#             New                          523        525    525        493
#             Common                       510        508    431        444
#             Added                         13         17     94         49
#             Removed                       15         15     34         56
#             Changed                       10         17     47          0
#             - Field added                  6          6     20          0
#             - Field removed                1          2     11          0
#             - Field type changed           5         10     21          0
#             - Layout changed               9         14     43          0
# raw_tp      Old                          533        531    473        508
#             New                          531        533    533        501
#             Common                       518        516    439        452
#             Added                         13         17     94         49
#             Removed                       15         15     34         56
#             Changed                        3         10     21          0
#             - Param added                  2          4     10          0
#             - Param removed                2          0     15          0
#             - Param type changed           1          6      1          0
#             - Param reordered              1          3      9          0
# lsm         Old                          199        203    189        198
#             New                          203        203    203        198
#             Common                       198        203    187        198
#             Added                          5          0     16          0
#             Removed                        1          0      2          0
#             Changed                        4          5     23          0
#             - Param added                  4          0     20          0
#             - Param removed                0          1     15          0
#             - Param type changed           0          4      3          0
#             - Param reordered              4          0      4          0
# func        Old                        51749      52337  48181      49745
#             New                        52337      53335  53335      51650
#             Common                     50994      51214  44377      41714
#             Added                       1343       2121   8958       9936
#             Removed                      755       1123   3804       8031
#             Changed                      549        640   2385        111
#             - Param added                428        298   1194         58
#             - Param removed              172        194    848         58
#             - Param type changed          42        214    799         52
#             - Param reordered            280        104    544          2
#             - Return type changed         51        111    276          7
# struct      Old                         9079       9216   8396       8722
#             New                         9216       9382   9382       9492
#             Common                      8983       9099   7956       7689
#             Added                        233        283   1426       1803
#             Removed                       96        117    440       1033
#             Changed                      476        656   1513        301
#             - Field added                272        365    944         29
#             - Field removed              154        163    533         35
#             - Field type changed         111        140    400         37
#             - Layout changed             438        605   1408        294
# union       Old                          139        147    125        127
#             New                          147        150    150        106
#             Common                       138        147    111         81
#             Added                          9          3     39         25
#             Removed                        1          0     14         46
#             Changed                        6          4     11          2
#             - Field added                  5          1     10          0
#             - Field removed                2          1      3          0
#             - Field type changed           1          1      1          0
#             - Layout changed               6          3     11          2
# enum        Old                         1317       1361   1188       1237
#             New                         1361       1390   1390       1420
#             Common                      1308       1341   1142       1118
#             Added                         53         49    248        302
#             Removed                        9         20     46        119
#             Changed                       66         66    207         10
#             - Elem added                  61         60    185          7
#             - Elem removed                 7         13     44          8
#             - Value changed               40         35    121          7

# %%
import pandas as pd

pd.set_option("display.max_rows", None)

df = pd.read_pickle("output/diff.pkl")
df = df.astype(object)

kinds = ["struct", "func", "trace_event", "lsm"]
groups = ["20.04"]
df = df.loc[kinds, groups]

for kind in kinds:
    for row in df.loc[kind, :].index:
        if row == "Old":
            continue
        for col in df.columns:
            val = df.loc[(kind, row), col]
            percentage = val / df.loc[(kind, "Old"), col] * 100
            df.loc[(kind, row), col] = f"\\val{{{val}}}{{{percentage:4.1f}}}"

df = df.drop(index=["Old", "New", "Common"], level=1)

df.to_latex("output/diff.tex")

df
# Out:
#                                               20.04                    \
#                                            5.4->5.8         5.8->5.11
# struct      Added                   \val{529}{ 6.3}   \val{513}{ 5.9}
#             Removed                 \val{203}{ 2.4}   \val{156}{ 1.8}
#             Changed                 \val{973}{11.6}   \val{771}{ 8.8}
#             - Field added           \val{485}{ 5.8}   \val{439}{ 5.0}
#             - Field removed         \val{315}{ 3.8}   \val{232}{ 2.7}
#             - Field type changed    \val{219}{ 2.6}   \val{164}{ 1.9}
#             - Layout changed        \val{897}{10.7}   \val{720}{ 8.3}
# func        Added                  \val{3564}{ 7.4}  \val{3080}{ 6.2}
#             Removed                \val{2000}{ 4.2}  \val{1076}{ 2.2}
#             Changed                 \val{932}{ 1.9}  \val{1176}{ 2.4}
#             - Param added           \val{535}{ 1.1}   \val{375}{ 0.8}
#             - Param removed         \val{475}{ 1.0}   \val{343}{ 0.7}
#             - Param type changed    \val{208}{ 0.4}   \val{623}{ 1.3}
#             - Param reordered       \val{132}{ 0.3}   \val{163}{ 0.3}
#             - Return type changed   \val{130}{ 0.3}    \val{82}{ 0.2}
# trace_event Added                    \val{51}{11.0}    \val{31}{ 6.2}
#             Removed                  \val{16}{ 3.4}     \val{6}{ 1.2}
#             Changed                  \val{36}{ 7.7}    \val{14}{ 2.8}
#             - Field added             \val{8}{ 1.7}    \val{11}{ 2.2}
#             - Field removed           \val{8}{ 1.7}     \val{3}{ 0.6}
#             - Field type changed     \val{25}{ 5.4}     \val{0}{ 0.0}
#             - Layout changed         \val{31}{ 6.7}    \val{14}{ 2.8}
# lsm         Added                    \val{10}{ 5.3}     \val{1}{ 0.5}
#             Removed                   \val{1}{ 0.5}     \val{0}{ 0.0}
#             Changed                  \val{18}{ 9.5}     \val{5}{ 2.5}
#             - Param added            \val{13}{ 6.9}     \val{4}{ 2.0}
#             - Param removed          \val{13}{ 6.9}     \val{2}{ 1.0}
#             - Param type changed      \val{6}{ 3.2}     \val{1}{ 0.5}
#             - Param reordered         \val{0}{ 0.0}     \val{0}{ 0.0}
#
#                                                                        \
#                                          5.11->5.13        5.13->5.15
# struct      Added                   \val{233}{ 2.6}   \val{283}{ 3.1}
#             Removed                  \val{96}{ 1.1}   \val{117}{ 1.3}
#             Changed                 \val{476}{ 5.2}   \val{656}{ 7.1}
#             - Field added           \val{272}{ 3.0}   \val{365}{ 4.0}
#             - Field removed         \val{154}{ 1.7}   \val{163}{ 1.8}
#             - Field type changed    \val{111}{ 1.2}   \val{140}{ 1.5}
#             - Layout changed        \val{438}{ 4.8}   \val{605}{ 6.6}
# func        Added                  \val{1343}{ 2.6}  \val{2121}{ 4.1}
#             Removed                 \val{755}{ 1.5}  \val{1123}{ 2.1}
#             Changed                 \val{549}{ 1.1}   \val{640}{ 1.2}
#             - Param added           \val{428}{ 0.8}   \val{298}{ 0.6}
#             - Param removed         \val{172}{ 0.3}   \val{194}{ 0.4}
#             - Param type changed     \val{42}{ 0.1}   \val{214}{ 0.4}
#             - Param reordered       \val{280}{ 0.5}   \val{104}{ 0.2}
#             - Return type changed    \val{51}{ 0.1}   \val{111}{ 0.2}
# trace_event Added                    \val{13}{ 2.5}    \val{17}{ 3.3}
#             Removed                  \val{15}{ 2.9}    \val{15}{ 2.9}
#             Changed                  \val{10}{ 1.9}    \val{17}{ 3.3}
#             - Field added             \val{6}{ 1.1}     \val{6}{ 1.1}
#             - Field removed           \val{1}{ 0.2}     \val{2}{ 0.4}
#             - Field type changed      \val{5}{ 1.0}    \val{10}{ 1.9}
#             - Layout changed          \val{9}{ 1.7}    \val{14}{ 2.7}
# lsm         Added                     \val{5}{ 2.5}     \val{0}{ 0.0}
#             Removed                   \val{1}{ 0.5}     \val{0}{ 0.0}
#             Changed                   \val{4}{ 2.0}     \val{5}{ 2.5}
#             - Param added             \val{4}{ 2.0}     \val{0}{ 0.0}
#             - Param removed           \val{0}{ 0.0}     \val{1}{ 0.5}
#             - Param type changed      \val{0}{ 0.0}     \val{4}{ 2.0}
#             - Param reordered         \val{4}{ 2.0}     \val{0}{ 0.0}
#
#
#                                               Total        x86->arm64
# struct      Added                  \val{1426}{17.0}  \val{1803}{20.7}
#             Removed                 \val{440}{ 5.2}  \val{1033}{11.8}
#             Changed                \val{1513}{18.0}   \val{301}{ 3.5}
#             - Field added           \val{944}{11.2}    \val{29}{ 0.3}
#             - Field removed         \val{533}{ 6.3}    \val{35}{ 0.4}
#             - Field type changed    \val{400}{ 4.8}    \val{37}{ 0.4}
#             - Layout changed       \val{1408}{16.8}   \val{294}{ 3.4}
# func        Added                  \val{8958}{18.6}  \val{9936}{20.0}
#             Removed                \val{3804}{ 7.9}  \val{8031}{16.1}
#             Changed                \val{2385}{ 5.0}   \val{111}{ 0.2}
#             - Param added          \val{1194}{ 2.5}    \val{58}{ 0.1}
#             - Param removed         \val{848}{ 1.8}    \val{58}{ 0.1}
#             - Param type changed    \val{799}{ 1.7}    \val{52}{ 0.1}
#             - Param reordered       \val{544}{ 1.1}     \val{2}{ 0.0}
#             - Return type changed   \val{276}{ 0.6}     \val{7}{ 0.0}
# trace_event Added                    \val{94}{20.2}    \val{49}{ 9.8}
#             Removed                  \val{34}{ 7.3}    \val{56}{11.2}
#             Changed                  \val{47}{10.1}     \val{0}{ 0.0}
#             - Field added            \val{20}{ 4.3}     \val{0}{ 0.0}
#             - Field removed          \val{11}{ 2.4}     \val{0}{ 0.0}
#             - Field type changed     \val{21}{ 4.5}     \val{0}{ 0.0}
#             - Layout changed         \val{43}{ 9.2}     \val{0}{ 0.0}
# lsm         Added                    \val{16}{ 8.5}     \val{0}{ 0.0}
#             Removed                   \val{2}{ 1.1}     \val{0}{ 0.0}
#             Changed                  \val{23}{12.2}     \val{0}{ 0.0}
#             - Param added            \val{20}{10.6}     \val{0}{ 0.0}
#             - Param removed          \val{15}{ 7.9}     \val{0}{ 0.0}
#             - Param type changed      \val{3}{ 1.6}     \val{0}{ 0.0}
#             - Param reordered         \val{4}{ 2.1}     \val{0}{ 0.0}
