# %%
import os


def system(cmd):
    print(cmd)
    os.system(cmd)

# %%
from pathlib import Path

data_path = Path("data/ubuntu-18.04-x86")

# %%
for file in data_path.iterdir():
    if file.suffix == ".xz":
        system(f"tar -xf {file} -C {data_path}")
# Out:
# tar -xf data/ubuntu-18.04-x86/5.0.0-65-generic.btf.tar.xz -C data/ubuntu-18.04-x86
# tar -xf data/ubuntu-18.04-x86/4.18.0-25-generic.btf.tar.xz -C data/ubuntu-18.04-x86
# tar -xf data/ubuntu-18.04-x86/5.3.0-76-generic.btf.tar.xz -C data/ubuntu-18.04-x86
# tar -xf data/ubuntu-18.04-x86/4.15.0-213-generic.btf.tar.xz -C data/ubuntu-18.04-x86
# tar -xf data/ubuntu-18.04-x86/5.4.0-91-generic.btf.tar.xz -C data/ubuntu-18.04-x86

# %%
# !sudo apt install linux-tools-generic bpftool
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Note, selecting 'linux-tools-common' instead of 'bpftool'
# linux-tools-common is already the newest version (6.2.0-39.40).
# linux-tools-generic is already the newest version (6.2.0.39.39).
# 0 upgraded, 0 newly installed, 0 to remove and 0 not upgraded.

# %%
def get_linux_tools_path():
    parent = Path("/usr/lib/linux-tools")
    versions = [x for x in parent.iterdir() if x.is_dir()]
    if len(versions) == 0:
        raise Exception("No linux-tools found")
    versions.sort()
    return parent / versions[-1]


def get_bpftool_path():
    path = get_linux_tools_path() / "bpftool"
    if not path.exists():
        raise Exception("bpftool not found")
    return path


bpftool_path = get_bpftool_path()

# %%
for file in data_path.iterdir():
    if file.suffix == ".btf":
        system(
            f"{bpftool_path} btf dump file {file} format c > {file.with_suffix('.h')}")
        system(
            f"{bpftool_path} btf dump file {file} format raw > {file.with_suffix('.txt')}")
        system(
            f"{bpftool_path} btf dump file {file} --json > {file.with_suffix('.json')}")
# Out:
# /usr/lib/linux-tools/6.2.0-39-generic/bpftool btf dump file data/ubuntu-18.04-x86/5.4.0-91-generic.btf format c > data/ubuntu-18.04-x86/5.4.0-91-generic.h
# /usr/lib/linux-tools/6.2.0-39-generic/bpftool btf dump file data/ubuntu-18.04-x86/5.4.0-91-generic.btf format raw > data/ubuntu-18.04-x86/5.4.0-91-generic.txt
# /usr/lib/linux-tools/6.2.0-39-generic/bpftool btf dump file data/ubuntu-18.04-x86/5.4.0-91-generic.btf --json > data/ubuntu-18.04-x86/5.4.0-91-generic.json
# /usr/lib/linux-tools/6.2.0-39-generic/bpftool btf dump file data/ubuntu-18.04-x86/5.0.0-65-generic.btf format c > data/ubuntu-18.04-x86/5.0.0-65-generic.h
# /usr/lib/linux-tools/6.2.0-39-generic/bpftool btf dump file data/ubuntu-18.04-x86/5.0.0-65-generic.btf format raw > data/ubuntu-18.04-x86/5.0.0-65-generic.txt
# /usr/lib/linux-tools/6.2.0-39-generic/bpftool btf dump file data/ubuntu-18.04-x86/5.0.0-65-generic.btf --json > data/ubuntu-18.04-x86/5.0.0-65-generic.json
# /usr/lib/linux-tools/6.2.0-39-generic/bpftool btf dump file data/ubuntu-18.04-x86/5.3.0-76-generic.btf format c > data/ubuntu-18.04-x86/5.3.0-76-generic.h
# /usr/lib/linux-tools/6.2.0-39-generic/bpftool btf dump file data/ubuntu-18.04-x86/5.3.0-76-generic.btf format raw > data/ubuntu-18.04-x86/5.3.0-76-generic.txt
# /usr/lib/linux-tools/6.2.0-39-generic/bpftool btf dump file data/ubuntu-18.04-x86/5.3.0-76-generic.btf --json > data/ubuntu-18.04-x86/5.3.0-76-generic.json
# /usr/lib/linux-tools/6.2.0-39-generic/bpftool btf dump file data/ubuntu-18.04-x86/4.15.0-213-generic.btf format c > data/ubuntu-18.04-x86/4.15.0-213-generic.h
# /usr/lib/linux-tools/6.2.0-39-generic/bpftool btf dump file data/ubuntu-18.04-x86/4.15.0-213-generic.btf format raw > data/ubuntu-18.04-x86/4.15.0-213-generic.txt
# /usr/lib/linux-tools/6.2.0-39-generic/bpftool btf dump file data/ubuntu-18.04-x86/4.15.0-213-generic.btf --json > data/ubuntu-18.04-x86/4.15.0-213-generic.json
# /usr/lib/linux-tools/6.2.0-39-generic/bpftool btf dump file data/ubuntu-18.04-x86/4.18.0-25-generic.btf format c > data/ubuntu-18.04-x86/4.18.0-25-generic.h
# /usr/lib/linux-tools/6.2.0-39-generic/bpftool btf dump file data/ubuntu-18.04-x86/4.18.0-25-generic.btf format raw > data/ubuntu-18.04-x86/4.18.0-25-generic.txt
# /usr/lib/linux-tools/6.2.0-39-generic/bpftool btf dump file data/ubuntu-18.04-x86/4.18.0-25-generic.btf --json > data/ubuntu-18.04-x86/4.18.0-25-generic.json

# %%
json_files = sorted(file for file in data_path.iterdir()
                    if file.suffix == ".json")

# %%
import json


def load_json(json_path):
    with open(json_path) as f:
        return json.load(f)

# %%
class BTF:
    def __init__(self, path):
        self.path = path
        self.data = load_json(path)['types']

    def __getitem__(self, id):
        e = self.data[id - 1]
        assert e['id'] == id
        return e
    
    def __len__(self):
        return len(self.data)
    
    def __repr__(self):
        return self.path.stem

    def print(self):
        from collections import defaultdict

        print("Sample:")
        kinds = defaultdict(int)
        for e in self.data:
            if e['kind'] not in kinds:
                print(f"\t{e}")
            kinds[e['kind']] += 1

        kinds = sorted(kinds.items(), key=lambda x: x[1], reverse=True)
        print(f"Kinds: {dict(kinds)})")

    def filter_on_kind(self, kind):
        return {
            e['name']: e for e in self.data
            if e['kind'] == kind and e['name'] != '(anon)'
        }


d1 = BTF(json_files[0])
d2 = BTF(json_files[1])

# %%
d1.print()
# Out:
# Sample:
# 	{'id': 1, 'kind': 'INT', 'name': 'long unsigned int', 'size': 8, 'bits_offset': 0, 'nr_bits': 64, 'encoding': '(none)'}
# 	{'id': 2, 'kind': 'CONST', 'name': '(anon)', 'type_id': 1}
# 	{'id': 3, 'kind': 'VOLATILE', 'name': '(anon)', 'type_id': 1}
# 	{'id': 4, 'kind': 'ARRAY', 'name': '(anon)', 'type_id': 1, 'index_type_id': 20, 'nr_elems': 2}
# 	{'id': 5, 'kind': 'PTR', 'name': '(anon)', 'type_id': 8}
# 	{'id': 11, 'kind': 'TYPEDEF', 'name': '__s8', 'type_id': 12}
# 	{'id': 38, 'kind': 'FUNC_PROTO', 'name': '(anon)', 'ret_type_id': 0, 'vlen': 1, 'params': [{'name': '(anon)', 'type_id': 20}]}
# 	{'id': 78, 'kind': 'STRUCT', 'name': '(anon)', 'size': 4, 'vlen': 1, 'members': [{'name': 'counter', 'type_id': 20, 'bits_offset': 0}]}
# 	{'id': 106, 'kind': 'UNION', 'name': '(anon)', 'size': 8, 'vlen': 3, 'members': [{'name': 'type', 'type_id': 1, 'bits_offset': 0}, {'name': 'entries', 'type_id': 108, 'bits_offset': 0}, {'name': 'next', 'type_id': 109, 'bits_offset': 0}]}
# 	{'id': 120, 'kind': 'ENUM', 'name': 'system_states', 'encoding': 'UNSIGNED', 'size': 4, 'vlen': 6, 'values': [{'name': 'SYSTEM_BOOTING', 'val': 0}, {'name': 'SYSTEM_SCHEDULING', 'val': 1}, {'name': 'SYSTEM_RUNNING', 'val': 2}, {'name': 'SYSTEM_HALT', 'val': 3}, {'name': 'SYSTEM_POWER_OFF', 'val': 4}, {'name': 'SYSTEM_RESTART', 'val': 5}]}
# 	{'id': 1110, 'kind': 'FWD', 'name': 'nlm_lockowner', 'fwd_kind': 'struct'}
# 	{'id': 1671, 'kind': 'FUNC', 'name': 'copy_bootdata', 'type_id': 1670, 'linkage': 'static'}
# 	{'id': 4737, 'kind': 'VAR', 'name': 'cpu_loops_per_jiffy', 'type_id': 1, 'linkage': 'static'}
# 	{'id': 94558, 'kind': 'RESTRICT', 'name': '(anon)', 'type_id': 5}
# 	{'id': 94838, 'kind': 'DATASEC', 'name': '.data..percpu', 'size': 164036, 'vlen': 326, 'vars': [{'type_id': 5631, 'offset': 16384, 'size': 4096}, {'type_id': 8571, 'offset': 20480, 'size': 12288}, {'type_id': 9004, 'offset': 32768, 'size': 4096}, {'type_id': 12534, 'offset': 36864, 'size': 40960}, {'type_id': 12533, 'offset': 77824, 'size': 4096}, {'type_id': 8154, 'offset': 81920, 'size': 8}, {'type_id': 8153, 'offset': 81928, 'size': 8}, {'type_id': 9003, 'offset': 81936, 'size': 2}, {'type_id': 10430, 'offset': 81952, 'size': 8}, {'type_id': 10429, 'offset': 81960, 'size': 8}, {'type_id': 10428, 'offset': 81968, 'size': 8}, {'type_id': 10431, 'offset': 81984, 'size': 240}, {'type_id': 10452, 'offset': 82224, 'size': 4}, {'type_id': 10453, 'offset': 82232, 'size': 8}, {'type_id': 10596, 'offset': 82240, 'size': 4}, {'type_id': 10594, 'offset': 82244, 'size': 2}, {'type_id': 10595, 'offset': 82246, 'size': 2}, {'type_id': 11856, 'offset': 82248, 'size': 4}, {'type_id': 4737, 'offset': 82304, 'size': 8}, {'type_id': 5189, 'offset': 82336, 'size': 512}, {'type_id': 5188, 'offset': 82848, 'size': 4824}, {'type_id': 5231, 'offset': 87672, 'size': 8}, {'type_id': 5559, 'offset': 90112, 'size': 12288}, {'type_id': 5632, 'offset': 102400, 'size': 8}, {'type_id': 5797, 'offset': 102432, 'size': 168}, {'type_id': 6219, 'offset': 102624, 'size': 64}, {'type_id': 6220, 'offset': 102688, 'size': 4}, {'type_id': 6218, 'offset': 102696, 'size': 8}, {'type_id': 6243, 'offset': 102720, 'size': 3088}, {'type_id': 6244, 'offset': 105808, 'size': 8}, {'type_id': 6519, 'offset': 105856, 'size': 320}, {'type_id': 6548, 'offset': 106176, 'size': 8}, {'type_id': 6742, 'offset': 106192, 'size': 16}, {'type_id': 7016, 'offset': 106208, 'size': 8}, {'type_id': 7015, 'offset': 106216, 'size': 10}, {'type_id': 7014, 'offset': 106240, 'size': 24}, {'type_id': 7191, 'offset': 106264, 'size': 8}, {'type_id': 7190, 'offset': 106272, 'size': 8}, {'type_id': 7457, 'offset': 106288, 'size': 16}, {'type_id': 7456, 'offset': 106304, 'size': 16}, {'type_id': 7455, 'offset': 106320, 'size': 16}, {'type_id': 7454, 'offset': 106336, 'size': 16}, {'type_id': 7493, 'offset': 106352, 'size': 16}, {'type_id': 7492, 'offset': 106368, 'size': 16}, {'type_id': 7509, 'offset': 106384, 'size': 4}, {'type_id': 7508, 'offset': 106392, 'size': 8}, {'type_id': 7507, 'offset': 106400, 'size': 4}, {'type_id': 7620, 'offset': 106408, 'size': 8}, {'type_id': 7903, 'offset': 106416, 'size': 8}, {'type_id': 7988, 'offset': 106432, 'size': 4}, {'type_id': 7987, 'offset': 106440, 'size': 8}, {'type_id': 7986, 'offset': 106448, 'size': 4}, {'type_id': 7985, 'offset': 106456, 'size': 8}, {'type_id': 7984, 'offset': 106464, 'size': 1}, {'type_id': 7983, 'offset': 106480, 'size': 16}, {'type_id': 8100, 'offset': 106496, 'size': 2048}, {'type_id': 8280, 'offset': 108544, 'size': 744}, {'type_id': 8370, 'offset': 109312, 'size': 32}, {'type_id': 8369, 'offset': 109344, 'size': 32}, {'type_id': 8368, 'offset': 109376, 'size': 8}, {'type_id': 8574, 'offset': 109392, 'size': 24}, {'type_id': 8572, 'offset': 109416, 'size': 1}, {'type_id': 8573, 'offset': 109424, 'size': 8}, {'type_id': 8614, 'offset': 109432, 'size': 1}, {'type_id': 8615, 'offset': 109440, 'size': 8}, {'type_id': 9010, 'offset': 109504, 'size': 8}, {'type_id': 9011, 'offset': 109512, 'size': 4}, {'type_id': 9012, 'offset': 109516, 'size': 4}, {'type_id': 9008, 'offset': 109520, 'size': 4}, {'type_id': 9007, 'offset': 109524, 'size': 4}, {'type_id': 9006, 'offset': 109528, 'size': 8}, {'type_id': 9009, 'offset': 109536, 'size': 56}, {'type_id': 9005, 'offset': 109632, 'size': 8}, {'type_id': 9176, 'offset': 109640, 'size': 8}, {'type_id': 9187, 'offset': 109664, 'size': 32}, {'type_id': 9292, 'offset': 109696, 'size': 16}, {'type_id': 9566, 'offset': 109728, 'size': 40}, {'type_id': 9565, 'offset': 109768, 'size': 8}, {'type_id': 9561, 'offset': 109792, 'size': 120}, {'type_id': 9563, 'offset': 109920, 'size': 120}, {'type_id':  ...
# Kinds: {'FUNC': 42719, 'FUNC_PROTO': 22849, 'PTR': 11884, 'STRUCT': 8154, 'ARRAY': 2981, 'CONST': 2369, 'ENUM': 1528, 'TYPEDEF': 1005, 'UNION': 827, 'VAR': 326, 'FWD': 158, 'VOLATILE': 20, 'INT': 15, 'RESTRICT': 2, 'DATASEC': 1})

# %%
d2.print()
# Out:
# Sample:
# 	{'id': 1, 'kind': 'INT', 'name': 'long unsigned int', 'size': 8, 'bits_offset': 0, 'nr_bits': 64, 'encoding': '(none)'}
# 	{'id': 2, 'kind': 'CONST', 'name': '(anon)', 'type_id': 1}
# 	{'id': 3, 'kind': 'VOLATILE', 'name': '(anon)', 'type_id': 1}
# 	{'id': 4, 'kind': 'ARRAY', 'name': '(anon)', 'type_id': 1, 'index_type_id': 21, 'nr_elems': 2}
# 	{'id': 5, 'kind': 'PTR', 'name': '(anon)', 'type_id': 8}
# 	{'id': 11, 'kind': 'TYPEDEF', 'name': '__s8', 'type_id': 12}
# 	{'id': 37, 'kind': 'ENUM', 'name': '(anon)', 'encoding': 'UNSIGNED', 'size': 4, 'vlen': 2, 'values': [{'name': 'false', 'val': 0}, {'name': 'true', 'val': 1}]}
# 	{'id': 40, 'kind': 'FUNC_PROTO', 'name': '(anon)', 'ret_type_id': 0, 'vlen': 1, 'params': [{'name': '(anon)', 'type_id': 21}]}
# 	{'id': 80, 'kind': 'STRUCT', 'name': '(anon)', 'size': 4, 'vlen': 1, 'members': [{'name': 'counter', 'type_id': 21, 'bits_offset': 0}]}
# 	{'id': 110, 'kind': 'UNION', 'name': '(anon)', 'size': 8, 'vlen': 3, 'members': [{'name': 'type', 'type_id': 1, 'bits_offset': 0}, {'name': 'entries', 'type_id': 112, 'bits_offset': 0}, {'name': 'next', 'type_id': 113, 'bits_offset': 0}]}
# 	{'id': 960, 'kind': 'FWD', 'name': 'tick_device', 'fwd_kind': 'struct'}
# 	{'id': 1639, 'kind': 'FUNC', 'name': 'copy_bootdata', 'type_id': 1638, 'linkage': 'static'}
# 	{'id': 4834, 'kind': 'VAR', 'name': 'cpu_loops_per_jiffy', 'type_id': 1, 'linkage': 'static'}
# 	{'id': 5057, 'kind': 'ENUM64', 'name': 'perf_event_sample_format', 'encoding': 'UNSIGNED', 'size': 8, 'vlen': 22, 'values': [{'name': 'PERF_SAMPLE_IP', 'val': 1}, {'name': 'PERF_SAMPLE_TID', 'val': 2}, {'name': 'PERF_SAMPLE_TIME', 'val': 4}, {'name': 'PERF_SAMPLE_ADDR', 'val': 8}, {'name': 'PERF_SAMPLE_READ', 'val': 16}, {'name': 'PERF_SAMPLE_CALLCHAIN', 'val': 32}, {'name': 'PERF_SAMPLE_ID', 'val': 64}, {'name': 'PERF_SAMPLE_CPU', 'val': 128}, {'name': 'PERF_SAMPLE_PERIOD', 'val': 256}, {'name': 'PERF_SAMPLE_STREAM_ID', 'val': 512}, {'name': 'PERF_SAMPLE_RAW', 'val': 1024}, {'name': 'PERF_SAMPLE_BRANCH_STACK', 'val': 2048}, {'name': 'PERF_SAMPLE_REGS_USER', 'val': 4096}, {'name': 'PERF_SAMPLE_STACK_USER', 'val': 8192}, {'name': 'PERF_SAMPLE_WEIGHT', 'val': 16384}, {'name': 'PERF_SAMPLE_DATA_SRC', 'val': 32768}, {'name': 'PERF_SAMPLE_IDENTIFIER', 'val': 65536}, {'name': 'PERF_SAMPLE_TRANSACTION', 'val': 131072}, {'name': 'PERF_SAMPLE_REGS_INTR', 'val': 262144}, {'name': 'PERF_SAMPLE_PHYS_ADDR', 'val': 524288}, {'name': 'PERF_SAMPLE_MAX', 'val': 1048576}, {'name': '__PERF_SAMPLE_CALLCHAIN_EARLY', 'val': 9223372036854775808}]}
# 	{'id': 97856, 'kind': 'DATASEC', 'name': '.data..percpu', 'size': 147652, 'vlen': 325, 'vars': [{'type_id': 5722, 'offset': 16384, 'size': 4096}, {'type_id': 8720, 'offset': 20480, 'size': 12288}, {'type_id': 9146, 'offset': 32768, 'size': 4096}, {'type_id': 12630, 'offset': 36864, 'size': 20480}, {'type_id': 12629, 'offset': 57344, 'size': 4096}, {'type_id': 8323, 'offset': 61440, 'size': 8}, {'type_id': 8322, 'offset': 61448, 'size': 8}, {'type_id': 9145, 'offset': 61456, 'size': 2}, {'type_id': 10544, 'offset': 61472, 'size': 8}, {'type_id': 10543, 'offset': 61480, 'size': 8}, {'type_id': 10542, 'offset': 61488, 'size': 8}, {'type_id': 10545, 'offset': 61504, 'size': 240}, {'type_id': 10566, 'offset': 61744, 'size': 4}, {'type_id': 10567, 'offset': 61752, 'size': 8}, {'type_id': 10703, 'offset': 61760, 'size': 4}, {'type_id': 10701, 'offset': 61764, 'size': 2}, {'type_id': 10702, 'offset': 61766, 'size': 2}, {'type_id': 11951, 'offset': 61768, 'size': 4}, {'type_id': 4834, 'offset': 61824, 'size': 8}, {'type_id': 5291, 'offset': 61856, 'size': 512}, {'type_id': 5290, 'offset': 62368, 'size': 4816}, {'type_id': 5647, 'offset': 69632, 'size': 12288}, {'type_id': 5723, 'offset': 81920, 'size': 8}, {'type_id': 5890, 'offset': 81952, 'size': 168}, {'type_id': 6321, 'offset': 82144, 'size': 64}, {'type_id': 6322, 'offset': 82208, 'size': 4}, {'type_id': 6320, 'offset': 82216, 'size': 8}, {'type_id': 6345, 'offset': 82240, 'size': 3088}, {'type_id': 6346, 'offset': 85328, 'size': 8}, {'type_id': 6550, 'offset': 85376, 'size': 320}, {'type_id': 6577, 'offset': 85696, 'size': 8}, {'type_id': 6771, 'offset': 85712, 'size': 16}, {'type_id': 7052, 'offset': 85728, 'size': 8}, {'type_id': 7051, 'offset': 85736, 'size': 10}, {'type_id': 7050, 'offset': 85760, 'size': 24}, {'type_id': 7225, 'offset': 85784, 'size': 8}, {'type_id': 7224, 'offset': 85792, 'size': 8}, {'type_id': 7515, 'offset': 85808, 'size': 16}, {'type_id': 7514, 'offset': 85824, 'size': 16}, {'type_id': 7513, 'offset': 85840, 'size': 16}, {'type_id': 7512, 'offset': 85856, 'size': 16}, {'type_id': 7552, 'offset': 85872, 'size': 16}, {'type_id': 7551, 'offset': 85888, 'size': 16}, {'type_id': 7568, 'offset': 85904, 'size': 4}, {'type_id': 7567, 'offset': 85912, 'size': 8}, {'type_id': 7566, 'offset': 85920, 'size': 4}, {'type_id': 7725, 'offset': 85928, 'size': 8}, {'type_id': 8051, 'offset': 85936, 'size': 8}, {'type_id': 8159, 'offset': 85952, 'size': 4}, {'type_id': 8158, 'offset': 85960, 'size': 8}, {'type_id': 8157, 'offset': 85968, 'size': 4}, {'type_id': 8156, 'offset': 85976, 'size': 8}, {'type_id': 8155, 'offset': 85984, 'size': 1}, {'type_id': 8154, 'offset': 86000, 'size': 16}, {'type_id': 8269, 'offset': 86016, 'size': 2048}, {'type_id': 8442, 'offset': 88064, 'size': 736}, {'type_id': 8520, 'offset': 88800, 'size': 32}, {'type_id': 8519, 'offset': 88832, 'size': 32}, {'type_id': 8518, 'offset': 88864, 'size': 8}, {'type_id': 8723, 'offset': 88880, 'size': 24}, {'type_id': 8721, 'offset': 88904, 'size': 1}, {'type_id': 8722, 'offset': 88912, 'size': 8}, {'type_id': 8763, 'offset': 88920, 'size': 1}, {'type_id': 8764, 'offset': 88928, 'size': 8}, {'type_id': 9152, 'offset': 88960, 'size': 8}, {'type_id': 9153, 'offset': 88968, 'size': 4}, {'type_id': 9154, 'offset': 88972, 'size': 4}, {'type_id': 9150, 'offset': 88976, 'size': 4}, {'type_id': 9149, 'offset': 88980, 'size': 4}, {'type_id': 9148, 'offset': 88984, 'size': 8}, {'type_id': 9151, 'offset': 88992, 'size': 56}, {'type_id': 9147, 'offset': 89088, 'size': 8}, {'type_id': 9225, 'offset': 89120, 'size': 32}, {'type_id': 9337, 'offset': 89152, 'size': 16}, {'type_id': 9619, 'offset': 89184, 'size': 40}, {'type_id': 9618, 'offset': 89224, 'size': 8}, {'type_id': 9614, 'offset': 89248, 'size': 120}, {'type_id': 9616, 'offset': 89376, 'size': 120}, {'type_id': 9615, 'offset': 89496, 'size': 8}, {'type_id': 9617, 'offset': 89504, 'size': 4}, {'type_id': 9613, 'offset': 89508, 'size': 4}, {'type_id': 9620, 'off ...
# Kinds: {'FUNC': 44531, 'FUNC_PROTO': 23237, 'PTR': 12321, 'STRUCT': 8476, 'ARRAY': 2994, 'CONST': 2379, 'ENUM': 1531, 'TYPEDEF': 1023, 'UNION': 840, 'VAR': 325, 'FWD': 159, 'VOLATILE': 20, 'INT': 15, 'ENUM64': 4, 'DATASEC': 1})

# %%
import copy

def normalize_struct(s):
    s = copy.deepcopy(s)
    assert s['vlen'] == len(s['members'])
    del s['vlen']
    del s['id']
    for m in s['members']:
        del m['type_id']
    return s

def diff_struct(old, new):
    old_members = {m['name'] : m for m in old['members']}
    new_members = {m['name'] : m for m in new['members']}

    # fields added or removed
    if set(old_members) != set(new_members):
        added_members = new_members.keys() - old_members.keys()
        removed_members = old_members.keys() - new_members.keys()

        if added_members and removed_members:
            return f"Fields added and removed: {added_members} {removed_members}"
        elif added_members and not removed_members:
            return f"Added fields: {added_members}"
        elif not added_members and removed_members:
            return f"Removed fields: {removed_members}"
        else:
            assert False
    
    # fields reordered
    if list(old_members) != list(new_members):
        if old['size'] != new['size']:
            return "Struct size changed caused by field reordering"
        else:
            return "Fields reordered"
    
    if old['size'] != new['size']:
        return "Struct size changed caused by field size change"
    
    for old_member, new_member in zip(old['members'], new['members']):
        if old_member['bits_offset'] != new_member['bits_offset']:
            return "Field changed size without affecting size of struct"
        
    assert False, f"\n{old}\n{new}"


def print_collection(name, s):
    print(f"{name} ({len(s)}): {list(s)}")

def check_diff(d_old, d_new, kind):
    f_old = d_old.filter_on_kind(kind)
    f_new = d_new.filter_on_kind(kind)

    print_collection(f"Old {kind}", f_old.keys())
    print_collection(f"New {kind}", f_new.keys())

    print_collection(f"Removed {kind}", f_old.keys() - f_new.keys())
    print_collection(f"Added {kind}", f_new.keys() - f_old.keys())

    common = {
        name : (f_old[name], f_new[name])
        for name in f_old.keys() & f_new.keys()
    }
    print_collection(f"Common {kind}", common.keys())

    changed = {
        name : (old, new)
        for name, (old, new) in common.items()
        if normalize_struct(old) != normalize_struct(new)
    }
    print_collection(f"Changed {kind}", changed.keys())

    for name, (old, new) in changed.items():
        reason = diff_struct(old, new)
        print(f"{kind} {name} differs: {reason}")
        






check_diff(d1, d2, 'STRUCT')
# Out:
# Old STRUCT (7329): ['list_head', 'hlist_head', 'hlist_node', 'callback_head', 'jump_entry', 'static_key', 'static_key_true', 'static_key_false', 'file_operations', 'atomic_notifier_head', 'taint_flag', 'timespec', 'restart_block', 'task_struct', 'screen_info', 'apm_bios_info', 'apm_info', 'edd_device_params', 'edd_info', 'edd', 'ist_info', 'edid_info', 'setup_header', 'sys_desc_table', 'olpc_ofw_header', 'efi_info', 'boot_e820_entry', 'boot_params', 'range', 'pt_regs', 'desc_struct', 'idt_bits', 'gate_struct', 'desc_ptr', 'pgprot', 'page', 'paravirt_callee_save', 'pv_info', 'pv_init_ops', 'pv_lazy_ops', 'pv_time_ops', 'pv_cpu_ops', 'thread_struct', 'pv_irq_ops', 'pv_mmu_ops', 'mm_struct', 'cpumask', 'flush_tlb_info', 'qspinlock', 'qrwlock', 'pv_lock_ops', 'paravirt_patch_site', 'math_emu_info', 'tracepoint_func', 'tracepoint', 'fregs_state', 'fxregs_state', 'swregs_state', 'xstate_header', 'xregs_state', 'fpu', 'cpuinfo_x86', 'x86_hw_tss', 'seq_operations', 'entry_stack', 'entry_stack_page', 'tss_struct', 'orig_ist', 'thread_info', 'llist_node', 'mpc_table', 'mpc_cpu', 'mpc_bus', 'mpc_intsrc', 'x86_init_mpparse', 'x86_init_resources', 'x86_init_irqs', 'x86_init_oem', 'x86_init_paging', 'x86_init_timers', 'x86_init_iommu', 'x86_init_pci', 'x86_hyper_init', 'x86_init_ops', 'x86_cpuinit_ops', 'x86_legacy_devices', 'x86_legacy_features', 'x86_hyper_runtime', 'x86_platform_ops', 'x86_msi_ops', 'x86_io_apic_ops', 'physid_mask', 'lock_class_key', 'raw_spinlock', 'spinlock', 'optimistic_spin_queue', 'rw_semaphore', 'mutex', 'arch_shared_info', 'arch_vcpu_info', 'pvclock_vcpu_time_info', 'pvclock_wall_clock', 'vcpu_info', 'shared_info', 'start_info', 'fwnode_handle', 'fwnode_operations', 'fwnode_endpoint', 'fwnode_reference_args', 'rb_node', 'rb_root', 'rb_root_cached', 'vm_struct', 'real_mode_header', 'device', 'apic', 'smp_ops', 'wait_queue_head', 'seqcount', 'free_area', 'zone_padding', 'zone_reclaim_stat', 'lruvec', 'pglist_data', 'per_cpu_pages', 'per_cpu_pageset', 'per_cpu_nodestat', 'zone', 'zoneref', 'zonelist', 'timezone', 'timer_list', 'work_struct', 'completion', 'notifier_block', 'blocking_notifier_head', 'mem_section', 'arch_tlbflush_unmap_batch', 'vmacache', 'vm_area_struct', 'task_rss_stat', 'mm_rss_stat', 'page_frag', 'tlbflush_unmap_batch', 'arch_uprobe_task', 'uprobe_task', 'return_instance', 'uprobes_state', 'address_space', 'dev_pagemap', 'file', 'vm_userfaultfd_ctx', 'vm_operations_struct', 'core_thread', 'core_state', 'vm_fault', 'percpu_ref', 'shrink_control', 'shrinker', 'page_ext_operations', 'resource', 'vmem_altmap', 'hlist_bl_head', 'hlist_bl_node', 'lockref', 'qstr', 'dentry_stat_t', 'dentry', 'inode', 'dentry_operations', 'super_block', 'path', 'kstat', 'list_lru_one', 'list_lru_memcg', 'list_lru_node', 'list_lru', 'radix_tree_node', 'radix_tree_root', 'upid', 'pid', 'pid_link', 'kernel_cap_struct', 'fiemap_extent', 'rcuwait', 'rcu_sync', 'percpu_rw_semaphore', 'delayed_call', 'files_stat_struct', 'inodes_stat_t', 'kiocb', 'iattr', 'percpu_counter', 'dquot', 'kqid', 'mem_dqblk', 'mem_dqinfo', 'quota_format_type', 'dqstats', 'quota_format_ops', 'dquot_operations', 'qc_dqblk', 'qc_type_state', 'qc_state', 'qc_info', 'quotactl_ops', 'quota_info', 'address_space_operations', 'block_device', 'inode_operations', 'file_lock_context', 'fown_struct', 'file_ra_state', 'cred', 'file_lock_operations', 'file_lock', 'lock_manager_operations', 'nfs_lock_info', 'nfs4_lock_info', 'fasync_struct', 'sb_writers', 'file_system_type', 'super_operations', 'fiemap_extent_info', 'dir_context', 'seq_file', 'kobject', 'kobj_attribute', 'vm_event_state', 'memblock_region', 'memblock_type', 'memblock', 'debug_store', 'debug_store_buffers', 'cpu_entry_area', 'gdt_page', 'refcount_struct', 'sysv_sem', 'user_struct', 'sysv_shm', 'plist_node', 'timerqueue_node', 'timerqueue_head', 'hrtimer', 'hrtimer_clock_base', 'hrtimer_cpu_base', 'seccomp', 'siginfo', 'sigpending', 'task_io_accounting', 'prev_cputime', 'task_cputime', 'sched_info', 'lo ...
# New STRUCT (7619): ['list_head', 'hlist_head', 'hlist_node', 'callback_head', 'kernel_symbol', 'jump_entry', 'static_key', 'static_key_true', 'static_key_false', 'file_operations', 'atomic_notifier_head', 'taint_flag', 'timespec', 'timezone', 'timespec64', 'restart_block', 'task_struct', 'screen_info', 'apm_bios_info', 'apm_info', 'edd_device_params', 'edd_info', 'edd', 'ist_info', 'edid_info', 'setup_header', 'sys_desc_table', 'olpc_ofw_header', 'efi_info', 'boot_e820_entry', 'boot_params', 'range', 'pt_regs', 'desc_struct', 'idt_bits', 'gate_struct', 'desc_ptr', 'pgprot', 'page', 'paravirt_callee_save', 'pv_info', 'pv_init_ops', 'pv_lazy_ops', 'pv_time_ops', 'pv_cpu_ops', 'thread_struct', 'pv_irq_ops', 'pv_mmu_ops', 'mm_struct', 'cpumask', 'flush_tlb_info', 'qspinlock', 'qrwlock', 'pv_lock_ops', 'paravirt_patch_site', 'math_emu_info', 'tracepoint_func', 'tracepoint', 'fregs_state', 'fxregs_state', 'swregs_state', 'xstate_header', 'xregs_state', 'fpu', 'cpuinfo_x86', 'x86_hw_tss', 'entry_stack', 'entry_stack_page', 'tss_struct', 'orig_ist', 'thread_info', 'llist_node', 'mpc_table', 'mpc_cpu', 'mpc_bus', 'mpc_intsrc', 'x86_init_mpparse', 'x86_init_resources', 'x86_init_irqs', 'x86_init_oem', 'x86_init_paging', 'x86_init_timers', 'x86_init_iommu', 'x86_init_pci', 'x86_hyper_init', 'x86_init_acpi', 'x86_init_ops', 'x86_cpuinit_ops', 'x86_legacy_devices', 'x86_legacy_features', 'x86_hyper_runtime', 'x86_platform_ops', 'x86_msi_ops', 'x86_apic_ops', 'physid_mask', 'lock_class_key', 'raw_spinlock', 'spinlock', 'optimistic_spin_queue', 'rw_semaphore', 'mutex', 'arch_shared_info', 'arch_vcpu_info', 'pvclock_vcpu_time_info', 'pvclock_wall_clock', 'vcpu_info', 'shared_info', 'start_info', 'fwnode_handle', 'fwnode_operations', 'fwnode_endpoint', 'fwnode_reference_args', 'device', 'rb_node', 'rb_root', 'rb_root_cached', 'vm_struct', 'real_mode_header', 'apic', 'smp_ops', 'wait_queue_head', 'seqcount', 'free_area', 'zone_padding', 'zone_reclaim_stat', 'lruvec', 'pglist_data', 'per_cpu_pages', 'per_cpu_pageset', 'per_cpu_nodestat', 'zone', 'zoneref', 'zonelist', 'timer_list', 'work_struct', 'completion', 'notifier_block', 'blocking_notifier_head', 'mem_section', 'arch_tlbflush_unmap_batch', 'vmacache', 'vm_area_struct', 'task_rss_stat', 'mm_rss_stat', 'page_frag', 'tlbflush_unmap_batch', 'arch_uprobe_task', 'uprobe_task', 'return_instance', 'uprobes_state', 'address_space', 'dev_pagemap', 'file', 'vm_userfaultfd_ctx', 'vm_operations_struct', 'core_thread', 'core_state', 'vm_fault', 'percpu_ref', 'shrink_control', 'shrinker', 'page_ext_operations', 'resource', 'vmem_altmap', 'hlist_bl_head', 'hlist_bl_node', 'lockref', 'qstr', 'dentry_stat_t', 'dentry', 'inode', 'dentry_operations', 'super_block', 'path', 'kstat', 'list_lru_one', 'list_lru_memcg', 'list_lru_node', 'list_lru', 'radix_tree_node', 'radix_tree_root', 'upid', 'pid', 'pid_link', 'kernel_cap_struct', 'fiemap_extent', 'rcuwait', 'rcu_sync', 'percpu_rw_semaphore', 'delayed_call', 'refcount_struct', 'sysv_sem', 'sysv_shm', 'plist_node', 'timerqueue_node', 'timerqueue_head', 'hrtimer', 'hrtimer_clock_base', 'hrtimer_cpu_base', 'seccomp', 'siginfo', 'sigpending', 'task_io_accounting', 'rseq', 'prev_cputime', 'task_cputime', 'sched_info', 'load_weight', 'util_est', 'sched_avg', 'sched_statistics', 'sched_entity', 'sched_rt_entity', 'sched_dl_entity', 'wake_q_node', 'io_context', 'io_cq', 'files_stat_struct', 'inodes_stat_t', 'kiocb', 'iattr', 'percpu_counter', 'dquot', 'kqid', 'mem_dqblk', 'mem_dqinfo', 'quota_format_type', 'dqstats', 'quota_format_ops', 'dquot_operations', 'qc_dqblk', 'qc_type_state', 'qc_state', 'qc_info', 'quotactl_ops', 'quota_info', 'address_space_operations', 'block_device', 'inode_operations', 'file_lock_context', 'fown_struct', 'file_ra_state', 'file_lock_operations', 'file_lock', 'lock_manager_operations', 'nfs_lock_info', 'nfs4_lock_info', 'fasync_struct', 'sb_writers', 'file_system_type', 'super_operations', 'fiemap_extent_info', 'dir_context', 'kobject', 'ko ...
# Removed STRUCT (136): ['trace_event_raw_ext4_nfs_commit_metadata', 'ext4_proc_files', 'usb_phy_bind', 'bin_table', 'ah_predefined_name', 'flagsbuf', 'cgroup_stat', 'trace_event_raw_bpf_map_delete_elem', 'trace_event_raw_fib_validate_source', 'xts_crypt_req', 'batch_u32', 'blk_issue_stat', 'intel_pingroup', 'fold_pred_data', 'nf_conntrack_man', 'rose_neigh', 'intel_pad_context', 'trace_event_data_offsets_bpf_map_keyval', 'acpi_gpiolib_dmi_quirk', 'intel_pinctrl_soc_data', 'trace_event_raw_bpf_prog_load', 'update_classid_context', 'dim', 'x86_io_apic_ops', 'dim_stats', 'ah_device_id', 'dim_sample', 'arg_dev_net', 'pred_stack', 'cgroup_cpu_stat', 'font_data', 'ping_seq_afinfo', 'trace_event_raw_bpf_obj_map', 'trace_event_data_offsets_bpf_map_next_key', 'bpf_ext_analyzer_ops', 'aa_net', 'conflict_context', 'boot_params_to_save', 'ax25_cb', 'trace_event_data_offsets_bpf_prog_event', 'trace_event_data_offsets_bpf_prog_load', 'filter_parse_state', 'trace_event_data_offsets_bpf_obj_map', 'dim_cq_moder', 'mx6_config', 'compat_ncp_mount_data', 'soc_device_attribute', 'pid_cache', 'efi_mokvar_table_entry', 'check_pred_data', 'trace_event_data_offsets_tcp_set_state', 'postfix_elt', 'page_to_node', 'cgroup_file_ctx', 'intel_function', 'ncp_mount_data', 'nf_conn', 'intel_pinctrl_context', 'kdb_tm', 'ipmr_mfc_iter', 'mr6_table', 'nf_ct_gre', 'iommu_pool', 'firmware_priv', 'bpf_sanitize_info', 'msr_enumeration', 'crng', 'intel_community_context', 'evtchn_loop_ctrl', 'page_map', 'dpc_rp_pio_regs', 'nf_conntrack_tuple', 'trace_event_data_offsets_bpf_map_create', 'blake2s_state', 'ip_ct_sctp', 'xt_table', 'modversion_info', 'acpi_dev_present_info', 'lp8788_ldo_enable_pin', 'trace_event_raw_bpf_map_keyval', 'ipmr_vif_iter', 'compat_ncp_mount_data_v4', 'ext4_rcu_ptr', 'hv_flush_pcpu', 'x86_cpu_desc', 'intel_padgroup', 'sg_proc_leaf', 'dm_offload', 'trace_event_raw_bpf_prog_event', 'acpi_file_node', 'fbcon_dmi_rotate_data', 'ncp_mount_data_v4', 'efi_mokvar_sysfs_attr', 'siprand_state', 'blk_mq_timeout_data', 'iommu_map_table', 'nf_ct_dccp', 'xdp_pkt', 'intel_community', 'spi_flash_read_message', 'trace_event_data_offsets_ext4_nfs_commit_metadata', 'lsm_blob_sizes', 'bpf_dev_offload', 'trace_event_data_offsets_bpf_map_delete_elem', 'mif_device', 'trace_event_raw_fib_table_lookup_nh', 'rp_pio_header_log_regs', 'firmware_buf', 'ip_ct_tcp', 'mmc_context_info', 'trace_event_raw_tcp_set_state', 'xt_table_info', 'filter_op', 'nf_afinfo', 'hv_flush_pcpu_ex', 'ip_ct_tcp_state', 'opstack_op', 'trace_event_data_offsets_bpf_obj_prog', 'bpf_verifer_log', 'acpi_comment_addr_node', 'nf_conntrack_tuple_hash', 'ipfrag_skb_cb', 'trace_event_raw_bpf_obj_prog', 'trace_event_raw_bpf_map_next_key', 'batch_u64', 'filter_match_preds_data', 'do_proc_dopipe_max_size_conv_param', 'trace_event_data_offsets_fib_table_lookup_nh', 'mmc_async_req', 'lateeoi_work', 'intel_pinctrl', 'trace_event_data_offsets_fib_validate_source', 'detach_data', 'crash_elf_data', 'trace_event_raw_bpf_map_create', 'configfs_fragment']
# Added STRUCT (426): ['btf_enum', 'ib_flow_spec_list', 'sctp_outq', 'sctp_inithdr', 'iomap_swapfile_info', 'field_var', 'ib_flow_spec_ipv4', 'ib_flow_eth_filter', '__aio_sigset', 'ptp_pin_desc', 'pps_fdata_compat', 'sctp_af', 'xdp_umem_props', 'ib_counters', 'sctp_auth_bytes', 'xdp_rxq_info', 'compat_consolefontdesc', 'trace_event_data_offsets_random_read', 'bpf_prog_offload_ops', 'nvm_tgt_type', 'sfp_bus', 'sctp_paramhdr', 'poolinfo', 'ns_get_path_bpf_prog_args', 'sctp_event_subscribe', 'ib_flow_mpls_filter', 'sctp_inq', 'sctp_ifwdtsn_skip', 'x64_jit_data', 'trace_event_raw_rseq_ip_fixup', 'sctp_shared_key', 'sctp_errhdr', 'error_injection_entry', 'trace_event_data_offsets_push_to_pool', 'sctp_hashbucket', 'xdp_mem_info', 'sctp_chunkhdr', 'xdp_umem_reg', 'aa_net_compat', 'xhci_port', 'sctp_endpoint', 'bpf_insn_cbs', 'util_est', 'usb_phy_roothub', 'bpf_offloaded_map', 'copy_subpage_arg', 'ib_flow_action', 'seccomp_metadata', 'sctp_ifwdtsn_hdr', 'trace_event_raw_add_device_randomness', 'spi_mem', 'ptp_clock_request', 'trace_event_raw_random__extract_entropy', 'trace_event_raw_add_disk_randomness', 'tun_prog', 'umh_info', 'ieee80211_wmm_rule', 'sctp_supported_addrs_param', 'nvm_addrf', 'trace_event_raw_initcall_finish', 'sctp_cookie', 'trace_event_raw_rseq_update', 'sctp_stream_out', 'vmcoredd_node', 'fib6_info', 'selinux_map', 'trace_event_data_offsets_xdp_devmap_xmit', 'stack_map_irq_work', 'dcbnl_buffer', 'itimerspec64', 'nvm_ioctl_device_info', 'ib_dm', 'ib_flow_spec_eth', 'trace_event_data_offsets_add_disk_randomness', 'nvm_ioctl_remove', 'nvm_ch_map', 'ptp_clock_time', 'sctp_initmsg', 'nvm_ioctl_dev_init', 'bpf_prog_offload', 'rdma_restrack_root', 'sctp_bind_hashbucket', 'trace_event_data_offsets_rtc_irq_set_state', 'sctp_assocparams', 'tlsdev_ops', 'bpf_sock_progs', 'sfp_eeprom_base', 'sctp_cookie_param', 'sctp_stream_priorities', 'i2c_device_identity', 'tcp_zerocopy_receive', 'trace_event_raw_random_read', 'nf_nat_hook', 'ptp_sys_offset', 'display_timings', '__kernel_old_timeval', 'tc_mq_qopt_offload', 'sk_msg_buff', 'ppa_addr', 'ipv6_bpf_stub', 'timestamp_event_queue', 'acpi_battery_hook', 'crng_state', 'sctp_tsnmap', 'sctp_init_chunk', 'trace_event_raw_random__mix_pool_bytes', 'bpf_raw_tracepoint', 'sched_in_data', 'page_pool', 'lpss_device_links', 'trace_event_data_offsets_add_input_randomness', 'cpuid_regs', 'bpf_fib_lookup', 'hid_uid', 'sctp_hostname_param', 'hv_tsc_emulation_control', 'tcf_filter_chain_list_item', '__compat_aio_sigset', 'ib_flow_ib_filter', 'cooling_dev_stats', 'trace_event_data_offsets_add_device_randomness', 'ns_get_path_bpf_map_args', 'match_workbuf', 'ipi_arg_non_ex', 'rdma_restrack_entry', 'ib_flow_action_attrs_esp', 'ib_flow_action_attrs_esp_keymats', 'ptp_clock_caps', 'vmcoredd_data', 'cgroup_rstat_cpu', 'btf_kind_operations', 'hpc_ops', 'sctp_sock', 'display_timing', 'trace_event_raw_random__get_random_bytes', 'ei_entry', 'netlink_tap_net', 'task_move_callback', 'sctp_stream_interleave', 'cper_ia_err_info', 'zero_copy_allocator', 'pushbutton_work_info', 'scsi_log_buf', 'bpf_func_state', 'selinux_fs_info', 'random_ready_callback', 'sfp_eeprom_id', 'nvm_chk_meta', 'devlink_port_attrs', 'sctp_pf', 'ib_counters_read_attr', 'ib_flow_ipv4_filter', 'sctp_inithdr_host', 'ib_flow_spec_action_count', 'st_clk_data', 'trace_event_raw_credit_entropy_bits', 'hv_reenlightenment_control', 'trace_event_data_offsets_rtc_irq_set_freq', 'xdp_ring_offset', 'fd_data', 'ib_flow_spec_gre', 'trace_event_raw_rtc_irq_set_state', 'sctp_signed_cookie', 'xdp_umem_page', 'nvm_ioctl_create', 'bpf_subprog_info', 'trace_event_data_offsets_rtc_alarm_irq_enable', 'nvm_dev_map', 'sctp_shutdownhdr', 'resolve_vertex', 'ieee80211_wmm_ac', 'sctp_ipv6addr_param', 'hv_vp_assist_page', 'bpf_xfrm_state', 'pps_kinfo_compat', 'xdp_umem', 'rseq', 'nvm_ioctl_dev_factory', 'timing_entry', 'sctp_priv_assoc_stats', 'selinux_avc', 'msr_info_completion', 'ib_flow_spec_tcp_udp', 'trace_event_data_offsets_rtc_timer_class', 'cper_sec_proc_ia', 'pp ...
# Common STRUCT (7193): ['kprobe_ctlblk', 'ipc_ids', 'nd_btt', 'cfg80211_ssid', 'trace_event_data_offsets_iommu_group_event', 'icmpmsg_mib', 'dbc_str_descs', 'switchdev_ops', 'gpiohandle_data', 'tlvtype_proc', 'trace_event_data_offsets_sched_process_wait', 'compstat', 'device', 'trace_event_raw_dax_pmd_fault_class', 'atm_cirange', 'robust_list', 'acpi_gpio_params', 'pvclock_vcpu_time_info', 'acpi_sci_handler_info', 'dio', 'tboot_acpi_sleep_info', 'xhci_interval_bw', 'trace_event_raw_alarm_class', 'tomoyo_unix_acl', 'acpi_table_pcct', 'aml_resource_large_header', 'vme_resource', 'dev_pm_info', 'trace_event_data_offsets_wbt_stat', 'fb_info', 'mdio_board_entry', 'nf_queue_handler', 'switchdev_deferred_item', 'acpi_gpe_xrupt_info', 'uffdio_api', 'trace_event_raw_thermal_power_devfreq_get_power', 'apei_resources', 'dm_file', 'max8925_touch_pdata', 'memblock', 'trace_event_data_offsets_ext4_da_release_space', 'platform_suspend_ops', 'bio_set', 'usb2_lpm_parameters', 'ext4_filename', 'usb_otg_caps', 'trace_event_raw_hyperv_mmu_flush_tlb_others', 'strparser', 'extcon_cable', 'trace_event_data_offsets_rpm_return_int', 'tcp_repair_opt', 'location', 'md_thread', 'cn_queue_dev', 'dyn_ftrace', 'tomoyo_page_dump', 'trace_event_raw_ext4_allocate_blocks', 'skein_512_ctx', 'acpi_resource_pin_function', 'ubuf_info', 'hist_field', 'tty_ldisc_ops', 'ftrace_mod_map', 'mdio_driver_common', 'ftrace_func_probe', 'perf_ns_link_info', 'efi_system_resource_table', 'memcg_kmem_cache_create_work', 'fake_dirent', 'xhci_tt_bw_info', 'dql', 'wpan_dev', 'adp5520_keys_platform_data', 'aml_resource_pin_group_config', 'tboot_mac_region', 'tc_stats', 'trace_event_data_offsets_ext4_request_inode', 'vblk_dgrp', 'netdev_hw_addr', 'pnp_option', 'purgatory_info', 'ata_scsi_args', 'trace_event_data_offsets_ext4_ext_put_in_cache', 'trace_event_data_offsets_xen_mmu_release_ptpage', 'ib_cache', 'trace_event_data_offsets_scsi_eh_wakeup', 'lzo_ctx', 'idt_bits', 'acpi_package_info', 'trace_event_functions', 'inet_protosw', 'wiphy_coalesce_support', 'ncsi_cmd_pkt_hdr', 'intel_excl_cntrs', 'trace_event_raw_ata_eh_link_autopsy_qc', 'trace_event_data_offsets_clock', 'xhci_interval_bw_table', 'bad_iret_stack', 'ip_reply_arg', 'trace_event_raw_mm_compaction_isolate_template', 'cacheinfo', 'pefile_context', 'avtab_extended_perms', 'sdhci_pci_data', 'acpi_vendor_walk_info', 'ncsi_rsp_pkt', 'kset', 'perf_ibs', 'trace_event_data_offsets_mm_migrate_pages', 'ida', 'xhci_regset', 'blk_mq_tags', 'tcf_ematch_tree_hdr', 'boardinfo', 'slabinfo', 'packet_sock', 'kgdb_state', 'port', 'squashfs_ipc_inode', 'trace_event_data_offsets_spi_controller', 'cma', 'pci_ops', 'tpm_space', 'tun_struct', 'trace_event_data_offsets_br_fdb_external_learn_add', 'acpi_hotplug_profile', 'lp8788_buck2_dvs', 'prctl_mm_map', 'tcg_efi_specid_event', 'userspace_data', 'vt_setactivate', 'inet6_skb_parm', 'perf_amd_iommu', 'bsg_job', 'module_attribute', 'tcf_action_net', 'config_s', 'sk_security_struct', 'compat_msqid_ds', 'ifla_vf_rss_query_en', 'percpu_cluster', 'server_hdr', 'cpc_reg', 'iovec', 'aead_instance', 'trace_event_raw_ext4_ext_remove_space', 'tsq_tasklet', 'ff_effect', 'video_spu_palette', 'error_info2', 'pt_regs_offset', 'nmiaction', 'dbc_info_context', 'cpu_model', 'acpi_object_field_common', 'sockaddr_in6', 'trace_event_data_offsets_ext4_es_find_delayed_extent_range_enter', 'shmid_kernel', 'trace_event_raw_block_unplug', 'trace_event_data_offsets_block_rq_requeue', 'cpc_register_resource', 'trace_event_data_offsets_ext4__es_shrink_enter', 'rtnl_net_dump_cb', 'radix_tree_preload', '_xmmreg', 'lwtunnel_state', 'tracing_map_ops', 'dm_io_request', 'trace_event_raw_qdisc_dequeue', 'acpi_power_resource', 'blkg_stat', 'dma_fence', 'agp_allocate', 'percpu_ida_cpu', 'zone', 'thermal_state', 'tomoyo_env_acl', 'vmap_block_queue', 'pmc_clk_data', 'smp_call_on_cpu_struct', 'sched_rt_entity', 'x86_pmu', 'uinput_ff_upload', 'keyring_index_key', 'xen_add_to_physmap', 'trace_event_raw_jbd2_lock_buffer_stall', 'fib4_rule', ...
# Changed STRUCT (715): ['nd_btt', 'device', 'fb_info', 'bio_set', 'hist_field', 'mdio_driver_common', 'purgatory_info', 'perf_ibs', 'packet_sock', 'tpm_space', 'tun_struct', 'perf_amd_iommu', 'bsg_job', 'sk_security_struct', 'nmiaction', 'shmid_kernel', 'tracing_map_ops', 'acpi_power_resource', 'pmc_clk_data', 'x86_pmu', 'fib4_rule', 'sem', 'target_type', 'xenbus_driver', 'hist_trigger_data', 'regulator_config', 'usb_device', 'backlight_device', 'user_struct', 'pcie_device', 'tpmrm_priv', 'crash_mem', 'gpio_chip', 'sx150x_pinctrl', 'gnttab_ops', 'map_files_info', 'x86_init_irqs', 'acpi_thermal', 'serdev_controller_ops', 'ring_buffer_per_cpu', 'bpf_perf_event_data', 'cgroup_cls_state', 'sugov_cpu', 'nfs_client', 'sccnxp_port', 'rio_driver', 'ext4_inode_info', 'ib_device', 'serdev_device', 'netns_xfrm', 'eventpoll', 'pci_dev', 'device_private', 'tcf_bind_args', 'mousedev', 'as3711_bl_pdata', 'wm8350', 'page_counter', 'extcon_dev', 'filename', 'netns_sysctl_ipv6', 'mr_table', 'ata_host', 'security_hook_list', 'request', 'wm8350_pmic', 'packet_type', 'to_kill', 'pnp_protocol', 'fuse_inode', 'bpf_map', 'cpumap', 'blkif_sring', 'crypto_type', 'powercap_zone', 'tcf_idrinfo', 'css_task_iter', 'linux_mib', 'trace_event_raw_aer_event', 'mdio_device', 'ecryptfs_inode_info', 'wake_irq', 'cgroup', 'perf_addr_filter', 'clk', 'mfc_cache', 'tpm_chip', 'pnp_driver', 'swap_info_struct', 'apic', 'spi_driver', 'hmm_range', 'compat_stat', 'wm8400', 'frag_queue', 'tracing_map', 'pci_epc', 'netlink_sock', 'scsi_device', 'hwmon_device', 'xenbus_watch', 'ms_hyperv_info', 'unwind_state', 'intel_iommu', 'bsg_class_device', 'entry_stack', 'stack_map_bucket', 'ib_flow_attr', 'dm_target_io', 'dwc2_core_params', 'md_personality', 'phy_attrs', 'xenbus_device', 'perf_cgroup', 'ipcm_cookie', 'ehci_platform_priv', 'inet_peer', 'task_struct', 'proc_inode', 'address_space', 'mipi_dsi_device', 'memory_block', 'power_supply', 'pnp_dev', 'mbm_state', 'i2c_board_info', 'usb_hcd', 'platform_driver', 'trace_event_raw_mm_shrink_slab_start', 'pwm_export', 'usbdrv_wrap', 'dwc2_hcd_pipe_info', 'netdev_rx_queue', 'pt_pmu', 'netfront_queue', 'dw_i2c_dev', 'nl_seq_iter', 'flow_keys', 'dst_entry', 'uart_8250_port', 'event_filter', 'lp_gpio', 'controller', 'nd_namespace_blk', 'metadata_dst', 'xenbus_file_priv', 'ata_link', 'netns_nftables', 'bpf_dtab_netdev', 'tps68470_gpio_data', 'acpi_gpio_info', 'ipc_proc_iter', 'pci_epf', 'kmem_cache', 'scsi_host_template', 'phy_device', 'ib_pd', 'ipv6_stub', 'acpi_device_pnp', 'nvdimm_bus', 'watchdog_core_data', 'regulator', 'dev_cgroup', 'fib_rule', 'configfs_dirent', 'device_link', 'usb_ep_ops', 'ext4_sb_info', 'bpf_call_arg_meta', 'dma_device', 'earlycon_device', 'worker_pool', 'i2c_driver', 'nd_label_ent', 'clone_info', 'cpuidle_state_usage', 'isa_dev', 'wb_writeback_work', 'nd_blk_region_desc', 'vme_driver', 'devlink_port', 'bpf_map_ops', 'pci_host_bridge', 'container_dev', 'idr', 'exit_proc_event', 'ttyprintk_port', 'netns_core', 'giveback_urb_bh', 'i2c_adapter', 'xfs_globals', 'raw_sock', 'proc_dir_entry', 'fasync_struct', 'rtnl_link', 'serdev_controller', 'csrow_info', 'rdma_cgroup', 'posix_clock', 'x86_cpu_id', 'netns_ipv6', 'sbitmap_queue', 'lpss_device_desc', 'cppc_perf_caps', 'device_driver', 'spi_controller', 'zpool', 'mmc_host', 'blk_mq_hw_ctx', 'mem_cgroup', 'x86_hyper_init', 'scsi_driver', 'node', 'rpc_rqst', 'smap_psock_map_entry', 'x86_legacy_features', 'nfs_rpc_ops', 'rfkill', 'ifacaddr6', 'dimm_info', 'pci_epf_group', 'rcu_node', 'hmm_devmem', 'rcu_data', 'net_protocol', 'dma_chan_dev', 'fork_frame', 'pg_state', 'cgroup_subsys', 'pcpu', 'radix_tree_root', 'parallel_data', 'dev_pagemap', 'scan_control', 'ext4_system_zone', 'intel_uncore_box', 'lp8788_platform_data', 'regmap_mmio_context', 'mii_bus', 'cred', 'rtable', 'ep_device', 'pnp_card', 'tracefs_mount_opts', 'tracefs_fs_info', 'inet6_ifaddr', 'throtl_data', 'xen_netif_rx_sring', 'nd_dax', 'Scsi_Host', 'xenbus_transaction_holder', 'mddev', 'worker', 'phy', 'regulator_ ...
# STRUCT nd_btt differs: Struct size changed caused by field size change
# STRUCT device differs: Fields added and removed: {'dma_32bit_limit'} {'msi_lock'}
# STRUCT fb_info differs: Added fields: {'fbcon_rotate_hint'}
# STRUCT bio_set differs: Struct size changed caused by field size change
# STRUCT hist_field differs: Added fields: {'var_ref_idx', 'hist_data', 'name', 'var_idx', 'var', 'event_name', 'system', 'read_once', 'operator', 'type'}
# STRUCT mdio_driver_common differs: Struct size changed caused by field size change
# STRUCT purgatory_info differs: Removed fields: {'purgatory_load_addr'}
# STRUCT perf_ibs differs: Removed fields: {'fetch_count_reset_broken', 'fetch_ignore_if_zero_rip'}
# STRUCT packet_sock differs: Removed fields: {'skb_completion'}
# STRUCT tpm_space differs: Removed fields: {'buf_size'}
# STRUCT tun_struct differs: Added fields: {'filter_prog', 'link_ksettings', 'steering_prog'}
# STRUCT perf_amd_iommu differs: Struct size changed caused by field size change
# STRUCT bsg_job differs: Fields added and removed: {'timeout', 'result', 'reply_payload_rcv_len'} {'req', 'sreq'}
# STRUCT sk_security_struct differs: Added fields: {'sctp_assoc_state'}
# STRUCT nmiaction differs: Added fields: {'irq_work'}
# STRUCT shmid_kernel differs: Removed fields: {'ns'}
# STRUCT tracing_map_ops differs: Removed fields: {'elt_copy'}
# STRUCT acpi_power_resource differs: Struct size changed caused by field size change
# STRUCT pmc_clk_data differs: Removed fields: {'critical'}
# STRUCT x86_pmu differs: Fields added and removed: {'read', 'large_pebs_flags'} {'check_period', 'free_running_flags'}
# STRUCT fib4_rule differs: Struct size changed caused by field size change
# STRUCT sem differs: Field changed size without affecting size of struct
# STRUCT target_type differs: Added fields: {'dax_copy_to_iter'}
# STRUCT xenbus_driver differs: Struct size changed caused by field size change
# STRUCT hist_trigger_data differs: Added fields: {'n_actions', 'actions', 'n_field_var_hists', 'n_field_vars', 'var_refs', 'synth_var_refs', 'enable_timestamps', 'n_var_refs', 'field_var_hists', 'remove', 'field_vars', 'n_vars', 'max_vars', 'n_max_var_str', 'n_synth_var_refs', 'n_max_vars', 'n_field_var_str'}
# STRUCT regulator_config differs: Added fields: {'ena_gpiod'}
# STRUCT usb_device differs: Fields added and removed: {'hub_delay', 'tx_lanes', 'rx_lanes'} {'reset_in_progress'}
# STRUCT backlight_device differs: Struct size changed caused by field size change
# STRUCT user_struct differs: Added fields: {'ratelimit'}
# STRUCT pcie_device differs: Struct size changed caused by field size change
# STRUCT tpmrm_priv differs: Struct size changed caused by field size change
# STRUCT crash_mem differs: Added fields: {'max_nr_ranges'}
# STRUCT gpio_chip differs: Added fields: {'valid_mask', 'need_valid_mask'}
# STRUCT sx150x_pinctrl differs: Struct size changed caused by field size change
# STRUCT gnttab_ops differs: Fields added and removed: {'query_foreign_access'} {'read_frame'}
# STRUCT map_files_info differs: Fields added and removed: {'start', 'end'} {'name', 'len'}
# STRUCT x86_init_irqs differs: Removed fields: {'intr_mode_select'}
# STRUCT acpi_thermal differs: Removed fields: {'thermal_check_lock', 'thermal_check_count'}
# STRUCT serdev_controller_ops differs: Added fields: {'set_parity'}
# STRUCT ring_buffer_per_cpu differs: Added fields: {'nest'}
# STRUCT bpf_perf_event_data differs: Added fields: {'addr'}
# STRUCT cgroup_cls_state differs: Struct size changed caused by field size change
# STRUCT sugov_cpu differs: Fields added and removed: {'util_cfs', 'util_dl'} {'util', 'flags'}
# STRUCT nfs_client differs: Added fields: {'cl_callback_count'}
# STRUCT sccnxp_port differs: Struct size changed caused by field size change
# STRUCT rio_driver differs: Struct size changed caused by field size change
# STRUCT ext4_inode_info differs: Struct size changed caused by field size change
# STRUCT ib_device differs: Added fields: {'modify_flow_action_esp', 'dealloc_dm', 'res', 'reg_dm_mr', 'create_flow_action_esp', 'destroy_flow_action', 'create_counters', 'alloc_dm', 'destroy_counters', 'driver_id', 'read_counters'}
# STRUCT serdev_device differs: Struct size changed caused by field size change
# STRUCT netns_xfrm differs: Removed fields: {'xfrm_state_hash_generation'}
# STRUCT eventpoll differs: Fields added and removed: {'visited_list_link', 'visited'} {'gen'}
# STRUCT pci_dev differs: Fields added and removed: {'broken_cmd_compl'} {'clear_retrain_link', 'skip_bus_pm', 'pref_window', 'io_window', 'is_added', 'pref_64_window'}
# STRUCT device_private differs: Removed fields: {'dead'}
# STRUCT tcf_bind_args differs: Removed fields: {'base'}
# STRUCT mousedev differs: Struct size changed caused by field size change
# STRUCT as3711_bl_pdata differs: Struct size changed caused by field size change
# STRUCT wm8350 differs: Struct size changed caused by field size change
# STRUCT page_counter differs: Fields added and removed: {'usage', 'min', 'max', 'children_low_usage', 'emin', 'children_min_usage', 'elow', 'low_usage', 'min_usage', 'low'} {'count', 'limit'}
# STRUCT extcon_dev differs: Struct size changed caused by field size change
# STRUCT filename differs: Fields reordered
# STRUCT netns_sysctl_ipv6 differs: Added fields: {'multipath_hash_policy', 'seg6_flowlabel'}
# STRUCT mr_table differs: Added fields: {'ops'}
# STRUCT ata_host differs: Added fields: {'kref'}
# STRUCT security_hook_list differs: Removed fields: {'lsm_index'}
# STRUCT request differs: Fields added and removed: {'__deadline', 'state', 'ref', 'wbt_flags'} {'issue_stat', 'deadline', 'atomic_flags', 'start_time'}
# STRUCT wm8350_pmic differs: Struct size changed caused by field size change
# STRUCT packet_type differs: Removed fields: {'af_packet_net'}
# STRUCT to_kill differs: Added fields: {'size_shift'}
# STRUCT pnp_protocol differs: Struct size changed caused by field size change
# STRUCT fuse_inode differs: Struct size changed caused by field size change
# STRUCT bpf_map differs: Added fields: {'btf', 'btf_value_type_id', 'btf_key_type_id'}
# STRUCT cpumap differs: Removed fields: {'managed_allocated'}
# STRUCT blkif_sring differs: Fields added and removed: {'pad'} {'__pad'}
# STRUCT crypto_type differs: Removed fields: {'lookup'}
# STRUCT powercap_zone differs: Struct size changed caused by field size change
# STRUCT tcf_idrinfo differs: Removed fields: {'net'}
# STRUCT css_task_iter differs: Removed fields: {'dying_tasks_head', 'cur_tasks_head'}
# STRUCT linux_mib differs: Struct size changed caused by field size change
# STRUCT trace_event_raw_aer_event differs: Added fields: {'tlp_header_valid', 'tlp_header'}
# STRUCT mdio_device differs: Fields added and removed: {'reset_deassert_delay', 'reset', 'reset_assert_delay'} {'pm_ops'}
# STRUCT ecryptfs_inode_info differs: Struct size changed caused by field size change
# STRUCT wake_irq differs: Added fields: {'name'}
# STRUCT cgroup differs: Fields added and removed: {'prev_cputime', 'rstat_cpu', 'rstat_css_list', 'pending_bstat', 'bstat'} {'pending_stat', 'stat', 'cpu_stat'}
# STRUCT perf_addr_filter differs: Fields added and removed: {'action'} {'range', 'filter'}
# STRUCT clk differs: Added fields: {'exclusive_count'}
# STRUCT mfc_cache differs: Fields added and removed: {'_c'} {'mfc_un', 'rcu', 'mfc_flags', 'mnode', 'mfc_parent', 'list'}
# STRUCT tpm_chip differs: Added fields: {'hwrng', 'hwrng_name'}
# STRUCT pnp_driver differs: Struct size changed caused by field size change
# STRUCT swap_info_struct differs: Struct size changed caused by field reordering:
# {'id': 1845, 'kind': 'STRUCT', 'name': 'swap_info_struct', 'size': 272, 'vlen': 27, 'members': [{'name': 'flags', 'type_id': 1, 'bits_offset': 0}, {'name': 'prio', 'type_id': 16, 'bits_offset': 64}, {'name': 'list', 'type_id': 1311, 'bits_offset': 128}, {'name': 'type', 'type_id': 12, 'bits_offset': 448}, {'name': 'max', 'type_id': 9, 'bits_offset': 480}, {'name': 'swap_map', 'type_id': 1730, 'bits_offset': 512}, {'name': 'cluster_info', 'type_id': 2409, 'bits_offset': 576}, {'name': 'free_clusters', 'type_id': 2408, 'bits_offset': 640}, {'name': 'lowest_bit', 'type_id': 9, 'bits_offset': 768}, {'name': 'highest_bit', 'type_id': 9, 'bits_offset': 800}, {'name': 'pages', 'type_id': 9, 'bits_offset': 832}, {'name': 'inuse_pages', 'type_id': 9, 'bits_offset': 864}, {'name': 'cluster_next', 'type_id': 9, 'bits_offset': 896}, {'name': 'cluster_nr', 'type_id': 9, 'bits_offset': 928}, {'name': 'percpu_cluster', 'type_id': 2410, 'bits_offset': 960}, {'name': 'curr_swap_extent', 'type_id': 2411, 'bits_offset': 1024}, {'name': 'first_swap_extent', 'type_id': 2405, 'bits_offset': 1088}, {'name': 'bdev', 'type_id': 1056, 'bits_offset': 1408}, {'name': 'swap_file', 'type_id': 746, 'bits_offset': 1472}, {'name': 'old_block_size', 'type_id': 9, 'bits_offset': 1536}, {'name': 'frontswap_map', 'type_id': 406, 'bits_offset': 1600}, {'name': 'frontswap_pages', 'type_id': 79, 'bits_offset': 1664}, {'name': 'lock', 'type_id': 492, 'bits_offset': 1696}, {'name': 'cont_lock', 'type_id': 492, 'bits_offset': 1728}, {'name': 'discard_work', 'type_id': 689, 'bits_offset': 1792}, {'name': 'discard_clusters', 'type_id': 2408, 'bits_offset': 2048}, {'name': 'avail_lists', 'type_id': 2412, 'bits_offset': 2176}]}
# {'id': 1852, 'kind': 'STRUCT', 'name': 'swap_info_struct', 'size': 41232, 'vlen': 27, 'members': [{'name': 'flags', 'type_id': 1, 'bits_offset': 0}, {'name': 'prio', 'type_id': 17, 'bits_offset': 64}, {'name': 'list', 'type_id': 944, 'bits_offset': 128}, {'name': 'avail_lists', 'type_id': 2447, 'bits_offset': 448}, {'name': 'type', 'type_id': 12, 'bits_offset': 328128}, {'name': 'max', 'type_id': 9, 'bits_offset': 328160}, {'name': 'swap_map', 'type_id': 1699, 'bits_offset': 328192}, {'name': 'cluster_info', 'type_id': 2448, 'bits_offset': 328256}, {'name': 'free_clusters', 'type_id': 2446, 'bits_offset': 328320}, {'name': 'lowest_bit', 'type_id': 9, 'bits_offset': 328448}, {'name': 'highest_bit', 'type_id': 9, 'bits_offset': 328480}, {'name': 'pages', 'type_id': 9, 'bits_offset': 328512}, {'name': 'inuse_pages', 'type_id': 9, 'bits_offset': 328544}, {'name': 'cluster_next', 'type_id': 9, 'bits_offset': 328576}, {'name': 'cluster_nr', 'type_id': 9, 'bits_offset': 328608}, {'name': 'percpu_cluster', 'type_id': 2449, 'bits_offset': 328640}, {'name': 'curr_swap_extent', 'type_id': 2450, 'bits_offset': 328704}, {'name': 'first_swap_extent', 'type_id': 2443, 'bits_offset': 328768}, {'name': 'bdev', 'type_id': 1164, 'bits_offset': 329088}, {'name': 'swap_file', 'type_id': 753, 'bits_offset': 329152}, {'name': 'old_block_size', 'type_id': 9, 'bits_offset': 329216}, {'name': 'frontswap_map', 'type_id': 412, 'bits_offset': 329280}, {'name': 'frontswap_pages', 'type_id': 81, 'bits_offset': 329344}, {'name': 'lock', 'type_id': 502, 'bits_offset': 329376}, {'name': 'cont_lock', 'type_id': 502, 'bits_offset': 329408}, {'name': 'discard_work', 'type_id': 693, 'bits_offset': 329472}, {'name': 'discard_clusters', 'type_id': 2446, 'bits_offset': 329728}]}
# STRUCT apic differs: Removed fields: {'vector_allocation_domain', 'cpu_mask_to_apicid'}
# STRUCT spi_driver differs: Struct size changed caused by field size change
# STRUCT hmm_range differs: Added fields: {'values', 'flags', 'pfn_shift', 'vma'}
# STRUCT compat_stat differs: Added fields: {'__pad1', '__pad2'}
# STRUCT wm8400 differs: Struct size changed caused by field size change
# STRUCT frag_queue differs: Struct size changed caused by field size change
# STRUCT tracing_map differs: Added fields: {'n_vars'}
# STRUCT pci_epc differs: Added fields: {'features'}
# STRUCT netlink_sock differs: Struct size changed caused by field size change
# STRUCT scsi_device differs: Struct size changed caused by field size change
# STRUCT hwmon_device differs: Struct size changed caused by field size change
# STRUCT xenbus_watch differs: Removed fields: {'will_handle', 'nr_pending'}
# STRUCT ms_hyperv_info differs: Added fields: {'nested_features'}
# STRUCT unwind_state differs: Removed fields: {'next_bp'}
# STRUCT intel_iommu differs: Removed fields: {'drhd'}
# STRUCT bsg_class_device differs: Fields added and removed: {'ops'} {'parent', 'ref', 'release'}
# STRUCT entry_stack differs: Fields added and removed: {'words'} {'stack'}
# STRUCT stack_map_bucket differs: Fields added and removed: {'data'} {'ip'}
# STRUCT ib_flow_attr differs: Added fields: {'flows'}
# STRUCT dm_target_io differs: Added fields: {'inside_dm_io', 'magic'}
# STRUCT dwc2_core_params differs: Fields added and removed: {'power_down', 'hird_threshold', 'ipg_isoc_en', 'lpm', 'acg_enable', 'besl', 'hird_threshold_en', 'lpm_clock_gating'} {'hibernation'}
# STRUCT md_personality differs: Added fields: {'start'}
# STRUCT phy_attrs differs: Added fields: {'mode'}
# STRUCT xenbus_device differs: Struct size changed caused by field size change
# STRUCT perf_cgroup differs: Struct size changed caused by field size change
# STRUCT ipcm_cookie differs: Added fields: {'gso_size'}
# STRUCT ehci_platform_priv differs: Removed fields: {'num_phys', 'phys', 'quirk_poll', 'poll_work', 'poll_timer'}
# STRUCT inet_peer differs: Removed fields: {'n_redirects'}
# STRUCT task_struct differs: Fields added and removed: {'rseq', 'rseq_len', 'rseq_sig', 'rseq_event_mask', 'recent_used_cpu'} {'futex_state', 'futex_exit_mutex', 'curr_ret_depth'}
# STRUCT proc_inode differs: Struct size changed caused by field size change
# STRUCT address_space differs: Fields added and removed: {'i_pages'} {'page_tree', 'tree_lock'}
# STRUCT mipi_dsi_device differs: Struct size changed caused by field size change
# STRUCT memory_block differs: Added fields: {'nid'}
# STRUCT power_supply differs: Struct size changed caused by field size change
# STRUCT pnp_dev differs: Struct size changed caused by field size change
# STRUCT mbm_state differs: Added fields: {'chunks_bw', 'delta_bw', 'delta_comp', 'prev_bw_msr', 'prev_bw'}
# STRUCT i2c_board_info differs: Removed fields: {'archdata'}
# STRUCT usb_hcd differs: Fields added and removed: {'phy_roothub', 'skip_phy_initialization'} {'phy', 'remove_phy'}
# STRUCT platform_driver differs: Struct size changed caused by field size change
# STRUCT trace_event_raw_mm_shrink_slab_start differs: Fields added and removed: {'priority'} {'pgs_scanned', 'lru_pgs'}
# STRUCT pwm_export differs: Struct size changed caused by field size change
# STRUCT usbdrv_wrap differs: Struct size changed caused by field size change
# STRUCT dwc2_hcd_pipe_info differs: Fields added and removed: {'mps'} {'maxp', 'maxp_mult'}
# STRUCT netdev_rx_queue differs: Added fields: {'xdp_rxq'}
# STRUCT pt_pmu differs: Struct size changed caused by field size change
# STRUCT netfront_queue differs: Removed fields: {'tx_link', 'rx_cons_lock', 'rx_rsp_unconsumed', 'tx_pend_queue'}
# STRUCT dw_i2c_dev differs: Fields added and removed: {'rinfo'} {'skip_resume', 'suspended'}
# STRUCT nl_seq_iter differs: Struct size changed caused by field size change
# STRUCT flow_keys differs: Struct size changed caused by field size change
# STRUCT dst_entry differs: Fields added and removed: {'__pad'} {'child', 'from', '__pad3', '(anon)', '__pad_to_align_refcnt', 'path'}
# STRUCT uart_8250_port differs: Removed fields: {'overrun_backoff', 'overrun_backoff_time_ms'}
# STRUCT event_filter differs: Fields added and removed: {'prog'} {'n_preds', 'a_preds', 'preds', 'root'}
# STRUCT lp_gpio differs: Struct size changed caused by field size change
# STRUCT controller differs: Fields added and removed: {'cmd_lock', 'slot_list', 'crit_sect', 'pci_dev', 'slot_device_offset', 'first_slot', 'num_slots', 'slot_num_inc', 'pcix_misc2_reg', 'cap_offset', 'hpc_ops', 'mmio_size', 'mmio_base', 'creg'} {'ctrl_lock', 'cmd_started', 'cmd_busy', 'slot', 'pcie', 'slot_cap', 'power_fault_detected', 'notification_enabled', 'link_active_reporting', 'slot_ctrl'}
# STRUCT nd_namespace_blk differs: Struct size changed caused by field size change
# STRUCT metadata_dst differs: Struct size changed caused by field size change
# STRUCT xenbus_file_priv differs: Removed fields: {'wq'}
# STRUCT ata_link differs: Field changed size without affecting size of struct
# STRUCT netns_nftables differs: Fields added and removed: {'tables', 'validate_state'} {'bridge', 'inet', 'arp', 'ipv4', 'ipv6', 'netdev', 'af_info'}
# STRUCT bpf_dtab_netdev differs: Added fields: {'bulkq'}
# STRUCT tps68470_gpio_data differs: Struct size changed caused by field size change
# STRUCT acpi_gpio_info differs: Added fields: {'adev', 'quirks'}
# STRUCT ipc_proc_iter differs: Added fields: {'pid_ns'}
# STRUCT pci_epf differs: Struct size changed caused by field size change
# STRUCT kmem_cache differs: Fields added and removed: {'usersize', 'useroffset'} {'reserved'}
# STRUCT scsi_host_template differs: Fields added and removed: {'sdev_groups'} {'legacy_hosts', 'detect', 'release'}
# STRUCT phy_device differs: Removed fields: {'suspended_by_mdio_bus'}
# STRUCT ib_pd differs: Added fields: {'res'}
# STRUCT ipv6_stub differs: Fields added and removed: {'ip6_mtu_from_fib6', 'fib6_lookup', 'ipv6_dst_lookup', 'fib6_get_table', 'fib6_table_lookup', 'fib6_multipath_select'} {'ipv6_dst_lookup_flow'}
# STRUCT acpi_device_pnp differs: Removed fields: {'instance_no'}
# STRUCT nvdimm_bus differs: Fields added and removed: {'probe_wait'} {'ioctl_active', 'wait'}
# STRUCT watchdog_core_data differs: Fields added and removed: {'kref', 'timer'} {'dev'}
# STRUCT regulator differs: Fields added and removed: {'voltage'} {'min_uV', 'max_uV'}
# STRUCT dev_cgroup differs: Struct size changed caused by field size change
# STRUCT fib_rule differs: Added fields: {'proto', 'sport_range', 'ip_proto', 'dport_range'}
# STRUCT configfs_dirent differs: Removed fields: {'s_frag'}
# STRUCT device_link differs: Added fields: {'kref'}
# STRUCT usb_ep_ops differs: Added fields: {'dispose'}
# STRUCT ext4_sb_info differs: Fields added and removed: {'s_journal_flag_rwsem'} {'s_writepages_rwsem'}
# STRUCT bpf_call_arg_meta differs: Added fields: {'msize_umax_value', 'msize_smax_value'}
# STRUCT dma_device differs: Removed fields: {'owner'}
# STRUCT earlycon_device differs: Struct size changed caused by field size change
# STRUCT worker_pool differs: Removed fields: {'attach_mutex'}
# STRUCT i2c_driver differs: Struct size changed caused by field size change
# STRUCT nd_label_ent differs: Removed fields: {'flags'}
# STRUCT clone_info differs: Removed fields: {'md'}
# STRUCT cpuidle_state_usage differs: Added fields: {'s2idle_usage', 's2idle_time'}
# STRUCT isa_dev differs: Struct size changed caused by field size change
# STRUCT wb_writeback_work differs: Added fields: {'older_than_this'}
# STRUCT nd_blk_region_desc differs: Struct size changed caused by field size change
# STRUCT vme_driver differs: Struct size changed caused by field size change
# STRUCT devlink_port differs: Fields added and removed: {'attrs'} {'split_group', 'split'}
# STRUCT bpf_map_ops differs: Fields added and removed: {'map_seq_show_elem', 'map_check_btf'} {'map_lookup_elem_sys_only'}
# STRUCT pci_host_bridge differs: Added fields: {'native_aer', 'native_pcie_hotplug', 'native_ltr', 'native_shpc_hotplug', 'native_pme'}
# STRUCT container_dev differs: Struct size changed caused by field size change
# STRUCT idr differs: Added fields: {'idr_base'}
# STRUCT exit_proc_event differs: Added fields: {'parent_pid', 'parent_tgid'}
# STRUCT ttyprintk_port differs: Fields added and removed: {'port_write_mutex'} {'spinlock'}
# STRUCT netns_core differs: Fields added and removed: {'sock_inuse', 'prot_inuse'} {'inuse'}
# STRUCT giveback_urb_bh differs: Removed fields: {'high_prio'}
# STRUCT i2c_adapter differs: Struct size changed caused by field size change
# STRUCT xfs_globals differs: Added fields: {'mount_delay'}
# STRUCT raw_sock differs: Struct size changed caused by field size change
# STRUCT proc_dir_entry differs: Fields added and removed: {'inline_name', 'write', '(anon)', 'state_size', 'refcnt'} {'count'}
# STRUCT fasync_struct differs: Field changed size without affecting size of struct
# STRUCT rtnl_link differs: Added fields: {'rcu', 'owner'}
# STRUCT serdev_controller differs: Struct size changed caused by field size change
# STRUCT csrow_info differs: Struct size changed caused by field size change
# STRUCT rdma_cgroup differs: Struct size changed caused by field size change
# STRUCT posix_clock differs: Fields added and removed: {'release', 'kref'} {'dev'}
# STRUCT x86_cpu_id differs: Removed fields: {'steppings'}
# STRUCT netns_ipv6 differs: Added fields: {'fib6_null_entry', 'ipmr_seq', 'ip6mr_notifier_ops', 'fib6_rules_require_fldissect'}
# STRUCT sbitmap_queue differs: Added fields: {'min_shallow_depth'}
# STRUCT lpss_device_desc differs: Removed fields: {'resume_from_noirq'}
# STRUCT cppc_perf_caps differs: Added fields: {'lowest_freq', 'nominal_freq'}
# STRUCT device_driver differs: Added fields: {'coredump'}
# STRUCT spi_controller differs: Fields added and removed: {'mem_ops'} {'devm_allocated', 'spi_flash_can_dma', 'flash_read_supported', 'spi_flash_read'}
# STRUCT zpool differs: Added fields: {'evictable'}
# STRUCT mmc_host differs: Fields added and removed: {'use_blk_mq'} {'areq', 'retune_crc_disable', 'context_info'}
# STRUCT blk_mq_hw_ctx differs: Fields added and removed: {'srcu', 'nr_expired'} {'queue_rq_srcu', 'dispatch_busy'}
# STRUCT mem_cgroup differs: Fields added and removed: {'swap_events_file'} {'low'}
# STRUCT x86_hyper_init differs: Added fields: {'init_after_bootmem'}
# STRUCT scsi_driver differs: Struct size changed caused by field size change
# STRUCT node differs: Struct size changed caused by field size change
# STRUCT rpc_rqst differs: Removed fields: {'rq_xprtdata'}
# STRUCT smap_psock_map_entry differs: Added fields: {'map', 'hash_link'}
# STRUCT x86_legacy_features differs: Added fields: {'warm_reset'}
# STRUCT nfs_rpc_ops differs: Removed fields: {'return_delegation'}
# STRUCT rfkill differs: Struct size changed caused by field size change
# STRUCT ifacaddr6 differs: Removed fields: {'aca_idev'}
# STRUCT dimm_info differs: Struct size changed caused by field size change
# STRUCT pci_epf_group differs: Added fields: {'index'}
# STRUCT rcu_node differs: Fields added and removed: {'rew', 'exp_need_flush'} {'n_normal_boosts', 'n_tasks_boosted', 'n_exp_boosts'}
# STRUCT hmm_devmem differs: Struct size changed caused by field size change
# STRUCT rcu_data differs: Removed fields: {'exp_workdone2', 'exp_workdone3', 'n_cbs_invoked', 'n_rp_cpu_needs_gp', 'n_rp_need_nothing', 'exp_workdone0', 'n_rp_cb_ready', 'n_rp_gp_completed', 'exp_workdone1', 'n_nocbs_invoked', 'n_rp_gp_started', 'n_rcu_pending', 'n_rp_report_qs', 'n_rp_nocb_defer_wakeup', 'n_rp_core_needs_qs'}
# STRUCT net_protocol differs: Added fields: {'early_demux_handler', 'early_demux'}
# STRUCT dma_chan_dev differs: Struct size changed caused by field size change
# STRUCT fork_frame differs: Struct size changed caused by field size change
# STRUCT pg_state differs: Added fields: {'effective_prot'}
# STRUCT cgroup_subsys differs: Fields added and removed: {'css_rstat_flush', 'free'} {'release'}
# STRUCT pcpu differs: Struct size changed caused by field size change
# STRUCT radix_tree_root differs: Added fields: {'xa_lock'}
# STRUCT parallel_data differs: Fields added and removed: {'timer', 'processed'} {'cpu', 'reorder_work'}
# STRUCT dev_pagemap differs: Added fields: {'altmap_valid'}
# STRUCT scan_control differs: Added fields: {'nr'}
# STRUCT ext4_system_zone differs: Removed fields: {'ino'}
# STRUCT intel_uncore_box differs: Struct size changed caused by field size change
# STRUCT lp8788_platform_data differs: Removed fields: {'ldo_pin'}
# STRUCT regmap_mmio_context differs: Added fields: {'attached_clk'}
# STRUCT mii_bus differs: Struct size changed caused by field size change
# STRUCT cred differs: Fields added and removed: {'rcu'} {'(anon)'}
# STRUCT rtable differs: Removed fields: {'rt_table_id'}
# STRUCT ep_device differs: Struct size changed caused by field size change
# STRUCT pnp_card differs: Struct size changed caused by field size change
# STRUCT tracefs_mount_opts differs: Removed fields: {'opts'}
# STRUCT tracefs_fs_info differs: Struct size changed caused by field size change
# STRUCT inet6_ifaddr differs: Added fields: {'rt_priority'}
# STRUCT throtl_data differs: Struct size changed caused by field size change
# STRUCT xen_netif_rx_sring differs: Fields added and removed: {'pad'} {'__pad'}
# STRUCT nd_dax differs: Struct size changed caused by field size change
# STRUCT Scsi_Host differs: Removed fields: {'sht_legacy_list'}
# STRUCT xenbus_transaction_holder differs: Removed fields: {'generation_id'}
# STRUCT mddev differs: Fields added and removed: {'flush_bio_pool', 'flush_pool'} {'flush_pending', 'last_flush', 'flush_bio', 'flush_work', 'start_flush'}
# STRUCT worker differs: Removed fields: {'desc_valid'}
# STRUCT phy differs: Struct size changed caused by field size change
# STRUCT regulator_init_data differs: Struct size changed caused by field size change
# STRUCT sdio_driver differs: Struct size changed caused by field size change
# STRUCT usb_gadget_driver differs: Struct size changed caused by field size change
# STRUCT thermal_cooling_device differs: Added fields: {'stats'}
# STRUCT rdt_resource differs: Struct size changed caused by field size change
# ...
# STRUCT cfg80211_ibss_params differs: Added fields: {'wep_tx_key', 'control_port_over_nl80211', 'wep_keys'}
# STRUCT header_ops differs: Removed fields: {'parse_protocol'}
# STRUCT usb_device_driver differs: Struct size changed caused by field size change
# STRUCT bpf_prog_dummy differs: Struct size changed caused by field size change
# STRUCT internal_container differs: Struct size changed caused by field size change
# STRUCT palmas_gpio differs: Struct size changed caused by field size change
# STRUCT ieee80211_reg_rule differs: Added fields: {'has_wmm', 'wmm_rule'}
# STRUCT wiphy differs: Added fields: {'txq_memory_limit', 'txq_limit', 'txq_quantum'}
# STRUCT rhashtable_iter differs: Added fields: {'end_of_table'}
# STRUCT userfaultfd_ctx differs: Added fields: {'mmap_changing', 'state'}
# STRUCT cfs_bandwidth differs: Added fields: {'expires_seq', 'runtime_expires'}
# STRUCT tps65090_regulator_plat_data differs: Fields added and removed: {'gpiod'} {'gpio'}
# STRUCT efi differs: Fields added and removed: {'mem_reserve', 'tpm_log'} {'mokvar_table'}
# STRUCT inode_security_struct differs: Fields added and removed: {'(anon)'} {'list'}
# STRUCT acpi_battery differs: Added fields: {'list'}
# STRUCT dm_io differs: Added fields: {'magic', 'tio'}
# STRUCT vif_device differs: Fields reordered
# STRUCT ifla_vf_stats differs: Added fields: {'rx_dropped', 'tx_dropped'}
# STRUCT raw_iter_state differs: Removed fields: {'h'}
# STRUCT packet_ring_buffer differs: Fields added and removed: {'prb_bdqc'} {'(anon)'}
# STRUCT rio_mport differs: Struct size changed caused by field size change
# STRUCT security_hook_heads differs: Added fields: {'socket_socketpair', 'cred_getsecid', 'sctp_assoc_request', 'sctp_bind_connect', 'sctp_sk_clone'}
# STRUCT kiocb differs: Added fields: {'ki_ioprio'}
# STRUCT loop_cmd differs: Removed fields: {'rq'}
# STRUCT pfifo_fast_priv differs: Removed fields: {'bitmap'}
# STRUCT proto_ops differs: Added fields: {'set_rcvlowat'}
# STRUCT bpf_stack_map differs: Struct size changed caused by field size change
# STRUCT bpf_stab differs: Fields added and removed: {'progs', 'lock'} {'bpf_parse', 'bpf_verdict'}
# STRUCT dw_pcie_ep differs: Added fields: {'msi_mem', 'msi_mem_phys'}
# STRUCT dw_pcie differs: Struct size changed caused by field size change
# STRUCT kimage differs: Struct size changed caused by field size change
# STRUCT xb_req_data differs: Removed fields: {'user_req'}
# STRUCT stack_entry differs: Struct size changed caused by field size change
# STRUCT cfs_rq differs: Added fields: {'expires_seq', 'runtime_expires'}
# STRUCT mapped_device differs: Fields added and removed: {'io_bs'} {'io_pool'}
# STRUCT i2c_devinfo differs: Struct size changed caused by field size change
# STRUCT tcf_block differs: Added fields: {'offloadcnt', 'nooffloaddevcnt', 'owner_list', 'keep_dst', 'index', 'refcnt'}
# STRUCT charger_manager differs: Struct size changed caused by field size change
# STRUCT hugetlbfs_inode_info differs: Added fields: {'seals'}
# STRUCT bpf_sock_ops differs: Added fields: {'retrans_out', 'snd_cwnd', 'mss_cache', 'segs_out', 'packets_out', 'data_segs_in', 'snd_ssthresh', 'bytes_received', 'ecn_flags', 'rcv_nxt', 'bpf_sock_ops_cb_flags', 'total_retrans', 'bytes_acked', 'data_segs_out', 'rate_interval_us', 'state', 'sk_txhash', 'snd_nxt', 'rate_delivered', 'segs_in', 'lost_out', 'rtt_min', 'sacked_out', 'snd_una', 'is_fullsock', 'srtt_us'}
# STRUCT tcf_proto differs: Removed fields: {'q', 'classid'}
# STRUCT tcf_chain differs: Fields added and removed: {'filter_chain_list'} {'chain_head_change_priv', 'chain_head_change'}
# STRUCT input_event_compat differs: Fields added and removed: {'sec', 'usec'} {'time'}
# STRUCT dwc2_hsotg differs: Added fields: {'reset_ecc', 'hibernated', 'non_periodic_sched_waiting', 'vbus_supply'}
# STRUCT pci_epf_bar differs: Added fields: {'flags', 'barno'}
# STRUCT mmc_bus_ops differs: Fields added and removed: {'hw_reset', 'sw_reset'} {'reset'}
# STRUCT rt6_info differs: Fields added and removed: {'from'} {'rt6i_metric', 'rt6i_pmtu', 'rt6i_node', 'rt6i_nh_flags', 'rt6i_table', 'exception_bucket_flushed', 'rt6i_ref', 'rt6i_siblings', 'rt6i_protocol', 'unused', 'rt6i_nsiblings', 'rt6i_exception_bucket', 'rt6i_pcpu'}
# STRUCT power_supply_config differs: Added fields: {'fwnode'}
# STRUCT power_supply_desc differs: Added fields: {'num_usb_types', 'usb_types'}
# STRUCT dwc2_hregs_backup differs: Added fields: {'hptxfsiz'}
# STRUCT nfs_server differs: Struct size changed caused by field size change
# STRUCT ipq differs: Struct size changed caused by field size change
# STRUCT dwc2_hcd_urb differs: Struct size changed caused by field size change
# STRUCT bpf_array differs: Struct size changed caused by field size change
# STRUCT dax_operations differs: Added fields: {'copy_to_iter'}
# STRUCT net differs: Fields added and removed: {'uevent_sock'} {'hash_mix'}
# STRUCT chv_pinctrl differs: Removed fields: {'irqchip'}
# STRUCT net_device differs: Fields added and removed: {'tlsdev_ops', 'sfp_bus'} {'lower_level', 'upper_level'}
# STRUCT mmc_gpio differs: Added fields: {'cd_debounce_delay_ms'}
# STRUCT xfrmdev_ops differs: Added fields: {'xdo_dev_state_advance_esn'}
# STRUCT max310x_one differs: Struct size changed caused by field size change
# STRUCT x86_cpu differs: Struct size changed caused by field size change
# STRUCT mdio_driver differs: Removed fields: {'shutdown'}
# STRUCT usb_hub differs: Removed fields: {'quirk_disable_autosuspend'}
# STRUCT bpf_verifier_state differs: Fields added and removed: {'frame', 'curframe'} {'allocated_stack', 'stack', 'regs'}
# STRUCT __ip6_tnl_parm differs: Added fields: {'hwid', 'erspan_ver', 'dir', 'index'}
# STRUCT ethtool_rxnfc differs: Fields added and removed: {'(anon)'} {'rule_cnt'}
# STRUCT keyctl_dh_params differs: Fields added and removed: {'private'} {'(anon)'}
# STRUCT nvdimm differs: Struct size changed caused by field size change
# STRUCT tracing_map_elt differs: Added fields: {'vars', 'var_set'}
# STRUCT audit_chunk differs: Removed fields: {'key'}
# STRUCT rtc_device differs: Fields added and removed: {'offset_secs', 'start_secs', 'range_min', 'set_start_time', 'range_max'} {'nvmem_config'}
# STRUCT ipcm6_cookie differs: Added fields: {'gso_size'}
# STRUCT spi_device differs: Struct size changed caused by field size change
# STRUCT hmm_mirror_ops differs: Added fields: {'release'}
# STRUCT mmc_part differs: Struct size changed caused by field size change
# STRUCT virtio_balloon differs: Struct size changed caused by field size change
# STRUCT task_group differs: Struct size changed caused by field size change
# STRUCT dw_pcie_host_ops differs: Added fields: {'msi_irq_ack', 'set_num_vectors'}
# STRUCT tps65910_gpio differs: Struct size changed caused by field size change
# STRUCT xennet_gnttab_make_txreq differs: Removed fields: {'tx_local'}
# STRUCT proto differs: Added fields: {'pre_connect', 'usersize', 'useroffset', 'stream_memory_read'}
# STRUCT cpudata differs: Added fields: {'hwp_req_cached', 'sched_flags', 'last_io_update', 'hwp_boost_min', 'hwp_cap_cached'}
# STRUCT zs_pool differs: Removed fields: {'destroying', 'shrinker_enabled', 'migration_wait', 'isolated_pages'}
# STRUCT blkcg differs: Struct size changed caused by field size change
# STRUCT tun_file differs: Fields added and removed: {'xdp_rxq', 'tx_ring'} {'tx_array'}
# STRUCT mipi_dsi_driver differs: Struct size changed caused by field size change
# STRUCT nf_ipv6_ops differs: Added fields: {'checksum_partial', 'checksum', 'reroute', 'route'}
# STRUCT arizona_ldo1_pdata differs: Removed fields: {'ldoena'}
# STRUCT scsi_disk differs: Removed fields: {'zones_wlock'}
# STRUCT bdev_inode differs: Struct size changed caused by field size change
# STRUCT clk_core differs: Added fields: {'protect_count'}
# STRUCT net_device_ops differs: Fields added and removed: {'ndo_xsk_async_xmit'} {'ndo_xdp_flush'}
# STRUCT ata_queued_cmd differs: Added fields: {'hw_tag'}
# STRUCT ib_qp differs: Added fields: {'res'}
# STRUCT kretprobe_instance differs: Removed fields: {'fp'}
# STRUCT virtio_device differs: Struct size changed caused by field size change
# STRUCT bpf_verifier_state_list differs: Struct size changed caused by field size change
# STRUCT pnp_card_driver differs: Struct size changed caused by field size change
# STRUCT rq_wb differs: Struct size changed caused by field size change
# STRUCT rtnl_link_ops differs: Removed fields: {'netns_refund'}
# STRUCT msg_queue differs: Field changed size without affecting size of struct
# STRUCT tcp_sock differs: Fields added and removed: {'recvmsg_inq', 'compressed_ack', 'max_packets_seq', 'bpf_sock_ops_cb_flags', 'compressed_ack_timer', 'delivered_ce'} {'cwnd_usage_seq', 'unused1', 'unused_1', 'tlp_retrans'}
# STRUCT cpuset differs: Struct size changed caused by field size change
# STRUCT squashfs_inode_info differs: Struct size changed caused by field size change
# STRUCT memory_failure_entry differs: Removed fields: {'trapno'}
# STRUCT xfrm_dst differs: Added fields: {'child', 'path'}
# STRUCT convert_context_args differs: Added fields: {'state'}
# STRUCT rio_net differs: Struct size changed caused by field size change
# STRUCT trace_event_raw_tcp_event_sk differs: Added fields: {'sock_cookie'}
# STRUCT x86_init_ops differs: Added fields: {'acpi'}
# STRUCT xen_bus_type differs: Removed fields: {'otherend_will_handle'}
# STRUCT pci_bus differs: Removed fields: {'unsafe_warn'}
# STRUCT lineevent_state differs: Added fields: {'timestamp'}
# STRUCT thermal_zone_device differs: Struct size changed caused by field size change
# STRUCT rcu_state differs: Removed fields: {'n_force_qs_lh', 'n_force_qs_ngp'}
# STRUCT devcd_entry differs: Struct size changed caused by field size change
# STRUCT timekeeper differs: Added fields: {'skip_second_overflow'}
# STRUCT mca_config differs: Added fields: {'__reserved'}
# STRUCT usb_interface differs: Added fields: {'pm_usage_cnt'}
# STRUCT dm_md_mempools differs: Fields added and removed: {'io_bs'} {'io_pool'}
# STRUCT aa_task_ctx differs: Fields added and removed: {'nnp'} {'label'}
# STRUCT klp_func differs: Removed fields: {'immediate'}
# STRUCT tcp6_sock differs: Struct size changed caused by field size change
# STRUCT phy_driver differs: Added fields: {'read_page', 'write_page'}
# STRUCT serdev_device_driver differs: Struct size changed caused by field size change
# STRUCT virtio_pci_device differs: Struct size changed caused by field size change
# STRUCT drbg_state differs: Fields added and removed: {'seed_work', 'random_ready'} {'fips_primed', 'prev'}
# STRUCT property_entry differs: Fields added and removed: {'type'} {'is_string'}
# STRUCT ib_cq differs: Fields added and removed: {'res'} {'comp_wq'}
# STRUCT tcp_iter_state differs: Removed fields: {'family'}
# STRUCT nd_namespace_pmem differs: Struct size changed caused by field size change
# STRUCT jit_context differs: Removed fields: {'seen_ax_reg', 'seen_ld_abs'}
# STRUCT hrtimer differs: Added fields: {'is_soft'}
# STRUCT mem_ctl_info differs: Struct size changed caused by field size change
# STRUCT net_bridge_fdb_entry differs: Fields added and removed: {'fdb_node', 'key', 'rhnode'} {'vlan_id', 'addr', 'hlist'}
# STRUCT hypervisor_x86 differs: Struct size changed caused by field size change
# STRUCT dwc2_dregs_backup differs: Added fields: {'dtxfsiz'}
# STRUCT signalfd_siginfo differs: Added fields: {'ssi_arch', 'ssi_syscall', '__pad2', 'ssi_call_addr'}
# STRUCT inet_timewait_sock differs: Fields added and removed: {'tw_mark'} {'tw_timeout'}
# STRUCT ip_tunnel differs: Added fields: {'dir', 'hwid', 'erspan_ver'}
# STRUCT max310x_port differs: Struct size changed caused by field size change
# STRUCT netfront_info differs: Removed fields: {'broken', 'bounce'}
# STRUCT dqstats differs: Struct size changed caused by field size change
# STRUCT rpc_xprt_ops differs: Added fields: {'free_slot'}
# STRUCT serio differs: Struct size changed caused by field size change
# STRUCT css_set differs: Fields added and removed: {'mg_preload_node'} {'mg_dst_preload_node', 'mg_src_preload_node', 'dying_tasks'}
# STRUCT powercap_control_type differs: Struct size changed caused by field size change
# STRUCT crb_priv differs: Added fields: {'iobase'}
# STRUCT xhci_hcd differs: Fields added and removed: {'reg_clk', 'hw_ports', 'imod_interval'} {'run_graceperiod', 'usb3_ports', 'usb2_ports', 'port_array', 'num_usb2_ports', 'num_usb3_ports'}
# STRUCT kmem_cache_order_objects differs: Struct size changed caused by field size change
# STRUCT hmm_device differs: Struct size changed caused by field size change
# STRUCT lpm_trie differs: Struct size changed caused by field size change
# STRUCT bpf_prog differs: Fields added and removed: {'undo_set_mem', 'jit_requested', 'kprobe_override', 'expected_attach_type', 'is_func', 'blinded', 'has_callchain_buf'} {'locked'}
# STRUCT inet_hashinfo differs: Added fields: {'lhash2', 'lhash2_mask'}
# STRUCT net_bridge differs: Fields added and removed: {'vlan_enabled', 'vlan_stats_enabled', 'nf_call_arptables', 'nf_call_ip6tables', 'mtu_set_by_user', 'fdb_list', 'nf_call_iptables', 'fdb_hash_tbl'} {'options', 'hash'}
# STRUCT always_present_id differs: Struct size changed caused by field size change
# STRUCT usb_dev_state differs: Removed fields: {'secid'}
# STRUCT acpi_ac differs: Struct size changed caused by field size change
# STRUCT public_key_signature differs: Struct size changed caused by field reordering:
# {'id': 46271, 'kind': 'STRUCT', 'name': 'public_key_signature', 'size': 56, 'vlen': 7, 'members': [{'name': 'auth_ids', 'type_id': 46272, 'bits_offset': 0}, {'name': 's', 'type_id': 342, 'bits_offset': 128}, {'name': 'digest', 'type_id': 342, 'bits_offset': 192}, {'name': 's_size', 'type_id': 33, 'bits_offset': 256}, {'name': 'digest_size', 'type_id': 33, 'bits_offset': 288}, {'name': 'pkey_algo', 'type_id': 5, 'bits_offset': 320}, {'name': 'hash_algo', 'type_id': 5, 'bits_offset': 384}]}
# {'id': 47979, 'kind': 'STRUCT', 'name': 'public_key_signature', 'size': 64, 'vlen': 7, 'members': [{'name': 'auth_ids', 'type_id': 47980, 'bits_offset': 0}, {'name': 's', 'type_id': 349, 'bits_offset': 128}, {'name': 's_size', 'type_id': 34, 'bits_offset': 192}, {'name': 'digest', 'type_id': 349, 'bits_offset': 256}, {'name': 'digest_size', 'type_id': 29, 'bits_offset': 320}, {'name': 'pkey_algo', 'type_id': 5, 'bits_offset': 384}, {'name': 'hash_algo', 'type_id': 5, 'bits_offset': 448}]}
# STRUCT acpi_control_state differs: Fields added and removed: {'loop_timeout'} {'loop_count'}
# STRUCT tcp_info differs: Added fields: {'tcpi_delivered', 'tcpi_delivered_ce'}
# STRUCT i2c_bus_recovery_info differs: Fields added and removed: {'scl_gpiod', 'set_sda', 'sda_gpiod'} {'sda_gpio', 'scl_gpio'}
# STRUCT iommu_dev_data differs: Struct size changed caused by field size change
# STRUCT bpf_reg_state differs: Added fields: {'frameno'}
# STRUCT fwnode_operations differs: Added fields: {'device_get_match_data'}
# STRUCT arizona_pdata differs: Struct size changed caused by field size change
# STRUCT dw_plat_pcie differs: Added fields: {'regmap', 'mode'}
# STRUCT perf_cpu_context differs: Struct size changed caused by field size change
# STRUCT trace_event_raw_fib6_table_lookup differs: Added fields: {'sport', 'proto', 'err', 'rt_type', 'dport'}
# STRUCT gendisk differs: Added fields: {'lookup_sem'}
# STRUCT freezer differs: Struct size changed caused by field size change
# STRUCT filter_pred differs: Removed fields: {'right', 'left', 'parent', 'index'}
# STRUCT jbd2_inode differs: Removed fields: {'i_dirty_end', 'i_dirty_start'}
# STRUCT pagevec differs: Field changed size without affecting size of struct
# STRUCT uart_port differs: Removed fields: {'sysrq_ch'}
# STRUCT fixed_regulator_data differs: Struct size changed caused by field size change
# STRUCT ax25_dev differs: Removed fields: {'refcount'}
# STRUCT pids_cgroup differs: Struct size changed caused by field size change
# STRUCT wireless_dev differs: Struct size changed caused by field size change
# STRUCT acpi_gpio_lookup differs: Removed fields: {'adev'}
# STRUCT isa_driver differs: Struct size changed caused by field size change
# STRUCT compat_msqid64_ds differs: Fields added and removed: {'msg_ctime_high', 'msg_stime_high', 'msg_rtime_high'} {'__unused1', '__unused2', '__unused3'}

# %%
# Sorry, I wasn't awake today at 5:45 PM (Central Time), but that time slot works for me in the future.
