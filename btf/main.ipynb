# %%
# !sudo apt install linux-tools-generic bpftool
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Note, selecting 'linux-tools-common' instead of 'bpftool'
# linux-tools-generic is already the newest version (6.2.0.39.39).
# linux-tools-common is already the newest version (6.2.0-39.40).
# 0 upgraded, 0 newly installed, 0 to remove and 0 not upgraded.

# %%
import os


def system(cmd):
    print(cmd)
    os.system(cmd)

# %%
from pathlib import Path

data_path = Path("data/18.04-x86")

# %%
def unzip_all(path, suffix=".tar.xz"):
    for file in path.glob(f"*{suffix}"):
        stem = file.name.removesuffix(suffix)
        result = path / stem
        if not result.exists():
            system(f"tar -xf {file} -C {path}")
        else:
            print(f"{result} already exists")


unzip_all(data_path)
# Out:
# data/ubuntu-18.04-x86/5.0.0-65-generic.btf already exists
# data/ubuntu-18.04-x86/4.18.0-25-generic.btf already exists
# data/ubuntu-18.04-x86/5.3.0-76-generic.btf already exists
# data/ubuntu-18.04-x86/4.15.0-213-generic.btf already exists
# data/ubuntu-18.04-x86/5.4.0-91-generic.btf already exists

# %%
def get_linux_tools_path():
    parent = Path("/usr/lib/linux-tools")
    versions = [x for x in parent.iterdir() if x.is_dir()]
    if len(versions) == 0:
        raise Exception("No linux-tools found")
    versions.sort()
    return parent / versions[-1]


def get_bpftool_path():
    path = get_linux_tools_path() / "bpftool"
    if not path.exists():
        raise Exception("bpftool not found")
    return path


bpftool_path = get_bpftool_path()
bpftool_path

# %%
for file in data_path.glob("*.btf"):
    for ext, cmd in [(".h", "format c"), (".txt", "format raw"), (".json", "--json")]:
        result = file.with_suffix(ext)
        if not result.exists():
            system(f"{bpftool_path} btf dump file {file} {cmd} > {result}")
        else:
            print(f"{result} already exists")
# Out:
# data/ubuntu-18.04-x86/5.4.0-91-generic.h already exists
# data/ubuntu-18.04-x86/5.4.0-91-generic.txt already exists
# data/ubuntu-18.04-x86/5.4.0-91-generic.json already exists
# data/ubuntu-18.04-x86/5.0.0-65-generic.h already exists
# data/ubuntu-18.04-x86/5.0.0-65-generic.txt already exists
# data/ubuntu-18.04-x86/5.0.0-65-generic.json already exists
# data/ubuntu-18.04-x86/5.3.0-76-generic.h already exists
# data/ubuntu-18.04-x86/5.3.0-76-generic.txt already exists
# data/ubuntu-18.04-x86/5.3.0-76-generic.json already exists
# data/ubuntu-18.04-x86/4.15.0-213-generic.h already exists
# data/ubuntu-18.04-x86/4.15.0-213-generic.txt already exists
# data/ubuntu-18.04-x86/4.15.0-213-generic.json already exists
# data/ubuntu-18.04-x86/4.18.0-25-generic.h already exists
# data/ubuntu-18.04-x86/4.18.0-25-generic.txt already exists
# data/ubuntu-18.04-x86/4.18.0-25-generic.json already exists

# %%
json_paths = sorted(file for file in data_path.glob("*.json"))

json_paths
# Out:
# [PosixPath('data/ubuntu-18.04-x86/4.15.0-213-generic.json'),
#  PosixPath('data/ubuntu-18.04-x86/4.18.0-25-generic.json'),
#  PosixPath('data/ubuntu-18.04-x86/5.0.0-65-generic.json'),
#  PosixPath('data/ubuntu-18.04-x86/5.3.0-76-generic.json'),
#  PosixPath('data/ubuntu-18.04-x86/5.4.0-91-generic.json')]

# %%
import json


def load_json(json_path):
    with open(json_path) as f:
        return json.load(f)


jsons = [load_json(p) for p in json_paths]

# %%
from enum import Enum


class Kind(str, Enum):
    INT = "INT"
    PTR = "PTR"
    ARRAY = "ARRAY"
    STRUCT = "STRUCT"
    UNION = "UNION"
    ENUM = "ENUM"
    FWD = "FWD"
    TYPEDEF = "TYPEDEF"
    VOLATILE = "VOLATILE"
    CONST = "CONST"
    RESTRICT = "RESTRICT"
    FUNC = "FUNC"
    FUNC_PROTO = "FUNC_PROTO"
    VAR = "VAR"
    DATASEC = "DATASEC"
    FLOAT = "FLOAT"
    DECL_TAG = "DECL_TAG"
    TYPE_TAG = "TYPE_TAG"
    ENUM64 = "ENUM64"

# %%
from functools import cache


class BTF:
    def __init__(self, path, raw_data=None):
        self.path = path
        if raw_data is None:
            self._raw_data = load_json(path)['types']
        else:
            self._raw_data = raw_data['types']

    def __getitem__(self, id):
        if id == 0:
            return {'id': 0, 'name': 'void', 'kind': 'VOID'}
        e = self._raw_data[id - 1]
        assert e['id'] == id
        return e

    def __len__(self):
        return len(self._raw_data)

    def __iter__(self):
        return iter(self._raw_data)

    @property
    def short_name(self):
        return self.path.name.split("-")[0]

    def print(self):
        from collections import defaultdict

        print(f"File: {self.path}")

        print("Sample:")
        kinds = defaultdict(int)
        for e in self:
            if e['kind'] not in kinds:
                print(f"\t{e['id']:6} ({e['kind']:10}): {e}")
                print(f"\t{'':18}-> {self.normalize(e['id'])}")
            kinds[e['kind']] += 1

        kinds = sorted(kinds.items(), key=lambda x: x[1], reverse=True)
        print(f"Kinds:")
        print(f"\t{dict(kinds)}")

        print()

    @cache
    def filter_on_kind(self, kind):
        return {
            e['name']: self.normalize(e['id']) for e in self
            if e['kind'] == kind and e['name'] != '(anon)'
        }

    @cache
    def get_by_kind_name(self, kind, name):
        return self.filter_on_kind(kind)[name]

    RECURSE_KINDS = {Kind.CONST, Kind.VOLATILE, Kind.RESTRICT,
                     Kind.PTR, Kind.FUNC, Kind.FUNC_PROTO, Kind.ARRAY}

    @cache
    def normalize(self, type_id, recurse=True):
        elem = self[type_id].copy()

        # Recurse into types for certain kinds
        recurse = recurse or elem['kind'] in self.RECURSE_KINDS

        # Remove redundant fields
        del elem['id']

        kind = elem['kind']
        if kind == Kind.INT:
            assert elem['bits_offset'] == 0
            del elem['bits_offset']
            del elem['encoding']
            del elem['nr_bits']
            del elem['size']
        elif kind == Kind.ARRAY:
            del elem['index_type_id']
        elif kind == Kind.ENUM:
            if not recurse:
                assert elem['vlen'] == len(elem['values'])
                del elem['values']
                del elem['vlen']
                del elem['encoding']
        elif kind == Kind.FUNC:
            assert elem['linkage'] == 'static'
            del elem['linkage']
        elif kind in (Kind.PTR, Kind.FUNC_PROTO):
            assert elem['name'] == '(anon)'
            del elem['name']

        # Normalize types
        for type in ['type', 'ret_type']:
            type_id = f"{type}_id"

            if type_id not in elem:
                continue

            if recurse:
                elem[type] = self.normalize(elem[type_id], recurse=False)
            del elem[type_id]

        for list_key in ['params', 'members']:
            if list_key not in elem:
                continue

            assert len(elem[list_key]) == elem['vlen']
            del elem['vlen']

            if recurse:
                elem[list_key] = [
                    {
                        **{k: v for k, v in item.items() if k != 'type_id'},
                        'type': self.normalize(item['type_id'], recurse=False)
                    }
                    for item in elem[list_key]
                ]
            else:
                del elem[list_key]
                if list_key == 'members':
                    del elem['size']

        return elem


d1 = BTF(json_paths[0])
d2 = BTF(json_paths[1])

d1.print()

d1.get_by_kind_name(Kind.STRUCT, "task_struct")
# d1.get_by_kind_name(Kind.FUNC, "vfs_read")
# Out:
# File: data/ubuntu-18.04-x86/4.15.0-213-generic.json
# Sample:
# 	     1 (INT       ): {'id': 1, 'kind': 'INT', 'name': 'long unsigned int', 'size': 8, 'bits_offset': 0, 'nr_bits': 64, 'encoding': '(none)'}
# 	                  -> {'kind': 'INT', 'name': 'long unsigned int'}
# 	     2 (CONST     ): {'id': 2, 'kind': 'CONST', 'name': '(anon)', 'type_id': 1}
# 	                  -> {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'INT', 'name': 'long unsigned int'}}
# 	     3 (VOLATILE  ): {'id': 3, 'kind': 'VOLATILE', 'name': '(anon)', 'type_id': 1}
# 	                  -> {'kind': 'VOLATILE', 'name': '(anon)', 'type': {'kind': 'INT', 'name': 'long unsigned int'}}
# 	     4 (ARRAY     ): {'id': 4, 'kind': 'ARRAY', 'name': '(anon)', 'type_id': 1, 'index_type_id': 20, 'nr_elems': 2}
# 	                  -> {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 2, 'type': {'kind': 'INT', 'name': 'long unsigned int'}}
# 	     5 (PTR       ): {'id': 5, 'kind': 'PTR', 'name': '(anon)', 'type_id': 8}
# 	                  -> {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'INT', 'name': 'char'}}}
# 	    11 (TYPEDEF   ): {'id': 11, 'kind': 'TYPEDEF', 'name': '__s8', 'type_id': 12}
# 	                  -> {'kind': 'TYPEDEF', 'name': '__s8', 'type': {'kind': 'INT', 'name': 'signed char'}}
# 	    38 (FUNC_PROTO): {'id': 38, 'kind': 'FUNC_PROTO', 'name': '(anon)', 'ret_type_id': 0, 'vlen': 1, 'params': [{'name': '(anon)', 'type_id': 20}]}
# 	                  -> {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}
# 	    78 (STRUCT    ): {'id': 78, 'kind': 'STRUCT', 'name': '(anon)', 'size': 4, 'vlen': 1, 'members': [{'name': 'counter', 'type_id': 20, 'bits_offset': 0}]}
# 	                  -> {'kind': 'STRUCT', 'name': '(anon)', 'size': 4, 'members': [{'name': 'counter', 'bits_offset': 0, 'type': {'kind': 'INT', 'name': 'int'}}]}
# 	   106 (UNION     ): {'id': 106, 'kind': 'UNION', 'name': '(anon)', 'size': 8, 'vlen': 3, 'members': [{'name': 'type', 'type_id': 1, 'bits_offset': 0}, {'name': 'entries', 'type_id': 108, 'bits_offset': 0}, {'name': 'next', 'type_id': 109, 'bits_offset': 0}]}
# 	                  -> {'kind': 'UNION', 'name': '(anon)', 'size': 8, 'members': [{'name': 'type', 'bits_offset': 0, 'type': {'kind': 'INT', 'name': 'long unsigned int'}}, {'name': 'entries', 'bits_offset': 0, 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'jump_entry'}}}, {'name': 'next', 'bits_offset': 0, 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'static_key_mod'}}}]}
# 	   120 (ENUM      ): {'id': 120, 'kind': 'ENUM', 'name': 'system_states', 'encoding': 'UNSIGNED', 'size': 4, 'vlen': 6, 'values': [{'name': 'SYSTEM_BOOTING', 'val': 0}, {'name': 'SYSTEM_SCHEDULING', 'val': 1}, {'name': 'SYSTEM_RUNNING', 'val': 2}, {'name': 'SYSTEM_HALT', 'val': 3}, {'name': 'SYSTEM_POWER_OFF', 'val': 4}, {'name': 'SYSTEM_RESTART', 'val': 5}]}
# 	                  -> {'kind': 'ENUM', 'name': 'system_states', 'encoding': 'UNSIGNED', 'size': 4, 'vlen': 6, 'values': [{'name': 'SYSTEM_BOOTING', 'val': 0}, {'name': 'SYSTEM_SCHEDULING', 'val': 1}, {'name': 'SYSTEM_RUNNING', 'val': 2}, {'name': 'SYSTEM_HALT', 'val': 3}, {'name': 'SYSTEM_POWER_OFF', 'val': 4}, {'name': 'SYSTEM_RESTART', 'val': 5}]}
# 	  1110 (FWD       ): {'id': 1110, 'kind': 'FWD', 'name': 'nlm_lockowner', 'fwd_kind': 'struct'}
# 	                  -> {'kind': 'FWD', 'name': 'nlm_lockowner', 'fwd_kind': 'struct'}
# 	  1671 (FUNC      ): {'id': 1671, 'kind': 'FUNC', 'name': 'copy_bootdata', 'type_id': 1670, 'linkage': 'static'}
# 	                  -> {'kind': 'FUNC', 'name': 'copy_bootdata', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': 'real_mode_data', 'type': {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'char'}}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
# 	  4737 (VAR       ): {'id': 4737, 'kind': 'VAR', 'name': 'cpu_loops_per_jiffy', 'type_id': 1, 'linkage': 'static'}
# 	                  -> {'kind': 'VAR', 'name': 'cpu_loops_per_jiffy', 'linkage': 'static', 'type': {'kind': 'INT', 'name': 'long unsigned int'}}
# 	 94558 (RESTRICT  ): {'id': 94558, 'kind': 'RESTRICT', 'name': '(anon)', 'type_id': 5}
# 	                  -> {'kind': 'RESTRICT', 'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'INT', 'name': 'char'}}}}
# 	 94838 (DATASEC   ): {'id': 94838, 'kind': 'DATASEC', 'name': '.data..percpu', 'size': 164036, 'vlen': 326, 'vars': [{'type_id': 5631, 'offset': 16384, 'size': 4096}, {'type_id': 8571, 'offset': 20480, 'size': 12288}, {'type_id': 9004, 'offset': 32768, 'size': 4096}, {'type_id': 12534, 'offset': 36864, 'size': 40960}, {'type_id': 12533, 'offset': 77824, 'size': 4096}, {'type_id': 8154, 'offset': 81920, 'size': 8}, {'type_id': 8153, 'offset': 81928, 'size': 8}, {'type_id': 9003, 'offset': 81936, 'size': 2}, {'type_id': 10430, 'offset': 81952, 'size': 8}, {'type_id': 10429, 'offset': 81960, 'size': 8}, {'type_id': 10428, 'offset': 81968, 'size': 8}, {'type_id': 10431, 'offset': 81984, 'size': 240}, {'type_id': 10452, 'offset': 82224, 'size': 4}, {'type_id': 10453, 'offset': 82232, 'size': 8}, {'type_id': 10596, 'offset': 82240, 'size': 4}, {'type_id': 10594, 'offset': 82244, 'size': 2}, {'type_id': 10595, 'offset': 82246, 'size': 2}, {'type_id': 11856, 'offset': 82248, 'size': 4}, {'type_id': 4737, 'offset': 82304, 'size': 8}, {'type_id': 5189, 'offset': 82336, 'size': 512}, {'type_id': 5188, 'offset': 82848, 'size': 4824}, {'type_id': 5231, 'offset': 87672, 'size': 8}, {'type_id': 5559, 'offset': 90112, 'size': 12288}, {'type_id': 5632, 'offset': 102400, 'size': 8}, {'type_id': 5797, 'offset': 102432, 'size': 168}, {'type_id': 6219, 'offset': 102624, 'size': 64}, {'type_id': 6220, 'offset': 102688, 'size': 4}, {'type_id': 6218, 'offset': 102696, 'size': 8}, {'type_id': 6243, 'offset': 102720, 'size': 3088}, {'type_id': 6244, 'offset': 105808, 'size': 8}, {'type_id': 6519, 'offset': 105856, 'size': 320}, {'type_id': 6548, 'offset': 106176, 'size': 8}, {'type_id': 6742, 'offset': 106192, 'size': 16}, {'type_id': 7016, 'offset': 106208, 'size': 8}, {'type_id': 7015, 'offset': 106216, 'size': 10}, {'type_id': 7014, 'offset': 106240, 'size': 24}, {'type_id': 7191, 'offset': 106264, 'size': 8}, {'type_id': 7190, 'offset': 106272, 'size': 8}, {'type_id': 7457, 'offset': 106288, 'size': 16}, {'type_id': 7456, 'offset': 106304, 'size': 16}, {'type_id': 7455, 'offset': 106320, 'size': 16}, {'type_id': 7454, 'offset': 106336, 'size': 16}, {'type_id': 7493, 'offset': 106352, 'size': 16}, {'type_id': 7492, 'offset': 106368, 'size': 16}, {'type_id': 7509, 'offset': 106384, 'size': 4}, {'type_id': 7508, 'offset': 106392, 'size': 8}, {'type_id': 7507, 'offset': 106400, 'size': 4}, {'type_id': 7620, 'offset': 106408, 'size': 8}, {'type_id': 7903, 'offset': 106416, 'size': 8}, {'type_id': 7988, 'offset': 106432, 'size': 4}, {'type_id': 7987, 'offset': 106440, 'size': 8}, {'type_id': 7986, 'offset': 106448, 'size': 4}, {'type_id': 7985, 'offset': 106456, 'size': 8}, {'type_id': 7984, 'offset': 106464, 'size': 1}, {'type_id': 7983, 'offset': 106480, 'size': 16}, {'type_id': 8100, 'offset': 106496, 'size': 2048}, {'type_id': 8280, 'offset': 108544, 'size': 744}, {'type_id': 8370, 'offset': 109312, 'size': 32}, {'type_id': 8369, 'offset': 109344, 'size': 32}, {'type_id': 8368, 'offset': 109376, 'size': 8}, {'type_id': 8574, 'offset': 109392, 'size': 24}, {'type_id': 8572, 'offset': 109416, 'size': 1}, {'type_id': 8573, 'offset': 109424, 'size': 8}, {'type_id': 8614, 'offset': 109432, 'size': 1}, {'type_id': 8615, 'offset': 109440, 'size': 8}, {'type_id': 9010, 'offset': 109504, 'size': 8}, {'type_id': 9011, 'offset': 109512, 'size': 4}, {'type_id': 9012, 'offset': 109516, 'size': 4}, {'type_id': 9008, 'offset': 109520, 'size': 4}, {'type_id': 9007, 'offset': 109524, 'size': 4}, {'type_id': 9006, 'offset': 109528, 'size': 8}, {'type_id': 9009, 'offset': 109536, 'size': 56}, {'type_id': 9005, 'offset': 109632, 'size': 8}, {'type_id': 9176, 'offset': 109640, 'size': 8}, {'type_id': 9187, 'offset': 109664, 'size': 32}, {'type_id': 9292, 'offset': 109696, 'size': 16}, {'type_id': 9566, 'offset': 109728, 'size': 40}, {'type_id': 9565, 'offset': 109768, 'size': 8}, {'type_id': 9561, 'offset': 109792, 'size': 120}, {'type_id': 9563, 'offset': 109920, 'size ...
# 	                  -> {'kind': 'DATASEC', 'name': '.data..percpu', 'size': 164036, 'vlen': 326, 'vars': [{'type_id': 5631, 'offset': 16384, 'size': 4096}, {'type_id': 8571, 'offset': 20480, 'size': 12288}, {'type_id': 9004, 'offset': 32768, 'size': 4096}, {'type_id': 12534, 'offset': 36864, 'size': 40960}, {'type_id': 12533, 'offset': 77824, 'size': 4096}, {'type_id': 8154, 'offset': 81920, 'size': 8}, {'type_id': 8153, 'offset': 81928, 'size': 8}, {'type_id': 9003, 'offset': 81936, 'size': 2}, {'type_id': 10430, 'offset': 81952, 'size': 8}, {'type_id': 10429, 'offset': 81960, 'size': 8}, {'type_id': 10428, 'offset': 81968, 'size': 8}, {'type_id': 10431, 'offset': 81984, 'size': 240}, {'type_id': 10452, 'offset': 82224, 'size': 4}, {'type_id': 10453, 'offset': 82232, 'size': 8}, {'type_id': 10596, 'offset': 82240, 'size': 4}, {'type_id': 10594, 'offset': 82244, 'size': 2}, {'type_id': 10595, 'offset': 82246, 'size': 2}, {'type_id': 11856, 'offset': 82248, 'size': 4}, {'type_id': 4737, 'offset': 82304, 'size': 8}, {'type_id': 5189, 'offset': 82336, 'size': 512}, {'type_id': 5188, 'offset': 82848, 'size': 4824}, {'type_id': 5231, 'offset': 87672, 'size': 8}, {'type_id': 5559, 'offset': 90112, 'size': 12288}, {'type_id': 5632, 'offset': 102400, 'size': 8}, {'type_id': 5797, 'offset': 102432, 'size': 168}, {'type_id': 6219, 'offset': 102624, 'size': 64}, {'type_id': 6220, 'offset': 102688, 'size': 4}, {'type_id': 6218, 'offset': 102696, 'size': 8}, {'type_id': 6243, 'offset': 102720, 'size': 3088}, {'type_id': 6244, 'offset': 105808, 'size': 8}, {'type_id': 6519, 'offset': 105856, 'size': 320}, {'type_id': 6548, 'offset': 106176, 'size': 8}, {'type_id': 6742, 'offset': 106192, 'size': 16}, {'type_id': 7016, 'offset': 106208, 'size': 8}, {'type_id': 7015, 'offset': 106216, 'size': 10}, {'type_id': 7014, 'offset': 106240, 'size': 24}, {'type_id': 7191, 'offset': 106264, 'size': 8}, {'type_id': 7190, 'offset': 106272, 'size': 8}, {'type_id': 7457, 'offset': 106288, 'size': 16}, {'type_id': 7456, 'offset': 106304, 'size': 16}, {'type_id': 7455, 'offset': 106320, 'size': 16}, {'type_id': 7454, 'offset': 106336, 'size': 16}, {'type_id': 7493, 'offset': 106352, 'size': 16}, {'type_id': 7492, 'offset': 106368, 'size': 16}, {'type_id': 7509, 'offset': 106384, 'size': 4}, {'type_id': 7508, 'offset': 106392, 'size': 8}, {'type_id': 7507, 'offset': 106400, 'size': 4}, {'type_id': 7620, 'offset': 106408, 'size': 8}, {'type_id': 7903, 'offset': 106416, 'size': 8}, {'type_id': 7988, 'offset': 106432, 'size': 4}, {'type_id': 7987, 'offset': 106440, 'size': 8}, {'type_id': 7986, 'offset': 106448, 'size': 4}, {'type_id': 7985, 'offset': 106456, 'size': 8}, {'type_id': 7984, 'offset': 106464, 'size': 1}, {'type_id': 7983, 'offset': 106480, 'size': 16}, {'type_id': 8100, 'offset': 106496, 'size': 2048}, {'type_id': 8280, 'offset': 108544, 'size': 744}, {'type_id': 8370, 'offset': 109312, 'size': 32}, {'type_id': 8369, 'offset': 109344, 'size': 32}, {'type_id': 8368, 'offset': 109376, 'size': 8}, {'type_id': 8574, 'offset': 109392, 'size': 24}, {'type_id': 8572, 'offset': 109416, 'size': 1}, {'type_id': 8573, 'offset': 109424, 'size': 8}, {'type_id': 8614, 'offset': 109432, 'size': 1}, {'type_id': 8615, 'offset': 109440, 'size': 8}, {'type_id': 9010, 'offset': 109504, 'size': 8}, {'type_id': 9011, 'offset': 109512, 'size': 4}, {'type_id': 9012, 'offset': 109516, 'size': 4}, {'type_id': 9008, 'offset': 109520, 'size': 4}, {'type_id': 9007, 'offset': 109524, 'size': 4}, {'type_id': 9006, 'offset': 109528, 'size': 8}, {'type_id': 9009, 'offset': 109536, 'size': 56}, {'type_id': 9005, 'offset': 109632, 'size': 8}, {'type_id': 9176, 'offset': 109640, 'size': 8}, {'type_id': 9187, 'offset': 109664, 'size': 32}, {'type_id': 9292, 'offset': 109696, 'size': 16}, {'type_id': 9566, 'offset': 109728, 'size': 40}, {'type_id': 9565, 'offset': 109768, 'size': 8}, {'type_id': 9561, 'offset': 109792, 'size': 120}, {'type_id': 9563, 'offset': 109920, 'size': 120}, {'ty ...
# Kinds:
# 	{'FUNC': 42719, 'FUNC_PROTO': 22849, 'PTR': 11884, 'STRUCT': 8154, 'ARRAY': 2981, 'CONST': 2369, 'ENUM': 1528, 'TYPEDEF': 1005, 'UNION': 827, 'VAR': 326, 'FWD': 158, 'VOLATILE': 20, 'INT': 15, 'RESTRICT': 2, 'DATASEC': 1}
# {'kind': 'STRUCT',
#  'name': 'task_struct',
#  'size': 9152,
#  'members': [{'name': 'thread_info',
#    'bits_offset': 0,
#    'type': {'kind': 'STRUCT', 'name': 'thread_info'}},
#   {'name': 'state',
#    'bits_offset': 128,
#    'type': {'kind': 'VOLATILE',
#     'name': '(anon)',
#     'type': {'kind': 'INT', 'name': 'long int'}}},
#   {'name': 'stack',
#    'bits_offset': 192,
#    'type': {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}},
#   {'name': 'usage',
#    'bits_offset': 256,
#    'type': {'kind': 'TYPEDEF', 'name': 'atomic_t'}},
#   {'name': 'flags',
#    'bits_offset': 288,
#    'type': {'kind': 'INT', 'name': 'unsigned int'}},
#   {'name': 'ptrace',
#    'bits_offset': 320,
#    'type': {'kind': 'INT', 'name': 'unsigned int'}},
#   {'name': 'wake_entry',
#    'bits_offset': 384,
#    'type': {'kind': 'STRUCT', 'name': 'llist_node'}},
#   {'name': 'on_cpu',
#    'bits_offset': 448,
#    'type': {'kind': 'INT', 'name': 'int'}},
#   {'name': 'cpu',
#    'bits_offset': 480,
#    'type': {'kind': 'INT', 'name': 'unsigned int'}},
#   {'name': 'wakee_flips',
#    'bits_offset': 512,
#    'type': {'kind': 'INT', 'name': 'unsigned int'}},
#   {'name': 'wakee_flip_decay_ts',
#    'bits_offset': 576,
#    'type': {'kind': 'INT', 'name': 'long unsigned int'}},
#   {'name': 'last_wakee',
#    'bits_offset': 640,
#    'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'task_struct'}}},
#   {'name': 'wake_cpu',
#    'bits_offset': 704,
#    'type': {'kind': 'INT', 'name': 'int'}},
#   {'name': 'on_rq',
#    'bits_offset': 736,
#    'type': {'kind': 'INT', 'name': 'int'}},
#   {'name': 'prio', 'bits_offset': 768, 'type': {'kind': 'INT', 'name': 'int'}},
#   {'name': 'static_prio',
#    'bits_offset': 800,
#    'type': {'kind': 'INT', 'name': 'int'}},
#   {'name': 'normal_prio',
#    'bits_offset': 832,
#    'type': {'kind': 'INT', 'name': 'int'}},
#   {'name': 'rt_priority',
#    'bits_offset': 864,
#    'type': {'kind': 'INT', 'name': 'unsigned int'}},
#   {'name': 'sched_class',
#    'bits_offset': 896,
#    'type': {'kind': 'PTR',
#     'type': {'kind': 'CONST',
#      'name': '(anon)',
#      'type': {'kind': 'STRUCT', 'name': 'sched_class'}}}},
#   {'name': 'se',
#    'bits_offset': 1024,
#    'type': {'kind': 'STRUCT', 'name': 'sched_entity'}},
#   {'name': 'rt',
#    'bits_offset': 4608,
#    'type': {'kind': 'STRUCT', 'name': 'sched_rt_entity'}},
#   {'name': 'sched_task_group',
#    'bits_offset': 4992,
#    'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'task_group'}}},
#   {'name': 'dl',
#    'bits_offset': 5056,
#    'type': {'kind': 'STRUCT', 'name': 'sched_dl_entity'}},
#   {'name': 'preempt_notifiers',
#    'bits_offset': 6784,
#    'type': {'kind': 'STRUCT', 'name': 'hlist_head'}},
#   {'name': 'btrace_seq',
#    'bits_offset': 6848,
#    'type': {'kind': 'INT', 'name': 'unsigned int'}},
#   {'name': 'policy',
#    'bits_offset': 6880,
#    'type': {'kind': 'INT', 'name': 'unsigned int'}},
#   {'name': 'nr_cpus_allowed',
#    'bits_offset': 6912,
#    'type': {'kind': 'INT', 'name': 'int'}},
#   {'name': 'cpus_allowed',
#    'bits_offset': 6976,
#    'type': {'kind': 'TYPEDEF', 'name': 'cpumask_t'}},
#   {'name': 'rcu_tasks_nvcsw',
#    'bits_offset': 15168,
#    'type': {'kind': 'INT', 'name': 'long unsigned int'}},
#   {'name': 'rcu_tasks_holdout',
#    'bits_offset': 15232,
#    'type': {'kind': 'TYPEDEF', 'name': 'u8'}},
#   {'name': 'rcu_tasks_idx',
#    'bits_offset': 15240,
#    'type': {'kind': 'TYPEDEF', 'name': 'u8'}},
#   {'name': 'rcu_tasks_idle_cpu',
#    'bits_offset': 15264,
#    'type': {'kind': 'INT', 'name': 'int'}},
#   {'name': 'rcu_tasks_holdout_list',
#    'bits_offset': 15296,
#    'type': {'kind': 'STRUCT', 'name': 'list_head'}},
#   {'name': 'sched_info',
#    'bits_offset': 15424,
#    'type': {'kind': 'STRUCT', 'name': 'sched_info'}},
#   {'name': 'tasks',
#    'bits_offset': 15680,
#    'type': {'kind': 'STRUCT', 'name': 'list_head'}},
#   {'name': 'pushable_tasks',
#    'bits_offset': 15808,
#    'type': {'kind': 'STRUCT', 'name': 'plist_node'}},
#   {'name': 'pushable_dl_tasks',
#    'bits_offset': 16128,
#    'type': {'kind': 'STRUCT', 'name': 'rb_node'}},
#   {'name': 'mm',
#    'bits_offset': 16320,
#    'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'mm_struct'}}},
#   {'name': 'active_mm',
#    'bits_offset': 16384,
#    'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'mm_struct'}}},
#   {'name': 'vmacache',
#    'bits_offset': 16448,
#    'type': {'kind': 'STRUCT', 'name': 'vmacache'}},
#   {'name': 'rss_stat',
#    'bits_offset': 16768,
#    'type': {'kind': 'STRUCT', 'name': 'task_rss_stat'}},
#   {'name': 'exit_state',
#    'bits_offset': 16928,
#    'type': {'kind': 'INT', 'name': 'int'}},
#   {'name': 'exit_code',
#    'bits_offset': 16960,
#    'type': {'kind': 'INT', 'name': 'int'}},
#   {'name': 'exit_signal',
#    'bits_offset': 16992,
#    'type': {'kind': 'INT', 'name': 'int'}},
#   {'name': 'pdeath_signal',
#    'bits_offset': 17024,
#    'type': {'kind': 'INT', 'name': 'int'}},
#   {'name': 'jobctl',
#    'bits_offset': 17088,
#    'type': {'kind': 'INT', 'name': 'long unsigned int'}},
#   {'name': 'personality',
#    'bits_offset': 17152,
#    'type': {'kind': 'INT', 'name': 'unsigned int'}},
#   {'name': 'sched_reset_on_fork',
#    'bits_offset': 17184,
#    'bitfield_size': 1,
#    'type': {'kind': 'INT', 'name': 'unsigned int'}},
#   {'name': 'sched_contributes_to_load',
#    'bits_offset': 17185,
#    'bitfield_size': 1,
#    'type': {'kind': 'INT', 'name': 'unsigned int'}},
#   {'name': 'sched_migrated',
#    'bits_offset': 17186,
#    'bitfield_size': 1,
#    'type': {'kind': 'INT', 'name': 'unsigned int'}},
#   {'name': 'sched_remote_wakeup',
#    'bits_offset': 17187,
#    'bitfield_size': 1,
#    'type': {'kind': 'INT', 'name': 'unsigned int'}},
#   {'name': 'in_execve',
#    'bits_offset': 17216,
#    'bitfield_size': 1,
#    'type': {'kind': 'INT', 'name': 'unsigned int'}},
#   {'name': 'in_iowait',
#    'bits_offset': 17217,
#    'bitfield_size': 1,
#    'type': {'kind': 'INT', 'name': 'unsigned int'}},
#   {'name': 'restore_sigmask',
#    'bits_offset': 17218,
#    'bitfield_size': 1,
#    'type': {'kind': 'INT', 'name': 'unsigned int'}},
#   {'name': 'memcg_may_oom',
#    'bits_offset': 17219,
#    'bitfield_size': 1,
#    'type': {'kind': 'INT', 'name': 'unsigned int'}},
#   {'name': 'memcg_kmem_skip_account',
#    'bits_offset': 17220,
#    'bitfield_size': 1,
#    'type': {'kind': 'INT', 'name': 'unsigned int'}},
#   {'name': 'no_cgroup_migration',
#    'bits_offset': 17221,
#    'bitfield_size': 1,
#    'type': {'kind': 'INT', 'name': 'unsigned int'}},
#   {'name': 'atomic_flags',
#    'bits_offset': 17280,
#    'type': {'kind': 'INT', 'name': 'long unsigned int'}},
#   {'name': 'restart_block',
#    'bits_offset': 17344,
#    'type': {'kind': 'STRUCT', 'name': 'restart_block'}},
#   {'name': 'pid',
#    'bits_offset': 17728,
#    'type': {'kind': 'TYPEDEF', 'name': 'pid_t'}},
#   {'name': 'tgid',
#    'bits_offset': 17760,
#    'type': {'kind': 'TYPEDEF', 'name': 'pid_t'}},
#   {'name': 'stack_canary',
#    'bits_offset': 17792,
#    'type': {'kind': 'INT', 'name': 'long unsigned int'}},
#   {'name': 'real_parent',
#    'bits_offset': 17856,
#    'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'task_struct'}}},
#   {'name': 'parent',
#    'bits_offset': 17920,
#    'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'task_struct'}}},
#   {'name': 'children',
#    'bits_offset': 17984,
#    'type': {'kind': 'STRUCT', 'name': 'list_head'}},
#   {'name': 'sibling',
#    'bits_offset': 18112,
#    'type': {'kind': 'STRUCT', 'name': 'list_head'}},
#   {'name': 'group_leader',
#    'bits_offset': 18240,
#    'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'task_struct'}}},
#   {'name': 'ptraced',
#    'bits_offset': 18304,
#    'type': {'kind': 'STRUCT', 'name': 'list_head'}},
#   {'name': 'ptrace_entry',
#    'bits_offset': 18432,
#    'type': {'kind': 'STRUCT', 'name': 'list_head'}},
#   {'name': 'pids',
#    'bits_offset': 18560,
#    'type': {'kind': 'ARRAY',
#     'name': '(anon)',
#     'nr_elems': 3,
#     'type': {'kind': 'STRUCT', 'name': 'pid_link'}}},
#   {'name': 'thread_group',
#    'bits_offset': 19136,
#    'type': {'kind': 'STRUCT', 'name': 'list_head'}},
#   {'name': 'thread_node',
#    'bits_offset': 19264,
#    'type': {'kind': 'STRUCT', 'name': 'list_head'}},
#   {'name': 'vfork_done',
#    'bits_offset': 19392,
#    'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'completion'}}},
#   {'name': 'set_child_tid',
#    'bits_offset': 19456,
#    'type': {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'int'}}},
#   {'name': 'clear_child_tid',
#    'bits_offset': 19520,
#    'type': {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'int'}}},
#   {'name': 'utime',
#    'bits_offset': 19584,
#    'type': {'kind': 'TYPEDEF', 'name': 'u64'}},
#   {'name': 'stime',
#    'bits_offset': 19648,
#    'type': {'kind': 'TYPEDEF', 'name': 'u64'}},
#   {'name': 'gtime',
#    'bits_offset': 19712,
#    'type': {'kind': 'TYPEDEF', 'name': 'u64'}},
#   {'name': 'prev_cputime',
#    'bits_offset': 19776,
#    'type': {'kind': 'STRUCT', 'name': 'prev_cputime'}},
#   {'name': 'nvcsw',
#    'bits_offset': 19968,
#    'type': {'kind': 'INT', 'name': 'long unsigned int'}},
#   {'name': 'nivcsw',
#    'bits_offset': 20032,
#    'type': {'kind': 'INT', 'name': 'long unsigned int'}},
#   {'name': 'start_time',
#    'bits_offset': 20096,
#    'type': {'kind': 'TYPEDEF', 'name': 'u64'}},
#   {'name': 'real_start_time',
#    'bits_offset': 20160,
#    'type': {'kind': 'TYPEDEF', 'name': 'u64'}},
#   {'name': 'min_flt',
#    'bits_offset': 20224,
#    'type': {'kind': 'INT', 'name': 'long unsigned int'}},
#   {'name': 'maj_flt',
#    'bits_offset': 20288,
#    'type': {'kind': 'INT', 'name': 'long unsigned int'}},
#   {'name': 'cputime_expires',
#    'bits_offset': 20352,
#    'type': {'kind': 'STRUCT', 'name': 'task_cputime'}},
#   {'name': 'cpu_timers',
#    'bits_offset': 20544,
#    'type': {'kind': 'ARRAY',
#     'name': '(anon)',
#     'nr_elems': 3,
#     'type': {'kind': 'STRUCT', 'name': 'list_head'}}},
#   {'name': 'ptracer_cred',
#    'bits_offset': 20928,
#    'type': {'kind': 'PTR',
#     'type': {'kind': 'CONST',
#      'name': '(anon)',
#      'type': {'kind': 'STRUCT', 'name': 'cred'}}}},
#   {'name': 'real_cred',
#    'bits_offset': 20992,
#    'type': {'kind': 'PTR',
#     'type': {'kind': 'CONST',
#      'name': '(anon)',
#      'type': {'kind': 'STRUCT', 'name': 'cred'}}}},
#   {'name': 'cred',
#    'bits_offset': 21056,
#    'type': {'kind': 'PTR',
#     'type': {'kind': 'CONST',
#      'name': '(anon)',
#      'type': {'kind': 'STRUCT', 'name': 'cred'}}}},
#   {'name': 'comm',
#    'bits_offset': 21120,
#    'type': {'kind': 'ARRAY',
#     'name': '(anon)',
#     'nr_elems': 16,
#     'type': {'kind': 'INT', 'name': 'char'}}},
#   {'name': 'nameidata',
#    'bits_offset': 21248,
#    'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'nameidata'}}},
#   {'name': 'sysvsem',
#    'bits_offset': 21312,
#    'type': {'kind': 'STRUCT', 'name': 'sysv_sem'}},
#   {'name': 'sysvshm',
#    'bits_offset': 21376,
#    'type': {'kind': 'STRUCT', 'name': 'sysv_shm'}},
#   {'name': 'last_switch_count',
#    'bits_offset': 21504,
#    'type': {'kind': 'INT', 'name': 'long unsigned int'}},
#   {'name': 'fs',
#    'bits_offset': 21568,
#    'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fs_struct'}}},
#   {'name': 'files',
#    'bits_offset': 21632,
#    'type': {'kind': 'PTR',
#     'type': {'kind': 'STRUCT', 'name': 'files_struct'}}},
#   {'name': 'nsproxy',
#    'bits_offset': 21696,
#    'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'nsproxy'}}},
#   {'name': 'signal',
#    'bits_offset': 21760,
#    'type': {'kind': 'PTR',
#     'type': {'kind': 'STRUCT', 'name': 'signal_struct'}}},
#   {'name': 'sighand',
#    'bits_offset': 21824,
#    'type': {'kind': 'PTR',
#     'type': {'kind': 'STRUCT', 'name': 'sighand_struct'}}},
#   {'name': 'blocked',
#    'bits_offset': 21888,
#    'type': {'kind': 'TYPEDEF', 'name': 'sigset_t'}},
#   {'name': 'real_blocked',
#    'bits_offset': 21952,
#    'type': {'kind': 'TYPEDEF', 'name': 'sigset_t'}},
#   {'name': 'saved_sigmask',
#    'bits_offset': 22016,
#    'type': {'kind': 'TYPEDEF', 'name': 'sigset_t'}},
#   {'name': 'pending',
#    'bits_offset': 22080,
#    'type': {'kind': 'STRUCT', 'name': 'sigpending'}},
#   {'name': 'sas_ss_sp',
#    'bits_offset': 22272,
#    'type': {'kind': 'INT', 'name': 'long unsigned int'}},
#   {'name': 'sas_ss_size',
#    'bits_offset': 22336,
#    'type': {'kind': 'TYPEDEF', 'name': 'size_t'}},
#   {'name': 'sas_ss_flags',
#    'bits_offset': 22400,
#    'type': {'kind': 'INT', 'name': 'unsigned int'}},
#   {'name': 'task_works',
#    'bits_offset': 22464,
#    'type': {'kind': 'PTR',
#     'type': {'kind': 'STRUCT', 'name': 'callback_head'}}},
#   {'name': 'audit_context',
#    'bits_offset': 22528,
#    'type': {'kind': 'PTR',
#     'type': {'kind': 'STRUCT', 'name': 'audit_context'}}},
#   {'name': 'loginuid',
#    'bits_offset': 22592,
#    'type': {'kind': 'TYPEDEF', 'name': 'kuid_t'}},
#   {'name': 'sessionid',
#    'bits_offset': 22624,
#    'type': {'kind': 'INT', 'name': 'unsigned int'}},
#   {'name': 'seccomp',
#    'bits_offset': 22656,
#    'type': {'kind': 'STRUCT', 'name': 'seccomp'}},
#   {'name': 'parent_exec_id',
#    'bits_offset': 22784,
#    'type': {'kind': 'TYPEDEF', 'name': 'u64'}},
#   {'name': 'self_exec_id',
#    'bits_offset': 22848,
#    'type': {'kind': 'TYPEDEF', 'name': 'u64'}},
#   {'name': 'alloc_lock',
#    'bits_offset': 22912,
#    'type': {'kind': 'TYPEDEF', 'name': 'spinlock_t'}},
#   {'name': 'pi_lock',
#    'bits_offset': 22944,
#    'type': {'kind': 'TYPEDEF', 'name': 'raw_spinlock_t'}},
#   {'name': 'wake_q',
#    'bits_offset': 22976,
#    'type': {'kind': 'STRUCT', 'name': 'wake_q_node'}},
#   {'name': 'pi_waiters',
#    'bits_offset': 23040,
#    'type': {'kind': 'STRUCT', 'name': 'rb_root_cached'}},
#   {'name': 'pi_top_task',
#    'bits_offset': 23168,
#    'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'task_struct'}}},
#   {'name': 'pi_blocked_on',
#    'bits_offset': 23232,
#    'type': {'kind': 'PTR',
#     'type': {'kind': 'STRUCT', 'name': 'rt_mutex_waiter'}}},
#   {'name': 'journal_info',
#    'bits_offset': 23296,
#    'type': {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}},
#   {'name': 'bio_list',
#    'bits_offset': 23360,
#    'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'bio_list'}}},
#   {'name': 'plug',
#    'bits_offset': 23424,
#    'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'blk_plug'}}},
#   {'name': 'reclaim_state',
#    'bits_offset': 23488,
#    'type': {'kind': 'PTR',
#     'type': {'kind': 'STRUCT', 'name': 'reclaim_state'}}},
#   {'name': 'backing_dev_info',
#    'bits_offset': 23552,
#    'type': {'kind': 'PTR',
#     'type': {'kind': 'STRUCT', 'name': 'backing_dev_info'}}},
#   {'name': 'io_context',
#    'bits_offset': 23616,
#    'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'io_context'}}},
#   {'name': 'ptrace_message',
#    'bits_offset': 23680,
#    'type': {'kind': 'INT', 'name': 'long unsigned int'}},
#   {'name': 'last_siginfo',
#    'bits_offset': 23744,
#    'type': {'kind': 'PTR', 'type': {'kind': 'TYPEDEF', 'name': 'siginfo_t'}}},
#   {'name': 'ioac',
#    'bits_offset': 23808,
#    'type': {'kind': 'STRUCT', 'name': 'task_io_accounting'}},
#   {'name': 'acct_rss_mem1',
#    'bits_offset': 24256,
#    'type': {'kind': 'TYPEDEF', 'name': 'u64'}},
#   {'name': 'acct_vm_mem1',
#    'bits_offset': 24320,
#    'type': {'kind': 'TYPEDEF', 'name': 'u64'}},
#   {'name': 'acct_timexpd',
#    'bits_offset': 24384,
#    'type': {'kind': 'TYPEDEF', 'name': 'u64'}},
#   {'name': 'mems_allowed',
#    'bits_offset': 24448,
#    'type': {'kind': 'TYPEDEF', 'name': 'nodemask_t'}},
#   {'name': 'mems_allowed_seq',
#    'bits_offset': 25472,
#    'type': {'kind': 'TYPEDEF', 'name': 'seqcount_t'}},
#   {'name': 'cpuset_mem_spread_rotor',
#    'bits_offset': 25504,
#    'type': {'kind': 'INT', 'name': 'int'}},
#   {'name': 'cpuset_slab_spread_rotor',
#    'bits_offset': 25536,
#    'type': {'kind': 'INT', 'name': 'int'}},
#   {'name': 'cgroups',
#    'bits_offset': 25600,
#    'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'css_set'}}},
#   {'name': 'cg_list',
#    'bits_offset': 25664,
#    'type': {'kind': 'STRUCT', 'name': 'list_head'}},
#   {'name': 'closid',
#    'bits_offset': 25792,
#    'type': {'kind': 'TYPEDEF', 'name': 'u32'}},
#   {'name': 'rmid',
#    'bits_offset': 25824,
#    'type': {'kind': 'TYPEDEF', 'name': 'u32'}},
#   {'name': 'robust_list',
#    'bits_offset': 25856,
#    'type': {'kind': 'PTR',
#     'type': {'kind': 'STRUCT', 'name': 'robust_list_head'}}},
#   {'name': 'compat_robust_list',
#    'bits_offset': 25920,
#    'type': {'kind': 'PTR',
#     'type': {'kind': 'STRUCT', 'name': 'compat_robust_list_head'}}},
#   {'name': 'pi_state_list',
#    'bits_offset': 25984,
#    'type': {'kind': 'STRUCT', 'name': 'list_head'}},
#   {'name': 'pi_state_cache',
#    'bits_offset': 26112,
#    'type': {'kind': 'PTR',
#     'type': {'kind': 'STRUCT', 'name': 'futex_pi_state'}}},
#   {'name': 'futex_exit_mutex',
#    'bits_offset': 26176,
#    'type': {'kind': 'STRUCT', 'name': 'mutex'}},
#   {'name': 'futex_state',
#    'bits_offset': 26432,
#    'type': {'kind': 'INT', 'name': 'unsigned int'}},
#   {'name': 'perf_event_ctxp',
#    'bits_offset': 26496,
#    'type': {'kind': 'ARRAY',
#     'name': '(anon)',
#     'nr_elems': 2,
#     'type': {'kind': 'PTR',
#      'type': {'kind': 'STRUCT', 'name': 'perf_event_context'}}}},
#   {'name': 'perf_event_mutex',
#    'bits_offset': 26624,
#    'type': {'kind': 'STRUCT', 'name': 'mutex'}},
#   {'name': 'perf_event_list',
#    'bits_offset': 26880,
#    'type': {'kind': 'STRUCT', 'name': 'list_head'}},
#   {'name': 'mempolicy',
#    'bits_offset': 27008,
#    'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'mempolicy'}}},
#   {'name': 'il_prev',
#    'bits_offset': 27072,
#    'type': {'kind': 'INT', 'name': 'short int'}},
#   {'name': 'pref_node_fork',
#    'bits_offset': 27088,
#    'type': {'kind': 'INT', 'name': 'short int'}},
#   {'name': 'numa_scan_seq',
#    'bits_offset': 27104,
#    'type': {'kind': 'INT', 'name': 'int'}},
#   {'name': 'numa_scan_period',
#    'bits_offset': 27136,
#    'type': {'kind': 'INT', 'name': 'unsigned int'}},
#   {'name': 'numa_scan_period_max',
#    'bits_offset': 27168,
#    'type': {'kind': 'INT', 'name': 'unsigned int'}},
#   {'name': 'numa_preferred_nid',
#    'bits_offset': 27200,
#    'type': {'kind': 'INT', 'name': 'int'}},
#   {'name': 'numa_migrate_retry',
#    'bits_offset': 27264,
#    'type': {'kind': 'INT', 'name': 'long unsigned int'}},
#   {'name': 'node_stamp',
#    'bits_offset': 27328,
#    'type': {'kind': 'TYPEDEF', 'name': 'u64'}},
#   {'name': 'last_task_numa_placement',
#    'bits_offset': 27392,
#    'type': {'kind': 'TYPEDEF', 'name': 'u64'}},
#   {'name': 'last_sum_exec_runtime',
#    'bits_offset': 27456,
#    'type': {'kind': 'TYPEDEF', 'name': 'u64'}},
#   {'name': 'numa_work',
#    'bits_offset': 27520,
#    'type': {'kind': 'STRUCT', 'name': 'callback_head'}},
#   {'name': 'numa_entry',
#    'bits_offset': 27648,
#    'type': {'kind': 'STRUCT', 'name': 'list_head'}},
#   {'name': 'numa_group',
#    'bits_offset': 27776,
#    'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'numa_group'}}},
#   {'name': 'numa_faults',
#    'bits_offset': 27840,
#    'type': {'kind': 'PTR',
#     'type': {'kind': 'INT', 'name': 'long unsigned int'}}},
#   {'name': 'total_numa_faults',
#    'bits_offset': 27904,
#    'type': {'kind': 'INT', 'name': 'long unsigned int'}},
#   {'name': 'numa_faults_locality',
#    'bits_offset': 27968,
#    'type': {'kind': 'ARRAY',
#     'name': '(anon)',
#     'nr_elems': 3,
#     'type': {'kind': 'INT', 'name': 'long unsigned int'}}},
#   {'name': 'numa_pages_migrated',
#    'bits_offset': 28160,
#    'type': {'kind': 'INT', 'name': 'long unsigned int'}},
#   {'name': 'tlb_ubc',
#    'bits_offset': 28224,
#    'type': {'kind': 'STRUCT', 'name': 'tlbflush_unmap_batch'}},
#   {'name': 'rcu',
#    'bits_offset': 36480,
#    'type': {'kind': 'STRUCT', 'name': 'callback_head'}},
#   {'name': 'splice_pipe',
#    'bits_offset': 36608,
#    'type': {'kind': 'PTR',
#     'type': {'kind': 'STRUCT', 'name': 'pipe_inode_info'}}},
#   {'name': 'task_frag',
#    'bits_offset': 36672,
#    'type': {'kind': 'STRUCT', 'name': 'page_frag'}},
#   {'name': 'delays',
#    'bits_offset': 36800,
#    'type': {'kind': 'PTR',
#     'type': {'kind': 'STRUCT', 'name': 'task_delay_info'}}},
#   {'name': 'nr_dirtied',
#    'bits_offset': 36864,
#    'type': {'kind': 'INT', 'name': 'int'}},
#   {'name': 'nr_dirtied_pause',
#    'bits_offset': 36896,
#    'type': {'kind': 'INT', 'name': 'int'}},
#   {'name': 'dirty_paused_when',
#    'bits_offset': 36928,
#    'type': {'kind': 'INT', 'name': 'long unsigned int'}},
#   {'name': 'timer_slack_ns',
#    'bits_offset': 36992,
#    'type': {'kind': 'TYPEDEF', 'name': 'u64'}},
#   {'name': 'default_timer_slack_ns',
#    'bits_offset': 37056,
#    'type': {'kind': 'TYPEDEF', 'name': 'u64'}},
#   {'name': 'curr_ret_stack',
#    'bits_offset': 37120,
#    'type': {'kind': 'INT', 'name': 'int'}},
#   {'name': 'curr_ret_depth',
#    'bits_offset': 37152,
#    'type': {'kind': 'INT', 'name': 'int'}},
#   {'name': 'ret_stack',
#    'bits_offset': 37184,
#    'type': {'kind': 'PTR',
#     'type': {'kind': 'STRUCT', 'name': 'ftrace_ret_stack'}}},
#   {'name': 'ftrace_timestamp',
#    'bits_offset': 37248,
#    'type': {'kind': 'INT', 'name': 'long long unsigned int'}},
#   {'name': 'trace_overrun',
#    'bits_offset': 37312,
#    'type': {'kind': 'TYPEDEF', 'name': 'atomic_t'}},
#   {'name': 'tracing_graph_pause',
#    'bits_offset': 37344,
#    'type': {'kind': 'TYPEDEF', 'name': 'atomic_t'}},
#   {'name': 'trace',
#    'bits_offset': 37376,
#    'type': {'kind': 'INT', 'name': 'long unsigned int'}},
#   {'name': 'trace_recursion',
#    'bits_offset': 37440,
#    'type': {'kind': 'INT', 'name': 'long unsigned int'}},
#   {'name': 'memcg_in_oom',
#    'bits_offset': 37504,
#    'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'mem_cgroup'}}},
#   {'name': 'memcg_oom_gfp_mask',
#    'bits_offset': 37568,
#    'type': {'kind': 'TYPEDEF', 'name': 'gfp_t'}},
#   {'name': 'memcg_oom_order',
#    'bits_offset': 37600,
#    'type': {'kind': 'INT', 'name': 'int'}},
#   {'name': 'memcg_nr_pages_over_high',
#    'bits_offset': 37632,
#    'type': {'kind': 'INT', 'name': 'unsigned int'}},
#   {'name': 'utask',
#    'bits_offset': 37696,
#    'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'uprobe_task'}}},
#   {'name': 'sequential_io',
#    'bits_offset': 37760,
#    'type': {'kind': 'INT', 'name': 'unsigned int'}},
#   {'name': 'sequential_io_avg',
#    'bits_offset': 37792,
#    'type': {'kind': 'INT', 'name': 'unsigned int'}},
#   {'name': 'pagefault_disabled',
#    'bits_offset': 37824,
#    'type': {'kind': 'INT', 'name': 'int'}},
#   {'name': 'oom_reaper_list',
#    'bits_offset': 37888,
#    'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'task_struct'}}},
#   {'name': 'stack_vm_area',
#    'bits_offset': 37952,
#    'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'vm_struct'}}},
#   {'name': 'stack_refcount',
#    'bits_offset': 38016,
#    'type': {'kind': 'TYPEDEF', 'name': 'atomic_t'}},
#   {'name': 'patch_state',
#    'bits_offset': 38048,
#    'type': {'kind': 'INT', 'name': 'int'}},
#   {'name': 'security',
#    'bits_offset': 38080,
#    'type': {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}},
#   {'name': 'thread',
#    'bits_offset': 38400,
#    'type': {'kind': 'STRUCT', 'name': 'thread_struct'}}]}

# %%
import sys


def print_as_list(name, s, num=10):
    print(f"{name} ({len(s)}): {list(s)[:num]}")


class FileLogger:
    def __init__(self, name):
        self.stdout = sys.stdout

        file_path = Path("output") / name
        file_path.parent.mkdir(parents=True, exist_ok=True)
        self.log = open(file_path, "w")

    def write(self, message):
        self.stdout.write(message)
        self.log.write(message)

    def __enter__(self):
        sys.stdout = self
        return self

    def __exit__(self, exc_type, exc_value, traceback):
        sys.stdout = self.stdout
        self.log.close()


def _check_diff(d_old, d_new, kind, diff):
    f_old = d_old.filter_on_kind(kind)
    f_new = d_new.filter_on_kind(kind)

    print_as_list(f"Old {kind}", f_old.keys())
    print_as_list(f"New {kind}", f_new.keys())

    print_as_list(f"Removed {kind}", f_old.keys() - f_new.keys())
    print_as_list(f"Added {kind}", f_new.keys() - f_old.keys())

    common = {
        name: (f_old[name], f_new[name])
        for name in f_old.keys() & f_new.keys()
    }
    print_as_list(f"Common {kind}", common.keys())

    changed = {
        name: (old, new)
        for name, (old, new) in common.items()
        if old != new
    }
    print_as_list(f"Changed {kind}", changed.keys())

    for name, (old, new) in changed.items():
        reason = diff(old, new)
        lines = reason.strip().split("\n")
        print(f"{kind:12}{name}")
        for line in lines:
            print(f"{'':20} {line}")


def check_diff(d_old, d_new, kind, diff):
    name = f"{d_old.short_name}-{d_new.short_name}-{kind.name}.txt"
    with FileLogger(name):
        _check_diff(d_old, d_new, kind, diff)

# %%
def diff_struct(old, new):
    result = ""

    old_members = {m['name']: m for m in old['members']}
    new_members = {m['name']: m for m in new['members']}

    # added field
    added_members = new_members.keys() - old_members.keys()
    if added_members:
        result += f"Added fields:\n"
        for name in added_members:
            result += f"{name:>20}: {new_members[name]['type']}\n"

    # removed field
    removed_members = old_members.keys() - new_members.keys()
    if removed_members:
        result += f"Removed fields:\n"
        for name in removed_members:
            result += f"{name:>20}: {old_members[name]['type']}\n"

    # fields reordered
    common = old_members.keys() & new_members.keys()
    if [n for n in old_members if n in common] != [n for n in new_members if n in common]:
        result += f"Fields reordered:\n"
        result += f"{'':>20} {list(old_members)}\n"
        result += f"{'':>20} {list(new_members)}\n"

    # fields changed type
    changed_types = {
        name: (old_members[name]['type'], new_members[name]['type'])
        for name in common
        if old_members[name]['type'] != new_members[name]['type']
    }
    if changed_types:
        result += "Field type changed:\n"
        for name, (old_type, new_type) in changed_types.items():
            result += f"{name:>20}: {old_type}\n"
            result += f"{'':>20}->{new_type}\n"

    # fields changed offset
    old_offset = {name: old_members[name]
                  ['bits_offset'] for name in old_members}
    new_offset = {name: new_members[name]
                  ['bits_offset'] for name in new_members}
    layout_changed = old_offset != new_offset or old['size'] != new['size']
    if layout_changed and result == "":
        result += f"Layout changed\n"

    assert result, f"\n{old}\n{new}"
    return result


check_diff(d1, d2, Kind.STRUCT, diff_struct)
# Out:
# Old Kind.STRUCT (7329): ['list_head', 'hlist_head', 'hlist_node', 'callback_head', 'jump_entry', 'static_key', 'static_key_true', 'static_key_false', 'file_operations', 'atomic_notifier_head']
# New Kind.STRUCT (7619): ['list_head', 'hlist_head', 'hlist_node', 'callback_head', 'kernel_symbol', 'jump_entry', 'static_key', 'static_key_true', 'static_key_false', 'file_operations']
# Removed Kind.STRUCT (136): ['blk_issue_stat', 'spi_flash_read_message', 'intel_pinctrl_soc_data', 'ip_ct_tcp', 'dpc_rp_pio_regs', 'trace_event_data_offsets_bpf_map_delete_elem', 'fbcon_dmi_rotate_data', 'bin_table', 'x86_cpu_desc', 'blake2s_state']
# Added Kind.STRUCT (426): ['pp_alloc_cache', 'stack_map_irq_work', 'nvm_ioctl_remove', 'trace_event_raw_xdp_devmap_xmit', 'freerunning_counters', 'ib_dm_alloc_attr', 'nvm_ioctl_device_info', 'selinux_fs_info', 'ib_flow_ipv4_filter', 'field_var']
# Common Kind.STRUCT (7193): ['rpc_version', 'config_s', 'ncsi_cmd_sp_pkt', 'aml_resource_spi_serialbus', 'ib_udata', 'nla_policy', 'trace_event_raw_mm_shrink_slab_start', 'rtc_task', 'mmiotrace_rw', 'nf_dccp_net']
# Changed Kind.STRUCT (785): ['trace_event_raw_mm_shrink_slab_start', 'powercap_zone', 'cgroup_bpf', 'devlink_port', 'ipcm_cookie', 'header_ops', 'xen_netif_tx_sring', 'bsg_job', 'net_bridge_fdb_entry', 'tpm_space']
# Kind.STRUCT trace_event_raw_mm_shrink_slab_start
#                      Added fields:
#                                  priority: {'kind': 'INT', 'name': 'int'}
#                      Removed fields:
#                                   lru_pgs: {'kind': 'INT', 'name': 'long unsigned int'}
#                               pgs_scanned: {'kind': 'INT', 'name': 'long unsigned int'}
# Kind.STRUCT powercap_zone
#                      Layout changed
# Kind.STRUCT cgroup_bpf
#                      Field type changed:
#                                     progs: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 7, 'type': {'kind': 'STRUCT', 'name': 'list_head'}}
#                                          ->{'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 17, 'type': {'kind': 'STRUCT', 'name': 'list_head'}}
#                                 effective: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 7, 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'bpf_prog_array'}}}
#                                          ->{'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 17, 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'bpf_prog_array'}}}
#                                     flags: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 7, 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}
#                                          ->{'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 17, 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}
# Kind.STRUCT devlink_port
#                      Added fields:
#                                     attrs: {'kind': 'STRUCT', 'name': 'devlink_port_attrs'}
#                      Removed fields:
#                                     split: {'kind': 'TYPEDEF', 'name': 'bool'}
#                               split_group: {'kind': 'TYPEDEF', 'name': 'u32'}
# Kind.STRUCT ipcm_cookie
#                      Added fields:
#                                  gso_size: {'kind': 'TYPEDEF', 'name': '__u16'}
# Kind.STRUCT header_ops
#                      Removed fields:
#                            parse_protocol: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'sk_buff'}}}}], 'ret_type': {'kind': 'TYPEDEF', 'name': '__be16'}}}
# Kind.STRUCT xen_netif_tx_sring
#                      Added fields:
#                                       pad: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 48, 'type': {'kind': 'TYPEDEF', 'name': 'uint8_t'}}
#                      Removed fields:
#                                     __pad: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 48, 'type': {'kind': 'TYPEDEF', 'name': 'uint8_t'}}
# Kind.STRUCT bsg_job
#                      Added fields:
#                                   timeout: {'kind': 'INT', 'name': 'unsigned int'}
#                                    result: {'kind': 'INT', 'name': 'int'}
#                      reply_payload_rcv_len: {'kind': 'INT', 'name': 'unsigned int'}
#                      Removed fields:
#                                      sreq: {'kind': 'STRUCT', 'name': 'scsi_request'}
#                                       req: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'request'}}
# Kind.STRUCT net_bridge_fdb_entry
#                      Added fields:
#                                    rhnode: {'kind': 'STRUCT', 'name': 'rhash_head'}
#                                       key: {'kind': 'STRUCT', 'name': 'net_bridge_fdb_key'}
#                                  fdb_node: {'kind': 'STRUCT', 'name': 'hlist_node'}
#                      Removed fields:
#                                      addr: {'kind': 'TYPEDEF', 'name': 'mac_addr'}
#                                     hlist: {'kind': 'STRUCT', 'name': 'hlist_node'}
#                                   vlan_id: {'kind': 'TYPEDEF', 'name': '__u16'}
# Kind.STRUCT tpm_space
#                      Removed fields:
#                                  buf_size: {'kind': 'TYPEDEF', 'name': 'u32'}
# Kind.STRUCT usb_dev_state
#                      Removed fields:
#                                     secid: {'kind': 'TYPEDEF', 'name': 'u32'}
# Kind.STRUCT backing_dev_info
#                      Removed fields:
#                           wb_switch_rwsem: {'kind': 'STRUCT', 'name': 'rw_semaphore'}
# Kind.STRUCT device_link
#                      Added fields:
#                                      kref: {'kind': 'STRUCT', 'name': 'kref'}
# Kind.STRUCT tcp_iter_state
#                      Removed fields:
#                                    family: {'kind': 'TYPEDEF', 'name': 'sa_family_t'}
# Kind.STRUCT mmc_gpio
#                      Added fields:
#                      cd_debounce_delay_ms: {'kind': 'TYPEDEF', 'name': 'u32'}
# Kind.STRUCT clone_info
#                      Removed fields:
#                                        md: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'mapped_device'}}
# Kind.STRUCT i2c_adapter
#                      Layout changed
# Kind.STRUCT nd_device_driver
#                      Layout changed
# Kind.STRUCT fib_lookup_arg
#                      Added fields:
#                               lookup_data: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'name': 'void', 'kind': 'VOID'}}}
# Kind.STRUCT perf_sample_data
#                      Removed fields:
#                              sample_flags: {'kind': 'TYPEDEF', 'name': 'u64'}
# Kind.STRUCT dwc2_dregs_backup
#                      Added fields:
#                                   dtxfsiz: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 16, 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}
# Kind.STRUCT spi_driver
#                      Layout changed
# Kind.STRUCT tty_operations
#                      Added fields:
#                                 proc_show: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'seq_file'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                      Removed fields:
#                                 proc_fops: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'file_operations'}}}
# Kind.STRUCT hd_struct
#                      Added fields:
#                             callback_head: {'kind': 'STRUCT', 'name': 'callback_head'}
#                      Removed fields:
#                                  rcu_work: {'kind': 'STRUCT', 'name': 'rcu_work'}
# Kind.STRUCT irq_desc
#                      Removed fields:
#                                 tot_count: {'kind': 'INT', 'name': 'unsigned int'}
# Kind.STRUCT frag_queue
#                      Layout changed
# Kind.STRUCT radix_tree_root
#                      Added fields:
#                                   xa_lock: {'kind': 'TYPEDEF', 'name': 'spinlock_t'}
# Kind.STRUCT netdev_rx_queue
#                      Added fields:
#                                   xdp_rxq: {'kind': 'STRUCT', 'name': 'xdp_rxq_info'}
# Kind.STRUCT cgroup_root
#                      Layout changed
# Kind.STRUCT pfifo_fast_priv
#                      Removed fields:
#                                    bitmap: {'kind': 'TYPEDEF', 'name': 'u32'}
#                      Field type changed:
#                                         q: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 3, 'type': {'kind': 'STRUCT', 'name': 'qdisc_skb_head'}}
#                                          ->{'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 3, 'type': {'kind': 'STRUCT', 'name': 'skb_array'}}
# Kind.STRUCT evdev
#                      Layout changed
# Kind.STRUCT intel_uncore_type
#                      Added fields:
#                               freerunning: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'freerunning_counters'}}
#                      num_freerunning_types: {'kind': 'INT', 'name': 'int'}
# Kind.STRUCT irq_remap_table
#                      Field type changed:
#                                      lock: {'kind': 'TYPEDEF', 'name': 'spinlock_t'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'raw_spinlock_t'}
# Kind.STRUCT raw_sock
#                      Layout changed
# Kind.STRUCT trace_event_raw_fib_table_lookup
#                      Added fields:
#                           __data_loc_name: {'kind': 'TYPEDEF', 'name': 'u32'}
#                                        gw: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 4, 'type': {'kind': 'TYPEDEF', 'name': '__u8'}}
#                                       err: {'kind': 'INT', 'name': 'int'}
#                                     dport: {'kind': 'TYPEDEF', 'name': 'u16'}
#                                     saddr: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 4, 'type': {'kind': 'TYPEDEF', 'name': '__u8'}}
#                                     proto: {'kind': 'TYPEDEF', 'name': 'u8'}
#                                     sport: {'kind': 'TYPEDEF', 'name': 'u16'}
# Kind.STRUCT macvlan_dev
#                      Added fields:
#                                accel_priv: {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}
#                      Removed fields:
#                                  fwd_priv: {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}
#                      Fields reordered:
#                                           ['dev', 'list', 'hlist', 'port', 'lowerdev', 'fwd_priv', 'pcpu_stats', 'mc_filter', 'set_features', 'mode', 'flags', 'nest_level', 'netpoll', 'macaddr_count']
#                                           ['dev', 'list', 'hlist', 'port', 'lowerdev', 'accel_priv', 'pcpu_stats', 'mc_filter', 'set_features', 'mode', 'flags', 'nest_level', 'macaddr_count', 'netpoll']
# Kind.STRUCT stack_map_bucket
#                      Added fields:
#                                      data: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 0, 'type': {'kind': 'TYPEDEF', 'name': 'u64'}}
#                      Removed fields:
#                                        ip: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 0, 'type': {'kind': 'TYPEDEF', 'name': 'u64'}}
# Kind.STRUCT nvdimm_bus
#                      Added fields:
#                                probe_wait: {'kind': 'TYPEDEF', 'name': 'wait_queue_head_t'}
#                      Removed fields:
#                                      wait: {'kind': 'TYPEDEF', 'name': 'wait_queue_head_t'}
#                              ioctl_active: {'kind': 'TYPEDEF', 'name': 'atomic_t'}
# Kind.STRUCT dax_operations
#                      Added fields:
#                              copy_to_iter: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'dax_device'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'long unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'size_t'}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'iov_iter'}}}], 'ret_type': {'kind': 'TYPEDEF', 'name': 'size_t'}}}
# Kind.STRUCT max310x_port
#                      Layout changed
# Kind.STRUCT page
#                      Added fields:
#                                 _refcount: {'kind': 'TYPEDEF', 'name': 'atomic_t'}
# Kind.STRUCT firmware_work
#                      Field type changed:
#                                 opt_flags: {'kind': 'INT', 'name': 'unsigned int'}
#                                          ->{'kind': 'ENUM', 'name': 'fw_opt', 'size': 4}
# Kind.STRUCT regulator
#                      Added fields:
#                                   voltage: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 5, 'type': {'kind': 'STRUCT', 'name': 'regulator_voltage'}}
#                      Removed fields:
#                                    min_uV: {'kind': 'INT', 'name': 'int'}
#                                    max_uV: {'kind': 'INT', 'name': 'int'}
# Kind.STRUCT powercap_control_type
#                      Layout changed
# Kind.STRUCT hmm_device
#                      Layout changed
# Kind.STRUCT bpf_verifier_state_list
#                      Layout changed
# Kind.STRUCT trace_event_raw_mm_vmscan_wakeup_kswapd
#                      Added fields:
#                                 gfp_flags: {'kind': 'TYPEDEF', 'name': 'gfp_t'}
# Kind.STRUCT kernfs_root
#                      Removed fields:
#                                  last_ino: {'kind': 'TYPEDEF', 'name': 'u32'}
# Kind.STRUCT opal_dev
#                      Field type changed:
#                                      resp: {'kind': 'PTR', 'type': {'kind': 'TYPEDEF', 'name': 'u8'}}
#                                          ->{'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 2048, 'type': {'kind': 'TYPEDEF', 'name': 'u8'}}
#                                       cmd: {'kind': 'PTR', 'type': {'kind': 'TYPEDEF', 'name': 'u8'}}
#                                          ->{'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 2048, 'type': {'kind': 'TYPEDEF', 'name': 'u8'}}
# Kind.STRUCT devlink_ops
#                      Added fields:
#                                    reload: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'netlink_ext_ack'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                      Field type changed:
#                                port_split: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'netlink_ext_ack'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                              port_unsplit: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'netlink_ext_ack'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
# Kind.STRUCT thermal_zone_device
#                      Layout changed
# Kind.STRUCT palmas_gpio
#                      Layout changed
# Kind.STRUCT dst_ops
#                      Field type changed:
#                               update_pmtu: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'dst_entry'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sock'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sk_buff'}}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'bool'}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'dst_entry'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sock'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sk_buff'}}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
# Kind.STRUCT compat_stat
#                      Added fields:
#                                    __pad1: {'kind': 'TYPEDEF', 'name': 'u16'}
#                                    __pad2: {'kind': 'TYPEDEF', 'name': 'u16'}
#                      Field type changed:
#                                    st_dev: {'kind': 'TYPEDEF', 'name': 'u32'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'compat_dev_t'}
#                                   st_rdev: {'kind': 'TYPEDEF', 'name': 'u32'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'compat_dev_t'}
# Kind.STRUCT container_dev
#                      Layout changed
# Kind.STRUCT smap_psock_map_entry
#                      Added fields:
#                                       map: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'bpf_map'}}
#                                 hash_link: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'htab_elem'}}
# Kind.STRUCT bpf_verifier_ops
#                      Added fields:
#                                gen_ld_abs: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'bpf_insn'}}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'bpf_insn'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                      Field type changed:
#                            get_func_proto: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'ENUM', 'name': 'bpf_func_id', 'size': 4}}], 'ret_type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'bpf_func_proto'}}}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'ENUM', 'name': 'bpf_func_id', 'size': 4}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'bpf_prog'}}}}], 'ret_type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'bpf_func_proto'}}}}}
#                           is_valid_access: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}, {'name': '(anon)', 'type': {'kind': 'ENUM', 'name': 'bpf_access_type', 'size': 4}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'bpf_insn_access_aux'}}}], 'ret_type': {'kind': 'TYPEDEF', 'name': 'bool'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}, {'name': '(anon)', 'type': {'kind': 'ENUM', 'name': 'bpf_access_type', 'size': 4}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'bpf_prog'}}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'bpf_insn_access_aux'}}}], 'ret_type': {'kind': 'TYPEDEF', 'name': 'bool'}}}
# Kind.STRUCT sched_dl_entity
#                      Added fields:
#                                dl_overrun: {'kind': 'INT', 'name': 'unsigned int'}
# Kind.STRUCT nd_pfn
#                      Layout changed
# Kind.STRUCT byt_gpio
#                      Added fields:
#                                      lock: {'kind': 'TYPEDEF', 'name': 'raw_spinlock_t'}
# Kind.STRUCT rdt_domain
#                      Added fields:
#                                  mbps_val: {'kind': 'PTR', 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}
# Kind.STRUCT selinux_audit_data
#                      Added fields:
#                                     state: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'selinux_state'}}
# Kind.STRUCT rc5t583_gpio
#                      Layout changed
# Kind.STRUCT gnttab_ops
#                      Added fields:
#                      query_foreign_access: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'grant_ref_t'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                      Removed fields:
#                                read_frame: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'grant_ref_t'}}], 'ret_type': {'kind': 'INT', 'name': 'long unsigned int'}}}
# Kind.STRUCT hwmon_device
#                      Layout changed
# Kind.STRUCT pci_epf_group
#                      Added fields:
#                                     index: {'kind': 'INT', 'name': 'int'}
# Kind.STRUCT netns_xfrm
#                      Removed fields:
#                      xfrm_state_hash_generation: {'kind': 'TYPEDEF', 'name': 'seqcount_t'}
# Kind.STRUCT dwc2_core_params
#                      Added fields:
#                          lpm_clock_gating: {'kind': 'TYPEDEF', 'name': 'bool'}
#                                power_down: {'kind': 'INT', 'name': 'int'}
#                               ipg_isoc_en: {'kind': 'TYPEDEF', 'name': 'bool'}
#                                acg_enable: {'kind': 'TYPEDEF', 'name': 'bool'}
#                                       lpm: {'kind': 'TYPEDEF', 'name': 'bool'}
#                            hird_threshold: {'kind': 'TYPEDEF', 'name': 'u8'}
#                                      besl: {'kind': 'TYPEDEF', 'name': 'bool'}
#                         hird_threshold_en: {'kind': 'TYPEDEF', 'name': 'bool'}
#                      Removed fields:
#                               hibernation: {'kind': 'TYPEDEF', 'name': 'bool'}
# Kind.STRUCT sx150x_pinctrl
#                      Layout changed
# Kind.STRUCT perf_ibs
#                      Removed fields:
#                      fetch_ignore_if_zero_rip: {'kind': 'INT', 'name': 'unsigned int'}
#                      fetch_count_reset_broken: {'kind': 'INT', 'name': 'unsigned int'}
# Kind.STRUCT spi_controller
#                      Added fields:
#                                   mem_ops: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'spi_controller_mem_ops'}}}
#                      Removed fields:
#                         spi_flash_can_dma: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'spi_device'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'spi_flash_read_message'}}}], 'ret_type': {'kind': 'TYPEDEF', 'name': 'bool'}}}
#                            devm_allocated: {'kind': 'TYPEDEF', 'name': 'bool'}
#                            spi_flash_read: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'spi_device'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'spi_flash_read_message'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                      flash_read_supported: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'spi_device'}}}], 'ret_type': {'kind': 'TYPEDEF', 'name': 'bool'}}}
# Kind.STRUCT x86_init_irqs
#                      Removed fields:
#                          intr_mode_select: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
# Kind.STRUCT bpf_stack_map
#                      Layout changed
# Kind.STRUCT css_set
#                      Added fields:
#                           mg_preload_node: {'kind': 'STRUCT', 'name': 'list_head'}
#                      Removed fields:
#                               dying_tasks: {'kind': 'STRUCT', 'name': 'list_head'}
#                       mg_dst_preload_node: {'kind': 'STRUCT', 'name': 'list_head'}
#                       mg_src_preload_node: {'kind': 'STRUCT', 'name': 'list_head'}
# Kind.STRUCT netfront_queue
#                      Removed fields:
#                              rx_cons_lock: {'kind': 'TYPEDEF', 'name': 'spinlock_t'}
#                         rx_rsp_unconsumed: {'kind': 'INT', 'name': 'unsigned int'}
#                             tx_pend_queue: {'kind': 'INT', 'name': 'unsigned int'}
#                                   tx_link: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 256, 'type': {'kind': 'INT', 'name': 'short unsigned int'}}
#                      Field type changed:
#                                   tx_skbs: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 256, 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sk_buff'}}}
#                                          ->{'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 256, 'type': {'kind': 'UNION', 'name': 'skb_entry'}}
# Kind.STRUCT serdev_controller
#                      Layout changed
# Kind.STRUCT acpi_gpio_lookup
#                      Removed fields:
#                                      adev: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'acpi_device'}}
# Kind.STRUCT pci_bus
#                      Removed fields:
#                               unsafe_warn: {'kind': 'INT', 'name': 'unsigned int'}
# Kind.STRUCT pcie_port
#                      Added fields:
#                               num_vectors: {'kind': 'TYPEDEF', 'name': 'u32'}
#                                msi_domain: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'irq_domain'}}
#                                irq_status: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 8, 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}
#                                      lock: {'kind': 'TYPEDEF', 'name': 'raw_spinlock_t'}
#                      Field type changed:
#                                  msi_data: {'kind': 'INT', 'name': 'long unsigned int'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'dma_addr_t'}
#                            msi_irq_in_use: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 1, 'type': {'kind': 'INT', 'name': 'long unsigned int'}}
#                                          ->{'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 4, 'type': {'kind': 'INT', 'name': 'long unsigned int'}}
# Kind.STRUCT max8997_platform_data
#                      Added fields:
#                                    wakeup: {'kind': 'INT', 'name': 'int'}
# Kind.STRUCT rq_wb
#                      Field type changed:
#                                sync_issue: {'kind': 'TYPEDEF', 'name': 's64'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'u64'}
#                                   rq_wait: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 2, 'type': {'kind': 'STRUCT', 'name': 'rq_wait'}}
#                                          ->{'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 3, 'type': {'kind': 'STRUCT', 'name': 'rq_wait'}}
# Kind.STRUCT tracing_map
#                      Added fields:
#                                    n_vars: {'kind': 'INT', 'name': 'unsigned int'}
# Kind.STRUCT trace_event_raw_aer_event
#                      Added fields:
#                          tlp_header_valid: {'kind': 'TYPEDEF', 'name': 'u8'}
#                                tlp_header: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 4, 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}
# Kind.STRUCT inet_connection_sock
#                      Added fields:
#                      icsk_listen_portaddr_node: {'kind': 'STRUCT', 'name': 'hlist_node'}
#                          icsk_clean_acked: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sock'}}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                      Field type changed:
#                              icsk_ca_priv: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 13, 'type': {'kind': 'TYPEDEF', 'name': 'u64'}}
#                                          ->{'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 11, 'type': {'kind': 'TYPEDEF', 'name': 'u64'}}
# Kind.STRUCT trace_event_raw_mm_vmscan_lru_isolate
#                      Field type changed:
#                              isolate_mode: {'kind': 'INT', 'name': 'unsigned int'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'isolate_mode_t'}
# Kind.STRUCT phy
#                      Layout changed
# Kind.STRUCT pnp_card
#                      Layout changed
# Kind.STRUCT ext4_sb_info
#                      Added fields:
#                      s_journal_flag_rwsem: {'kind': 'STRUCT', 'name': 'percpu_rw_semaphore'}
#                      Removed fields:
#                        s_writepages_rwsem: {'kind': 'STRUCT', 'name': 'percpu_rw_semaphore'}
#                      Field type changed:
#                             s_flex_groups: {'kind': 'PTR', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'flex_groups'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'flex_groups'}}
# Kind.STRUCT virtio_driver
#                      Layout changed
# Kind.STRUCT mmc_card
#                      Added fields:
#                            quirk_max_rate: {'kind': 'INT', 'name': 'unsigned int'}
# Kind.STRUCT pnp_protocol
#                      Layout changed
# Kind.STRUCT cpudata
#                      Added fields:
#                               sched_flags: {'kind': 'INT', 'name': 'unsigned int'}
#                            hwp_req_cached: {'kind': 'TYPEDEF', 'name': 'u64'}
#                             hwp_boost_min: {'kind': 'TYPEDEF', 'name': 'u32'}
#                            last_io_update: {'kind': 'TYPEDEF', 'name': 'u64'}
#                            hwp_cap_cached: {'kind': 'TYPEDEF', 'name': 'u64'}
# Kind.STRUCT scsi_device
#                      Layout changed
# Kind.STRUCT acpi_thermal
#                      Removed fields:
#                       thermal_check_count: {'kind': 'TYPEDEF', 'name': 'refcount_t'}
#                        thermal_check_lock: {'kind': 'STRUCT', 'name': 'mutex'}
# Kind.STRUCT rq
#                      Added fields:
#                          has_blocked_load: {'kind': 'INT', 'name': 'unsigned int'}
#                      last_blocked_load_update_tick: {'kind': 'INT', 'name': 'long unsigned int'}
#                         nohz_tick_stopped: {'kind': 'INT', 'name': 'unsigned int'}
#                      Field type changed:
#                                nohz_flags: {'kind': 'INT', 'name': 'long unsigned int'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'atomic_t'}
# Kind.STRUCT nd_namespace_common
#                      Layout changed
# Kind.STRUCT linux_binprm
#                      Added fields:
#                                rlim_stack: {'kind': 'STRUCT', 'name': 'rlimit'}
# Kind.STRUCT trace_event_raw_fib6_table_lookup
#                      Added fields:
#                                   rt_type: {'kind': 'TYPEDEF', 'name': 'u8'}
#                                       err: {'kind': 'INT', 'name': 'int'}
#                                     dport: {'kind': 'TYPEDEF', 'name': 'u16'}
#                                     proto: {'kind': 'TYPEDEF', 'name': 'u8'}
#                                     sport: {'kind': 'TYPEDEF', 'name': 'u16'}
# Kind.STRUCT scan_control
#                      Added fields:
#                                        nr: {'kind': 'STRUCT', 'name': '(anon)'}
# Kind.STRUCT fib4_rule
#                      Layout changed
# Kind.STRUCT tcp_info
#                      Added fields:
#                         tcpi_delivered_ce: {'kind': 'TYPEDEF', 'name': '__u32'}
#                            tcpi_delivered: {'kind': 'TYPEDEF', 'name': '__u32'}
# Kind.STRUCT nfnl_ct_hook
#                      Field type changed:
#                             attach_expect: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'nlattr'}}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'nf_conn'}}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'nlattr'}}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'FWD', 'name': 'nf_conn', 'fwd_kind': 'struct'}}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                build_size: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'nf_conn'}}}}], 'ret_type': {'kind': 'TYPEDEF', 'name': 'size_t'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'FWD', 'name': 'nf_conn', 'fwd_kind': 'struct'}}}}], 'ret_type': {'kind': 'TYPEDEF', 'name': 'size_t'}}}
#                                     build: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sk_buff'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'nf_conn'}}}, {'name': '(anon)', 'type': {'kind': 'ENUM', 'name': 'ip_conntrack_info', 'size': 4}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u_int16_t'}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u_int16_t'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sk_buff'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'FWD', 'name': 'nf_conn', 'fwd_kind': 'struct'}}}, {'name': '(anon)', 'type': {'kind': 'ENUM', 'name': 'ip_conntrack_info', 'size': 4}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u_int16_t'}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u_int16_t'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                     parse: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'nlattr'}}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'nf_conn'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'nlattr'}}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'FWD', 'name': 'nf_conn', 'fwd_kind': 'struct'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                    get_ct: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'sk_buff'}}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'ENUM', 'name': 'ip_conntrack_info', 'size': 4}}}], 'ret_type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'nf_conn'}}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'sk_buff'}}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'ENUM', 'name': 'ip_conntrack_info', 'size': 4}}}], 'ret_type': {'kind': 'PTR', 'type': {'kind': 'FWD', 'name': 'nf_conn', 'fwd_kind': 'struct'}}}}
#                                seq_adjust: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sk_buff'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'nf_conn'}}}, {'name': '(anon)', 'type': {'kind': 'ENUM', 'name': 'ip_conntrack_info', 'size': 4}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 's32'}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sk_buff'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'FWD', 'name': 'nf_conn', 'fwd_kind': 'struct'}}}, {'name': '(anon)', 'type': {'kind': 'ENUM', 'name': 'ip_conntrack_info', 'size': 4}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 's32'}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
# Kind.STRUCT regulation_constraints
#                      Added fields:
#                                max_spread: {'kind': 'INT', 'name': 'int'}
# Kind.STRUCT sock
#                      Added fields:
#                      sk_validate_xmit_skb: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sock'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'net_device'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sk_buff'}}}], 'ret_type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sk_buff'}}}}
#                      sk_route_forced_caps: {'kind': 'TYPEDEF', 'name': 'netdev_features_t'}
#                      Removed fields:
#                              sk_peer_lock: {'kind': 'TYPEDEF', 'name': 'spinlock_t'}
# Kind.STRUCT memory_failure_entry
#                      Removed fields:
#                                    trapno: {'kind': 'INT', 'name': 'int'}
# Kind.STRUCT nmiaction
#                      Added fields:
#                                  irq_work: {'kind': 'STRUCT', 'name': 'irq_work'}
# Kind.STRUCT pci_epf_bar
#                      Added fields:
#                                     barno: {'kind': 'ENUM', 'name': 'pci_barno', 'size': 4}
#                                     flags: {'kind': 'INT', 'name': 'int'}
# Kind.STRUCT wq_device
#                      Layout changed
# Kind.STRUCT kiocb
#                      Added fields:
#                                 ki_ioprio: {'kind': 'TYPEDEF', 'name': 'u16'}
#                      Field type changed:
#                                   ki_hint: {'kind': 'ENUM', 'name': 'rw_hint', 'size': 4}
#                                          ->{'kind': 'TYPEDEF', 'name': 'u16'}
# Kind.STRUCT bpf_dtab_netdev
#                      Added fields:
#                                     bulkq: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'xdp_bulk_queue'}}
# Kind.STRUCT acpi_device_pnp
#                      Removed fields:
#                               instance_no: {'kind': 'INT', 'name': 'int'}
# Kind.STRUCT usb_gadget_driver
#                      Layout changed
# Kind.STRUCT nf_queue_handler
#                      Field type changed:
#                              nf_hook_drop: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'net'}}}], 'ret_type': {'kind': 'INT', 'name': 'unsigned int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'net'}}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
# Kind.STRUCT vm_operations_struct
#                      Added fields:
#                                  pagesize: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'vm_area_struct'}}}], 'ret_type': {'kind': 'INT', 'name': 'long unsigned int'}}}
#                      Field type changed:
#                                     fault: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'vm_fault'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'vm_fault'}}}], 'ret_type': {'kind': 'TYPEDEF', 'name': 'vm_fault_t'}}}
#                              page_mkwrite: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'vm_fault'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'vm_fault'}}}], 'ret_type': {'kind': 'TYPEDEF', 'name': 'vm_fault_t'}}}
#                               pfn_mkwrite: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'vm_fault'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'vm_fault'}}}], 'ret_type': {'kind': 'TYPEDEF', 'name': 'vm_fault_t'}}}
#                                huge_fault: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'vm_fault'}}}, {'name': '(anon)', 'type': {'kind': 'ENUM', 'name': 'page_entry_size', 'size': 4}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'vm_fault'}}}, {'name': '(anon)', 'type': {'kind': 'ENUM', 'name': 'page_entry_size', 'size': 4}}], 'ret_type': {'kind': 'TYPEDEF', 'name': 'vm_fault_t'}}}
# Kind.STRUCT mem_cgroup_per_node
#                      Added fields:
#                                 congested: {'kind': 'TYPEDEF', 'name': 'bool'}
# Kind.STRUCT blkcg
#                      Layout changed
# Kind.STRUCT kmalloc_info_struct
#                      Field type changed:
#                                      size: {'kind': 'INT', 'name': 'long unsigned int'}
#                                          ->{'kind': 'INT', 'name': 'unsigned int'}
# Kind.STRUCT tps6586x_gpio
#                      Layout changed
# Kind.STRUCT fb_info
#                      Added fields:
#                         fbcon_rotate_hint: {'kind': 'INT', 'name': 'int'}
# Kind.STRUCT dmi_memdev_info
#                      Added fields:
#                                      size: {'kind': 'TYPEDEF', 'name': 'u64'}
# Kind.STRUCT nd_blk_region
#                      Layout changed
# Kind.STRUCT pmu
#                      Removed fields:
#                              check_period: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'perf_event'}}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u64'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                      Field type changed:
#                                 setup_aux: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'perf_event'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'bool'}}], 'ret_type': {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'bool'}}], 'ret_type': {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}}}
# Kind.STRUCT crypto_type
#                      Removed fields:
#                                    lookup: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'INT', 'name': 'char'}}}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}], 'ret_type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'crypto_alg'}}}}
# Kind.STRUCT scsi_dev_info_list
#                      Layout changed
# Kind.STRUCT ib_cq
#                      Added fields:
#                                       res: {'kind': 'STRUCT', 'name': 'rdma_restrack_entry'}
#                      Removed fields:
#                                   comp_wq: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'workqueue_struct'}}
# Kind.STRUCT posix_clock_operations
#                      Field type changed:
#                              clock_getres: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'posix_clock'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'posix_clock'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                      poll: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'posix_clock'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'file'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'TYPEDEF', 'name': 'poll_table'}}}], 'ret_type': {'kind': 'TYPEDEF', 'name': 'uint'}}}
# ...
#                        reset_assert_delay: {'kind': 'INT', 'name': 'unsigned int'}
#                      reset_deassert_delay: {'kind': 'INT', 'name': 'unsigned int'}
#                      Removed fields:
#                                    pm_ops: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'dev_pm_ops'}}}
# Kind.STRUCT fbcon_ops
#                      Field type changed:
#                                    cursor: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'vc_data'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fb_info'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'vc_data'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fb_info'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
# Kind.STRUCT flow_keys
#                      Layout changed
# Kind.STRUCT ehci_hcd
#                      Removed fields:
#                                 is_aspeed: {'kind': 'INT', 'name': 'unsigned int'}
# Kind.STRUCT vme_driver
#                      Layout changed
# Kind.STRUCT queue_limits
#                      Fields reordered:
#                                           ['bounce_pfn', 'seg_boundary_mask', 'virt_boundary_mask', 'max_hw_sectors', 'max_dev_sectors', 'chunk_sectors', 'max_sectors', 'max_segment_size', 'physical_block_size', 'logical_block_size', 'alignment_offset', 'io_min', 'io_opt', 'max_discard_sectors', 'max_hw_discard_sectors', 'max_write_same_sectors', 'max_write_zeroes_sectors', 'discard_granularity', 'discard_alignment', 'max_segments', 'max_integrity_segments', 'max_discard_segments', 'misaligned', 'discard_misaligned', 'cluster', 'raid_partial_stripes_expensive', 'zoned']
#                                           ['bounce_pfn', 'seg_boundary_mask', 'virt_boundary_mask', 'max_hw_sectors', 'max_dev_sectors', 'chunk_sectors', 'max_sectors', 'max_segment_size', 'physical_block_size', 'alignment_offset', 'io_min', 'io_opt', 'max_discard_sectors', 'max_hw_discard_sectors', 'max_write_same_sectors', 'max_write_zeroes_sectors', 'discard_granularity', 'discard_alignment', 'logical_block_size', 'max_segments', 'max_integrity_segments', 'max_discard_segments', 'misaligned', 'discard_misaligned', 'cluster', 'raid_partial_stripes_expensive', 'zoned']
#                      Field type changed:
#                        logical_block_size: {'kind': 'INT', 'name': 'unsigned int'}
#                                          ->{'kind': 'INT', 'name': 'short unsigned int'}
# Kind.STRUCT xenbus_driver
#                      Layout changed
# Kind.STRUCT nd_namespace_blk
#                      Layout changed
# Kind.STRUCT net_protocol
#                      Added fields:
#                       early_demux_handler: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sk_buff'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                               early_demux: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sk_buff'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
# Kind.STRUCT ohci_platform_priv
#                      Removed fields:
#                                  num_phys: {'kind': 'INT', 'name': 'int'}
#                                      phys: {'kind': 'PTR', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'phy'}}}
# Kind.STRUCT tun_file
#                      Added fields:
#                                   tx_ring: {'kind': 'STRUCT', 'name': 'ptr_ring'}
#                                   xdp_rxq: {'kind': 'STRUCT', 'name': 'xdp_rxq_info'}
#                      Removed fields:
#                                  tx_array: {'kind': 'STRUCT', 'name': 'skb_array'}
# Kind.STRUCT bpf_map_info
#                      Added fields:
#                                   ifindex: {'kind': 'TYPEDEF', 'name': '__u32'}
#                                    btf_id: {'kind': 'TYPEDEF', 'name': '__u32'}
#                           btf_key_type_id: {'kind': 'TYPEDEF', 'name': '__u32'}
#                                 netns_dev: {'kind': 'TYPEDEF', 'name': '__u64'}
#                         btf_value_type_id: {'kind': 'TYPEDEF', 'name': '__u32'}
#                                 netns_ino: {'kind': 'TYPEDEF', 'name': '__u64'}
# Kind.STRUCT kioctx
#                      Added fields:
#                                free_rwork: {'kind': 'STRUCT', 'name': 'rcu_work'}
#                      Removed fields:
#                                  free_rcu: {'kind': 'STRUCT', 'name': 'callback_head'}
#                                 free_work: {'kind': 'STRUCT', 'name': 'work_struct'}
# Kind.STRUCT perf_event_context
#                      Added fields:
#                           flexible_active: {'kind': 'STRUCT', 'name': 'list_head'}
#                             pinned_active: {'kind': 'STRUCT', 'name': 'list_head'}
#                      Field type changed:
#                           flexible_groups: {'kind': 'STRUCT', 'name': 'list_head'}
#                                          ->{'kind': 'STRUCT', 'name': 'perf_event_groups'}
#                             pinned_groups: {'kind': 'STRUCT', 'name': 'list_head'}
#                                          ->{'kind': 'STRUCT', 'name': 'perf_event_groups'}
# Kind.STRUCT bpf_map_ops
#                      Added fields:
#                             map_check_btf: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'bpf_map'}}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'btf'}}}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                         map_seq_show_elem: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'bpf_map'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'seq_file'}}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                      Removed fields:
#                      map_lookup_elem_sys_only: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'bpf_map'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}}], 'ret_type': {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}}}
# Kind.STRUCT efi
#                      Added fields:
#                                   tpm_log: {'kind': 'INT', 'name': 'long unsigned int'}
#                               mem_reserve: {'kind': 'INT', 'name': 'long unsigned int'}
#                      Removed fields:
#                              mokvar_table: {'kind': 'INT', 'name': 'long unsigned int'}
# Kind.STRUCT userfaultfd_ctx
#                      Added fields:
#                                     state: {'kind': 'ENUM', 'name': 'userfaultfd_state', 'size': 4}
#                             mmap_changing: {'kind': 'TYPEDEF', 'name': 'bool'}
# Kind.STRUCT ttyprintk_port
#                      Added fields:
#                          port_write_mutex: {'kind': 'STRUCT', 'name': 'mutex'}
#                      Removed fields:
#                                  spinlock: {'kind': 'TYPEDEF', 'name': 'spinlock_t'}
# Kind.STRUCT bpf_call_arg_meta
#                      Added fields:
#                          msize_smax_value: {'kind': 'TYPEDEF', 'name': 's64'}
#                          msize_umax_value: {'kind': 'TYPEDEF', 'name': 'u64'}
# Kind.STRUCT softnet_data
#                      Added fields:
#                              xfrm_backlog: {'kind': 'STRUCT', 'name': 'sk_buff_head'}
# Kind.STRUCT rcu_node
#                      Added fields:
#                            exp_need_flush: {'kind': 'TYPEDEF', 'name': 'bool'}
#                                       rew: {'kind': 'STRUCT', 'name': 'rcu_exp_work'}
#                      Removed fields:
#                           n_tasks_boosted: {'kind': 'INT', 'name': 'long unsigned int'}
#                              n_exp_boosts: {'kind': 'INT', 'name': 'long unsigned int'}
#                           n_normal_boosts: {'kind': 'INT', 'name': 'long unsigned int'}
#                      Field type changed:
#                            need_future_gp: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 2, 'type': {'kind': 'INT', 'name': 'int'}}
#                                          ->{'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 4, 'type': {'kind': 'TYPEDEF', 'name': 'u8'}}
# Kind.STRUCT blk_mq_hw_ctx
#                      Added fields:
#                                      srcu: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 0, 'type': {'kind': 'STRUCT', 'name': 'srcu_struct'}}
#                                nr_expired: {'kind': 'INT', 'name': 'unsigned int'}
#                      Removed fields:
#                             queue_rq_srcu: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 0, 'type': {'kind': 'STRUCT', 'name': 'srcu_struct'}}
#                             dispatch_busy: {'kind': 'INT', 'name': 'unsigned int'}
#                      Fields reordered:
#                                           ['(anon)', 'run_work', 'cpumask', 'next_cpu', 'next_cpu_batch', 'flags', 'sched_data', 'queue', 'fq', 'driver_data', 'ctx_map', 'dispatch_from', 'dispatch_busy', 'nr_ctx', 'ctxs', 'dispatch_wait', 'wait_index', 'tags', 'sched_tags', 'queued', 'run', 'dispatched', 'numa_node', 'queue_num', 'nr_active', 'cpuhp_dead', 'kobj', 'poll_considered', 'poll_invoked', 'poll_success', 'debugfs_dir', 'sched_debugfs_dir', 'queue_rq_srcu']
#                                           ['(anon)', 'run_work', 'cpumask', 'next_cpu', 'next_cpu_batch', 'flags', 'sched_data', 'queue', 'fq', 'driver_data', 'ctx_map', 'dispatch_from', 'ctxs', 'nr_ctx', 'dispatch_wait', 'wait_index', 'tags', 'sched_tags', 'queued', 'run', 'dispatched', 'numa_node', 'queue_num', 'nr_active', 'nr_expired', 'cpuhp_dead', 'kobj', 'poll_considered', 'poll_invoked', 'poll_success', 'debugfs_dir', 'sched_debugfs_dir', 'srcu']
# Kind.STRUCT wb_writeback_work
#                      Added fields:
#                           older_than_this: {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'long unsigned int'}}
# Kind.STRUCT fsnotify_iter_info
#                      Added fields:
#                               report_mask: {'kind': 'INT', 'name': 'unsigned int'}
#                                     marks: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 2, 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fsnotify_mark'}}}
#                      Removed fields:
#                             vfsmount_mark: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fsnotify_mark'}}
#                                inode_mark: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fsnotify_mark'}}
# Kind.STRUCT compat_shmid64_ds
#                      Added fields:
#                            shm_atime_high: {'kind': 'TYPEDEF', 'name': 'compat_ulong_t'}
#                            shm_dtime_high: {'kind': 'TYPEDEF', 'name': 'compat_ulong_t'}
#                            shm_ctime_high: {'kind': 'TYPEDEF', 'name': 'compat_ulong_t'}
#                      Removed fields:
#                                 __unused3: {'kind': 'TYPEDEF', 'name': 'compat_ulong_t'}
#                                 __unused2: {'kind': 'TYPEDEF', 'name': 'compat_ulong_t'}
#                                 __unused1: {'kind': 'TYPEDEF', 'name': 'compat_ulong_t'}
#                      Field type changed:
#                                 shm_dtime: {'kind': 'TYPEDEF', 'name': 'compat_time_t'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'compat_ulong_t'}
#                                 shm_ctime: {'kind': 'TYPEDEF', 'name': 'compat_time_t'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'compat_ulong_t'}
#                                 shm_atime: {'kind': 'TYPEDEF', 'name': 'compat_time_t'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'compat_ulong_t'}
# Kind.STRUCT blkif_sring
#                      Added fields:
#                                       pad: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 48, 'type': {'kind': 'TYPEDEF', 'name': 'uint8_t'}}
#                      Removed fields:
#                                     __pad: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 48, 'type': {'kind': 'TYPEDEF', 'name': 'uint8_t'}}
# Kind.STRUCT worker
#                      Removed fields:
#                                desc_valid: {'kind': 'TYPEDEF', 'name': 'bool'}
# Kind.STRUCT coredump_proc_event
#                      Added fields:
#                                parent_pid: {'kind': 'TYPEDEF', 'name': '__kernel_pid_t'}
#                               parent_tgid: {'kind': 'TYPEDEF', 'name': '__kernel_pid_t'}
# Kind.STRUCT filename
#                      Fields reordered:
#                                           ['name', 'uptr', 'aname', 'refcnt', 'iname']
#                                           ['name', 'uptr', 'refcnt', 'aname', 'iname']
# Kind.STRUCT efi_scratch
#                      Added fields:
#                                   prev_mm: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'mm_struct'}}
#                      Removed fields:
#                                       r15: {'kind': 'TYPEDEF', 'name': 'u64'}
#                                   use_pgd: {'kind': 'TYPEDEF', 'name': 'bool'}
#                                  prev_cr3: {'kind': 'TYPEDEF', 'name': 'u64'}
#                                   efi_pgt: {'kind': 'PTR', 'type': {'kind': 'TYPEDEF', 'name': 'pgd_t'}}
# Kind.STRUCT nfs_server
#                      Layout changed
# Kind.STRUCT inet_listen_hashbucket
#                      Added fields:
#                                      head: {'kind': 'STRUCT', 'name': 'hlist_head'}
#                                     count: {'kind': 'INT', 'name': 'unsigned int'}
#                      Removed fields:
#                                    (anon): {'kind': 'UNION', 'name': '(anon)'}
# Kind.STRUCT amd_iommu
#                      Field type changed:
#                                      lock: {'kind': 'TYPEDEF', 'name': 'spinlock_t'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'raw_spinlock_t'}
# Kind.STRUCT mii_bus
#                      Layout changed
# Kind.STRUCT acpi_battery
#                      Added fields:
#                                      list: {'kind': 'STRUCT', 'name': 'list_head'}
# Kind.STRUCT pnp_card_driver
#                      Layout changed
# Kind.STRUCT atm_dev
#                      Layout changed
# Kind.STRUCT pci_host_bridge
#                      Added fields:
#                                native_aer: {'kind': 'INT', 'name': 'unsigned int'}
#                                native_ltr: {'kind': 'INT', 'name': 'unsigned int'}
#                                native_pme: {'kind': 'INT', 'name': 'unsigned int'}
#                       native_shpc_hotplug: {'kind': 'INT', 'name': 'unsigned int'}
#                       native_pcie_hotplug: {'kind': 'INT', 'name': 'unsigned int'}

# %%
check_diff(d1, d2, Kind.UNION, diff_struct)
# Out:
# Old Kind.UNION (99): ['fpregs_state', 'irq_stack_union', 'sigval', 'kernfs_node_id', 'key_payload', 'thread_union', 'perf_mem_data_src', 'flowi_uli', 'ethtool_flow_union', 'perf_capabilities']
# New Kind.UNION (102): ['fpregs_state', 'irq_stack_union', 'sigval', 'kernfs_node_id', 'thread_union', 'key_payload', 'perf_mem_data_src', 'flowi_uli', 'ethtool_flow_union', 'perf_capabilities']
# Removed Kind.UNION (3): ['nf_inet_addr', 'nf_conntrack_proto', 'nf_conntrack_man_proto']
# Added Kind.UNION (6): ['sctp_params', 'sctp_addr_param', 'sctp_sack_variable', 'sctp_addr', 'skb_entry', 'ib_flow_spec']
# Common Kind.UNION (96): ['tpacket_req_u', 'mon_data_bits', 'acpi_descriptor', 'tpm2_cmd_params', 'irte_ga_lo', 'entry_union', 'hsw_tsx_tuning', 'l2_cache', 'tcp_cc_info', 'l3_cache']
# Changed Kind.UNION (4): ['proc_op', 'bpf_attr', 'security_list_options', 'thread_union']
# Kind.UNION  proc_op
#                      Removed fields:
#                                       lsm: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'INT', 'name': 'char'}}}
# Kind.UNION  bpf_attr
#                      Added fields:
#                            raw_tracepoint: {'kind': 'STRUCT', 'name': '(anon)'}
#                             task_fd_query: {'kind': 'STRUCT', 'name': '(anon)'}
# Kind.UNION  security_list_options
#                      Added fields:
#                             sctp_sk_clone: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sctp_endpoint'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sock'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sock'}}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                         sctp_bind_connect: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sock'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sockaddr'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                        sctp_assoc_request: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sctp_endpoint'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sk_buff'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                         socket_socketpair: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'socket'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'socket'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                             cred_getsecid: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'cred'}}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                      Field type changed:
#                        sem_alloc_security: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sem_array'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                             shm_associate: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'shmid_kernel'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                        shm_alloc_security: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'shmid_kernel'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                shm_shmctl: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'shmid_kernel'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                   capable: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'cred'}}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'user_namespace'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'cred'}}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'user_namespace'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                 shm_shmat: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'shmid_kernel'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'char'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'char'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                         sem_free_security: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sem_array'}}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                      msg_queue_alloc_security: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'msg_queue'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                 task_kill: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'task_struct'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'siginfo'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'task_struct'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'siginfo'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'cred'}}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                          msg_queue_msgsnd: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'msg_queue'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'msg_msg'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'msg_msg'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                         shm_free_security: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'shmid_kernel'}}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                          msg_queue_msgctl: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'msg_queue'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                          msg_queue_msgrcv: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'msg_queue'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'msg_msg'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'task_struct'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'long int'}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'msg_msg'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'task_struct'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'long int'}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                   settime: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timezone'}}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timezone'}}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                       msg_queue_associate: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'msg_queue'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                      msg_queue_free_security: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'msg_queue'}}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                             sem_associate: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sem_array'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                 sem_semop: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sem_array'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sembuf'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sembuf'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                sem_semctl: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sem_array'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
# Kind.UNION  thread_union
#                      Added fields:
#                                      task: {'kind': 'STRUCT', 'name': 'task_struct'}

# %%
def diff_func(old, new):
    result = ""

    old_params = {p['name']: p for p in old['type']['params']}
    new_params = {p['name']: p for p in new['type']['params']}

    # params added
    added_params = new_params.keys() - old_params.keys()
    if added_params:
        result += f"Added params:\n"
        for name in added_params:
            result += f"{name:>20}: {new_params[name]['type']}\n"

    # params removed
    removed_params = old_params.keys() - new_params.keys()
    if removed_params:
        result += f"Removed params:\n"
        for name in removed_params:
            result += f"{name:>20}: {old_params[name]['type']}\n"

    # params reordered
    common = old_params.keys() & new_params.keys()
    if [n for n in old_params if n in common] != [n for n in new_params if n in common]:
        result += f"Params reordered:\n"
        result += f"{'':>20} {list(old_params)}\n"
        result += f"{'':>20} {list(new_params)}\n"

    # params changed type
    changed_types = {
        name: (old_params[name]['type'], new_params[name]['type'])
        for name in common
        if old_params[name]['type'] != new_params[name]['type']
    }
    if changed_types:
        result += "Param type changed:\n"
        for name, (old_type, new_type) in changed_types.items():
            result += f"{name:>20}: {old_type}\n"
            result += f"{'':>20}->{new_type}\n"

    # changed return value
    old_ret = old['type']['ret_type']
    new_ret = new['type']['ret_type']
    if old_ret != new_ret:
        result += f"Return type changed:\n"
        result += f"{'':>20}: {old_ret}\n"
        result += f"{'':>20}->{new_ret}\n"

    assert result, f"\n{old}\n{new}"
    return result


check_diff(d1, d2, Kind.FUNC, diff_func)
# Out:
# Old Kind.FUNC (42719): ['copy_bootdata', 'early_make_pgtable', 'reset_early_page_tables', '__startup_secondary_64', '__startup_64', 'x86_64_start_reservations', 'x86_64_start_kernel', '__early_make_pgtable', 'read_cr3_pa', 'clear_page']
# New Kind.FUNC (44531): ['copy_bootdata', 'early_make_pgtable', 'reset_early_page_tables', '__startup_secondary_64', '__startup_64', 'x86_64_start_reservations', 'x86_64_start_kernel', '__early_make_pgtable', 'read_cr3_pa', 'clear_page']
# Removed Kind.FUNC (1801): ['disable_acpi_xsdt', 'kiocb_free', 'cpu_mitigations_auto_nosmt', 'SyS_setresgid16', 'nommu_sync_sg_for_device', 'SYSC_statfs64', 'seq_open_wireless', 'ext4_sb_bread', 'SyS_send', 'rtpm_status_show']
# Added Kind.FUNC (3613): ['ip6_sk_dst_store_flow', '__ia32_sys_fcntl', '__ia32_sys_exit', 'mdio_device_reset', '__bpf_trace_writeback_sb_inodes_requeue', 'show_lowest_freq', '__do_compat_sys_rt_tgsigqueueinfo', 'bpf_verifier_log_write', 'clk_core_set_parent_nolock', 'page_counter_set_min']
# Common Kind.FUNC (40918): ['pci_wch_ch355_setup', 'devtmpfsd', 'mark_hash_blacklisted', 'smack_inode_notifysecctx', 'ioread8', 'bio_put', 'hwrng_attr_current_store', 'ipv6_add_addr', 'tcp_cleanup_rbuf', 'key_schedule_gc']
# Changed Kind.FUNC (1062): ['ipv6_add_addr', 'proc_pid_instantiate', '__uncore_thresh6_show', 'rt6_lookup', 'fib4_rule_configure', 'dm_alloc_md_mempools', 'posix_cpu_timer_get', 'mix_pool_bytes', 'mls_compute_sid', 'security_member_sid']
# Kind.FUNC   ipv6_add_addr
#                      Added params:
#                                       cfg: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'ifa6_config'}}
#                      Removed params:
#                                      addr: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'in6_addr'}}}
#                                 peer_addr: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'in6_addr'}}}
#                                     flags: {'kind': 'TYPEDEF', 'name': 'u32'}
#                              prefered_lft: {'kind': 'TYPEDEF', 'name': 'u32'}
#                                     scope: {'kind': 'INT', 'name': 'int'}
#                                    pfxlen: {'kind': 'INT', 'name': 'int'}
#                                 valid_lft: {'kind': 'TYPEDEF', 'name': 'u32'}
# Kind.FUNC   proc_pid_instantiate
#                      Removed params:
#                                       dir: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'inode'}}
#                      Return type changed:
#                                          : {'kind': 'INT', 'name': 'int'}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'dentry'}}
# Kind.FUNC   __uncore_thresh6_show
#                      Added params:
#                                      kobj: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kobject'}}
#                      Removed params:
#                                       dev: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device'}}
#                      Param type changed:
#                                      attr: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device_attribute'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kobj_attribute'}}
# Kind.FUNC   rt6_lookup
#                      Added params:
#                                       skb: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'sk_buff'}}}
# Kind.FUNC   fib4_rule_configure
#                      Added params:
#                                    extack: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'netlink_ext_ack'}}
# Kind.FUNC   dm_alloc_md_mempools
#                      Added params:
#                             min_pool_size: {'kind': 'INT', 'name': 'unsigned int'}
# Kind.FUNC   posix_cpu_timer_get
#                      Param type changed:
#                                       itp: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'itimerspec'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'itimerspec64'}}
# Kind.FUNC   mix_pool_bytes
#                      Added params:
#                                    nbytes: {'kind': 'INT', 'name': 'int'}
#                                         r: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'entropy_store'}}
#                                        in: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'name': 'void', 'kind': 'VOID'}}}
#                      Removed params:
#                                       len: {'kind': 'TYPEDEF', 'name': 'size_t'}
#                                       buf: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'name': 'void', 'kind': 'VOID'}}}
# Kind.FUNC   mls_compute_sid
#                      Added params:
#                                         p: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'policydb'}}
# Kind.FUNC   security_member_sid
#                      Added params:
#                                     state: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'selinux_state'}}
# Kind.FUNC   __uncore_qor_show
#                      Added params:
#                                      kobj: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kobject'}}
#                      Removed params:
#                                       dev: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device'}}
#                      Param type changed:
#                                      attr: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device_attribute'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kobj_attribute'}}
# Kind.FUNC   secure_ipv6_port_ephemeral
#                      Return type changed:
#                                          : {'kind': 'TYPEDEF', 'name': 'u64'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'u32'}
# Kind.FUNC   task_numa_free
#                      Removed params:
#                                     final: {'kind': 'TYPEDEF', 'name': 'bool'}
# Kind.FUNC   __ip6_route_redirect
#                      Added params:
#                                       skb: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'sk_buff'}}}
# Kind.FUNC   ps2_sendbyte
#                      Param type changed:
#                                   timeout: {'kind': 'INT', 'name': 'int'}
#                                          ->{'kind': 'INT', 'name': 'unsigned int'}
#                                      byte: {'kind': 'INT', 'name': 'unsigned char'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'u8'}
# Kind.FUNC   bts_buffer_setup_aux
#                      Added params:
#                                       cpu: {'kind': 'INT', 'name': 'int'}
#                      Removed params:
#                                     event: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'perf_event'}}
# Kind.FUNC   prandom_reseed
#                      Removed params:
#                                    unused: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'timer_list'}}
#                      Return type changed:
#                                          : {'name': 'void', 'kind': 'VOID'}
#                                          ->{'kind': 'INT', 'name': 'int'}
# Kind.FUNC   port_fops_poll
#                      Return type changed:
#                                          : {'kind': 'INT', 'name': 'unsigned int'}
#                                          ->{'kind': 'TYPEDEF', 'name': '__poll_t'}
# Kind.FUNC   tun_attach
#                      Removed params:
#                               publish_tun: {'kind': 'TYPEDEF', 'name': 'bool'}
# Kind.FUNC   timekeeping_inject_offset
#                      Param type changed:
#                                        ts: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}
# Kind.FUNC   __uncore_filter_all_op_show
#                      Added params:
#                                      kobj: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kobject'}}
#                      Removed params:
#                                       dev: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device'}}
#                      Param type changed:
#                                      attr: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device_attribute'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kobj_attribute'}}
# Kind.FUNC   nanosleep_copyout
#                      Param type changed:
#                                        ts: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}
# Kind.FUNC   event_triggers_call
#                      Added params:
#                                     event: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'ring_buffer_event'}}
# Kind.FUNC   cpuidle_select
#                      Added params:
#                                 stop_tick: {'kind': 'PTR', 'type': {'kind': 'TYPEDEF', 'name': 'bool'}}
# Kind.FUNC   cw_cursor
#                      Added params:
#                            softback_lines: {'kind': 'INT', 'name': 'int'}
# Kind.FUNC   posix_cpu_clock_set
#                      Param type changed:
#                                        tp: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}}
# Kind.FUNC   do_io_getevents
#                      Param type changed:
#                                        ts: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}
# Kind.FUNC   add_hwgenerator_randomness
#                      Added params:
#                                    buffer: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'INT', 'name': 'char'}}}
#                                     count: {'kind': 'TYPEDEF', 'name': 'size_t'}
#                      Removed params:
#                                       len: {'kind': 'TYPEDEF', 'name': 'size_t'}
#                                       buf: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'name': 'void', 'kind': 'VOID'}}}
# Kind.FUNC   gpiod_set_raw_array_value_cansleep
#                      Return type changed:
#                                          : {'name': 'void', 'kind': 'VOID'}
#                                          ->{'kind': 'INT', 'name': 'int'}
# Kind.FUNC   posix_cpu_clock_getres
#                      Param type changed:
#                                        tp: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}
# Kind.FUNC   __uncore_cmask5_show
#                      Added params:
#                                      kobj: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kobject'}}
#                      Removed params:
#                                       dev: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device'}}
#                      Param type changed:
#                                      attr: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device_attribute'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kobj_attribute'}}
# Kind.FUNC   edac_mc_get_poll_msec
#                      Return type changed:
#                                          : {'kind': 'INT', 'name': 'unsigned int'}
#                                          ->{'kind': 'INT', 'name': 'int'}
# Kind.FUNC   allocate_threshold_blocks
#                      Removed params:
#                                        tb: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'threshold_bank'}}
# Kind.FUNC   fanotify_alloc_event
#                      Added params:
#                                     group: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fsnotify_group'}}
# Kind.FUNC   bsg_setup_queue
#                      Removed params:
#                                   release: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device'}}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
# Kind.FUNC   ps2_handle_ack
#                      Param type changed:
#                                      data: {'kind': 'INT', 'name': 'unsigned char'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'u8'}
#                      Return type changed:
#                                          : {'kind': 'INT', 'name': 'int'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'bool'}
# Kind.FUNC   security_context_to_sid_force
#                      Added params:
#                                     state: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'selinux_state'}}
# Kind.FUNC   stacktrace_count_trigger
#                      Added params:
#                                     event: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'ring_buffer_event'}}
# Kind.FUNC   __uncore_filter_nid2_show
#                      Added params:
#                                      kobj: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kobject'}}
#                      Removed params:
#                                       dev: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device'}}
#                      Param type changed:
#                                      attr: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device_attribute'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kobj_attribute'}}
# Kind.FUNC   tca_action_flush
#                      Added params:
#                                    extack: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'netlink_ext_ack'}}
# Kind.FUNC   inet6_rt_notify
#                      Param type changed:
#                                        rt: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'rt6_info'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fib6_info'}}
# Kind.FUNC   validate_xmit_skb
#                      Added params:
#                                     again: {'kind': 'PTR', 'type': {'kind': 'TYPEDEF', 'name': 'bool'}}
# Kind.FUNC   proc_ns_instantiate
#                      Removed params:
#                                       dir: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'inode'}}
#                      Return type changed:
#                                          : {'kind': 'INT', 'name': 'int'}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'dentry'}}
# Kind.FUNC   security_set_bools
#                      Added params:
#                                     state: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'selinux_state'}}
# Kind.FUNC   fuse_file_poll
#                      Return type changed:
#                                          : {'kind': 'INT', 'name': 'unsigned int'}
#                                          ->{'kind': 'TYPEDEF', 'name': '__poll_t'}
# Kind.FUNC   ip6mr_rule_configure
#                      Added params:
#                                    extack: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'netlink_ext_ack'}}
# Kind.FUNC   jiffies_to_timespec64
#                      Param type changed:
#                                     value: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}
# Kind.FUNC   sk_filter_func_proto
#                      Added params:
#                                      prog: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'bpf_prog'}}}
# Kind.FUNC   ip6mr_cache_unresolved
#                      Param type changed:
#                                       mrt: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'mr6_table'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'mr_table'}}
# Kind.FUNC   __scsi_queue_insert
#                      Param type changed:
#                                    unbusy: {'kind': 'INT', 'name': 'int'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'bool'}
# Kind.FUNC   poll_select_set_timeout
#                      Param type changed:
#                                        to: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}
# Kind.FUNC   avc_ss_reset
#                      Added params:
#                                       avc: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'selinux_avc'}}
# Kind.FUNC   __ip6_del_rt
#                      Param type changed:
#                                        rt: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'rt6_info'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fib6_info'}}
# Kind.FUNC   blk_alloc_queue_node
#                      Added params:
#                                      lock: {'kind': 'PTR', 'type': {'kind': 'TYPEDEF', 'name': 'spinlock_t'}}
# Kind.FUNC   fname_encrypt
#                      Added params:
#                                      olen: {'kind': 'INT', 'name': 'unsigned int'}
#                                       out: {'kind': 'PTR', 'type': {'kind': 'TYPEDEF', 'name': 'u8'}}
#                      Removed params:
#                                     oname: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fscrypt_str'}}
# Kind.FUNC   __nf_unregister_net_hook
#                      Added params:
#                                        pf: {'kind': 'INT', 'name': 'int'}
#                                       net: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'net'}}
#                                       reg: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'nf_hook_ops'}}}
#                      Removed params:
#                                       old: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'nf_hook_entries'}}
#                                     unreg: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'nf_hook_ops'}}}
# Kind.FUNC   bind_evtchn_to_irqhandler
#                      Param type changed:
#                                    evtchn: {'kind': 'TYPEDEF', 'name': 'evtchn_port_t'}
#                                          ->{'kind': 'INT', 'name': 'unsigned int'}
# Kind.FUNC   pci_epc_set_msi
#                      Added params:
#                                   func_no: {'kind': 'TYPEDEF', 'name': 'u8'}
# Kind.FUNC   packet_getname
#                      Removed params:
#                                 uaddr_len: {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'int'}}
# Kind.FUNC   mif6_delete
#                      Param type changed:
#                                       mrt: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'mr6_table'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'mr_table'}}
# Kind.FUNC   security_netlbl_sid_to_secattr
#                      Added params:
#                                     state: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'selinux_state'}}
# Kind.FUNC   hist_field_s8
#                      Added params:
#                                       elt: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'tracing_map_elt'}}
#                                       rbe: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'ring_buffer_event'}}
# Kind.FUNC   selinux_msg_queue_msgctl
#                      Param type changed:
#                                       msq: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'msg_queue'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}
# Kind.FUNC   eventfd_poll
#                      Return type changed:
#                                          : {'kind': 'INT', 'name': 'unsigned int'}
#                                          ->{'kind': 'TYPEDEF', 'name': '__poll_t'}
# Kind.FUNC   fanotify_handle_event
#                      Removed params:
#                             fanotify_mark: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fsnotify_mark'}}
#                                inode_mark: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fsnotify_mark'}}
# Kind.FUNC   compaction_alloc
#                      Removed params:
#                                    result: {'kind': 'PTR', 'type': {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'int'}}}
# Kind.FUNC   icmp6_send
#                      Removed params:
#                                      parm: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'inet6_skb_parm'}}}
# Kind.FUNC   attach_to_pi_owner
#                      Removed params:
#                                     uaddr: {'kind': 'PTR', 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}
#                                   exiting: {'kind': 'PTR', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'task_struct'}}}
# Kind.FUNC   ip6_pol_route_lookup
#                      Added params:
#                                       skb: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'sk_buff'}}}
# Kind.FUNC   io_err_release_clone_rq
#                      Removed params:
#                               map_context: {'kind': 'PTR', 'type': {'kind': 'UNION', 'name': 'map_info'}}
# Kind.FUNC   __uncore_occ_invert_show
#                      Added params:
#                                      kobj: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kobject'}}
#                      Removed params:
#                                       dev: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device'}}
#                      Param type changed:
#                                      attr: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device_attribute'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kobj_attribute'}}
# Kind.FUNC   rt6_nexthop_info
#                      Param type changed:
#                                        rt: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'rt6_info'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fib6_info'}}
# Kind.FUNC   traceoff_trigger
#                      Added params:
#                                     event: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'ring_buffer_event'}}
# Kind.FUNC   tpm_is_tpm2
#                      Added params:
#                                      chip: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'tpm_chip'}}
#                      Removed params:
#                                  chip_num: {'kind': 'TYPEDEF', 'name': 'u32'}
# Kind.FUNC   pci_epc_map_addr
#                      Added params:
#                                   func_no: {'kind': 'TYPEDEF', 'name': 'u8'}
# Kind.FUNC   klp_shadow_free
#                      Added params:
#                                      dtor: {'kind': 'TYPEDEF', 'name': 'klp_shadow_dtor_t'}
# Kind.FUNC   hpet_poll
#                      Return type changed:
#                                          : {'kind': 'INT', 'name': 'unsigned int'}
#                                          ->{'kind': 'TYPEDEF', 'name': '__poll_t'}
# Kind.FUNC   __do_page_fault
#                      Added params:
#                                error_code: {'kind': 'INT', 'name': 'long unsigned int'}
#                      Removed params:
#                             hw_error_code: {'kind': 'INT', 'name': 'long unsigned int'}
# Kind.FUNC   security_load_policy
#                      Added params:
#                                     state: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'selinux_state'}}
# Kind.FUNC   do_mq_timedsend
#                      Param type changed:
#                                        ts: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}
# Kind.FUNC   unmap_page
#                      Added params:
#                                      size: {'kind': 'TYPEDEF', 'name': 'size_t'}
#                                       dir: {'kind': 'ENUM', 'name': 'dma_data_direction', 'size': 4}
#                                     attrs: {'kind': 'INT', 'name': 'long unsigned int'}
#                                       dev: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device'}}
#                                  dma_addr: {'kind': 'TYPEDEF', 'name': 'dma_addr_t'}
#                      Removed params:
#                                      page: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'page'}}
# Kind.FUNC   __uncore_filter_band2_show
#                      Added params:
#                                      kobj: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kobject'}}
#                      Removed params:
#                                       dev: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device'}}
#                      Param type changed:
#                                      attr: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device_attribute'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kobj_attribute'}}
# Kind.FUNC   __uncore_mask_show
#                      Added params:
#                                      kobj: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kobject'}}
#                      Removed params:
#                                       dev: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device'}}
#                      Param type changed:
#                                      attr: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device_attribute'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kobj_attribute'}}
# Kind.FUNC   __uncore_filter_c6_show
#                      Added params:
#                                      kobj: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kobject'}}
#                      Removed params:
#                                       dev: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device'}}
#                      Param type changed:
#                                      attr: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device_attribute'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kobj_attribute'}}
# Kind.FUNC   __uncore_filter_opc_0_show
#                      Added params:
#                                      kobj: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kobject'}}
#                      Removed params:
#                                       dev: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device'}}
#                      Param type changed:
#                                      attr: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device_attribute'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kobj_attribute'}}
# Kind.FUNC   migrate_page_add
#                      Return type changed:
#                                          : {'kind': 'INT', 'name': 'int'}
#                                          ->{'name': 'void', 'kind': 'VOID'}
# Kind.FUNC   do_timerfd_settime
#                      Param type changed:
#                                       new: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'itimerspec'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'itimerspec64'}}}
#                                       old: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'itimerspec'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'itimerspec64'}}
# Kind.FUNC   proc_map_files_instantiate
#                      Removed params:
#                                       dir: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'inode'}}
#                      Return type changed:
#                                          : {'kind': 'INT', 'name': 'int'}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'dentry'}}
# Kind.FUNC   xhci_endpoint_reset
#                      Added params:
#                                   host_ep: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'usb_host_endpoint'}}
#                      Removed params:
#                                        ep: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'usb_host_endpoint'}}
# Kind.FUNC   ipmr_do_expire_process
#                      Param type changed:
#                                       mrt: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'mr6_table'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'mr_table'}}
# Kind.FUNC   ptype_get_idx
#                      Removed params:
#                                       seq: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'seq_file'}}
# Kind.FUNC   __uncore_xbr_match_show
#                      Added params:
#                                      kobj: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kobject'}}
#                      Removed params:
#                                       dev: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device'}}
#                      Param type changed:
#                                      attr: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device_attribute'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kobj_attribute'}}
# Kind.FUNC   igmp6_group_added
#                      Added params:
#                                      mode: {'kind': 'INT', 'name': 'unsigned int'}
# Kind.FUNC   security_ib_endport_sid
#                      Added params:
#                                     state: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'selinux_state'}}
# Kind.FUNC   sel_mmap_policy_fault
#                      Return type changed:
#                                          : {'kind': 'INT', 'name': 'int'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'vm_fault_t'}
# Kind.FUNC   kvm_get_wallclock
#                      Param type changed:
#                                       now: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}
# Kind.FUNC   ata_bmdma_qc_prep
#                      Return type changed:
#                                          : {'kind': 'ENUM', 'name': 'ata_completion_errors', 'size': 4}
#                                          ->{'name': 'void', 'kind': 'VOID'}
# Kind.FUNC   event_enable_trigger
#                      Added params:
#                                     event: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'ring_buffer_event'}}
# Kind.FUNC   sparse_mem_map_populate
#                      Added params:
#                                    altmap: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'vmem_altmap'}}
# Kind.FUNC   security_shm_shmat
#                      Param type changed:
#                                       shp: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'shmid_kernel'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}
# Kind.FUNC   pciehp_is_native
#                      Added params:
#                                    bridge: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'pci_dev'}}
#                      Removed params:
#                                      pdev: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'pci_dev'}}
# Kind.FUNC   new_page
#                      Removed params:
#                                         x: {'kind': 'PTR', 'type': {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'int'}}}
# Kind.FUNC   xhci_reset
#                      Removed params:
#                                timeout_us: {'kind': 'TYPEDEF', 'name': 'u64'}
# Kind.FUNC   __uncore_filter_nid_show
#                      Added params:
#                                      kobj: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kobject'}}
#                      Removed params:
#                                       dev: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device'}}
#                      Param type changed:
#                                      attr: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device_attribute'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kobj_attribute'}}
# Kind.FUNC   ip_mr_forward
#                      Added params:
#                                         c: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'mfc_cache'}}
#                      Removed params:
#                                     cache: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'mfc_cache'}}
# Kind.FUNC   xfrm_policy_byid
#                      Param type changed:
#                                      mark: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'xfrm_mark'}}}
#                                          ->{'kind': 'TYPEDEF', 'name': 'u32'}
# Kind.FUNC   udp_poll
#                      Return type changed:
#                                          : {'kind': 'INT', 'name': 'unsigned int'}
#                                          ->{'kind': 'TYPEDEF', 'name': '__poll_t'}
# Kind.FUNC   wait_iff_congested
#                      Removed params:
#                                     pgdat: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'pglist_data'}}
# Kind.FUNC   xen_mce_chrdev_poll
#                      Return type changed:
#                                          : {'kind': 'INT', 'name': 'unsigned int'}
#                                          ->{'kind': 'TYPEDEF', 'name': '__poll_t'}
# Kind.FUNC   set_normalized_timespec64
#                      Param type changed:
#                                        ts: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}
# Kind.FUNC   tpm_seal_trusted
#                      Added params:
#                                      chip: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'tpm_chip'}}
#                      Removed params:
#                                  chip_num: {'kind': 'TYPEDEF', 'name': 'u32'}
# Kind.FUNC   rt6_dump_route
#                      Param type changed:
#                                        rt: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'rt6_info'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fib6_info'}}
# Kind.FUNC   nvdimm_setup_pfn
#                      Added params:
#                                     pgmap: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'dev_pagemap'}}
#                      Removed params:
#                                    altmap: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'vmem_altmap'}}
#                                       res: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'resource'}}
#                      Return type changed:
#                                          : {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'vmem_altmap'}}
#                                          ->{'kind': 'INT', 'name': 'int'}
# Kind.FUNC   sk_skb_is_valid_access
#                      Added params:
#                                      prog: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'bpf_prog'}}}
# Kind.FUNC   ip6mr_cache_find_any
#                      Param type changed:
#                                       mrt: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'mr6_table'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'mr_table'}}
# Kind.FUNC   show_num_pstates
#                      Param type changed:
#                                      attr: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kobj_attribute'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'attribute'}}
# Kind.FUNC   proc_readdir_de
#                      Params reordered:
#                                           ['de', 'file', 'ctx']
#                                           ['file', 'ctx', 'de']
# Kind.FUNC   watchdog_core_data_release
#                      Added params:
#                                      kref: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kref'}}
#                      Removed params:
#                                       dev: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device'}}
# Kind.FUNC   __add_pages
#                      Added params:
#                                    altmap: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'vmem_altmap'}}
# Kind.FUNC   __uncore_filter_mask_show
#                      Added params:
#                                      kobj: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kobject'}}
#                      Removed params:
#                                       dev: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device'}}
#                      Param type changed:
#                                      attr: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device_attribute'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kobj_attribute'}}
# Kind.FUNC   dwc2_exit_hibernation
#                      Added params:
#                                rem_wakeup: {'kind': 'INT', 'name': 'int'}
#                                     reset: {'kind': 'INT', 'name': 'int'}
#                                   is_host: {'kind': 'INT', 'name': 'int'}
#                      Removed params:
#                                   restore: {'kind': 'TYPEDEF', 'name': 'bool'}
# Kind.FUNC   qdisc_create_dflt
#                      Added params:
#                                    extack: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'netlink_ext_ack'}}
# Kind.FUNC   add_system_zone
#                      Removed params:
#                                       ino: {'kind': 'TYPEDEF', 'name': 'u32'}
# Kind.FUNC   fill_random_ptr_key
#                      Added params:
#                                    unused: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'random_ready_callback'}}
#                      Removed params:
#                                    action: {'kind': 'INT', 'name': 'long unsigned int'}
#                                      data: {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}
#                                        nb: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'notifier_block'}}
#                      Return type changed:
#                                          : {'kind': 'INT', 'name': 'int'}
#                                          ->{'name': 'void', 'kind': 'VOID'}
# Kind.FUNC   do_timer_gettime
#                      Param type changed:
#                                   setting: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'itimerspec'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'itimerspec64'}}
# Kind.FUNC   __uncore_tid_en_show
#                      Added params:
#                                      kobj: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kobject'}}
#                      Removed params:
#                                       dev: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device'}}
#                      Param type changed:
#                                      attr: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device_attribute'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kobj_attribute'}}
# Kind.FUNC   trace_event_raw_event_mm_vmscan_lru_shrink_inactive
#                      Added params:
#                                      stat: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'reclaim_stat'}}
#                      Removed params:
#                              nr_writeback: {'kind': 'INT', 'name': 'long unsigned int'}
#                                  nr_dirty: {'kind': 'INT', 'name': 'long unsigned int'}
#                              nr_immediate: {'kind': 'INT', 'name': 'long unsigned int'}
#                               nr_activate: {'kind': 'INT', 'name': 'long unsigned int'}
#                              nr_congested: {'kind': 'INT', 'name': 'long unsigned int'}
#                             nr_unmap_fail: {'kind': 'INT', 'name': 'long unsigned int'}
#                               nr_ref_keep: {'kind': 'INT', 'name': 'long unsigned int'}
# Kind.FUNC   unix_poll
#                      Return type changed:
#                                          : {'kind': 'INT', 'name': 'unsigned int'}
#                                          ->{'kind': 'TYPEDEF', 'name': '__poll_t'}
# Kind.FUNC   posix_get_monotonic_raw
#                      Param type changed:
#                                        tp: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}
# Kind.FUNC   current_time
#                      Return type changed:
#                                          : {'kind': 'STRUCT', 'name': 'timespec'}
#                                          ->{'kind': 'STRUCT', 'name': 'timespec64'}
# Kind.FUNC   rt6_score_route
#                      Param type changed:
#                                        rt: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'rt6_info'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fib6_info'}}
# Kind.FUNC   __uncore_filter_opc3_show
#                      Added params:
#                                      kobj: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kobject'}}
#                      Removed params:
#                                       dev: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device'}}
#                      Param type changed:
#                                      attr: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device_attribute'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kobj_attribute'}}
# Kind.FUNC   store_boost
#                      Param type changed:
#                                      attr: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kobj_attribute'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'attribute'}}
# Kind.FUNC   ftrace_trace_userstack
#                      Removed params:
#                                        tr: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'trace_array'}}
# Kind.FUNC   xfrm_policy_bysel_ctx
#                      Param type changed:
#                                      mark: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'xfrm_mark'}}}
#                                          ->{'kind': 'TYPEDEF', 'name': 'u32'}
# Kind.FUNC   security_context_to_sid_default
#                      Added params:
#                                     state: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'selinux_state'}}
# Kind.FUNC   security_validate_transition_user
#                      Added params:
#                                     state: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'selinux_state'}}
# Kind.FUNC   ghes_edac_report_mem_error
#                      Removed params:
#                                      ghes: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'ghes'}}
# Kind.FUNC   tun_chr_poll
#                      Return type changed:
#                                          : {'kind': 'INT', 'name': 'unsigned int'}
#                                          ->{'kind': 'TYPEDEF', 'name': '__poll_t'}
# Kind.FUNC   shm_fault
#                      Return type changed:
#                                          : {'kind': 'INT', 'name': 'int'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'vm_fault_t'}
# Kind.FUNC   arch_kexec_apply_relocations_add
#                      Added params:
#                                        pi: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'purgatory_info'}}
#                                 symtabsec: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'Elf64_Shdr'}}}
#                                   section: {'kind': 'PTR', 'type': {'kind': 'TYPEDEF', 'name': 'Elf64_Shdr'}}
#                      Removed params:
#                                   sechdrs: {'kind': 'PTR', 'type': {'kind': 'TYPEDEF', 'name': 'Elf64_Shdr'}}
#                                      ehdr: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'Elf64_Ehdr'}}}
#                      Param type changed:
#                                    relsec: {'kind': 'INT', 'name': 'unsigned int'}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'Elf64_Shdr'}}}
# Kind.FUNC   tcp_rack_mark_lost
#                      Return type changed:
#                                          : {'kind': 'TYPEDEF', 'name': 'bool'}
#                                          ->{'name': 'void', 'kind': 'VOID'}
# Kind.FUNC   do_settimeofday64
#                      Param type changed:
#                                        ts: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}}
# Kind.FUNC   security_task_kill
#                      Added params:
#                                      cred: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'cred'}}}
#                      Removed params:
#                                     secid: {'kind': 'TYPEDEF', 'name': 'u32'}
# Kind.FUNC   __uncore_match_dnid_show
#                      Added params:
#                                      kobj: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kobject'}}
#                      Removed params:
#                                       dev: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device'}}
#                      Param type changed:
#                                      attr: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device_attribute'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kobj_attribute'}}
# Kind.FUNC   __synchronize_hardirq
#                      Removed params:
#                                 sync_chip: {'kind': 'TYPEDEF', 'name': 'bool'}
# Kind.FUNC   ip6_route_mpath_notify
#                      Param type changed:
#                                   rt_last: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'rt6_info'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fib6_info'}}
#                                        rt: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'rt6_info'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fib6_info'}}
# Kind.FUNC   rt6_multipath_hash
#                      Added params:
# ...
# Kind.FUNC   selinux_shm_shmat
#                      Param type changed:
#                                       shp: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'shmid_kernel'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}
# Kind.FUNC   __uncore_filter_state3_show
#                      Added params:
#                                      kobj: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kobject'}}
#                      Removed params:
#                                       dev: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device'}}
#                      Param type changed:
#                                      attr: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device_attribute'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kobj_attribute'}}
# Kind.FUNC   __reserve_bp_slot
#                      Added params:
#                                   bp_type: {'kind': 'TYPEDEF', 'name': 'u64'}
# Kind.FUNC   do_sys_poll
#                      Param type changed:
#                                  end_time: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}
# Kind.FUNC   store_status
#                      Added params:
#                                    status: {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'int'}}
#                                        nr: {'kind': 'INT', 'name': 'int'}
#                                     start: {'kind': 'INT', 'name': 'int'}
#                                     value: {'kind': 'INT', 'name': 'int'}
#                      Removed params:
#                                       buf: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'INT', 'name': 'char'}}}
#                                         b: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kobj_attribute'}}
#                                     count: {'kind': 'TYPEDEF', 'name': 'size_t'}
#                                         a: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kobject'}}
#                      Return type changed:
#                                          : {'kind': 'TYPEDEF', 'name': 'ssize_t'}
#                                          ->{'kind': 'INT', 'name': 'int'}
# Kind.FUNC   smack_msg_queue_msgrcv
#                      Added params:
#                                       isp: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}
#                      Removed params:
#                                       msq: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'msg_queue'}}
# Kind.FUNC   security_node_sid
#                      Added params:
#                                     state: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'selinux_state'}}
# Kind.FUNC   rt_mutex_proxy_unlock
#                      Added params:
#                               proxy_owner: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'task_struct'}}
# Kind.FUNC   inotify_handle_event
#                      Removed params:
#                             vfsmount_mark: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fsnotify_mark'}}
#                                inode_mark: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fsnotify_mark'}}
# Kind.FUNC   pagevec_lookup_entries
#                      Added params:
#                                nr_entries: {'kind': 'INT', 'name': 'unsigned int'}
#                      Removed params:
#                                  nr_pages: {'kind': 'INT', 'name': 'unsigned int'}
# Kind.FUNC   selinux_sem_semctl
#                      Param type changed:
#                                       sma: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sem_array'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}
# Kind.FUNC   hist_field_u8
#                      Added params:
#                                       elt: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'tracing_map_elt'}}
#                                       rbe: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'ring_buffer_event'}}
# Kind.FUNC   __uncore_filter_link2_show
#                      Added params:
#                                      kobj: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kobject'}}
#                      Removed params:
#                                       dev: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device'}}
#                      Param type changed:
#                                      attr: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device_attribute'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kobj_attribute'}}
# Kind.FUNC   show_lowest_nonlinear_perf
#                      Param type changed:
#                                      attr: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kobj_attribute'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'attribute'}}
# Kind.FUNC   security_get_reject_unknown
#                      Added params:
#                                     state: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'selinux_state'}}
# Kind.FUNC   cpu_matches
#                      Removed params:
#                                     table: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'x86_cpu_id'}}}
# Kind.FUNC   smack_msg_queue_msgsnd
#                      Added params:
#                                       isp: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}
#                      Removed params:
#                                       msq: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'msg_queue'}}
# Kind.FUNC   __uncore_match_mc_show
#                      Added params:
#                                      kobj: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kobject'}}
#                      Removed params:
#                                       dev: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device'}}
#                      Param type changed:
#                                      attr: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device_attribute'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kobj_attribute'}}
# Kind.FUNC   arch_remove_memory
#                      Added params:
#                                    altmap: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'vmem_altmap'}}
# Kind.FUNC   compute_sid_handle_invalid_context
#                      Added params:
#                                     state: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'selinux_state'}}
# Kind.FUNC   selinux_msg_queue_alloc_security
#                      Param type changed:
#                                       msq: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'msg_queue'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}
# Kind.FUNC   ata_host_release
#                      Added params:
#                                      kref: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kref'}}
#                      Removed params:
#                                       res: {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}
#                                    gendev: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device'}}
# Kind.FUNC   tcf_block_get
#                      Added params:
#                                    extack: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'netlink_ext_ack'}}
# Kind.FUNC   scsi_dev_info_list_del_keyed
#                      Param type changed:
#                                       key: {'kind': 'INT', 'name': 'int'}
#                                          ->{'kind': 'ENUM', 'name': 'scsi_devinfo_key', 'size': 4}
# Kind.FUNC   proc_register
#                      Return type changed:
#                                          : {'kind': 'INT', 'name': 'int'}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'proc_dir_entry'}}
# Kind.FUNC   kvm_set_wallclock
#                      Param type changed:
#                                       now: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}}
# Kind.FUNC   mls_setup_user_range
#                      Added params:
#                                         p: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'policydb'}}
# Kind.FUNC   nohz_balance_exit_idle
#                      Added params:
#                                        rq: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'rq'}}
#                      Removed params:
#                                       cpu: {'kind': 'INT', 'name': 'unsigned int'}
# Kind.FUNC   init_memory_block
#                      Added params:
#                                   section: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'mem_section'}}
#                      Removed params:
#                                  block_id: {'kind': 'INT', 'name': 'int'}
# Kind.FUNC   shrink_slab
#                      Added params:
#                                  priority: {'kind': 'INT', 'name': 'int'}
#                      Removed params:
#                               nr_eligible: {'kind': 'INT', 'name': 'long unsigned int'}
#                                nr_scanned: {'kind': 'INT', 'name': 'long unsigned int'}
# Kind.FUNC   vga_arb_fpoll
#                      Return type changed:
#                                          : {'kind': 'INT', 'name': 'unsigned int'}
#                                          ->{'kind': 'TYPEDEF', 'name': '__poll_t'}
# Kind.FUNC   create_boot_cache
#                      Added params:
#                                  usersize: {'kind': 'INT', 'name': 'unsigned int'}
#                                useroffset: {'kind': 'INT', 'name': 'unsigned int'}
#                      Param type changed:
#                                      size: {'kind': 'TYPEDEF', 'name': 'size_t'}
#                                          ->{'kind': 'INT', 'name': 'unsigned int'}
# Kind.FUNC   security_bounded_transition
#                      Added params:
#                                     state: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'selinux_state'}}
# Kind.FUNC   squashfs_read_xattr_id_table
#                      Added params:
#                                     start: {'kind': 'TYPEDEF', 'name': 'u64'}
#                      Removed params:
#                               table_start: {'kind': 'TYPEDEF', 'name': 'u64'}
#                      Param type changed:
#                                 xattr_ids: {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'unsigned int'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'int'}}
# Kind.FUNC   rt6_fill_node
#                      Added params:
#                                      dest: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'in6_addr'}}
#                      Param type changed:
#                                        rt: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'rt6_info'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fib6_info'}}
#                                       dst: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'in6_addr'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'dst_entry'}}
# Kind.FUNC   __map_bio
#                      Return type changed:
#                                          : {'name': 'void', 'kind': 'VOID'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'blk_qc_t'}
# Kind.FUNC   __uncore_match_opc_show
#                      Added params:
#                                      kobj: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kobject'}}
#                      Removed params:
#                                       dev: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device'}}
#                      Param type changed:
#                                      attr: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device_attribute'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kobj_attribute'}}
# Kind.FUNC   noqueue_init
#                      Added params:
#                                    extack: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'netlink_ext_ack'}}
# Kind.FUNC   __dev_map_lookup_elem
#                      Return type changed:
#                                          : {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'net_device'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'bpf_dtab_netdev'}}
# Kind.FUNC   rt6_find_cached_rt
#                      Param type changed:
#                                        rt: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'rt6_info'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fib6_info'}}
# Kind.FUNC   gen_pool_first_fit_align
#                      Removed params:
#                                start_addr: {'kind': 'INT', 'name': 'long unsigned int'}
# Kind.FUNC   ip_rt_ioctl
#                      Added params:
#                                        rt: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'rtentry'}}
#                      Removed params:
#                                       arg: {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}
# Kind.FUNC   hist_field_s16
#                      Added params:
#                                       elt: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'tracing_map_elt'}}
#                                       rbe: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'ring_buffer_event'}}
# Kind.FUNC   __uncore_dsp_show
#                      Added params:
#                                      kobj: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kobject'}}
#                      Removed params:
#                                       dev: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device'}}
#                      Param type changed:
#                                      attr: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device_attribute'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kobj_attribute'}}
# Kind.FUNC   selinux_shm_alloc_security
#                      Param type changed:
#                                       shp: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'shmid_kernel'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}
# Kind.FUNC   security_load_policycaps
#                      Added params:
#                                     state: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'selinux_state'}}
# Kind.FUNC   crng_reseed
#                      Added params:
#                                      crng: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'crng_state'}}
#                                         r: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'entropy_store'}}
# Kind.FUNC   proc_reg_poll
#                      Return type changed:
#                                          : {'kind': 'INT', 'name': 'unsigned int'}
#                                          ->{'kind': 'TYPEDEF', 'name': '__poll_t'}
# Kind.FUNC   avc_policy_seqno
#                      Added params:
#                                     state: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'selinux_state'}}
# Kind.FUNC   zap_vma_ptes
#                      Return type changed:
#                                          : {'kind': 'INT', 'name': 'int'}
#                                          ->{'name': 'void', 'kind': 'VOID'}

# %%
def diff_enum(old, new):
    result = ""

    old_values = {v['name']: v for v in old['values']}
    new_values = {v['name']: v for v in new['values']}

    # added value
    added_values = new_values.keys() - old_values.keys()
    if added_values:
        result += f"Added values:\n"
        for name in added_values:
            result += f"{'':8}{name:40}: {new_values[name]['val']}\n"

    # removed value
    removed_values = old_values.keys() - new_values.keys()
    if removed_values:
        result += f"Removed values:\n"
        for name in removed_values:
            result += f"{'':8}{name:40}: {old_values[name]['val']}\n"

    # values changed
    common = old_values.keys() & new_values.keys()
    changed_values = {
        name: (old_values[name]['val'], new_values[name]['val'])
        for name in common
        if old_values[name]['val'] != new_values[name]['val']
    }
    if changed_values:
        result += "Value changed:\n"
        for name, (old_val, new_val) in changed_values.items():
            result += f"{'':8}{name:40}: {old_val} -> {new_val}\n"

    assert result, f"\n{old}\n{new}"

    return result


check_diff(d1, d2, Kind.ENUM, diff_enum)
# Out:
# Old Kind.ENUM (979): ['system_states', 'timespec_type', 'x86_hardware_subarch', 'l1tf_mitigations', 'x86_legacy_i8042_state', 'xen_domain_type', 'fixed_addresses', 'apic_intr_mode_id', 'pcpu_fc', 'numa_stat_item']
# New Kind.ENUM (1015): ['system_states', 'timespec_type', 'x86_hardware_subarch', 'l1tf_mitigations', 'x86_legacy_i8042_state', 'xen_domain_type', 'fixed_addresses', 'apic_intr_mode_id', 'pcpu_fc', 'numa_stat_item']
# Removed Kind.ENUM (25): ['move_type', 'nd_ioctl_mode', 'rq_atomic_flags', 'mmio_mitigations', 'perf_event_sample_format', 'blake2s_iv', 'retbleed_mitigation', 'blake2s_lengths', 'rpc_display_format_t', 'ip_conntrack_status']
# Added Kind.ENUM (61): ['rseq_cpu_id_state', 'sctp_event_timeout', 'netdev_cmd', 'rdma_restrack_type', 'perf_probe_config', 'userfaultfd_state', 'ptp_clock_events', 'hmm_pfn_value_e', 'err_types', 'mem_cgroup_protection']
# Common Kind.ENUM (954): ['audit_nlgrps', 'tg_state_flags', 'devkmsg_log_bits', 'cgroup_filetype', 'tcp_queue', 'ib_sig_type', 'ec_led_colors', 'req_opf', 'actions', 'tomoyo_memory_stat_type']
# Changed Kind.ENUM (81): ['wbt_flags', 'cppc_regs', 'sysctl_writes_mode', 'of_gpio_flags', 'mf_action_page_type', 'netdev_priv_flags', 'blkif_state', 'bpf_map_type', 'tpm_timeout', 'dmi_device_type']
# Kind.ENUM   wbt_flags
#                      Added values:
#                              WBT_DISCARD                             : 8
#                      Value changed:
#                              WBT_NR_BITS                             : 3 -> 4
# Kind.ENUM   cppc_regs
#                      Added values:
#                              LOWEST_FREQ                             : 19
#                              NOMINAL_FREQ                            : 20
# Kind.ENUM   sysctl_writes_mode
#                      Value changed:
#                              SYSCTL_WRITES_LEGACY                    : 18446744073709551615 -> -1
# Kind.ENUM   of_gpio_flags
#                      Added values:
#                              OF_GPIO_TRANSITORY                      : 8
#                      Removed values:
#                              OF_GPIO_SLEEP_MAY_LOSE_VALUE            : 8
# Kind.ENUM   mf_action_page_type
#                      Added values:
#                              MF_MSG_DAX                              : 20
#                      Value changed:
#                              MF_MSG_UNKNOWN                          : 20 -> 21
# Kind.ENUM   netdev_priv_flags
#                      Added values:
#                              IFF_NO_RX_HANDLER                       : 67108864
#                              IFF_FAILOVER_SLAVE                      : 268435456
#                              IFF_FAILOVER                            : 134217728
#                      Removed values:
#                              IFF_IPVLAN_MASTER                       : 262144
#                              IFF_L3MDEV_RX_HANDLER                   : 268435456
#                              IFF_IPVLAN_SLAVE                        : 524288
#                      Value changed:
#                              IFF_MACSEC                              : 134217728 -> 33554432
#                              IFF_TEAM                                : 16777216 -> 4194304
#                              IFF_OPENVSWITCH                         : 4194304 -> 1048576
#                              IFF_NO_QUEUE                            : 2097152 -> 524288
#                              IFF_PHONY_HEADROOM                      : 67108864 -> 16777216
#                              IFF_RXFH_CONFIGURED                     : 33554432 -> 8388608
#                              IFF_L3MDEV_MASTER                       : 1048576 -> 262144
#                              IFF_L3MDEV_SLAVE                        : 8388608 -> 2097152
# Kind.ENUM   blkif_state
#                      Removed values:
#                              BLKIF_STATE_ERROR                       : 3
# Kind.ENUM   bpf_map_type
#                      Added values:
#                              BPF_MAP_TYPE_XSKMAP                     : 17
#                              BPF_MAP_TYPE_SOCKHASH                   : 18
# Kind.ENUM   tpm_timeout
#                      Added values:
#                              TPM_TIMEOUT_USECS_MIN                   : 100
#                              TPM_TIMEOUT_USECS_MAX                   : 500
#                              TPM_TIMEOUT_POLL                        : 1
# Kind.ENUM   dmi_device_type
#                      Value changed:
#                              DMI_DEV_TYPE_DEV_ONBOARD                : 18446744073709551613 -> -3
#                              DMI_DEV_TYPE_DEV_SLOT                   : 18446744073709551612 -> -4
#                              DMI_DEV_TYPE_IPMI                       : 18446744073709551615 -> -1
#                              DMI_DEV_TYPE_OEM_STRING                 : 18446744073709551614 -> -2
# Kind.ENUM   rt6_nud_state
#                      Value changed:
#                              RT6_NUD_FAIL_PROBE                      : 18446744073709551614 -> -2
#                              RT6_NUD_FAIL_HARD                       : 18446744073709551613 -> -3
#                              RT6_NUD_FAIL_DO_RR                      : 18446744073709551615 -> -1
# Kind.ENUM   dm_queue_mode
#                      Added values:
#                              DM_TYPE_NVME_BIO_BASED                  : 5
# Kind.ENUM   cpuid_leafs
#                      Added values:
#                              CPUID_F_0_EDX                           : 11
#                              CPUID_F_1_EDX                           : 12
#                      Removed values:
#                              CPUID_DUMMY                             : 12
#                              CPUID_LNX_4                             : 11
# Kind.ENUM   blk_req_status
#                      Removed values:
#                              REQ_PROCESSING                          : 0
#                      Value changed:
#                              REQ_DONE                                : 2 -> 1
#                              REQ_EOPNOTSUPP                          : 4 -> 3
#                              REQ_ERROR                               : 3 -> 2
#                              REQ_WAITING                             : 1 -> 0
# Kind.ENUM   tc_setup_type
#                      Added values:
#                              TC_SETUP_QDISC_PRIO                     : 8
#                              TC_SETUP_QDISC_MQ                       : 9
# Kind.ENUM   bpf_cmd
#                      Added values:
#                              BPF_BTF_GET_FD_BY_ID                    : 19
#                              BPF_TASK_FD_QUERY                       : 20
#                              BPF_BTF_LOAD                            : 18
#                              BPF_RAW_TRACEPOINT_OPEN                 : 17
# Kind.ENUM   memcg_memory_event
#                      Added values:
#                              MEMCG_SWAP_MAX                          : 5
#                              MEMCG_SWAP_FAIL                         : 6
#                      Value changed:
#                              MEMCG_NR_MEMORY_EVENTS                  : 5 -> 7
# Kind.ENUM   phy_mode
#                      Added values:
#                              PHY_MODE_USB_HOST_LS                    : 2
#                              PHY_MODE_USB_DEVICE_HS                  : 9
#                              PHY_MODE_2500SGMII                      : 13
#                              PHY_MODE_USB_DEVICE_LS                  : 7
#                              PHY_MODE_USB_DEVICE_FS                  : 8
#                              PHY_MODE_USB_DEVICE_SS                  : 10
#                              PHY_MODE_USB_HOST_FS                    : 3
#                              PHY_MODE_USB_HOST_HS                    : 4
#                              PHY_MODE_USB_HOST_SS                    : 5
#                      Value changed:
#                              PHY_MODE_10GKR                          : 5 -> 14
#                              PHY_MODE_USB_DEVICE                     : 2 -> 6
#                              PHY_MODE_UFS_HS_A                       : 6 -> 15
#                              PHY_MODE_USB_OTG                        : 3 -> 11
#                              PHY_MODE_UFS_HS_B                       : 7 -> 16
#                              PHY_MODE_SGMII                          : 4 -> 12
# Kind.ENUM   pm_qos_flags_status
#                      Value changed:
#                              PM_QOS_FLAGS_UNDEFINED                  : 18446744073709551615 -> -1
# Kind.ENUM   siginfo_layout
#                      Added values:
#                              SIL_FAULT_PKUERR                        : 6
#                              SIL_FAULT_BNDERR                        : 5
#                              SIL_FAULT_MCEERR                        : 4
#                      Value changed:
#                              SIL_RT                                  : 5 -> 8
#                              SIL_CHLD                                : 4 -> 7
#                              SIL_SYS                                 : 6 -> 9
# Kind.ENUM   nf_ip_hook_priorities
#                      Added values:
#                              NF_IP_PRI_RAW_BEFORE_DEFRAG             : -450
#                      Value changed:
#                              NF_IP_PRI_CONNTRACK_DEFRAG              : 18446744073709551216 -> -400
#                              NF_IP_PRI_CONNTRACK                     : 18446744073709551416 -> -200
#                              NF_IP_PRI_FIRST                         : 18446744071562067968 -> -2147483648
#                              NF_IP_PRI_MANGLE                        : 18446744073709551466 -> -150
#                              NF_IP_PRI_NAT_DST                       : 18446744073709551516 -> -100
#                              NF_IP_PRI_RAW                           : 18446744073709551316 -> -300
#                              NF_IP_PRI_SELINUX_FIRST                 : 18446744073709551391 -> -225
# Kind.ENUM   hk_flags
#                      Added values:
#                              HK_FLAG_WQ                              : 64
# Kind.ENUM   enable_type
#                      Value changed:
#                              undefined                               : 18446744073709551615 -> -1
# Kind.ENUM   pci_board_num_t
#                      Added values:
#                              pbn_endrun_2_4000000                    : 71
#                      Removed values:
#                              pbn_sunix_pci_16s                       : 109
#                              pbn_sunix_pci_8s                        : 108
#                              pbn_sunix_pci_1s                        : 105
#                              pbn_sunix_pci_4s                        : 107
#                              pbn_endrun_2_3906250                    : 71
#                              pbn_sunix_pci_2s                        : 106
# Kind.ENUM   bpf_func_id
#                      Added values:
#                              BPF_FUNC_get_stack                      : 67
#                              BPF_FUNC_sk_redirect_hash               : 72
#                              BPF_FUNC_lwt_push_encap                 : 73
#                              BPF_FUNC_msg_apply_bytes                : 61
#                              BPF_FUNC_msg_redirect_hash              : 71
#                              BPF_FUNC_sock_ops_cb_flags_set          : 59
#                              BPF_FUNC_override_return                : 58
#                              BPF_FUNC_skb_get_xfrm_state             : 66
#                              BPF_FUNC_lwt_seg6_adjust_srh            : 75
#                              BPF_FUNC_msg_redirect_map               : 60
#                              BPF_FUNC_get_current_cgroup_id          : 80
#                              BPF_FUNC_xdp_adjust_tail                : 65
#                              BPF_FUNC_msg_pull_data                  : 63
#                              BPF_FUNC_sock_hash_update               : 70
#                              BPF_FUNC_lwt_seg6_store_bytes           : 74
#                              BPF_FUNC_rc_keydown                     : 78
#                              BPF_FUNC_bind                           : 64
#                              BPF_FUNC_skb_load_bytes_relative        : 68
#                              BPF_FUNC_msg_cork_bytes                 : 62
#                              BPF_FUNC_lwt_seg6_action                : 76
#                              BPF_FUNC_skb_cgroup_id                  : 79
#                              BPF_FUNC_rc_repeat                      : 77
#                              BPF_FUNC_fib_lookup                     : 69
#                      Value changed:
#                              __BPF_FUNC_MAX_ID                       : 58 -> 81
# Kind.ENUM   gpio_lookup_flags
#                      Added values:
#                              GPIO_PERSISTENT                         : 0
#                              GPIO_TRANSITORY                         : 8
#                      Removed values:
#                              GPIO_SLEEP_MAINTAIN_VALUE               : 0
#                              GPIO_SLEEP_MAY_LOSE_VALUE               : 8
# Kind.ENUM   spectre_v2_mitigation
#                      Added values:
#                              SPECTRE_V2_IBRS_ENHANCED                : 3
#                              SPECTRE_V2_RETPOLINE_AMD                : 2
#                              SPECTRE_V2_RETPOLINE_GENERIC            : 1
#                      Removed values:
#                              SPECTRE_V2_EIBRS_RETPOLINE              : 4
#                              SPECTRE_V2_EIBRS                        : 3
#                              SPECTRE_V2_LFENCE                       : 2
#                              SPECTRE_V2_EIBRS_LFENCE                 : 5
#                              SPECTRE_V2_RETPOLINE                    : 1
#                              SPECTRE_V2_IBRS                         : 6
# Kind.ENUM   HV_GENERIC_SET_FORMAT
#                      Added values:
#                              HV_GENERIC_SET_SPARSE_4K                : 0
#                      Removed values:
#                              HV_GENERIC_SET_SPARCE_4K                : 0
# Kind.ENUM   nl80211_ext_feature_index
#                      Added values:
#                              NL80211_EXT_FEATURE_DFS_OFFLOAD         : 25
#                              NL80211_EXT_FEATURE_TXQS                : 28
#                              NL80211_EXT_FEATURE_LOW_SPAN_SCAN       : 22
#                              NL80211_EXT_FEATURE_LOW_POWER_SCAN      : 23
#                              NL80211_EXT_FEATURE_CONTROL_PORT_OVER_NL80211: 26
#                              NL80211_EXT_FEATURE_DATA_ACK_SIGNAL_SUPPORT: 27
#                              NL80211_EXT_FEATURE_HIGH_ACCURACY_SCAN  : 24
#                      Value changed:
#                              NUM_NL80211_EXT_FEATURES                : 22 -> 29
#                              MAX_NL80211_EXT_FEATURES                : 21 -> 28
# Kind.ENUM   system_states
#                      Added values:
#                              SYSTEM_SUSPEND                          : 6
# Kind.ENUM   membarrier_cmd
#                      Added values:
#                              MEMBARRIER_CMD_GLOBAL                   : 1
#                              MEMBARRIER_CMD_REGISTER_PRIVATE_EXPEDITED_SYNC_CORE: 64
#                              MEMBARRIER_CMD_GLOBAL_EXPEDITED         : 2
#                              MEMBARRIER_CMD_PRIVATE_EXPEDITED_SYNC_CORE: 32
#                              MEMBARRIER_CMD_REGISTER_GLOBAL_EXPEDITED: 4
# Kind.ENUM   hist_field_flags
#                      Added values:
#                              HIST_FIELD_FL_TIMESTAMP                 : 1024
#                              HIST_FIELD_FL_ALIAS                     : 65536
#                              HIST_FIELD_FL_VAR_REF                   : 16384
#                              HIST_FIELD_FL_EXPR                      : 8192
#                              HIST_FIELD_FL_CPU                       : 32768
#                              HIST_FIELD_FL_TIMESTAMP_USECS           : 2048
#                              HIST_FIELD_FL_VAR                       : 4096
# Kind.ENUM   tunable_id
#                      Added values:
#                              ETHTOOL_PFC_PREVENTION_TOUT             : 3
#                      Value changed:
#                              __ETHTOOL_TUNABLE_COUNT                 : 3 -> 4
# Kind.ENUM   recovery_flags
#                      Added values:
#                              MD_RECOVERY_WAIT                        : 11
# Kind.ENUM   ib_qp_type
#                      Added values:
#                              IB_QPT_DRIVER                           : 255
# Kind.ENUM   ctx_state
#                      Value changed:
#                              CONTEXT_DISABLED                        : 18446744073709551615 -> -1
# Kind.ENUM   evtreturn
#                      Value changed:
#                              EVT_ERR                                 : 18446744073709551615 -> -1
# Kind.ENUM   device_link_state
#                      Value changed:
#                              DL_STATE_NONE                           : 18446744073709551615 -> -1
# Kind.ENUM   cpuhp_state
#                      Added values:
#                              CPUHP_AP_ARM_CACHE_B15_RAC_DEAD         : 34
#                              CPUHP_AP_ARM_CACHE_B15_RAC_DYING        : 130
#                      Removed values:
#                              CPUHP_PERF_BFIN                         : 5
#                              CPUHP_AP_METAG_TIMER_STARTING           : 119
#                              CPUHP_AP_BASE_CACHEINFO_ONLINE          : 166
#                              CPUHP_RANDOM_PREPARE                    : 36
#                              CPUHP_AP_RANDOM_ONLINE                  : 164
#                              CPUHP_AP_PERF_METAG_STARTING            : 105
#                              CPUHP_AP_MICROCODE_LOADER               : 98
#                              CPUHP_PADATA_DEAD                       : 35
#                      Value changed:
#                              CPUHP_POWERPC_PMAC_PREPARE              : 48 -> 46
#                              CPUHP_AP_QCOM_TIMER_STARTING            : 120 -> 115
#                              CPUHP_AP_PERF_ARM_HISI_HHA_ONLINE       : 154 -> 150
#                              CPUHP_AP_PERF_X86_UNCORE_ONLINE         : 143 -> 139
#                              CPUHP_AP_PERF_X86_STARTING              : 100 -> 97
#                              CPUHP_AP_PERF_S390_SF_ONLINE            : 150 -> 146
#                              CPUHP_AP_IRQ_HIP04_STARTING             : 93 -> 91
#                              CPUHP_PERF_SUPERH                       : 7 -> 6
#                              CPUHP_BLK_MQ_DEAD                       : 24 -> 23
#                              CPUHP_AP_ARM_SDEI_STARTING              : 107 -> 103
#                              CPUHP_X2APIC_PREPARE                    : 41 -> 39
#                              CPUHP_AP_PERF_X86_CSTATE_STARTING       : 103 -> 100
#                              CPUHP_AP_PERF_ARM_STARTING              : 112 -> 108
#                              CPUHP_AP_PERF_POWERPC_CORE_IMC_ONLINE   : 161 -> 157
#                              CPUHP_X86_MCE_DEAD                      : 10 -> 9
#                              CPUHP_AP_ARM_ARCH_TIMER_STARTING        : 115 -> 110
#                              CPUHP_AP_PERF_ARM_QCOM_L3_ONLINE        : 158 -> 154
#                              CPUHP_AP_PERF_POWERPC_NEST_IMC_ONLINE   : 160 -> 156
#                              CPUHP_AP_PERF_X86_ONLINE                : 142 -> 138
#                              CPUHP_PERF_POWER                        : 6 -> 5
#                              CPUHP_AP_OFFLINE                        : 89 -> 87
#                              CPUHP_NET_MVNETA_DEAD                   : 16 -> 15
#                              CPUHP_KVM_PPC_BOOK3S_PREPARE            : 62 -> 60
#                              CPUHP_AP_PERF_X86_RAPL_ONLINE           : 146 -> 142
#                              CPUHP_AP_PERF_ARM_HW_BREAKPOINT_STARTING: 110 -> 106
#                              CPUHP_ARM_BL_PREPARE                    : 57 -> 55
#                              CPUHP_S390_PFAULT_DEAD                  : 23 -> 22
#                              CPUHP_AP_SCHED_STARTING                 : 90 -> 88
#                              CPUHP_AP_ARM_MVEBU_COHERENCY            : 97 -> 95
#                              CPUHP_AP_PERF_X86_CQM_ONLINE            : 147 -> 143
#                              CPUHP_SH_SH3X_PREPARE                   : 53 -> 51
#                              CPUHP_LUSTRE_CFS_DEAD                   : 34 -> 33
#                              CPUHP_X86_APB_DEAD                      : 9 -> 8
#                              CPUHP_MM_ZSWP_POOL_PREPARE              : 61 -> 59
#                              CPUHP_AP_ARM_GLOBAL_TIMER_STARTING      : 116 -> 111
#                              CPUHP_AP_PERF_ARM_L2X0_ONLINE           : 156 -> 152
#                              CPUHP_VIRT_NET_DEAD                     : 11 -> 10
#                              CPUHP_AP_JCORE_TIMER_STARTING           : 117 -> 112
#                              CPUHP_AP_ARM_TWD_STARTING               : 118 -> 114
#                              CPUHP_SLAB_PREPARE                      : 44 -> 42
#                              CPUHP_AP_ARM_XEN_STARTING               : 130 -> 125
#                              CPUHP_BP_PREPARE_DYN_END                : 86 -> 84
#                              CPUHP_AP_ARM_CORESIGHT_STARTING         : 131 -> 126
#                              CPUHP_WORKQUEUE_PREP                    : 37 -> 35
#                              CPUHP_AP_PERF_ONLINE                    : 141 -> 137
#                              CPUHP_AP_X86_TBOOT_DYING                : 134 -> 129
#                              CPUHP_FS_BUFF_DEAD                      : 25 -> 24
#                              CPUHP_AP_IRQ_GIC_STARTING               : 92 -> 90
#                              CPUHP_ACPI_CPUDRV_DEAD                  : 22 -> 21
#                              CPUHP_RADIX_DEAD                        : 29 -> 28
#                              CPUHP_AP_ONLINE                         : 135 -> 131
#                              CPUHP_TEARDOWN_CPU                      : 136 -> 132
#                              CPUHP_AP_ARM64_ISNDEP_STARTING          : 132 -> 127
#                              CPUHP_AP_ARMADA_TIMER_STARTING          : 121 -> 116
#                              CPUHP_RCUTREE_PREP                      : 46 -> 44
#                              CPUHP_AP_PERF_ARM_HISI_L3_ONLINE        : 155 -> 151
#                              CPUHP_AP_PERF_X86_CSTATE_ONLINE         : 148 -> 144
#                              CPUHP_AP_ARM_VFP_STARTING               : 108 -> 104
#                              CPUHP_MM_ZS_PREPARE                     : 59 -> 57
#                              CPUHP_AP_PERF_X86_AMD_POWER_ONLINE      : 145 -> 141
#                              CPUHP_XEN_PREPARE                       : 50 -> 48
#                              CPUHP_MM_ZSWP_MEM_PREPARE               : 60 -> 58
#                              CPUHP_AP_IRQ_MIPS_GIC_STARTING          : 96 -> 94
#                              CPUHP_HRTIMERS_PREPARE                  : 39 -> 37
#                              CPUHP_MM_VMSTAT_DEAD                    : 14 -> 13
#                              CPUHP_ZCOMP_PREPARE                     : 63 -> 61
#                              CPUHP_AP_X86_KVM_CLK_ONLINE             : 199 -> 193
#                              CPUHP_POWER_NUMA_PREPARE                : 38 -> 36
#                              CPUHP_AP_KVM_ARM_VGIC_STARTING          : 127 -> 122
#                              CPUHP_AP_X86_HPET_ONLINE                : 198 -> 192
#                              CPUHP_NET_FLOW_PREPARE                  : 54 -> 52
#                              CPUHP_NET_DEV_DEAD                      : 31 -> 30
#                              CPUHP_AP_IRQ_BCM2836_STARTING           : 95 -> 93
#                              CPUHP_TOPOLOGY_PREPARE                  : 55 -> 53
#                              CPUHP_AP_KVM_STARTING                   : 125 -> 120
#                              CPUHP_SMPCFD_PREPARE                    : 42 -> 40
#                              CPUHP_MIPS_SOC_PREPARE                  : 65 -> 63
#                              CPUHP_AP_MIPS_GIC_TIMER_STARTING        : 123 -> 118
#                              CPUHP_AP_DUMMY_TIMER_STARTING           : 129 -> 124
#                              CPUHP_AP_RCUTREE_DYING                  : 91 -> 89
#                              CPUHP_AP_PERF_ARM_CCN_ONLINE            : 152 -> 148
#                              CPUHP_XEN_EVTCHN_PREPARE                : 51 -> 49
#                              CPUHP_AP_SMPBOOT_THREADS                : 138 -> 134
#                              CPUHP_AP_PERF_S390_CF_ONLINE            : 149 -> 145
#                              CPUHP_AP_PERF_X86_AMD_IBS_STARTING      : 101 -> 98
#                              CPUHP_TRACE_RB_PREPARE                  : 58 -> 56
#                              CPUHP_AP_ONLINE_DYN                     : 167 -> 161
#                              CPUHP_POWERPC_MMU_CTX_PREPARE           : 49 -> 47
#                              CPUHP_AP_ONLINE_DYN_END                 : 197 -> 191
#                              CPUHP_AP_PERF_ARM_HISI_DDRC_ONLINE      : 153 -> 149
#                              CPUHP_AP_IRQ_ARMADA_XP_STARTING         : 94 -> 92
#                              CPUHP_IOMMU_INTEL_DEAD                  : 33 -> 32
#                              CPUHP_PCI_XGENE_DEAD                    : 32 -> 31
#                              CPUHP_PERCPU_CNT_DEAD                   : 28 -> 27
#                              CPUHP_AP_PERF_X86_AMD_UNCORE_STARTING   : 99 -> 96
#                              CPUHP_RELAY_PREPARE                     : 43 -> 41
#                              CPUHP_PRINTK_DEAD                       : 26 -> 25
#                              CPUHP_AP_PERF_X86_CQM_STARTING          : 102 -> 99
#                              CPUHP_AP_EXYNOS4_MCT_TIMER_STARTING     : 114 -> 113
#                              CPUHP_AP_WORKQUEUE_ONLINE               : 163 -> 159
#                              CPUHP_ONLINE                            : 201 -> 195
#                              CPUHP_AP_IDLE_DEAD                      : 88 -> 86
#                              CPUHP_MM_WRITEBACK_DEAD                 : 13 -> 12
#                              CPUHP_PAGE_ALLOC_DEAD                   : 30 -> 29
#                              CPUHP_BP_PREPARE_DYN                    : 66 -> 64
#                              CPUHP_SOFTIRQ_DEAD                      : 15 -> 14
#                              CPUHP_AP_MARCO_TIMER_STARTING           : 122 -> 117
#                              CPUHP_AP_ONLINE_IDLE                    : 137 -> 133
#                              CPUHP_CPUIDLE_COUPLED_PREPARE           : 47 -> 45
#                              CPUHP_AP_ACTIVE                         : 200 -> 194
#                              CPUHP_BLOCK_SOFTIRQ_DEAD                : 21 -> 20
#                              CPUHP_ARM64_FPSIMD_DEAD                 : 18 -> 17
#                              CPUHP_AP_PERF_ARM_ACPI_STARTING         : 111 -> 107
#                              CPUHP_SLUB_DEAD                         : 12 -> 11
#                              CPUHP_AP_PERF_ARM_CCI_ONLINE            : 151 -> 147
#                              CPUHP_CPUIDLE_DEAD                      : 17 -> 16
#                              CPUHP_MM_MEMCQ_DEAD                     : 27 -> 26
#                              CPUHP_AP_ARM64_DEBUG_MONITORS_STARTING  : 109 -> 105
#                              CPUHP_ARM_OMAP_WAKE_DEAD                : 19 -> 18
#                              CPUHP_ARM_SHMOBILE_SCU_PREPARE          : 52 -> 50
#                              CPUHP_AP_IRQ_AFFINITY_ONLINE            : 140 -> 136
#                              CPUHP_IRQ_POLL_DEAD                     : 20 -> 19
#                              CPUHP_AP_SMPCFD_DYING                   : 133 -> 128
#                              CPUHP_AP_PERF_POWERPC_THREAD_IMC_ONLINE : 162 -> 158
#                              CPUHP_AP_KVM_ARM_TIMER_STARTING         : 128 -> 123
#                              CPUHP_AP_X86_VDSO_VMA_ONLINE            : 139 -> 135
#                              CPUHP_BRINGUP_CPU                       : 87 -> 85
#                              CPUHP_TIMERS_PREPARE                    : 64 -> 62
#                              CPUHP_AP_RCUTREE_ONLINE                 : 165 -> 160
#                              CPUHP_AP_PERF_ARM_QCOM_L2_ONLINE        : 157 -> 153
#                              CPUHP_X86_HPET_DEAD                     : 8 -> 7
#                              CPUHP_AP_PERF_X86_AMD_UNCORE_ONLINE     : 144 -> 140
#                              CPUHP_INVALID                           : 18446744073709551615 -> -1
#                              CPUHP_AP_PERF_XTENSA_STARTING           : 104 -> 101
#                              CPUHP_MD_RAID5_PREPARE                  : 45 -> 43
#                              CPUHP_AP_PERF_ARM_CAVIUM_TX2_UNCORE_ONLINE: 159 -> 155
#                              CPUHP_PROFILE_PREPARE                   : 40 -> 38
#                              CPUHP_AP_ARM_L2X0_STARTING              : 113 -> 109
#                              CPUHP_AP_KVM_ARM_VGIC_INIT_STARTING     : 126 -> 121
#                              CPUHP_AP_MIPS_OP_LOONGSON3_STARTING     : 106 -> 102
#                              CPUHP_AP_ARC_TIMER_STARTING             : 124 -> 119
#                              CPUHP_NET_IUCV_PREPARE                  : 56 -> 54
# Kind.ENUM   hdmi_3d_structure
#                      Value changed:
#                              HDMI_3D_STRUCTURE_INVALID               : 18446744073709551615 -> -1
# Kind.ENUM   hwmon_sensor_types
#                      Added values:
#                              hwmon_max                               : 9
# Kind.ENUM   blk_eh_timer_return
#                      Added values:
#                              BLK_EH_DONE                             : 0
#                      Removed values:
#                              BLK_EH_NOT_HANDLED                      : 0
#                              BLK_EH_HANDLED                          : 1
#                      Value changed:
#                              BLK_EH_RESET_TIMER                      : 2 -> 1
# Kind.ENUM   bpf_prog_type
#                      Added values:
#                              BPF_PROG_TYPE_RAW_TRACEPOINT            : 17
#                              BPF_PROG_TYPE_LWT_SEG6LOCAL             : 19
#                              BPF_PROG_TYPE_CGROUP_SOCK_ADDR          : 18
#                              BPF_PROG_TYPE_LIRC_MODE2                : 20
#                              BPF_PROG_TYPE_SK_MSG                    : 16
# Kind.ENUM   ima_hooks
#                      Added values:
#                              CREDS_CHECK                             : 4
#                      Value changed:
#                              MAX_CHECK                               : 10 -> 11
#                              POST_SETATTR                            : 4 -> 5
#                              FIRMWARE_CHECK                          : 6 -> 7
#                              KEXEC_INITRAMFS_CHECK                   : 8 -> 9
#                              MODULE_CHECK                            : 5 -> 6
#                              KEXEC_KERNEL_CHECK                      : 7 -> 8
#                              POLICY_CHECK                            : 9 -> 10
# Kind.ENUM   netevent_notif_type
#                      Added values:
#                              NETEVENT_IPV6_MPATH_HASH_UPDATE         : 5
#                              NETEVENT_IPV4_MPATH_HASH_UPDATE         : 4
#                      Removed values:
#                              NETEVENT_MULTIPATH_HASH_UPDATE          : 4
# Kind.ENUM   netdev_tx
#                      Value changed:
#                              __NETDEV_TX_MIN                         : 18446744071562067968 -> -2147483648
# Kind.ENUM   ata_completion_errors
#                      Removed values:
#                              AC_ERR_OK                               : 0
# Kind.ENUM   ib_poll_context
#                      Removed values:
#                              IB_POLL_UNBOUND_WORKQUEUE               : 3
# Kind.ENUM   nf_ip6_hook_priorities
#                      Added values:
#                              NF_IP6_PRI_RAW_BEFORE_DEFRAG            : -450
#                      Value changed:
#                              NF_IP6_PRI_RAW                          : 18446744073709551316 -> -300
#                              NF_IP6_PRI_MANGLE                       : 18446744073709551466 -> -150
#                              NF_IP6_PRI_NAT_DST                      : 18446744073709551516 -> -100
#                              NF_IP6_PRI_FIRST                        : 18446744071562067968 -> -2147483648
#                              NF_IP6_PRI_CONNTRACK                    : 18446744073709551416 -> -200
#                              NF_IP6_PRI_SELINUX_FIRST                : 18446744073709551391 -> -225
#                              NF_IP6_PRI_CONNTRACK_DEFRAG             : 18446744073709551216 -> -400
# Kind.ENUM   migrate_reason
#                      Added values:
#                              MR_CONTIG_RANGE                         : 6
#                      Removed values:
#                              MR_CMA                                  : 6
# Kind.ENUM   spectre_v2_mitigation_cmd
#                      Added values:
#                              SPECTRE_V2_CMD_RETPOLINE_AMD            : 5
#                      Removed values:
#                              SPECTRE_V2_CMD_EIBRS_RETPOLINE          : 7
#                              SPECTRE_V2_CMD_EIBRS_LFENCE             : 8
#                              SPECTRE_V2_CMD_EIBRS                    : 6
#                              SPECTRE_V2_CMD_IBRS                     : 9
#                              SPECTRE_V2_CMD_RETPOLINE_LFENCE         : 5
# Kind.ENUM   pci_bus_flags
#                      Added values:
#                              PCI_BUS_FLAGS_NO_EXTCFG                 : 8
# Kind.ENUM   filter_op_ids
#                      Added values:
#                              OP_MAX                                  : 8
#                      Removed values:
#                              OP_OR                                   : 0
#                              OP_AND                                  : 1
#                              OP_NOT                                  : 10
#                              OP_NONE                                 : 11
#                              OP_OPEN_PAREN                           : 12
#                      Value changed:
#                              OP_LE                                   : 6 -> 3
#                              OP_GE                                   : 8 -> 5
#                              OP_LT                                   : 5 -> 4
#                              OP_NE                                   : 3 -> 1
#                              OP_EQ                                   : 4 -> 2
#                              OP_GT                                   : 7 -> 6
#                              OP_GLOB                                 : 2 -> 0
#                              OP_BAND                                 : 9 -> 7
# Kind.ENUM   ttu_flags
#                      Removed values:
#                              TTU_SYNC                                : 512
# Kind.ENUM   dmi_field
#                      Added values:
#                              DMI_OEM_STRING                          : 22
#                              DMI_PRODUCT_SKU                         : 9
#                      Value changed:
#                              DMI_CHASSIS_ASSET_TAG                   : 19 -> 20
#                              DMI_BOARD_VENDOR                        : 10 -> 11
#                              DMI_CHASSIS_VENDOR                      : 15 -> 16
#                              DMI_BOARD_VERSION                       : 12 -> 13
#                              DMI_CHASSIS_SERIAL                      : 18 -> 19
#                              DMI_BOARD_NAME                          : 11 -> 12
#                              DMI_PRODUCT_FAMILY                      : 9 -> 10
#                              DMI_CHASSIS_TYPE                        : 16 -> 17
#                              DMI_STRING_MAX                          : 20 -> 21
#                              DMI_BOARD_ASSET_TAG                     : 14 -> 15
#                              DMI_CHASSIS_VERSION                     : 17 -> 18
#                              DMI_BOARD_SERIAL                        : 13 -> 14
# Kind.ENUM   bpf_netdev_command
#                      Added values:
#                              XDP_SETUP_XSK_UMEM                      : 9
#                              XDP_QUERY_XSK_UMEM                      : 8
#                              BPF_OFFLOAD_MAP_FREE                    : 7
#                              BPF_OFFLOAD_MAP_ALLOC                   : 6
# Kind.ENUM   perf_event_state
#                      Value changed:
#                              PERF_EVENT_STATE_DEAD                   : 18446744073709551612 -> -4
#                              PERF_EVENT_STATE_ERROR                  : 18446744073709551614 -> -2
#                              PERF_EVENT_STATE_EXIT                   : 18446744073709551613 -> -3
#                              PERF_EVENT_STATE_OFF                    : 18446744073709551615 -> -1
# Kind.ENUM   ieee_attrs
#                      Added values:
#                              DCB_ATTR_DCB_BUFFER                     : 10
#                      Value changed:
#                              __DCB_ATTR_IEEE_MAX                     : 10 -> 11
# Kind.ENUM   perf_msr_id
#                      Added values:
#                              PERF_MSR_THERM_SNAP                     : 8
#                              PERF_MSR_THERM_UNIT                     : 9
#                              PERF_MSR_THERM                          : 7
#                      Value changed:
#                              PERF_MSR_EVENT_MAX                      : 7 -> 10
# Kind.ENUM   tpm_duration
#                      Added values:
#                              TPM_NUM_DURATIONS                       : 4
#                              TPM_LONG_LONG                           : 3
#                      Value changed:
#                              TPM_UNDEFINED                           : 3 -> 4
# Kind.ENUM   mddev_flags
#                      Removed values:
#                              MD_NOT_READY                            : 10
#                              MD_BROKEN                               : 11
# Kind.ENUM   x86_hypervisor_type
#                      Added values:
#                              X86_HYPER_JAILHOUSE                     : 6
# Kind.ENUM   bpf_stack_slot_type
#                      Added values:
#                              STACK_ZERO                              : 3
# Kind.ENUM   perf_event_task_context
#                      Value changed:
#                              perf_invalid_context                    : 18446744073709551615 -> -1
# Kind.ENUM   tpm2_const
#                      Removed values:
#                              TPM2_TIMEOUT_A                          : 750
#                              TPM2_TIMEOUT_D                          : 30
#                              TPM2_DURATION_SHORT                     : 20
#                              TPM2_TIMEOUT_B                          : 2000
#                              TPM2_DURATION_MEDIUM                    : 750
#                              TPM2_DURATION_LONG                      : 2000
#                              TPM2_TIMEOUT_C                          : 200
# Kind.ENUM   rtattr_type_t
#                      Added values:
#                              RTA_DPORT                               : 29
#                              RTA_SPORT                               : 28
#                              RTA_IP_PROTO                            : 27
#                      Value changed:
#                              __RTA_MAX                               : 27 -> 30
# Kind.ENUM   pin_config_param
#                      Added values:
#                              PIN_CONFIG_PERSIST_STATE                : 21
# Kind.ENUM   qlock_stats
#                      Added values:
#                              qstat_lock_slowpath                     : 12
#                              qstat_lock_pending                      : 11
#                      Removed values:
#                              qstat_pv_lock_slowpath                  : 5
#                      Value changed:
#                              qstat_pv_wait_early                     : 9 -> 8
#                              qstat_pv_wait_head                      : 10 -> 9
#                              qstat_pv_wait_again                     : 8 -> 7
#                              qstat_pv_spurious_wakeup                : 7 -> 6
#                              qstat_pv_wait_node                      : 11 -> 10
#                              qstat_num                               : 12 -> 13
#                              qstat_pv_lock_stealing                  : 6 -> 5
#                              qstat_reset_cnts                        : 12 -> 13
# Kind.ENUM   extra_reg_type
#                      Value changed:
#                              EXTRA_REG_NONE                          : 18446744073709551615 -> -1
# Kind.ENUM   array_state
#                      Removed values:
#                              broken                                  : 9
#                      Value changed:
#                              bad_word                                : 10 -> 9
# Kind.ENUM   __sk_action
#                      Added values:
#                              __SK_NONE                               : 3
# Kind.ENUM   bpf_attach_type
#                      Added values:
#                              BPF_CGROUP_INET6_BIND                   : 9
#                              BPF_LIRC_MODE2                          : 16
#                              BPF_CGROUP_INET6_POST_BIND              : 13
#                              BPF_CGROUP_UDP6_SENDMSG                 : 15
#                              BPF_SK_MSG_VERDICT                      : 7
#                              BPF_CGROUP_INET6_CONNECT                : 11
#                              BPF_CGROUP_INET4_POST_BIND              : 12
#                              BPF_CGROUP_INET4_CONNECT                : 10
#                              BPF_CGROUP_INET4_BIND                   : 8
#                              BPF_CGROUP_UDP4_SENDMSG                 : 14
#                      Value changed:
#                              __MAX_BPF_ATTACH_TYPE                   : 7 -> 17
# Kind.ENUM   power_supply_property
#                      Added values:
#                              POWER_SUPPLY_PROP_USB_TYPE              : 59
#                      Value changed:
#                              POWER_SUPPLY_PROP_CHARGE_TERM_CURRENT   : 61 -> 62
#                              POWER_SUPPLY_PROP_SCOPE                 : 59 -> 60
#                              POWER_SUPPLY_PROP_MANUFACTURER          : 64 -> 65
#                              POWER_SUPPLY_PROP_MODEL_NAME            : 63 -> 64
#                              POWER_SUPPLY_PROP_PRECHARGE_CURRENT     : 60 -> 61
#                              POWER_SUPPLY_PROP_CALIBRATE             : 62 -> 63
#                              POWER_SUPPLY_PROP_SERIAL_NUMBER         : 65 -> 66
# Kind.ENUM   hrtimer_base_type
#                      Added values:
#                              HRTIMER_BASE_MONOTONIC_SOFT             : 4
#                              HRTIMER_BASE_BOOTTIME_SOFT              : 6
#                              HRTIMER_BASE_TAI_SOFT                   : 7
#                              HRTIMER_BASE_REALTIME_SOFT              : 5
#                      Value changed:
#                              HRTIMER_MAX_CLOCK_BASES                 : 4 -> 8
# Kind.ENUM   nfs3_stable_how
#                      Value changed:
#                              NFS_INVALID_STABLE_HOW                  : 18446744073709551615 -> -1
# Kind.ENUM   tpm2_command_codes
#                      Added values:
#                              TPM2_CC_CREATE_PRIMARY                  : 305
# Kind.ENUM   shutdown_state
#                      Value changed:
#                              SHUTDOWN_INVALID                        : 18446744073709551615 -> -1
# Kind.ENUM   hrtimer_mode
#                      Added values:
#                              HRTIMER_MODE_ABS_PINNED_SOFT            : 6
#                              HRTIMER_MODE_REL_PINNED_SOFT            : 7
#                              HRTIMER_MODE_SOFT                       : 4
#                              HRTIMER_MODE_REL_SOFT                   : 5
#                              HRTIMER_MODE_ABS_SOFT                   : 4
# Kind.ENUM   memory_type
#                      Added values:
#                              MEMORY_DEVICE_FS_DAX                    : 3
#                      Removed values:
#                              MEMORY_DEVICE_HOST                      : 0
# Kind.ENUM   address_markers_idx
#                      Value changed:
#                              CPU_ENTRY_AREA_NR                       : 6 -> 5
#                              VMALLOC_START_NR                        : 4 -> 3
#                              LOW_KERNEL_NR                           : 3 -> 2
#                              LDT_NR                                  : 2 -> 6
#                              VMEMMAP_START_NR                        : 5 -> 4
# Kind.ENUM   mem_type
#                      Added values:
#                              MEM_NVDIMM                              : 21
