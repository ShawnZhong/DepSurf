# %%
# !sudo apt install linux-tools-generic bpftool
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Note, selecting 'linux-tools-common' instead of 'bpftool'
# linux-tools-generic is already the newest version (6.2.0.39.39).
# linux-tools-common is already the newest version (6.2.0-39.40).
# 0 upgraded, 0 newly installed, 0 to remove and 0 not upgraded.

# %%
import os


def system(cmd):
    print(cmd)
    os.system(cmd)

# %%
from pathlib import Path

data_path = Path("data/ubuntu-18.04-x86")

# %%
def unzip_all(path, suffix=".tar.xz"):
    for file in path.glob(f"*{suffix}"):
        stem = file.name.removesuffix(suffix)
        result = path / stem
        if not result.exists():
            system(f"tar -xf {file} -C {path}")
        else:
            print(f"{result} already exists")


unzip_all(data_path)
# Out:
# data/ubuntu-18.04-x86/5.0.0-65-generic.btf already exists
# data/ubuntu-18.04-x86/4.18.0-25-generic.btf already exists
# data/ubuntu-18.04-x86/5.3.0-76-generic.btf already exists
# data/ubuntu-18.04-x86/4.15.0-213-generic.btf already exists
# data/ubuntu-18.04-x86/5.4.0-91-generic.btf already exists

# %%
def get_linux_tools_path():
    parent = Path("/usr/lib/linux-tools")
    versions = [x for x in parent.iterdir() if x.is_dir()]
    if len(versions) == 0:
        raise Exception("No linux-tools found")
    versions.sort()
    return parent / versions[-1]


def get_bpftool_path():
    path = get_linux_tools_path() / "bpftool"
    if not path.exists():
        raise Exception("bpftool not found")
    return path


bpftool_path = get_bpftool_path()

# %%
for file in data_path.glob("*.btf"):
    for ext, cmd in [(".h", "format c"), (".txt", "format raw"), (".json", "--json")]:
        result = file.with_suffix(ext)
        if not result.exists():
            system(f"{bpftool_path} btf dump file {file} {cmd} > {result}")
        else:
            print(f"{result} already exists")
# Out:
# data/ubuntu-18.04-x86/5.4.0-91-generic.h already exists
# data/ubuntu-18.04-x86/5.4.0-91-generic.txt already exists
# data/ubuntu-18.04-x86/5.4.0-91-generic.json already exists
# data/ubuntu-18.04-x86/5.0.0-65-generic.h already exists
# data/ubuntu-18.04-x86/5.0.0-65-generic.txt already exists
# data/ubuntu-18.04-x86/5.0.0-65-generic.json already exists
# data/ubuntu-18.04-x86/5.3.0-76-generic.h already exists
# data/ubuntu-18.04-x86/5.3.0-76-generic.txt already exists
# data/ubuntu-18.04-x86/5.3.0-76-generic.json already exists
# data/ubuntu-18.04-x86/4.15.0-213-generic.h already exists
# data/ubuntu-18.04-x86/4.15.0-213-generic.txt already exists
# data/ubuntu-18.04-x86/4.15.0-213-generic.json already exists
# data/ubuntu-18.04-x86/4.18.0-25-generic.h already exists
# data/ubuntu-18.04-x86/4.18.0-25-generic.txt already exists
# data/ubuntu-18.04-x86/4.18.0-25-generic.json already exists

# %%
json_paths = sorted(file for file in data_path.glob("*.json"))

json_paths
# Out:
# [PosixPath('data/ubuntu-18.04-x86/4.15.0-213-generic.json'),
#  PosixPath('data/ubuntu-18.04-x86/4.18.0-25-generic.json'),
#  PosixPath('data/ubuntu-18.04-x86/5.0.0-65-generic.json'),
#  PosixPath('data/ubuntu-18.04-x86/5.3.0-76-generic.json'),
#  PosixPath('data/ubuntu-18.04-x86/5.4.0-91-generic.json')]

# %%
import json


def load_json(json_path):
    with open(json_path) as f:
        return json.load(f)


jsons = [load_json(p) for p in json_paths]

# %%
from enum import Enum


class Kind(str, Enum):
    INT = "INT"
    PTR = "PTR"
    ARRAY = "ARRAY"
    STRUCT = "STRUCT"
    UNION = "UNION"
    ENUM = "ENUM"
    FWD = "FWD"
    TYPEDEF = "TYPEDEF"
    VOLATILE = "VOLATILE"
    CONST = "CONST"
    RESTRICT = "RESTRICT"
    FUNC = "FUNC"
    FUNC_PROTO = "FUNC_PROTO"
    VAR = "VAR"
    DATASEC = "DATASEC"
    FLOAT = "FLOAT"
    DECL_TAG = "DECL_TAG"
    TYPE_TAG = "TYPE_TAG"
    ENUM64 = "ENUM64"

# %%
import copy
from functools import cache


class BTF:
    def __init__(self, path, raw_data=None):
        self.path = path
        if raw_data is None:
            self._raw_data = load_json(path)['types']
        else:
            self._raw_data = raw_data['types']

    def __getitem__(self, id):
        if id == 0:
            return {'id': 0, 'name': 'void', 'kind': 'VOID'}
        e = self._raw_data[id - 1]
        assert e['id'] == id
        return e

    def __len__(self):
        return len(self._raw_data)

    def __iter__(self):
        return iter(self._raw_data)

    def print(self):
        from collections import defaultdict

        print(f"File: {self.path}")

        print("Sample:")
        kinds = defaultdict(int)
        for e in self:
            if e['kind'] not in kinds:
                print(f"\t{e['id']:6} ({e['kind']:10}): {e}")
                print(f"\t{'':18}-> {self.normalize(e)}")
            kinds[e['kind']] += 1

        kinds = sorted(kinds.items(), key=lambda x: x[1], reverse=True)
        print(f"Kinds:")
        print(f"\t{dict(kinds)}")

        print()

    @cache
    def filter_on_kind(self, kind):
        return {
            e['name']: self.normalize(e) for e in self
            if e['kind'] == kind and e['name'] != '(anon)'
        }

    def get_by_kind_name(self, kind, name):
        return self.filter_on_kind(kind)[name]

    RECURSE_KINDS = {Kind.CONST, Kind.VOLATILE,
                     Kind.PTR, Kind.FUNC, Kind.FUNC_PROTO, Kind.ARRAY}

    @cache
    def _normalize_sub_elem(self, type_id):
        elem = self[type_id]
        recurse = elem['kind'] in self.RECURSE_KINDS
        return self.normalize(elem, recurse=recurse)

    def normalize(self, elem, recurse=True):
        elem = copy.deepcopy(elem)

        # Remove redundant fields
        del elem['id']
        if elem['kind'] == Kind.INT:
            assert elem['bits_offset'] == 0
            del elem['bits_offset']
            del elem['encoding']
            del elem['nr_bits']
            del elem['size']
        if elem['kind'] == Kind.ARRAY:
            del elem['index_type_id']
        if elem['kind'] == Kind.ENUM:
            if not recurse:
                assert elem['vlen'] == len(elem['values'])
                del elem['values']
                del elem['vlen']
                del elem['encoding']
        if elem['kind'] == Kind.FUNC:
            assert elem['linkage'] == 'static'
            del elem['linkage']

        # Normalize types
        for type in ['type', 'ret_type']:
            type_id = f"{type}_id"

            if type_id not in elem:
                continue

            if recurse:
                elem[type] = self._normalize_sub_elem(elem[type_id])
            del elem[type_id]

        for list_key in ['params', 'members']:
            if list_key not in elem:
                continue

            assert len(elem[list_key]) == elem['vlen']
            del elem['vlen']

            if recurse:
                for item in elem[list_key]:
                    item['type'] = self._normalize_sub_elem(item['type_id'])
                    del item['type_id']
            else:
                del elem[list_key]
                if list_key == 'members':
                    del elem['size']

        return elem


d1 = BTF(json_paths[0], jsons[0])
d2 = BTF(json_paths[1], jsons[1])

d1.print()

# d1.get_by_kind_name(Kind.STRUCT, "task_struct")
# d1.get_by_kind_name(Kind.STRUCT, "uprobe_task")
d1.get_by_kind_name(Kind.FUNC, "vfs_read")
# Out:
# File: data/ubuntu-18.04-x86/4.15.0-213-generic.json
# Sample:
# 	     1 (INT       ): {'id': 1, 'kind': 'INT', 'name': 'long unsigned int', 'size': 8, 'bits_offset': 0, 'nr_bits': 64, 'encoding': '(none)'}
# 	                  -> {'kind': 'INT', 'name': 'long unsigned int'}
# 	     2 (CONST     ): {'id': 2, 'kind': 'CONST', 'name': '(anon)', 'type_id': 1}
# 	                  -> {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'INT', 'name': 'long unsigned int'}}
# 	     3 (VOLATILE  ): {'id': 3, 'kind': 'VOLATILE', 'name': '(anon)', 'type_id': 1}
# 	                  -> {'kind': 'VOLATILE', 'name': '(anon)', 'type': {'kind': 'INT', 'name': 'long unsigned int'}}
# 	     4 (ARRAY     ): {'id': 4, 'kind': 'ARRAY', 'name': '(anon)', 'type_id': 1, 'index_type_id': 20, 'nr_elems': 2}
# 	                  -> {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 2, 'type': {'kind': 'INT', 'name': 'long unsigned int'}}
# 	     5 (PTR       ): {'id': 5, 'kind': 'PTR', 'name': '(anon)', 'type_id': 8}
# 	                  -> {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'INT', 'name': 'char'}}}
# 	    11 (TYPEDEF   ): {'id': 11, 'kind': 'TYPEDEF', 'name': '__s8', 'type_id': 12}
# 	                  -> {'kind': 'TYPEDEF', 'name': '__s8', 'type': {'kind': 'INT', 'name': 'signed char'}}
# 	    38 (FUNC_PROTO): {'id': 38, 'kind': 'FUNC_PROTO', 'name': '(anon)', 'ret_type_id': 0, 'vlen': 1, 'params': [{'name': '(anon)', 'type_id': 20}]}
# 	                  -> {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}
# 	    78 (STRUCT    ): {'id': 78, 'kind': 'STRUCT', 'name': '(anon)', 'size': 4, 'vlen': 1, 'members': [{'name': 'counter', 'type_id': 20, 'bits_offset': 0}]}
# 	                  -> {'kind': 'STRUCT', 'name': '(anon)', 'size': 4, 'members': [{'name': 'counter', 'bits_offset': 0, 'type': {'kind': 'INT', 'name': 'int'}}]}
# 	   106 (UNION     ): {'id': 106, 'kind': 'UNION', 'name': '(anon)', 'size': 8, 'vlen': 3, 'members': [{'name': 'type', 'type_id': 1, 'bits_offset': 0}, {'name': 'entries', 'type_id': 108, 'bits_offset': 0}, {'name': 'next', 'type_id': 109, 'bits_offset': 0}]}
# 	                  -> {'kind': 'UNION', 'name': '(anon)', 'size': 8, 'members': [{'name': 'type', 'bits_offset': 0, 'type': {'kind': 'INT', 'name': 'long unsigned int'}}, {'name': 'entries', 'bits_offset': 0, 'type': {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'jump_entry'}}}, {'name': 'next', 'bits_offset': 0, 'type': {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'static_key_mod'}}}]}
# 	   120 (ENUM      ): {'id': 120, 'kind': 'ENUM', 'name': 'system_states', 'encoding': 'UNSIGNED', 'size': 4, 'vlen': 6, 'values': [{'name': 'SYSTEM_BOOTING', 'val': 0}, {'name': 'SYSTEM_SCHEDULING', 'val': 1}, {'name': 'SYSTEM_RUNNING', 'val': 2}, {'name': 'SYSTEM_HALT', 'val': 3}, {'name': 'SYSTEM_POWER_OFF', 'val': 4}, {'name': 'SYSTEM_RESTART', 'val': 5}]}
# 	                  -> {'kind': 'ENUM', 'name': 'system_states', 'encoding': 'UNSIGNED', 'size': 4, 'vlen': 6, 'values': [{'name': 'SYSTEM_BOOTING', 'val': 0}, {'name': 'SYSTEM_SCHEDULING', 'val': 1}, {'name': 'SYSTEM_RUNNING', 'val': 2}, {'name': 'SYSTEM_HALT', 'val': 3}, {'name': 'SYSTEM_POWER_OFF', 'val': 4}, {'name': 'SYSTEM_RESTART', 'val': 5}]}
# 	  1110 (FWD       ): {'id': 1110, 'kind': 'FWD', 'name': 'nlm_lockowner', 'fwd_kind': 'struct'}
# 	                  -> {'kind': 'FWD', 'name': 'nlm_lockowner', 'fwd_kind': 'struct'}
# 	  1671 (FUNC      ): {'id': 1671, 'kind': 'FUNC', 'name': 'copy_bootdata', 'type_id': 1670, 'linkage': 'static'}
# 	                  -> {'kind': 'FUNC', 'name': 'copy_bootdata', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': 'real_mode_data', 'type': {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'INT', 'name': 'char'}}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
# 	  4737 (VAR       ): {'id': 4737, 'kind': 'VAR', 'name': 'cpu_loops_per_jiffy', 'type_id': 1, 'linkage': 'static'}
# 	                  -> {'kind': 'VAR', 'name': 'cpu_loops_per_jiffy', 'linkage': 'static', 'type': {'kind': 'INT', 'name': 'long unsigned int'}}
# 	 94558 (RESTRICT  ): {'id': 94558, 'kind': 'RESTRICT', 'name': '(anon)', 'type_id': 5}
# 	                  -> {'kind': 'RESTRICT', 'name': '(anon)', 'type': {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'INT', 'name': 'char'}}}}
# 	 94838 (DATASEC   ): {'id': 94838, 'kind': 'DATASEC', 'name': '.data..percpu', 'size': 164036, 'vlen': 326, 'vars': [{'type_id': 5631, 'offset': 16384, 'size': 4096}, {'type_id': 8571, 'offset': 20480, 'size': 12288}, {'type_id': 9004, 'offset': 32768, 'size': 4096}, {'type_id': 12534, 'offset': 36864, 'size': 40960}, {'type_id': 12533, 'offset': 77824, 'size': 4096}, {'type_id': 8154, 'offset': 81920, 'size': 8}, {'type_id': 8153, 'offset': 81928, 'size': 8}, {'type_id': 9003, 'offset': 81936, 'size': 2}, {'type_id': 10430, 'offset': 81952, 'size': 8}, {'type_id': 10429, 'offset': 81960, 'size': 8}, {'type_id': 10428, 'offset': 81968, 'size': 8}, {'type_id': 10431, 'offset': 81984, 'size': 240}, {'type_id': 10452, 'offset': 82224, 'size': 4}, {'type_id': 10453, 'offset': 82232, 'size': 8}, {'type_id': 10596, 'offset': 82240, 'size': 4}, {'type_id': 10594, 'offset': 82244, 'size': 2}, {'type_id': 10595, 'offset': 82246, 'size': 2}, {'type_id': 11856, 'offset': 82248, 'size': 4}, {'type_id': 4737, 'offset': 82304, 'size': 8}, {'type_id': 5189, 'offset': 82336, 'size': 512}, {'type_id': 5188, 'offset': 82848, 'size': 4824}, {'type_id': 5231, 'offset': 87672, 'size': 8}, {'type_id': 5559, 'offset': 90112, 'size': 12288}, {'type_id': 5632, 'offset': 102400, 'size': 8}, {'type_id': 5797, 'offset': 102432, 'size': 168}, {'type_id': 6219, 'offset': 102624, 'size': 64}, {'type_id': 6220, 'offset': 102688, 'size': 4}, {'type_id': 6218, 'offset': 102696, 'size': 8}, {'type_id': 6243, 'offset': 102720, 'size': 3088}, {'type_id': 6244, 'offset': 105808, 'size': 8}, {'type_id': 6519, 'offset': 105856, 'size': 320}, {'type_id': 6548, 'offset': 106176, 'size': 8}, {'type_id': 6742, 'offset': 106192, 'size': 16}, {'type_id': 7016, 'offset': 106208, 'size': 8}, {'type_id': 7015, 'offset': 106216, 'size': 10}, {'type_id': 7014, 'offset': 106240, 'size': 24}, {'type_id': 7191, 'offset': 106264, 'size': 8}, {'type_id': 7190, 'offset': 106272, 'size': 8}, {'type_id': 7457, 'offset': 106288, 'size': 16}, {'type_id': 7456, 'offset': 106304, 'size': 16}, {'type_id': 7455, 'offset': 106320, 'size': 16}, {'type_id': 7454, 'offset': 106336, 'size': 16}, {'type_id': 7493, 'offset': 106352, 'size': 16}, {'type_id': 7492, 'offset': 106368, 'size': 16}, {'type_id': 7509, 'offset': 106384, 'size': 4}, {'type_id': 7508, 'offset': 106392, 'size': 8}, {'type_id': 7507, 'offset': 106400, 'size': 4}, {'type_id': 7620, 'offset': 106408, 'size': 8}, {'type_id': 7903, 'offset': 106416, 'size': 8}, {'type_id': 7988, 'offset': 106432, 'size': 4}, {'type_id': 7987, 'offset': 106440, 'size': 8}, {'type_id': 7986, 'offset': 106448, 'size': 4}, {'type_id': 7985, 'offset': 106456, 'size': 8}, {'type_id': 7984, 'offset': 106464, 'size': 1}, {'type_id': 7983, 'offset': 106480, 'size': 16}, {'type_id': 8100, 'offset': 106496, 'size': 2048}, {'type_id': 8280, 'offset': 108544, 'size': 744}, {'type_id': 8370, 'offset': 109312, 'size': 32}, {'type_id': 8369, 'offset': 109344, 'size': 32}, {'type_id': 8368, 'offset': 109376, 'size': 8}, {'type_id': 8574, 'offset': 109392, 'size': 24}, {'type_id': 8572, 'offset': 109416, 'size': 1}, {'type_id': 8573, 'offset': 109424, 'size': 8}, {'type_id': 8614, 'offset': 109432, 'size': 1}, {'type_id': 8615, 'offset': 109440, 'size': 8}, {'type_id': 9010, 'offset': 109504, 'size': 8}, {'type_id': 9011, 'offset': 109512, 'size': 4}, {'type_id': 9012, 'offset': 109516, 'size': 4}, {'type_id': 9008, 'offset': 109520, 'size': 4}, {'type_id': 9007, 'offset': 109524, 'size': 4}, {'type_id': 9006, 'offset': 109528, 'size': 8}, {'type_id': 9009, 'offset': 109536, 'size': 56}, {'type_id': 9005, 'offset': 109632, 'size': 8}, {'type_id': 9176, 'offset': 109640, 'size': 8}, {'type_id': 9187, 'offset': 109664, 'size': 32}, {'type_id': 9292, 'offset': 109696, 'size': 16}, {'type_id': 9566, 'offset': 109728, 'size': 40}, {'type_id': 9565, 'offset': 109768, 'size': 8}, {'type_id': 9561, 'offset': 109792, 'size': 120}, {'type_id': 9563, 'offset': 109920, 'size ...
# 	                  -> {'kind': 'DATASEC', 'name': '.data..percpu', 'size': 164036, 'vlen': 326, 'vars': [{'type_id': 5631, 'offset': 16384, 'size': 4096}, {'type_id': 8571, 'offset': 20480, 'size': 12288}, {'type_id': 9004, 'offset': 32768, 'size': 4096}, {'type_id': 12534, 'offset': 36864, 'size': 40960}, {'type_id': 12533, 'offset': 77824, 'size': 4096}, {'type_id': 8154, 'offset': 81920, 'size': 8}, {'type_id': 8153, 'offset': 81928, 'size': 8}, {'type_id': 9003, 'offset': 81936, 'size': 2}, {'type_id': 10430, 'offset': 81952, 'size': 8}, {'type_id': 10429, 'offset': 81960, 'size': 8}, {'type_id': 10428, 'offset': 81968, 'size': 8}, {'type_id': 10431, 'offset': 81984, 'size': 240}, {'type_id': 10452, 'offset': 82224, 'size': 4}, {'type_id': 10453, 'offset': 82232, 'size': 8}, {'type_id': 10596, 'offset': 82240, 'size': 4}, {'type_id': 10594, 'offset': 82244, 'size': 2}, {'type_id': 10595, 'offset': 82246, 'size': 2}, {'type_id': 11856, 'offset': 82248, 'size': 4}, {'type_id': 4737, 'offset': 82304, 'size': 8}, {'type_id': 5189, 'offset': 82336, 'size': 512}, {'type_id': 5188, 'offset': 82848, 'size': 4824}, {'type_id': 5231, 'offset': 87672, 'size': 8}, {'type_id': 5559, 'offset': 90112, 'size': 12288}, {'type_id': 5632, 'offset': 102400, 'size': 8}, {'type_id': 5797, 'offset': 102432, 'size': 168}, {'type_id': 6219, 'offset': 102624, 'size': 64}, {'type_id': 6220, 'offset': 102688, 'size': 4}, {'type_id': 6218, 'offset': 102696, 'size': 8}, {'type_id': 6243, 'offset': 102720, 'size': 3088}, {'type_id': 6244, 'offset': 105808, 'size': 8}, {'type_id': 6519, 'offset': 105856, 'size': 320}, {'type_id': 6548, 'offset': 106176, 'size': 8}, {'type_id': 6742, 'offset': 106192, 'size': 16}, {'type_id': 7016, 'offset': 106208, 'size': 8}, {'type_id': 7015, 'offset': 106216, 'size': 10}, {'type_id': 7014, 'offset': 106240, 'size': 24}, {'type_id': 7191, 'offset': 106264, 'size': 8}, {'type_id': 7190, 'offset': 106272, 'size': 8}, {'type_id': 7457, 'offset': 106288, 'size': 16}, {'type_id': 7456, 'offset': 106304, 'size': 16}, {'type_id': 7455, 'offset': 106320, 'size': 16}, {'type_id': 7454, 'offset': 106336, 'size': 16}, {'type_id': 7493, 'offset': 106352, 'size': 16}, {'type_id': 7492, 'offset': 106368, 'size': 16}, {'type_id': 7509, 'offset': 106384, 'size': 4}, {'type_id': 7508, 'offset': 106392, 'size': 8}, {'type_id': 7507, 'offset': 106400, 'size': 4}, {'type_id': 7620, 'offset': 106408, 'size': 8}, {'type_id': 7903, 'offset': 106416, 'size': 8}, {'type_id': 7988, 'offset': 106432, 'size': 4}, {'type_id': 7987, 'offset': 106440, 'size': 8}, {'type_id': 7986, 'offset': 106448, 'size': 4}, {'type_id': 7985, 'offset': 106456, 'size': 8}, {'type_id': 7984, 'offset': 106464, 'size': 1}, {'type_id': 7983, 'offset': 106480, 'size': 16}, {'type_id': 8100, 'offset': 106496, 'size': 2048}, {'type_id': 8280, 'offset': 108544, 'size': 744}, {'type_id': 8370, 'offset': 109312, 'size': 32}, {'type_id': 8369, 'offset': 109344, 'size': 32}, {'type_id': 8368, 'offset': 109376, 'size': 8}, {'type_id': 8574, 'offset': 109392, 'size': 24}, {'type_id': 8572, 'offset': 109416, 'size': 1}, {'type_id': 8573, 'offset': 109424, 'size': 8}, {'type_id': 8614, 'offset': 109432, 'size': 1}, {'type_id': 8615, 'offset': 109440, 'size': 8}, {'type_id': 9010, 'offset': 109504, 'size': 8}, {'type_id': 9011, 'offset': 109512, 'size': 4}, {'type_id': 9012, 'offset': 109516, 'size': 4}, {'type_id': 9008, 'offset': 109520, 'size': 4}, {'type_id': 9007, 'offset': 109524, 'size': 4}, {'type_id': 9006, 'offset': 109528, 'size': 8}, {'type_id': 9009, 'offset': 109536, 'size': 56}, {'type_id': 9005, 'offset': 109632, 'size': 8}, {'type_id': 9176, 'offset': 109640, 'size': 8}, {'type_id': 9187, 'offset': 109664, 'size': 32}, {'type_id': 9292, 'offset': 109696, 'size': 16}, {'type_id': 9566, 'offset': 109728, 'size': 40}, {'type_id': 9565, 'offset': 109768, 'size': 8}, {'type_id': 9561, 'offset': 109792, 'size': 120}, {'type_id': 9563, 'offset': 109920, 'size': 120}, {'ty ...
# Kinds:
# 	{'FUNC': 42719, 'FUNC_PROTO': 22849, 'PTR': 11884, 'STRUCT': 8154, 'ARRAY': 2981, 'CONST': 2369, 'ENUM': 1528, 'TYPEDEF': 1005, 'UNION': 827, 'VAR': 326, 'FWD': 158, 'VOLATILE': 20, 'INT': 15, 'RESTRICT': 2, 'DATASEC': 1}
# {'kind': 'FUNC',
#  'name': 'vfs_read',
#  'type': {'kind': 'FUNC_PROTO',
#   'name': '(anon)',
#   'params': [{'name': 'file',
#     'type': {'kind': 'PTR',
#      'name': '(anon)',
#      'type': {'kind': 'STRUCT', 'name': 'file'}}},
#    {'name': 'buf',
#     'type': {'kind': 'PTR',
#      'name': '(anon)',
#      'type': {'kind': 'INT', 'name': 'char'}}},
#    {'name': 'count', 'type': {'kind': 'TYPEDEF', 'name': 'size_t'}},
#    {'name': 'pos',
#     'type': {'kind': 'PTR',
#      'name': '(anon)',
#      'type': {'kind': 'TYPEDEF', 'name': 'loff_t'}}}],
#   'ret_type': {'kind': 'TYPEDEF', 'name': 'ssize_t'}}}

# %%
def diff_struct(old, new):
    old_members = {m['name']: m for m in old['members']}
    new_members = {m['name']: m for m in new['members']}

    # fields added or removed
    if set(old_members) != set(new_members):
        added_members = new_members.keys() - old_members.keys()
        removed_members = old_members.keys() - new_members.keys()

        if added_members and removed_members:
            return f"Fields added and removed: {added_members} {removed_members}"
        elif added_members and not removed_members:
            return f"Added fields: {added_members}"
        elif not added_members and removed_members:
            return f"Removed fields: {removed_members}"
        else:
            assert False

    # fields reordered
    if list(old_members) != list(new_members):
        return f"Fields reordered: {old_members} {new_members}"
    
    # fields changed type
    changed_types = {
        name: (old_members[name]['type'], new_members[name]['type'])
        for name in old_members
        if old_members[name]['type'] != new_members[name]['type']
    }
    if changed_types:
        result = "Field type changed:\n"
        for name, (old_type, new_type) in changed_types.items():
            result += f"{name:20}: {old_type} \n{'':20}->{new_type}\n"
        return result

    # same type but different size
    for name in old_members:
        if old_members[name]['bits_offset'] != new_members[name]['bits_offset']:
            return f"Field size changed despite same type"

    if old['size'] != new['size']:
        return f"Field size changed despite same type"

    assert False, f"\n{old}\n{new}"



def print_collection(name, s, num=10):
    print(f"{name} ({len(s)}): {list(s)[:num]}")


def check_diff(d_old, d_new, kind):
    f_old = d_old.filter_on_kind(kind)
    f_new = d_new.filter_on_kind(kind)

    print_collection(f"Old {kind}", f_old.keys())
    print_collection(f"New {kind}", f_new.keys())

    print_collection(f"Removed {kind}", f_old.keys() - f_new.keys())
    print_collection(f"Added {kind}", f_new.keys() - f_old.keys())

    common = {
        name: (f_old[name], f_new[name])
        for name in f_old.keys() & f_new.keys()
    }
    print_collection(f"Common {kind}", common.keys())

    diff = {
        "STRUCT": diff_struct,
        "FUNC": diff_func
    }[kind]

    changed = {
        name: (old, new)
        for name, (old, new) in common.items()
        if old != new
    }
    print_collection(f"Changed {kind}", changed.keys())

    for name, (old, new) in changed.items():
        reason = diff(old, new)
        lines = reason.split("\n")
        print(f"{kind:10}{name:30}: {lines[0]}")
        for line in lines[1:]:
            print(f"{'':40} {line}")

def diff_func(old, new):
    assert old['type']['kind'] == Kind.FUNC_PROTO
    assert new['type']['kind'] == Kind.FUNC_PROTO
    old_params = {p['name']: p for p in old['type']['params']}
    new_params = {p['name']: p for p in new['type']['params']}

    # params added or removed
    if set(old_params) != set(new_params):
        added_params = new_params.keys() - old_params.keys()
        removed_params = old_params.keys() - new_params.keys()

        if added_params and removed_params:
            return f"Params added and removed: {added_params} {removed_params}"
        elif added_params and not removed_params:
            return f"Added params: {added_params}"
        elif not added_params and removed_params:
            return f"Removed params: {removed_params}"
        else:
            assert False

    # params reordered
    if list(old_params) != list(new_params):
        return f"Params reordered: {old_params} {new_params}"
    
    # params changed type
    changed_types = {
        name: (old_params[name]['type'], new_params[name]['type'])
        for name in old_params
        if old_params[name]['type'] != new_params[name]['type']
    }
    if changed_types:
        result = "Param type changed:\n"
        for name, (old_type, new_type) in changed_types.items():
            result += f"{name:20}: {old_type} \n{'':20}->{new_type}\n"
        return result
    
    # param changed return value
    old_ret = old['type']['ret_type']
    new_ret = new['type']['ret_type']
    if old_ret != new_ret:
        return f"Return type changed: {old_ret} -> {new_ret}"

    assert False, f"\n{old}\n{new}" 

# check_diff(d1, d2, 'STRUCT')
check_diff(d1, d2, 'FUNC')
# Out:
# Old FUNC (42719): ['copy_bootdata', 'early_make_pgtable', 'reset_early_page_tables', '__startup_secondary_64', '__startup_64', 'x86_64_start_reservations', 'x86_64_start_kernel', '__early_make_pgtable', 'read_cr3_pa', 'clear_page']
# New FUNC (44531): ['copy_bootdata', 'early_make_pgtable', 'reset_early_page_tables', '__startup_secondary_64', '__startup_64', 'x86_64_start_reservations', 'x86_64_start_kernel', '__early_make_pgtable', 'read_cr3_pa', 'clear_page']
# Removed FUNC (1801): ['SYSC_newfstatat', 'SyS_fchown', 'sme_map_range_encrypted', 'SyS_pwrite64', 'SyS_sched_get_priority_max', 'hv_pci_init', 'compat_SyS_clock_adjtime', 'acpi_gpiochip_alloc_event', 'compat_SyS_old_getrlimit', 'serial8250_get_baud_rate']
# Added FUNC (3613): ['dev_direct_xmit', 'genpd_perf_state_show', '__bpf_trace_ext4_fsmap_class', 'dma_direct_free', '__bpf_trace_rtc_alarm_irq_enable', '__x64_sys_brk', '__x64_sys_setregid16', '__device_add_disk', 'ip6mr_seq_read', 'smack_sk_free_security']
# Common FUNC (40918): ['get_wireless_stats', 'acpi_os_notify_command_complete', 'hpet_rtc_timer_init', 'descriptor_loc', 'platform_msi_alloc_descs_with_irq', 'pmd_clear_huge', 'iomap_dirty_actor', 'disable_trace_kprobe', 'journal_init', 'acpi_ut_walk_aml_resources']
# Changed FUNC (1062): ['xdp_is_valid_access', '__uncore_tid_en_show', 'do_timerfd_settime', 'ip6_pol_route_input', 'ip_options_rcv_srr', 'linear_prepare_ioctl', 'tpm_unseal_trusted', 'lineevent_poll', 'call_sbin_request_key', '__uncore_filter_band0_show']
# FUNC      xdp_is_valid_access           : Added params: {'prog'}
# FUNC      __uncore_tid_en_show          : Params added and removed: {'kobj'} {'dev'}
# FUNC      do_timerfd_settime            : Param type changed:
#                                          new                 : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'itimerspec'}}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'itimerspec64'}}}
#                                          old                 : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'itimerspec'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'itimerspec64'}}
#
# FUNC      ip6_pol_route_input           : Added params: {'skb'}
# FUNC      ip_options_rcv_srr            : Removed params: {'dev'}
# FUNC      linear_prepare_ioctl          : Removed params: {'mode'}
# FUNC      tpm_unseal_trusted            : Params added and removed: {'chip'} {'chip_num'}
# FUNC      lineevent_poll                : Return type changed: {'kind': 'INT', 'name': 'unsigned int'} -> {'kind': 'TYPEDEF', 'name': '__poll_t'}
# FUNC      call_sbin_request_key         : Params added and removed: {'op', 'cons'} {'authkey'}
# FUNC      __uncore_filter_band0_show    : Params added and removed: {'kobj'} {'dev'}
# FUNC      __uncore_umask_show           : Params added and removed: {'kobj'} {'dev'}
# FUNC      log_buf_len_update            : Param type changed:
#                                          size                : {'kind': 'TYPEDEF', 'name': 'u64'}
#                                                              ->{'kind': 'INT', 'name': 'unsigned int'}
#
# FUNC      __uncore_qlx_cfg_show         : Params added and removed: {'kobj'} {'dev'}
# FUNC      xennet_start_xmit             : Return type changed: {'kind': 'INT', 'name': 'int'} -> {'kind': 'TYPEDEF', 'name': 'netdev_tx_t'}
# FUNC      wbt_issue                     : Params added and removed: {'rq'} {'stat'}
# FUNC      vmemmap_populate              : Added params: {'altmap'}
# FUNC      evdev_poll                    : Return type changed: {'kind': 'INT', 'name': 'unsigned int'} -> {'kind': 'TYPEDEF', 'name': '__poll_t'}
# FUNC      packet_poll                   : Return type changed: {'kind': 'INT', 'name': 'unsigned int'} -> {'kind': 'TYPEDEF', 'name': '__poll_t'}
# FUNC      memmap_init_zone              : Added params: {'altmap'}
# FUNC      slow_avc_audit                : Added params: {'state'}
# FUNC      arch_pick_mmap_layout         : Added params: {'rlim_stack'}
# FUNC      security_msg_queue_msgctl     : Param type changed:
#                                          msq                 : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'msg_queue'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}
#
# FUNC      security_compute_sid          : Added params: {'state'}
# FUNC      find_mergeable                : Param type changed:
#                                          size                : {'kind': 'TYPEDEF', 'name': 'size_t'}
#                                                              ->{'kind': 'INT', 'name': 'unsigned int'}
#                                          align               : {'kind': 'TYPEDEF', 'name': 'size_t'}
#                                                              ->{'kind': 'INT', 'name': 'unsigned int'}
#
# FUNC      kprobe_prog_func_proto        : Added params: {'prog'}
# FUNC      xhci_set_link_state           : Params added and removed: {'port'} {'port_id', 'port_array'}
# FUNC      event_hist_trigger            : Added params: {'rbe'}
# FUNC      blk_alloc_queue_node          : Added params: {'lock'}
# FUNC      fuse_abort_conn               : Added params: {'is_abort'}
# FUNC      intel_gtt_get                 : Removed params: {'stolen_size'}
# FUNC      add_pages                     : Added params: {'altmap'}
# FUNC      get_timespec64                : Param type changed:
#                                          ts                  : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}
#
# FUNC      chacha20_block                : Param type changed:
#                                          stream              : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u8'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}
#
# FUNC      get_random_bytes_arch         : Params added and removed: {'nbytes'} {'len'}
# FUNC      show_min_perf_pct             : Param type changed:
#                                          attr                : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'kobj_attribute'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'attribute'}}
#
# FUNC      __uncore_iperf_cfg_show       : Params added and removed: {'kobj'} {'dev'}
# FUNC      store_status                  : Params added and removed: {'value', 'nr', 'start', 'status'} {'a', 'b', 'count', 'buf'}
# FUNC      security_get_classes          : Added params: {'state'}
# FUNC      __split_and_process_bio       : Return type changed: {'name': 'void', 'kind': 'VOID'} -> {'kind': 'TYPEDEF', 'name': 'blk_qc_t'}
# FUNC      do_semtimedop                 : Param type changed:
#                                          timeout             : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}}
#
# FUNC      tty_termios_hw_change         : Param type changed:
#                                          a                   : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'ktermios'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'ktermios'}}}
#                                          b                   : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'ktermios'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'ktermios'}}}
#
# FUNC      avc_flush                     : Added params: {'avc'}
# FUNC      hmm_vma_range_done            : Removed params: {'vma'}
# FUNC      scsi_dev_info_add_list        : Param type changed:
#                                          key                 : {'kind': 'INT', 'name': 'int'}
#                                                              ->{'kind': 'ENUM', 'name': 'scsi_devinfo_key', 'size': 4}
#
# FUNC      generic_pipe_buf_get          : Return type changed: {'kind': 'TYPEDEF', 'name': 'bool'} -> {'name': 'void', 'kind': 'VOID'}
# FUNC      kernel_getpeername            : Removed params: {'addrlen'}
# FUNC      tick_nohz_get_sleep_length    : Added params: {'delta_next'}
# FUNC      tcp_rcv_established           : Removed params: {'th'}
# FUNC      show_lowest_perf              : Param type changed:
#                                          attr                : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'kobj_attribute'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'attribute'}}
#
# FUNC      tcp_poll                      : Return type changed: {'kind': 'INT', 'name': 'unsigned int'} -> {'kind': 'TYPEDEF', 'name': '__poll_t'}
# FUNC      ip6_del_rt                    : Added params: {'net'}
# FUNC      security_getprocattr          : Removed params: {'lsm'}
# FUNC      show_feedback_ctrs            : Param type changed:
#                                          attr                : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'kobj_attribute'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'attribute'}}
#
# FUNC      type_attribute_bounds_av      : Added params: {'policydb'}
# FUNC      event_triggers_post_call      : Removed params: {'rec'}
# FUNC      fib_multipath_hash            : Params added and removed: {'net', 'flkeys'} {'fi'}
# FUNC      avc_node_delete               : Added params: {'avc'}
# FUNC      perf_trace_writeback_queue_io : Removed params: {'dirtied_before'}
# FUNC      cred_has_capability           : Params added and removed: {'audit'} {'opts'}
# FUNC      ip_make_skb                   : Added params: {'cork'}
# FUNC      __uncore_cmask5_show          : Params added and removed: {'kobj'} {'dev'}
# FUNC      posix_get_boottime            : Param type changed:
#                                          tp                  : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}
#
# FUNC      __do_page_fault               : Params added and removed: {'error_code'} {'hw_error_code'}
# FUNC      edac_device_reset_delay_period: Params added and removed: {'value'} {'msec'}
# FUNC      security_port_sid             : Added params: {'state'}
# FUNC      ep_read_events_proc           : Return type changed: {'kind': 'INT', 'name': 'int'} -> {'kind': 'TYPEDEF', 'name': '__poll_t'}
# FUNC      selinux_msg_queue_alloc_security: Param type changed:
#                                          msq                 : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'msg_queue'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}
#
# FUNC      read_persistent_clock64       : Params added and removed: {'ts'} {'ts64'}
# FUNC      cmp_entries_dup               : Params added and removed: {'a', 'b'} {'A', 'B'}
# FUNC      security_mls_enabled          : Added params: {'state'}
# FUNC      _opp_add                      : Added params: {'rate_not_available'}
# FUNC      mls_import_netlbl_lvl         : Added params: {'p'}
# FUNC      proc_sys_poll                 : Return type changed: {'kind': 'INT', 'name': 'unsigned int'} -> {'kind': 'TYPEDEF', 'name': '__poll_t'}
# FUNC      smack_sem_associate           : Params added and removed: {'isp'} {'sma'}
# FUNC      __uncore_event_show           : Params added and removed: {'kobj'} {'dev'}
# FUNC      sparse_mem_map_populate       : Added params: {'altmap'}
# FUNC      validate_xmit_skb_list        : Added params: {'again'}
# FUNC      __acpi_device_wakeup_enable   : Added params: {'max_count'}
# FUNC      security_read_policy          : Added params: {'state'}
# FUNC      sch_direct_xmit               : Return type changed: {'kind': 'INT', 'name': 'int'} -> {'kind': 'TYPEDEF', 'name': 'bool'}
# FUNC      mfill_zeropage                : Added params: {'mmap_changing'}
# FUNC      i85x_stolen_base              : Param type changed:
#                                          stolen_size         : {'kind': 'TYPEDEF', 'name': 'size_t'}
#                                                              ->{'kind': 'TYPEDEF', 'name': 'resource_size_t'}
#
# FUNC      fuse_file_poll                : Return type changed: {'kind': 'INT', 'name': 'unsigned int'} -> {'kind': 'TYPEDEF', 'name': '__poll_t'}
# FUNC      queue_io                      : Removed params: {'dirtied_before'}
# FUNC      timespec64_add_safe           : Param type changed:
#                                          lhs                 : {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}
#                                                              ->{'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}
#                                          rhs                 : {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}
#                                                              ->{'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}
#
# FUNC      fscrypt_fname_alloc_buffer    : Params added and removed: {'max_encrypted_len'} {'ilen'}
# FUNC      input_mt_report_slot_state    : Return type changed: {'name': 'void', 'kind': 'VOID'} -> {'kind': 'TYPEDEF', 'name': 'bool'}
# FUNC      __uncore_xbr_mask_show        : Params added and removed: {'kobj'} {'dev'}
# FUNC      hist_field_none               : Added params: {'rbe', 'elt'}
# FUNC      security_settime64            : Param type changed:
#                                          ts                  : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}}
#
# FUNC      fib6_age                      : Param type changed:
#                                          rt                  : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'rt6_info'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'fib6_info'}}
#
# FUNC      tpm_transmit_cmd              : Param type changed:
#                                          buf                 : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'name': 'void', 'kind': 'VOID'}}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'name': 'void', 'kind': 'VOID'}}
#
# FUNC      __uncore_thr_show             : Params added and removed: {'kobj'} {'dev'}
# FUNC      ip6mr_destroy_unres           : Param type changed:
#                                          mrt                 : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'mr6_table'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'mr_table'}}
#
# FUNC      __uncore_event2_show          : Params added and removed: {'kobj'} {'dev'}
# FUNC      hist_field_u8                 : Added params: {'rbe', 'elt'}
# FUNC      ip6_route_input_lookup        : Added params: {'skb'}
# FUNC      security_context_to_sid_force : Added params: {'state'}
# FUNC      __uncore_edge_show            : Params added and removed: {'kobj'} {'dev'}
# FUNC      watchdog_core_data_release    : Params added and removed: {'kref'} {'dev'}
# FUNC      squashfs_read_xattr_id_table  : Params added and removed: {'start'} {'table_start'}
# FUNC      pci_epc_set_bar               : Params added and removed: {'epf_bar', 'func_no'} {'size', 'bar_phys', 'bar', 'flags'}
# FUNC      __uncore_filter_all_op_show   : Params added and removed: {'kobj'} {'dev'}
# FUNC      show_highest_perf             : Param type changed:
#                                          attr                : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'kobj_attribute'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'attribute'}}
#
# FUNC      update_persistent_clock64     : Params added and removed: {'now'} {'now64'}
# FUNC      security_validate_transition  : Added params: {'state'}
# FUNC      xen_get_wallclock             : Param type changed:
#                                          now                 : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}
#
# FUNC      smack_task_kill               : Params added and removed: {'cred'} {'secid'}
# FUNC      skb_rbtree_purge              : Return type changed: {'kind': 'INT', 'name': 'unsigned int'} -> {'name': 'void', 'kind': 'VOID'}
# FUNC      gen_pool_first_fit            : Removed params: {'start_addr'}
# FUNC      cmos_nvram_read               : Params added and removed: {'val', 'priv'} {'kobj', 'buf', 'filp', 'attr'}
# FUNC      __sys_sendmsg                 : Added params: {'forbid_cmsg_compat'}
# FUNC      dwc2_exit_hibernation         : Params added and removed: {'is_host', 'rem_wakeup', 'reset'} {'restore'}
# FUNC      input_proc_devices_poll       : Return type changed: {'kind': 'INT', 'name': 'unsigned int'} -> {'kind': 'TYPEDEF', 'name': '__poll_t'}
# FUNC      __uncore_filter_local_show    : Params added and removed: {'kobj'} {'dev'}
# FUNC      ipmr_do_expire_process        : Param type changed:
#                                          mrt                 : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'mr6_table'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'mr_table'}}
#
# FUNC      fill_random_ptr_key           : Params added and removed: {'unused'} {'data', 'action', 'nb'}
# FUNC      get_itimerspec64              : Param type changed:
#                                          it                  : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'itimerspec'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'itimerspec64'}}
#
# FUNC      security_get_bools            : Added params: {'state'}
# FUNC      tcp_set_congestion_control    : Removed params: {'cap_net_admin'}
# FUNC      ip6mr_rule_configure          : Added params: {'extack'}
# FUNC      selinux_capable               : Params added and removed: {'audit'} {'opts'}
# FUNC      __uncore_filter_state2_show   : Params added and removed: {'kobj'} {'dev'}
# FUNC      audit_tree_handle_event       : Removed params: {'vfsmount_mark', 'inode_mark'}
# FUNC      ip6_make_skb                  : Added params: {'cork'}
# FUNC      aa_capable                    : Params added and removed: {'audit'} {'opts'}
# FUNC      stacktrace_count_trigger      : Added params: {'event'}
# FUNC      ipv6_add_addr                 : Params added and removed: {'cfg'} {'addr', 'scope', 'prefered_lft', 'peer_addr', 'pfxlen', 'flags', 'valid_lft'}
# FUNC      mr6_netlink_event             : Param type changed:
#                                          mrt                 : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'mr6_table'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'mr_table'}}
#
# FUNC      __uncore_filter_loc_show      : Params added and removed: {'kobj'} {'dev'}
# FUNC      remove_pagetable              : Added params: {'altmap'}
# FUNC      hmm_vma_fault                 : Removed params: {'end', 'write', 'pfns', 'vma', 'start'}
# FUNC      vmf_insert_pfn_pud            : Params added and removed: {'addr', 'pud', 'vma'} {'vmf'}
# FUNC      addrconf_get_prefix_route     : Return type changed: {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'rt6_info'}} -> {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'fib6_info'}}
# FUNC      rt6_dump_route                : Param type changed:
#                                          rt                  : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'rt6_info'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'fib6_info'}}
#
# FUNC      kvm_set_wallclock             : Param type changed:
#                                          now                 : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}}
#
# FUNC      inotify_poll                  : Return type changed: {'kind': 'INT', 'name': 'unsigned int'} -> {'kind': 'TYPEDEF', 'name': '__poll_t'}
# FUNC      ip6_rt_update_pmtu            : Removed params: {'confirm_neigh'}
# FUNC      print_track                   : Added params: {'pr_time'}
# FUNC      fib6_rule_lookup              : Added params: {'skb'}
# FUNC      poll_select_set_timeout       : Param type changed:
#                                          to                  : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}
#
# FUNC      __uncore_filter_tid4_show     : Params added and removed: {'kobj'} {'dev'}
# FUNC      ip6mr_update_thresholds       : Param type changed:
#                                          mrt                 : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'mr6_table'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'mr_table'}}
#                                          cache               : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'mfc6_cache'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'mr_mfc'}}
#
# FUNC      nf_queue_nf_hook_drop         : Return type changed: {'kind': 'INT', 'name': 'unsigned int'} -> {'name': 'void', 'kind': 'VOID'}
# FUNC      tca_action_flush              : Added params: {'extack'}
# FUNC      init_memory_block             : Params added and removed: {'section'} {'block_id'}
# FUNC      __uncore_filter_state5_show   : Params added and removed: {'kobj'} {'dev'}
# FUNC      proc_map_files_instantiate    : Removed params: {'dir'}
# FUNC      fib6_clean_tohost             : Param type changed:
#                                          rt                  : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'rt6_info'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'fib6_info'}}
#
# FUNC      __ip6_route_redirect          : Added params: {'skb'}
# FUNC      ud_cursor                     : Added params: {'softback_lines'}
# FUNC      ip6mr_new_table               : Return type changed: {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'mr6_table'}} -> {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'mr_table'}}
# FUNC      perf_poll                     : Return type changed: {'kind': 'INT', 'name': 'unsigned int'} -> {'kind': 'TYPEDEF', 'name': '__poll_t'}
# FUNC      timekeeping_inject_sleeptime64: Param type changed:
#                                          delta               : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}
#
# FUNC      event_triggers_call           : Added params: {'event'}
# FUNC      tracing_poll_pipe             : Return type changed: {'kind': 'INT', 'name': 'unsigned int'} -> {'kind': 'TYPEDEF', 'name': '__poll_t'}
# FUNC      hpet_poll                     : Return type changed: {'kind': 'INT', 'name': 'unsigned int'} -> {'kind': 'TYPEDEF', 'name': '__poll_t'}
# FUNC      security_ib_pkey_sid          : Added params: {'state'}
# FUNC      rt6_add_nexthop               : Param type changed:
#                                          rt                  : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'rt6_info'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'fib6_info'}}
#
# FUNC      trace_event_raw_event_aer_event: Added params: {'tlp', 'tlp_header_valid'}
# FUNC      trace_event_raw_event_mm_vmscan_lru_shrink_inactive: Params added and removed: {'stat'} {'nr_writeback', 'nr_unmap_fail', 'nr_congested', 'nr_ref_keep', 'nr_immediate', 'nr_activate', 'nr_dirty'}
# FUNC      ftrace_trace_userstack        : Removed params: {'tr'}
# FUNC      secure_ipv4_port_ephemeral    : Return type changed: {'kind': 'TYPEDEF', 'name': 'u64'} -> {'kind': 'TYPEDEF', 'name': 'u32'}
# FUNC      tcf_block_get_ext             : Added params: {'extack'}
# FUNC      security_fs_use               : Added params: {'state'}
# FUNC      get_random_bytes              : Params added and removed: {'nbytes'} {'len'}
# FUNC      __pci_msi_desc_mask_irq       : Return type changed: {'name': 'void', 'kind': 'VOID'} -> {'kind': 'TYPEDEF', 'name': 'u32'}
# FUNC      __uncore_pgt_show             : Params added and removed: {'kobj'} {'dev'}
# FUNC      pipe_poll                     : Return type changed: {'kind': 'INT', 'name': 'unsigned int'} -> {'kind': 'TYPEDEF', 'name': '__poll_t'}
# FUNC      cpufreq_stats_update          : Return type changed: {'kind': 'INT', 'name': 'int'} -> {'name': 'void', 'kind': 'VOID'}
# FUNC      ipmr_update_thresholds        : Param type changed:
#                                          cache               : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'mfc_cache'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'mr_mfc'}}
#
# FUNC      pciehp_is_native              : Params added and removed: {'bridge'} {'pdev'}
# FUNC      copy_verifier_state           : Params added and removed: {'dst_state'} {'dst'}
# FUNC      tcf_action_init_1             : Added params: {'extack'}
# FUNC      nf_queue_entry_get_refs       : Return type changed: {'kind': 'TYPEDEF', 'name': 'bool'} -> {'name': 'void', 'kind': 'VOID'}
# FUNC      do_timer_settime              : Param type changed:
#                                          new_spec64          : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'itimerspec'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'itimerspec64'}}
#                                          old_spec64          : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'itimerspec'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'itimerspec64'}}
#
# FUNC      io_err_release_clone_rq       : Removed params: {'map_context'}
# FUNC      security_sem_semctl           : Param type changed:
#                                          sma                 : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'sem_array'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}
#
# FUNC      tp_prog_func_proto            : Added params: {'prog'}
# FUNC      posix_clock_realtime_get      : Param type changed:
#                                          tp                  : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}
#
# FUNC      proc_reg_poll                 : Return type changed: {'kind': 'INT', 'name': 'unsigned int'} -> {'kind': 'TYPEDEF', 'name': '__poll_t'}
# FUNC      wbt_requeue                   : Params added and removed: {'rq'} {'stat'}
# FUNC      tomoyo_poll_query             : Return type changed: {'kind': 'INT', 'name': 'unsigned int'} -> {'kind': 'TYPEDEF', 'name': '__poll_t'}
# FUNC      scsi_dev_info_remove_list     : Param type changed:
#                                          key                 : {'kind': 'INT', 'name': 'int'}
#                                                              ->{'kind': 'ENUM', 'name': 'scsi_devinfo_key', 'size': 4}
#
# FUNC      skb_get_hash_perturb          : Param type changed:
#                                          perturb             : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'siphash_key_t'}}}
#                                                              ->{'kind': 'TYPEDEF', 'name': 'u32'}
#
# FUNC      security_sem_alloc            : Param type changed:
#                                          sma                 : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'sem_array'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}
#
# FUNC      event_enable_count_trigger    : Added params: {'event'}
# FUNC      __scsi_queue_insert           : Param type changed:
#                                          unbusy              : {'kind': 'INT', 'name': 'int'}
#                                                              ->{'kind': 'TYPEDEF', 'name': 'bool'}
#
# FUNC      put_itimerspec64              : Param type changed:
#                                          it                  : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'itimerspec'}}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'itimerspec64'}}}
#
# FUNC      fb_deferred_io_fault          : Return type changed: {'kind': 'INT', 'name': 'int'} -> {'kind': 'TYPEDEF', 'name': 'vm_fault_t'}
# FUNC      dax_finish_sync_fault         : Return type changed: {'kind': 'INT', 'name': 'int'} -> {'kind': 'TYPEDEF', 'name': 'vm_fault_t'}
# FUNC      tomoyo_poll_log               : Return type changed: {'kind': 'INT', 'name': 'unsigned int'} -> {'kind': 'TYPEDEF', 'name': '__poll_t'}
# FUNC      udp_poll                      : Return type changed: {'kind': 'INT', 'name': 'unsigned int'} -> {'kind': 'TYPEDEF', 'name': '__poll_t'}
# FUNC      print_bpf_insn                : Params added and removed: {'cbs'} {'env', 'verbose'}
# FUNC      posix_cpu_timer_get           : Param type changed:
#                                          itp                 : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'itimerspec'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'itimerspec64'}}
#
# FUNC      __uncore_filter_opc3_show     : Params added and removed: {'kobj'} {'dev'}
# FUNC      do_sys_poll                   : Param type changed:
#                                          end_time            : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}
#
# FUNC      device_wakeup_attach_irq      : Return type changed: {'kind': 'INT', 'name': 'int'} -> {'name': 'void', 'kind': 'VOID'}
# FUNC      security_change_sid           : Added params: {'state'}
# FUNC      mach_get_cmos_time            : Param type changed:
#                                          now                 : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}
#
# FUNC      selinux_msg_queue_associate   : Param type changed:
#                                          msq                 : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'msg_queue'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}
#
# FUNC      snapshot_count_trigger        : Added params: {'event'}
# FUNC      compat_get_timespec64         : Param type changed:
#                                          ts                  : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}
#
# FUNC      fanotify_poll                 : Return type changed: {'kind': 'INT', 'name': 'unsigned int'} -> {'kind': 'TYPEDEF', 'name': '__poll_t'}
# FUNC      avc_node_replace              : Added params: {'avc'}
# FUNC      posix_clock_poll              : Return type changed: {'kind': 'INT', 'name': 'unsigned int'} -> {'kind': 'TYPEDEF', 'name': '__poll_t'}
# FUNC      ns_capable_common             : Params added and removed: {'audit'} {'opts'}
# FUNC      request_key_auth_new          : Removed params: {'op'}
# FUNC      print_verifier_state          : Param type changed:
#                                          state               : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'bpf_verifier_state'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'bpf_func_state'}}}
#
# FUNC      kernfs_vma_fault              : Return type changed: {'kind': 'INT', 'name': 'int'} -> {'kind': 'TYPEDEF', 'name': 'vm_fault_t'}
# FUNC      klp_shadow_free               : Added params: {'dtor'}
# FUNC      evtchn_2l_handle_events       : Removed params: {'ctrl'}
# FUNC      inet_getname                  : Removed params: {'uaddr_len'}
# FUNC      memory_failure_queue          : Removed params: {'trapno'}
# FUNC      __uncore_filter_link2_show    : Params added and removed: {'kobj'} {'dev'}
# FUNC      complete_request_key          : Params added and removed: {'cons'} {'authkey'}
# FUNC      blk_stat_add                  : Added params: {'now'}
# FUNC      sg_poll                       : Return type changed: {'kind': 'INT', 'name': 'unsigned int'} -> {'kind': 'TYPEDEF', 'name': '__poll_t'}
# FUNC      ip6_rt_cache_alloc            : Param type changed:
#                                          ort                 : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'rt6_info'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'fib6_info'}}
#
# FUNC      klp_shadow_free_all           : Added params: {'dtor'}
# FUNC      rt6_score_route               : Param type changed:
#                                          rt                  : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'rt6_info'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'fib6_info'}}
#
# FUNC      audit_watch_handle_event      : Removed params: {'vfsmount_mark', 'inode_mark'}
# FUNC      common_timer_get              : Param type changed:
#                                          cur_setting         : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'itimerspec'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'itimerspec64'}}
#
# FUNC      __uncore_thresh5_show         : Params added and removed: {'kobj'} {'dev'}
# FUNC      cpu_matches                   : Removed params: {'table'}
# FUNC      rb_add_time_stamp             : Added params: {'abs'}
# FUNC      security_genfs_sid            : Added params: {'state'}
# FUNC      fib4_rule_configure           : Added params: {'extack'}
# FUNC      thread_cpu_clock_get          : Param type changed:
#                                          tp                  : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}
#
# FUNC      __synchronize_hardirq         : Removed params: {'sync_chip'}
# FUNC      traceoff_count_trigger        : Added params: {'event'}
# FUNC      jbd2_journal_file_inode       : Removed params: {'end_byte', 'start_byte'}
# FUNC      kill_pid_info_as_cred         : Removed params: {'secid'}
# FUNC      tcp_check_req                 : Added params: {'req_stolen'}
# FUNC      rfkill_fop_poll               : Return type changed: {'kind': 'INT', 'name': 'unsigned int'} -> {'kind': 'TYPEDEF', 'name': '__poll_t'}
# FUNC      kmem_cache_create             : Param type changed:
#                                          size                : {'kind': 'TYPEDEF', 'name': 'size_t'}
#                                                              ->{'kind': 'INT', 'name': 'unsigned int'}
#                                          align               : {'kind': 'TYPEDEF', 'name': 'size_t'}
#                                                              ->{'kind': 'INT', 'name': 'unsigned int'}
#
# FUNC      bsg_setup_queue               : Removed params: {'release'}
# FUNC      mix_pool_bytes                : Params added and removed: {'r', 'in', 'nbytes'} {'len', 'buf'}
# FUNC      hmm_devmem_release            : Added params: {'dev'}
# FUNC      sched_rr_get_interval         : Param type changed:
#                                          t                   : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}
#
# FUNC      tk_debug_account_sleep_time   : Param type changed:
#                                          t                   : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}
#
# FUNC      security_shm_associate        : Param type changed:
#                                          shp                 : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'shmid_kernel'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}
#
# FUNC      smp_call_function_single_async: Param type changed:
#                                          csd                 : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': '__call_single_data'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'call_single_data_t'}}
#
# FUNC      sk_filter_func_proto          : Added params: {'prog'}
# FUNC      ata_bmdma_dumb_qc_prep        : Return type changed: {'kind': 'ENUM', 'name': 'ata_completion_errors', 'size': 4} -> {'name': 'void', 'kind': 'VOID'}
# FUNC      __skb_get_poff                : Param type changed:
#                                          keys                : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'flow_keys'}}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'flow_keys_basic'}}}
#
# FUNC      dax_iomap_fault               : Added params: {'iomap_errp'}
# FUNC      poll_select_copy_remaining    : Param type changed:
#                                          end_time            : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}
#
# FUNC      gen9_stolen_size              : Return type changed: {'kind': 'TYPEDEF', 'name': 'size_t'} -> {'kind': 'TYPEDEF', 'name': 'resource_size_t'}
# FUNC      ip6_pol_route_lookup          : Added params: {'skb'}
# FUNC      ip6mr_fill_mroute             : Param type changed:
#                                          mrt                 : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'mr6_table'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'mr_table'}}
#
# FUNC      security_transition_sid       : Added params: {'state'}
# FUNC      fuse_release_common           : Params added and removed: {'opcode'} {'isdir'}
# FUNC      qdisc_alloc                   : Added params: {'extack'}
# FUNC      set_selection                 : Params added and removed: {'sel'} {'v'}
# FUNC      sparse_remove_one_section     : Added params: {'altmap'}
# FUNC      bad_inode_update_time         : Param type changed:
#                                          time                : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}
#
# FUNC      security_get_reject_unknown   : Added params: {'state'}
# FUNC      pc_clock_settime              : Param type changed:
#                                          ts                  : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}}
#
# FUNC      context_struct_to_string      : Added params: {'p'}
# FUNC      ep_send_events_proc           : Return type changed: {'kind': 'INT', 'name': 'int'} -> {'kind': 'TYPEDEF', 'name': '__poll_t'}
# FUNC      trace_event_raw_event_writeback_queue_io: Removed params: {'dirtied_before'}
# FUNC      selinux_status_update_policyload: Added params: {'state'}
# FUNC      blk_queue_logical_block_size  : Param type changed:
#                                          size                : {'kind': 'INT', 'name': 'unsigned int'}
#                                                              ->{'kind': 'INT', 'name': 'short unsigned int'}
#
# FUNC      __uncore_match_rnid4_show     : Params added and removed: {'kobj'} {'dev'}
# FUNC      ip6mr_cache_find              : Param type changed:
#                                          mrt                 : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'mr6_table'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'mr_table'}}
#
# FUNC      __uncore_event_ext_show       : Params added and removed: {'kobj'} {'dev'}
# FUNC      userfaultfd_poll              : Return type changed: {'kind': 'INT', 'name': 'unsigned int'} -> {'kind': 'TYPEDEF', 'name': '__poll_t'}
# FUNC      __uncore_thresh8_show         : Params added and removed: {'kobj'} {'dev'}
# FUNC      __uncore_count_mode_show      : Params added and removed: {'kobj'} {'dev'}
# FUNC      do_utimes                     : Param type changed:
#                                          times               : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}
# ...
#
# FUNC      bts_buffer_setup_aux          : Params added and removed: {'cpu'} {'event'}
# FUNC      fib_table_flush               : Removed params: {'flush_all'}
# FUNC      shm_fault                     : Return type changed: {'kind': 'INT', 'name': 'int'} -> {'kind': 'TYPEDEF', 'name': 'vm_fault_t'}
# FUNC      kvm_get_wallclock             : Param type changed:
#                                          now                 : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}
#
# FUNC      dst_cache_set_ip6             : Params added and removed: {'saddr'} {'addr'}
# FUNC      rt6_multipath_hash            : Added params: {'net', 'flkeys'}
# FUNC      kernfs_vma_page_mkwrite       : Return type changed: {'kind': 'INT', 'name': 'int'} -> {'kind': 'TYPEDEF', 'name': 'vm_fault_t'}
# FUNC      __uncore_xbr_mm_cfg_show      : Params added and removed: {'kobj'} {'dev'}
# FUNC      security_msg_queue_alloc      : Param type changed:
#                                          msq                 : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'msg_queue'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}
#
# FUNC      common_timer_set              : Param type changed:
#                                          new_setting         : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'itimerspec'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'itimerspec64'}}
#                                          old_setting         : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'itimerspec'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'itimerspec64'}}
#
# FUNC      hist_field_s16                : Added params: {'rbe', 'elt'}
# FUNC      mls_sid_to_context            : Added params: {'p'}
# FUNC      max310x_port_irq              : Return type changed: {'name': 'void', 'kind': 'VOID'} -> {'kind': 'TYPEDEF', 'name': 'irqreturn_t'}
# FUNC      proc_fill_cache               : Param type changed:
#                                          len                 : {'kind': 'INT', 'name': 'int'}
#                                                              ->{'kind': 'INT', 'name': 'unsigned int'}
#
# FUNC      fib6_clean_tree               : Param type changed:
#                                          func                : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'rt6_info'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'name': '(anon)', 'type': {'name': 'void', 'kind': 'VOID'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'fib6_info'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'name': '(anon)', 'type': {'name': 'void', 'kind': 'VOID'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#
# FUNC      num_to_str                    : Added params: {'width'}
# FUNC      pci_reset_bridge_secondary_bus: Return type changed: {'name': 'void', 'kind': 'VOID'} -> {'kind': 'INT', 'name': 'int'}
# FUNC      kallsyms_symbol_next          : Removed params: {'buf_size'}
# FUNC      relay_file_poll               : Return type changed: {'kind': 'INT', 'name': 'unsigned int'} -> {'kind': 'TYPEDEF', 'name': '__poll_t'}
# FUNC      __uncore_filter_tid2_show     : Params added and removed: {'kobj'} {'dev'}
# FUNC      do_mq_timedreceive            : Param type changed:
#                                          ts                  : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}
#
# FUNC      __uncore_filter_opc2_show     : Params added and removed: {'kobj'} {'dev'}
# FUNC      ip6_route_info_create         : Added params: {'gfp_flags'}
# FUNC      smack_shm_shmat               : Params added and removed: {'ipc'} {'shp'}
# FUNC      configfs_new_dirent           : Removed params: {'frag'}
# FUNC      kprobe_perf_func              : Return type changed: {'name': 'void', 'kind': 'VOID'} -> {'kind': 'INT', 'name': 'int'}
# FUNC      ip_mr_forward                 : Params added and removed: {'c'} {'cache'}
# FUNC      xennet_tx_buf_gc              : Return type changed: {'kind': 'TYPEDEF', 'name': 'bool'} -> {'name': 'void', 'kind': 'VOID'}
# FUNC      fb_deferred_io_mkwrite        : Return type changed: {'kind': 'INT', 'name': 'int'} -> {'kind': 'TYPEDEF', 'name': 'vm_fault_t'}
# FUNC      scsi_get_device_flags_keyed   : Param type changed:
#                                          key                 : {'kind': 'INT', 'name': 'int'}
#                                                              ->{'kind': 'ENUM', 'name': 'scsi_devinfo_key', 'size': 4}
#
# FUNC      ip6_ins_rt                    : Added params: {'net'}
# FUNC      do_sys_settimeofday64         : Param type changed:
#                                          tv                  : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}}
#
# FUNC      tcf_generic_walker            : Added params: {'extack'}
# FUNC      add_interrupt_randomness      : Added params: {'irq_flags'}
# FUNC      __dev_map_lookup_elem         : Return type changed: {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'net_device'}} -> {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'bpf_dtab_netdev'}}
# FUNC      qdisc_create                  : Added params: {'extack'}
# FUNC      memory_block_action           : Params added and removed: {'phys_index'} {'start_section_nr'}
# FUNC      rtc_dev_poll                  : Return type changed: {'kind': 'INT', 'name': 'unsigned int'} -> {'kind': 'TYPEDEF', 'name': '__poll_t'}
# FUNC      vmf_insert_pfn_pmd            : Params added and removed: {'addr', 'vma', 'pmd'} {'vmf'}
# FUNC      ep_eventpoll_poll             : Return type changed: {'kind': 'INT', 'name': 'unsigned int'} -> {'kind': 'TYPEDEF', 'name': '__poll_t'}
# FUNC      ring_buffer_read_prepare      : Removed params: {'flags'}
# FUNC      security_policydb_len         : Added params: {'state'}
# FUNC      swaps_poll                    : Return type changed: {'kind': 'INT', 'name': 'unsigned int'} -> {'kind': 'TYPEDEF', 'name': '__poll_t'}
# FUNC      ipv6_chk_addr_and_flags       : Added params: {'skip_dev_check'}
# FUNC      relay_buf_fault               : Return type changed: {'kind': 'INT', 'name': 'int'} -> {'kind': 'TYPEDEF', 'name': 'vm_fault_t'}
# FUNC      xhci_endpoint_reset           : Params added and removed: {'host_ep'} {'ep'}
# FUNC      scsi_dev_info_list_del_keyed  : Param type changed:
#                                          key                 : {'kind': 'INT', 'name': 'int'}
#                                                              ->{'kind': 'ENUM', 'name': 'scsi_devinfo_key', 'size': 4}
#
# FUNC      __uncore_wrap_mode_show       : Params added and removed: {'kobj'} {'dev'}
# FUNC      __sys_recvmsg                 : Added params: {'forbid_cmsg_compat'}
# FUNC      perf_trace_aer_event          : Added params: {'tlp', 'tlp_header_valid'}
# FUNC      sock_poll                     : Return type changed: {'kind': 'INT', 'name': 'unsigned int'} -> {'kind': 'TYPEDEF', 'name': '__poll_t'}
# FUNC      bpf_convert_filter            : Added params: {'seen_ld_abs'}
# FUNC      dax_unlock_mapping_entry      : Params added and removed: {'page'} {'index', 'mapping'}
# FUNC      tpm_is_tpm2                   : Params added and removed: {'chip'} {'chip_num'}
# FUNC      prandom_reseed                : Removed params: {'unused'}
# FUNC      posix_clock_realtime_set      : Param type changed:
#                                          tp                  : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}}
#
# FUNC      bq_flush_to_queue             : Added params: {'in_napi_ctx'}
# FUNC      kauditd_retry_skb             : Removed params: {'error'}
# FUNC      __ip6_rt_update_pmtu          : Removed params: {'confirm_neigh'}
# FUNC      __uncore_filter_band1_show    : Params added and removed: {'kobj'} {'dev'}
# FUNC      __uncore_set_flag_sel_show    : Params added and removed: {'kobj'} {'dev'}
# FUNC      hist_field_s64                : Added params: {'rbe', 'elt'}
# FUNC      _iommu_event_show             : Params added and removed: {'kobj'} {'dev'}
# FUNC      nohz_balance_exit_idle        : Params added and removed: {'rq'} {'cpu'}
# FUNC      show_reference_perf           : Param type changed:
#                                          attr                : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'kobj_attribute'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'attribute'}}
#
# FUNC      validate_xmit_skb             : Added params: {'again'}
# FUNC      __uncore_inv_show             : Params added and removed: {'kobj'} {'dev'}
# FUNC      avc_denied                    : Added params: {'state'}
# FUNC      timerfd_poll                  : Return type changed: {'kind': 'INT', 'name': 'unsigned int'} -> {'kind': 'TYPEDEF', 'name': '__poll_t'}
# FUNC      security_node_sid             : Added params: {'state'}
# FUNC      __check_heap_object           : Added params: {'to_user'}
# FUNC      mls_import_netlbl_cat         : Added params: {'p'}
# FUNC      show_nominal_perf             : Param type changed:
#                                          attr                : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'kobj_attribute'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'attribute'}}
#
# FUNC      crypto_gcm_create_common      : Added params: {'full_name'}
# FUNC      chv_stolen_size               : Return type changed: {'kind': 'TYPEDEF', 'name': 'size_t'} -> {'kind': 'TYPEDEF', 'name': 'resource_size_t'}
# FUNC      unix_getname                  : Removed params: {'uaddr_len'}
# FUNC      cgroup_dev_is_valid_access    : Added params: {'prog'}
# FUNC      compat_put_timespec64         : Param type changed:
#                                          ts                  : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}}
#
# FUNC      security_validate_transition_user: Added params: {'state'}
# FUNC      __uncore_qor_show             : Params added and removed: {'kobj'} {'dev'}
# FUNC      lwt_xmit_func_proto           : Added params: {'prog'}
# FUNC      compat_core_sys_select        : Param type changed:
#                                          end_time            : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}
#
# FUNC      __uncore_flag_mode_show       : Params added and removed: {'kobj'} {'dev'}
# FUNC      bind_evtchn_to_irqhandler     : Param type changed:
#                                          evtchn              : {'kind': 'TYPEDEF', 'name': 'evtchn_port_t'}
#                                                              ->{'kind': 'INT', 'name': 'unsigned int'}
#
# FUNC      copy_siginfo_to_user32        : Param type changed:
#                                          to                  : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'compat_siginfo_t'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'compat_siginfo'}}
#                                          from                : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'siginfo_t'}}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'siginfo'}}}
#
# FUNC      blk_alloc_flush_queue         : Removed params: {'flags'}
# FUNC      security_ib_endport_sid       : Added params: {'state'}
# FUNC      klp_shadow_get_or_alloc       : Params added and removed: {'ctor', 'ctor_data'} {'data'}
# FUNC      mls_from_string               : Added params: {'p'}
# FUNC      move_expired_inodes           : Params added and removed: {'work', 'flags'} {'dirtied_before'}
# FUNC      acpi_get_hp_hw_control_from_firmware: Removed params: {'flags'}
# FUNC      pci_epc_map_addr              : Added params: {'func_no'}
# FUNC      show_no_turbo                 : Param type changed:
#                                          attr                : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'kobj_attribute'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'attribute'}}
#
# FUNC      link_mem_sections             : Added params: {'check_nid'}
# FUNC      __netlink_deliver_tap         : Added params: {'nn'}
# FUNC      inet_ehash_insert             : Removed params: {'found_dup_sk'}
# FUNC      __uncore_filter_nid_show      : Params added and removed: {'kobj'} {'dev'}
# FUNC      pc_clock_gettime              : Param type changed:
#                                          ts                  : {'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}
#                                                              ->{'kind': 'PTR', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}
#
# FUNC      __inet_hash_connect           : Param type changed:
#                                          port_offset         : {'kind': 'TYPEDEF', 'name': 'u64'}
#                                                              ->{'kind': 'TYPEDEF', 'name': 'u32'}
