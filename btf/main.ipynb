# %%
# !sudo apt install linux-tools-generic bpftool zstd
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Note, selecting 'linux-tools-common' instead of 'bpftool'
# linux-tools-generic is already the newest version (6.2.0.39.39).
# linux-tools-common is already the newest version (6.2.0-39.40).
# zstd is already the newest version (1.5.4+dfsg2-4).
# 0 upgraded, 0 newly installed, 0 to remove and 2 not upgraded.

# %%
import os


def system(cmd):
    print(f"Running: `{cmd}`")
    os.system(cmd)

# %% [markdown]
# # Getting BTF Files for Ubuntu 20.04

# %%
from pathlib import Path

data_path = Path("data/20.04-x86")
tmp_path = data_path / 'tmp'
tmp_path.mkdir(parents=True, exist_ok=True)

# %%
import urllib.request
import gzip

def download_package_index():
    url = "http://security.ubuntu.com/ubuntu/dists/focal-security/main/binary-amd64/Packages.gz"
    gz_path = tmp_path / "Packages.gz"

    if not gz_path.exists():
        print(f"Downloading {url} to {gz_path}")
        urllib.request.urlretrieve(url, gz_path)
    else:
        print(f"Using {gz_path}")

    package_path = gz_path.with_suffix("")
    if not package_path.with_suffix("").exists():
        print(f"Unzipping {gz_path} to {package_path}")
        with gzip.open(gz_path, 'rb') as f_in:
            with open(package_path, 'wb') as f_out:
                f_out.write(f_in.read())
    else:
        print(f"Using {package_path}")

    return package_path


package_path = download_package_index()
package_path
# Out:
# Using data/20.04-x86/tmp/Packages.gz
# Using data/20.04-x86/tmp/Packages
# PosixPath('data/20.04-x86/tmp/Packages')

# %%
def parse_package_index(package_path):
    result = {}
    with open(package_path) as f:
        for line in f:
            line = line.strip()
            if not line:
                continue

            key, val = line.split(": ", 1)
            if key == "Package":
                package = val
            elif key == "Filename":
                result[package] = val
    return result


package_index = parse_package_index(package_path)

package_index
# Out:
# {'accountsservice': 'pool/main/a/accountsservice/accountsservice_0.6.55-0ubuntu12~20.04.6_amd64.deb',
#  'adcli': 'pool/main/a/adcli/adcli_0.9.0-1ubuntu0.20.04.1_amd64.deb',
#  'adsys': 'pool/main/a/adsys/adsys_0.9.2~20.04.1_amd64.deb',
#  'adsys-windows': 'pool/main/a/adsys/adsys-windows_0.9.2~20.04.1_amd64.deb',
#  'advancecomp': 'pool/main/a/advancecomp/advancecomp_2.1-2.1ubuntu0.20.04.1_amd64.deb',
#  'aide': 'pool/main/a/aide/aide_0.16.1-1ubuntu0.1_amd64.deb',
#  'aide-common': 'pool/main/a/aide/aide-common_0.16.1-1ubuntu0.1_all.deb',
#  'amd64-microcode': 'pool/main/a/amd64-microcode/amd64-microcode_3.20191218.1ubuntu1.2_amd64.deb',
#  'apache2': 'pool/main/a/apache2/apache2_2.4.41-4ubuntu3.15_amd64.deb',
#  'apache2-bin': 'pool/main/a/apache2/apache2-bin_2.4.41-4ubuntu3.15_amd64.deb',
#  'apache2-data': 'pool/main/a/apache2/apache2-data_2.4.41-4ubuntu3.15_all.deb',
#  'apache2-dev': 'pool/main/a/apache2/apache2-dev_2.4.41-4ubuntu3.15_amd64.deb',
#  'apache2-doc': 'pool/main/a/apache2/apache2-doc_2.4.41-4ubuntu3.15_all.deb',
#  'apache2-ssl-dev': 'pool/main/a/apache2/apache2-ssl-dev_2.4.41-4ubuntu3.15_amd64.deb',
#  'apache2-utils': 'pool/main/a/apache2/apache2-utils_2.4.41-4ubuntu3.15_amd64.deb',
#  'apport': 'pool/main/a/apport/apport_2.20.11-0ubuntu27.26_all.deb',
#  'apport-gtk': 'pool/main/a/apport/apport-gtk_2.20.11-0ubuntu27.26_all.deb',
#  'apport-retrace': 'pool/main/a/apport/apport-retrace_2.20.11-0ubuntu27.26_all.deb',
#  'apt': 'pool/main/a/apt/apt_2.0.2ubuntu0.2_amd64.deb',
#  'apt-doc': 'pool/main/a/apt/apt-doc_2.0.2ubuntu0.2_all.deb',
#  'apt-utils': 'pool/main/a/apt/apt-utils_2.0.2ubuntu0.2_amd64.deb',
#  'aptdaemon': 'pool/main/a/aptdaemon/aptdaemon_1.1.1+bzr982-0ubuntu32.3_all.deb',
#  'aptdaemon-data': 'pool/main/a/aptdaemon/aptdaemon-data_1.1.1+bzr982-0ubuntu32.3_all.deb',
#  'aspell': 'pool/main/a/aspell/aspell_0.60.8-1ubuntu0.1_amd64.deb',
#  'aspell-doc': 'pool/main/a/aspell/aspell-doc_0.60.8-1ubuntu0.1_all.deb',
#  'avahi-autoipd': 'pool/main/a/avahi/avahi-autoipd_0.7-4ubuntu7.3_amd64.deb',
#  'avahi-daemon': 'pool/main/a/avahi/avahi-daemon_0.7-4ubuntu7.3_amd64.deb',
#  'avahi-utils': 'pool/main/a/avahi/avahi-utils_0.7-4ubuntu7.3_amd64.deb',
#  'awstats': 'pool/main/a/awstats/awstats_7.6+dfsg-2ubuntu0.20.04.2_all.deb',
#  'backuppc': 'pool/main/b/backuppc/backuppc_3.3.2-3ubuntu0.3_amd64.deb',
#  'barbican-api': 'pool/main/b/barbican/barbican-api_10.1.0-0ubuntu2.2_all.deb',
#  'barbican-common': 'pool/main/b/barbican/barbican-common_10.1.0-0ubuntu2.2_all.deb',
#  'barbican-doc': 'pool/main/b/barbican/barbican-doc_10.1.0-0ubuntu2.2_all.deb',
#  'barbican-keystone-listener': 'pool/main/b/barbican/barbican-keystone-listener_10.1.0-0ubuntu2.2_all.deb',
#  'barbican-worker': 'pool/main/b/barbican/barbican-worker_10.1.0-0ubuntu2.2_all.deb',
#  'bash': 'pool/main/b/bash/bash_5.0-6ubuntu1.2_amd64.deb',
#  'bash-doc': 'pool/main/b/bash/bash-doc_5.0-6ubuntu1.2_all.deb',
#  'bind9': 'pool/main/b/bind9/bind9_9.16.1-0ubuntu2.16_amd64.deb',
#  'bind9-dnsutils': 'pool/main/b/bind9/bind9-dnsutils_9.16.1-0ubuntu2.16_amd64.deb',
#  'bind9-doc': 'pool/main/b/bind9/bind9-doc_9.16.1-0ubuntu2.16_all.deb',
#  'bind9-host': 'pool/main/b/bind9/bind9-host_9.16.1-0ubuntu2.16_amd64.deb',
#  'bind9-libs': 'pool/main/b/bind9/bind9-libs_9.16.1-0ubuntu2.16_amd64.deb',
#  'bind9-utils': 'pool/main/b/bind9/bind9-utils_9.16.1-0ubuntu2.16_amd64.deb',
#  'binutils': 'pool/main/b/binutils/binutils_2.34-6ubuntu1.8_amd64.deb',
#  'binutils-aarch64-linux-gnu': 'pool/main/b/binutils/binutils-aarch64-linux-gnu_2.34-6ubuntu1.8_amd64.deb',
#  'binutils-aarch64-linux-gnu-dbg': 'pool/main/b/binutils/binutils-aarch64-linux-gnu-dbg_2.34-6ubuntu1.8_amd64.deb',
#  'binutils-arm-linux-gnueabihf': 'pool/main/b/binutils/binutils-arm-linux-gnueabihf_2.34-6ubuntu1.8_amd64.deb',
#  'binutils-arm-linux-gnueabihf-dbg': 'pool/main/b/binutils/binutils-arm-linux-gnueabihf-dbg_2.34-6ubuntu1.8_amd64.deb',
#  'binutils-common': 'pool/main/b/binutils/binutils-common_2.34-6ubuntu1.8_amd64.deb',
#  'binutils-dev': 'pool/main/b/binutils/binutils-dev_2.34-6ubuntu1.8_amd64.deb',
#  'binutils-doc': 'pool/main/b/binutils/binutils-doc_2.34-6ubuntu1.8_all.deb',
#  'binutils-i686-gnu': 'pool/main/b/binutils/binutils-i686-gnu_2.34-6ubuntu1.8_amd64.deb',
#  'binutils-i686-gnu-dbg': 'pool/main/b/binutils/binutils-i686-gnu-dbg_2.34-6ubuntu1.8_amd64.deb',
#  'binutils-i686-kfreebsd-gnu': 'pool/main/b/binutils/binutils-i686-kfreebsd-gnu_2.34-6ubuntu1.8_amd64.deb',
#  'binutils-i686-kfreebsd-gnu-dbg': 'pool/main/b/binutils/binutils-i686-kfreebsd-gnu-dbg_2.34-6ubuntu1.8_amd64.deb',
#  'binutils-i686-linux-gnu': 'pool/main/b/binutils/binutils-i686-linux-gnu_2.34-6ubuntu1.8_amd64.deb',
#  'binutils-i686-linux-gnu-dbg': 'pool/main/b/binutils/binutils-i686-linux-gnu-dbg_2.34-6ubuntu1.8_amd64.deb',
#  'binutils-multiarch': 'pool/main/b/binutils/binutils-multiarch_2.34-6ubuntu1.8_amd64.deb',
#  'binutils-multiarch-dbg': 'pool/main/b/binutils/binutils-multiarch-dbg_2.34-6ubuntu1.8_amd64.deb',
#  'binutils-multiarch-dev': 'pool/main/b/binutils/binutils-multiarch-dev_2.34-6ubuntu1.8_amd64.deb',
#  'binutils-powerpc-linux-gnu': 'pool/main/b/binutils/binutils-powerpc-linux-gnu_2.34-6ubuntu1.8_amd64.deb',
#  'binutils-powerpc-linux-gnu-dbg': 'pool/main/b/binutils/binutils-powerpc-linux-gnu-dbg_2.34-6ubuntu1.8_amd64.deb',
#  'binutils-powerpc64le-linux-gnu': 'pool/main/b/binutils/binutils-powerpc64le-linux-gnu_2.34-6ubuntu1.8_amd64.deb',
#  'binutils-powerpc64le-linux-gnu-dbg': 'pool/main/b/binutils/binutils-powerpc64le-linux-gnu-dbg_2.34-6ubuntu1.8_amd64.deb',
#  'binutils-riscv64-linux-gnu': 'pool/main/b/binutils/binutils-riscv64-linux-gnu_2.34-6ubuntu1.8_amd64.deb',
#  'binutils-s390x-linux-gnu': 'pool/main/b/binutils/binutils-s390x-linux-gnu_2.34-6ubuntu1.8_amd64.deb',
#  'binutils-s390x-linux-gnu-dbg': 'pool/main/b/binutils/binutils-s390x-linux-gnu-dbg_2.34-6ubuntu1.8_amd64.deb',
#  'binutils-x86-64-kfreebsd-gnu': 'pool/main/b/binutils/binutils-x86-64-kfreebsd-gnu_2.34-6ubuntu1.8_amd64.deb',
#  'binutils-x86-64-kfreebsd-gnu-dbg': 'pool/main/b/binutils/binutils-x86-64-kfreebsd-gnu-dbg_2.34-6ubuntu1.8_amd64.deb',
#  'binutils-x86-64-linux-gnu': 'pool/main/b/binutils/binutils-x86-64-linux-gnu_2.34-6ubuntu1.8_amd64.deb',
#  'binutils-x86-64-linux-gnu-dbg': 'pool/main/b/binutils/binutils-x86-64-linux-gnu-dbg_2.34-6ubuntu1.8_amd64.deb',
#  'binutils-x86-64-linux-gnux32': 'pool/main/b/binutils/binutils-x86-64-linux-gnux32_2.34-6ubuntu1.8_amd64.deb',
#  'binutils-x86-64-linux-gnux32-dbg': 'pool/main/b/binutils/binutils-x86-64-linux-gnux32-dbg_2.34-6ubuntu1.8_amd64.deb',
#  'bluez': 'pool/main/b/bluez/bluez_5.53-0ubuntu3.7_amd64.deb',
#  'bluez-cups': 'pool/main/b/bluez/bluez-cups_5.53-0ubuntu3.7_amd64.deb',
#  'bluez-dbg': 'pool/main/b/bluez/bluez-dbg_5.53-0ubuntu3.7_amd64.deb',
#  'bluez-obexd': 'pool/main/b/bluez/bluez-obexd_5.53-0ubuntu3.7_amd64.deb',
#  'bsdutils': 'pool/main/u/util-linux/bsdutils_2.34-0.1ubuntu9.3_amd64.deb',
#  'busybox-initramfs': 'pool/main/b/busybox/busybox-initramfs_1.30.1-4ubuntu6.4_amd64.deb',
#  'busybox-static': 'pool/main/b/busybox/busybox-static_1.30.1-4ubuntu6.4_amd64.deb',
#  'busybox-syslogd': 'pool/main/b/busybox/busybox-syslogd_1.30.1-4ubuntu6.4_all.deb',
#  'ca-certificates': 'pool/main/c/ca-certificates/ca-certificates_20230311ubuntu0.20.04.1_all.deb',
#  'ca-certificates-java': 'pool/main/c/ca-certificates-java/ca-certificates-java_20190405ubuntu1.1_all.deb',
#  'ceph': 'pool/main/c/ceph/ceph_15.2.17-0ubuntu0.20.04.3_amd64.deb',
#  'ceph-base': 'pool/main/c/ceph/ceph-base_15.2.17-0ubuntu0.20.04.3_amd64.deb',
#  'ceph-common': 'pool/main/c/ceph/ceph-common_15.2.17-0ubuntu0.20.04.3_amd64.deb',
#  'ceph-mds': 'pool/main/c/ceph/ceph-mds_15.2.17-0ubuntu0.20.04.3_amd64.deb',
#  'ceph-mgr': 'pool/main/c/ceph/ceph-mgr_15.2.17-0ubuntu0.20.04.3_amd64.deb',
#  'ceph-mgr-modules-core': 'pool/main/c/ceph/ceph-mgr-modules-core_15.2.17-0ubuntu0.20.04.3_all.deb',
#  'ceph-mon': 'pool/main/c/ceph/ceph-mon_15.2.17-0ubuntu0.20.04.3_amd64.deb',
#  'ceph-osd': 'pool/main/c/ceph/ceph-osd_15.2.17-0ubuntu0.20.04.3_amd64.deb',
#  'chrony': 'pool/main/c/chrony/chrony_3.5-6ubuntu6.2_amd64.deb',
#  'cifs-utils': 'pool/main/c/cifs-utils/cifs-utils_6.9-1ubuntu0.2_amd64.deb',
#  'cinder-api': 'pool/main/c/cinder/cinder-api_16.4.2-0ubuntu2.4_all.deb',
#  'cinder-backup': 'pool/main/c/cinder/cinder-backup_16.4.2-0ubuntu2.4_all.deb',
#  'cinder-common': 'pool/main/c/cinder/cinder-common_16.4.2-0ubuntu2.4_all.deb',
#  'cinder-scheduler': 'pool/main/c/cinder/cinder-scheduler_16.4.2-0ubuntu2.4_all.deb',
#  'cinder-volume': 'pool/main/c/cinder/cinder-volume_16.4.2-0ubuntu2.4_all.deb',
#  'clamav': 'pool/main/c/clamav/clamav_0.103.11+dfsg-0ubuntu0.20.04.1_amd64.deb',
#  'clamav-base': 'pool/main/c/clamav/clamav-base_0.103.11+dfsg-0ubuntu0.20.04.1_all.deb',
#  'clamav-daemon': 'pool/main/c/clamav/clamav-daemon_0.103.11+dfsg-0ubuntu0.20.04.1_amd64.deb',
#  'clamav-docs': 'pool/main/c/clamav/clamav-docs_0.103.11+dfsg-0ubuntu0.20.04.1_all.deb',
#  'clamav-freshclam': 'pool/main/c/clamav/clamav-freshclam_0.103.11+dfsg-0ubuntu0.20.04.1_amd64.deb',
#  'clamdscan': 'pool/main/c/clamav/clamdscan_0.103.11+dfsg-0ubuntu0.20.04.1_amd64.deb',
#  'cloud-init': 'pool/main/c/cloud-init/cloud-init_23.1.2-0ubuntu0~20.04.2_all.deb',
#  'comerr-dev': 'pool/main/e/e2fsprogs/comerr-dev_2.1-1.45.5-2ubuntu1.1_amd64.deb',
#  'containerd': 'pool/main/c/containerd/containerd_1.6.12-0ubuntu1~20.04.3_amd64.deb',
#  'cpio': 'pool/main/c/cpio/cpio_2.13+dfsg-2ubuntu0.3_amd64.deb',
#  'cpp-9': 'pool/main/g/gcc-9/cpp-9_9.4.0-1ubuntu1~20.04.2_amd64.deb',
#  'cpp-9-aarch64-linux-gnu': 'pool/main/g/gcc-9-cross/cpp-9-aarch64-linux-gnu_9.4.0-1ubuntu1~20.04.2cross2_amd64.deb',
#  'cpp-9-arm-linux-gnueabihf': 'pool/main/g/gcc-9-cross/cpp-9-arm-linux-gnueabihf_9.4.0-1ubuntu1~20.04.2cross2_amd64.deb',
#  'cpp-9-doc': 'pool/main/g/gcc-9/cpp-9-doc_9.4.0-1ubuntu1~20.04.2_all.deb',
#  'cpp-9-powerpc64le-linux-gnu': 'pool/main/g/gcc-9-cross/cpp-9-powerpc64le-linux-gnu_9.4.0-1ubuntu1~20.04.2cross2_amd64.deb',
#  'cpp-9-s390x-linux-gnu': 'pool/main/g/gcc-9-cross/cpp-9-s390x-linux-gnu_9.4.0-1ubuntu1~20.04.2cross2_amd64.deb',
#  'cryptsetup': 'pool/main/c/cryptsetup/cryptsetup_2.2.2-3ubuntu2.4_amd64.deb',
#  'cryptsetup-bin': 'pool/main/c/cryptsetup/cryptsetup-bin_2.2.2-3ubuntu2.4_amd64.deb',
#  'cryptsetup-initramfs': 'pool/main/c/cryptsetup/cryptsetup-initramfs_2.2.2-3ubuntu2.4_all.deb',
#  'cryptsetup-run': 'pool/main/c/cryptsetup/cryptsetup-run_2.2.2-3ubuntu2.4_all.deb',
#  'cups': 'pool/main/c/cups/cups_2.3.1-9ubuntu1.6_amd64.deb',
#  'cups-browsed': 'pool/main/c/cups-filters/cups-browsed_1.27.4-1ubuntu0.2_amd64.deb',
#  'cups-bsd': 'pool/main/c/cups/cups-bsd_2.3.1-9ubuntu1.6_amd64.deb',
#  'cups-client': 'pool/main/c/cups/cups-client_2.3.1-9ubuntu1.6_amd64.deb',
#  'cups-common': 'pool/main/c/cups/cups-common_2.3.1-9ubuntu1.6_all.deb',
#  'cups-core-drivers': 'pool/main/c/cups/cups-core-drivers_2.3.1-9ubuntu1.6_amd64.deb',
#  'cups-daemon': 'pool/main/c/cups/cups-daemon_2.3.1-9ubuntu1.6_amd64.deb',
#  'cups-filters': 'pool/main/c/cups-filters/cups-filters_1.27.4-1ubuntu0.2_amd64.deb',
#  'cups-filters-core-drivers': 'pool/main/c/cups-filters/cups-filters-core-drivers_1.27.4-1ubuntu0.2_amd64.deb',
#  'cups-ipp-utils': 'pool/main/c/cups/cups-ipp-utils_2.3.1-9ubuntu1.6_amd64.deb',
#  'cups-ppdc': 'pool/main/c/cups/cups-ppdc_2.3.1-9ubuntu1.6_amd64.deb',
#  'cups-server-common': 'pool/main/c/cups/cups-server-common_2.3.1-9ubuntu1.6_all.deb',
#  'curl': 'pool/main/c/curl/curl_7.68.0-1ubuntu2.21_amd64.deb',
#  'cyrus-sasl2-doc': 'pool/main/c/cyrus-sasl2/cyrus-sasl2-doc_2.1.27+dfsg-2ubuntu0.1_all.deb',
#  'dbus': 'pool/main/d/dbus/dbus_1.12.16-2ubuntu2.3_amd64.deb',
#  'dbus-1-doc': 'pool/main/d/dbus/dbus-1-doc_1.12.16-2ubuntu2.3_all.deb',
#  'dbus-user-session': 'pool/main/d/dbus/dbus-user-session_1.12.16-2ubuntu2.3_amd64.deb',
#  'dbus-x11': 'pool/main/d/dbus/dbus-x11_1.12.16-2ubuntu2.3_amd64.deb',
#  'dirmngr': 'pool/main/g/gnupg2/dirmngr_2.2.19-3ubuntu2.2_amd64.deb',
#  'distro-info-data': 'pool/main/d/distro-info-data/distro-info-data_0.43ubuntu1.10_all.deb',
#  'dnsmasq-base': 'pool/main/d/dnsmasq/dnsmasq-base_2.80-1.1ubuntu1.7_amd64.deb',
#  'dnsmasq-utils': 'pool/main/d/dnsmasq/dnsmasq-utils_2.80-1.1ubuntu1.7_amd64.deb',
#  'dovecot-core': 'pool/main/d/dovecot/dovecot-core_2.3.7.2-1ubuntu3.6_amd64.deb',
#  'dovecot-dev': 'pool/main/d/dovecot/dovecot-dev_2.3.7.2-1ubuntu3.6_amd64.deb',
#  'dovecot-imapd': 'pool/main/d/dovecot/dovecot-imapd_2.3.7.2-1ubuntu3.6_amd64.deb',
#  'dovecot-pop3d': 'pool/main/d/dovecot/dovecot-pop3d_2.3.7.2-1ubuntu3.6_amd64.deb',
#  'dpdk': 'pool/main/d/dpdk/dpdk_19.11.13-0ubuntu0.20.04.1_amd64.deb',
#  'dpkg': 'pool/main/d/dpkg/dpkg_1.19.7ubuntu3.2_amd64.deb',
#  'dpkg-dev': 'pool/main/d/dpkg/dpkg-dev_1.19.7ubuntu3.2_all.deb',
#  'dselect': 'pool/main/d/dpkg/dselect_1.19.7ubuntu3.2_amd64.deb',
#  'e2fslibs': 'pool/main/e/e2fsprogs/e2fslibs_1.45.5-2ubuntu1.1_amd64.deb',
#  'e2fslibs-dev': 'pool/main/e/e2fsprogs/e2fslibs-dev_1.45.5-2ubuntu1.1_all.deb',
#  'e2fsprogs': 'pool/main/e/e2fsprogs/e2fsprogs_1.45.5-2ubuntu1.1_amd64.deb',
#  'elfutils': 'pool/main/e/elfutils/elfutils_0.176-1.1ubuntu0.1_amd64.deb',
#  'erlang-asn1': 'pool/main/e/erlang/erlang-asn1_22.2.7+dfsg-1ubuntu0.2_amd64.deb',
#  'erlang-base': 'pool/main/e/erlang/erlang-base_22.2.7+dfsg-1ubuntu0.2_amd64.deb',
#  'erlang-crypto': 'pool/main/e/erlang/erlang-crypto_22.2.7+dfsg-1ubuntu0.2_amd64.deb',
#  'erlang-dev': 'pool/main/e/erlang/erlang-dev_22.2.7+dfsg-1ubuntu0.2_amd64.deb',
#  'erlang-doc': 'pool/main/e/erlang/erlang-doc_22.2.7+dfsg-1ubuntu0.2_all.deb',
#  'erlang-eldap': 'pool/main/e/erlang/erlang-eldap_22.2.7+dfsg-1ubuntu0.2_amd64.deb',
#  'erlang-examples': 'pool/main/e/erlang/erlang-examples_22.2.7+dfsg-1ubuntu0.2_all.deb',
#  'erlang-ftp': 'pool/main/e/erlang/erlang-ftp_22.2.7+dfsg-1ubuntu0.2_amd64.deb',
#  'erlang-inets': 'pool/main/e/erlang/erlang-inets_22.2.7+dfsg-1ubuntu0.2_amd64.deb',
#  'erlang-megaco': 'pool/main/e/erlang/erlang-megaco_22.2.7+dfsg-1ubuntu0.2_amd64.deb',
#  'erlang-mnesia': 'pool/main/e/erlang/erlang-mnesia_22.2.7+dfsg-1ubuntu0.2_amd64.deb',
#  'erlang-os-mon': 'pool/main/e/erlang/erlang-os-mon_22.2.7+dfsg-1ubuntu0.2_amd64.deb',
#  'erlang-parsetools': 'pool/main/e/erlang/erlang-parsetools_22.2.7+dfsg-1ubuntu0.2_amd64.deb',
#  'erlang-public-key': 'pool/main/e/erlang/erlang-public-key_22.2.7+dfsg-1ubuntu0.2_amd64.deb',
#  'erlang-runtime-tools': 'pool/main/e/erlang/erlang-runtime-tools_22.2.7+dfsg-1ubuntu0.2_amd64.deb',
#  'erlang-snmp': 'pool/main/e/erlang/erlang-snmp_22.2.7+dfsg-1ubuntu0.2_amd64.deb',
#  'erlang-ssh': 'pool/main/e/erlang/erlang-ssh_22.2.7+dfsg-1ubuntu0.2_amd64.deb',
#  'erlang-ssl': 'pool/main/e/erlang/erlang-ssl_22.2.7+dfsg-1ubuntu0.2_amd64.deb',
#  'erlang-syntax-tools': 'pool/main/e/erlang/erlang-syntax-tools_22.2.7+dfsg-1ubuntu0.2_amd64.deb',
#  'erlang-tftp': 'pool/main/e/erlang/erlang-tftp_22.2.7+dfsg-1ubuntu0.2_amd64.deb',
#  'erlang-tools': 'pool/main/e/erlang/erlang-tools_22.2.7+dfsg-1ubuntu0.2_amd64.deb',
#  'erlang-xmerl': 'pool/main/e/erlang/erlang-xmerl_22.2.7+dfsg-1ubuntu0.2_amd64.deb',
#  'evolution-data-server': 'pool/main/e/evolution-data-server/evolution-data-server_3.36.3-0ubuntu1.1_amd64.deb',
#  'evolution-data-server-common': 'pool/main/e/evolution-data-server/evolution-data-server-common_3.36.3-0ubuntu1.1_all.deb',
#  'evolution-data-server-dev': 'pool/main/e/evolution-data-server/evolution-data-server-dev_3.36.3-0ubuntu1.1_amd64.deb',
#  'evolution-data-server-doc': 'pool/main/e/evolution-data-server/evolution-data-server-doc_3.36.3-0ubuntu1.1_all.deb',
#  'exim4': 'pool/main/e/exim4/exim4_4.93-13ubuntu1.9_all.deb',
#  'exim4-base': 'pool/main/e/exim4/exim4-base_4.93-13ubuntu1.9_amd64.deb',
#  'exim4-config': 'pool/main/e/exim4/exim4-config_4.93-13ubuntu1.9_all.deb',
#  'exim4-daemon-heavy': 'pool/main/e/exim4/exim4-daemon-heavy_4.93-13ubuntu1.9_amd64.deb',
#  'exim4-daemon-light': 'pool/main/e/exim4/exim4-daemon-light_4.93-13ubuntu1.9_amd64.deb',
#  'exim4-dev': 'pool/main/e/exim4/exim4-dev_4.93-13ubuntu1.9_amd64.deb',
#  'exuberant-ctags': 'pool/main/e/exuberant-ctags/exuberant-ctags_5.9~svn20110310-12ubuntu0.1_amd64.deb',
#  'fdisk': 'pool/main/u/util-linux/fdisk_2.34-0.1ubuntu9.3_amd64.deb',
#  'file-roller': 'pool/main/f/file-roller/file-roller_3.36.3-0ubuntu1.1_amd64.deb',
#  'firefox': 'pool/main/f/firefox/firefox_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-dbg': 'pool/main/f/firefox/firefox-dbg_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-dev': 'pool/main/f/firefox/firefox-dev_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-af': 'pool/main/f/firefox/firefox-locale-af_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-an': 'pool/main/f/firefox/firefox-locale-an_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-ar': 'pool/main/f/firefox/firefox-locale-ar_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-as': 'pool/main/f/firefox/firefox-locale-as_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-ast': 'pool/main/f/firefox/firefox-locale-ast_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-az': 'pool/main/f/firefox/firefox-locale-az_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-be': 'pool/main/f/firefox/firefox-locale-be_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-bg': 'pool/main/f/firefox/firefox-locale-bg_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-bn': 'pool/main/f/firefox/firefox-locale-bn_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-br': 'pool/main/f/firefox/firefox-locale-br_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-bs': 'pool/main/f/firefox/firefox-locale-bs_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-ca': 'pool/main/f/firefox/firefox-locale-ca_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-cak': 'pool/main/f/firefox/firefox-locale-cak_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-cs': 'pool/main/f/firefox/firefox-locale-cs_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-csb': 'pool/main/f/firefox/firefox-locale-csb_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-cy': 'pool/main/f/firefox/firefox-locale-cy_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-da': 'pool/main/f/firefox/firefox-locale-da_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-de': 'pool/main/f/firefox/firefox-locale-de_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-el': 'pool/main/f/firefox/firefox-locale-el_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-en': 'pool/main/f/firefox/firefox-locale-en_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-eo': 'pool/main/f/firefox/firefox-locale-eo_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-es': 'pool/main/f/firefox/firefox-locale-es_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-et': 'pool/main/f/firefox/firefox-locale-et_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-eu': 'pool/main/f/firefox/firefox-locale-eu_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-fa': 'pool/main/f/firefox/firefox-locale-fa_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-fi': 'pool/main/f/firefox/firefox-locale-fi_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-fr': 'pool/main/f/firefox/firefox-locale-fr_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-fy': 'pool/main/f/firefox/firefox-locale-fy_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-ga': 'pool/main/f/firefox/firefox-locale-ga_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-gd': 'pool/main/f/firefox/firefox-locale-gd_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-gl': 'pool/main/f/firefox/firefox-locale-gl_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-gn': 'pool/main/f/firefox/firefox-locale-gn_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-gu': 'pool/main/f/firefox/firefox-locale-gu_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-he': 'pool/main/f/firefox/firefox-locale-he_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-hi': 'pool/main/f/firefox/firefox-locale-hi_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-hr': 'pool/main/f/firefox/firefox-locale-hr_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-hsb': 'pool/main/f/firefox/firefox-locale-hsb_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-hu': 'pool/main/f/firefox/firefox-locale-hu_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-hy': 'pool/main/f/firefox/firefox-locale-hy_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-ia': 'pool/main/f/firefox/firefox-locale-ia_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-id': 'pool/main/f/firefox/firefox-locale-id_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-is': 'pool/main/f/firefox/firefox-locale-is_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-it': 'pool/main/f/firefox/firefox-locale-it_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-ja': 'pool/main/f/firefox/firefox-locale-ja_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-ka': 'pool/main/f/firefox/firefox-locale-ka_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-kab': 'pool/main/f/firefox/firefox-locale-kab_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-kk': 'pool/main/f/firefox/firefox-locale-kk_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-km': 'pool/main/f/firefox/firefox-locale-km_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-kn': 'pool/main/f/firefox/firefox-locale-kn_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-ko': 'pool/main/f/firefox/firefox-locale-ko_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-ku': 'pool/main/f/firefox/firefox-locale-ku_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-lg': 'pool/main/f/firefox/firefox-locale-lg_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-lt': 'pool/main/f/firefox/firefox-locale-lt_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-lv': 'pool/main/f/firefox/firefox-locale-lv_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-mai': 'pool/main/f/firefox/firefox-locale-mai_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-mk': 'pool/main/f/firefox/firefox-locale-mk_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-ml': 'pool/main/f/firefox/firefox-locale-ml_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-mn': 'pool/main/f/firefox/firefox-locale-mn_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-mr': 'pool/main/f/firefox/firefox-locale-mr_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-ms': 'pool/main/f/firefox/firefox-locale-ms_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-my': 'pool/main/f/firefox/firefox-locale-my_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-nb': 'pool/main/f/firefox/firefox-locale-nb_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-ne': 'pool/main/f/firefox/firefox-locale-ne_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-nl': 'pool/main/f/firefox/firefox-locale-nl_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-nn': 'pool/main/f/firefox/firefox-locale-nn_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-nso': 'pool/main/f/firefox/firefox-locale-nso_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-oc': 'pool/main/f/firefox/firefox-locale-oc_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-or': 'pool/main/f/firefox/firefox-locale-or_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-pa': 'pool/main/f/firefox/firefox-locale-pa_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-pl': 'pool/main/f/firefox/firefox-locale-pl_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-pt': 'pool/main/f/firefox/firefox-locale-pt_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-ro': 'pool/main/f/firefox/firefox-locale-ro_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-ru': 'pool/main/f/firefox/firefox-locale-ru_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-si': 'pool/main/f/firefox/firefox-locale-si_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-sk': 'pool/main/f/firefox/firefox-locale-sk_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-sl': 'pool/main/f/firefox/firefox-locale-sl_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-sq': 'pool/main/f/firefox/firefox-locale-sq_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-sr': 'pool/main/f/firefox/firefox-locale-sr_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-sv': 'pool/main/f/firefox/firefox-locale-sv_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-sw': 'pool/main/f/firefox/firefox-locale-sw_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-szl': 'pool/main/f/firefox/firefox-locale-szl_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-ta': 'pool/main/f/firefox/firefox-locale-ta_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-te': 'pool/main/f/firefox/firefox-locale-te_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-tg': 'pool/main/f/firefox/firefox-locale-tg_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-th': 'pool/main/f/firefox/firefox-locale-th_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-tr': 'pool/main/f/firefox/firefox-locale-tr_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-uk': 'pool/main/f/firefox/firefox-locale-uk_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-ur': 'pool/main/f/firefox/firefox-locale-ur_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-uz': 'pool/main/f/firefox/firefox-locale-uz_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-vi': 'pool/main/f/firefox/firefox-locale-vi_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-xh': 'pool/main/f/firefox/firefox-locale-xh_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-zh-hans': 'pool/main/f/firefox/firefox-locale-zh-hans_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-zh-hant': 'pool/main/f/firefox/firefox-locale-zh-hant_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'firefox-locale-zu': 'pool/main/f/firefox/firefox-locale-zu_121.0.1+build1-0ubuntu0.20.04.1_amd64.deb',
#  'fonts-opensymbol': 'pool/main/libr/libreoffice/fonts-opensymbol_102.11+LibO6.4.7-0ubuntu0.20.04.9_all.deb',
#  'freeradius': 'pool/main/f/freeradius/freeradius_3.0.20+dfsg-3ubuntu0.2_amd64.deb',
#  'freeradius-common': 'pool/main/f/freeradius/freeradius-common_3.0.20+dfsg-3ubuntu0.2_all.deb',
#  'freeradius-config': 'pool/main/f/freeradius/freeradius-config_3.0.20+dfsg-3ubuntu0.2_amd64.deb',
#  'freeradius-dhcp': 'pool/main/f/freeradius/freeradius-dhcp_3.0.20+dfsg-3ubuntu0.2_amd64.deb',
#  'freeradius-utils': 'pool/main/f/freeradius/freeradius-utils_3.0.20+dfsg-3ubuntu0.2_amd64.deb',
#  'freerdp2-dev': 'pool/main/f/freerdp2/freerdp2-dev_2.2.0+dfsg1-0ubuntu0.20.04.6_amd64.deb',
#  'freetype2-doc': 'pool/main/f/freetype/freetype2-doc_2.10.1-2ubuntu0.3_all.deb',
#  'fwupd': 'pool/main/f/fwupd/fwupd_1.3.9-4ubuntu0.1_amd64.deb',
#  'fwupd-doc': 'pool/main/f/fwupd/fwupd-doc_1.3.9-4ubuntu0.1_all.deb',
#  'fwupd-signed': 'pool/main/f/fwupd-signed/fwupd-signed_1.27.1ubuntu1+1.3.9-4ubuntu0.1_amd64.deb',
#  'g++-9': 'pool/main/g/gcc-9/g++-9_9.4.0-1ubuntu1~20.04.2_amd64.deb',
#  'g++-9-aarch64-linux-gnu': 'pool/main/g/gcc-9-cross/g++-9-aarch64-linux-gnu_9.4.0-1ubuntu1~20.04.2cross2_amd64.deb',
#  'g++-9-arm-linux-gnueabihf': 'pool/main/g/gcc-9-cross/g++-9-arm-linux-gnueabihf_9.4.0-1ubuntu1~20.04.2cross2_amd64.deb',
#  'g++-9-multilib': 'pool/main/g/gcc-9/g++-9-multilib_9.4.0-1ubuntu1~20.04.2_amd64.deb',
#  'g++-9-powerpc64le-linux-gnu': 'pool/main/g/gcc-9-cross/g++-9-powerpc64le-linux-gnu_9.4.0-1ubuntu1~20.04.2cross2_amd64.deb',
#  'g++-9-s390x-linux-gnu': 'pool/main/g/gcc-9-cross/g++-9-s390x-linux-gnu_9.4.0-1ubuntu1~20.04.2cross2_amd64.deb',
#  'gawk': 'pool/main/g/gawk/gawk_5.0.1+dfsg-1ubuntu0.1_amd64.deb',
#  'gcc-10-base': 'pool/main/g/gcc-10/gcc-10-base_10.5.0-1ubuntu1~20.04_amd64.deb',
#  'gcc-10-cross-base': 'pool/main/g/gcc-10-cross/gcc-10-cross-base_10.5.0-1ubuntu1~20.04cross1_all.deb',
#  'gcc-9': 'pool/main/g/gcc-9/gcc-9_9.4.0-1ubuntu1~20.04.2_amd64.deb',
#  'gcc-9-aarch64-linux-gnu': 'pool/main/g/gcc-9-cross/gcc-9-aarch64-linux-gnu_9.4.0-1ubuntu1~20.04.2cross2_amd64.deb',
#  'gcc-9-aarch64-linux-gnu-base': 'pool/main/g/gcc-9-cross/gcc-9-aarch64-linux-gnu-base_9.4.0-1ubuntu1~20.04.2cross2_amd64.deb',
#  'gcc-9-arm-linux-gnueabihf': 'pool/main/g/gcc-9-cross/gcc-9-arm-linux-gnueabihf_9.4.0-1ubuntu1~20.04.2cross2_amd64.deb',
#  'gcc-9-arm-linux-gnueabihf-base': 'pool/main/g/gcc-9-cross/gcc-9-arm-linux-gnueabihf-base_9.4.0-1ubuntu1~20.04.2cross2_amd64.deb',
#  'gcc-9-base': 'pool/main/g/gcc-9/gcc-9-base_9.4.0-1ubuntu1~20.04.2_amd64.deb',
#  'gcc-9-cross-base': 'pool/main/g/gcc-9-cross/gcc-9-cross-base_9.4.0-1ubuntu1~20.04.2cross2_all.deb',
#  'gcc-9-doc': 'pool/main/g/gcc-9/gcc-9-doc_9.4.0-1ubuntu1~20.04.2_all.deb',
#  'gcc-9-multilib': 'pool/main/g/gcc-9/gcc-9-multilib_9.4.0-1ubuntu1~20.04.2_amd64.deb',
#  'gcc-9-powerpc64le-linux-gnu': 'pool/main/g/gcc-9-cross/gcc-9-powerpc64le-linux-gnu_9.4.0-1ubuntu1~20.04.2cross2_amd64.deb',
#  'gcc-9-powerpc64le-linux-gnu-base': 'pool/main/g/gcc-9-cross/gcc-9-powerpc64le-linux-gnu-base_9.4.0-1ubuntu1~20.04.2cross2_amd64.deb',
#  'gcc-9-s390x-linux-gnu': 'pool/main/g/gcc-9-cross/gcc-9-s390x-linux-gnu_9.4.0-1ubuntu1~20.04.2cross2_amd64.deb',
#  'gcc-9-s390x-linux-gnu-base': 'pool/main/g/gcc-9-cross/gcc-9-s390x-linux-gnu-base_9.4.0-1ubuntu1~20.04.2cross2_amd64.deb',
#  'gce-compute-image-packages': 'pool/main/g/gce-compute-image-packages/gce-compute-image-packages_20190801-0ubuntu4.1_all.deb',
#  'gdm3': 'pool/main/g/gdm3/gdm3_3.36.3-0ubuntu0.20.04.2_amd64.deb',
#  'gfortran-9': 'pool/main/g/gcc-9/gfortran-9_9.4.0-1ubuntu1~20.04.2_amd64.deb',
#  'gfortran-9-doc': 'pool/main/g/gcc-9/gfortran-9-doc_9.4.0-1ubuntu1~20.04.2_all.deb',
#  'gfortran-9-multilib': 'pool/main/g/gcc-9/gfortran-9-multilib_9.4.0-1ubuntu1~20.04.2_amd64.deb',
#  'ghostscript': 'pool/main/g/ghostscript/ghostscript_9.50~dfsg-5ubuntu4.11_amd64.deb',
#  'ghostscript-dbg': 'pool/main/g/ghostscript/ghostscript-dbg_9.50~dfsg-5ubuntu4.11_amd64.deb',
#  'ghostscript-doc': 'pool/main/g/ghostscript/ghostscript-doc_9.50~dfsg-5ubuntu4.11_all.deb',
#  'ghostscript-x': 'pool/main/g/ghostscript/ghostscript-x_9.50~dfsg-5ubuntu4.11_amd64.deb',
#  'gir1.2-accountsservice-1.0': 'pool/main/a/accountsservice/gir1.2-accountsservice-1.0_0.6.55-0ubuntu12~20.04.6_amd64.deb',
#  'gir1.2-avahi-0.6': 'pool/main/a/avahi/gir1.2-avahi-0.6_0.7-4ubuntu7.3_amd64.deb',
#  'gir1.2-camel-1.2': 'pool/main/e/evolution-data-server/gir1.2-camel-1.2_3.36.3-0ubuntu1.1_amd64.deb',
#  'gir1.2-ebackend-1.2': 'pool/main/e/evolution-data-server/gir1.2-ebackend-1.2_3.36.3-0ubuntu1.1_amd64.deb',
#  'gir1.2-ebook-1.2': 'pool/main/e/evolution-data-server/gir1.2-ebook-1.2_3.36.3-0ubuntu1.1_amd64.deb',
#  'gir1.2-ebookcontacts-1.2': 'pool/main/e/evolution-data-server/gir1.2-ebookcontacts-1.2_3.36.3-0ubuntu1.1_amd64.deb',
#  'gir1.2-ecal-2.0': 'pool/main/e/evolution-data-server/gir1.2-ecal-2.0_3.36.3-0ubuntu1.1_amd64.deb',
#  'gir1.2-edatabook-1.2': 'pool/main/e/evolution-data-server/gir1.2-edatabook-1.2_3.36.3-0ubuntu1.1_amd64.deb',
#  'gir1.2-edatacal-2.0': 'pool/main/e/evolution-data-server/gir1.2-edatacal-2.0_3.36.3-0ubuntu1.1_amd64.deb',
#  'gir1.2-edataserver-1.2': 'pool/main/e/evolution-data-server/gir1.2-edataserver-1.2_3.36.3-0ubuntu1.1_amd64.deb',
#  'gir1.2-edataserverui-1.2': 'pool/main/e/evolution-data-server/gir1.2-edataserverui-1.2_3.36.3-0ubuntu1.1_amd64.deb',
#  'gir1.2-fwupd-2.0': 'pool/main/f/fwupd/gir1.2-fwupd-2.0_1.3.9-4ubuntu0.1_amd64.deb',
#  'gir1.2-fwupdplugin-1.0': 'pool/main/f/fwupd/gir1.2-fwupdplugin-1.0_1.3.9-4ubuntu0.1_amd64.deb',
#  'gir1.2-gdkpixbuf-2.0': 'pool/main/g/gdk-pixbuf/gir1.2-gdkpixbuf-2.0_2.40.0+dfsg-3ubuntu0.4_amd64.deb',
#  'gir1.2-gdm-1.0': 'pool/main/g/gdm3/gir1.2-gdm-1.0_3.36.3-0ubuntu0.20.04.2_amd64.deb',
#  'gir1.2-gnomeautoar-0.1': 'pool/main/g/gnome-autoar/gir1.2-gnomeautoar-0.1_0.2.3-2ubuntu0.4_amd64.deb',
#  'gir1.2-gnomeautoargtk-0.1': 'pool/main/g/gnome-autoar/gir1.2-gnomeautoargtk-0.1_0.2.3-2ubuntu0.4_amd64.deb',
#  'gir1.2-grilo-0.3': 'pool/main/g/grilo/gir1.2-grilo-0.3_0.3.12-1ubuntu0.1_amd64.deb',
#  'gir1.2-gssdp-1.2': 'pool/main/g/gssdp/gir1.2-gssdp-1.2_1.2.3-0ubuntu0.20.04.1_amd64.deb',
#  'gir1.2-gst-plugins-base-1.0': 'pool/main/g/gst-plugins-base1.0/gir1.2-gst-plugins-base-1.0_1.16.3-0ubuntu1.2_amd64.deb',
#  'gir1.2-gstreamer-1.0': 'pool/main/g/gstreamer1.0/gir1.2-gstreamer-1.0_1.16.3-0ubuntu1.1_amd64.deb',
#  'gir1.2-gupnp-1.2': 'pool/main/g/gupnp/gir1.2-gupnp-1.2_1.2.3-0ubuntu0.20.04.2_amd64.deb',
#  'gir1.2-harfbuzz-0.0': 'pool/main/h/harfbuzz/gir1.2-harfbuzz-0.0_2.6.4-1ubuntu4.2_amd64.deb',
#  'gir1.2-javascriptcoregtk-4.0': 'pool/main/w/webkit2gtk/gir1.2-javascriptcoregtk-4.0_2.38.6-0ubuntu0.20.04.1_amd64.deb',
#  'gir1.2-lokdocview-0.1': 'pool/main/libr/libreoffice/gir1.2-lokdocview-0.1_6.4.7-0ubuntu0.20.04.9_amd64.deb',
#  'gir1.2-nautilus-3.0': 'pool/main/n/nautilus/gir1.2-nautilus-3.0_3.36.3-0ubuntu1.20.04.2_amd64.deb',
#  'gir1.2-packagekitglib-1.0': 'pool/main/p/packagekit/gir1.2-packagekitglib-1.0_1.1.13-2ubuntu1.1_amd64.deb',
#  'gir1.2-polkit-1.0': 'pool/main/p/policykit-1/gir1.2-polkit-1.0_0.105-26ubuntu1.3_amd64.deb',
#  'gir1.2-poppler-0.18': 'pool/main/p/poppler/gir1.2-poppler-0.18_0.86.1-0ubuntu1.4_amd64.deb',
#  'gir1.2-rsvg-2.0': 'pool/main/libr/librsvg/gir1.2-rsvg-2.0_2.48.9-1ubuntu0.20.04.4_amd64.deb',
#  'gir1.2-webkit2-4.0': 'pool/main/w/webkit2gtk/gir1.2-webkit2-4.0_2.38.6-0ubuntu0.20.04.1_amd64.deb',
#  'git': 'pool/main/g/git/git_2.25.1-1ubuntu3.11_amd64.deb',
#  'git-doc': 'pool/main/g/git/git-doc_2.25.1-1ubuntu3.11_all.deb',
#  'git-man': 'pool/main/g/git/git-man_2.25.1-1ubuntu3.11_all.deb',
#  'glance': 'pool/main/g/glance/glance_20.2.0-0ubuntu1.1_all.deb',
#  'glance-api': 'pool/main/g/glance/glance-api_20.2.0-0ubuntu1.1_all.deb',
#  'glance-common': 'pool/main/g/glance/glance-common_20.2.0-0ubuntu1.1_all.deb',
#  'glib-networking': 'pool/main/g/glib-networking/glib-networking_2.64.2-1ubuntu0.1_amd64.deb',
#  'glib-networking-common': 'pool/main/g/glib-networking/glib-networking-common_2.64.2-1ubuntu0.1_all.deb',
#  'glib-networking-services': 'pool/main/g/glib-networking/glib-networking-services_2.64.2-1ubuntu0.1_amd64.deb',
#  'glibc-doc': 'pool/main/g/glibc/glibc-doc_2.31-0ubuntu9.14_all.deb',
#  'gnome-control-center': 'pool/main/g/gnome-control-center/gnome-control-center_3.36.5-0ubuntu4.1_amd64.deb',
#  'gnome-control-center-data': 'pool/main/g/gnome-control-center/gnome-control-center-data_3.36.5-0ubuntu4.1_all.deb',
#  'gnome-control-center-dev': 'pool/main/g/gnome-control-center/gnome-control-center-dev_3.36.5-0ubuntu4.1_all.deb',
#  'gnome-control-center-faces': 'pool/main/g/gnome-control-center/gnome-control-center-faces_3.36.5-0ubuntu4.1_all.deb',
#  'gnome-shell': 'pool/main/g/gnome-shell/gnome-shell_3.36.4-1ubuntu1~20.04.2_amd64.deb',
#  'gnome-shell-common': 'pool/main/g/gnome-shell/gnome-shell-common_3.36.4-1ubuntu1~20.04.2_all.deb',
#  'gnupg': 'pool/main/g/gnupg2/gnupg_2.2.19-3ubuntu2.2_all.deb',
#  'gnupg-l10n': 'pool/main/g/gnupg2/gnupg-l10n_2.2.19-3ubuntu2.2_all.deb',
#  'gnupg-utils': 'pool/main/g/gnupg2/gnupg-utils_2.2.19-3ubuntu2.2_amd64.deb',
#  'gnutls-doc': 'pool/main/g/gnutls28/gnutls-doc_3.6.13-2ubuntu1.10_all.deb',
#  'golang-1.13': 'pool/main/g/golang-1.13/golang-1.13_1.13.8-1ubuntu1.2_all.deb',
#  'golang-1.13-doc': 'pool/main/g/golang-1.13/golang-1.13-doc_1.13.8-1ubuntu1.2_all.deb',
#  'golang-1.13-go': 'pool/main/g/golang-1.13/golang-1.13-go_1.13.8-1ubuntu1.2_amd64.deb',
#  'golang-1.13-src': 'pool/main/g/golang-1.13/golang-1.13-src_1.13.8-1ubuntu1.2_amd64.deb',
#  'golang-1.14': 'pool/main/g/golang-1.14/golang-1.14_1.14.3-2ubuntu2~20.04.2_all.deb',
#  'golang-1.14-doc': 'pool/main/g/golang-1.14/golang-1.14-doc_1.14.3-2ubuntu2~20.04.2_all.deb',
#  'golang-1.14-go': 'pool/main/g/golang-1.14/golang-1.14-go_1.14.3-2ubuntu2~20.04.2_amd64.deb',
#  'golang-1.14-src': 'pool/main/g/golang-1.14/golang-1.14-src_1.14.3-2ubuntu2~20.04.2_amd64.deb',
#  'golang-github-containerd-containerd-dev': 'pool/main/c/containerd/golang-github-containerd-containerd-dev_1.6.12-0ubuntu1~20.04.6_all.deb',
#  'golang-github-docker-containerd-dev': 'pool/main/c/containerd/golang-github-docker-containerd-dev_1.5.2-0ubuntu1~20.04.3_all.deb',
#  'golang-github-opencontainers-runc-dev': 'pool/main/r/runc/golang-github-opencontainers-runc-dev_1.1.4-0ubuntu1~20.04.3_all.deb',
#  'golang-github-snapcore-snapd-dev': 'pool/main/s/snapd/golang-github-snapcore-snapd-dev_2.58+20.04.1_all.deb',
#  'golang-github-ubuntu-core-snappy-dev': 'pool/main/s/snapd/golang-github-ubuntu-core-snappy-dev_2.58+20.04.1_all.deb',
#  'google-compute-engine-oslogin': 'pool/main/g/gce-compute-image-packages/google-compute-engine-oslogin_20190801-0ubuntu4.1_amd64.deb',
#  'gpg': 'pool/main/g/gnupg2/gpg_2.2.19-3ubuntu2.2_amd64.deb',
#  'gpg-agent': 'pool/main/g/gnupg2/gpg-agent_2.2.19-3ubuntu2.2_amd64.deb',
#  'gpg-wks-client': 'pool/main/g/gnupg2/gpg-wks-client_2.2.19-3ubuntu2.2_amd64.deb',
#  'gpg-wks-server': 'pool/main/g/gnupg2/gpg-wks-server_2.2.19-3ubuntu2.2_amd64.deb',
#  'gpgconf': 'pool/main/g/gnupg2/gpgconf_2.2.19-3ubuntu2.2_amd64.deb',
#  'gpgsm': 'pool/main/g/gnupg2/gpgsm_2.2.19-3ubuntu2.2_amd64.deb',
#  'gpgv': 'pool/main/g/gnupg2/gpgv_2.2.19-3ubuntu2.2_amd64.deb',
#  'gpsd': 'pool/main/g/gpsd/gpsd_3.20-8ubuntu0.4_amd64.deb',
#  'grub-common': 'pool/main/g/grub2/grub-common_2.04-1ubuntu26.12_amd64.deb',
#  'grub-efi': 'pool/main/g/grub2/grub-efi_2.04-1ubuntu26.12_amd64.deb',
#  'grub-efi-amd64': 'pool/main/g/grub2-unsigned/grub-efi-amd64_2.06-2ubuntu14.4_amd64.deb',
#  'grub-efi-amd64-bin': 'pool/main/g/grub2-unsigned/grub-efi-amd64-bin_2.06-2ubuntu14.4_amd64.deb',
#  'grub-efi-amd64-dbg': 'pool/main/g/grub2-unsigned/grub-efi-amd64-dbg_2.06-2ubuntu14.4_amd64.deb',
#  'grub-efi-amd64-signed': 'pool/main/g/grub2-signed/grub-efi-amd64-signed_1.187.6~20.04.1+2.06-2ubuntu14.4_amd64.deb',
#  'grub-efi-ia32': 'pool/main/g/grub2/grub-efi-ia32_2.04-1ubuntu26.12_amd64.deb',
#  'grub-efi-ia32-bin': 'pool/main/g/grub2/grub-efi-ia32-bin_2.04-1ubuntu26.12_amd64.deb',
#  'grub-efi-ia32-dbg': 'pool/main/g/grub2/grub-efi-ia32-dbg_2.04-1ubuntu26.12_amd64.deb',
#  'grub-ieee1275': 'pool/main/g/grub2/grub-ieee1275_2.04-1ubuntu26.12_amd64.deb',
#  'grub-ieee1275-bin': 'pool/main/g/grub2/grub-ieee1275-bin_2.04-1ubuntu26.12_amd64.deb',
#  'grub-ieee1275-dbg': 'pool/main/g/grub2/grub-ieee1275-dbg_2.04-1ubuntu26.12_amd64.deb',
#  'grub-pc': 'pool/main/g/grub2/grub-pc_2.04-1ubuntu26.12_amd64.deb',
#  'grub-pc-bin': 'pool/main/g/grub2/grub-pc-bin_2.04-1ubuntu26.12_amd64.deb',
#  'grub-pc-dbg': 'pool/main/g/grub2/grub-pc-dbg_2.04-1ubuntu26.12_amd64.deb',
#  'grub-xen': 'pool/main/g/grub2/grub-xen_2.04-1ubuntu26.12_amd64.deb',
#  'grub-xen-bin': 'pool/main/g/grub2/grub-xen-bin_2.04-1ubuntu26.12_amd64.deb',
#  'grub-xen-dbg': 'pool/main/g/grub2/grub-xen-dbg_2.04-1ubuntu26.12_amd64.deb',
#  'grub2-common': 'pool/main/g/grub2/grub2-common_2.04-1ubuntu26.12_amd64.deb',
#  'gstreamer1.0-alsa': 'pool/main/g/gst-plugins-base1.0/gstreamer1.0-alsa_1.16.3-0ubuntu1.2_amd64.deb',
#  'gstreamer1.0-doc': 'pool/main/g/gstreamer1.0/gstreamer1.0-doc_1.16.3-0ubuntu1.1_all.deb',
#  'gstreamer1.0-gl': 'pool/main/g/gst-plugins-base1.0/gstreamer1.0-gl_1.16.3-0ubuntu1.2_amd64.deb',
#  'gstreamer1.0-gtk3': 'pool/main/g/gst-plugins-good1.0/gstreamer1.0-gtk3_1.16.3-0ubuntu1.2_amd64.deb',
#  'gstreamer1.0-packagekit': 'pool/main/p/packagekit/gstreamer1.0-packagekit_1.1.13-2ubuntu1.1_amd64.deb',
#  'gstreamer1.0-plugins-base': 'pool/main/g/gst-plugins-base1.0/gstreamer1.0-plugins-base_1.16.3-0ubuntu1.2_amd64.deb',
#  'gstreamer1.0-plugins-base-apps': 'pool/main/g/gst-plugins-base1.0/gstreamer1.0-plugins-base-apps_1.16.3-0ubuntu1.2_amd64.deb',
#  'gstreamer1.0-plugins-base-dbg': 'pool/main/g/gst-plugins-base1.0/gstreamer1.0-plugins-base-dbg_1.16.3-0ubuntu1.2_amd64.deb',
#  'gstreamer1.0-plugins-base-doc': 'pool/main/g/gst-plugins-base1.0/gstreamer1.0-plugins-base-doc_1.16.3-0ubuntu1.2_all.deb',
#  'gstreamer1.0-plugins-good': 'pool/main/g/gst-plugins-good1.0/gstreamer1.0-plugins-good_1.16.3-0ubuntu1.2_amd64.deb',
#  'gstreamer1.0-plugins-good-doc': 'pool/main/g/gst-plugins-good1.0/gstreamer1.0-plugins-good-doc_1.16.3-0ubuntu1.2_all.deb',
#  'gstreamer1.0-pulseaudio': 'pool/main/g/gst-plugins-good1.0/gstreamer1.0-pulseaudio_1.16.3-0ubuntu1.2_amd64.deb',
#  'gstreamer1.0-tools': 'pool/main/g/gstreamer1.0/gstreamer1.0-tools_1.16.3-0ubuntu1.1_amd64.deb',
#  'gstreamer1.0-x': 'pool/main/g/gst-plugins-base1.0/gstreamer1.0-x_1.16.3-0ubuntu1.2_amd64.deb',
#  'gvfs': 'pool/main/g/gvfs/gvfs_1.44.1-1ubuntu1.2_amd64.deb',
#  'gvfs-backends': 'pool/main/g/gvfs/gvfs-backends_1.44.1-1ubuntu1.2_amd64.deb',
#  'gvfs-bin': 'pool/main/g/gvfs/gvfs-bin_1.44.1-1ubuntu1.2_amd64.deb',
#  'gvfs-common': 'pool/main/g/gvfs/gvfs-common_1.44.1-1ubuntu1.2_all.deb',
#  'gvfs-daemons': 'pool/main/g/gvfs/gvfs-daemons_1.44.1-1ubuntu1.2_amd64.deb',
#  'gvfs-fuse': 'pool/main/g/gvfs/gvfs-fuse_1.44.1-1ubuntu1.2_amd64.deb',
#  'gvfs-libs': 'pool/main/g/gvfs/gvfs-libs_1.44.1-1ubuntu1.2_amd64.deb',
#  'gzip': 'pool/main/g/gzip/gzip_1.10-0ubuntu4.1_amd64.deb',
#  'haproxy': 'pool/main/h/haproxy/haproxy_2.0.31-0ubuntu0.3_amd64.deb',
#  'heat-api': 'pool/main/h/heat/heat-api_14.2.0-0ubuntu1.1_all.deb',
#  'heat-api-cfn': 'pool/main/h/heat/heat-api-cfn_14.2.0-0ubuntu1.1_all.deb',
#  'heat-common': 'pool/main/h/heat/heat-common_14.2.0-0ubuntu1.1_all.deb',
#  'heat-engine': 'pool/main/h/heat/heat-engine_14.2.0-0ubuntu1.1_all.deb',
#  'heimdal-dev': 'pool/main/h/heimdal/heimdal-dev_7.7.0+dfsg-1ubuntu1.4_amd64.deb',
#  'heimdal-docs': 'pool/main/h/heimdal/heimdal-docs_7.7.0+dfsg-1ubuntu1.4_all.deb',
#  'heimdal-multidev': 'pool/main/h/heimdal/heimdal-multidev_7.7.0+dfsg-1ubuntu1.4_amd64.deb',
#  'hibagent': 'pool/main/h/hibagent/hibagent_1.0.1-0ubuntu1.20.04.2_all.deb',
#  'icu-devtools': 'pool/main/i/icu/icu-devtools_66.1-2ubuntu2.1_amd64.deb',
#  'icu-doc': 'pool/main/i/icu/icu-doc_66.1-2ubuntu2.1_all.deb',
#  'indent': 'pool/main/i/indent/indent_2.2.12-1ubuntu0.20.04.1_amd64.deb',
#  'indent-doc': 'pool/main/i/indent/indent-doc_2.2.12-1ubuntu0.20.04.1_all.deb',
#  'intel-microcode': 'pool/main/i/intel-microcode/intel-microcode_3.20231114.0ubuntu0.20.04.1_amd64.deb',
#  'isc-dhcp-client': 'pool/main/i/isc-dhcp/isc-dhcp-client_4.4.1-2.1ubuntu5.20.04.4_amd64.deb',
#  'isc-dhcp-common': 'pool/main/i/isc-dhcp/isc-dhcp-common_4.4.1-2.1ubuntu5.20.04.4_amd64.deb',
#  'isc-dhcp-dev': 'pool/main/i/isc-dhcp/isc-dhcp-dev_4.4.1-2.1ubuntu5.20.04.4_amd64.deb',
#  'isc-dhcp-server': 'pool/main/i/isc-dhcp/isc-dhcp-server_4.4.1-2.1ubuntu5.20.04.4_amd64.deb',
#  'keepalived': 'pool/main/k/keepalived/keepalived_2.0.19-2ubuntu0.1_amd64.deb',
#  'klibc-utils': 'pool/main/k/klibc/klibc-utils_2.0.7-1ubuntu5.1_amd64.deb',
#  'kpartx': 'pool/main/m/multipath-tools/kpartx_0.8.3-1ubuntu2.1_amd64.deb',
#  'kpartx-boot': 'pool/main/m/multipath-tools/kpartx-boot_0.8.3-1ubuntu2.1_all.deb',
#  'krb5-doc': 'pool/main/k/krb5/krb5-doc_1.17-6ubuntu4.4_all.deb',
#  'krb5-locales': 'pool/main/k/krb5/krb5-locales_1.17-6ubuntu4.4_all.deb',
#  'krb5-multidev': 'pool/main/k/krb5/krb5-multidev_1.17-6ubuntu4.4_amd64.deb',
#  'ldap-utils': 'pool/main/o/openldap/ldap-utils_2.4.49+dfsg-2ubuntu1.9_amd64.deb',
#  'lib32asan5': 'pool/main/g/gcc-9/lib32asan5_9.4.0-1ubuntu1~20.04.2_amd64.deb',
#  'lib32asan6': 'pool/main/g/gcc-10/lib32asan6_10.5.0-1ubuntu1~20.04_amd64.deb',
#  'lib32atomic1': 'pool/main/g/gcc-10/lib32atomic1_10.5.0-1ubuntu1~20.04_amd64.deb',
#  'lib32gcc-10-dev': 'pool/main/g/gcc-10/lib32gcc-10-dev_10.5.0-1ubuntu1~20.04_amd64.deb',
#  'lib32gcc-9-dev': 'pool/main/g/gcc-9/lib32gcc-9-dev_9.4.0-1ubuntu1~20.04.2_amd64.deb',
#  'lib32gcc-s1': 'pool/main/g/gcc-10/lib32gcc-s1_10.5.0-1ubuntu1~20.04_amd64.deb',
#  'lib32gcc1': 'pool/main/g/gcc-10/lib32gcc1_10.5.0-1ubuntu1~20.04_amd64.deb',
#  'lib32gfortran-9-dev': 'pool/main/g/gcc-9/lib32gfortran-9-dev_9.4.0-1ubuntu1~20.04.2_amd64.deb',
#  'lib32gfortran5': 'pool/main/g/gcc-10/lib32gfortran5_10.5.0-1ubuntu1~20.04_amd64.deb',
#  'lib32go-10-dev': 'pool/main/g/gcc-10/lib32go-10-dev_10.5.0-1ubuntu1~20.04_amd64.deb',
#  'lib32go-9-dev': 'pool/main/g/gcc-9/lib32go-9-dev_9.4.0-1ubuntu1~20.04.2_amd64.deb',
#  'lib32go14': 'pool/main/g/gcc-9/lib32go14_9.4.0-1ubuntu1~20.04.2_amd64.deb',
#  'lib32go16': 'pool/main/g/gcc-10/lib32go16_10.5.0-1ubuntu1~20.04_amd64.deb',
#  'lib32gomp1': 'pool/main/g/gcc-10/lib32gomp1_10.5.0-1ubuntu1~20.04_amd64.deb',
#  'lib32itm1': 'pool/main/g/gcc-10/lib32itm1_10.5.0-1ubuntu1~20.04_amd64.deb',
#  'lib32ncurses-dev': 'pool/main/n/ncurses/lib32ncurses-dev_6.2-0ubuntu2.1_amd64.deb',
#  'lib32ncurses6': 'pool/main/n/ncurses/lib32ncurses6_6.2-0ubuntu2.1_amd64.deb',
#  'lib32ncursesw6': 'pool/main/n/ncurses/lib32ncursesw6_6.2-0ubuntu2.1_amd64.deb',
#  'lib32quadmath0': 'pool/main/g/gcc-10/lib32quadmath0_10.5.0-1ubuntu1~20.04_amd64.deb',
#  'lib32stdc++-9-dev': 'pool/main/g/gcc-9/lib32stdc++-9-dev_9.4.0-1ubuntu1~20.04.2_amd64.deb',
#  'lib32stdc++6': 'pool/main/g/gcc-10/lib32stdc++6_10.5.0-1ubuntu1~20.04_amd64.deb',
#  'lib32tinfo6': 'pool/main/n/ncurses/lib32tinfo6_6.2-0ubuntu2.1_amd64.deb',
#  'lib32ubsan1': 'pool/main/g/gcc-10/lib32ubsan1_10.5.0-1ubuntu1~20.04_amd64.deb',
#  'lib32z1': 'pool/main/z/zlib/lib32z1_1.2.11.dfsg-2ubuntu1.5_amd64.deb',
#  'lib32z1-dev': 'pool/main/z/zlib/lib32z1-dev_1.2.11.dfsg-2ubuntu1.5_amd64.deb',
#  'libaccountsservice-dev': 'pool/main/a/accountsservice/libaccountsservice-dev_0.6.55-0ubuntu12~20.04.6_amd64.deb',
#  'libaccountsservice-doc': 'pool/main/a/accountsservice/libaccountsservice-doc_0.6.55-0ubuntu12~20.04.6_all.deb',
#  'libaccountsservice0': 'pool/main/a/accountsservice/libaccountsservice0_0.6.55-0ubuntu12~20.04.6_amd64.deb',
#  'libapache2-mod-auth-mellon': 'pool/main/liba/libapache2-mod-auth-mellon/libapache2-mod-auth-mellon_0.16.0-1ubuntu0.1_amd64.deb',
#  'libapache2-mod-php7.4': 'pool/main/p/php7.4/libapache2-mod-php7.4_7.4.3-4ubuntu2.19_amd64.deb',
#  'libapache2-mod-wsgi-py3': 'pool/main/m/mod-wsgi/libapache2-mod-wsgi-py3_4.6.8-1ubuntu3.1_amd64.deb',
#  'libaprutil1': 'pool/main/a/apr-util/libaprutil1_1.6.1-4ubuntu2.2_amd64.deb',
#  'libaprutil1-dbd-sqlite3': 'pool/main/a/apr-util/libaprutil1-dbd-sqlite3_1.6.1-4ubuntu2.2_amd64.deb',
#  'libaprutil1-dbg': 'pool/main/a/apr-util/libaprutil1-dbg_1.6.1-4ubuntu2.2_amd64.deb',
#  'libaprutil1-dev': 'pool/main/a/apr-util/libaprutil1-dev_1.6.1-4ubuntu2.2_amd64.deb',
#  'libaprutil1-ldap': 'pool/main/a/apr-util/libaprutil1-ldap_1.6.1-4ubuntu2.2_amd64.deb',
#  'libapt-pkg-dev': 'pool/main/a/apt/libapt-pkg-dev_2.0.2ubuntu0.2_amd64.deb',
#  'libapt-pkg-doc': 'pool/main/a/apt/libapt-pkg-doc_2.0.2ubuntu0.2_all.deb',
#  'libapt-pkg6.0': 'pool/main/a/apt/libapt-pkg6.0_2.0.2ubuntu0.2_amd64.deb',
#  'libarchive-dev': 'pool/main/liba/libarchive/libarchive-dev_3.4.0-2ubuntu1.2_amd64.deb',
#  'libarchive13': 'pool/main/liba/libarchive/libarchive13_3.4.0-2ubuntu1.2_amd64.deb',
#  'libasan5': 'pool/main/g/gcc-9/libasan5_9.4.0-1ubuntu1~20.04.2_amd64.deb',
#  'libasan5-arm64-cross': 'pool/main/g/gcc-9-cross/libasan5-arm64-cross_9.4.0-1ubuntu1~20.04.2cross2_all.deb',
#  'libasan5-armhf-cross': 'pool/main/g/gcc-9-cross/libasan5-armhf-cross_9.4.0-1ubuntu1~20.04.2cross2_all.deb',
#  'libasan5-ppc64el-cross': 'pool/main/g/gcc-9-cross/libasan5-ppc64el-cross_9.4.0-1ubuntu1~20.04.2cross2_all.deb',
#  'libasan5-s390x-cross': 'pool/main/g/gcc-9-cross/libasan5-s390x-cross_9.4.0-1ubuntu1~20.04.2cross2_all.deb',
#  'libasan6': 'pool/main/g/gcc-10/libasan6_10.5.0-1ubuntu1~20.04_amd64.deb',
#  'libasm-dev': 'pool/main/e/elfutils/libasm-dev_0.176-1.1ubuntu0.1_amd64.deb',
#  'libasm1': 'pool/main/e/elfutils/libasm1_0.176-1.1ubuntu0.1_amd64.deb',
#  'libasn1-8-heimdal': 'pool/main/h/heimdal/libasn1-8-heimdal_7.7.0+dfsg-1ubuntu1.4_amd64.deb',
#  'libaspell-dev': 'pool/main/a/aspell/libaspell-dev_0.60.8-1ubuntu0.1_amd64.deb',
#  'libaspell15': 'pool/main/a/aspell/libaspell15_0.60.8-1ubuntu0.1_amd64.deb',
#  'libatomic1': 'pool/main/g/gcc-10/libatomic1_10.5.0-1ubuntu1~20.04_amd64.deb',
# ...
#  'libjson-c-dev': 'pool/main/j/json-c/libjson-c-dev_0.13.1+dfsg-7ubuntu0.3_amd64.deb',
#  'libjson-c-doc': 'pool/main/j/json-c/libjson-c-doc_0.13.1+dfsg-7ubuntu0.3_all.deb',
#  'libjson-c4': 'pool/main/j/json-c/libjson-c4_0.13.1+dfsg-7ubuntu0.3_amd64.deb',
#  'libjuh-java': 'pool/main/libr/libreoffice/libjuh-java_6.4.7-0ubuntu0.20.04.9_all.deb',
#  'libjurt-java': 'pool/main/libr/libreoffice/libjurt-java_6.4.7-0ubuntu0.20.04.9_all.deb',
#  'libk5crypto3': 'pool/main/k/krb5/libk5crypto3_1.17-6ubuntu4.4_amd64.deb',
#  'libkadm5clnt-mit11': 'pool/main/k/krb5/libkadm5clnt-mit11_1.17-6ubuntu4.4_amd64.deb',
#  'libkadm5clnt7-heimdal': 'pool/main/h/heimdal/libkadm5clnt7-heimdal_7.7.0+dfsg-1ubuntu1.4_amd64.deb',
#  'libkadm5srv-mit11': 'pool/main/k/krb5/libkadm5srv-mit11_1.17-6ubuntu4.4_amd64.deb',
#  'libkadm5srv8-heimdal': 'pool/main/h/heimdal/libkadm5srv8-heimdal_7.7.0+dfsg-1ubuntu1.4_amd64.deb',
#  'libkafs0-heimdal': 'pool/main/h/heimdal/libkafs0-heimdal_7.7.0+dfsg-1ubuntu1.4_amd64.deb',
#  'libkdb5-9': 'pool/main/k/krb5/libkdb5-9_1.17-6ubuntu4.4_amd64.deb',
#  'libkdc2-heimdal': 'pool/main/h/heimdal/libkdc2-heimdal_7.7.0+dfsg-1ubuntu1.4_amd64.deb',
#  'libklibc': 'pool/main/k/klibc/libklibc_2.0.7-1ubuntu5.1_amd64.deb',
#  'libklibc-dev': 'pool/main/k/klibc/libklibc-dev_2.0.7-1ubuntu5.1_amd64.deb',
#  'libkpathsea-dev': 'pool/main/t/texlive-bin/libkpathsea-dev_2019.20190605.51237-3ubuntu0.1_amd64.deb',
#  'libkpathsea6': 'pool/main/t/texlive-bin/libkpathsea6_2019.20190605.51237-3ubuntu0.1_amd64.deb',
#  'libkrad-dev': 'pool/main/k/krb5/libkrad-dev_1.17-6ubuntu4.4_amd64.deb',
#  'libkrad0': 'pool/main/k/krb5/libkrad0_1.17-6ubuntu4.4_amd64.deb',
#  'libkrb5-26-heimdal': 'pool/main/h/heimdal/libkrb5-26-heimdal_7.7.0+dfsg-1ubuntu1.4_amd64.deb',
#  'libkrb5-3': 'pool/main/k/krb5/libkrb5-3_1.17-6ubuntu4.4_amd64.deb',
#  'libkrb5-dbg': 'pool/main/k/krb5/libkrb5-dbg_1.17-6ubuntu4.4_amd64.deb',
#  'libkrb5-dev': 'pool/main/k/krb5/libkrb5-dev_1.17-6ubuntu4.4_amd64.deb',
#  'libkrb5support0': 'pool/main/k/krb5/libkrb5support0_1.17-6ubuntu4.4_amd64.deb',
#  'libksba-dev': 'pool/main/libk/libksba/libksba-dev_1.3.5-2ubuntu0.20.04.2_amd64.deb',
#  'libksba8': 'pool/main/libk/libksba/libksba8_1.3.5-2ubuntu0.20.04.2_amd64.deb',
#  'liblasso3': 'pool/main/l/lasso/liblasso3_2.6.0-7ubuntu1.2_amd64.deb',
#  'liblasso3-dev': 'pool/main/l/lasso/liblasso3-dev_2.6.0-7ubuntu1.2_amd64.deb',
#  'libldap-2.4-2': 'pool/main/o/openldap/libldap-2.4-2_2.4.49+dfsg-2ubuntu1.9_amd64.deb',
#  'libldap-common': 'pool/main/o/openldap/libldap-common_2.4.49+dfsg-2ubuntu1.9_all.deb',
#  'libldap2-dev': 'pool/main/o/openldap/libldap2-dev_2.4.49+dfsg-2ubuntu1.9_amd64.deb',
#  'libldb-dev': 'pool/main/l/ldb/libldb-dev_2.4.4-0ubuntu0.20.04.2_amd64.deb',
#  'libldb2': 'pool/main/l/ldb/libldb2_2.4.4-0ubuntu0.20.04.2_amd64.deb',
#  'liblibreofficekitgtk': 'pool/main/libr/libreoffice/liblibreofficekitgtk_6.4.7-0ubuntu0.20.04.9_amd64.deb',
#  'libllvm12': 'pool/main/l/llvm-toolchain-12/libllvm12_12.0.0-3ubuntu1~20.04.5_amd64.deb',
#  'liblouis-data': 'pool/main/libl/liblouis/liblouis-data_3.12.0-3ubuntu0.2_all.deb',
#  'liblouis-dev': 'pool/main/libl/liblouis/liblouis-dev_3.12.0-3ubuntu0.2_amd64.deb',
#  'liblouis20': 'pool/main/libl/liblouis/liblouis20_3.12.0-3ubuntu0.2_amd64.deb',
#  'liblrmd-dev': 'pool/main/p/pacemaker/liblrmd-dev_2.0.3-3ubuntu4.1_all.deb',
#  'liblrmd28': 'pool/main/p/pacemaker/liblrmd28_2.0.3-3ubuntu4.1_amd64.deb',
#  'liblsan0': 'pool/main/g/gcc-10/liblsan0_10.5.0-1ubuntu1~20.04_amd64.deb',
#  'liblsan0-arm64-cross': 'pool/main/g/gcc-10-cross/liblsan0-arm64-cross_10.5.0-1ubuntu1~20.04cross1_all.deb',
#  'liblsan0-ppc64el-cross': 'pool/main/g/gcc-10-cross/liblsan0-ppc64el-cross_10.5.0-1ubuntu1~20.04cross1_all.deb',
#  'liblz4-1': 'pool/main/l/lz4/liblz4-1_1.9.2-2ubuntu0.20.04.1_amd64.deb',
#  'liblz4-dev': 'pool/main/l/lz4/liblz4-dev_1.9.2-2ubuntu0.20.04.1_amd64.deb',
#  'liblzma-dev': 'pool/main/x/xz-utils/liblzma-dev_5.2.4-1ubuntu1.1_amd64.deb',
#  'liblzma-doc': 'pool/main/x/xz-utils/liblzma-doc_5.2.4-1ubuntu1.1_all.deb',
#  'liblzma5': 'pool/main/x/xz-utils/liblzma5_5.2.4-1ubuntu1.1_amd64.deb',
#  'libmaxminddb-dev': 'pool/main/libm/libmaxminddb/libmaxminddb-dev_1.4.2-0ubuntu1.20.04.1_amd64.deb',
#  'libmaxminddb0': 'pool/main/libm/libmaxminddb/libmaxminddb0_1.4.2-0ubuntu1.20.04.1_amd64.deb',
#  'libmount-dev': 'pool/main/u/util-linux/libmount-dev_2.34-0.1ubuntu9.3_amd64.deb',
#  'libmount1': 'pool/main/u/util-linux/libmount1_2.34-0.1ubuntu9.3_amd64.deb',
#  'libmysqlclient-dev': 'pool/main/m/mysql-8.0/libmysqlclient-dev_8.0.35-0ubuntu0.20.04.1_amd64.deb',
#  'libmysqlclient21': 'pool/main/m/mysql-8.0/libmysqlclient21_8.0.35-0ubuntu0.20.04.1_amd64.deb',
#  'libnautilus-extension-dev': 'pool/main/n/nautilus/libnautilus-extension-dev_3.36.3-0ubuntu1.20.04.2_amd64.deb',
#  'libnautilus-extension1a': 'pool/main/n/nautilus/libnautilus-extension1a_3.36.3-0ubuntu1.20.04.2_amd64.deb',
#  'libncurses-dev': 'pool/main/n/ncurses/libncurses-dev_6.2-0ubuntu2.1_amd64.deb',
#  'libncurses5-dev': 'pool/main/n/ncurses/libncurses5-dev_6.2-0ubuntu2.1_amd64.deb',
#  'libncurses6': 'pool/main/n/ncurses/libncurses6_6.2-0ubuntu2.1_amd64.deb',
#  'libncursesw5-dev': 'pool/main/n/ncurses/libncursesw5-dev_6.2-0ubuntu2.1_amd64.deb',
#  'libncursesw6': 'pool/main/n/ncurses/libncursesw6_6.2-0ubuntu2.1_amd64.deb',
#  'libnettle7': 'pool/main/n/nettle/libnettle7_3.5.1+really3.5.1-2ubuntu0.2_amd64.deb',
#  'libnghttp2-14': 'pool/main/n/nghttp2/libnghttp2-14_1.40.0-1ubuntu0.2_amd64.deb',
#  'libnghttp2-dev': 'pool/main/n/nghttp2/libnghttp2-dev_1.40.0-1ubuntu0.2_amd64.deb',
#  'libnghttp2-doc': 'pool/main/n/nghttp2/libnghttp2-doc_1.40.0-1ubuntu0.2_all.deb',
#  'libnginx-mod-http-image-filter': 'pool/main/n/nginx/libnginx-mod-http-image-filter_1.18.0-0ubuntu1.4_amd64.deb',
#  'libnginx-mod-http-xslt-filter': 'pool/main/n/nginx/libnginx-mod-http-xslt-filter_1.18.0-0ubuntu1.4_amd64.deb',
#  'libnginx-mod-mail': 'pool/main/n/nginx/libnginx-mod-mail_1.18.0-0ubuntu1.4_amd64.deb',
#  'libnginx-mod-stream': 'pool/main/n/nginx/libnginx-mod-stream_1.18.0-0ubuntu1.4_amd64.deb',
#  'libnss-myhostname': 'pool/main/s/systemd/libnss-myhostname_245.4-4ubuntu3.20_amd64.deb',
#  'libnss-mymachines': 'pool/main/s/systemd/libnss-mymachines_245.4-4ubuntu3.20_amd64.deb',
#  'libnss-sss': 'pool/main/s/sssd/libnss-sss_2.2.3-3ubuntu0.12_amd64.deb',
#  'libnss-systemd': 'pool/main/s/systemd/libnss-systemd_245.4-4ubuntu3.20_amd64.deb',
#  'libnss-winbind': 'pool/main/s/samba/libnss-winbind_4.15.13+dfsg-0ubuntu0.20.04.7_amd64.deb',
#  'libnss3': 'pool/main/n/nss/libnss3_3.49.1-1ubuntu1.9_amd64.deb',
#  'libnss3-dev': 'pool/main/n/nss/libnss3-dev_3.49.1-1ubuntu1.9_amd64.deb',
#  'libntfs-3g883': 'pool/main/n/ntfs-3g/libntfs-3g883_2017.3.23AR.3-3ubuntu1.3_amd64.deb',
#  'libnvpair1linux': 'pool/main/z/zfs-linux/libnvpair1linux_0.8.3-1ubuntu12.16_amd64.deb',
#  'libofficebean-java': 'pool/main/libr/libreoffice/libofficebean-java_6.4.7-0ubuntu0.20.04.9_amd64.deb',
#  'libopengl-dev': 'pool/main/libg/libglvnd/libopengl-dev_1.3.2-1~ubuntu0.20.04.2_amd64.deb',
#  'libopengl0': 'pool/main/libg/libglvnd/libopengl0_1.3.2-1~ubuntu0.20.04.2_amd64.deb',
#  'libopenjp2-7': 'pool/main/o/openjpeg2/libopenjp2-7_2.3.1-1ubuntu4.20.04.1_amd64.deb',
#  'libopenjp2-7-dev': 'pool/main/o/openjpeg2/libopenjp2-7-dev_2.3.1-1ubuntu4.20.04.1_amd64.deb',
#  'libosmesa6': 'pool/main/m/mesa/libosmesa6_21.2.6-0ubuntu0.1~20.04.2_amd64.deb',
#  'libosmesa6-dev': 'pool/main/m/mesa/libosmesa6-dev_21.2.6-0ubuntu0.1~20.04.2_amd64.deb',
#  'libotp0-heimdal': 'pool/main/h/heimdal/libotp0-heimdal_7.7.0+dfsg-1ubuntu1.4_amd64.deb',
#  'libp11-kit-dev': 'pool/main/p/p11-kit/libp11-kit-dev_0.23.20-1ubuntu0.1_amd64.deb',
#  'libp11-kit0': 'pool/main/p/p11-kit/libp11-kit0_0.23.20-1ubuntu0.1_amd64.deb',
#  'libpacemaker1': 'pool/main/p/pacemaker/libpacemaker1_2.0.3-3ubuntu4.1_amd64.deb',
#  'libpackagekit-glib2-18': 'pool/main/p/packagekit/libpackagekit-glib2-18_1.1.13-2ubuntu1.1_amd64.deb',
#  'libpackagekit-glib2-dev': 'pool/main/p/packagekit/libpackagekit-glib2-dev_1.1.13-2ubuntu1.1_amd64.deb',
#  'libpam-cap': 'pool/main/libc/libcap2/libpam-cap_2.32-1ubuntu0.1_amd64.deb',
#  'libpam-cracklib': 'pool/main/p/pam/libpam-cracklib_1.3.1-5ubuntu4.7_amd64.deb',
#  'libpam-doc': 'pool/main/p/pam/libpam-doc_1.3.1-5ubuntu4.7_all.deb',
#  'libpam-modules': 'pool/main/p/pam/libpam-modules_1.3.1-5ubuntu4.7_amd64.deb',
#  'libpam-modules-bin': 'pool/main/p/pam/libpam-modules-bin_1.3.1-5ubuntu4.7_amd64.deb',
#  'libpam-runtime': 'pool/main/p/pam/libpam-runtime_1.3.1-5ubuntu4.7_all.deb',
#  'libpam-sss': 'pool/main/s/sssd/libpam-sss_2.2.3-3ubuntu0.12_amd64.deb',
#  'libpam-systemd': 'pool/main/s/systemd/libpam-systemd_245.4-4ubuntu3.20_amd64.deb',
#  'libpam-winbind': 'pool/main/s/samba/libpam-winbind_4.15.13+dfsg-0ubuntu0.20.04.7_amd64.deb',
#  'libpam0g': 'pool/main/p/pam/libpam0g_1.3.1-5ubuntu4.7_amd64.deb',
#  'libpam0g-dev': 'pool/main/p/pam/libpam0g-dev_1.3.1-5ubuntu4.7_amd64.deb',
#  'libpcre16-3': 'pool/main/p/pcre3/libpcre16-3_8.39-12ubuntu0.1_amd64.deb',
#  'libpcre2-16-0': 'pool/main/p/pcre2/libpcre2-16-0_10.34-7ubuntu0.1_amd64.deb',
#  'libpcre2-32-0': 'pool/main/p/pcre2/libpcre2-32-0_10.34-7ubuntu0.1_amd64.deb',
#  'libpcre2-8-0': 'pool/main/p/pcre2/libpcre2-8-0_10.34-7ubuntu0.1_amd64.deb',
#  'libpcre2-dev': 'pool/main/p/pcre2/libpcre2-dev_10.34-7ubuntu0.1_amd64.deb',
#  'libpcre2-posix2': 'pool/main/p/pcre2/libpcre2-posix2_10.34-7ubuntu0.1_amd64.deb',
#  'libpcre3': 'pool/main/p/pcre3/libpcre3_8.39-12ubuntu0.1_amd64.deb',
#  'libpcre3-dbg': 'pool/main/p/pcre3/libpcre3-dbg_8.39-12ubuntu0.1_amd64.deb',
#  'libpcre3-dev': 'pool/main/p/pcre3/libpcre3-dev_8.39-12ubuntu0.1_amd64.deb',
#  'libpcre32-3': 'pool/main/p/pcre3/libpcre32-3_8.39-12ubuntu0.1_amd64.deb',
#  'libpcrecpp0v5': 'pool/main/p/pcre3/libpcrecpp0v5_8.39-12ubuntu0.1_amd64.deb',
#  'libpe-rules26': 'pool/main/p/pacemaker/libpe-rules26_2.0.3-3ubuntu4.1_amd64.deb',
#  'libpe-status28': 'pool/main/p/pacemaker/libpe-status28_2.0.3-3ubuntu4.1_amd64.deb',
#  'libpengine-dev': 'pool/main/p/pacemaker/libpengine-dev_2.0.3-3ubuntu4.1_all.deb',
#  'libperl-dev': 'pool/main/p/perl/libperl-dev_5.30.0-9ubuntu0.5_amd64.deb',
#  'libperl5.30': 'pool/main/p/perl/libperl5.30_5.30.0-9ubuntu0.5_amd64.deb',
#  'libpgtypes3': 'pool/main/p/postgresql-12/libpgtypes3_12.17-0ubuntu0.20.04.1_amd64.deb',
#  'libpixman-1-0': 'pool/main/p/pixman/libpixman-1-0_0.38.4-0ubuntu2.1_amd64.deb',
#  'libpixman-1-dev': 'pool/main/p/pixman/libpixman-1-dev_0.38.4-0ubuntu2.1_amd64.deb',
#  'libpolkit-agent-1-0': 'pool/main/p/policykit-1/libpolkit-agent-1-0_0.105-26ubuntu1.3_amd64.deb',
#  'libpolkit-agent-1-dev': 'pool/main/p/policykit-1/libpolkit-agent-1-dev_0.105-26ubuntu1.3_amd64.deb',
#  'libpolkit-gobject-1-0': 'pool/main/p/policykit-1/libpolkit-gobject-1-0_0.105-26ubuntu1.3_amd64.deb',
#  'libpolkit-gobject-1-dev': 'pool/main/p/policykit-1/libpolkit-gobject-1-dev_0.105-26ubuntu1.3_amd64.deb',
#  'libpoppler-cpp-dev': 'pool/main/p/poppler/libpoppler-cpp-dev_0.86.1-0ubuntu1.4_amd64.deb',
#  'libpoppler-cpp0v5': 'pool/main/p/poppler/libpoppler-cpp0v5_0.86.1-0ubuntu1.4_amd64.deb',
#  'libpoppler-dev': 'pool/main/p/poppler/libpoppler-dev_0.86.1-0ubuntu1.4_amd64.deb',
#  'libpoppler-glib-dev': 'pool/main/p/poppler/libpoppler-glib-dev_0.86.1-0ubuntu1.4_amd64.deb',
#  'libpoppler-glib-doc': 'pool/main/p/poppler/libpoppler-glib-doc_0.86.1-0ubuntu1.4_all.deb',
#  'libpoppler-glib8': 'pool/main/p/poppler/libpoppler-glib8_0.86.1-0ubuntu1.4_amd64.deb',
#  'libpoppler-private-dev': 'pool/main/p/poppler/libpoppler-private-dev_0.86.1-0ubuntu1.4_amd64.deb',
#  'libpoppler97': 'pool/main/p/poppler/libpoppler97_0.86.1-0ubuntu1.4_amd64.deb',
#  'libpq-dev': 'pool/main/p/postgresql-12/libpq-dev_12.17-0ubuntu0.20.04.1_amd64.deb',
#  'libpq5': 'pool/main/p/postgresql-12/libpq5_12.17-0ubuntu0.20.04.1_amd64.deb',
#  'libprocps-dev': 'pool/main/p/procps/libprocps-dev_3.3.16-1ubuntu2.4_amd64.deb',
#  'libprocps8': 'pool/main/p/procps/libprocps8_3.3.16-1ubuntu2.4_amd64.deb',
#  'libprotobuf-dev': 'pool/main/p/protobuf/libprotobuf-dev_3.6.1.3-2ubuntu5.2_amd64.deb',
#  'libprotobuf-lite17': 'pool/main/p/protobuf/libprotobuf-lite17_3.6.1.3-2ubuntu5.2_amd64.deb',
#  'libprotobuf17': 'pool/main/p/protobuf/libprotobuf17_3.6.1.3-2ubuntu5.2_amd64.deb',
#  'libprotoc-dev': 'pool/main/p/protobuf/libprotoc-dev_3.6.1.3-2ubuntu5.2_amd64.deb',
#  'libprotoc17': 'pool/main/p/protobuf/libprotoc17_3.6.1.3-2ubuntu5.2_amd64.deb',
#  'libproxy-dev': 'pool/main/libp/libproxy/libproxy-dev_0.4.15-10ubuntu1.2_amd64.deb',
#  'libproxy1-plugin-gsettings': 'pool/main/libp/libproxy/libproxy1-plugin-gsettings_0.4.15-10ubuntu1.2_amd64.deb',
#  'libproxy1-plugin-networkmanager': 'pool/main/libp/libproxy/libproxy1-plugin-networkmanager_0.4.15-10ubuntu1.2_amd64.deb',
#  'libproxy1v5': 'pool/main/libp/libproxy/libproxy1v5_0.4.15-10ubuntu1.2_amd64.deb',
#  'libpspell-dev': 'pool/main/a/aspell/libpspell-dev_0.60.8-1ubuntu0.1_amd64.deb',
#  'libptexenc-dev': 'pool/main/t/texlive-bin/libptexenc-dev_2019.20190605.51237-3ubuntu0.1_amd64.deb',
#  'libptexenc1': 'pool/main/t/texlive-bin/libptexenc1_2019.20190605.51237-3ubuntu0.1_amd64.deb',
#  'libpulse-dev': 'pool/main/p/pulseaudio/libpulse-dev_13.99.1-1ubuntu3.8_amd64.deb',
#  'libpulse-mainloop-glib0': 'pool/main/p/pulseaudio/libpulse-mainloop-glib0_13.99.1-1ubuntu3.8_amd64.deb',
#  'libpulse0': 'pool/main/p/pulseaudio/libpulse0_13.99.1-1ubuntu3.8_amd64.deb',
#  'libpulsedsp': 'pool/main/p/pulseaudio/libpulsedsp_13.99.1-1ubuntu3.8_amd64.deb',
#  'libpython3.8': 'pool/main/p/python3.8/libpython3.8_3.8.10-0ubuntu1~20.04.9_amd64.deb',
#  'libpython3.8-dbg': 'pool/main/p/python3.8/libpython3.8-dbg_3.8.10-0ubuntu1~20.04.9_amd64.deb',
#  'libpython3.8-dev': 'pool/main/p/python3.8/libpython3.8-dev_3.8.10-0ubuntu1~20.04.9_amd64.deb',
#  'libpython3.8-minimal': 'pool/main/p/python3.8/libpython3.8-minimal_3.8.10-0ubuntu1~20.04.9_amd64.deb',
#  'libpython3.8-stdlib': 'pool/main/p/python3.8/libpython3.8-stdlib_3.8.10-0ubuntu1~20.04.9_amd64.deb',
#  'libqpdf-dev': 'pool/main/q/qpdf/libqpdf-dev_9.1.1-1ubuntu0.1_amd64.deb',
#  'libqpdf26': 'pool/main/q/qpdf/libqpdf26_9.1.1-1ubuntu0.1_amd64.deb',
#  'libquadmath0': 'pool/main/g/gcc-10/libquadmath0_10.5.0-1ubuntu1~20.04_amd64.deb',
#  'libquadmath0-ppc64el-cross': 'pool/main/g/gcc-10-cross/libquadmath0-ppc64el-cross_10.5.0-1ubuntu1~20.04cross1_all.deb',
#  'librados-dev': 'pool/main/c/ceph/librados-dev_15.2.17-0ubuntu0.20.04.3_amd64.deb',
#  'librados2': 'pool/main/c/ceph/librados2_15.2.17-0ubuntu0.20.04.3_amd64.deb',
#  'libradospp-dev': 'pool/main/c/ceph/libradospp-dev_15.2.17-0ubuntu0.20.04.3_amd64.deb',
#  'libradosstriper-dev': 'pool/main/c/ceph/libradosstriper-dev_15.2.17-0ubuntu0.20.04.3_amd64.deb',
#  'libradosstriper1': 'pool/main/c/ceph/libradosstriper1_15.2.17-0ubuntu0.20.04.3_amd64.deb',
#  'libraptor2-0': 'pool/main/r/raptor2/libraptor2-0_2.0.15-0ubuntu1.20.04.1_amd64.deb',
#  'libraptor2-0-dbg': 'pool/main/r/raptor2/libraptor2-0-dbg_2.0.15-0ubuntu1.20.04.1_amd64.deb',
#  'libraptor2-dev': 'pool/main/r/raptor2/libraptor2-dev_2.0.15-0ubuntu1.20.04.1_amd64.deb',
#  'libraptor2-doc': 'pool/main/r/raptor2/libraptor2-doc_2.0.15-0ubuntu1.20.04.1_all.deb',
#  'libraw-dev': 'pool/main/libr/libraw/libraw-dev_0.19.5-1ubuntu1.3_amd64.deb',
#  'libraw-doc': 'pool/main/libr/libraw/libraw-doc_0.19.5-1ubuntu1.3_all.deb',
#  'libraw19': 'pool/main/libr/libraw/libraw19_0.19.5-1ubuntu1.3_amd64.deb',
#  'librbd-dev': 'pool/main/c/ceph/librbd-dev_15.2.17-0ubuntu0.20.04.3_amd64.deb',
#  'librbd1': 'pool/main/c/ceph/librbd1_15.2.17-0ubuntu0.20.04.3_amd64.deb',
#  'libreoffice-base-core': 'pool/main/libr/libreoffice/libreoffice-base-core_6.4.7-0ubuntu0.20.04.9_amd64.deb',
#  'libreoffice-calc': 'pool/main/libr/libreoffice/libreoffice-calc_6.4.7-0ubuntu0.20.04.9_amd64.deb',
#  'libreoffice-common': 'pool/main/libr/libreoffice/libreoffice-common_6.4.7-0ubuntu0.20.04.9_all.deb',
#  'libreoffice-core': 'pool/main/libr/libreoffice/libreoffice-core_6.4.7-0ubuntu0.20.04.9_amd64.deb',
#  'libreoffice-dev': 'pool/main/libr/libreoffice/libreoffice-dev_6.4.7-0ubuntu0.20.04.9_amd64.deb',
#  'libreoffice-dev-common': 'pool/main/libr/libreoffice/libreoffice-dev-common_6.4.7-0ubuntu0.20.04.9_all.deb',
#  ...}

# %%
import re
from collections import defaultdict

def filter_linux_images(package_index):
    result = defaultdict(dict)
    for package, path in package_index.items():
        groups = re.match(
            r"linux-image-(\d+\.\d+\.\d+)-(\d+)-generic", package)
        if groups is None:
            continue

        version, build = groups.groups()
        result[version][int(build)] = package, path

    result = {k: v[max(v.keys())] for k, v in result.items()}
    return result


linux_versions = filter_linux_images(package_index)

linux_versions
# Out:
# {'5.11.0': ('linux-image-5.11.0-46-generic',
#   'pool/main/l/linux-signed-hwe-5.11/linux-image-5.11.0-46-generic_5.11.0-46.51~20.04.1_amd64.deb'),
#  '5.13.0': ('linux-image-5.13.0-52-generic',
#   'pool/main/l/linux-signed-hwe-5.13/linux-image-5.13.0-52-generic_5.13.0-52.59~20.04.1_amd64.deb'),
#  '5.15.0': ('linux-image-5.15.0-92-generic',
#   'pool/main/l/linux-signed-hwe-5.15/linux-image-5.15.0-92-generic_5.15.0-92.102~20.04.1_amd64.deb'),
#  '5.4.0': ('linux-image-5.4.0-170-generic',
#   'pool/main/l/linux-signed/linux-image-5.4.0-170-generic_5.4.0-170.188_amd64.deb'),
#  '5.8.0': ('linux-image-5.8.0-63-generic',
#   'pool/main/l/linux-signed-hwe-5.8/linux-image-5.8.0-63-generic_5.8.0-63.71~20.04.1_amd64.deb')}

# %%
def download_deb_files(linux_versions):
    results = {}
    for version, (package, path) in linux_versions.items():
        if version in ['5.4.0', '5.8.0']:  # we already have these
            continue

        url = f"http://security.ubuntu.com/ubuntu/{path}"
        file_path = tmp_path / path.split("/")[-1]
        if not file_path.exists():
            print(f"Downloading {url} to {file_path}")
            urllib.request.urlretrieve(url, file_path)
        else:
            print(f"Using {file_path}")

        key = package.removeprefix("linux-image-")
        results[key] = file_path

    return results


deb_paths = download_deb_files(linux_versions)

deb_paths
# Out:
# Using data/20.04-x86/tmp/linux-image-5.11.0-46-generic_5.11.0-46.51~20.04.1_amd64.deb
# Using data/20.04-x86/tmp/linux-image-5.13.0-52-generic_5.13.0-52.59~20.04.1_amd64.deb
# Using data/20.04-x86/tmp/linux-image-5.15.0-92-generic_5.15.0-92.102~20.04.1_amd64.deb
# {'5.11.0-46-generic': PosixPath('data/20.04-x86/tmp/linux-image-5.11.0-46-generic_5.11.0-46.51~20.04.1_amd64.deb'),
#  '5.13.0-52-generic': PosixPath('data/20.04-x86/tmp/linux-image-5.13.0-52-generic_5.13.0-52.59~20.04.1_amd64.deb'),
#  '5.15.0-92-generic': PosixPath('data/20.04-x86/tmp/linux-image-5.15.0-92-generic_5.15.0-92.102~20.04.1_amd64.deb')}

# %%
def extract_vmlinuz_files(deb_paths):
    results = {}
    for name, deb_path in deb_paths.items():
        vmlinuz_path = tmp_path / "boot" / f"vmlinuz-{name}"
        if not vmlinuz_path.exists():
            print(f"Extracting {deb_path} to {vmlinuz_path}")
            system(f"dpkg-deb -x {deb_path} {tmp_path}")
        else:
            print(f"Using {vmlinuz_path}")
        results[name] = vmlinuz_path
    return results


vmlinuz_paths = extract_vmlinuz_files(deb_paths)

vmlinuz_paths
# Out:
# Using data/20.04-x86/tmp/boot/vmlinuz-5.11.0-46-generic
# Using data/20.04-x86/tmp/boot/vmlinuz-5.13.0-52-generic
# Using data/20.04-x86/tmp/boot/vmlinuz-5.15.0-92-generic
# {'5.11.0-46-generic': PosixPath('data/20.04-x86/tmp/boot/vmlinuz-5.11.0-46-generic'),
#  '5.13.0-52-generic': PosixPath('data/20.04-x86/tmp/boot/vmlinuz-5.13.0-52-generic'),
#  '5.15.0-92-generic': PosixPath('data/20.04-x86/tmp/boot/vmlinuz-5.15.0-92-generic')}

# %%
def download_extract_vmlinux():
    result = tmp_path / Path("extract-vmlinux")
    if not result.exists():
        print(f"Downloading {result}")
        urllib.request.urlretrieve(
            "https://raw.githubusercontent.com/torvalds/linux/master/scripts/extract-vmlinux", result)
        system(f"chmod +x {result}")
    else:
        print(f"Using {result}")
    return result


extract_vmlinux = download_extract_vmlinux()

extract_vmlinux
# Out:
# Using data/20.04-x86/tmp/extract-vmlinux
# PosixPath('data/20.04-x86/tmp/extract-vmlinux')

# %%
def extract_vmlinux_files(vmlinuz_paths):
    results = {}
    for name, vmlinuz_path in vmlinuz_paths.items():
        vmlinux_path = tmp_path / f"vmlinux-{name}"
        if not vmlinux_path.exists():
            print(f"Extracting {vmlinuz_path} to {vmlinux_path}")
            system(f"{extract_vmlinux} {vmlinuz_path} > {vmlinux_path}")
        else:
            print(f"Using {vmlinux_path}")
        results[name] = vmlinux_path
    return results


vmlinux_paths = extract_vmlinux_files(vmlinuz_paths)

vmlinux_paths
# Out:
# Using data/20.04-x86/tmp/vmlinux-5.11.0-46-generic
# Using data/20.04-x86/tmp/vmlinux-5.13.0-52-generic
# Using data/20.04-x86/tmp/vmlinux-5.15.0-92-generic
# {'5.11.0-46-generic': PosixPath('data/20.04-x86/tmp/vmlinux-5.11.0-46-generic'),
#  '5.13.0-52-generic': PosixPath('data/20.04-x86/tmp/vmlinux-5.13.0-52-generic'),
#  '5.15.0-92-generic': PosixPath('data/20.04-x86/tmp/vmlinux-5.15.0-92-generic')}

# %%
def extract_btf_files(vmlinux_paths):
    results = {}
    for name, vmlinux_path in vmlinux_paths.items():
        btf_path = data_path / f"{name}.btf"
        if not btf_path.exists():
            print(f"Extracting {vmlinux_path} to {btf_path}")
            system(
                f"objcopy -I elf64-little {vmlinux_path} --dump-section .BTF={btf_path}")
            # we use objcopy instead of pahole because pahole sometimes fails with
            # "btf_encoder__new: cannot get ELF header", and pahole seems does more
            # processing than we need
            # system(f"pahole --btf_encode_detached {btf_path} {vmlinux_path}")
        else:
            print(f"Using {btf_path}")
        results[vmlinux_path.name] = btf_path

    return results


btf_paths = extract_btf_files(vmlinux_paths)

btf_paths
# Out:
# Using data/20.04-x86/5.11.0-46-generic.btf
# Using data/20.04-x86/5.13.0-52-generic.btf
# Using data/20.04-x86/5.15.0-92-generic.btf
# {'vmlinux-5.11.0-46-generic': PosixPath('data/20.04-x86/5.11.0-46-generic.btf'),
#  'vmlinux-5.13.0-52-generic': PosixPath('data/20.04-x86/5.13.0-52-generic.btf'),
#  'vmlinux-5.15.0-92-generic': PosixPath('data/20.04-x86/5.15.0-92-generic.btf')}

# %% [markdown]
# # Generate JSON Files

# %%
from pathlib import Path

def get_linux_tools_path():
    parent = Path("/usr/lib/linux-tools")
    versions = [x for x in parent.iterdir() if x.is_dir()]
    if len(versions) == 0:
        raise Exception("No linux-tools found")
    versions.sort()
    return parent / versions[-1]


def get_bpftool_path():
    path = get_linux_tools_path() / "bpftool"
    if not path.exists():
        raise Exception("bpftool not found")
    return path


bpftool_path = get_bpftool_path()
bpftool_path
# Out:
# PosixPath('/usr/lib/linux-tools/6.2.0-39-generic/bpftool')

# %%
def dump_btf(parent_path):
    for file in parent_path.glob("*.btf"):
        for ext, cmd in [(".h", "format c"), (".txt", "format raw"), (".json", "--json")]:
            result = file.with_suffix(ext)
            if not result.exists():
                system(f"{bpftool_path} btf dump file {file} {cmd} > {result}")
            else:
                print(f"{result} already exists")

for path in Path("data").glob("*"):
    if path.is_dir():
        dump_btf(path)

# %% [markdown]
# # Diffing JSON Files

# %%
from enum import Enum


class Kind(str, Enum):
    INT = "INT"
    PTR = "PTR"
    ARRAY = "ARRAY"
    STRUCT = "STRUCT"
    UNION = "UNION"
    ENUM = "ENUM"
    FWD = "FWD"
    TYPEDEF = "TYPEDEF"
    VOLATILE = "VOLATILE"
    CONST = "CONST"
    RESTRICT = "RESTRICT"
    FUNC = "FUNC"
    FUNC_PROTO = "FUNC_PROTO"
    VAR = "VAR"
    DATASEC = "DATASEC"
    FLOAT = "FLOAT"
    DECL_TAG = "DECL_TAG"
    TYPE_TAG = "TYPE_TAG"
    ENUM64 = "ENUM64"

# %%
from functools import cache
from pathlib import Path
import json


class BTF:
    def __init__(self, path):
        self.path = Path(path)
        with open(path) as f:
            self._raw_data = json.load(f)['types']

    def __getitem__(self, id):
        if id == 0:
            return {'id': 0, 'name': 'void', 'kind': 'VOID'}
        e = self._raw_data[id - 1]
        assert e['id'] == id
        return e

    def __len__(self):
        return len(self._raw_data)

    def __iter__(self):
        return iter(self._raw_data)

    @property
    def short_name(self):
        linux_version = self.path.name.split("-")[0]
        assert linux_version.endswith(".0")
        return linux_version[:-2]

    def print(self):
        from collections import defaultdict

        print(f"File: {self.path}")

        print("Sample:")
        kinds = defaultdict(int)
        for e in self:
            if e['kind'] not in kinds:
                print(f"\t{e['id']:6} ({e['kind']:10}): {e}")
                print(f"\t{'':18}-> {self.normalize(e['id'])}")
            kinds[e['kind']] += 1

        kinds = sorted(kinds.items(), key=lambda x: x[1], reverse=True)
        print(f"Kinds:")
        print(f"\t{dict(kinds)}")

        print()

    def filter_on_kind(self, kind):
        return {
            e['name']: self.normalize(e['id']) for e in self
            if e['kind'] == kind and e['name'] != '(anon)'
        }

    def get(self, kind, name):
        for elem in self:
            if elem['kind'] == kind and elem['name'] == name:
                return self.normalize(elem['id'])

    RECURSE_KINDS = {Kind.CONST, Kind.VOLATILE, Kind.RESTRICT,
                     Kind.PTR, Kind.FUNC, Kind.FUNC_PROTO, Kind.ARRAY}

    # @cache
    def normalize(self, type_id, recurse=True):
        elem = self[type_id].copy()

        # Recurse into types for certain kinds
        recurse = recurse or elem['kind'] in self.RECURSE_KINDS

        # Remove redundant fields
        del elem['id']

        kind = elem['kind']
        if kind == Kind.INT:
            assert elem['bits_offset'] == 0
            del elem['bits_offset']
            del elem['encoding']
            del elem['nr_bits']
            del elem['size']
        elif kind == Kind.ARRAY:
            del elem['index_type_id']
        elif kind == Kind.ENUM:
            if not recurse:
                assert elem['vlen'] == len(elem['values'])
                del elem['values']
                del elem['vlen']
                del elem['encoding']
        elif kind == Kind.FUNC:
            assert elem['linkage'] == 'static'
            del elem['linkage']
        elif kind in (Kind.PTR, Kind.FUNC_PROTO):
            assert elem['name'] == '(anon)'
            del elem['name']

        # Normalize types
        for type in ['type', 'ret_type']:
            type_id = f"{type}_id"

            if type_id not in elem:
                continue

            if recurse:
                elem[type] = self.normalize(elem[type_id], recurse=False)
            del elem[type_id]

        for list_key in ['params', 'members']:
            if list_key not in elem:
                continue

            assert len(elem[list_key]) == elem['vlen']
            del elem['vlen']

            if recurse:
                elem[list_key] = [
                    {
                        **{k: v for k, v in item.items() if k != 'type_id'},
                        'type': self.normalize(item['type_id'], recurse=False)
                    }
                    for item in elem[list_key]
                ]
            else:
                del elem[list_key]
                if list_key == 'members':
                    del elem['size']

        return elem


d1 = BTF("data/20.04-x86/5.13.0-52-generic.json")
d2 = BTF("data/20.04-x86/5.15.0-92-generic.json")

d1.get(Kind.UNION, "intel_x86_pebs_dse")

# d1.print()

# d1.get_by_kind_name(Kind.STRUCT, "task_struct")
# d1.get_by_kind_name(Kind.FUNC, "vfs_read")
# Out:
# {'kind': 'UNION',
#  'name': 'intel_x86_pebs_dse',
#  'size': 8,
#  'members': [{'name': 'val',
#    'bits_offset': 0,
#    'type': {'kind': 'TYPEDEF', 'name': 'u64'}},
#   {'name': '(anon)',
#    'bits_offset': 0,
#    'type': {'kind': 'STRUCT', 'name': '(anon)'}},
#   {'name': '(anon)',
#    'bits_offset': 0,
#    'type': {'kind': 'STRUCT', 'name': '(anon)'}},
#   {'name': '(anon)',
#    'bits_offset': 0,
#    'type': {'kind': 'STRUCT', 'name': '(anon)'}}]}

# %%
import sys

def print_as_list(name, s, num=10):
    print(f"{name} ({len(s)}): {list(s)[:num]}")


def diff_dict(old, new):
    added = {k: v for k, v in new.items() if k not in old}
    removed = {k: v for k, v in old.items() if k not in new}
    common = {k: (old[k], new[k]) for k in old.keys() if k in new}
    return added, removed, common


def _check_diff(d_old, d_new, kind, diff):
    f_old = d_old.filter_on_kind(kind)
    f_new = d_new.filter_on_kind(kind)

    print_as_list(f"Old {kind}", f_old.keys())
    print_as_list(f"New {kind}", f_new.keys())

    added, removed, common = diff_dict(f_old, f_new)

    print_as_list(f"Added {kind}", added)
    print_as_list(f"Removed {kind}", removed)
    print_as_list(f"Common {kind}", common)

    changed = {
        name: (old, new)
        for name, (old, new) in common.items()
        if old != new
    }
    print_as_list(f"Changed {kind}", changed.keys())

    for name, (old, new) in changed.items():
        reason = diff(old, new)
        lines = reason.strip().split("\n")
        print(f"{kind:12}{name}")
        for line in lines:
            print(f"{'':20} {line}")


class FileLogger:
    def __init__(self, name, print=True):
        self.print = print
        self.stdout = sys.stdout

        file_path = Path("output") / name
        file_path.parent.mkdir(parents=True, exist_ok=True)
        self.log = open(file_path, "w")

    def write(self, message):
        if self.print:
            self.stdout.write(message)
        self.log.write(message)

    def __enter__(self):
        sys.stdout = self
        return self

    def __exit__(self, exc_type, exc_value, traceback):
        sys.stdout = self.stdout
        self.log.close()

def check_diff(d_old, d_new, kind, diff, print=False):
    assert d_old.path.parent == d_new.path.parent
    parent_name = d_old.path.parent.name
    name = f"{parent_name}/{d_old.short_name}->{d_new.short_name}.{kind.name}.log"
    with FileLogger(name, print=print):
        _check_diff(d_old, d_new, kind, diff)

# %%
def diff_struct(old, new):
    result = ""

    old_members = {m['name']: m for m in old['members']}
    new_members = {m['name']: m for m in new['members']}

    if '(anon)' in old_members or '(anon)' in new_members:
        return "Struct has anonymous fields"

    added, removed, common = diff_dict(old_members, new_members)

    # added field
    if added:
        result += f"Added fields:\n"
        for name, value in added.items():
            result += f"{name:>20}: {value['type']}\n"

    # removed field
    if removed:
        result += f"Removed fields:\n"
        for name, value in removed.items():
            result += f"{name:>20}: {value['type']}\n"

    # fields reordered
    if [n for n in old_members if n in common] != [n for n in new_members if n in common]:
        result += f"Fields reordered:\n"
        result += f"{'':>20} {list(old_members)}\n"
        result += f"{'':>20} {list(new_members)}\n"

    # fields changed type
    changed_types = {
        name: (old_value['type'], new_value['type'])
        for name, (old_value, new_value) in common.items()
        if old_value['type'] != new_value['type']
    }
    if changed_types:
        result += "Field type changed:\n"
        for name, (old_type, new_type) in changed_types.items():
            result += f"{name:>20}: {old_type}\n"
            result += f"{'':>20}->{new_type}\n"

    # fields changed offset
    old_offset = {name: old_members[name]
                  ['bits_offset'] for name in old_members}
    new_offset = {name: new_members[name]
                  ['bits_offset'] for name in new_members}
    layout_changed = old_offset != new_offset or old['size'] != new['size']
    if layout_changed and result == "":
        result += f"Layout changed\n"

    assert result, f"\n{old}\n{new}"
    return result


# check_diff(d1, d2, Kind.STRUCT, diff_struct, print=True)

# %%
# check_diff(d1, d2, Kind.UNION, diff_struct, print=True)

# %%
def diff_func(old, new):
    result = ""

    old_params = {p['name']: p for p in old['type']['params']}
    new_params = {p['name']: p for p in new['type']['params']}

    added, removed, common = diff_dict(old_params, new_params)

    # params added
    if added:
        result += f"Added params:\n"
        for name, value in added.items():
            result += f"{name:>20}: {value['type']}\n"

    # params removed
    if removed:
        result += f"Removed params:\n"
        for name, value in removed.items():
            result += f"{name:>20}: {value['type']}\n"

    # params reordered
    if [n for n in old_params if n in common] != [n for n in new_params if n in common]:
        result += f"Params reordered:\n"
        result += f"{'':>20} {list(old_params)}\n"
        result += f"{'':>20} {list(new_params)}\n"

    # params changed type
    changed_types = {
        name: (old_value['type'], new_value['type'])
        for name, (old_value, new_value) in common.items()
        if old_value['type'] != new_value['type']
    }
    if changed_types:
        result += "Param type changed:\n"
        for name, (old_type, new_type) in changed_types.items():
            result += f"{name:>20}: {old_type}\n"
            result += f"{'':>20}->{new_type}\n"

    # changed return value
    old_ret = old['type']['ret_type']
    new_ret = new['type']['ret_type']
    if old_ret != new_ret:
        result += f"Return type changed:\n"
        result += f"{'':>20}: {old_ret}\n"
        result += f"{'':>20}->{new_ret}\n"

    assert result, f"\n{old}\n{new}"
    return result


# check_diff(d1, d2, Kind.FUNC, diff_func, print=True)

# %%
def diff_enum(old, new):
    result = ""

    old_values = {v['name']: v for v in old['values']}
    new_values = {v['name']: v for v in new['values']}

    added, removed, common = diff_dict(old_values, new_values)

    # added value
    if added:
        result += f"Added values:\n"
        for name, value in added.items():
            result += f"{'':8}{name:40}: {value['val']}\n"

    # removed value
    if removed:
        result += f"Removed values:\n"
        for name, value in removed.items():
            result += f"{'':8}{name:40}: {value['val']}\n"

    # values changed
    changed_values = {
        name: (old_value['val'], new_value['val'])
        for name, (old_value, new_value) in common.items()
        if old_value['val'] != new_value['val']
    }
    if changed_values:
        result += "Value changed:\n"
        for name, (old_val, new_val) in changed_values.items():
            result += f"{'':8}{name:40}: {old_val} -> {new_val}\n"

    assert result, f"\n{old}\n{new}"

    return result


# check_diff(d1, d2, Kind.ENUM, diff_enum, print=True)

# %% [markdown]
# # Main

# %%
def get_json_paths(path):
    return sorted(
        (file for file in path.glob("*.json")),
        key=lambda name: tuple(map(int, name.stem.split("-")[0].split(".")))
    )


json_paths = get_json_paths(Path("data/16.04-x86"))

json_paths
# Out:
# [PosixPath('data/16.04-x86/4.4.0-210-generic.json'),
#  PosixPath('data/16.04-x86/4.8.0-58-generic.json'),
#  PosixPath('data/16.04-x86/4.10.0-42-generic.json'),
#  PosixPath('data/16.04-x86/4.13.0-45-generic.json'),
#  PosixPath('data/16.04-x86/4.15.0-142-generic.json')]

# %%
def diff_btf_file(path1, path2):
    d1 = BTF(path1)
    d2 = BTF(path2)
    print(f"Diffing {d1.path} and {d2.path}")
    check_diff(d1, d2, Kind.STRUCT, diff_struct)
    check_diff(d1, d2, Kind.UNION, diff_struct)
    check_diff(d1, d2, Kind.FUNC, diff_func)
    check_diff(d1, d2, Kind.ENUM, diff_enum)


def diff_all_btf_files(paths):
    for path1, path2 in list(zip(paths[:-1], paths[1:])) + [(paths[0], paths[-1])]:
        diff_btf_file(path1, path2)

# %%
diff_all_btf_files(json_paths)
# Out:
# Diffing data/16.04-x86/4.4.0-210-generic.json and data/16.04-x86/4.8.0-58-generic.json
# Diffing data/16.04-x86/4.8.0-58-generic.json and data/16.04-x86/4.10.0-42-generic.json
# Diffing data/16.04-x86/4.10.0-42-generic.json and data/16.04-x86/4.13.0-45-generic.json
# Diffing data/16.04-x86/4.13.0-45-generic.json and data/16.04-x86/4.15.0-142-generic.json
# Diffing data/16.04-x86/4.4.0-210-generic.json and data/16.04-x86/4.15.0-142-generic.json
