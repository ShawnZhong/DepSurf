# %%
# !sudo apt install linux-tools-generic bpftool
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Note, selecting 'linux-tools-common' instead of 'bpftool'
# linux-tools-generic is already the newest version (6.2.0.39.39).
# linux-tools-common is already the newest version (6.2.0-39.40).
# 0 upgraded, 0 newly installed, 0 to remove and 0 not upgraded.

# %%
import os


def system(cmd):
    print(cmd)
    os.system(cmd)

# %%
from pathlib import Path

data_path = Path("data/ubuntu-18.04-x86")

# %%
def unzip_all(path, suffix=".tar.xz"):
    for file in path.glob(f"*{suffix}"):
        stem = file.name.removesuffix(suffix)
        result = path / stem
        if not result.exists():
            system(f"tar -xf {file} -C {path}")
        else:
            print(f"{result} already exists")


unzip_all(data_path)
# Out:
# data/ubuntu-18.04-x86/5.0.0-65-generic.btf already exists
# data/ubuntu-18.04-x86/4.18.0-25-generic.btf already exists
# data/ubuntu-18.04-x86/5.3.0-76-generic.btf already exists
# data/ubuntu-18.04-x86/4.15.0-213-generic.btf already exists
# data/ubuntu-18.04-x86/5.4.0-91-generic.btf already exists

# %%
def get_linux_tools_path():
    parent = Path("/usr/lib/linux-tools")
    versions = [x for x in parent.iterdir() if x.is_dir()]
    if len(versions) == 0:
        raise Exception("No linux-tools found")
    versions.sort()
    return parent / versions[-1]


def get_bpftool_path():
    path = get_linux_tools_path() / "bpftool"
    if not path.exists():
        raise Exception("bpftool not found")
    return path


bpftool_path = get_bpftool_path()

# %%
for file in data_path.glob("*.btf"):
    for ext, cmd in [(".h", "format c"), (".txt", "format raw"), (".json", "--json")]:
        result = file.with_suffix(ext)
        if not result.exists():
            system(f"{bpftool_path} btf dump file {file} {cmd} > {result}")
        else:
            print(f"{result} already exists")
# Out:
# data/ubuntu-18.04-x86/5.4.0-91-generic.h already exists
# data/ubuntu-18.04-x86/5.4.0-91-generic.txt already exists
# data/ubuntu-18.04-x86/5.4.0-91-generic.json already exists
# data/ubuntu-18.04-x86/5.0.0-65-generic.h already exists
# data/ubuntu-18.04-x86/5.0.0-65-generic.txt already exists
# data/ubuntu-18.04-x86/5.0.0-65-generic.json already exists
# data/ubuntu-18.04-x86/5.3.0-76-generic.h already exists
# data/ubuntu-18.04-x86/5.3.0-76-generic.txt already exists
# data/ubuntu-18.04-x86/5.3.0-76-generic.json already exists
# data/ubuntu-18.04-x86/4.15.0-213-generic.h already exists
# data/ubuntu-18.04-x86/4.15.0-213-generic.txt already exists
# data/ubuntu-18.04-x86/4.15.0-213-generic.json already exists
# data/ubuntu-18.04-x86/4.18.0-25-generic.h already exists
# data/ubuntu-18.04-x86/4.18.0-25-generic.txt already exists
# data/ubuntu-18.04-x86/4.18.0-25-generic.json already exists

# %%
json_paths = sorted(file for file in data_path.glob("*.json"))

json_paths
# Out:
# [PosixPath('data/ubuntu-18.04-x86/4.15.0-213-generic.json'),
#  PosixPath('data/ubuntu-18.04-x86/4.18.0-25-generic.json'),
#  PosixPath('data/ubuntu-18.04-x86/5.0.0-65-generic.json'),
#  PosixPath('data/ubuntu-18.04-x86/5.3.0-76-generic.json'),
#  PosixPath('data/ubuntu-18.04-x86/5.4.0-91-generic.json')]

# %%
import json


def load_json(json_path):
    with open(json_path) as f:
        return json.load(f)


jsons = [load_json(p) for p in json_paths]

# %%
from enum import Enum


class Kind(str, Enum):
    INT = "INT"
    PTR = "PTR"
    ARRAY = "ARRAY"
    STRUCT = "STRUCT"
    UNION = "UNION"
    ENUM = "ENUM"
    FWD = "FWD"
    TYPEDEF = "TYPEDEF"
    VOLATILE = "VOLATILE"
    CONST = "CONST"
    RESTRICT = "RESTRICT"
    FUNC = "FUNC"
    FUNC_PROTO = "FUNC_PROTO"
    VAR = "VAR"
    DATASEC = "DATASEC"
    FLOAT = "FLOAT"
    DECL_TAG = "DECL_TAG"
    TYPE_TAG = "TYPE_TAG"
    ENUM64 = "ENUM64"

# %%
from functools import cache


class BTF:
    def __init__(self, path, raw_data=None):
        self.path = path
        if raw_data is None:
            self._raw_data = load_json(path)['types']
        else:
            self._raw_data = raw_data['types']

    def __getitem__(self, id):
        if id == 0:
            return {'id': 0, 'name': 'void', 'kind': 'VOID'}
        e = self._raw_data[id - 1]
        assert e['id'] == id
        return e

    def __len__(self):
        return len(self._raw_data)

    def __iter__(self):
        return iter(self._raw_data)

    @property
    def short_name(self):
        return self.path.name.split("-")[0]

    def print(self):
        from collections import defaultdict

        print(f"File: {self.path}")

        print("Sample:")
        kinds = defaultdict(int)
        for e in self:
            if e['kind'] not in kinds:
                print(f"\t{e['id']:6} ({e['kind']:10}): {e}")
                print(f"\t{'':18}-> {self.normalize(e['id'])}")
            kinds[e['kind']] += 1

        kinds = sorted(kinds.items(), key=lambda x: x[1], reverse=True)
        print(f"Kinds:")
        print(f"\t{dict(kinds)}")

        print()

    @cache
    def filter_on_kind(self, kind):
        return {
            e['name']: self.normalize(e['id']) for e in self
            if e['kind'] == kind and e['name'] != '(anon)'
        }

    @cache
    def get_by_kind_name(self, kind, name):
        return self.filter_on_kind(kind)[name]

    RECURSE_KINDS = {Kind.CONST, Kind.VOLATILE, Kind.RESTRICT,
                     Kind.PTR, Kind.FUNC, Kind.FUNC_PROTO, Kind.ARRAY}

    @cache
    def normalize(self, type_id, recurse=True):
        elem = self[type_id].copy()

        # Recurse into types for certain kinds
        recurse = recurse or elem['kind'] in self.RECURSE_KINDS

        # Remove redundant fields
        del elem['id']

        kind = elem['kind']
        if kind == Kind.INT:
            assert elem['bits_offset'] == 0
            del elem['bits_offset']
            del elem['encoding']
            del elem['nr_bits']
            del elem['size']
        elif kind == Kind.ARRAY:
            del elem['index_type_id']
        elif kind == Kind.ENUM:
            if not recurse:
                assert elem['vlen'] == len(elem['values'])
                del elem['values']
                del elem['vlen']
                del elem['encoding']
        elif kind == Kind.FUNC:
            assert elem['linkage'] == 'static'
            del elem['linkage']
        elif kind in (Kind.PTR, Kind.FUNC_PROTO):
            assert elem['name'] == '(anon)'
            del elem['name']

        # Normalize types
        for type in ['type', 'ret_type']:
            type_id = f"{type}_id"

            if type_id not in elem:
                continue

            if recurse:
                elem[type] = self.normalize(elem[type_id], recurse=False)
            del elem[type_id]

        for list_key in ['params', 'members']:
            if list_key not in elem:
                continue

            assert len(elem[list_key]) == elem['vlen']
            del elem['vlen']

            if recurse:
                elem[list_key] = [
                    {
                        **{k: v for k, v in item.items() if k != 'type_id'},
                        'type': self.normalize(item['type_id'], recurse=False)
                    }
                    for item in elem[list_key]
                ]
            else:
                del elem[list_key]
                if list_key == 'members':
                    del elem['size']

        return elem


d1 = BTF(json_paths[0])
d2 = BTF(json_paths[1])

d1.print()

d1.get_by_kind_name(Kind.STRUCT, "task_struct")
# d1.get_by_kind_name(Kind.FUNC, "vfs_read")
# Out:
# File: data/ubuntu-18.04-x86/4.15.0-213-generic.json
# Sample:
# 	     1 (INT       ): {'id': 1, 'kind': 'INT', 'name': 'long unsigned int', 'size': 8, 'bits_offset': 0, 'nr_bits': 64, 'encoding': '(none)'}
# 	                  -> {'kind': 'INT', 'name': 'long unsigned int'}
# 	     2 (CONST     ): {'id': 2, 'kind': 'CONST', 'name': '(anon)', 'type_id': 1}
# 	                  -> {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'INT', 'name': 'long unsigned int'}}
# 	     3 (VOLATILE  ): {'id': 3, 'kind': 'VOLATILE', 'name': '(anon)', 'type_id': 1}
# 	                  -> {'kind': 'VOLATILE', 'name': '(anon)', 'type': {'kind': 'INT', 'name': 'long unsigned int'}}
# 	     4 (ARRAY     ): {'id': 4, 'kind': 'ARRAY', 'name': '(anon)', 'type_id': 1, 'index_type_id': 20, 'nr_elems': 2}
# 	                  -> {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 2, 'type': {'kind': 'INT', 'name': 'long unsigned int'}}
# 	     5 (PTR       ): {'id': 5, 'kind': 'PTR', 'name': '(anon)', 'type_id': 8}
# 	                  -> {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'INT', 'name': 'char'}}}
# 	    11 (TYPEDEF   ): {'id': 11, 'kind': 'TYPEDEF', 'name': '__s8', 'type_id': 12}
# 	                  -> {'kind': 'TYPEDEF', 'name': '__s8', 'type': {'kind': 'INT', 'name': 'signed char'}}
# 	    38 (FUNC_PROTO): {'id': 38, 'kind': 'FUNC_PROTO', 'name': '(anon)', 'ret_type_id': 0, 'vlen': 1, 'params': [{'name': '(anon)', 'type_id': 20}]}
# 	                  -> {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}
# 	    78 (STRUCT    ): {'id': 78, 'kind': 'STRUCT', 'name': '(anon)', 'size': 4, 'vlen': 1, 'members': [{'name': 'counter', 'type_id': 20, 'bits_offset': 0}]}
# 	                  -> {'kind': 'STRUCT', 'name': '(anon)', 'size': 4, 'members': [{'name': 'counter', 'bits_offset': 0, 'type': {'kind': 'INT', 'name': 'int'}}]}
# 	   106 (UNION     ): {'id': 106, 'kind': 'UNION', 'name': '(anon)', 'size': 8, 'vlen': 3, 'members': [{'name': 'type', 'type_id': 1, 'bits_offset': 0}, {'name': 'entries', 'type_id': 108, 'bits_offset': 0}, {'name': 'next', 'type_id': 109, 'bits_offset': 0}]}
# 	                  -> {'kind': 'UNION', 'name': '(anon)', 'size': 8, 'members': [{'name': 'type', 'bits_offset': 0, 'type': {'kind': 'INT', 'name': 'long unsigned int'}}, {'name': 'entries', 'bits_offset': 0, 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'jump_entry'}}}, {'name': 'next', 'bits_offset': 0, 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'static_key_mod'}}}]}
# 	   120 (ENUM      ): {'id': 120, 'kind': 'ENUM', 'name': 'system_states', 'encoding': 'UNSIGNED', 'size': 4, 'vlen': 6, 'values': [{'name': 'SYSTEM_BOOTING', 'val': 0}, {'name': 'SYSTEM_SCHEDULING', 'val': 1}, {'name': 'SYSTEM_RUNNING', 'val': 2}, {'name': 'SYSTEM_HALT', 'val': 3}, {'name': 'SYSTEM_POWER_OFF', 'val': 4}, {'name': 'SYSTEM_RESTART', 'val': 5}]}
# 	                  -> {'kind': 'ENUM', 'name': 'system_states', 'encoding': 'UNSIGNED', 'size': 4, 'vlen': 6, 'values': [{'name': 'SYSTEM_BOOTING', 'val': 0}, {'name': 'SYSTEM_SCHEDULING', 'val': 1}, {'name': 'SYSTEM_RUNNING', 'val': 2}, {'name': 'SYSTEM_HALT', 'val': 3}, {'name': 'SYSTEM_POWER_OFF', 'val': 4}, {'name': 'SYSTEM_RESTART', 'val': 5}]}
# 	  1110 (FWD       ): {'id': 1110, 'kind': 'FWD', 'name': 'nlm_lockowner', 'fwd_kind': 'struct'}
# 	                  -> {'kind': 'FWD', 'name': 'nlm_lockowner', 'fwd_kind': 'struct'}
# 	  1671 (FUNC      ): {'id': 1671, 'kind': 'FUNC', 'name': 'copy_bootdata', 'type_id': 1670, 'linkage': 'static'}
# 	                  -> {'kind': 'FUNC', 'name': 'copy_bootdata', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': 'real_mode_data', 'type': {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'char'}}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
# 	  4737 (VAR       ): {'id': 4737, 'kind': 'VAR', 'name': 'cpu_loops_per_jiffy', 'type_id': 1, 'linkage': 'static'}
# 	                  -> {'kind': 'VAR', 'name': 'cpu_loops_per_jiffy', 'linkage': 'static', 'type': {'kind': 'INT', 'name': 'long unsigned int'}}
# 	 94558 (RESTRICT  ): {'id': 94558, 'kind': 'RESTRICT', 'name': '(anon)', 'type_id': 5}
# 	                  -> {'kind': 'RESTRICT', 'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'INT', 'name': 'char'}}}}
# 	 94838 (DATASEC   ): {'id': 94838, 'kind': 'DATASEC', 'name': '.data..percpu', 'size': 164036, 'vlen': 326, 'vars': [{'type_id': 5631, 'offset': 16384, 'size': 4096}, {'type_id': 8571, 'offset': 20480, 'size': 12288}, {'type_id': 9004, 'offset': 32768, 'size': 4096}, {'type_id': 12534, 'offset': 36864, 'size': 40960}, {'type_id': 12533, 'offset': 77824, 'size': 4096}, {'type_id': 8154, 'offset': 81920, 'size': 8}, {'type_id': 8153, 'offset': 81928, 'size': 8}, {'type_id': 9003, 'offset': 81936, 'size': 2}, {'type_id': 10430, 'offset': 81952, 'size': 8}, {'type_id': 10429, 'offset': 81960, 'size': 8}, {'type_id': 10428, 'offset': 81968, 'size': 8}, {'type_id': 10431, 'offset': 81984, 'size': 240}, {'type_id': 10452, 'offset': 82224, 'size': 4}, {'type_id': 10453, 'offset': 82232, 'size': 8}, {'type_id': 10596, 'offset': 82240, 'size': 4}, {'type_id': 10594, 'offset': 82244, 'size': 2}, {'type_id': 10595, 'offset': 82246, 'size': 2}, {'type_id': 11856, 'offset': 82248, 'size': 4}, {'type_id': 4737, 'offset': 82304, 'size': 8}, {'type_id': 5189, 'offset': 82336, 'size': 512}, {'type_id': 5188, 'offset': 82848, 'size': 4824}, {'type_id': 5231, 'offset': 87672, 'size': 8}, {'type_id': 5559, 'offset': 90112, 'size': 12288}, {'type_id': 5632, 'offset': 102400, 'size': 8}, {'type_id': 5797, 'offset': 102432, 'size': 168}, {'type_id': 6219, 'offset': 102624, 'size': 64}, {'type_id': 6220, 'offset': 102688, 'size': 4}, {'type_id': 6218, 'offset': 102696, 'size': 8}, {'type_id': 6243, 'offset': 102720, 'size': 3088}, {'type_id': 6244, 'offset': 105808, 'size': 8}, {'type_id': 6519, 'offset': 105856, 'size': 320}, {'type_id': 6548, 'offset': 106176, 'size': 8}, {'type_id': 6742, 'offset': 106192, 'size': 16}, {'type_id': 7016, 'offset': 106208, 'size': 8}, {'type_id': 7015, 'offset': 106216, 'size': 10}, {'type_id': 7014, 'offset': 106240, 'size': 24}, {'type_id': 7191, 'offset': 106264, 'size': 8}, {'type_id': 7190, 'offset': 106272, 'size': 8}, {'type_id': 7457, 'offset': 106288, 'size': 16}, {'type_id': 7456, 'offset': 106304, 'size': 16}, {'type_id': 7455, 'offset': 106320, 'size': 16}, {'type_id': 7454, 'offset': 106336, 'size': 16}, {'type_id': 7493, 'offset': 106352, 'size': 16}, {'type_id': 7492, 'offset': 106368, 'size': 16}, {'type_id': 7509, 'offset': 106384, 'size': 4}, {'type_id': 7508, 'offset': 106392, 'size': 8}, {'type_id': 7507, 'offset': 106400, 'size': 4}, {'type_id': 7620, 'offset': 106408, 'size': 8}, {'type_id': 7903, 'offset': 106416, 'size': 8}, {'type_id': 7988, 'offset': 106432, 'size': 4}, {'type_id': 7987, 'offset': 106440, 'size': 8}, {'type_id': 7986, 'offset': 106448, 'size': 4}, {'type_id': 7985, 'offset': 106456, 'size': 8}, {'type_id': 7984, 'offset': 106464, 'size': 1}, {'type_id': 7983, 'offset': 106480, 'size': 16}, {'type_id': 8100, 'offset': 106496, 'size': 2048}, {'type_id': 8280, 'offset': 108544, 'size': 744}, {'type_id': 8370, 'offset': 109312, 'size': 32}, {'type_id': 8369, 'offset': 109344, 'size': 32}, {'type_id': 8368, 'offset': 109376, 'size': 8}, {'type_id': 8574, 'offset': 109392, 'size': 24}, {'type_id': 8572, 'offset': 109416, 'size': 1}, {'type_id': 8573, 'offset': 109424, 'size': 8}, {'type_id': 8614, 'offset': 109432, 'size': 1}, {'type_id': 8615, 'offset': 109440, 'size': 8}, {'type_id': 9010, 'offset': 109504, 'size': 8}, {'type_id': 9011, 'offset': 109512, 'size': 4}, {'type_id': 9012, 'offset': 109516, 'size': 4}, {'type_id': 9008, 'offset': 109520, 'size': 4}, {'type_id': 9007, 'offset': 109524, 'size': 4}, {'type_id': 9006, 'offset': 109528, 'size': 8}, {'type_id': 9009, 'offset': 109536, 'size': 56}, {'type_id': 9005, 'offset': 109632, 'size': 8}, {'type_id': 9176, 'offset': 109640, 'size': 8}, {'type_id': 9187, 'offset': 109664, 'size': 32}, {'type_id': 9292, 'offset': 109696, 'size': 16}, {'type_id': 9566, 'offset': 109728, 'size': 40}, {'type_id': 9565, 'offset': 109768, 'size': 8}, {'type_id': 9561, 'offset': 109792, 'size': 120}, {'type_id': 9563, 'offset': 109920, 'size ...
# 	                  -> {'kind': 'DATASEC', 'name': '.data..percpu', 'size': 164036, 'vlen': 326, 'vars': [{'type_id': 5631, 'offset': 16384, 'size': 4096}, {'type_id': 8571, 'offset': 20480, 'size': 12288}, {'type_id': 9004, 'offset': 32768, 'size': 4096}, {'type_id': 12534, 'offset': 36864, 'size': 40960}, {'type_id': 12533, 'offset': 77824, 'size': 4096}, {'type_id': 8154, 'offset': 81920, 'size': 8}, {'type_id': 8153, 'offset': 81928, 'size': 8}, {'type_id': 9003, 'offset': 81936, 'size': 2}, {'type_id': 10430, 'offset': 81952, 'size': 8}, {'type_id': 10429, 'offset': 81960, 'size': 8}, {'type_id': 10428, 'offset': 81968, 'size': 8}, {'type_id': 10431, 'offset': 81984, 'size': 240}, {'type_id': 10452, 'offset': 82224, 'size': 4}, {'type_id': 10453, 'offset': 82232, 'size': 8}, {'type_id': 10596, 'offset': 82240, 'size': 4}, {'type_id': 10594, 'offset': 82244, 'size': 2}, {'type_id': 10595, 'offset': 82246, 'size': 2}, {'type_id': 11856, 'offset': 82248, 'size': 4}, {'type_id': 4737, 'offset': 82304, 'size': 8}, {'type_id': 5189, 'offset': 82336, 'size': 512}, {'type_id': 5188, 'offset': 82848, 'size': 4824}, {'type_id': 5231, 'offset': 87672, 'size': 8}, {'type_id': 5559, 'offset': 90112, 'size': 12288}, {'type_id': 5632, 'offset': 102400, 'size': 8}, {'type_id': 5797, 'offset': 102432, 'size': 168}, {'type_id': 6219, 'offset': 102624, 'size': 64}, {'type_id': 6220, 'offset': 102688, 'size': 4}, {'type_id': 6218, 'offset': 102696, 'size': 8}, {'type_id': 6243, 'offset': 102720, 'size': 3088}, {'type_id': 6244, 'offset': 105808, 'size': 8}, {'type_id': 6519, 'offset': 105856, 'size': 320}, {'type_id': 6548, 'offset': 106176, 'size': 8}, {'type_id': 6742, 'offset': 106192, 'size': 16}, {'type_id': 7016, 'offset': 106208, 'size': 8}, {'type_id': 7015, 'offset': 106216, 'size': 10}, {'type_id': 7014, 'offset': 106240, 'size': 24}, {'type_id': 7191, 'offset': 106264, 'size': 8}, {'type_id': 7190, 'offset': 106272, 'size': 8}, {'type_id': 7457, 'offset': 106288, 'size': 16}, {'type_id': 7456, 'offset': 106304, 'size': 16}, {'type_id': 7455, 'offset': 106320, 'size': 16}, {'type_id': 7454, 'offset': 106336, 'size': 16}, {'type_id': 7493, 'offset': 106352, 'size': 16}, {'type_id': 7492, 'offset': 106368, 'size': 16}, {'type_id': 7509, 'offset': 106384, 'size': 4}, {'type_id': 7508, 'offset': 106392, 'size': 8}, {'type_id': 7507, 'offset': 106400, 'size': 4}, {'type_id': 7620, 'offset': 106408, 'size': 8}, {'type_id': 7903, 'offset': 106416, 'size': 8}, {'type_id': 7988, 'offset': 106432, 'size': 4}, {'type_id': 7987, 'offset': 106440, 'size': 8}, {'type_id': 7986, 'offset': 106448, 'size': 4}, {'type_id': 7985, 'offset': 106456, 'size': 8}, {'type_id': 7984, 'offset': 106464, 'size': 1}, {'type_id': 7983, 'offset': 106480, 'size': 16}, {'type_id': 8100, 'offset': 106496, 'size': 2048}, {'type_id': 8280, 'offset': 108544, 'size': 744}, {'type_id': 8370, 'offset': 109312, 'size': 32}, {'type_id': 8369, 'offset': 109344, 'size': 32}, {'type_id': 8368, 'offset': 109376, 'size': 8}, {'type_id': 8574, 'offset': 109392, 'size': 24}, {'type_id': 8572, 'offset': 109416, 'size': 1}, {'type_id': 8573, 'offset': 109424, 'size': 8}, {'type_id': 8614, 'offset': 109432, 'size': 1}, {'type_id': 8615, 'offset': 109440, 'size': 8}, {'type_id': 9010, 'offset': 109504, 'size': 8}, {'type_id': 9011, 'offset': 109512, 'size': 4}, {'type_id': 9012, 'offset': 109516, 'size': 4}, {'type_id': 9008, 'offset': 109520, 'size': 4}, {'type_id': 9007, 'offset': 109524, 'size': 4}, {'type_id': 9006, 'offset': 109528, 'size': 8}, {'type_id': 9009, 'offset': 109536, 'size': 56}, {'type_id': 9005, 'offset': 109632, 'size': 8}, {'type_id': 9176, 'offset': 109640, 'size': 8}, {'type_id': 9187, 'offset': 109664, 'size': 32}, {'type_id': 9292, 'offset': 109696, 'size': 16}, {'type_id': 9566, 'offset': 109728, 'size': 40}, {'type_id': 9565, 'offset': 109768, 'size': 8}, {'type_id': 9561, 'offset': 109792, 'size': 120}, {'type_id': 9563, 'offset': 109920, 'size': 120}, {'ty ...
# Kinds:
# 	{'FUNC': 42719, 'FUNC_PROTO': 22849, 'PTR': 11884, 'STRUCT': 8154, 'ARRAY': 2981, 'CONST': 2369, 'ENUM': 1528, 'TYPEDEF': 1005, 'UNION': 827, 'VAR': 326, 'FWD': 158, 'VOLATILE': 20, 'INT': 15, 'RESTRICT': 2, 'DATASEC': 1}
# {'kind': 'STRUCT',
#  'name': 'task_struct',
#  'size': 9152,
#  'members': [{'name': 'thread_info',
#    'bits_offset': 0,
#    'type': {'kind': 'STRUCT', 'name': 'thread_info'}},
#   {'name': 'state',
#    'bits_offset': 128,
#    'type': {'kind': 'VOLATILE',
#     'name': '(anon)',
#     'type': {'kind': 'INT', 'name': 'long int'}}},
#   {'name': 'stack',
#    'bits_offset': 192,
#    'type': {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}},
#   {'name': 'usage',
#    'bits_offset': 256,
#    'type': {'kind': 'TYPEDEF', 'name': 'atomic_t'}},
#   {'name': 'flags',
#    'bits_offset': 288,
#    'type': {'kind': 'INT', 'name': 'unsigned int'}},
#   {'name': 'ptrace',
#    'bits_offset': 320,
#    'type': {'kind': 'INT', 'name': 'unsigned int'}},
#   {'name': 'wake_entry',
#    'bits_offset': 384,
#    'type': {'kind': 'STRUCT', 'name': 'llist_node'}},
#   {'name': 'on_cpu',
#    'bits_offset': 448,
#    'type': {'kind': 'INT', 'name': 'int'}},
#   {'name': 'cpu',
#    'bits_offset': 480,
#    'type': {'kind': 'INT', 'name': 'unsigned int'}},
#   {'name': 'wakee_flips',
#    'bits_offset': 512,
#    'type': {'kind': 'INT', 'name': 'unsigned int'}},
#   {'name': 'wakee_flip_decay_ts',
#    'bits_offset': 576,
#    'type': {'kind': 'INT', 'name': 'long unsigned int'}},
#   {'name': 'last_wakee',
#    'bits_offset': 640,
#    'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'task_struct'}}},
#   {'name': 'wake_cpu',
#    'bits_offset': 704,
#    'type': {'kind': 'INT', 'name': 'int'}},
#   {'name': 'on_rq',
#    'bits_offset': 736,
#    'type': {'kind': 'INT', 'name': 'int'}},
#   {'name': 'prio', 'bits_offset': 768, 'type': {'kind': 'INT', 'name': 'int'}},
#   {'name': 'static_prio',
#    'bits_offset': 800,
#    'type': {'kind': 'INT', 'name': 'int'}},
#   {'name': 'normal_prio',
#    'bits_offset': 832,
#    'type': {'kind': 'INT', 'name': 'int'}},
#   {'name': 'rt_priority',
#    'bits_offset': 864,
#    'type': {'kind': 'INT', 'name': 'unsigned int'}},
#   {'name': 'sched_class',
#    'bits_offset': 896,
#    'type': {'kind': 'PTR',
#     'type': {'kind': 'CONST',
#      'name': '(anon)',
#      'type': {'kind': 'STRUCT', 'name': 'sched_class'}}}},
#   {'name': 'se',
#    'bits_offset': 1024,
#    'type': {'kind': 'STRUCT', 'name': 'sched_entity'}},
#   {'name': 'rt',
#    'bits_offset': 4608,
#    'type': {'kind': 'STRUCT', 'name': 'sched_rt_entity'}},
#   {'name': 'sched_task_group',
#    'bits_offset': 4992,
#    'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'task_group'}}},
#   {'name': 'dl',
#    'bits_offset': 5056,
#    'type': {'kind': 'STRUCT', 'name': 'sched_dl_entity'}},
#   {'name': 'preempt_notifiers',
#    'bits_offset': 6784,
#    'type': {'kind': 'STRUCT', 'name': 'hlist_head'}},
#   {'name': 'btrace_seq',
#    'bits_offset': 6848,
#    'type': {'kind': 'INT', 'name': 'unsigned int'}},
#   {'name': 'policy',
#    'bits_offset': 6880,
#    'type': {'kind': 'INT', 'name': 'unsigned int'}},
#   {'name': 'nr_cpus_allowed',
#    'bits_offset': 6912,
#    'type': {'kind': 'INT', 'name': 'int'}},
#   {'name': 'cpus_allowed',
#    'bits_offset': 6976,
#    'type': {'kind': 'TYPEDEF', 'name': 'cpumask_t'}},
#   {'name': 'rcu_tasks_nvcsw',
#    'bits_offset': 15168,
#    'type': {'kind': 'INT', 'name': 'long unsigned int'}},
#   {'name': 'rcu_tasks_holdout',
#    'bits_offset': 15232,
#    'type': {'kind': 'TYPEDEF', 'name': 'u8'}},
#   {'name': 'rcu_tasks_idx',
#    'bits_offset': 15240,
#    'type': {'kind': 'TYPEDEF', 'name': 'u8'}},
#   {'name': 'rcu_tasks_idle_cpu',
#    'bits_offset': 15264,
#    'type': {'kind': 'INT', 'name': 'int'}},
#   {'name': 'rcu_tasks_holdout_list',
#    'bits_offset': 15296,
#    'type': {'kind': 'STRUCT', 'name': 'list_head'}},
#   {'name': 'sched_info',
#    'bits_offset': 15424,
#    'type': {'kind': 'STRUCT', 'name': 'sched_info'}},
#   {'name': 'tasks',
#    'bits_offset': 15680,
#    'type': {'kind': 'STRUCT', 'name': 'list_head'}},
#   {'name': 'pushable_tasks',
#    'bits_offset': 15808,
#    'type': {'kind': 'STRUCT', 'name': 'plist_node'}},
#   {'name': 'pushable_dl_tasks',
#    'bits_offset': 16128,
#    'type': {'kind': 'STRUCT', 'name': 'rb_node'}},
#   {'name': 'mm',
#    'bits_offset': 16320,
#    'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'mm_struct'}}},
#   {'name': 'active_mm',
#    'bits_offset': 16384,
#    'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'mm_struct'}}},
#   {'name': 'vmacache',
#    'bits_offset': 16448,
#    'type': {'kind': 'STRUCT', 'name': 'vmacache'}},
#   {'name': 'rss_stat',
#    'bits_offset': 16768,
#    'type': {'kind': 'STRUCT', 'name': 'task_rss_stat'}},
#   {'name': 'exit_state',
#    'bits_offset': 16928,
#    'type': {'kind': 'INT', 'name': 'int'}},
#   {'name': 'exit_code',
#    'bits_offset': 16960,
#    'type': {'kind': 'INT', 'name': 'int'}},
#   {'name': 'exit_signal',
#    'bits_offset': 16992,
#    'type': {'kind': 'INT', 'name': 'int'}},
#   {'name': 'pdeath_signal',
#    'bits_offset': 17024,
#    'type': {'kind': 'INT', 'name': 'int'}},
#   {'name': 'jobctl',
#    'bits_offset': 17088,
#    'type': {'kind': 'INT', 'name': 'long unsigned int'}},
#   {'name': 'personality',
#    'bits_offset': 17152,
#    'type': {'kind': 'INT', 'name': 'unsigned int'}},
#   {'name': 'sched_reset_on_fork',
#    'bits_offset': 17184,
#    'bitfield_size': 1,
#    'type': {'kind': 'INT', 'name': 'unsigned int'}},
#   {'name': 'sched_contributes_to_load',
#    'bits_offset': 17185,
#    'bitfield_size': 1,
#    'type': {'kind': 'INT', 'name': 'unsigned int'}},
#   {'name': 'sched_migrated',
#    'bits_offset': 17186,
#    'bitfield_size': 1,
#    'type': {'kind': 'INT', 'name': 'unsigned int'}},
#   {'name': 'sched_remote_wakeup',
#    'bits_offset': 17187,
#    'bitfield_size': 1,
#    'type': {'kind': 'INT', 'name': 'unsigned int'}},
#   {'name': 'in_execve',
#    'bits_offset': 17216,
#    'bitfield_size': 1,
#    'type': {'kind': 'INT', 'name': 'unsigned int'}},
#   {'name': 'in_iowait',
#    'bits_offset': 17217,
#    'bitfield_size': 1,
#    'type': {'kind': 'INT', 'name': 'unsigned int'}},
#   {'name': 'restore_sigmask',
#    'bits_offset': 17218,
#    'bitfield_size': 1,
#    'type': {'kind': 'INT', 'name': 'unsigned int'}},
#   {'name': 'memcg_may_oom',
#    'bits_offset': 17219,
#    'bitfield_size': 1,
#    'type': {'kind': 'INT', 'name': 'unsigned int'}},
#   {'name': 'memcg_kmem_skip_account',
#    'bits_offset': 17220,
#    'bitfield_size': 1,
#    'type': {'kind': 'INT', 'name': 'unsigned int'}},
#   {'name': 'no_cgroup_migration',
#    'bits_offset': 17221,
#    'bitfield_size': 1,
#    'type': {'kind': 'INT', 'name': 'unsigned int'}},
#   {'name': 'atomic_flags',
#    'bits_offset': 17280,
#    'type': {'kind': 'INT', 'name': 'long unsigned int'}},
#   {'name': 'restart_block',
#    'bits_offset': 17344,
#    'type': {'kind': 'STRUCT', 'name': 'restart_block'}},
#   {'name': 'pid',
#    'bits_offset': 17728,
#    'type': {'kind': 'TYPEDEF', 'name': 'pid_t'}},
#   {'name': 'tgid',
#    'bits_offset': 17760,
#    'type': {'kind': 'TYPEDEF', 'name': 'pid_t'}},
#   {'name': 'stack_canary',
#    'bits_offset': 17792,
#    'type': {'kind': 'INT', 'name': 'long unsigned int'}},
#   {'name': 'real_parent',
#    'bits_offset': 17856,
#    'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'task_struct'}}},
#   {'name': 'parent',
#    'bits_offset': 17920,
#    'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'task_struct'}}},
#   {'name': 'children',
#    'bits_offset': 17984,
#    'type': {'kind': 'STRUCT', 'name': 'list_head'}},
#   {'name': 'sibling',
#    'bits_offset': 18112,
#    'type': {'kind': 'STRUCT', 'name': 'list_head'}},
#   {'name': 'group_leader',
#    'bits_offset': 18240,
#    'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'task_struct'}}},
#   {'name': 'ptraced',
#    'bits_offset': 18304,
#    'type': {'kind': 'STRUCT', 'name': 'list_head'}},
#   {'name': 'ptrace_entry',
#    'bits_offset': 18432,
#    'type': {'kind': 'STRUCT', 'name': 'list_head'}},
#   {'name': 'pids',
#    'bits_offset': 18560,
#    'type': {'kind': 'ARRAY',
#     'name': '(anon)',
#     'nr_elems': 3,
#     'type': {'kind': 'STRUCT', 'name': 'pid_link'}}},
#   {'name': 'thread_group',
#    'bits_offset': 19136,
#    'type': {'kind': 'STRUCT', 'name': 'list_head'}},
#   {'name': 'thread_node',
#    'bits_offset': 19264,
#    'type': {'kind': 'STRUCT', 'name': 'list_head'}},
#   {'name': 'vfork_done',
#    'bits_offset': 19392,
#    'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'completion'}}},
#   {'name': 'set_child_tid',
#    'bits_offset': 19456,
#    'type': {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'int'}}},
#   {'name': 'clear_child_tid',
#    'bits_offset': 19520,
#    'type': {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'int'}}},
#   {'name': 'utime',
#    'bits_offset': 19584,
#    'type': {'kind': 'TYPEDEF', 'name': 'u64'}},
#   {'name': 'stime',
#    'bits_offset': 19648,
#    'type': {'kind': 'TYPEDEF', 'name': 'u64'}},
#   {'name': 'gtime',
#    'bits_offset': 19712,
#    'type': {'kind': 'TYPEDEF', 'name': 'u64'}},
#   {'name': 'prev_cputime',
#    'bits_offset': 19776,
#    'type': {'kind': 'STRUCT', 'name': 'prev_cputime'}},
#   {'name': 'nvcsw',
#    'bits_offset': 19968,
#    'type': {'kind': 'INT', 'name': 'long unsigned int'}},
#   {'name': 'nivcsw',
#    'bits_offset': 20032,
#    'type': {'kind': 'INT', 'name': 'long unsigned int'}},
#   {'name': 'start_time',
#    'bits_offset': 20096,
#    'type': {'kind': 'TYPEDEF', 'name': 'u64'}},
#   {'name': 'real_start_time',
#    'bits_offset': 20160,
#    'type': {'kind': 'TYPEDEF', 'name': 'u64'}},
#   {'name': 'min_flt',
#    'bits_offset': 20224,
#    'type': {'kind': 'INT', 'name': 'long unsigned int'}},
#   {'name': 'maj_flt',
#    'bits_offset': 20288,
#    'type': {'kind': 'INT', 'name': 'long unsigned int'}},
#   {'name': 'cputime_expires',
#    'bits_offset': 20352,
#    'type': {'kind': 'STRUCT', 'name': 'task_cputime'}},
#   {'name': 'cpu_timers',
#    'bits_offset': 20544,
#    'type': {'kind': 'ARRAY',
#     'name': '(anon)',
#     'nr_elems': 3,
#     'type': {'kind': 'STRUCT', 'name': 'list_head'}}},
#   {'name': 'ptracer_cred',
#    'bits_offset': 20928,
#    'type': {'kind': 'PTR',
#     'type': {'kind': 'CONST',
#      'name': '(anon)',
#      'type': {'kind': 'STRUCT', 'name': 'cred'}}}},
#   {'name': 'real_cred',
#    'bits_offset': 20992,
#    'type': {'kind': 'PTR',
#     'type': {'kind': 'CONST',
#      'name': '(anon)',
#      'type': {'kind': 'STRUCT', 'name': 'cred'}}}},
#   {'name': 'cred',
#    'bits_offset': 21056,
#    'type': {'kind': 'PTR',
#     'type': {'kind': 'CONST',
#      'name': '(anon)',
#      'type': {'kind': 'STRUCT', 'name': 'cred'}}}},
#   {'name': 'comm',
#    'bits_offset': 21120,
#    'type': {'kind': 'ARRAY',
#     'name': '(anon)',
#     'nr_elems': 16,
#     'type': {'kind': 'INT', 'name': 'char'}}},
#   {'name': 'nameidata',
#    'bits_offset': 21248,
#    'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'nameidata'}}},
#   {'name': 'sysvsem',
#    'bits_offset': 21312,
#    'type': {'kind': 'STRUCT', 'name': 'sysv_sem'}},
#   {'name': 'sysvshm',
#    'bits_offset': 21376,
#    'type': {'kind': 'STRUCT', 'name': 'sysv_shm'}},
#   {'name': 'last_switch_count',
#    'bits_offset': 21504,
#    'type': {'kind': 'INT', 'name': 'long unsigned int'}},
#   {'name': 'fs',
#    'bits_offset': 21568,
#    'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fs_struct'}}},
#   {'name': 'files',
#    'bits_offset': 21632,
#    'type': {'kind': 'PTR',
#     'type': {'kind': 'STRUCT', 'name': 'files_struct'}}},
#   {'name': 'nsproxy',
#    'bits_offset': 21696,
#    'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'nsproxy'}}},
#   {'name': 'signal',
#    'bits_offset': 21760,
#    'type': {'kind': 'PTR',
#     'type': {'kind': 'STRUCT', 'name': 'signal_struct'}}},
#   {'name': 'sighand',
#    'bits_offset': 21824,
#    'type': {'kind': 'PTR',
#     'type': {'kind': 'STRUCT', 'name': 'sighand_struct'}}},
#   {'name': 'blocked',
#    'bits_offset': 21888,
#    'type': {'kind': 'TYPEDEF', 'name': 'sigset_t'}},
#   {'name': 'real_blocked',
#    'bits_offset': 21952,
#    'type': {'kind': 'TYPEDEF', 'name': 'sigset_t'}},
#   {'name': 'saved_sigmask',
#    'bits_offset': 22016,
#    'type': {'kind': 'TYPEDEF', 'name': 'sigset_t'}},
#   {'name': 'pending',
#    'bits_offset': 22080,
#    'type': {'kind': 'STRUCT', 'name': 'sigpending'}},
#   {'name': 'sas_ss_sp',
#    'bits_offset': 22272,
#    'type': {'kind': 'INT', 'name': 'long unsigned int'}},
#   {'name': 'sas_ss_size',
#    'bits_offset': 22336,
#    'type': {'kind': 'TYPEDEF', 'name': 'size_t'}},
#   {'name': 'sas_ss_flags',
#    'bits_offset': 22400,
#    'type': {'kind': 'INT', 'name': 'unsigned int'}},
#   {'name': 'task_works',
#    'bits_offset': 22464,
#    'type': {'kind': 'PTR',
#     'type': {'kind': 'STRUCT', 'name': 'callback_head'}}},
#   {'name': 'audit_context',
#    'bits_offset': 22528,
#    'type': {'kind': 'PTR',
#     'type': {'kind': 'STRUCT', 'name': 'audit_context'}}},
#   {'name': 'loginuid',
#    'bits_offset': 22592,
#    'type': {'kind': 'TYPEDEF', 'name': 'kuid_t'}},
#   {'name': 'sessionid',
#    'bits_offset': 22624,
#    'type': {'kind': 'INT', 'name': 'unsigned int'}},
#   {'name': 'seccomp',
#    'bits_offset': 22656,
#    'type': {'kind': 'STRUCT', 'name': 'seccomp'}},
#   {'name': 'parent_exec_id',
#    'bits_offset': 22784,
#    'type': {'kind': 'TYPEDEF', 'name': 'u64'}},
#   {'name': 'self_exec_id',
#    'bits_offset': 22848,
#    'type': {'kind': 'TYPEDEF', 'name': 'u64'}},
#   {'name': 'alloc_lock',
#    'bits_offset': 22912,
#    'type': {'kind': 'TYPEDEF', 'name': 'spinlock_t'}},
#   {'name': 'pi_lock',
#    'bits_offset': 22944,
#    'type': {'kind': 'TYPEDEF', 'name': 'raw_spinlock_t'}},
#   {'name': 'wake_q',
#    'bits_offset': 22976,
#    'type': {'kind': 'STRUCT', 'name': 'wake_q_node'}},
#   {'name': 'pi_waiters',
#    'bits_offset': 23040,
#    'type': {'kind': 'STRUCT', 'name': 'rb_root_cached'}},
#   {'name': 'pi_top_task',
#    'bits_offset': 23168,
#    'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'task_struct'}}},
#   {'name': 'pi_blocked_on',
#    'bits_offset': 23232,
#    'type': {'kind': 'PTR',
#     'type': {'kind': 'STRUCT', 'name': 'rt_mutex_waiter'}}},
#   {'name': 'journal_info',
#    'bits_offset': 23296,
#    'type': {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}},
#   {'name': 'bio_list',
#    'bits_offset': 23360,
#    'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'bio_list'}}},
#   {'name': 'plug',
#    'bits_offset': 23424,
#    'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'blk_plug'}}},
#   {'name': 'reclaim_state',
#    'bits_offset': 23488,
#    'type': {'kind': 'PTR',
#     'type': {'kind': 'STRUCT', 'name': 'reclaim_state'}}},
#   {'name': 'backing_dev_info',
#    'bits_offset': 23552,
#    'type': {'kind': 'PTR',
#     'type': {'kind': 'STRUCT', 'name': 'backing_dev_info'}}},
#   {'name': 'io_context',
#    'bits_offset': 23616,
#    'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'io_context'}}},
#   {'name': 'ptrace_message',
#    'bits_offset': 23680,
#    'type': {'kind': 'INT', 'name': 'long unsigned int'}},
#   {'name': 'last_siginfo',
#    'bits_offset': 23744,
#    'type': {'kind': 'PTR', 'type': {'kind': 'TYPEDEF', 'name': 'siginfo_t'}}},
#   {'name': 'ioac',
#    'bits_offset': 23808,
#    'type': {'kind': 'STRUCT', 'name': 'task_io_accounting'}},
#   {'name': 'acct_rss_mem1',
#    'bits_offset': 24256,
#    'type': {'kind': 'TYPEDEF', 'name': 'u64'}},
#   {'name': 'acct_vm_mem1',
#    'bits_offset': 24320,
#    'type': {'kind': 'TYPEDEF', 'name': 'u64'}},
#   {'name': 'acct_timexpd',
#    'bits_offset': 24384,
#    'type': {'kind': 'TYPEDEF', 'name': 'u64'}},
#   {'name': 'mems_allowed',
#    'bits_offset': 24448,
#    'type': {'kind': 'TYPEDEF', 'name': 'nodemask_t'}},
#   {'name': 'mems_allowed_seq',
#    'bits_offset': 25472,
#    'type': {'kind': 'TYPEDEF', 'name': 'seqcount_t'}},
#   {'name': 'cpuset_mem_spread_rotor',
#    'bits_offset': 25504,
#    'type': {'kind': 'INT', 'name': 'int'}},
#   {'name': 'cpuset_slab_spread_rotor',
#    'bits_offset': 25536,
#    'type': {'kind': 'INT', 'name': 'int'}},
#   {'name': 'cgroups',
#    'bits_offset': 25600,
#    'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'css_set'}}},
#   {'name': 'cg_list',
#    'bits_offset': 25664,
#    'type': {'kind': 'STRUCT', 'name': 'list_head'}},
#   {'name': 'closid',
#    'bits_offset': 25792,
#    'type': {'kind': 'TYPEDEF', 'name': 'u32'}},
#   {'name': 'rmid',
#    'bits_offset': 25824,
#    'type': {'kind': 'TYPEDEF', 'name': 'u32'}},
#   {'name': 'robust_list',
#    'bits_offset': 25856,
#    'type': {'kind': 'PTR',
#     'type': {'kind': 'STRUCT', 'name': 'robust_list_head'}}},
#   {'name': 'compat_robust_list',
#    'bits_offset': 25920,
#    'type': {'kind': 'PTR',
#     'type': {'kind': 'STRUCT', 'name': 'compat_robust_list_head'}}},
#   {'name': 'pi_state_list',
#    'bits_offset': 25984,
#    'type': {'kind': 'STRUCT', 'name': 'list_head'}},
#   {'name': 'pi_state_cache',
#    'bits_offset': 26112,
#    'type': {'kind': 'PTR',
#     'type': {'kind': 'STRUCT', 'name': 'futex_pi_state'}}},
#   {'name': 'futex_exit_mutex',
#    'bits_offset': 26176,
#    'type': {'kind': 'STRUCT', 'name': 'mutex'}},
#   {'name': 'futex_state',
#    'bits_offset': 26432,
#    'type': {'kind': 'INT', 'name': 'unsigned int'}},
#   {'name': 'perf_event_ctxp',
#    'bits_offset': 26496,
#    'type': {'kind': 'ARRAY',
#     'name': '(anon)',
#     'nr_elems': 2,
#     'type': {'kind': 'PTR',
#      'type': {'kind': 'STRUCT', 'name': 'perf_event_context'}}}},
#   {'name': 'perf_event_mutex',
#    'bits_offset': 26624,
#    'type': {'kind': 'STRUCT', 'name': 'mutex'}},
#   {'name': 'perf_event_list',
#    'bits_offset': 26880,
#    'type': {'kind': 'STRUCT', 'name': 'list_head'}},
#   {'name': 'mempolicy',
#    'bits_offset': 27008,
#    'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'mempolicy'}}},
#   {'name': 'il_prev',
#    'bits_offset': 27072,
#    'type': {'kind': 'INT', 'name': 'short int'}},
#   {'name': 'pref_node_fork',
#    'bits_offset': 27088,
#    'type': {'kind': 'INT', 'name': 'short int'}},
#   {'name': 'numa_scan_seq',
#    'bits_offset': 27104,
#    'type': {'kind': 'INT', 'name': 'int'}},
#   {'name': 'numa_scan_period',
#    'bits_offset': 27136,
#    'type': {'kind': 'INT', 'name': 'unsigned int'}},
#   {'name': 'numa_scan_period_max',
#    'bits_offset': 27168,
#    'type': {'kind': 'INT', 'name': 'unsigned int'}},
#   {'name': 'numa_preferred_nid',
#    'bits_offset': 27200,
#    'type': {'kind': 'INT', 'name': 'int'}},
#   {'name': 'numa_migrate_retry',
#    'bits_offset': 27264,
#    'type': {'kind': 'INT', 'name': 'long unsigned int'}},
#   {'name': 'node_stamp',
#    'bits_offset': 27328,
#    'type': {'kind': 'TYPEDEF', 'name': 'u64'}},
#   {'name': 'last_task_numa_placement',
#    'bits_offset': 27392,
#    'type': {'kind': 'TYPEDEF', 'name': 'u64'}},
#   {'name': 'last_sum_exec_runtime',
#    'bits_offset': 27456,
#    'type': {'kind': 'TYPEDEF', 'name': 'u64'}},
#   {'name': 'numa_work',
#    'bits_offset': 27520,
#    'type': {'kind': 'STRUCT', 'name': 'callback_head'}},
#   {'name': 'numa_entry',
#    'bits_offset': 27648,
#    'type': {'kind': 'STRUCT', 'name': 'list_head'}},
#   {'name': 'numa_group',
#    'bits_offset': 27776,
#    'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'numa_group'}}},
#   {'name': 'numa_faults',
#    'bits_offset': 27840,
#    'type': {'kind': 'PTR',
#     'type': {'kind': 'INT', 'name': 'long unsigned int'}}},
#   {'name': 'total_numa_faults',
#    'bits_offset': 27904,
#    'type': {'kind': 'INT', 'name': 'long unsigned int'}},
#   {'name': 'numa_faults_locality',
#    'bits_offset': 27968,
#    'type': {'kind': 'ARRAY',
#     'name': '(anon)',
#     'nr_elems': 3,
#     'type': {'kind': 'INT', 'name': 'long unsigned int'}}},
#   {'name': 'numa_pages_migrated',
#    'bits_offset': 28160,
#    'type': {'kind': 'INT', 'name': 'long unsigned int'}},
#   {'name': 'tlb_ubc',
#    'bits_offset': 28224,
#    'type': {'kind': 'STRUCT', 'name': 'tlbflush_unmap_batch'}},
#   {'name': 'rcu',
#    'bits_offset': 36480,
#    'type': {'kind': 'STRUCT', 'name': 'callback_head'}},
#   {'name': 'splice_pipe',
#    'bits_offset': 36608,
#    'type': {'kind': 'PTR',
#     'type': {'kind': 'STRUCT', 'name': 'pipe_inode_info'}}},
#   {'name': 'task_frag',
#    'bits_offset': 36672,
#    'type': {'kind': 'STRUCT', 'name': 'page_frag'}},
#   {'name': 'delays',
#    'bits_offset': 36800,
#    'type': {'kind': 'PTR',
#     'type': {'kind': 'STRUCT', 'name': 'task_delay_info'}}},
#   {'name': 'nr_dirtied',
#    'bits_offset': 36864,
#    'type': {'kind': 'INT', 'name': 'int'}},
#   {'name': 'nr_dirtied_pause',
#    'bits_offset': 36896,
#    'type': {'kind': 'INT', 'name': 'int'}},
#   {'name': 'dirty_paused_when',
#    'bits_offset': 36928,
#    'type': {'kind': 'INT', 'name': 'long unsigned int'}},
#   {'name': 'timer_slack_ns',
#    'bits_offset': 36992,
#    'type': {'kind': 'TYPEDEF', 'name': 'u64'}},
#   {'name': 'default_timer_slack_ns',
#    'bits_offset': 37056,
#    'type': {'kind': 'TYPEDEF', 'name': 'u64'}},
#   {'name': 'curr_ret_stack',
#    'bits_offset': 37120,
#    'type': {'kind': 'INT', 'name': 'int'}},
#   {'name': 'curr_ret_depth',
#    'bits_offset': 37152,
#    'type': {'kind': 'INT', 'name': 'int'}},
#   {'name': 'ret_stack',
#    'bits_offset': 37184,
#    'type': {'kind': 'PTR',
#     'type': {'kind': 'STRUCT', 'name': 'ftrace_ret_stack'}}},
#   {'name': 'ftrace_timestamp',
#    'bits_offset': 37248,
#    'type': {'kind': 'INT', 'name': 'long long unsigned int'}},
#   {'name': 'trace_overrun',
#    'bits_offset': 37312,
#    'type': {'kind': 'TYPEDEF', 'name': 'atomic_t'}},
#   {'name': 'tracing_graph_pause',
#    'bits_offset': 37344,
#    'type': {'kind': 'TYPEDEF', 'name': 'atomic_t'}},
#   {'name': 'trace',
#    'bits_offset': 37376,
#    'type': {'kind': 'INT', 'name': 'long unsigned int'}},
#   {'name': 'trace_recursion',
#    'bits_offset': 37440,
#    'type': {'kind': 'INT', 'name': 'long unsigned int'}},
#   {'name': 'memcg_in_oom',
#    'bits_offset': 37504,
#    'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'mem_cgroup'}}},
#   {'name': 'memcg_oom_gfp_mask',
#    'bits_offset': 37568,
#    'type': {'kind': 'TYPEDEF', 'name': 'gfp_t'}},
#   {'name': 'memcg_oom_order',
#    'bits_offset': 37600,
#    'type': {'kind': 'INT', 'name': 'int'}},
#   {'name': 'memcg_nr_pages_over_high',
#    'bits_offset': 37632,
#    'type': {'kind': 'INT', 'name': 'unsigned int'}},
#   {'name': 'utask',
#    'bits_offset': 37696,
#    'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'uprobe_task'}}},
#   {'name': 'sequential_io',
#    'bits_offset': 37760,
#    'type': {'kind': 'INT', 'name': 'unsigned int'}},
#   {'name': 'sequential_io_avg',
#    'bits_offset': 37792,
#    'type': {'kind': 'INT', 'name': 'unsigned int'}},
#   {'name': 'pagefault_disabled',
#    'bits_offset': 37824,
#    'type': {'kind': 'INT', 'name': 'int'}},
#   {'name': 'oom_reaper_list',
#    'bits_offset': 37888,
#    'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'task_struct'}}},
#   {'name': 'stack_vm_area',
#    'bits_offset': 37952,
#    'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'vm_struct'}}},
#   {'name': 'stack_refcount',
#    'bits_offset': 38016,
#    'type': {'kind': 'TYPEDEF', 'name': 'atomic_t'}},
#   {'name': 'patch_state',
#    'bits_offset': 38048,
#    'type': {'kind': 'INT', 'name': 'int'}},
#   {'name': 'security',
#    'bits_offset': 38080,
#    'type': {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}},
#   {'name': 'thread',
#    'bits_offset': 38400,
#    'type': {'kind': 'STRUCT', 'name': 'thread_struct'}}]}

# %%
import sys


def print_as_list(name, s, num=10):
    print(f"{name} ({len(s)}): {list(s)[:num]}")


class FileLogger:
    def __init__(self, name):
        self.stdout = sys.stdout

        file_path = Path("output") / name
        file_path.parent.mkdir(parents=True, exist_ok=True)
        self.log = open(file_path, "w")

    def write(self, message):
        self.stdout.write(message)
        self.log.write(message)

    def __enter__(self):
        sys.stdout = self
        return self

    def __exit__(self, exc_type, exc_value, traceback):
        sys.stdout = self.stdout
        self.log.close()


def _check_diff(d_old, d_new, kind, diff):
    f_old = d_old.filter_on_kind(kind)
    f_new = d_new.filter_on_kind(kind)

    print_as_list(f"Old {kind}", f_old.keys())
    print_as_list(f"New {kind}", f_new.keys())

    print_as_list(f"Removed {kind}", f_old.keys() - f_new.keys())
    print_as_list(f"Added {kind}", f_new.keys() - f_old.keys())

    common = {
        name: (f_old[name], f_new[name])
        for name in f_old.keys() & f_new.keys()
    }
    print_as_list(f"Common {kind}", common.keys())

    changed = {
        name: (old, new)
        for name, (old, new) in common.items()
        if old != new
    }
    print_as_list(f"Changed {kind}", changed.keys())

    for name, (old, new) in changed.items():
        reason = diff(old, new)
        lines = reason.strip().split("\n")
        print(f"{kind:12}{name}")
        for line in lines:
            print(f"{'':20} {line}")


def check_diff(d_old, d_new, kind, diff):
    name = f"{d_old.short_name}-{d_new.short_name}-{kind.name}.txt"
    with FileLogger(name):
        _check_diff(d_old, d_new, kind, diff)

# %%
def diff_struct(old, new):
    result = ""

    old_members = {m['name']: m for m in old['members']}
    new_members = {m['name']: m for m in new['members']}

    # added field
    added_members = new_members.keys() - old_members.keys()
    if added_members:
        result += f"Added fields:\n"
        for name in added_members:
            result += f"{name:>20}: {new_members[name]['type']}\n"

    # removed field
    removed_members = old_members.keys() - new_members.keys()
    if removed_members:
        result += f"Removed fields:\n"
        for name in removed_members:
            result += f"{name:>20}: {old_members[name]['type']}\n"

    # fields reordered
    common = old_members.keys() & new_members.keys()
    if [n for n in old_members if n in common] != [n for n in new_members if n in common]:
        result += f"Fields reordered:\n"
        result += f"{'':>20} {list(old_members)}\n"
        result += f"{'':>20} {list(new_members)}\n"

    # fields changed type
    changed_types = {
        name: (old_members[name]['type'], new_members[name]['type'])
        for name in common
        if old_members[name]['type'] != new_members[name]['type']
    }
    if changed_types:
        result += "Field type changed:\n"
        for name, (old_type, new_type) in changed_types.items():
            result += f"{name:>20}: {old_type}\n"
            result += f"{'':>20}->{new_type}\n"

    # fields changed offset
    old_offset = {name: old_members[name]
                  ['bits_offset'] for name in old_members}
    new_offset = {name: new_members[name]
                  ['bits_offset'] for name in new_members}
    layout_changed = old_offset != new_offset or old['size'] != new['size']
    if layout_changed and result == "":
        result += f"Layout changed\n"

    assert result, f"\n{old}\n{new}"
    return result


check_diff(d1, d2, Kind.STRUCT, diff_struct)
# Out:
# Old Kind.STRUCT (7329): ['list_head', 'hlist_head', 'hlist_node', 'callback_head', 'jump_entry', 'static_key', 'static_key_true', 'static_key_false', 'file_operations', 'atomic_notifier_head']
# New Kind.STRUCT (8439): ['list_head', 'hlist_head', 'hlist_node', 'callback_head', 'file_system_type', 'jump_entry', 'static_key', 'static_key_true', 'static_key_false', 'file_operations']
# Removed Kind.STRUCT (272): ['blk_issue_stat', 'hotplug_slot_info', 'spi_flash_read_message', 'tpm_cmd_t', 'request_list', 'fuse_out', 'cpufreq_user_policy', 'dpc_rp_pio_regs', 'property_set', 'trace_event_data_offsets_bpf_map_delete_elem']
# Added Kind.STRUCT (1382): ['ib_dm_alloc_attr', 'mctrl_gpios', 'irq_bypass_producer', 'vfio_iommu', 'x86_perf_regs', 'cpuid_regs', 'cfg80211_pmsr_capabilities', 'xarray', 'fw_priv', 'sctp_globals']
# Common Kind.STRUCT (7057): ['rpc_version', 'config_s', 'ncsi_cmd_sp_pkt', 'aml_resource_spi_serialbus', 'ib_udata', 'nla_policy', 'trace_event_raw_mm_shrink_slab_start', 'clk_notifier', 'mmiotrace_rw', 'nf_dccp_net']
# Changed Kind.STRUCT (1293): ['nla_policy', 'trace_event_raw_mm_shrink_slab_start', 'nf_dccp_net', '__kernel_sockaddr_storage', 'powercap_zone', 'platform_s2idle_ops', 'cgroup_bpf', 'devlink_port', 'ipcm_cookie', 'kallsym_iter']
# Kind.STRUCT nla_policy
#                      Added fields:
#                                    (anon): {'kind': 'UNION', 'name': '(anon)'}
#                           validation_type: {'kind': 'TYPEDEF', 'name': 'u8'}
#                      Removed fields:
#                           validation_data: {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}
#                      Field type changed:
#                                      type: {'kind': 'TYPEDEF', 'name': 'u16'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'u8'}
# Kind.STRUCT trace_event_raw_mm_shrink_slab_start
#                      Added fields:
#                                  priority: {'kind': 'INT', 'name': 'int'}
#                      Removed fields:
#                                   lru_pgs: {'kind': 'INT', 'name': 'long unsigned int'}
#                               pgs_scanned: {'kind': 'INT', 'name': 'long unsigned int'}
# Kind.STRUCT nf_dccp_net
#                      Removed fields:
#                                        pn: {'kind': 'STRUCT', 'name': 'nf_proto_net'}
# Kind.STRUCT __kernel_sockaddr_storage
#                      Added fields:
#                                    (anon): {'kind': 'UNION', 'name': '(anon)'}
#                      Removed fields:
#                                 ss_family: {'kind': 'TYPEDEF', 'name': '__kernel_sa_family_t'}
#                                    __data: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 126, 'type': {'kind': 'INT', 'name': 'char'}}
# Kind.STRUCT powercap_zone
#                      Layout changed
# Kind.STRUCT platform_s2idle_ops
#                      Added fields:
#                             restore_early: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                              prepare_late: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                      Removed fields:
#                                      sync: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                      Field type changed:
#                                      wake: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [], 'ret_type': {'kind': 'TYPEDEF', 'name': 'bool'}}}
# Kind.STRUCT cgroup_bpf
#                      Added fields:
#                                    refcnt: {'kind': 'STRUCT', 'name': 'percpu_ref'}
#                              release_work: {'kind': 'STRUCT', 'name': 'work_struct'}
#                      Field type changed:
#                                     progs: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 7, 'type': {'kind': 'STRUCT', 'name': 'list_head'}}
#                                          ->{'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 23, 'type': {'kind': 'STRUCT', 'name': 'list_head'}}
#                                 effective: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 7, 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'bpf_prog_array'}}}
#                                          ->{'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 23, 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'bpf_prog_array'}}}
#                                     flags: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 7, 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}
#                                          ->{'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 23, 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}
# Kind.STRUCT devlink_port
#                      Added fields:
#                              type_warn_dw: {'kind': 'STRUCT', 'name': 'delayed_work'}
#                                     attrs: {'kind': 'STRUCT', 'name': 'devlink_port_attrs'}
#                                 type_lock: {'kind': 'TYPEDEF', 'name': 'spinlock_t'}
#                                param_list: {'kind': 'STRUCT', 'name': 'list_head'}
#                      Removed fields:
#                                     split: {'kind': 'TYPEDEF', 'name': 'bool'}
#                               split_group: {'kind': 'TYPEDEF', 'name': 'u32'}
# Kind.STRUCT ipcm_cookie
#                      Added fields:
#                                  gso_size: {'kind': 'TYPEDEF', 'name': '__u16'}
#                      Removed fields:
#                                  tx_flags: {'kind': 'TYPEDEF', 'name': '__u8'}
# Kind.STRUCT kallsym_iter
#                      Added fields:
#                              pos_arch_end: {'kind': 'TYPEDEF', 'name': 'loff_t'}
# Kind.STRUCT xen_netif_tx_sring
#                      Added fields:
#                                       pad: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 48, 'type': {'kind': 'TYPEDEF', 'name': 'uint8_t'}}
#                      Removed fields:
#                                     __pad: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 48, 'type': {'kind': 'TYPEDEF', 'name': 'uint8_t'}}
# Kind.STRUCT elevator_type
#                      Added fields:
#                         elevator_features: {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}
#                      Removed fields:
#                                   uses_mq: {'kind': 'TYPEDEF', 'name': 'bool'}
#                      Field type changed:
#                             elevator_name: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 16, 'type': {'kind': 'INT', 'name': 'char'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'INT', 'name': 'char'}}}
#                                       ops: {'kind': 'UNION', 'name': '(anon)'}
#                                          ->{'kind': 'STRUCT', 'name': 'elevator_mq_ops'}
# Kind.STRUCT ib_ah
#                      Added fields:
#                                 sgid_attr: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'ib_gid_attr'}}}
# Kind.STRUCT bsg_job
#                      Added fields:
#                                    result: {'kind': 'INT', 'name': 'int'}
#                      reply_payload_rcv_len: {'kind': 'INT', 'name': 'unsigned int'}
#                                   bidi_rq: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'request'}}
#                                  bidi_bio: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'bio'}}
#                                   timeout: {'kind': 'INT', 'name': 'unsigned int'}
#                      Removed fields:
#                                      sreq: {'kind': 'STRUCT', 'name': 'scsi_request'}
#                                       req: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'request'}}
# Kind.STRUCT compat_itimerval
#                      Field type changed:
#                                  it_value: {'kind': 'STRUCT', 'name': 'compat_timeval'}
#                                          ->{'kind': 'STRUCT', 'name': 'old_timeval32'}
#                               it_interval: {'kind': 'STRUCT', 'name': 'compat_timeval'}
#                                          ->{'kind': 'STRUCT', 'name': 'old_timeval32'}
# Kind.STRUCT rand_data
#                      Removed fields:
#                                     stuck: {'kind': 'INT', 'name': 'unsigned int'}
#                                      stir: {'kind': 'INT', 'name': 'unsigned int'}
#                            disable_unbias: {'kind': 'INT', 'name': 'unsigned int'}
# Kind.STRUCT pv_node
#                      Removed fields:
#                                     __res: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 3, 'type': {'kind': 'STRUCT', 'name': 'mcs_spinlock'}}
# Kind.STRUCT net_bridge_fdb_entry
#                      Added fields:
#                                    rhnode: {'kind': 'STRUCT', 'name': 'rhash_head'}
#                                       key: {'kind': 'STRUCT', 'name': 'net_bridge_fdb_key'}
#                                  fdb_node: {'kind': 'STRUCT', 'name': 'hlist_node'}
#                                 is_sticky: {'kind': 'INT', 'name': 'unsigned char'}
#                      Removed fields:
#                                      addr: {'kind': 'TYPEDEF', 'name': 'mac_addr'}
#                                     hlist: {'kind': 'STRUCT', 'name': 'hlist_node'}
#                                   vlan_id: {'kind': 'TYPEDEF', 'name': '__u16'}
# Kind.STRUCT kernfs_syscall_ops
#                      Removed fields:
#                                remount_fs: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kernfs_root'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'int'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'char'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
# Kind.STRUCT tracer
#                      Removed fields:
#                                       ref: {'kind': 'INT', 'name': 'int'}
# Kind.STRUCT usb_dev_state
#                      Added fields:
#                           not_yet_resumed: {'kind': 'INT', 'name': 'int'}
#                           wait_for_resume: {'kind': 'TYPEDEF', 'name': 'wait_queue_head_t'}
#                           suspend_allowed: {'kind': 'TYPEDEF', 'name': 'bool'}
#                      Removed fields:
#                                     secid: {'kind': 'TYPEDEF', 'name': 'u32'}
#                      Fields reordered:
#                                           ['list', 'dev', 'file', 'lock', 'async_pending', 'async_completed', 'memory_list', 'wait', 'discsignr', 'disc_pid', 'cred', 'disccontext', 'ifclaimed', 'secid', 'disabled_bulk_eps', 'privileges_dropped', 'interface_allowed_mask']
#                                           ['list', 'dev', 'file', 'lock', 'async_pending', 'async_completed', 'memory_list', 'wait', 'wait_for_resume', 'discsignr', 'disc_pid', 'cred', 'disccontext', 'ifclaimed', 'disabled_bulk_eps', 'interface_allowed_mask', 'not_yet_resumed', 'suspend_allowed', 'privileges_dropped']
#                      Field type changed:
#                               disccontext: {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}
#                                          ->{'kind': 'TYPEDEF', 'name': 'sigval_t'}
# Kind.STRUCT backing_dev_info
#                      Added fields:
#                                        id: {'kind': 'TYPEDEF', 'name': 'u64'}
#                                  dev_name: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 64, 'type': {'kind': 'INT', 'name': 'char'}}
#                                   rb_node: {'kind': 'STRUCT', 'name': 'rb_node'}
#                      Removed fields:
#                               debug_stats: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'dentry'}}
#                      Field type changed:
#                                 cgwb_tree: {'kind': 'STRUCT', 'name': 'radix_tree_root'}
#                                          ->{'kind': 'STRUCT', 'name': 'xarray'}
# Kind.STRUCT device_link
#                      Added fields:
#                      supplier_preactivated: {'kind': 'TYPEDEF', 'name': 'bool'}
#                                      kref: {'kind': 'STRUCT', 'name': 'kref'}
#                      Field type changed:
#                                rpm_active: {'kind': 'TYPEDEF', 'name': 'bool'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'refcount_t'}
# Kind.STRUCT tcp_iter_state
#                      Removed fields:
#                                    family: {'kind': 'TYPEDEF', 'name': 'sa_family_t'}
# Kind.STRUCT regmap_async_spi
#                      Layout changed
# Kind.STRUCT chv_community
#                      Field type changed:
#                                 functions: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'chv_function'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'intel_function'}}}
# Kind.STRUCT mmc_gpio
#                      Added fields:
#                      cd_debounce_delay_ms: {'kind': 'TYPEDEF', 'name': 'u32'}
#                      Removed fields:
#                      override_ro_active_level: {'kind': 'TYPEDEF', 'name': 'bool'}
#                      Field type changed:
#                                  cd_label: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 0, 'type': {'kind': 'INT', 'name': 'char'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'char'}}
# Kind.STRUCT clone_info
#                      Removed fields:
#                                        md: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'mapped_device'}}
# Kind.STRUCT i2c_adapter
#                      Added fields:
#                              locked_flags: {'kind': 'INT', 'name': 'long unsigned int'}
# Kind.STRUCT nd_device_driver
#                      Layout changed
# Kind.STRUCT fib_lookup_arg
#                      Added fields:
#                               lookup_data: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'name': 'void', 'kind': 'VOID'}}}
# Kind.STRUCT perf_sample_data
#                      Removed fields:
#                              sample_flags: {'kind': 'TYPEDEF', 'name': 'u64'}
# Kind.STRUCT dwc2_dregs_backup
#                      Added fields:
#                                   dtxfsiz: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 16, 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}
# Kind.STRUCT spi_driver
#                      Layout changed
# Kind.STRUCT boot_params
#                      Added fields:
#                            acpi_rsdp_addr: {'kind': 'TYPEDEF', 'name': '__u64'}
#                      Field type changed:
#                                     _pad3: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 16, 'type': {'kind': 'TYPEDEF', 'name': '__u8'}}
#                                          ->{'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 8, 'type': {'kind': 'TYPEDEF', 'name': '__u8'}}
# Kind.STRUCT tty_operations
#                      Added fields:
#                                 proc_show: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'seq_file'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                get_serial: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'tty_struct'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'serial_struct'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                set_serial: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'tty_struct'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'serial_struct'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                      Removed fields:
#                                 proc_fops: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'file_operations'}}}
# Kind.STRUCT gpio_irq_chip
#                      Added fields:
#                       child_offset_to_irq: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'gpio_chip'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}], 'ret_type': {'kind': 'INT', 'name': 'unsigned int'}}}
#                                   init_hw: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'gpio_chip'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                irq_enable: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'irq_data'}}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                             parent_domain: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'irq_domain'}}
#                      populate_parent_fwspec: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'gpio_chip'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'irq_fwspec'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                      child_to_parent_hwirq: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'gpio_chip'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'unsigned int'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'unsigned int'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                      child_irq_domain_ops: {'kind': 'STRUCT', 'name': 'irq_domain_ops'}
#                           init_valid_mask: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'gpio_chip'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'long unsigned int'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                                    fwnode: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fwnode_handle'}}
#                               irq_disable: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'irq_data'}}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                      Removed fields:
#                           need_valid_mask: {'kind': 'TYPEDEF', 'name': 'bool'}
#                                parent_irq: {'kind': 'INT', 'name': 'unsigned int'}
# Kind.STRUCT flow_dissector_key_vlan
#                      Added fields:
#                                 vlan_tpid: {'kind': 'TYPEDEF', 'name': '__be16'}
#                                  vlan_dei: {'kind': 'TYPEDEF', 'name': 'u16'}
#                      Removed fields:
#                                   padding: {'kind': 'TYPEDEF', 'name': 'u16'}
# Kind.STRUCT hd_struct
#                      Removed fields:
#                                 in_flight: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 2, 'type': {'kind': 'TYPEDEF', 'name': 'atomic_t'}}
# Kind.STRUCT lock_manager_operations
#                      Removed fields:
#                              lm_owner_key: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'file_lock'}}}], 'ret_type': {'kind': 'INT', 'name': 'long unsigned int'}}}
#                          lm_compare_owner: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'file_lock'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'file_lock'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
# Kind.STRUCT frag_queue
#                      Layout changed
# Kind.STRUCT platform_hibernation_ops
#                      Field type changed:
#                                     begin: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'pm_message_t'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
# Kind.STRUCT netdev_rx_queue
#                      Added fields:
#                                      umem: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'xdp_umem'}}
#                                   xdp_rxq: {'kind': 'STRUCT', 'name': 'xdp_rxq_info'}
# Kind.STRUCT mmu_gather
#                      Added fields:
#                                  vma_exec: {'kind': 'INT', 'name': 'unsigned int'}
#                              cleared_puds: {'kind': 'INT', 'name': 'unsigned int'}
#                              cleared_p4ds: {'kind': 'INT', 'name': 'unsigned int'}
#                              cleared_pmds: {'kind': 'INT', 'name': 'unsigned int'}
#                              cleared_ptes: {'kind': 'INT', 'name': 'unsigned int'}
#                              freed_tables: {'kind': 'INT', 'name': 'unsigned int'}
#                                  vma_huge: {'kind': 'INT', 'name': 'unsigned int'}
#                      Removed fields:
#                                 page_size: {'kind': 'INT', 'name': 'int'}
#                      Fields reordered:
#                                           ['mm', 'batch', 'start', 'end', 'fullmm', 'need_flush_all', 'active', 'local', '__pages', 'batch_count', 'page_size']
#                                           ['mm', 'batch', 'start', 'end', 'fullmm', 'need_flush_all', 'freed_tables', 'cleared_ptes', 'cleared_pmds', 'cleared_puds', 'cleared_p4ds', 'vma_exec', 'vma_huge', 'batch_count', 'active', 'local', '__pages']
# Kind.STRUCT cpuhp_cpu_state
#                      Removed fields:
#                               booted_once: {'kind': 'TYPEDEF', 'name': 'bool'}
# Kind.STRUCT cgroup_root
#                      Layout changed
# Kind.STRUCT lruvec_stat
#                      Field type changed:
#                                     count: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 28, 'type': {'kind': 'INT', 'name': 'long int'}}
#                                          ->{'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 32, 'type': {'kind': 'INT', 'name': 'long int'}}
# Kind.STRUCT pfifo_fast_priv
#                      Removed fields:
#                                    bitmap: {'kind': 'TYPEDEF', 'name': 'u32'}
#                      Field type changed:
#                                         q: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 3, 'type': {'kind': 'STRUCT', 'name': 'qdisc_skb_head'}}
#                                          ->{'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 3, 'type': {'kind': 'STRUCT', 'name': 'skb_array'}}
# Kind.STRUCT sync_pt
#                      Layout changed
# Kind.STRUCT evdev
#                      Layout changed
# Kind.STRUCT shash_alg
#                      Layout changed
# Kind.STRUCT blkcipher_alg
#                      Removed fields:
#                                     geniv: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'INT', 'name': 'char'}}}
# Kind.STRUCT trace_event_data_offsets_xhci_log_trb
#                      Added fields:
#                                       str: {'kind': 'TYPEDEF', 'name': 'u32'}
# Kind.STRUCT tcp_fastopen_context
#                      Added fields:
#                                       num: {'kind': 'INT', 'name': 'int'}
#                      Removed fields:
#                                       tfm: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'crypto_cipher'}}
#                      Field type changed:
#                                       key: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 16, 'type': {'kind': 'TYPEDEF', 'name': '__u8'}}
#                                          ->{'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 2, 'type': {'kind': 'TYPEDEF', 'name': 'siphash_key_t'}}
# Kind.STRUCT trace_event_raw_x86_fpu
#                      Added fields:
#                                  load_fpu: {'kind': 'TYPEDEF', 'name': 'bool'}
#                      Removed fields:
#                               initialized: {'kind': 'TYPEDEF', 'name': 'bool'}
# Kind.STRUCT intel_uncore_type
#                      Added fields:
#                                    (anon): {'kind': 'UNION', 'name': '(anon)'}
#                               freerunning: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'freerunning_counters'}}
#                      num_freerunning_types: {'kind': 'INT', 'name': 'int'}
#                      Removed fields:
#                                msr_offset: {'kind': 'INT', 'name': 'unsigned int'}
# Kind.STRUCT compat_rusage
#                      Field type changed:
#                                  ru_stime: {'kind': 'STRUCT', 'name': 'compat_timeval'}
#                                          ->{'kind': 'STRUCT', 'name': 'old_timeval32'}
#                                  ru_utime: {'kind': 'STRUCT', 'name': 'compat_timeval'}
#                                          ->{'kind': 'STRUCT', 'name': 'old_timeval32'}
# Kind.STRUCT irq_remap_table
#                      Field type changed:
#                                      lock: {'kind': 'TYPEDEF', 'name': 'spinlock_t'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'raw_spinlock_t'}
# Kind.STRUCT raw_sock
#                      Layout changed
# Kind.STRUCT trace_event_raw_fib_table_lookup
#                      Added fields:
#                           __data_loc_name: {'kind': 'TYPEDEF', 'name': 'u32'}
#                                       gw4: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 4, 'type': {'kind': 'TYPEDEF', 'name': '__u8'}}
#                                       err: {'kind': 'INT', 'name': 'int'}
#                                     dport: {'kind': 'TYPEDEF', 'name': 'u16'}
#                                       gw6: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 16, 'type': {'kind': 'TYPEDEF', 'name': '__u8'}}
#                                     proto: {'kind': 'TYPEDEF', 'name': 'u8'}
#                                     sport: {'kind': 'TYPEDEF', 'name': 'u16'}
# Kind.STRUCT macvlan_dev
#                      Added fields:
#                                accel_priv: {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}
#                      Removed fields:
#                                nest_level: {'kind': 'INT', 'name': 'int'}
#                                  fwd_priv: {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}
#                      Fields reordered:
#                                           ['dev', 'list', 'hlist', 'port', 'lowerdev', 'fwd_priv', 'pcpu_stats', 'mc_filter', 'set_features', 'mode', 'flags', 'nest_level', 'netpoll', 'macaddr_count']
#                                           ['dev', 'list', 'hlist', 'port', 'lowerdev', 'accel_priv', 'pcpu_stats', 'mc_filter', 'set_features', 'mode', 'flags', 'macaddr_count', 'netpoll']
# Kind.STRUCT stack_map_bucket
#                      Added fields:
#                                      data: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 0, 'type': {'kind': 'TYPEDEF', 'name': 'u64'}}
#                      Removed fields:
#                                        ip: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 0, 'type': {'kind': 'TYPEDEF', 'name': 'u64'}}
# Kind.STRUCT bpf_cpu_map_entry
#                      Added fields:
#                                      cmap: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'bpf_cpu_map'}}
# Kind.STRUCT key
#                      Layout changed
# Kind.STRUCT nvdimm_bus
#                      Layout changed
# Kind.STRUCT dax_operations
#                      Added fields:
#                              copy_to_iter: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'dax_device'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'long unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'size_t'}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'iov_iter'}}}], 'ret_type': {'kind': 'TYPEDEF', 'name': 'size_t'}}}
#                             dax_supported: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'dax_device'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'block_device'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'sector_t'}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'sector_t'}}], 'ret_type': {'kind': 'TYPEDEF', 'name': 'bool'}}}
# Kind.STRUCT max310x_port
#                      Removed fields:
#                                     mutex: {'kind': 'STRUCT', 'name': 'mutex'}
# Kind.STRUCT page
#                      Added fields:
#                                 _refcount: {'kind': 'TYPEDEF', 'name': 'atomic_t'}
# Kind.STRUCT firmware_work
#                      Field type changed:
#                                 opt_flags: {'kind': 'INT', 'name': 'unsigned int'}
#                                          ->{'kind': 'ENUM', 'name': 'fw_opt', 'size': 4}
# Kind.STRUCT ib_global_route
#                      Added fields:
#                                 sgid_attr: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'ib_gid_attr'}}}
# Kind.STRUCT regulator
#                      Added fields:
#                                   voltage: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 5, 'type': {'kind': 'STRUCT', 'name': 'regulator_voltage'}}
#                         deferred_disables: {'kind': 'INT', 'name': 'unsigned int'}
#                              enable_count: {'kind': 'INT', 'name': 'unsigned int'}
#                      Removed fields:
#                                    min_uV: {'kind': 'INT', 'name': 'int'}
#                                    max_uV: {'kind': 'INT', 'name': 'int'}
# Kind.STRUCT hstate
#                      Layout changed
# Kind.STRUCT powercap_control_type
#                      Layout changed
# Kind.STRUCT tpm_class_ops
#                      Field type changed:
#                           update_timeouts: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'tpm_chip'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'long unsigned int'}}}], 'ret_type': {'kind': 'TYPEDEF', 'name': 'bool'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'tpm_chip'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'long unsigned int'}}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
# Kind.STRUCT cpu_vfs_cap_data
#                      Added fields:
#                                    rootid: {'kind': 'TYPEDEF', 'name': 'kuid_t'}
# Kind.STRUCT cper_sec_pcie
#                      Field type changed:
#                                  reserved: {'kind': 'TYPEDEF', 'name': '__u32'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'u32'}
#                                capability: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 60, 'type': {'kind': 'TYPEDEF', 'name': '__u8'}}
#                                          ->{'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 60, 'type': {'kind': 'TYPEDEF', 'name': 'u8'}}
#                                 port_type: {'kind': 'TYPEDEF', 'name': '__u32'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'u32'}
#                                  aer_info: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 96, 'type': {'kind': 'TYPEDEF', 'name': '__u8'}}
#                                          ->{'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 96, 'type': {'kind': 'TYPEDEF', 'name': 'u8'}}
#                           validation_bits: {'kind': 'TYPEDEF', 'name': '__u64'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'u64'}
#                                   command: {'kind': 'TYPEDEF', 'name': '__u16'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'u16'}
#                                    status: {'kind': 'TYPEDEF', 'name': '__u16'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'u16'}
# Kind.STRUCT probe_arg
#                      Added fields:
#                                     count: {'kind': 'INT', 'name': 'unsigned int'}
#                                       fmt: {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'char'}}
#                                      code: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fetch_insn'}}
#                                   dynamic: {'kind': 'TYPEDEF', 'name': 'bool'}
#                      Removed fields:
#                                     fetch: {'kind': 'STRUCT', 'name': 'fetch_param'}
#                                fetch_size: {'kind': 'STRUCT', 'name': 'fetch_param'}
# Kind.STRUCT file_lock
#                      Added fields:
#                         fl_blocked_member: {'kind': 'STRUCT', 'name': 'list_head'}
#                                fl_blocker: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'file_lock'}}
#                       fl_blocked_requests: {'kind': 'STRUCT', 'name': 'list_head'}
#                      Removed fields:
#                                   fl_next: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'file_lock'}}
#                                  fl_block: {'kind': 'STRUCT', 'name': 'list_head'}
# Kind.STRUCT bpf_verifier_state_list
#                      Added fields:
#                                   hit_cnt: {'kind': 'INT', 'name': 'int'}
#                                  miss_cnt: {'kind': 'INT', 'name': 'int'}
# Kind.STRUCT fpu
#                      Added fields:
#                          avx512_timestamp: {'kind': 'INT', 'name': 'long unsigned int'}
#                      Removed fields:
#                               initialized: {'kind': 'INT', 'name': 'unsigned char'}
# Kind.STRUCT audit_names
#                      Layout changed
# Kind.STRUCT trace_event_raw_mm_vmscan_wakeup_kswapd
#                      Added fields:
#                                 gfp_flags: {'kind': 'TYPEDEF', 'name': 'gfp_t'}
# Kind.STRUCT opal_dev
#                      Removed fields:
#                                     steps: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'opal_step'}}}
#                      Field type changed:
#                                      resp: {'kind': 'PTR', 'type': {'kind': 'TYPEDEF', 'name': 'u8'}}
#                                          ->{'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 2048, 'type': {'kind': 'TYPEDEF', 'name': 'u8'}}
#                                       cmd: {'kind': 'PTR', 'type': {'kind': 'TYPEDEF', 'name': 'u8'}}
#                                          ->{'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 2048, 'type': {'kind': 'TYPEDEF', 'name': 'u8'}}
# Kind.STRUCT devlink_ops
#                      Added fields:
#                                 trap_fini: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'devlink_trap'}}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                                 reload_up: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'netlink_ext_ack'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                 trap_init: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'devlink_trap'}}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                  info_get: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink_info_req'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'netlink_ext_ack'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                           trap_group_init: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'devlink_trap_group'}}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                               reload_down: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'netlink_ext_ack'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                           trap_action_set: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'devlink_trap'}}}}, {'name': '(anon)', 'type': {'kind': 'ENUM', 'name': 'devlink_trap_action', 'size': 4}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                              flash_update: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'INT', 'name': 'char'}}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'INT', 'name': 'char'}}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'netlink_ext_ack'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                      Field type changed:
#                       sb_tc_pool_bind_set: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink_port'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u16'}}, {'name': '(anon)', 'type': {'kind': 'ENUM', 'name': 'devlink_sb_pool_type', 'size': 4}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u16'}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink_port'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u16'}}, {'name': '(anon)', 'type': {'kind': 'ENUM', 'name': 'devlink_sb_pool_type', 'size': 4}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u16'}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'netlink_ext_ack'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                          sb_port_pool_set: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink_port'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u16'}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink_port'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u16'}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'netlink_ext_ack'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                      eswitch_encap_mode_set: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink'}}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u8'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink'}}}, {'name': '(anon)', 'type': {'kind': 'ENUM', 'name': 'devlink_eswitch_encap_mode', 'size': 4}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'netlink_ext_ack'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                      eswitch_encap_mode_get: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'TYPEDEF', 'name': 'u8'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'ENUM', 'name': 'devlink_eswitch_encap_mode', 'size': 4}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                port_split: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'netlink_ext_ack'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                               sb_pool_set: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u16'}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}, {'name': '(anon)', 'type': {'kind': 'ENUM', 'name': 'devlink_sb_threshold_type', 'size': 4}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u16'}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}, {'name': '(anon)', 'type': {'kind': 'ENUM', 'name': 'devlink_sb_threshold_type', 'size': 4}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'netlink_ext_ack'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                              port_unsplit: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'netlink_ext_ack'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                          eswitch_mode_set: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink'}}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u16'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink'}}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u16'}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'netlink_ext_ack'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                      eswitch_inline_mode_set: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink'}}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u8'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink'}}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u8'}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'netlink_ext_ack'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
# Kind.STRUCT thermal_zone_device
#                      Layout changed
# Kind.STRUCT nfs_lock_context
#                      Added fields:
#                             callback_head: {'kind': 'STRUCT', 'name': 'callback_head'}
# Kind.STRUCT blk_mq_ctx
#                      Added fields:
# ...
#                                          ->{'kind': 'INT', 'name': 'short unsigned int'}
# Kind.STRUCT sigqueue
#                      Field type changed:
#                                      info: {'kind': 'TYPEDEF', 'name': 'siginfo_t'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'kernel_siginfo_t'}
# Kind.STRUCT fsnotify_iter_info
#                      Added fields:
#                               report_mask: {'kind': 'INT', 'name': 'unsigned int'}
#                                     marks: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 3, 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fsnotify_mark'}}}
#                      Removed fields:
#                             vfsmount_mark: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fsnotify_mark'}}
#                                inode_mark: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fsnotify_mark'}}
# Kind.STRUCT compat_shmid64_ds
#                      Added fields:
#                            shm_atime_high: {'kind': 'TYPEDEF', 'name': 'compat_ulong_t'}
#                            shm_dtime_high: {'kind': 'TYPEDEF', 'name': 'compat_ulong_t'}
#                            shm_ctime_high: {'kind': 'TYPEDEF', 'name': 'compat_ulong_t'}
#                      Removed fields:
#                                 __unused3: {'kind': 'TYPEDEF', 'name': 'compat_ulong_t'}
#                                 __unused2: {'kind': 'TYPEDEF', 'name': 'compat_ulong_t'}
#                                 __unused1: {'kind': 'TYPEDEF', 'name': 'compat_ulong_t'}
#                      Field type changed:
#                                 shm_dtime: {'kind': 'TYPEDEF', 'name': 'compat_time_t'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'compat_ulong_t'}
#                                 shm_ctime: {'kind': 'TYPEDEF', 'name': 'compat_time_t'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'compat_ulong_t'}
#                                 shm_atime: {'kind': 'TYPEDEF', 'name': 'compat_time_t'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'compat_ulong_t'}
# Kind.STRUCT blkif_sring
#                      Added fields:
#                                       pad: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 48, 'type': {'kind': 'TYPEDEF', 'name': 'uint8_t'}}
#                      Removed fields:
#                                     __pad: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 48, 'type': {'kind': 'TYPEDEF', 'name': 'uint8_t'}}
# Kind.STRUCT trace_event_raw_filelock_lease
#                      Added fields:
#                                fl_blocker: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'file_lock'}}
#                      Removed fields:
#                                   fl_next: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'file_lock'}}
# Kind.STRUCT worker
#                      Added fields:
#                                 last_func: {'kind': 'TYPEDEF', 'name': 'work_func_t'}
#                                  sleeping: {'kind': 'INT', 'name': 'int'}
#                      Removed fields:
#                                desc_valid: {'kind': 'TYPEDEF', 'name': 'bool'}
# Kind.STRUCT trace_event_raw_mm_vmscan_lru_shrink_inactive
#                      Added fields:
#                              nr_activate0: {'kind': 'INT', 'name': 'unsigned int'}
#                              nr_activate1: {'kind': 'INT', 'name': 'unsigned int'}
#                      Removed fields:
#                               nr_activate: {'kind': 'INT', 'name': 'long unsigned int'}
# Kind.STRUCT coredump_proc_event
#                      Added fields:
#                                parent_pid: {'kind': 'TYPEDEF', 'name': '__kernel_pid_t'}
#                               parent_tgid: {'kind': 'TYPEDEF', 'name': '__kernel_pid_t'}
# Kind.STRUCT filename
#                      Fields reordered:
#                                           ['name', 'uptr', 'aname', 'refcnt', 'iname']
#                                           ['name', 'uptr', 'refcnt', 'aname', 'iname']
# Kind.STRUCT efi_scratch
#                      Added fields:
#                                   prev_mm: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'mm_struct'}}
#                      Removed fields:
#                                       r15: {'kind': 'TYPEDEF', 'name': 'u64'}
#                                   use_pgd: {'kind': 'TYPEDEF', 'name': 'bool'}
#                                  prev_cr3: {'kind': 'TYPEDEF', 'name': 'u64'}
#                                   efi_pgt: {'kind': 'PTR', 'type': {'kind': 'TYPEDEF', 'name': 'pgd_t'}}
# Kind.STRUCT select_data
#                      Added fields:
#                                    (anon): {'kind': 'UNION', 'name': '(anon)'}
#                      Removed fields:
#                                     found: {'kind': 'INT', 'name': 'int'}
# Kind.STRUCT nfs_server
#                      Added fields:
#                                      cred: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'cred'}}}
#                                 ss_copies: {'kind': 'STRUCT', 'name': 'list_head'}
#                              read_hdrsize: {'kind': 'INT', 'name': 'unsigned int'}
# Kind.STRUCT inet_listen_hashbucket
#                      Added fields:
#                                     count: {'kind': 'INT', 'name': 'unsigned int'}
# Kind.STRUCT inet_frags
#                      Added fields:
#                                completion: {'kind': 'STRUCT', 'name': 'completion'}
#                                    refcnt: {'kind': 'TYPEDEF', 'name': 'refcount_t'}
# Kind.STRUCT elants_data
#                      Fields reordered:
#                                           ['client', 'input', 'vcc33', 'vccio', 'reset_gpio', 'fw_version', 'test_version', 'solution_version', 'bc_version', 'iap_version', 'hw_version', 'x_res', 'y_res', 'x_max', 'y_max', 'state', 'iap_mode', 'sysfs_mutex', 'cmd_resp', 'cmd_done', 'buf', 'wake_irq_enabled', 'keep_power_in_suspend']
#                                           ['client', 'input', 'vcc33', 'vccio', 'reset_gpio', 'fw_version', 'test_version', 'solution_version', 'bc_version', 'iap_version', 'hw_version', 'x_res', 'y_res', 'x_max', 'y_max', 'state', 'iap_mode', 'sysfs_mutex', 'cmd_resp', 'cmd_done', 'wake_irq_enabled', 'keep_power_in_suspend', 'buf']
# Kind.STRUCT amd_iommu
#                      Added fields:
#                           intcapxt_notify: {'kind': 'STRUCT', 'name': 'irq_affinity_notify'}
#                      Field type changed:
#                                      lock: {'kind': 'TYPEDEF', 'name': 'spinlock_t'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'raw_spinlock_t'}
# Kind.STRUCT reclaim_stat
#                      Field type changed:
#                               nr_activate: {'kind': 'INT', 'name': 'unsigned int'}
#                                          ->{'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 2, 'type': {'kind': 'INT', 'name': 'unsigned int'}}
# Kind.STRUCT policydb
#                      Added fields:
#                        type_val_to_struct: {'kind': 'PTR', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'type_datum'}}}
#                      Removed fields:
#                      type_val_to_struct_array: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'flex_array'}}
#                      Field type changed:
#                           sym_val_to_name: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 8, 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'flex_array'}}}
#                                          ->{'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 8, 'type': {'kind': 'PTR', 'type': {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'char'}}}}
#                       type_attr_map_array: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'flex_array'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'ebitmap'}}
# Kind.STRUCT pv_mmu_ops
#                      Added fields:
#                          tlb_remove_table: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'mmu_gather'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                      Fields reordered:
#                                           ['read_cr2', 'write_cr2', 'read_cr3', 'write_cr3', 'activate_mm', 'dup_mmap', 'exit_mmap', 'flush_tlb_user', 'flush_tlb_kernel', 'flush_tlb_one_user', 'flush_tlb_others', 'pgd_alloc', 'pgd_free', 'alloc_pte', 'alloc_pmd', 'alloc_pud', 'alloc_p4d', 'release_pte', 'release_pmd', 'release_pud', 'release_p4d', 'set_pte', 'set_pte_at', 'set_pmd', 'ptep_modify_prot_start', 'ptep_modify_prot_commit', 'pte_val', 'make_pte', 'pgd_val', 'make_pgd', 'set_pud', 'pmd_val', 'make_pmd', 'pud_val', 'make_pud', 'set_p4d', 'lazy_mode', 'set_fixmap']
#                                           ['flush_tlb_user', 'flush_tlb_kernel', 'flush_tlb_one_user', 'flush_tlb_others', 'tlb_remove_table', 'exit_mmap', 'read_cr2', 'write_cr2', 'read_cr3', 'write_cr3', 'activate_mm', 'dup_mmap', 'pgd_alloc', 'pgd_free', 'alloc_pte', 'alloc_pmd', 'alloc_pud', 'alloc_p4d', 'release_pte', 'release_pmd', 'release_pud', 'release_p4d', 'set_pte', 'set_pte_at', 'set_pmd', 'ptep_modify_prot_start', 'ptep_modify_prot_commit', 'pte_val', 'make_pte', 'pgd_val', 'make_pgd', 'set_pud', 'pmd_val', 'make_pmd', 'pud_val', 'make_pud', 'set_p4d', 'lazy_mode', 'set_fixmap']
#                      Field type changed:
#                      ptep_modify_prot_start: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'mm_struct'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'long unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'TYPEDEF', 'name': 'pte_t'}}}], 'ret_type': {'kind': 'TYPEDEF', 'name': 'pte_t'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'vm_area_struct'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'long unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'TYPEDEF', 'name': 'pte_t'}}}], 'ret_type': {'kind': 'TYPEDEF', 'name': 'pte_t'}}}
#                                  read_cr2: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [], 'ret_type': {'kind': 'INT', 'name': 'long unsigned int'}}}
#                                          ->{'kind': 'STRUCT', 'name': 'paravirt_callee_save'}
#                      ptep_modify_prot_commit: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'mm_struct'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'long unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'TYPEDEF', 'name': 'pte_t'}}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'pte_t'}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'vm_area_struct'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'long unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'TYPEDEF', 'name': 'pte_t'}}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'pte_t'}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
# Kind.STRUCT mii_bus
#                      Layout changed
# Kind.STRUCT tpm_tis_tcg_phy
#                      Layout changed
# Kind.STRUCT acpi_battery
#                      Added fields:
#                                      list: {'kind': 'STRUCT', 'name': 'list_head'}
# Kind.STRUCT sdesc
#                      Layout changed
# Kind.STRUCT dma_buf_ops
#                      Added fields:
#                         cache_sgt_mapping: {'kind': 'TYPEDEF', 'name': 'bool'}
#                      Removed fields:
#                                map_atomic: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'dma_buf'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'long unsigned int'}}], 'ret_type': {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}}}
#                              unmap_atomic: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'dma_buf'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'long unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                      Fields reordered:
#                                           ['attach', 'detach', 'map_dma_buf', 'unmap_dma_buf', 'release', 'begin_cpu_access', 'end_cpu_access', 'map_atomic', 'unmap_atomic', 'map', 'unmap', 'mmap', 'vmap', 'vunmap']
#                                           ['cache_sgt_mapping', 'attach', 'detach', 'map_dma_buf', 'unmap_dma_buf', 'release', 'begin_cpu_access', 'end_cpu_access', 'mmap', 'map', 'unmap', 'vmap', 'vunmap']
#                      Field type changed:
#                                    attach: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'dma_buf'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'dma_buf_attachment'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'dma_buf'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'dma_buf_attachment'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
# Kind.STRUCT pnp_card_driver
#                      Layout changed
# Kind.STRUCT fib_info
#                      Added fields:
#                                   nh_list: {'kind': 'STRUCT', 'name': 'list_head'}
#                              fib_nh_is_v6: {'kind': 'TYPEDEF', 'name': 'bool'}
#                                nh_updated: {'kind': 'TYPEDEF', 'name': 'bool'}
#                                        nh: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'nexthop'}}
# Kind.STRUCT cn_dev
#                      Removed fields:
#                                     input: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sk_buff'}}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
# Kind.STRUCT pci_host_bridge
#                      Added fields:
#                                native_aer: {'kind': 'INT', 'name': 'unsigned int'}
#                                native_ltr: {'kind': 'INT', 'name': 'unsigned int'}
#                                dma_ranges: {'kind': 'STRUCT', 'name': 'list_head'}
#                                native_pme: {'kind': 'INT', 'name': 'unsigned int'}
#                       native_shpc_hotplug: {'kind': 'INT', 'name': 'unsigned int'}
#                           preserve_config: {'kind': 'INT', 'name': 'unsigned int'}
#                       native_pcie_hotplug: {'kind': 'INT', 'name': 'unsigned int'}
# Kind.STRUCT tun_flow_entry
#                      Layout changed
# Kind.STRUCT ftrace_stack
#                      Field type changed:
#                                     calls: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 512, 'type': {'kind': 'INT', 'name': 'long unsigned int'}}
#                                          ->{'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 1024, 'type': {'kind': 'INT', 'name': 'long unsigned int'}}

# %%
check_diff(d1, d2, Kind.UNION, diff_struct)
# Out:
# Old Kind.UNION (99): ['fpregs_state', 'irq_stack_union', 'sigval', 'kernfs_node_id', 'key_payload', 'thread_union', 'perf_mem_data_src', 'flowi_uli', 'ethtool_flow_union', 'perf_capabilities']
# New Kind.UNION (126): ['fpregs_state', 'sigval', '__sifields', 'kernfs_node_id', 'thread_union', 'key_payload', 'perf_mem_data_src', 'bpf_attr', 'flowi_uli', 'ethtool_flow_union']
# Removed Kind.UNION (6): ['ipmi_smi_info_union', 'irq_stack_union', 'c', 'ec_response_get_next_data', 'fuse_dentry', 'tpm2_cmd_params']
# Added Kind.UNION (33): ['uvh_rh_gam_alias210_redirect_config_2_mmr_u', 'uvh_apicid', 'sidtab_entry_inner', 'hv_gpa_page_range', 'ec_response_get_next_data_v1', 'tls_crypto_context', 'uvh_rh_gam_config_mmr_u', 'uv1h_lb_target_physical_apic_id_mask_u', 'uv3h_gr0_gam_gr_config_u', 'bau_payload_header']
# Common Kind.UNION (93): ['tpacket_req_u', 'mon_data_bits', 'acpi_descriptor', 'irte_ga_lo', 'entry_union', 'hsw_tsx_tuning', 'l2_cache', 'tcp_cc_info', 'l3_cache', 'ftrace_code_union']
# Changed Kind.UNION (6): ['bpf_attr', 'security_list_options', 'thread_union', 'hdmi_infoframe', 'nested_table', 'nf_conntrack_proto']
# Kind.UNION  bpf_attr
#                      Added fields:
#                            raw_tracepoint: {'kind': 'STRUCT', 'name': '(anon)'}
#                             task_fd_query: {'kind': 'STRUCT', 'name': '(anon)'}
# Kind.UNION  security_list_options
#                      Added fields:
#                             sctp_sk_clone: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sctp_endpoint'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sock'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sock'}}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                        sctp_assoc_request: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sctp_endpoint'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sk_buff'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                           sb_eat_lsm_opts: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'char'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                               path_notify: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'path'}}}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u64'}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                            fs_context_dup: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fs_context'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fs_context'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                             cred_getsecid: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'cred'}}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                      fs_context_parse_param: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fs_context'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fs_parameter'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                         sctp_bind_connect: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sock'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sockaddr'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                         socket_socketpair: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'socket'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'socket'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                move_mount: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'path'}}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'path'}}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                               locked_down: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'ENUM', 'name': 'lockdown_reason', 'size': 4}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                          sb_free_mnt_opts: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                          lock_kernel_down: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'INT', 'name': 'char'}}}}, {'name': '(anon)', 'type': {'kind': 'ENUM', 'name': 'lockdown_reason', 'size': 4}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                          kernel_load_data: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'ENUM', 'name': 'kernel_load_data_id', 'size': 4}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                      kernfs_init_security: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kernfs_node'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kernfs_node'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                            sb_add_mnt_opt: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'INT', 'name': 'char'}}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'INT', 'name': 'char'}}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                      Removed fields:
#                              sb_copy_data: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'char'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'char'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                         sb_parse_opts_str: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'char'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'security_mnt_opts'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                      Field type changed:
#                        sem_alloc_security: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sem_array'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                             shm_associate: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'shmid_kernel'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                        shm_alloc_security: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'shmid_kernel'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                shm_shmctl: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'shmid_kernel'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                          audit_rule_match: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'audit_context'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                 shm_shmat: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'shmid_kernel'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'char'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'char'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                         sem_free_security: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sem_array'}}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                      msg_queue_alloc_security: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'msg_queue'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                 task_kill: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'task_struct'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'siginfo'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'task_struct'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kernel_siginfo'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'cred'}}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                          msg_queue_msgsnd: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'msg_queue'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'msg_msg'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'msg_msg'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                         shm_free_security: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'shmid_kernel'}}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                          msg_queue_msgctl: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'msg_queue'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                          msg_queue_msgrcv: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'msg_queue'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'msg_msg'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'task_struct'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'long int'}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'msg_msg'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'task_struct'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'long int'}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                   settime: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timezone'}}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timezone'}}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                       msg_queue_associate: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'msg_queue'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                      msg_queue_free_security: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'msg_queue'}}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                             sem_associate: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sem_array'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                 sem_semop: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sem_array'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sembuf'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sembuf'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                sem_semctl: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sem_array'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                           sb_set_mnt_opts: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'super_block'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'security_mnt_opts'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'long unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'long unsigned int'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'super_block'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'long unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'long unsigned int'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                             sb_kern_mount: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'super_block'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'super_block'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                 file_open: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'file'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'cred'}}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'file'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
# Kind.UNION  thread_union
#                      Added fields:
#                                      task: {'kind': 'STRUCT', 'name': 'task_struct'}
# Kind.UNION  hdmi_infoframe
#                      Added fields:
#                                       drm: {'kind': 'STRUCT', 'name': 'hdmi_drm_infoframe'}
# Kind.UNION  nested_table
#                      Field type changed:
#                                    bucket: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'rhash_head'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'rhash_lock_head'}}
# Kind.UNION  nf_conntrack_proto
#                      Added fields:
#                                       udp: {'kind': 'STRUCT', 'name': 'nf_ct_udp'}

# %%
def diff_func(old, new):
    result = ""

    old_params = {p['name']: p for p in old['type']['params']}
    new_params = {p['name']: p for p in new['type']['params']}

    # params added
    added_params = new_params.keys() - old_params.keys()
    if added_params:
        result += f"Added params:\n"
        for name in added_params:
            result += f"{name:>20}: {new_params[name]['type']}\n"

    # params removed
    removed_params = old_params.keys() - new_params.keys()
    if removed_params:
        result += f"Removed params:\n"
        for name in removed_params:
            result += f"{name:>20}: {old_params[name]['type']}\n"

    # params reordered
    common = old_params.keys() & new_params.keys()
    if [n for n in old_params if n in common] != [n for n in new_params if n in common]:
        result += f"Params reordered:\n"
        result += f"{'':>20} {list(old_params)}\n"
        result += f"{'':>20} {list(new_params)}\n"

    # params changed type
    changed_types = {
        name: (old_params[name]['type'], new_params[name]['type'])
        for name in common
        if old_params[name]['type'] != new_params[name]['type']
    }
    if changed_types:
        result += "Param type changed:\n"
        for name, (old_type, new_type) in changed_types.items():
            result += f"{name:>20}: {old_type}\n"
            result += f"{'':>20}->{new_type}\n"

    # changed return value
    old_ret = old['type']['ret_type']
    new_ret = new['type']['ret_type']
    if old_ret != new_ret:
        result += f"Return type changed:\n"
        result += f"{'':>20}: {old_ret}\n"
        result += f"{'':>20}->{new_ret}\n"

    assert result, f"\n{old}\n{new}"
    return result


check_diff(d1, d2, Kind.FUNC, diff_func)

# %%
def diff_enum(old, new):
    result = ""

    old_values = {v['name']: v for v in old['values']}
    new_values = {v['name']: v for v in new['values']}

    # added value
    added_values = new_values.keys() - old_values.keys()
    if added_values:
        result += f"Added values:\n"
        for name in added_values:
            result += f"{'':8}{name:40}: {new_values[name]['val']}\n"

    # removed value
    removed_values = old_values.keys() - new_values.keys()
    if removed_values:
        result += f"Removed values:\n"
        for name in removed_values:
            result += f"{'':8}{name:40}: {old_values[name]['val']}\n"

    # values changed
    common = old_values.keys() & new_values.keys()
    changed_values = {
        name: (old_values[name]['val'], new_values[name]['val'])
        for name in common
        if old_values[name]['val'] != new_values[name]['val']
    }
    if changed_values:
        result += "Value changed:\n"
        for name, (old_val, new_val) in changed_values.items():
            result += f"{'':8}{name:40}: {old_val} -> {new_val}\n"

    assert result, f"\n{old}\n{new}"

    return result


check_diff(d1, d2, Kind.ENUM, diff_enum)
# Out:
# Old Kind.ENUM (1153): ['system_states', 'timespec_type', 'x86_hardware_subarch', 'l1tf_mitigations', 'x86_legacy_i8042_state', 'fixed_addresses', 'uprobe_task_state', 'apic_intr_mode_id', 'pcpu_fc', 'numa_stat_item']
# New Kind.ENUM (1178): ['system_states', 'timespec_type', 'x86_hardware_subarch', 'l1tf_mitigations', 'x86_legacy_i8042_state', 'fixed_addresses', 'uprobe_task_state', 'apic_intr_mode_id', 'pcpu_fc', 'numa_stat_item']
# Removed Kind.ENUM (7): ['hmm_update_event', 'nvdimm_security_state', 'userfaultfd_state', 'si_sm_result', 'evdev_clock_type', 'pcie_data_rate', 'memmap_context']
# Added Kind.ENUM (32): ['uv_memprotect', 'ramfs_param', 'rproc_crash_type', 'vfio_notify_type', 'input_clock_type', 'ioc_running', 'net_dm_attr', 'perf_event_sample_format', 'devlink_trap_action', 'ip_conntrack_status']
# Common Kind.ENUM (1146): ['audit_nlgrps', 'tg_state_flags', 'rseq_cpu_id_state', 'devkmsg_log_bits', 'opal_mbr_done_flag', 'cgroup_filetype', 'iommu_fault_type', 'devlink_dpipe_header_id', 'tcp_queue', 'ib_sig_type']
# Changed Kind.ENUM (55): ['rseq_cpu_id_state', 'req_opf', 'dev_pm_qos_req_type', 'sysctl_writes_mode', 'drm_panel_orientation', 'bpf_map_type', 'dmi_device_type', 'rt6_nud_state', 'scan_result', 'lsm_order']
# Kind.ENUM   rseq_cpu_id_state
#                      Value changed:
#                              RSEQ_CPU_ID_UNINITIALIZED               : -1 -> 18446744073709551615
#                              RSEQ_CPU_ID_REGISTRATION_FAILED         : -2 -> 18446744073709551614
# Kind.ENUM   req_opf
#                      Added values:
#                              REQ_OP_ZONE_RESET_ALL                   : 8
# Kind.ENUM   dev_pm_qos_req_type
#                      Removed values:
#                              DEV_PM_QOS_MAX_FREQUENCY                : 4
#                              DEV_PM_QOS_MIN_FREQUENCY                : 3
#                      Value changed:
#                              DEV_PM_QOS_FLAGS                        : 5 -> 3
# Kind.ENUM   sysctl_writes_mode
#                      Value changed:
#                              SYSCTL_WRITES_LEGACY                    : -1 -> 18446744073709551615
# Kind.ENUM   drm_panel_orientation
#                      Value changed:
#                              DRM_MODE_PANEL_ORIENTATION_UNKNOWN      : -1 -> 18446744073709551615
# Kind.ENUM   bpf_map_type
#                      Added values:
#                              BPF_MAP_TYPE_DEVMAP_HASH                : 25
# Kind.ENUM   dmi_device_type
#                      Value changed:
#                              DMI_DEV_TYPE_DEV_ONBOARD                : -3 -> 18446744073709551613
#                              DMI_DEV_TYPE_DEV_SLOT                   : -4 -> 18446744073709551612
#                              DMI_DEV_TYPE_IPMI                       : -1 -> 18446744073709551615
#                              DMI_DEV_TYPE_OEM_STRING                 : -2 -> 18446744073709551614
# Kind.ENUM   rt6_nud_state
#                      Value changed:
#                              RT6_NUD_FAIL_PROBE                      : -2 -> 18446744073709551614
#                              RT6_NUD_FAIL_HARD                       : -3 -> 18446744073709551613
#                              RT6_NUD_FAIL_DO_RR                      : -1 -> 18446744073709551615
# Kind.ENUM   scan_result
#                      Added values:
#                              SCAN_PAGE_HAS_PRIVATE                   : 24
# Kind.ENUM   lsm_order
#                      Value changed:
#                              LSM_ORDER_FIRST                         : -1 -> 18446744073709551615
# Kind.ENUM   vfs_get_super_keying
#                      Added values:
#                              vfs_get_single_reconf_super             : 1
#                      Value changed:
#                              vfs_get_keyed_super                     : 1 -> 2
#                              vfs_get_independent_super               : 2 -> 3
# Kind.ENUM   phy_tunable_id
#                      Added values:
#                              ETHTOOL_PHY_EDPD                        : 3
#                      Value changed:
#                              __ETHTOOL_PHY_TUNABLE_COUNT             : 3 -> 4
# Kind.ENUM   tc_setup_type
#                      Added values:
#                              TC_SETUP_QDISC_TAPRIO                   : 13
# Kind.ENUM   bpf_cmd
#                      Added values:
#                              BPF_BTF_GET_NEXT_ID                     : 23
# Kind.ENUM   pm_qos_flags_status
#                      Value changed:
#                              PM_QOS_FLAGS_UNDEFINED                  : -1 -> 18446744073709551615
# Kind.ENUM   nf_ip_hook_priorities
#                      Value changed:
#                              NF_IP_PRI_CONNTRACK_DEFRAG              : -400 -> 18446744073709551216
#                              NF_IP_PRI_RAW_BEFORE_DEFRAG             : -450 -> 18446744073709551166
#                              NF_IP_PRI_CONNTRACK                     : -200 -> 18446744073709551416
#                              NF_IP_PRI_FIRST                         : -2147483648 -> 18446744071562067968
#                              NF_IP_PRI_MANGLE                        : -150 -> 18446744073709551466
#                              NF_IP_PRI_NAT_DST                       : -100 -> 18446744073709551516
#                              NF_IP_PRI_RAW                           : -300 -> 18446744073709551316
#                              NF_IP_PRI_SELINUX_FIRST                 : -225 -> 18446744073709551391
# Kind.ENUM   enable_type
#                      Value changed:
#                              undefined                               : -1 -> 18446744073709551615
# Kind.ENUM   fuse_opcode
#                      Added values:
#                              FUSE_REMOVEMAPPING                      : 49
#                              FUSE_INIT_BSWAP_RESERVED                : 436207616
#                              FUSE_SETUPMAPPING                       : 48
#                              CUSE_INIT_BSWAP_RESERVED                : 1048576
# Kind.ENUM   pci_board_num_t
#                      Added values:
#                              pbn_fintek_F81504A                      : 99
#                              pbn_moxa8250_4p                         : 114
#                              pbn_fintek_F81512A                      : 101
#                              pbn_fintek_F81508A                      : 100
#                              pbn_moxa8250_8p                         : 115
#                              pbn_moxa8250_2p                         : 113
#                      Value changed:
#                              pbn_pericom_PI7C9X7951                  : 101 -> 104
#                              pbn_sunix_pci_4s                        : 107 -> 110
#                              pbn_pericom_PI7C9X7952                  : 102 -> 105
#                              pbn_pericom_PI7C9X7958                  : 104 -> 107
#                              pbn_sunix_pci_8s                        : 108 -> 111
#                              pbn_wch384_4                            : 100 -> 103
#                              pbn_sunix_pci_2s                        : 106 -> 109
#                              pbn_wch382_2                            : 99 -> 102
#                              pbn_sunix_pci_16s                       : 109 -> 112
#                              pbn_sunix_pci_1s                        : 105 -> 108
#                              pbn_pericom_PI7C9X7954                  : 103 -> 106
# Kind.ENUM   memcg_stat_item
#                      Value changed:
#                              MEMCG_RSS                               : 31 -> 33
#                              MEMCG_RSS_HUGE                          : 32 -> 34
#                              MEMCG_SWAP                              : 33 -> 35
#                              MEMCG_KERNEL_STACK_KB                   : 35 -> 37
#                              MEMCG_CACHE                             : 30 -> 32
#                              MEMCG_SOCK                              : 34 -> 36
#                              MEMCG_NR_STAT                           : 36 -> 38
# Kind.ENUM   rq_qos_id
#                      Added values:
#                              RQ_QOS_COST                             : 2
#                              RQ_QOS_LATENCY                          : 1
#                      Removed values:
#                              RQ_QOS_CGROUP                           : 1
# Kind.ENUM   wb_reason
#                      Added values:
#                              WB_REASON_FOREIGN_FLUSH                 : 8
#                      Value changed:
#                              WB_REASON_MAX                           : 8 -> 9
# Kind.ENUM   bpf_func_id
#                      Added values:
#                              BPF_FUNC_tcp_gen_syncookie              : 110
#                      Value changed:
#                              __BPF_FUNC_MAX_ID                       : 110 -> 111
# Kind.ENUM   dsa_tag_protocol
#                      Added values:
#                              DSA_TAG_PROTO_KSZ8795                   : 14
# Kind.ENUM   qdisc_state_t
#                      Added values:
#                              __QDISC_STATE_MISSED                    : 2
# Kind.ENUM   tpm_pcrs
#                      Added values:
#                              TPM_PCR10                               : 10
# Kind.ENUM   ctx_state
#                      Value changed:
#                              CONTEXT_DISABLED                        : -1 -> 18446744073709551615
# Kind.ENUM   smca_bank_types
#                      Added values:
#                              SMCA_LS_V2                              : 1
#                      Value changed:
#                              SMCA_RESERVED                           : 4 -> 5
#                              SMCA_PCIE                               : 19 -> 20
#                              SMCA_NBIO                               : 18 -> 19
#                              SMCA_EX                                 : 5 -> 6
#                              SMCA_SMU                                : 15 -> 16
#                              SMCA_PSP                                : 13 -> 14
#                              SMCA_SMU_V2                             : 16 -> 17
#                              SMCA_FP                                 : 6 -> 7
#                              N_SMCA_BANK_TYPES                       : 20 -> 21
#                              SMCA_PSP_V2                             : 14 -> 15
#                              SMCA_PB                                 : 12 -> 13
#                              SMCA_CS_V2                              : 9 -> 10
#                              SMCA_CS                                 : 8 -> 9
#                              SMCA_L3_CACHE                           : 7 -> 8
#                              SMCA_IF                                 : 1 -> 2
#                              SMCA_L2_CACHE                           : 2 -> 3
#                              SMCA_MP5                                : 17 -> 18
#                              SMCA_DE                                 : 3 -> 4
#                              SMCA_UMC                                : 11 -> 12
#                              SMCA_PIE                                : 10 -> 11
# Kind.ENUM   evtreturn
#                      Value changed:
#                              EVT_ERR                                 : -1 -> 18446744073709551615
# Kind.ENUM   device_link_state
#                      Value changed:
#                              DL_STATE_NONE                           : -1 -> 18446744073709551615
# Kind.ENUM   devlink_param_generic_id
#                      Added values:
#                              DEVLINK_PARAM_GENERIC_ID_RESET_DEV_ON_DRV_PROBE: 8
#                              DEVLINK_PARAM_GENERIC_ID_ENABLE_ROCE    : 9
#                      Value changed:
#                              DEVLINK_PARAM_GENERIC_ID_MAX            : 7 -> 9
#                              __DEVLINK_PARAM_GENERIC_ID_MAX          : 8 -> 10
# Kind.ENUM   cpuhp_state
#                      Added values:
#                              CPUHP_PADATA_DEAD                       : 35
#                              CPUHP_AP_OMAP_DM_TIMER_STARTING         : 114
#                      Value changed:
#                              CPUHP_POWERPC_PMAC_PREPARE              : 46 -> 47
#                              CPUHP_AP_QCOM_TIMER_STARTING            : 116 -> 118
#                              CPUHP_AP_PERF_ARM_HISI_HHA_ONLINE       : 156 -> 158
#                              CPUHP_AP_PERF_X86_UNCORE_ONLINE         : 145 -> 147
#                              CPUHP_AP_PERF_X86_STARTING              : 98 -> 99
#                              CPUHP_AP_PERF_S390_SF_ONLINE            : 152 -> 154
#                              CPUHP_AP_IRQ_HIP04_STARTING             : 91 -> 92
#                              CPUHP_AP_ARM_CACHE_B15_RAC_DYING        : 134 -> 136
#                              CPUHP_AP_ARM_SDEI_STARTING              : 104 -> 105
#                              CPUHP_X2APIC_PREPARE                    : 39 -> 40
#                              CPUHP_AP_PERF_X86_CSTATE_STARTING       : 101 -> 102
#                              CPUHP_AP_PERF_ARM_STARTING              : 109 -> 110
#                              CPUHP_AP_PERF_POWERPC_CORE_IMC_ONLINE   : 164 -> 166
#                              CPUHP_AP_X86_INTEL_EPB_ONLINE           : 142 -> 144
#                              CPUHP_AP_ARM_ARCH_TIMER_STARTING        : 112 -> 113
#                              CPUHP_AP_PERF_ARM_QCOM_L3_ONLINE        : 160 -> 162
#                              CPUHP_AP_PERF_POWERPC_NEST_IMC_ONLINE   : 163 -> 165
#                              CPUHP_AP_PERF_X86_ONLINE                : 144 -> 146
#                              CPUHP_AP_OFFLINE                        : 87 -> 88
#                              CPUHP_KVM_PPC_BOOK3S_PREPARE            : 60 -> 61
#                              CPUHP_AP_PERF_X86_RAPL_ONLINE           : 148 -> 150
#                              CPUHP_AP_PERF_ARM_HW_BREAKPOINT_STARTING: 107 -> 108
#                              CPUHP_ARM_BL_PREPARE                    : 55 -> 56
#                              CPUHP_AP_SCHED_STARTING                 : 88 -> 89
#                              CPUHP_AP_ARM_MVEBU_COHERENCY            : 95 -> 96
#                              CPUHP_AP_PERF_X86_CQM_ONLINE            : 149 -> 151
#                              CPUHP_SH_SH3X_PREPARE                   : 51 -> 52
#                              CPUHP_MM_ZSWP_POOL_PREPARE              : 59 -> 60
#                              CPUHP_AP_ARM_GLOBAL_TIMER_STARTING      : 113 -> 115
#                              CPUHP_AP_PERF_ARM_L2X0_ONLINE           : 158 -> 160
#                              CPUHP_AP_JCORE_TIMER_STARTING           : 114 -> 116
#                              CPUHP_AP_ARM_TWD_STARTING               : 115 -> 117
#                              CPUHP_SLAB_PREPARE                      : 42 -> 43
#                              CPUHP_AP_ARM_XEN_STARTING               : 129 -> 131
#                              CPUHP_AP_BASE_CACHEINFO_ONLINE          : 170 -> 172
#                              CPUHP_BP_PREPARE_DYN_END                : 84 -> 85
#                              CPUHP_AP_ARM_CORESIGHT_STARTING         : 130 -> 132
#                              CPUHP_WORKQUEUE_PREP                    : 35 -> 36
#                              CPUHP_AP_PERF_ONLINE                    : 143 -> 145
#                              CPUHP_AP_X86_TBOOT_DYING                : 133 -> 135
#                              CPUHP_AP_IRQ_GIC_STARTING               : 90 -> 91
#                              CPUHP_AP_ONLINE                         : 135 -> 137
#                              CPUHP_TEARDOWN_CPU                      : 136 -> 138
#                              CPUHP_AP_ARM64_ISNDEP_STARTING          : 131 -> 133
#                              CPUHP_AP_ARMADA_TIMER_STARTING          : 118 -> 120
#                              CPUHP_RCUTREE_PREP                      : 44 -> 45
#                              CPUHP_AP_PERF_ARM_HISI_L3_ONLINE        : 157 -> 159
#                              CPUHP_AP_PERF_X86_CSTATE_ONLINE         : 150 -> 152
#                              CPUHP_AP_ARM_VFP_STARTING               : 105 -> 106
#                              CPUHP_MM_ZS_PREPARE                     : 57 -> 58
#                              CPUHP_AP_PERF_X86_AMD_POWER_ONLINE      : 147 -> 149
#                              CPUHP_XEN_PREPARE                       : 48 -> 49
#                              CPUHP_MM_ZSWP_MEM_PREPARE               : 58 -> 59
#                              CPUHP_AP_IRQ_MIPS_GIC_STARTING          : 94 -> 95
#                              CPUHP_HRTIMERS_PREPARE                  : 37 -> 38
#                              CPUHP_ZCOMP_PREPARE                     : 61 -> 62
#                              CPUHP_AP_X86_KVM_CLK_ONLINE             : 203 -> 205
#                              CPUHP_POWER_NUMA_PREPARE                : 36 -> 37
#                              CPUHP_AP_KVM_ARM_VGIC_STARTING          : 126 -> 128
#                              CPUHP_AP_MICROCODE_LOADER               : 96 -> 97
#                              CPUHP_AP_X86_HPET_ONLINE                : 202 -> 204
#                              CPUHP_NET_FLOW_PREPARE                  : 52 -> 53
#                              CPUHP_AP_IRQ_BCM2836_STARTING           : 93 -> 94
#                              CPUHP_TOPOLOGY_PREPARE                  : 53 -> 54
#                              CPUHP_AP_KVM_STARTING                   : 124 -> 126
#                              CPUHP_SMPCFD_PREPARE                    : 40 -> 41
#                              CPUHP_AP_RISCV_TIMER_STARTING           : 122 -> 124
#                              CPUHP_MIPS_SOC_PREPARE                  : 63 -> 64
#                              CPUHP_AP_MIPS_GIC_TIMER_STARTING        : 120 -> 122
#                              CPUHP_AP_DUMMY_TIMER_STARTING           : 128 -> 130
#                              CPUHP_AP_RCUTREE_DYING                  : 89 -> 90
#                              CPUHP_AP_TEGRA_TIMER_STARTING           : 117 -> 119
#                              CPUHP_AP_PERF_ARM_CCN_ONLINE            : 154 -> 156
#                              CPUHP_XEN_EVTCHN_PREPARE                : 49 -> 50
#                              CPUHP_AP_SMPBOOT_THREADS                : 138 -> 140
#                              CPUHP_AP_PERF_S390_CF_ONLINE            : 151 -> 153
#                              CPUHP_AP_PERF_POWERPC_TRACE_IMC_ONLINE  : 166 -> 168
#                              CPUHP_AP_PERF_X86_AMD_IBS_STARTING      : 99 -> 100
#                              CPUHP_TRACE_RB_PREPARE                  : 56 -> 57
#                              CPUHP_AP_PERF_ARM_APM_XGENE_ONLINE      : 161 -> 163
#                              CPUHP_AP_ONLINE_DYN                     : 171 -> 173
#                              CPUHP_POWERPC_MMU_CTX_PREPARE           : 47 -> 48
#                              CPUHP_AP_ONLINE_DYN_END                 : 201 -> 203
#                              CPUHP_AP_PERF_ARM_HISI_DDRC_ONLINE      : 155 -> 157
#                              CPUHP_AP_IRQ_ARMADA_XP_STARTING         : 92 -> 93
#                              CPUHP_AP_PERF_X86_AMD_UNCORE_STARTING   : 97 -> 98
#                              CPUHP_RELAY_PREPARE                     : 41 -> 42
#                              CPUHP_AP_PERF_X86_CQM_STARTING          : 100 -> 101
#                              CPUHP_AP_EXYNOS4_MCT_TIMER_STARTING     : 111 -> 112
#                              CPUHP_AP_WORKQUEUE_ONLINE               : 168 -> 170
#                              CPUHP_ONLINE                            : 205 -> 207
#                              CPUHP_AP_IDLE_DEAD                      : 86 -> 87
#                              CPUHP_BP_PREPARE_DYN                    : 64 -> 65
#                              CPUHP_AP_MARCO_TIMER_STARTING           : 119 -> 121
#                              CPUHP_AP_ONLINE_IDLE                    : 137 -> 139
#                              CPUHP_CPUIDLE_COUPLED_PREPARE           : 45 -> 46
#                              CPUHP_AP_ACTIVE                         : 204 -> 206
#                              CPUHP_AP_PERF_ARM_ACPI_STARTING         : 108 -> 109
#                              CPUHP_AP_PERF_ARM_CCI_ONLINE            : 153 -> 155
#                              CPUHP_AP_ARM64_DEBUG_MONITORS_STARTING  : 106 -> 107
#                              CPUHP_AP_WATCHDOG_ONLINE                : 167 -> 169
#                              CPUHP_ARM_SHMOBILE_SCU_PREPARE          : 50 -> 51
#                              CPUHP_AP_IRQ_AFFINITY_ONLINE            : 140 -> 142
#                              CPUHP_AP_SMPCFD_DYING                   : 132 -> 134
#                              CPUHP_AP_PERF_POWERPC_THREAD_IMC_ONLINE : 165 -> 167
#                              CPUHP_AP_KVM_ARM_TIMER_STARTING         : 127 -> 129
#                              CPUHP_AP_X86_VDSO_VMA_ONLINE            : 139 -> 141
#                              CPUHP_BRINGUP_CPU                       : 85 -> 86
#                              CPUHP_TIMERS_PREPARE                    : 62 -> 63
#                              CPUHP_AP_RCUTREE_ONLINE                 : 169 -> 171
#                              CPUHP_AP_PERF_ARM_QCOM_L2_ONLINE        : 159 -> 161
#                              CPUHP_AP_PERF_X86_AMD_UNCORE_ONLINE     : 146 -> 148
#                              CPUHP_INVALID                           : -1 -> 18446744073709551615
#                              CPUHP_AP_PERF_XTENSA_STARTING           : 102 -> 103
#                              CPUHP_AP_CSKY_TIMER_STARTING            : 123 -> 125
#                              CPUHP_MD_RAID5_PREPARE                  : 43 -> 44
#                              CPUHP_AP_PERF_ARM_CAVIUM_TX2_UNCORE_ONLINE: 162 -> 164
#                              CPUHP_PROFILE_PREPARE                   : 38 -> 39
#                              CPUHP_AP_ARM_L2X0_STARTING              : 110 -> 111
#                              CPUHP_AP_KVM_ARM_VGIC_INIT_STARTING     : 125 -> 127
#                              CPUHP_AP_ARM_MVEBU_SYNC_CLOCKS          : 141 -> 143
#                              CPUHP_AP_MIPS_OP_LOONGSON3_STARTING     : 103 -> 104
#                              CPUHP_AP_ARC_TIMER_STARTING             : 121 -> 123
#                              CPUHP_NET_IUCV_PREPARE                  : 54 -> 55
# Kind.ENUM   skb_ext_id
#                      Added values:
#                              TC_SKB_EXT                              : 2
#                      Value changed:
#                              SKB_EXT_NUM                             : 2 -> 3
# Kind.ENUM   hdmi_3d_structure
#                      Value changed:
#                              HDMI_3D_STRUCTURE_INVALID               : -1 -> 18446744073709551615
# Kind.ENUM   req_flag_bits
#                      Added values:
#                              __REQ_NOWAIT_INLINE                     : 22
#                      Value changed:
#                              __REQ_NOUNMAP                           : 23 -> 24
#                              __REQ_SWAP                              : 26 -> 27
#                              __REQ_CGROUP_PUNT                       : 22 -> 23
#                              __REQ_DRV                               : 25 -> 26
#                              __REQ_NR_BITS                           : 27 -> 28
#                              __REQ_HIPRI                             : 24 -> 25
# Kind.ENUM   netdev_tx
#                      Value changed:
#                              __NETDEV_TX_MIN                         : -2147483648 -> 18446744071562067968
# Kind.ENUM   ata_completion_errors
#                      Added values:
#                              AC_ERR_OK                               : 0
# Kind.ENUM   nf_ip6_hook_priorities
#                      Value changed:
#                              NF_IP6_PRI_RAW_BEFORE_DEFRAG            : -450 -> 18446744073709551166
#                              NF_IP6_PRI_RAW                          : -300 -> 18446744073709551316
#                              NF_IP6_PRI_MANGLE                       : -150 -> 18446744073709551466
#                              NF_IP6_PRI_NAT_DST                      : -100 -> 18446744073709551516
#                              NF_IP6_PRI_FIRST                        : -2147483648 -> 18446744071562067968
#                              NF_IP6_PRI_CONNTRACK                    : -200 -> 18446744073709551416
#                              NF_IP6_PRI_SELINUX_FIRST                : -225 -> 18446744073709551391
#                              NF_IP6_PRI_CONNTRACK_DEFRAG             : -400 -> 18446744073709551216
# Kind.ENUM   node_stat_item
#                      Added values:
#                              NR_FILE_PMDMAPPED                       : 24
#                              NR_FILE_THPS                            : 23
#                      Value changed:
#                              NR_VMSCAN_IMMEDIATE                     : 26 -> 28
#                              NR_VMSCAN_WRITE                         : 25 -> 27
#                              NR_VM_NODE_STAT_ITEMS                   : 30 -> 32
#                              NR_KERNEL_MISC_RECLAIMABLE              : 29 -> 31
#                              NR_ANON_THPS                            : 23 -> 25
#                              NR_DIRTIED                              : 27 -> 29
#                              NR_WRITTEN                              : 28 -> 30
#                              NR_UNSTABLE_NFS                         : 24 -> 26
# Kind.ENUM   ttu_flags
#                      Added values:
#                              TTU_SYNC                                : 512
# Kind.ENUM   reboot_mode
#                      Value changed:
#                              REBOOT_UNDEFINED                        : -1 -> 18446744073709551615
# Kind.ENUM   nl80211_band
#                      Added values:
#                              NL80211_BAND_6GHZ                       : 3
#                      Value changed:
#                              NUM_NL80211_BANDS                       : 3 -> 4
# Kind.ENUM   perf_event_state
#                      Value changed:
#                              PERF_EVENT_STATE_DEAD                   : -4 -> 18446744073709551612
#                              PERF_EVENT_STATE_ERROR                  : -2 -> 18446744073709551614
#                              PERF_EVENT_STATE_EXIT                   : -3 -> 18446744073709551613
#                              PERF_EVENT_STATE_OFF                    : -1 -> 18446744073709551615
# Kind.ENUM   devlink_attr
#                      Added values:
#                              DEVLINK_ATTR_TRAP_ACTION                : 131
#                              DEVLINK_ATTR_TRAP_GROUP_NAME            : 135
#                              DEVLINK_ATTR_RELOAD_FAILED              : 136
#                              DEVLINK_ATTR_TRAP_GENERIC               : 133
#                              DEVLINK_ATTR_TRAP_NAME                  : 130
#                              DEVLINK_ATTR_STATS                      : 129
#                              DEVLINK_ATTR_TRAP_METADATA              : 134
#                              DEVLINK_ATTR_TRAP_TYPE                  : 132
#                      Value changed:
#                              DEVLINK_ATTR_HEALTH_REPORTER_DUMP_TS_NS : 129 -> 137
#                              __DEVLINK_ATTR_MAX                      : 130 -> 138
#                              DEVLINK_ATTR_MAX                        : 129 -> 137
# Kind.ENUM   flow_dissector_key_id
#                      Added values:
#                              FLOW_DISSECTOR_KEY_PORTS_RANGE          : 5
#                      Value changed:
#                              FLOW_DISSECTOR_KEY_ENC_CONTROL          : 16 -> 17
#                              FLOW_DISSECTOR_KEY_ARP                  : 8 -> 9
#                              FLOW_DISSECTOR_KEY_ETH_ADDRS            : 6 -> 7
#                              FLOW_DISSECTOR_KEY_FLOW_LABEL           : 10 -> 11
#                              FLOW_DISSECTOR_KEY_GRE_KEYID            : 11 -> 12
#                              FLOW_DISSECTOR_KEY_ENC_IPV6_ADDRS       : 15 -> 16
#                              FLOW_DISSECTOR_KEY_CVLAN                : 21 -> 22
#                              FLOW_DISSECTOR_KEY_ENC_IPV4_ADDRS       : 14 -> 15
#                              FLOW_DISSECTOR_KEY_META                 : 24 -> 25
#                              FLOW_DISSECTOR_KEY_MPLS                 : 18 -> 19
#                              FLOW_DISSECTOR_KEY_MAX                  : 26 -> 27
#                              FLOW_DISSECTOR_KEY_TCP                  : 19 -> 20
#                              FLOW_DISSECTOR_KEY_ENC_OPTS             : 23 -> 24
#                              FLOW_DISSECTOR_KEY_MPLS_ENTROPY         : 12 -> 13
#                              FLOW_DISSECTOR_KEY_IP                   : 20 -> 21
#                              FLOW_DISSECTOR_KEY_ENC_PORTS            : 17 -> 18
#                              FLOW_DISSECTOR_KEY_VLAN                 : 9 -> 10
#                              FLOW_DISSECTOR_KEY_CT                   : 25 -> 26
#                              FLOW_DISSECTOR_KEY_TIPC                 : 7 -> 8
#                              FLOW_DISSECTOR_KEY_ENC_KEYID            : 13 -> 14
#                              FLOW_DISSECTOR_KEY_ICMP                 : 5 -> 6
#                              FLOW_DISSECTOR_KEY_ENC_IP               : 22 -> 23
# Kind.ENUM   perf_event_task_context
#                      Value changed:
#                              perf_invalid_context                    : -1 -> 18446744073709551615
# Kind.ENUM   fetch_op
#                      Added values:
#                              FETCH_OP_DATA                           : 9
#                      Value changed:
#                              FETCH_OP_LP_ARRAY                       : 17 -> 18
#                              FETCH_OP_END                            : 18 -> 19
#                              FETCH_OP_ST_STRING                      : 14 -> 15
#                              FETCH_OP_ST_USTRING                     : 15 -> 16
#                              FETCH_OP_ST_UMEM                        : 13 -> 14
#                              FETCH_OP_ST_RAW                         : 11 -> 12
#                              FETCH_OP_MOD_BF                         : 16 -> 17
#                              FETCH_OP_ST_MEM                         : 12 -> 13
#                              FETCH_NOP_SYMBOL                        : 19 -> 20
#                              FETCH_OP_UDEREF                         : 10 -> 11
#                              FETCH_OP_DEREF                          : 9 -> 10
# Kind.ENUM   fuse_parse_result
#                      Value changed:
#                              FOUND_ERR                               : -1 -> 18446744073709551615
# Kind.ENUM   flow_action_id
#                      Added values:
#                              FLOW_ACTION_MPLS_PUSH                   : 23
#                              FLOW_ACTION_MIRRED_INGRESS              : 7
#                              FLOW_ACTION_PTYPE                       : 17
#                              FLOW_ACTION_MPLS_POP                    : 24
#                              NUM_FLOW_ACTIONS                        : 26
#                              FLOW_ACTION_REDIRECT_INGRESS            : 6
#                              FLOW_ACTION_MPLS_MANGLE                 : 25
#                      Value changed:
#                              FLOW_ACTION_SAMPLE                      : 17 -> 20
#                              FLOW_ACTION_CSUM                        : 13 -> 15
#                              FLOW_ACTION_VLAN_MANGLE                 : 8 -> 10
#                              FLOW_ACTION_CT                          : 19 -> 22
#                              FLOW_ACTION_MARK                        : 14 -> 16
#                              FLOW_ACTION_TUNNEL_ENCAP                : 9 -> 11
#                              FLOW_ACTION_POLICE                      : 18 -> 21
#                              FLOW_ACTION_TUNNEL_DECAP                : 10 -> 12
#                              FLOW_ACTION_VLAN_POP                    : 7 -> 9
#                              FLOW_ACTION_VLAN_PUSH                   : 6 -> 8
#                              FLOW_ACTION_QUEUE                       : 16 -> 19
#                              FLOW_ACTION_MANGLE                      : 11 -> 13
#                              FLOW_ACTION_ADD                         : 12 -> 14
#                              FLOW_ACTION_WAKE                        : 15 -> 18
# Kind.ENUM   extra_reg_type
#                      Value changed:
#                              EXTRA_REG_NONE                          : -1 -> 18446744073709551615
# Kind.ENUM   devlink_command
#                      Added values:
#                              DEVLINK_CMD_TRAP_GROUP_DEL              : 68
#                              DEVLINK_CMD_TRAP_GROUP_GET              : 65
#                              DEVLINK_CMD_TRAP_GROUP_SET              : 66
#                              DEVLINK_CMD_TRAP_GET                    : 61
#                              DEVLINK_CMD_TRAP_DEL                    : 64
#                              DEVLINK_CMD_TRAP_NEW                    : 63
#                              DEVLINK_CMD_TRAP_GROUP_NEW              : 67
#                              DEVLINK_CMD_TRAP_SET                    : 62
#                      Value changed:
#                              __DEVLINK_CMD_MAX                       : 61 -> 69
#                              DEVLINK_CMD_MAX                         : 60 -> 68
# Kind.ENUM   nfs3_stable_how
#                      Value changed:
#                              NFS_INVALID_STABLE_HOW                  : -1 -> 18446744073709551615
# Kind.ENUM   fuse_req_flag
#                      Added values:
#                              FR_ASYNC                                : 11
# Kind.ENUM   shutdown_state
#                      Value changed:
#                              SHUTDOWN_INVALID                        : -1 -> 18446744073709551615
# Kind.ENUM   hrtimer_mode
#                      Added values:
#                              HRTIMER_MODE_HARD                       : 8
#                              HRTIMER_MODE_ABS_PINNED_HARD            : 10
#                              HRTIMER_MODE_REL_PINNED_HARD            : 11
#                              HRTIMER_MODE_ABS_HARD                   : 8
#                              HRTIMER_MODE_REL_HARD                   : 9
