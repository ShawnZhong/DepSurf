# %%
# !sudo apt install linux-tools-generic bpftool
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Note, selecting 'linux-tools-common' instead of 'bpftool'
# linux-tools-generic is already the newest version (6.2.0.39.39).
# linux-tools-common is already the newest version (6.2.0-39.40).
# 0 upgraded, 0 newly installed, 0 to remove and 0 not upgraded.

# %%
import os


def system(cmd):
    print(cmd)
    os.system(cmd)

# %%
from pathlib import Path

data_path = Path("data/ubuntu-18.04-x86")

# %%
def unzip_all(path, suffix=".tar.xz"):
    for file in path.glob(f"*{suffix}"):
        stem = file.name.removesuffix(suffix)
        result = path / stem
        if not result.exists():
            system(f"tar -xf {file} -C {path}")
        else:
            print(f"{result} already exists")


unzip_all(data_path)
# Out:
# data/ubuntu-18.04-x86/5.0.0-65-generic.btf already exists
# data/ubuntu-18.04-x86/4.18.0-25-generic.btf already exists
# data/ubuntu-18.04-x86/5.3.0-76-generic.btf already exists
# data/ubuntu-18.04-x86/4.15.0-213-generic.btf already exists
# data/ubuntu-18.04-x86/5.4.0-91-generic.btf already exists

# %%
def get_linux_tools_path():
    parent = Path("/usr/lib/linux-tools")
    versions = [x for x in parent.iterdir() if x.is_dir()]
    if len(versions) == 0:
        raise Exception("No linux-tools found")
    versions.sort()
    return parent / versions[-1]


def get_bpftool_path():
    path = get_linux_tools_path() / "bpftool"
    if not path.exists():
        raise Exception("bpftool not found")
    return path


bpftool_path = get_bpftool_path()

# %%
for file in data_path.glob("*.btf"):
    for ext, cmd in [(".h", "format c"), (".txt", "format raw"), (".json", "--json")]:
        result = file.with_suffix(ext)
        if not result.exists():
            system(f"{bpftool_path} btf dump file {file} {cmd} > {result}")
        else:
            print(f"{result} already exists")
# Out:
# data/ubuntu-18.04-x86/5.4.0-91-generic.h already exists
# data/ubuntu-18.04-x86/5.4.0-91-generic.txt already exists
# data/ubuntu-18.04-x86/5.4.0-91-generic.json already exists
# data/ubuntu-18.04-x86/5.0.0-65-generic.h already exists
# data/ubuntu-18.04-x86/5.0.0-65-generic.txt already exists
# data/ubuntu-18.04-x86/5.0.0-65-generic.json already exists
# data/ubuntu-18.04-x86/5.3.0-76-generic.h already exists
# data/ubuntu-18.04-x86/5.3.0-76-generic.txt already exists
# data/ubuntu-18.04-x86/5.3.0-76-generic.json already exists
# data/ubuntu-18.04-x86/4.15.0-213-generic.h already exists
# data/ubuntu-18.04-x86/4.15.0-213-generic.txt already exists
# data/ubuntu-18.04-x86/4.15.0-213-generic.json already exists
# data/ubuntu-18.04-x86/4.18.0-25-generic.h already exists
# data/ubuntu-18.04-x86/4.18.0-25-generic.txt already exists
# data/ubuntu-18.04-x86/4.18.0-25-generic.json already exists

# %%
json_paths = sorted(file for file in data_path.glob("*.json"))

json_paths
# Out:
# [PosixPath('data/ubuntu-18.04-x86/4.15.0-213-generic.json'),
#  PosixPath('data/ubuntu-18.04-x86/4.18.0-25-generic.json'),
#  PosixPath('data/ubuntu-18.04-x86/5.0.0-65-generic.json'),
#  PosixPath('data/ubuntu-18.04-x86/5.3.0-76-generic.json'),
#  PosixPath('data/ubuntu-18.04-x86/5.4.0-91-generic.json')]

# %%
import json


def load_json(json_path):
    with open(json_path) as f:
        return json.load(f)


jsons = [load_json(p) for p in json_paths]

# %%
from enum import Enum


class Kind(str, Enum):
    INT = "INT"
    PTR = "PTR"
    ARRAY = "ARRAY"
    STRUCT = "STRUCT"
    UNION = "UNION"
    ENUM = "ENUM"
    FWD = "FWD"
    TYPEDEF = "TYPEDEF"
    VOLATILE = "VOLATILE"
    CONST = "CONST"
    RESTRICT = "RESTRICT"
    FUNC = "FUNC"
    FUNC_PROTO = "FUNC_PROTO"
    VAR = "VAR"
    DATASEC = "DATASEC"
    FLOAT = "FLOAT"
    DECL_TAG = "DECL_TAG"
    TYPE_TAG = "TYPE_TAG"
    ENUM64 = "ENUM64"

# %%
import copy
from functools import cache


class BTF:
    def __init__(self, path, raw_data=None):
        self.path = path
        if raw_data is None:
            self._raw_data = load_json(path)['types']
        else:
            self._raw_data = raw_data['types']

    def __getitem__(self, id):
        if id == 0:
            return {'id': 0, 'name': 'void', 'kind': 'VOID'}
        e = self._raw_data[id - 1]
        assert e['id'] == id
        return e

    def __len__(self):
        return len(self._raw_data)

    def __iter__(self):
        return iter(self._raw_data)
    
    @property
    def short_name(self):
        return self.path.name.split("-")[0]

    def print(self):
        from collections import defaultdict

        print(f"File: {self.path}")

        print("Sample:")
        kinds = defaultdict(int)
        for e in self:
            if e['kind'] not in kinds:
                print(f"\t{e['id']:6} ({e['kind']:10}): {e}")
                print(f"\t{'':18}-> {self.normalize(e)}")
            kinds[e['kind']] += 1

        kinds = sorted(kinds.items(), key=lambda x: x[1], reverse=True)
        print(f"Kinds:")
        print(f"\t{dict(kinds)}")

        print()

    @cache
    def filter_on_kind(self, kind):
        return {
            e['name']: self.normalize(e) for e in self
            if e['kind'] == kind and e['name'] != '(anon)'
        }

    def get_by_kind_name(self, kind, name):
        return self.filter_on_kind(kind)[name]

    RECURSE_KINDS = {Kind.CONST, Kind.VOLATILE, Kind.RESTRICT,
                     Kind.PTR, Kind.FUNC, Kind.FUNC_PROTO, Kind.ARRAY}

    @cache
    def _normalize_sub_elem(self, type_id):
        elem = self[type_id]
        recurse = elem['kind'] in self.RECURSE_KINDS
        return self.normalize(elem, recurse=recurse)

    def normalize(self, elem, recurse=True):
        elem = copy.deepcopy(elem)

        # Remove redundant fields
        del elem['id']

        kind = elem['kind']
        if kind == Kind.INT:
            assert elem['bits_offset'] == 0
            del elem['bits_offset']
            del elem['encoding']
            del elem['nr_bits']
            del elem['size']
        elif kind == Kind.ARRAY:
            del elem['index_type_id']
        elif kind == Kind.ENUM:
            if not recurse:
                assert elem['vlen'] == len(elem['values'])
                del elem['values']
                del elem['vlen']
                del elem['encoding']
        elif kind == Kind.FUNC:
            assert elem['linkage'] == 'static'
            del elem['linkage']
        elif kind == Kind.PTR:
            assert elem['name'] == '(anon)'
            del elem['name']

        # Normalize types
        for type in ['type', 'ret_type']:
            type_id = f"{type}_id"

            if type_id not in elem:
                continue

            if recurse:
                elem[type] = self._normalize_sub_elem(elem[type_id])
            del elem[type_id]

        for list_key in ['params', 'members']:
            if list_key not in elem:
                continue

            assert len(elem[list_key]) == elem['vlen']
            del elem['vlen']

            if recurse:
                for item in elem[list_key]:
                    item['type'] = self._normalize_sub_elem(item['type_id'])
                    del item['type_id']
            else:
                del elem[list_key]
                if list_key == 'members':
                    del elem['size']

        return elem


d1 = BTF(json_paths[0])
d2 = BTF(json_paths[1])

# d1.print()

# d1.get_by_kind_name(Kind.STRUCT, "task_struct")
# d1.get_by_kind_name(Kind.STRUCT, "uprobe_task")
# d1.get_by_kind_name(Kind.FUNC, "vfs_read")

# %%
import sys

def print_as_list(name, s, num=10):
    print(f"{name} ({len(s)}): {list(s)[:num]}")


class FileLogger:
    def __init__(self, name):
        self.stdout = sys.stdout

        file_path = Path("output") / name
        file_path.parent.mkdir(parents=True, exist_ok=True)
        self.log = open(file_path, "w")

    def write(self, message):
        self.stdout.write(message)
        self.log.write(message)

    def __enter__(self):
        sys.stdout = self
        return self
    
    def __exit__(self, exc_type, exc_value, traceback):
        sys.stdout = self.stdout
        self.log.close()


def _check_diff(d_old, d_new, kind, diff):
    f_old = d_old.filter_on_kind(kind)
    f_new = d_new.filter_on_kind(kind)

    print_as_list(f"Old {kind}", f_old.keys())
    print_as_list(f"New {kind}", f_new.keys())

    print_as_list(f"Removed {kind}", f_old.keys() - f_new.keys())
    print_as_list(f"Added {kind}", f_new.keys() - f_old.keys())

    common = {
        name: (f_old[name], f_new[name])
        for name in f_old.keys() & f_new.keys()
    }
    print_as_list(f"Common {kind}", common.keys())

    changed = {
        name: (old, new)
        for name, (old, new) in common.items()
        if old != new
    }
    print_as_list(f"Changed {kind}", changed.keys())

    for name, (old, new) in changed.items():
        reason = diff(old, new)
        lines = reason.strip().split("\n")
        print(f"{kind:12}{name}")
        for line in lines:
            print(f"{'':20} {line}")


def check_diff(d_old, d_new, kind, diff):
    name = f"{d_old.short_name}-{d_new.short_name}-{kind.name}.txt"
    with FileLogger(name):
        _check_diff(d_old, d_new, kind, diff)

# %%
def diff_struct(old, new):
    result = ""

    old_members = {m['name']: m for m in old['members']}
    new_members = {m['name']: m for m in new['members']}

    # added field
    added_members = new_members.keys() - old_members.keys()
    if added_members:
        result += f"Added fields:\n"
        for name in added_members:
            result += f"{name:>20}: {new_members[name]['type']}\n"

    # removed field
    removed_members = old_members.keys() - new_members.keys()
    if removed_members:
        result += f"Removed fields:\n"
        for name in removed_members:
            result += f"{name:>20}: {old_members[name]['type']}\n"

    # fields reordered
    common = old_members.keys() & new_members.keys()
    if [n for n in old_members if n in common] != [n for n in new_members if n in common]:
        result += f"Fields reordered:\n"
        result += f"{'':>20} {list(old_members)}\n"
        result += f"{'':>20} {list(new_members)}\n"

    # fields changed type
    changed_types = {
        name: (old_members[name]['type'], new_members[name]['type'])
        for name in common
        if old_members[name]['type'] != new_members[name]['type']
    }
    if changed_types:
        result += "Field type changed:\n"
        for name, (old_type, new_type) in changed_types.items():
            result += f"{name:>20}: {old_type}\n"
            result += f"{'':>20}->{new_type}\n"

    # fields changed offset
    old_offset = {name: old_members[name]
                  ['bits_offset'] for name in old_members}
    new_offset = {name: new_members[name]
                  ['bits_offset'] for name in new_members}
    layout_changed = old_offset != new_offset or old['size'] != new['size']
    if layout_changed and result == "":
        result += f"Layout changed\n"

    assert result, f"\n{old}\n{new}"
    return result

check_diff(d1, d2, Kind.STRUCT, diff_struct)
# Out:
# Old Kind.STRUCT (7329): ['list_head', 'hlist_head', 'hlist_node', 'callback_head', 'jump_entry', 'static_key', 'static_key_true', 'static_key_false', 'file_operations', 'atomic_notifier_head']
# New Kind.STRUCT (8439): ['list_head', 'hlist_head', 'hlist_node', 'callback_head', 'file_system_type', 'jump_entry', 'static_key', 'static_key_true', 'static_key_false', 'file_operations']
# Removed Kind.STRUCT (272): ['blk_issue_stat', 'hotplug_slot_info', 'spi_flash_read_message', 'tpm_cmd_t', 'request_list', 'fuse_out', 'cpufreq_user_policy', 'dpc_rp_pio_regs', 'property_set', 'trace_event_data_offsets_bpf_map_delete_elem']
# Added Kind.STRUCT (1382): ['ib_dm_alloc_attr', 'mctrl_gpios', 'irq_bypass_producer', 'vfio_iommu', 'x86_perf_regs', 'cpuid_regs', 'cfg80211_pmsr_capabilities', 'xarray', 'fw_priv', 'sctp_globals']
# Common Kind.STRUCT (7057): ['rpc_version', 'config_s', 'ncsi_cmd_sp_pkt', 'aml_resource_spi_serialbus', 'ib_udata', 'nla_policy', 'trace_event_raw_mm_shrink_slab_start', 'clk_notifier', 'mmiotrace_rw', 'nf_dccp_net']
# Changed Kind.STRUCT (1293): ['nla_policy', 'trace_event_raw_mm_shrink_slab_start', 'nf_dccp_net', '__kernel_sockaddr_storage', 'powercap_zone', 'platform_s2idle_ops', 'cgroup_bpf', 'devlink_port', 'ipcm_cookie', 'kallsym_iter']
# Kind.STRUCT nla_policy
#                      Added fields:
#                                    (anon): {'kind': 'UNION', 'name': '(anon)'}
#                           validation_type: {'kind': 'TYPEDEF', 'name': 'u8'}
#                      Removed fields:
#                           validation_data: {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}
#                      Field type changed:
#                                      type: {'kind': 'TYPEDEF', 'name': 'u16'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'u8'}
# Kind.STRUCT trace_event_raw_mm_shrink_slab_start
#                      Added fields:
#                                  priority: {'kind': 'INT', 'name': 'int'}
#                      Removed fields:
#                                   lru_pgs: {'kind': 'INT', 'name': 'long unsigned int'}
#                               pgs_scanned: {'kind': 'INT', 'name': 'long unsigned int'}
# Kind.STRUCT nf_dccp_net
#                      Removed fields:
#                                        pn: {'kind': 'STRUCT', 'name': 'nf_proto_net'}
# Kind.STRUCT __kernel_sockaddr_storage
#                      Added fields:
#                                    (anon): {'kind': 'UNION', 'name': '(anon)'}
#                      Removed fields:
#                                 ss_family: {'kind': 'TYPEDEF', 'name': '__kernel_sa_family_t'}
#                                    __data: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 126, 'type': {'kind': 'INT', 'name': 'char'}}
# Kind.STRUCT powercap_zone
#                      Layout changed
# Kind.STRUCT platform_s2idle_ops
#                      Added fields:
#                             restore_early: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                              prepare_late: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                      Removed fields:
#                                      sync: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                      Field type changed:
#                                      wake: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [], 'ret_type': {'kind': 'TYPEDEF', 'name': 'bool'}}}
# Kind.STRUCT cgroup_bpf
#                      Added fields:
#                                    refcnt: {'kind': 'STRUCT', 'name': 'percpu_ref'}
#                              release_work: {'kind': 'STRUCT', 'name': 'work_struct'}
#                      Field type changed:
#                                     progs: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 7, 'type': {'kind': 'STRUCT', 'name': 'list_head'}}
#                                          ->{'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 23, 'type': {'kind': 'STRUCT', 'name': 'list_head'}}
#                                 effective: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 7, 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'bpf_prog_array'}}}
#                                          ->{'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 23, 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'bpf_prog_array'}}}
#                                     flags: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 7, 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}
#                                          ->{'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 23, 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}
# Kind.STRUCT devlink_port
#                      Added fields:
#                              type_warn_dw: {'kind': 'STRUCT', 'name': 'delayed_work'}
#                                     attrs: {'kind': 'STRUCT', 'name': 'devlink_port_attrs'}
#                                 type_lock: {'kind': 'TYPEDEF', 'name': 'spinlock_t'}
#                                param_list: {'kind': 'STRUCT', 'name': 'list_head'}
#                      Removed fields:
#                                     split: {'kind': 'TYPEDEF', 'name': 'bool'}
#                               split_group: {'kind': 'TYPEDEF', 'name': 'u32'}
# Kind.STRUCT ipcm_cookie
#                      Added fields:
#                                  gso_size: {'kind': 'TYPEDEF', 'name': '__u16'}
#                      Removed fields:
#                                  tx_flags: {'kind': 'TYPEDEF', 'name': '__u8'}
# Kind.STRUCT kallsym_iter
#                      Added fields:
#                              pos_arch_end: {'kind': 'TYPEDEF', 'name': 'loff_t'}
# Kind.STRUCT xen_netif_tx_sring
#                      Added fields:
#                                       pad: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 48, 'type': {'kind': 'TYPEDEF', 'name': 'uint8_t'}}
#                      Removed fields:
#                                     __pad: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 48, 'type': {'kind': 'TYPEDEF', 'name': 'uint8_t'}}
# Kind.STRUCT elevator_type
#                      Added fields:
#                         elevator_features: {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}
#                      Removed fields:
#                                   uses_mq: {'kind': 'TYPEDEF', 'name': 'bool'}
#                      Field type changed:
#                             elevator_name: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 16, 'type': {'kind': 'INT', 'name': 'char'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'INT', 'name': 'char'}}}
#                                       ops: {'kind': 'UNION', 'name': '(anon)'}
#                                          ->{'kind': 'STRUCT', 'name': 'elevator_mq_ops'}
# Kind.STRUCT ib_ah
#                      Added fields:
#                                 sgid_attr: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'ib_gid_attr'}}}
# Kind.STRUCT bsg_job
#                      Added fields:
#                                    result: {'kind': 'INT', 'name': 'int'}
#                      reply_payload_rcv_len: {'kind': 'INT', 'name': 'unsigned int'}
#                                   bidi_rq: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'request'}}
#                                  bidi_bio: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'bio'}}
#                                   timeout: {'kind': 'INT', 'name': 'unsigned int'}
#                      Removed fields:
#                                      sreq: {'kind': 'STRUCT', 'name': 'scsi_request'}
#                                       req: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'request'}}
# Kind.STRUCT compat_itimerval
#                      Field type changed:
#                                  it_value: {'kind': 'STRUCT', 'name': 'compat_timeval'}
#                                          ->{'kind': 'STRUCT', 'name': 'old_timeval32'}
#                               it_interval: {'kind': 'STRUCT', 'name': 'compat_timeval'}
#                                          ->{'kind': 'STRUCT', 'name': 'old_timeval32'}
# Kind.STRUCT rand_data
#                      Removed fields:
#                                     stuck: {'kind': 'INT', 'name': 'unsigned int'}
#                                      stir: {'kind': 'INT', 'name': 'unsigned int'}
#                            disable_unbias: {'kind': 'INT', 'name': 'unsigned int'}
# Kind.STRUCT pv_node
#                      Removed fields:
#                                     __res: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 3, 'type': {'kind': 'STRUCT', 'name': 'mcs_spinlock'}}
# Kind.STRUCT net_bridge_fdb_entry
#                      Added fields:
#                                    rhnode: {'kind': 'STRUCT', 'name': 'rhash_head'}
#                                       key: {'kind': 'STRUCT', 'name': 'net_bridge_fdb_key'}
#                                  fdb_node: {'kind': 'STRUCT', 'name': 'hlist_node'}
#                                 is_sticky: {'kind': 'INT', 'name': 'unsigned char'}
#                      Removed fields:
#                                      addr: {'kind': 'TYPEDEF', 'name': 'mac_addr'}
#                                     hlist: {'kind': 'STRUCT', 'name': 'hlist_node'}
#                                   vlan_id: {'kind': 'TYPEDEF', 'name': '__u16'}
# Kind.STRUCT kernfs_syscall_ops
#                      Removed fields:
#                                remount_fs: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kernfs_root'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'int'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'char'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
# Kind.STRUCT tracer
#                      Removed fields:
#                                       ref: {'kind': 'INT', 'name': 'int'}
# Kind.STRUCT usb_dev_state
#                      Added fields:
#                           not_yet_resumed: {'kind': 'INT', 'name': 'int'}
#                           wait_for_resume: {'kind': 'TYPEDEF', 'name': 'wait_queue_head_t'}
#                           suspend_allowed: {'kind': 'TYPEDEF', 'name': 'bool'}
#                      Removed fields:
#                                     secid: {'kind': 'TYPEDEF', 'name': 'u32'}
#                      Fields reordered:
#                                           ['list', 'dev', 'file', 'lock', 'async_pending', 'async_completed', 'memory_list', 'wait', 'discsignr', 'disc_pid', 'cred', 'disccontext', 'ifclaimed', 'secid', 'disabled_bulk_eps', 'privileges_dropped', 'interface_allowed_mask']
#                                           ['list', 'dev', 'file', 'lock', 'async_pending', 'async_completed', 'memory_list', 'wait', 'wait_for_resume', 'discsignr', 'disc_pid', 'cred', 'disccontext', 'ifclaimed', 'disabled_bulk_eps', 'interface_allowed_mask', 'not_yet_resumed', 'suspend_allowed', 'privileges_dropped']
#                      Field type changed:
#                               disccontext: {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}
#                                          ->{'kind': 'TYPEDEF', 'name': 'sigval_t'}
# Kind.STRUCT backing_dev_info
#                      Added fields:
#                                        id: {'kind': 'TYPEDEF', 'name': 'u64'}
#                                  dev_name: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 64, 'type': {'kind': 'INT', 'name': 'char'}}
#                                   rb_node: {'kind': 'STRUCT', 'name': 'rb_node'}
#                      Removed fields:
#                               debug_stats: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'dentry'}}
#                      Field type changed:
#                                 cgwb_tree: {'kind': 'STRUCT', 'name': 'radix_tree_root'}
#                                          ->{'kind': 'STRUCT', 'name': 'xarray'}
# Kind.STRUCT device_link
#                      Added fields:
#                      supplier_preactivated: {'kind': 'TYPEDEF', 'name': 'bool'}
#                                      kref: {'kind': 'STRUCT', 'name': 'kref'}
#                      Field type changed:
#                                rpm_active: {'kind': 'TYPEDEF', 'name': 'bool'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'refcount_t'}
# Kind.STRUCT tcp_iter_state
#                      Removed fields:
#                                    family: {'kind': 'TYPEDEF', 'name': 'sa_family_t'}
# Kind.STRUCT regmap_async_spi
#                      Layout changed
# Kind.STRUCT chv_community
#                      Field type changed:
#                                 functions: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'chv_function'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'intel_function'}}}
# Kind.STRUCT mmc_gpio
#                      Added fields:
#                      cd_debounce_delay_ms: {'kind': 'TYPEDEF', 'name': 'u32'}
#                      Removed fields:
#                      override_ro_active_level: {'kind': 'TYPEDEF', 'name': 'bool'}
#                      Field type changed:
#                                  cd_label: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 0, 'type': {'kind': 'INT', 'name': 'char'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'char'}}
# Kind.STRUCT clone_info
#                      Removed fields:
#                                        md: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'mapped_device'}}
# Kind.STRUCT i2c_adapter
#                      Added fields:
#                              locked_flags: {'kind': 'INT', 'name': 'long unsigned int'}
# Kind.STRUCT nd_device_driver
#                      Layout changed
# Kind.STRUCT fib_lookup_arg
#                      Added fields:
#                               lookup_data: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'name': 'void', 'kind': 'VOID'}}}
# Kind.STRUCT perf_sample_data
#                      Removed fields:
#                              sample_flags: {'kind': 'TYPEDEF', 'name': 'u64'}
# Kind.STRUCT dwc2_dregs_backup
#                      Added fields:
#                                   dtxfsiz: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 16, 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}
# Kind.STRUCT spi_driver
#                      Layout changed
# Kind.STRUCT boot_params
#                      Added fields:
#                            acpi_rsdp_addr: {'kind': 'TYPEDEF', 'name': '__u64'}
#                      Field type changed:
#                                     _pad3: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 16, 'type': {'kind': 'TYPEDEF', 'name': '__u8'}}
#                                          ->{'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 8, 'type': {'kind': 'TYPEDEF', 'name': '__u8'}}
# Kind.STRUCT tty_operations
#                      Added fields:
#                                 proc_show: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'seq_file'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                get_serial: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'tty_struct'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'serial_struct'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                set_serial: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'tty_struct'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'serial_struct'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                      Removed fields:
#                                 proc_fops: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'file_operations'}}}
# Kind.STRUCT gpio_irq_chip
#                      Added fields:
#                       child_offset_to_irq: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'gpio_chip'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}], 'ret_type': {'kind': 'INT', 'name': 'unsigned int'}}}
#                                   init_hw: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'gpio_chip'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                irq_enable: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'irq_data'}}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                             parent_domain: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'irq_domain'}}
#                      populate_parent_fwspec: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'gpio_chip'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'irq_fwspec'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                      child_to_parent_hwirq: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'gpio_chip'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'unsigned int'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'unsigned int'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                      child_irq_domain_ops: {'kind': 'STRUCT', 'name': 'irq_domain_ops'}
#                           init_valid_mask: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'gpio_chip'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'long unsigned int'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                                    fwnode: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fwnode_handle'}}
#                               irq_disable: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'irq_data'}}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                      Removed fields:
#                           need_valid_mask: {'kind': 'TYPEDEF', 'name': 'bool'}
#                                parent_irq: {'kind': 'INT', 'name': 'unsigned int'}
# Kind.STRUCT flow_dissector_key_vlan
#                      Added fields:
#                                 vlan_tpid: {'kind': 'TYPEDEF', 'name': '__be16'}
#                                  vlan_dei: {'kind': 'TYPEDEF', 'name': 'u16'}
#                      Removed fields:
#                                   padding: {'kind': 'TYPEDEF', 'name': 'u16'}
# Kind.STRUCT hd_struct
#                      Removed fields:
#                                 in_flight: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 2, 'type': {'kind': 'TYPEDEF', 'name': 'atomic_t'}}
# Kind.STRUCT lock_manager_operations
#                      Removed fields:
#                              lm_owner_key: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'file_lock'}}}], 'ret_type': {'kind': 'INT', 'name': 'long unsigned int'}}}
#                          lm_compare_owner: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'file_lock'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'file_lock'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
# Kind.STRUCT frag_queue
#                      Layout changed
# Kind.STRUCT platform_hibernation_ops
#                      Field type changed:
#                                     begin: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'pm_message_t'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
# Kind.STRUCT netdev_rx_queue
#                      Added fields:
#                                      umem: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'xdp_umem'}}
#                                   xdp_rxq: {'kind': 'STRUCT', 'name': 'xdp_rxq_info'}
# Kind.STRUCT mmu_gather
#                      Added fields:
#                                  vma_exec: {'kind': 'INT', 'name': 'unsigned int'}
#                              cleared_puds: {'kind': 'INT', 'name': 'unsigned int'}
#                              cleared_p4ds: {'kind': 'INT', 'name': 'unsigned int'}
#                              cleared_pmds: {'kind': 'INT', 'name': 'unsigned int'}
#                              cleared_ptes: {'kind': 'INT', 'name': 'unsigned int'}
#                              freed_tables: {'kind': 'INT', 'name': 'unsigned int'}
#                                  vma_huge: {'kind': 'INT', 'name': 'unsigned int'}
#                      Removed fields:
#                                 page_size: {'kind': 'INT', 'name': 'int'}
#                      Fields reordered:
#                                           ['mm', 'batch', 'start', 'end', 'fullmm', 'need_flush_all', 'active', 'local', '__pages', 'batch_count', 'page_size']
#                                           ['mm', 'batch', 'start', 'end', 'fullmm', 'need_flush_all', 'freed_tables', 'cleared_ptes', 'cleared_pmds', 'cleared_puds', 'cleared_p4ds', 'vma_exec', 'vma_huge', 'batch_count', 'active', 'local', '__pages']
# Kind.STRUCT cpuhp_cpu_state
#                      Removed fields:
#                               booted_once: {'kind': 'TYPEDEF', 'name': 'bool'}
# Kind.STRUCT cgroup_root
#                      Layout changed
# Kind.STRUCT lruvec_stat
#                      Field type changed:
#                                     count: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 28, 'type': {'kind': 'INT', 'name': 'long int'}}
#                                          ->{'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 32, 'type': {'kind': 'INT', 'name': 'long int'}}
# Kind.STRUCT pfifo_fast_priv
#                      Removed fields:
#                                    bitmap: {'kind': 'TYPEDEF', 'name': 'u32'}
#                      Field type changed:
#                                         q: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 3, 'type': {'kind': 'STRUCT', 'name': 'qdisc_skb_head'}}
#                                          ->{'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 3, 'type': {'kind': 'STRUCT', 'name': 'skb_array'}}
# Kind.STRUCT sync_pt
#                      Layout changed
# Kind.STRUCT evdev
#                      Layout changed
# Kind.STRUCT shash_alg
#                      Layout changed
# Kind.STRUCT blkcipher_alg
#                      Removed fields:
#                                     geniv: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'INT', 'name': 'char'}}}
# Kind.STRUCT trace_event_data_offsets_xhci_log_trb
#                      Added fields:
#                                       str: {'kind': 'TYPEDEF', 'name': 'u32'}
# Kind.STRUCT tcp_fastopen_context
#                      Added fields:
#                                       num: {'kind': 'INT', 'name': 'int'}
#                      Removed fields:
#                                       tfm: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'crypto_cipher'}}
#                      Field type changed:
#                                       key: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 16, 'type': {'kind': 'TYPEDEF', 'name': '__u8'}}
#                                          ->{'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 2, 'type': {'kind': 'TYPEDEF', 'name': 'siphash_key_t'}}
# Kind.STRUCT trace_event_raw_x86_fpu
#                      Added fields:
#                                  load_fpu: {'kind': 'TYPEDEF', 'name': 'bool'}
#                      Removed fields:
#                               initialized: {'kind': 'TYPEDEF', 'name': 'bool'}
# Kind.STRUCT intel_uncore_type
#                      Added fields:
#                                    (anon): {'kind': 'UNION', 'name': '(anon)'}
#                               freerunning: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'freerunning_counters'}}
#                      num_freerunning_types: {'kind': 'INT', 'name': 'int'}
#                      Removed fields:
#                                msr_offset: {'kind': 'INT', 'name': 'unsigned int'}
# Kind.STRUCT compat_rusage
#                      Field type changed:
#                                  ru_stime: {'kind': 'STRUCT', 'name': 'compat_timeval'}
#                                          ->{'kind': 'STRUCT', 'name': 'old_timeval32'}
#                                  ru_utime: {'kind': 'STRUCT', 'name': 'compat_timeval'}
#                                          ->{'kind': 'STRUCT', 'name': 'old_timeval32'}
# Kind.STRUCT irq_remap_table
#                      Field type changed:
#                                      lock: {'kind': 'TYPEDEF', 'name': 'spinlock_t'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'raw_spinlock_t'}
# Kind.STRUCT raw_sock
#                      Layout changed
# Kind.STRUCT trace_event_raw_fib_table_lookup
#                      Added fields:
#                           __data_loc_name: {'kind': 'TYPEDEF', 'name': 'u32'}
#                                       gw4: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 4, 'type': {'kind': 'TYPEDEF', 'name': '__u8'}}
#                                       err: {'kind': 'INT', 'name': 'int'}
#                                     dport: {'kind': 'TYPEDEF', 'name': 'u16'}
#                                       gw6: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 16, 'type': {'kind': 'TYPEDEF', 'name': '__u8'}}
#                                     proto: {'kind': 'TYPEDEF', 'name': 'u8'}
#                                     sport: {'kind': 'TYPEDEF', 'name': 'u16'}
# Kind.STRUCT macvlan_dev
#                      Added fields:
#                                accel_priv: {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}
#                      Removed fields:
#                                nest_level: {'kind': 'INT', 'name': 'int'}
#                                  fwd_priv: {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}
#                      Fields reordered:
#                                           ['dev', 'list', 'hlist', 'port', 'lowerdev', 'fwd_priv', 'pcpu_stats', 'mc_filter', 'set_features', 'mode', 'flags', 'nest_level', 'netpoll', 'macaddr_count']
#                                           ['dev', 'list', 'hlist', 'port', 'lowerdev', 'accel_priv', 'pcpu_stats', 'mc_filter', 'set_features', 'mode', 'flags', 'macaddr_count', 'netpoll']
# Kind.STRUCT stack_map_bucket
#                      Added fields:
#                                      data: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 0, 'type': {'kind': 'TYPEDEF', 'name': 'u64'}}
#                      Removed fields:
#                                        ip: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 0, 'type': {'kind': 'TYPEDEF', 'name': 'u64'}}
# Kind.STRUCT bpf_cpu_map_entry
#                      Added fields:
#                                      cmap: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'bpf_cpu_map'}}
# Kind.STRUCT key
#                      Layout changed
# Kind.STRUCT nvdimm_bus
#                      Layout changed
# Kind.STRUCT dax_operations
#                      Added fields:
#                              copy_to_iter: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'dax_device'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'long unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'size_t'}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'iov_iter'}}}], 'ret_type': {'kind': 'TYPEDEF', 'name': 'size_t'}}}
#                             dax_supported: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'dax_device'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'block_device'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'sector_t'}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'sector_t'}}], 'ret_type': {'kind': 'TYPEDEF', 'name': 'bool'}}}
# Kind.STRUCT max310x_port
#                      Removed fields:
#                                     mutex: {'kind': 'STRUCT', 'name': 'mutex'}
# Kind.STRUCT page
#                      Added fields:
#                                 _refcount: {'kind': 'TYPEDEF', 'name': 'atomic_t'}
# Kind.STRUCT firmware_work
#                      Field type changed:
#                                 opt_flags: {'kind': 'INT', 'name': 'unsigned int'}
#                                          ->{'kind': 'ENUM', 'name': 'fw_opt', 'size': 4}
# Kind.STRUCT ib_global_route
#                      Added fields:
#                                 sgid_attr: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'ib_gid_attr'}}}
# Kind.STRUCT regulator
#                      Added fields:
#                                   voltage: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 5, 'type': {'kind': 'STRUCT', 'name': 'regulator_voltage'}}
#                         deferred_disables: {'kind': 'INT', 'name': 'unsigned int'}
#                              enable_count: {'kind': 'INT', 'name': 'unsigned int'}
#                      Removed fields:
#                                    min_uV: {'kind': 'INT', 'name': 'int'}
#                                    max_uV: {'kind': 'INT', 'name': 'int'}
# Kind.STRUCT hstate
#                      Layout changed
# Kind.STRUCT powercap_control_type
#                      Layout changed
# Kind.STRUCT tpm_class_ops
#                      Field type changed:
#                           update_timeouts: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'tpm_chip'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'long unsigned int'}}}], 'ret_type': {'kind': 'TYPEDEF', 'name': 'bool'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'tpm_chip'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'long unsigned int'}}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
# Kind.STRUCT cpu_vfs_cap_data
#                      Added fields:
#                                    rootid: {'kind': 'TYPEDEF', 'name': 'kuid_t'}
# Kind.STRUCT cper_sec_pcie
#                      Field type changed:
#                                  reserved: {'kind': 'TYPEDEF', 'name': '__u32'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'u32'}
#                                capability: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 60, 'type': {'kind': 'TYPEDEF', 'name': '__u8'}}
#                                          ->{'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 60, 'type': {'kind': 'TYPEDEF', 'name': 'u8'}}
#                                 port_type: {'kind': 'TYPEDEF', 'name': '__u32'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'u32'}
#                                  aer_info: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 96, 'type': {'kind': 'TYPEDEF', 'name': '__u8'}}
#                                          ->{'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 96, 'type': {'kind': 'TYPEDEF', 'name': 'u8'}}
#                           validation_bits: {'kind': 'TYPEDEF', 'name': '__u64'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'u64'}
#                                   command: {'kind': 'TYPEDEF', 'name': '__u16'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'u16'}
#                                    status: {'kind': 'TYPEDEF', 'name': '__u16'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'u16'}
# Kind.STRUCT probe_arg
#                      Added fields:
#                                     count: {'kind': 'INT', 'name': 'unsigned int'}
#                                       fmt: {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'char'}}
#                                      code: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fetch_insn'}}
#                                   dynamic: {'kind': 'TYPEDEF', 'name': 'bool'}
#                      Removed fields:
#                                     fetch: {'kind': 'STRUCT', 'name': 'fetch_param'}
#                                fetch_size: {'kind': 'STRUCT', 'name': 'fetch_param'}
# Kind.STRUCT file_lock
#                      Added fields:
#                         fl_blocked_member: {'kind': 'STRUCT', 'name': 'list_head'}
#                                fl_blocker: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'file_lock'}}
#                       fl_blocked_requests: {'kind': 'STRUCT', 'name': 'list_head'}
#                      Removed fields:
#                                   fl_next: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'file_lock'}}
#                                  fl_block: {'kind': 'STRUCT', 'name': 'list_head'}
# Kind.STRUCT bpf_verifier_state_list
#                      Added fields:
#                                   hit_cnt: {'kind': 'INT', 'name': 'int'}
#                                  miss_cnt: {'kind': 'INT', 'name': 'int'}
# Kind.STRUCT fpu
#                      Added fields:
#                          avx512_timestamp: {'kind': 'INT', 'name': 'long unsigned int'}
#                      Removed fields:
#                               initialized: {'kind': 'INT', 'name': 'unsigned char'}
# Kind.STRUCT audit_names
#                      Layout changed
# Kind.STRUCT trace_event_raw_mm_vmscan_wakeup_kswapd
#                      Added fields:
#                                 gfp_flags: {'kind': 'TYPEDEF', 'name': 'gfp_t'}
# Kind.STRUCT opal_dev
#                      Removed fields:
#                                     steps: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'opal_step'}}}
#                      Field type changed:
#                                      resp: {'kind': 'PTR', 'type': {'kind': 'TYPEDEF', 'name': 'u8'}}
#                                          ->{'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 2048, 'type': {'kind': 'TYPEDEF', 'name': 'u8'}}
#                                       cmd: {'kind': 'PTR', 'type': {'kind': 'TYPEDEF', 'name': 'u8'}}
#                                          ->{'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 2048, 'type': {'kind': 'TYPEDEF', 'name': 'u8'}}
# Kind.STRUCT devlink_ops
#                      Added fields:
#                                 trap_fini: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'devlink_trap'}}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                                 reload_up: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'netlink_ext_ack'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                 trap_init: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'devlink_trap'}}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                  info_get: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink_info_req'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'netlink_ext_ack'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                           trap_group_init: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'devlink_trap_group'}}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                               reload_down: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'netlink_ext_ack'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                           trap_action_set: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'devlink_trap'}}}}, {'name': '(anon)', 'type': {'kind': 'ENUM', 'name': 'devlink_trap_action', 'size': 4}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                              flash_update: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'INT', 'name': 'char'}}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'INT', 'name': 'char'}}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'netlink_ext_ack'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                      Field type changed:
#                       sb_tc_pool_bind_set: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink_port'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u16'}}, {'name': '(anon)', 'type': {'kind': 'ENUM', 'name': 'devlink_sb_pool_type', 'size': 4}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u16'}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink_port'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u16'}}, {'name': '(anon)', 'type': {'kind': 'ENUM', 'name': 'devlink_sb_pool_type', 'size': 4}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u16'}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'netlink_ext_ack'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                          sb_port_pool_set: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink_port'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u16'}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink_port'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u16'}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'netlink_ext_ack'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                      eswitch_encap_mode_set: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink'}}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u8'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink'}}}, {'name': '(anon)', 'type': {'kind': 'ENUM', 'name': 'devlink_eswitch_encap_mode', 'size': 4}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'netlink_ext_ack'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                      eswitch_encap_mode_get: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'TYPEDEF', 'name': 'u8'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'ENUM', 'name': 'devlink_eswitch_encap_mode', 'size': 4}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                port_split: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'netlink_ext_ack'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                               sb_pool_set: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u16'}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}, {'name': '(anon)', 'type': {'kind': 'ENUM', 'name': 'devlink_sb_threshold_type', 'size': 4}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u16'}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}, {'name': '(anon)', 'type': {'kind': 'ENUM', 'name': 'devlink_sb_threshold_type', 'size': 4}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'netlink_ext_ack'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                              port_unsplit: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'netlink_ext_ack'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                          eswitch_mode_set: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink'}}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u16'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'devlink'}}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u16'}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'netlink_ext_ack'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
# ...
#                                      info: {'kind': 'TYPEDEF', 'name': 'siginfo_t'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'kernel_siginfo_t'}
# Kind.STRUCT fsnotify_iter_info
#                      Added fields:
#                               report_mask: {'kind': 'INT', 'name': 'unsigned int'}
#                                     marks: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 3, 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fsnotify_mark'}}}
#                      Removed fields:
#                             vfsmount_mark: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fsnotify_mark'}}
#                                inode_mark: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fsnotify_mark'}}
# Kind.STRUCT compat_shmid64_ds
#                      Added fields:
#                            shm_atime_high: {'kind': 'TYPEDEF', 'name': 'compat_ulong_t'}
#                            shm_dtime_high: {'kind': 'TYPEDEF', 'name': 'compat_ulong_t'}
#                            shm_ctime_high: {'kind': 'TYPEDEF', 'name': 'compat_ulong_t'}
#                      Removed fields:
#                                 __unused3: {'kind': 'TYPEDEF', 'name': 'compat_ulong_t'}
#                                 __unused2: {'kind': 'TYPEDEF', 'name': 'compat_ulong_t'}
#                                 __unused1: {'kind': 'TYPEDEF', 'name': 'compat_ulong_t'}
#                      Field type changed:
#                                 shm_dtime: {'kind': 'TYPEDEF', 'name': 'compat_time_t'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'compat_ulong_t'}
#                                 shm_ctime: {'kind': 'TYPEDEF', 'name': 'compat_time_t'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'compat_ulong_t'}
#                                 shm_atime: {'kind': 'TYPEDEF', 'name': 'compat_time_t'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'compat_ulong_t'}
# Kind.STRUCT blkif_sring
#                      Added fields:
#                                       pad: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 48, 'type': {'kind': 'TYPEDEF', 'name': 'uint8_t'}}
#                      Removed fields:
#                                     __pad: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 48, 'type': {'kind': 'TYPEDEF', 'name': 'uint8_t'}}
# Kind.STRUCT trace_event_raw_filelock_lease
#                      Added fields:
#                                fl_blocker: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'file_lock'}}
#                      Removed fields:
#                                   fl_next: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'file_lock'}}
# Kind.STRUCT worker
#                      Added fields:
#                                 last_func: {'kind': 'TYPEDEF', 'name': 'work_func_t'}
#                                  sleeping: {'kind': 'INT', 'name': 'int'}
#                      Removed fields:
#                                desc_valid: {'kind': 'TYPEDEF', 'name': 'bool'}
# Kind.STRUCT trace_event_raw_mm_vmscan_lru_shrink_inactive
#                      Added fields:
#                              nr_activate0: {'kind': 'INT', 'name': 'unsigned int'}
#                              nr_activate1: {'kind': 'INT', 'name': 'unsigned int'}
#                      Removed fields:
#                               nr_activate: {'kind': 'INT', 'name': 'long unsigned int'}
# Kind.STRUCT coredump_proc_event
#                      Added fields:
#                                parent_pid: {'kind': 'TYPEDEF', 'name': '__kernel_pid_t'}
#                               parent_tgid: {'kind': 'TYPEDEF', 'name': '__kernel_pid_t'}
# Kind.STRUCT filename
#                      Fields reordered:
#                                           ['name', 'uptr', 'aname', 'refcnt', 'iname']
#                                           ['name', 'uptr', 'refcnt', 'aname', 'iname']
# Kind.STRUCT efi_scratch
#                      Added fields:
#                                   prev_mm: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'mm_struct'}}
#                      Removed fields:
#                                       r15: {'kind': 'TYPEDEF', 'name': 'u64'}
#                                   use_pgd: {'kind': 'TYPEDEF', 'name': 'bool'}
#                                  prev_cr3: {'kind': 'TYPEDEF', 'name': 'u64'}
#                                   efi_pgt: {'kind': 'PTR', 'type': {'kind': 'TYPEDEF', 'name': 'pgd_t'}}
# Kind.STRUCT select_data
#                      Added fields:
#                                    (anon): {'kind': 'UNION', 'name': '(anon)'}
#                      Removed fields:
#                                     found: {'kind': 'INT', 'name': 'int'}
# Kind.STRUCT nfs_server
#                      Added fields:
#                                      cred: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'cred'}}}
#                                 ss_copies: {'kind': 'STRUCT', 'name': 'list_head'}
#                              read_hdrsize: {'kind': 'INT', 'name': 'unsigned int'}
# Kind.STRUCT inet_listen_hashbucket
#                      Added fields:
#                                     count: {'kind': 'INT', 'name': 'unsigned int'}
# Kind.STRUCT inet_frags
#                      Added fields:
#                                completion: {'kind': 'STRUCT', 'name': 'completion'}
#                                    refcnt: {'kind': 'TYPEDEF', 'name': 'refcount_t'}
# Kind.STRUCT elants_data
#                      Fields reordered:
#                                           ['client', 'input', 'vcc33', 'vccio', 'reset_gpio', 'fw_version', 'test_version', 'solution_version', 'bc_version', 'iap_version', 'hw_version', 'x_res', 'y_res', 'x_max', 'y_max', 'state', 'iap_mode', 'sysfs_mutex', 'cmd_resp', 'cmd_done', 'buf', 'wake_irq_enabled', 'keep_power_in_suspend']
#                                           ['client', 'input', 'vcc33', 'vccio', 'reset_gpio', 'fw_version', 'test_version', 'solution_version', 'bc_version', 'iap_version', 'hw_version', 'x_res', 'y_res', 'x_max', 'y_max', 'state', 'iap_mode', 'sysfs_mutex', 'cmd_resp', 'cmd_done', 'wake_irq_enabled', 'keep_power_in_suspend', 'buf']
# Kind.STRUCT amd_iommu
#                      Added fields:
#                           intcapxt_notify: {'kind': 'STRUCT', 'name': 'irq_affinity_notify'}
#                      Field type changed:
#                                      lock: {'kind': 'TYPEDEF', 'name': 'spinlock_t'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'raw_spinlock_t'}
# Kind.STRUCT reclaim_stat
#                      Field type changed:
#                               nr_activate: {'kind': 'INT', 'name': 'unsigned int'}
#                                          ->{'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 2, 'type': {'kind': 'INT', 'name': 'unsigned int'}}
# Kind.STRUCT policydb
#                      Added fields:
#                        type_val_to_struct: {'kind': 'PTR', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'type_datum'}}}
#                      Removed fields:
#                      type_val_to_struct_array: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'flex_array'}}
#                      Field type changed:
#                           sym_val_to_name: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 8, 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'flex_array'}}}
#                                          ->{'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 8, 'type': {'kind': 'PTR', 'type': {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'char'}}}}
#                       type_attr_map_array: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'flex_array'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'ebitmap'}}
# Kind.STRUCT pv_mmu_ops
#                      Added fields:
#                          tlb_remove_table: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'mmu_gather'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                      Fields reordered:
#                                           ['read_cr2', 'write_cr2', 'read_cr3', 'write_cr3', 'activate_mm', 'dup_mmap', 'exit_mmap', 'flush_tlb_user', 'flush_tlb_kernel', 'flush_tlb_one_user', 'flush_tlb_others', 'pgd_alloc', 'pgd_free', 'alloc_pte', 'alloc_pmd', 'alloc_pud', 'alloc_p4d', 'release_pte', 'release_pmd', 'release_pud', 'release_p4d', 'set_pte', 'set_pte_at', 'set_pmd', 'ptep_modify_prot_start', 'ptep_modify_prot_commit', 'pte_val', 'make_pte', 'pgd_val', 'make_pgd', 'set_pud', 'pmd_val', 'make_pmd', 'pud_val', 'make_pud', 'set_p4d', 'lazy_mode', 'set_fixmap']
#                                           ['flush_tlb_user', 'flush_tlb_kernel', 'flush_tlb_one_user', 'flush_tlb_others', 'tlb_remove_table', 'exit_mmap', 'read_cr2', 'write_cr2', 'read_cr3', 'write_cr3', 'activate_mm', 'dup_mmap', 'pgd_alloc', 'pgd_free', 'alloc_pte', 'alloc_pmd', 'alloc_pud', 'alloc_p4d', 'release_pte', 'release_pmd', 'release_pud', 'release_p4d', 'set_pte', 'set_pte_at', 'set_pmd', 'ptep_modify_prot_start', 'ptep_modify_prot_commit', 'pte_val', 'make_pte', 'pgd_val', 'make_pgd', 'set_pud', 'pmd_val', 'make_pmd', 'pud_val', 'make_pud', 'set_p4d', 'lazy_mode', 'set_fixmap']
#                      Field type changed:
#                      ptep_modify_prot_start: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'mm_struct'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'long unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'TYPEDEF', 'name': 'pte_t'}}}], 'ret_type': {'kind': 'TYPEDEF', 'name': 'pte_t'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'vm_area_struct'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'long unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'TYPEDEF', 'name': 'pte_t'}}}], 'ret_type': {'kind': 'TYPEDEF', 'name': 'pte_t'}}}
#                                  read_cr2: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [], 'ret_type': {'kind': 'INT', 'name': 'long unsigned int'}}}
#                                          ->{'kind': 'STRUCT', 'name': 'paravirt_callee_save'}
#                      ptep_modify_prot_commit: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'mm_struct'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'long unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'TYPEDEF', 'name': 'pte_t'}}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'pte_t'}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'vm_area_struct'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'long unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'TYPEDEF', 'name': 'pte_t'}}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'pte_t'}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
# Kind.STRUCT mii_bus
#                      Layout changed
# Kind.STRUCT tpm_tis_tcg_phy
#                      Layout changed
# Kind.STRUCT acpi_battery
#                      Added fields:
#                                      list: {'kind': 'STRUCT', 'name': 'list_head'}
# Kind.STRUCT sdesc
#                      Layout changed
# Kind.STRUCT dma_buf_ops
#                      Added fields:
#                         cache_sgt_mapping: {'kind': 'TYPEDEF', 'name': 'bool'}
#                      Removed fields:
#                                map_atomic: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'dma_buf'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'long unsigned int'}}], 'ret_type': {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}}}
#                              unmap_atomic: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'dma_buf'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'long unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                      Fields reordered:
#                                           ['attach', 'detach', 'map_dma_buf', 'unmap_dma_buf', 'release', 'begin_cpu_access', 'end_cpu_access', 'map_atomic', 'unmap_atomic', 'map', 'unmap', 'mmap', 'vmap', 'vunmap']
#                                           ['cache_sgt_mapping', 'attach', 'detach', 'map_dma_buf', 'unmap_dma_buf', 'release', 'begin_cpu_access', 'end_cpu_access', 'mmap', 'map', 'unmap', 'vmap', 'vunmap']
#                      Field type changed:
#                                    attach: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'dma_buf'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'dma_buf_attachment'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'dma_buf'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'dma_buf_attachment'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
# Kind.STRUCT pnp_card_driver
#                      Layout changed
# Kind.STRUCT fib_info
#                      Added fields:
#                                   nh_list: {'kind': 'STRUCT', 'name': 'list_head'}
#                              fib_nh_is_v6: {'kind': 'TYPEDEF', 'name': 'bool'}
#                                nh_updated: {'kind': 'TYPEDEF', 'name': 'bool'}
#                                        nh: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'nexthop'}}
# Kind.STRUCT cn_dev
#                      Removed fields:
#                                     input: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sk_buff'}}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
# Kind.STRUCT pci_host_bridge
#                      Added fields:
#                                native_aer: {'kind': 'INT', 'name': 'unsigned int'}
#                                native_ltr: {'kind': 'INT', 'name': 'unsigned int'}
#                                dma_ranges: {'kind': 'STRUCT', 'name': 'list_head'}
#                                native_pme: {'kind': 'INT', 'name': 'unsigned int'}
#                       native_shpc_hotplug: {'kind': 'INT', 'name': 'unsigned int'}
#                           preserve_config: {'kind': 'INT', 'name': 'unsigned int'}
#                       native_pcie_hotplug: {'kind': 'INT', 'name': 'unsigned int'}
# Kind.STRUCT tun_flow_entry
#                      Layout changed
# Kind.STRUCT ftrace_stack
#                      Field type changed:
#                                     calls: {'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 512, 'type': {'kind': 'INT', 'name': 'long unsigned int'}}
#                                          ->{'kind': 'ARRAY', 'name': '(anon)', 'nr_elems': 1024, 'type': {'kind': 'INT', 'name': 'long unsigned int'}}

# %%
check_diff(d1, d2, Kind.UNION, diff_struct)
# Out:
# Old Kind.UNION (99): ['fpregs_state', 'irq_stack_union', 'sigval', 'kernfs_node_id', 'key_payload', 'thread_union', 'perf_mem_data_src', 'flowi_uli', 'ethtool_flow_union', 'perf_capabilities']
# New Kind.UNION (126): ['fpregs_state', 'sigval', '__sifields', 'kernfs_node_id', 'thread_union', 'key_payload', 'perf_mem_data_src', 'bpf_attr', 'flowi_uli', 'ethtool_flow_union']
# Removed Kind.UNION (6): ['ipmi_smi_info_union', 'irq_stack_union', 'c', 'ec_response_get_next_data', 'fuse_dentry', 'tpm2_cmd_params']
# Added Kind.UNION (33): ['uvh_rh_gam_alias210_redirect_config_2_mmr_u', 'uvh_apicid', 'sidtab_entry_inner', 'hv_gpa_page_range', 'ec_response_get_next_data_v1', 'tls_crypto_context', 'uvh_rh_gam_config_mmr_u', 'uv1h_lb_target_physical_apic_id_mask_u', 'uv3h_gr0_gam_gr_config_u', 'bau_payload_header']
# Common Kind.UNION (93): ['tpacket_req_u', 'mon_data_bits', 'acpi_descriptor', 'irte_ga_lo', 'entry_union', 'hsw_tsx_tuning', 'l2_cache', 'tcp_cc_info', 'l3_cache', 'ftrace_code_union']
# Changed Kind.UNION (6): ['bpf_attr', 'security_list_options', 'thread_union', 'hdmi_infoframe', 'nested_table', 'nf_conntrack_proto']
# Kind.UNION  bpf_attr
#                      Added fields:
#                            raw_tracepoint: {'kind': 'STRUCT', 'name': '(anon)'}
#                             task_fd_query: {'kind': 'STRUCT', 'name': '(anon)'}
# Kind.UNION  security_list_options
#                      Added fields:
#                             sctp_sk_clone: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sctp_endpoint'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sock'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sock'}}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                        sctp_assoc_request: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sctp_endpoint'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sk_buff'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                           sb_eat_lsm_opts: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'char'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                               path_notify: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'path'}}}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u64'}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                            fs_context_dup: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fs_context'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fs_context'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                             cred_getsecid: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'cred'}}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                      fs_context_parse_param: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fs_context'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fs_parameter'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                         sctp_bind_connect: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sock'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sockaddr'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                         socket_socketpair: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'socket'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'socket'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                move_mount: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'path'}}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'path'}}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                               locked_down: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'ENUM', 'name': 'lockdown_reason', 'size': 4}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                          sb_free_mnt_opts: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                          lock_kernel_down: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'INT', 'name': 'char'}}}}, {'name': '(anon)', 'type': {'kind': 'ENUM', 'name': 'lockdown_reason', 'size': 4}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                          kernel_load_data: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'ENUM', 'name': 'kernel_load_data_id', 'size': 4}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                      kernfs_init_security: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kernfs_node'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kernfs_node'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                            sb_add_mnt_opt: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'INT', 'name': 'char'}}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'INT', 'name': 'char'}}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                      Removed fields:
#                              sb_copy_data: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'char'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'char'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                         sb_parse_opts_str: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'char'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'security_mnt_opts'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                      Field type changed:
#                        sem_alloc_security: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sem_array'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                             shm_associate: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'shmid_kernel'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                        shm_alloc_security: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'shmid_kernel'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                shm_shmctl: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'shmid_kernel'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                          audit_rule_match: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'audit_context'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                 shm_shmat: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'shmid_kernel'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'char'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'char'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                         sem_free_security: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sem_array'}}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                      msg_queue_alloc_security: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'msg_queue'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                 task_kill: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'task_struct'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'siginfo'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'task_struct'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kernel_siginfo'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'cred'}}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                          msg_queue_msgsnd: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'msg_queue'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'msg_msg'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'msg_msg'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                         shm_free_security: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'shmid_kernel'}}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                          msg_queue_msgctl: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'msg_queue'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                          msg_queue_msgrcv: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'msg_queue'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'msg_msg'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'task_struct'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'long int'}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'msg_msg'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'task_struct'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'long int'}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                   settime: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timezone'}}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timezone'}}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                       msg_queue_associate: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'msg_queue'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                      msg_queue_free_security: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'msg_queue'}}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
#                             sem_associate: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sem_array'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                 sem_semop: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sem_array'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sembuf'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sembuf'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                sem_semctl: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sem_array'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                           sb_set_mnt_opts: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'super_block'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'security_mnt_opts'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'long unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'long unsigned int'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'super_block'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'long unsigned int'}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'long unsigned int'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                             sb_kern_mount: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'super_block'}}}, {'name': '(anon)', 'type': {'kind': 'INT', 'name': 'int'}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'super_block'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                 file_open: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'file'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'cred'}}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'file'}}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
# Kind.UNION  thread_union
#                      Added fields:
#                                      task: {'kind': 'STRUCT', 'name': 'task_struct'}
# Kind.UNION  hdmi_infoframe
#                      Added fields:
#                                       drm: {'kind': 'STRUCT', 'name': 'hdmi_drm_infoframe'}
# Kind.UNION  nested_table
#                      Field type changed:
#                                    bucket: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'rhash_head'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'rhash_lock_head'}}
# Kind.UNION  nf_conntrack_proto
#                      Added fields:
#                                       udp: {'kind': 'STRUCT', 'name': 'nf_ct_udp'}

# %%
def diff_func(old, new):
    result = ""

    old_params = {p['name']: p for p in old['type']['params']}
    new_params = {p['name']: p for p in new['type']['params']}

    # params added
    added_params = new_params.keys() - old_params.keys()
    if added_params:
        result += f"Added params:\n"
        for name in added_params:
            result += f"{name:>20}: {new_params[name]['type']}\n"

    # params removed
    removed_params = old_params.keys() - new_params.keys()
    if removed_params:
        result += f"Removed params:\n"
        for name in removed_params:
            result += f"{name:>20}: {old_params[name]['type']}\n"

    # params reordered
    common = old_params.keys() & new_params.keys()
    if [n for n in old_params if n in common] != [n for n in new_params if n in common]:
        result += f"Params reordered:\n"
        result += f"{'':>20} {list(old_params)}\n"
        result += f"{'':>20} {list(new_params)}\n"

    # params changed type
    changed_types = {
        name: (old_params[name]['type'], new_params[name]['type'])
        for name in common
        if old_params[name]['type'] != new_params[name]['type']
    }
    if changed_types:
        result += "Param type changed:\n"
        for name, (old_type, new_type) in changed_types.items():
            result += f"{name:>20}: {old_type}\n"
            result += f"{'':>20}->{new_type}\n"

    # changed return value
    old_ret = old['type']['ret_type']
    new_ret = new['type']['ret_type']
    if old_ret != new_ret:
        result += f"Return type changed:\n"
        result += f"{'':>20}: {old_ret}\n"
        result += f"{'':>20}->{new_ret}\n"

    assert result, f"\n{old}\n{new}"
    return result

check_diff(d1, d2, Kind.FUNC, diff_func)
# Out:
# Old Kind.FUNC (42719): ['copy_bootdata', 'early_make_pgtable', 'reset_early_page_tables', '__startup_secondary_64', '__startup_64', 'x86_64_start_reservations', 'x86_64_start_kernel', '__early_make_pgtable', 'read_cr3_pa', 'clear_page']
# New Kind.FUNC (47961): ['copy_bootdata', 'early_make_pgtable', 'reset_early_page_tables', '__startup_secondary_64', '__startup_64', 'x86_64_start_reservations', 'x86_64_start_kernel', '__early_make_pgtable', 'read_cr3_pa', 'memcpy']
# Removed Kind.FUNC (3147): ['kiocb_free', 'device_private_entry_fault', 'SyS_setresgid16', 'nommu_sync_sg_for_device', 'SYSC_statfs64', 'seq_open_wireless', 'choose_lsm', 'smack_parse_opts_str', 'hpet_msi_set_periodic', 'cfqg_print_stat_recursive']
# Added Kind.FUNC (8389): ['rcu_core', 'nvmem_cell_read_u16', 'flow_rule_match_enc_ipv4_addrs', 'fuse_send_destroy', 'devlink_nl_cmd_dpipe_headers_get', 'topology_update_die_map', 'page_counter_set_min', 'exit_net_drop_monitor', 'mount_one_hugetlbfs', '__bpf_trace_global_dirty_state']
# Common Kind.FUNC (39572): ['pci_wch_ch355_setup', 'devtmpfsd', 'mark_hash_blacklisted', 'smack_inode_notifysecctx', 'ioread8', 'bio_put', 'hwrng_attr_current_store', 'ipv6_add_addr', 'tcp_cleanup_rbuf', 'key_schedule_gc']
# Changed Kind.FUNC (1755): ['ipv6_add_addr', 'proc_pid_instantiate', 'wp_page_copy', 'rt6_lookup', 'tracer_tracing_is_on', '__srcu_read_unlock', 'trace_event_raw_event_ext4_ext_remove_space_done', 'fib4_rule_configure', 'node_tag_clear', '_regulator_disable']
# Kind.FUNC   ipv6_add_addr
#                      Added params:
#                                       cfg: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'ifa6_config'}}
#                      Removed params:
#                                      addr: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'in6_addr'}}}
#                                 peer_addr: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'in6_addr'}}}
#                                     flags: {'kind': 'TYPEDEF', 'name': 'u32'}
#                              prefered_lft: {'kind': 'TYPEDEF', 'name': 'u32'}
#                                     scope: {'kind': 'INT', 'name': 'int'}
#                                    pfxlen: {'kind': 'INT', 'name': 'int'}
#                                 valid_lft: {'kind': 'TYPEDEF', 'name': 'u32'}
# Kind.FUNC   proc_pid_instantiate
#                      Removed params:
#                                       dir: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'inode'}}
#                      Return type changed:
#                                          : {'kind': 'INT', 'name': 'int'}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'dentry'}}
# Kind.FUNC   wp_page_copy
#                      Return type changed:
#                                          : {'kind': 'INT', 'name': 'int'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'vm_fault_t'}
# Kind.FUNC   rt6_lookup
#                      Added params:
#                                       skb: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'sk_buff'}}}
# Kind.FUNC   tracer_tracing_is_on
#                      Return type changed:
#                                          : {'kind': 'INT', 'name': 'int'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'bool'}
# Kind.FUNC   __srcu_read_unlock
#                      Added params:
#                                       ssp: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'srcu_struct'}}
#                      Removed params:
#                                        sp: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'srcu_struct'}}
# Kind.FUNC   trace_event_raw_event_ext4_ext_remove_space_done
#                      Added params:
#                                        pc: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'partial_cluster'}}
#                      Removed params:
#                                   partial: {'kind': 'INT', 'name': 'long long int'}
# Kind.FUNC   fib4_rule_configure
#                      Added params:
#                                    extack: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'netlink_ext_ack'}}
# Kind.FUNC   node_tag_clear
#                      Param type changed:
#                                      root: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'radix_tree_root'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'xarray'}}
#                                      node: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'radix_tree_node'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'xa_node'}}
# Kind.FUNC   _regulator_disable
#                      Added params:
#                                 regulator: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'regulator'}}
#                      Removed params:
#                                      rdev: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'regulator_dev'}}
# Kind.FUNC   dm_alloc_md_mempools
#                      Added params:
#                             min_pool_size: {'kind': 'INT', 'name': 'unsigned int'}
# Kind.FUNC   __next_mem_range_rev
#                      Param type changed:
#                                     flags: {'kind': 'TYPEDEF', 'name': 'ulong'}
#                                          ->{'kind': 'ENUM', 'name': 'memblock_flags', 'size': 4}
# Kind.FUNC   posix_cpu_timer_get
#                      Param type changed:
#                                       itp: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'itimerspec'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'itimerspec64'}}
# Kind.FUNC   mix_pool_bytes
#                      Added params:
#                                    nbytes: {'kind': 'INT', 'name': 'int'}
#                                         r: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'entropy_store'}}
#                                        in: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'name': 'void', 'kind': 'VOID'}}}
#                      Removed params:
#                                       len: {'kind': 'TYPEDEF', 'name': 'size_t'}
#                                       buf: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'name': 'void', 'kind': 'VOID'}}}
# Kind.FUNC   mls_compute_sid
#                      Added params:
#                                         p: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'policydb'}}
# Kind.FUNC   sem_init_ns
#                      Return type changed:
#                                          : {'kind': 'INT', 'name': 'int'}
#                                          ->{'name': 'void', 'kind': 'VOID'}
# Kind.FUNC   security_member_sid
#                      Added params:
#                                     state: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'selinux_state'}}
# Kind.FUNC   tcp_stream_memory_free
#                      Added params:
#                                      wake: {'kind': 'INT', 'name': 'int'}
# Kind.FUNC   secure_ipv6_port_ephemeral
#                      Return type changed:
#                                          : {'kind': 'TYPEDEF', 'name': 'u64'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'u32'}
# Kind.FUNC   perf_trace_timer_expire_entry
#                      Added params:
#                                   baseclk: {'kind': 'INT', 'name': 'long unsigned int'}
# Kind.FUNC   __ip6_route_redirect
#                      Added params:
#                                       skb: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'sk_buff'}}}
# Kind.FUNC   ps2_sendbyte
#                      Param type changed:
#                                   timeout: {'kind': 'INT', 'name': 'int'}
#                                          ->{'kind': 'INT', 'name': 'unsigned int'}
#                                      byte: {'kind': 'INT', 'name': 'unsigned char'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'u8'}
# Kind.FUNC   fsnotify_add_mark_locked
#                      Added params:
#                                      fsid: {'kind': 'PTR', 'type': {'kind': 'TYPEDEF', 'name': '__kernel_fsid_t'}}
#                                      type: {'kind': 'INT', 'name': 'unsigned int'}
#                                     connp: {'kind': 'PTR', 'type': {'kind': 'TYPEDEF', 'name': 'fsnotify_connp_t'}}
#                      Removed params:
#                                     inode: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'inode'}}
#                                       mnt: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'vfsmount'}}
# Kind.FUNC   __find_interface
#                      Param type changed:
#                                      data: {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'name': 'void', 'kind': 'VOID'}}}
# Kind.FUNC   do_mpage_readpage
#                      Added params:
#                                      args: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'mpage_readpage_args'}}
#                      Removed params:
#                                  nr_pages: {'kind': 'INT', 'name': 'unsigned int'}
#                         last_block_in_bio: {'kind': 'PTR', 'type': {'kind': 'TYPEDEF', 'name': 'sector_t'}}
#                                       gfp: {'kind': 'TYPEDEF', 'name': 'gfp_t'}
#                       first_logical_block: {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'long unsigned int'}}
#                                       bio: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'bio'}}
#                                      page: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'page'}}
#                                    map_bh: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'buffer_head'}}
#                                 get_block: {'kind': 'PTR', 'type': {'kind': 'TYPEDEF', 'name': 'get_block_t'}}
# Kind.FUNC   port_fops_poll
#                      Return type changed:
#                                          : {'kind': 'INT', 'name': 'unsigned int'}
#                                          ->{'kind': 'TYPEDEF', 'name': '__poll_t'}
# Kind.FUNC   acpi_hibernation_begin_old
#                      Added params:
#                                     stage: {'kind': 'TYPEDEF', 'name': 'pm_message_t'}
# Kind.FUNC   fscrypt_alloc_bounce_page
#                      Removed params:
#                                       ctx: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fscrypt_ctx'}}
# Kind.FUNC   timekeeping_inject_offset
#                      Param type changed:
#                                        ts: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}}
# Kind.FUNC   udplite_err
#                      Return type changed:
#                                          : {'name': 'void', 'kind': 'VOID'}
#                                          ->{'kind': 'INT', 'name': 'int'}
# Kind.FUNC   bpf_prog_array_delete_safe
#                      Added params:
#                                     array: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'bpf_prog_array'}}
#                      Removed params:
#                                     progs: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'bpf_prog_array'}}
# Kind.FUNC   nanosleep_copyout
#                      Param type changed:
#                                        ts: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}
# Kind.FUNC   event_triggers_call
#                      Added params:
#                                     event: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'ring_buffer_event'}}
# Kind.FUNC   cpuidle_select
#                      Added params:
#                                 stop_tick: {'kind': 'PTR', 'type': {'kind': 'TYPEDEF', 'name': 'bool'}}
# Kind.FUNC   _enable_swap_info
#                      Removed params:
#                                      prio: {'kind': 'INT', 'name': 'int'}
#                                  swap_map: {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'unsigned char'}}
#                              cluster_info: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'swap_cluster_info'}}
# Kind.FUNC   evm_calc_hmac
#                      Added params:
#                                      data: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'evm_digest'}}
#                      Removed params:
#                                    digest: {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'char'}}
# Kind.FUNC   audit_kill_trees
#                      Added params:
#                                   context: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'audit_context'}}
#                      Removed params:
#                                      list: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'list_head'}}
# Kind.FUNC   get_xsave_field_ptr
#                      Added params:
#                               xfeature_nr: {'kind': 'INT', 'name': 'int'}
#                      Removed params:
#                               xsave_state: {'kind': 'INT', 'name': 'int'}
# Kind.FUNC   posix_cpu_clock_set
#                      Added params:
#                                     clock: {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'clockid_t'}}
#                      Removed params:
#                               which_clock: {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'clockid_t'}}
#                      Param type changed:
#                                        tp: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}}
# Kind.FUNC   find_exception
#                      Added params:
#                                       nhc: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fib_nh_common'}}
#                      Removed params:
#                                        nh: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fib_nh'}}
# Kind.FUNC   _regmap_raw_write
#                      Added params:
#                                     noinc: {'kind': 'TYPEDEF', 'name': 'bool'}
# Kind.FUNC   do_io_getevents
#                      Param type changed:
#                                        ts: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}
# Kind.FUNC   add_hwgenerator_randomness
#                      Added params:
#                                    buffer: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'INT', 'name': 'char'}}}
#                                     count: {'kind': 'TYPEDEF', 'name': 'size_t'}
#                      Removed params:
#                                       len: {'kind': 'TYPEDEF', 'name': 'size_t'}
#                                       buf: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'name': 'void', 'kind': 'VOID'}}}
# Kind.FUNC   vdso_fault
#                      Return type changed:
#                                          : {'kind': 'INT', 'name': 'int'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'vm_fault_t'}
# Kind.FUNC   gpiod_set_raw_array_value_cansleep
#                      Added params:
#                              value_bitmap: {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'long unsigned int'}}
#                                array_info: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'gpio_array'}}
#                      Removed params:
#                               value_array: {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'int'}}
#                      Return type changed:
#                                          : {'name': 'void', 'kind': 'VOID'}
#                                          ->{'kind': 'INT', 'name': 'int'}
# Kind.FUNC   posix_cpu_clock_getres
#                      Param type changed:
#                                        tp: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}
# Kind.FUNC   rt_cache_route
#                      Added params:
#                                       nhc: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fib_nh_common'}}
#                      Removed params:
#                                        nh: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fib_nh'}}
# Kind.FUNC   __iommu_unmap
#                      Added params:
#                              iotlb_gather: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'iommu_iotlb_gather'}}
#                      Removed params:
#                                      sync: {'kind': 'TYPEDEF', 'name': 'bool'}
# Kind.FUNC   pciehp_check_link_active
#                      Return type changed:
#                                          : {'kind': 'TYPEDEF', 'name': 'bool'}
#                                          ->{'kind': 'INT', 'name': 'int'}
# Kind.FUNC   tpm2_get_random
#                      Added params:
#                                      dest: {'kind': 'PTR', 'type': {'kind': 'TYPEDEF', 'name': 'u8'}}
#                      Removed params:
#                                       out: {'kind': 'PTR', 'type': {'kind': 'TYPEDEF', 'name': 'u8'}}
# Kind.FUNC   trace_event_raw_event_cgroup
#                      Added params:
#                                      path: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'INT', 'name': 'char'}}}
# Kind.FUNC   pciehp_disable_slot
#                      Added params:
#                                      ctrl: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'controller'}}
#                              safe_removal: {'kind': 'TYPEDEF', 'name': 'bool'}
#                      Removed params:
#                                    p_slot: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'slot'}}
# Kind.FUNC   start_isolate_page_range
#                      Added params:
#                                     flags: {'kind': 'INT', 'name': 'int'}
#                      Removed params:
#                      skip_hwpoisoned_pages: {'kind': 'TYPEDEF', 'name': 'bool'}
# Kind.FUNC   fanotify_alloc_event
#                      Added params:
#                                      fsid: {'kind': 'PTR', 'type': {'kind': 'TYPEDEF', 'name': '__kernel_fsid_t'}}
#                                 data_type: {'kind': 'INT', 'name': 'int'}
#                                     group: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fsnotify_group'}}
#                                      data: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'name': 'void', 'kind': 'VOID'}}}
#                      Removed params:
#                                      path: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'path'}}}
#                      Return type changed:
#                                          : {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fanotify_event_info'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fanotify_event'}}
# Kind.FUNC   test_aperfmperf
#                      Added params:
#                                      data: {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}
# Kind.FUNC   bsg_setup_queue
#                      Added params:
#                                   timeout: {'kind': 'PTR', 'type': {'kind': 'TYPEDEF', 'name': 'bsg_timeout_fn'}}
#                      Removed params:
#                                   release: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device'}}}], 'ret_type': {'name': 'void', 'kind': 'VOID'}}}
# Kind.FUNC   migrate_task_rq_dl
#                      Added params:
#                                   new_cpu: {'kind': 'INT', 'name': 'int'}
# Kind.FUNC   xfrm_unregister_type_offload
#                      Return type changed:
#                                          : {'kind': 'INT', 'name': 'int'}
#                                          ->{'name': 'void', 'kind': 'VOID'}
# Kind.FUNC   ps2_handle_ack
#                      Param type changed:
#                                      data: {'kind': 'INT', 'name': 'unsigned char'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'u8'}
#                      Return type changed:
#                                          : {'kind': 'INT', 'name': 'int'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'bool'}
# Kind.FUNC   pci_reset_bus
#                      Added params:
#                                      pdev: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'pci_dev'}}
#                      Removed params:
#                                       bus: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'pci_bus'}}
# Kind.FUNC   gpiod_get_array_value
#                      Added params:
#                              value_bitmap: {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'long unsigned int'}}
#                                array_info: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'gpio_array'}}
#                      Removed params:
#                               value_array: {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'int'}}
# Kind.FUNC   probe_event_enable
#                      Added params:
#                                      call: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'trace_event_call'}}
#                      Removed params:
#                                        tu: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'trace_uprobe'}}
# Kind.FUNC   security_context_to_sid_force
#                      Added params:
#                                     state: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'selinux_state'}}
# Kind.FUNC   stacktrace_count_trigger
#                      Added params:
#                                     event: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'ring_buffer_event'}}
# Kind.FUNC   init_rootfs
#                      Return type changed:
#                                          : {'kind': 'INT', 'name': 'int'}
#                                          ->{'name': 'void', 'kind': 'VOID'}
# Kind.FUNC   is_branch_taken
#                      Added params:
#                                  is_jmp32: {'kind': 'TYPEDEF', 'name': 'bool'}
# Kind.FUNC   xen_efi_init
#                      Added params:
#                               boot_params: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'boot_params'}}
# Kind.FUNC   inet6_rt_notify
#                      Param type changed:
#                                        rt: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'rt6_info'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fib6_info'}}
# Kind.FUNC   radix_tree_iter_tag_clear
#                      Param type changed:
#                                      root: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'radix_tree_root'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'xarray'}}
# Kind.FUNC   validate_xmit_skb
#                      Added params:
#                                     again: {'kind': 'PTR', 'type': {'kind': 'TYPEDEF', 'name': 'bool'}}
# Kind.FUNC   security_sb_remount
#                      Added params:
#                                  mnt_opts: {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}
#                      Removed params:
#                                      data: {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}
# Kind.FUNC   nvmem_cell_get
#                      Added params:
#                                        id: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'INT', 'name': 'char'}}}
#                      Removed params:
#                                   cell_id: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'INT', 'name': 'char'}}}
# Kind.FUNC   bpf_sock_map_update
#                      Added params:
#                                      sops: {'kind': 'TYPEDEF', 'name': 'u64'}
#                      Removed params:
#                                  bpf_sock: {'kind': 'TYPEDEF', 'name': 'u64'}
# Kind.FUNC   bad_area_nosemaphore
#                      Removed params:
#                                      pkey: {'kind': 'PTR', 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}
# Kind.FUNC   proc_ns_instantiate
#                      Removed params:
#                                       dir: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'inode'}}
#                      Return type changed:
#                                          : {'kind': 'INT', 'name': 'int'}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'dentry'}}
# Kind.FUNC   security_set_bools
#                      Added params:
#                                     state: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'selinux_state'}}
# Kind.FUNC   fuse_file_poll
#                      Return type changed:
#                                          : {'kind': 'INT', 'name': 'unsigned int'}
#                                          ->{'kind': 'TYPEDEF', 'name': '__poll_t'}
# Kind.FUNC   pagevec_lookup_range_tag
#                      Param type changed:
#                                       tag: {'kind': 'INT', 'name': 'int'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'xa_mark_t'}
# Kind.FUNC   ip6mr_rule_configure
#                      Added params:
#                                    extack: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'netlink_ext_ack'}}
# Kind.FUNC   tpm2_pcr_extend
#                      Removed params:
#                                     count: {'kind': 'TYPEDEF', 'name': 'u32'}
#                      Param type changed:
#                                   pcr_idx: {'kind': 'INT', 'name': 'int'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'u32'}
#                                   digests: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'tpm2_digest'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'tpm_digest'}}
# Kind.FUNC   shrink_page_list
#                      Added params:
#                         ignore_references: {'kind': 'TYPEDEF', 'name': 'bool'}
#                      Removed params:
#                             force_reclaim: {'kind': 'TYPEDEF', 'name': 'bool'}
# Kind.FUNC   dns_query
#                      Added params:
#                                       net: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'net'}}
#                                invalidate: {'kind': 'TYPEDEF', 'name': 'bool'}
# Kind.FUNC   jiffies_to_timespec64
#                      Param type changed:
#                                     value: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}
# Kind.FUNC   sk_filter_func_proto
#                      Added params:
#                                      prog: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'bpf_prog'}}}
# Kind.FUNC   udp_err
#                      Return type changed:
#                                          : {'name': 'void', 'kind': 'VOID'}
#                                          ->{'kind': 'INT', 'name': 'int'}
# Kind.FUNC   ip6mr_cache_unresolved
#                      Added params:
#                                       dev: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'net_device'}}
#                      Param type changed:
#                                       mrt: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'mr6_table'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'mr_table'}}
# Kind.FUNC   __scsi_queue_insert
#                      Param type changed:
#                                    unbusy: {'kind': 'INT', 'name': 'int'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'bool'}
# Kind.FUNC   poll_select_set_timeout
#                      Param type changed:
#                                        to: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}
# Kind.FUNC   emulate_vsyscall
#                      Added params:
#                                error_code: {'kind': 'INT', 'name': 'long unsigned int'}
# Kind.FUNC   avc_ss_reset
#                      Added params:
#                                       avc: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'selinux_avc'}}
# Kind.FUNC   __ip6_del_rt
#                      Param type changed:
#                                        rt: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'rt6_info'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fib6_info'}}
# Kind.FUNC   xfrm4_ipcomp_err
#                      Return type changed:
#                                          : {'name': 'void', 'kind': 'VOID'}
#                                          ->{'kind': 'INT', 'name': 'int'}
# Kind.FUNC   radix_tree_next_chunk
#                      Param type changed:
#                                      root: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'radix_tree_root'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'xarray'}}}
# Kind.FUNC   padata_alloc_pd
#                      Added params:
#                                        ps: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'padata_shell'}}
#                      Removed params:
#                                 cbcpumask: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'cpumask'}}}
#                                     pinst: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'padata_instance'}}
#                                  pcpumask: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'cpumask'}}}
# Kind.FUNC   radix_tree_iter_replace
#                      Param type changed:
#                                      root: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'radix_tree_root'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'xarray'}}
# Kind.FUNC   ksize
#                      Added params:
#                                      objp: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'name': 'void', 'kind': 'VOID'}}}
#                      Removed params:
#                                    object: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'name': 'void', 'kind': 'VOID'}}}
# Kind.FUNC   init_srcu_struct_fields
#                      Added params:
#                                       ssp: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'srcu_struct'}}
#                      Removed params:
#                                        sp: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'srcu_struct'}}
# Kind.FUNC   fuse_fsync_common
#                      Added params:
#                                    opcode: {'kind': 'INT', 'name': 'int'}
#                      Removed params:
#                                     isdir: {'kind': 'INT', 'name': 'int'}
# Kind.FUNC   fname_encrypt
#                      Added params:
#                                      olen: {'kind': 'INT', 'name': 'unsigned int'}
#                                       out: {'kind': 'PTR', 'type': {'kind': 'TYPEDEF', 'name': 'u8'}}
#                      Removed params:
#                                     oname: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fscrypt_str'}}
# Kind.FUNC   __nf_unregister_net_hook
#                      Added params:
#                                        pf: {'kind': 'INT', 'name': 'int'}
#                                       net: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'net'}}
#                                       reg: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'nf_hook_ops'}}}
#                      Removed params:
#                                       old: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'nf_hook_entries'}}
#                                     unreg: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'nf_hook_ops'}}}
# Kind.FUNC   audit_tree_destroy_watch
#                      Added params:
#                                      mark: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fsnotify_mark'}}
#                      Removed params:
#                                     entry: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fsnotify_mark'}}
# Kind.FUNC   pci_epc_set_msi
#                      Added params:
#                                   func_no: {'kind': 'TYPEDEF', 'name': 'u8'}
# Kind.FUNC   packet_getname
#                      Removed params:
#                                 uaddr_len: {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'int'}}
# Kind.FUNC   smack_audit_rule_match
#                      Removed params:
#                                      actx: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'audit_context'}}
# Kind.FUNC   mif6_delete
#                      Param type changed:
#                                       mrt: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'mr6_table'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'mr_table'}}
# Kind.FUNC   security_netlbl_sid_to_secattr
#                      Added params:
#                                     state: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'selinux_state'}}
# Kind.FUNC   call_fib6_entry_notifiers
#                      Param type changed:
#                                        rt: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'rt6_info'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fib6_info'}}
# Kind.FUNC   hist_field_s8
#                      Added params:
#                                       elt: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'tracing_map_elt'}}
#                                       rbe: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'ring_buffer_event'}}
# Kind.FUNC   generic_load_microcode
#                      Added params:
#                                      iter: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'iov_iter'}}
#                      Removed params:
#                                      data: {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}
#                                      size: {'kind': 'TYPEDEF', 'name': 'size_t'}
#                            get_ucode_data: {'kind': 'PTR', 'type': {'kind': 'FUNC_PROTO', 'name': '(anon)', 'params': [{'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}}, {'name': '(anon)', 'type': {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'name': 'void', 'kind': 'VOID'}}}}, {'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'size_t'}}], 'ret_type': {'kind': 'INT', 'name': 'int'}}}
# Kind.FUNC   kprobe_on_func_entry
#                      Return type changed:
#                                          : {'kind': 'TYPEDEF', 'name': 'bool'}
#                                          ->{'kind': 'INT', 'name': 'int'}
# Kind.FUNC   selinux_msg_queue_msgctl
#                      Param type changed:
#                                       msq: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'msg_queue'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}
# Kind.FUNC   intel_pstate_verify_policy
#                      Param type changed:
#                                    policy: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'cpufreq_policy'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'cpufreq_policy_data'}}
# Kind.FUNC   phy_device_create
#                      Param type changed:
#                                    phy_id: {'kind': 'INT', 'name': 'int'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'u32'}
# Kind.FUNC   eventfd_poll
#                      Return type changed:
#                                          : {'kind': 'INT', 'name': 'unsigned int'}
#                                          ->{'kind': 'TYPEDEF', 'name': '__poll_t'}
# Kind.FUNC   hmm_invalidate_range_end
#                      Added params:
#                                    nrange: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'mmu_notifier_range'}}}
#                      Removed params:
#                                        mm: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'mm_struct'}}
#                                     start: {'kind': 'INT', 'name': 'long unsigned int'}
#                                       end: {'kind': 'INT', 'name': 'long unsigned int'}
# Kind.FUNC   send_sigqueue
#                      Added params:
#                                       pid: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'pid'}}
#                                      type: {'kind': 'ENUM', 'name': 'pid_type', 'size': 4}
#                      Removed params:
#                                         t: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'task_struct'}}
#                                     group: {'kind': 'INT', 'name': 'int'}
# Kind.FUNC   __netdev_has_upper_dev
#                      Added params:
#                                       dev: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'net_device'}}
#                      Removed params:
#                                      data: {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}
#                      Return type changed:
#                                          : {'kind': 'INT', 'name': 'int'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'bool'}
# Kind.FUNC   fanotify_handle_event
#                      Removed params:
#                             fanotify_mark: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fsnotify_mark'}}
#                                inode_mark: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fsnotify_mark'}}
#                      Param type changed:
#                                 file_name: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'INT', 'name': 'unsigned char'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'qstr'}}}
# Kind.FUNC   compaction_alloc
#                      Removed params:
#                                    result: {'kind': 'PTR', 'type': {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'int'}}}
# Kind.FUNC   ip6_pol_route_lookup
#                      Added params:
#                                       skb: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'sk_buff'}}}
# Kind.FUNC   traceoff_trigger
#                      Added params:
#                                     event: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'ring_buffer_event'}}
# Kind.FUNC   tpm_is_tpm2
#                      Added params:
#                                      chip: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'tpm_chip'}}
#                      Removed params:
#                                  chip_num: {'kind': 'TYPEDEF', 'name': 'u32'}
# Kind.FUNC   secpath_set
#                      Return type changed:
#                                          : {'kind': 'INT', 'name': 'int'}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'sec_path'}}
# Kind.FUNC   pci_epc_map_addr
#                      Added params:
#                                   func_no: {'kind': 'TYPEDEF', 'name': 'u8'}
# Kind.FUNC   msi_setup_entry
#                      Param type changed:
#                                      affd: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'irq_affinity'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'irq_affinity'}}
# Kind.FUNC   oom_badness
#                      Removed params:
#                                  nodemask: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'TYPEDEF', 'name': 'nodemask_t'}}}
#                                     memcg: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'mem_cgroup'}}
#                      Return type changed:
#                                          : {'kind': 'INT', 'name': 'long unsigned int'}
#                                          ->{'kind': 'INT', 'name': 'long int'}
# Kind.FUNC   hdmi_infoframe_unpack
#                      Added params:
#                                      size: {'kind': 'TYPEDEF', 'name': 'size_t'}
#                      Param type changed:
#                                    buffer: {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'name': 'void', 'kind': 'VOID'}}}
# Kind.FUNC   pci_epf_alloc_space
#                      Added params:
#                                     align: {'kind': 'TYPEDEF', 'name': 'size_t'}
# Kind.FUNC   disable_trace_kprobe
#                      Added params:
#                                      call: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'trace_event_call'}}
#                      Removed params:
#                                        tk: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'trace_kprobe'}}
# Kind.FUNC   klp_shadow_free
#                      Added params:
#                                      dtor: {'kind': 'TYPEDEF', 'name': 'klp_shadow_dtor_t'}
# Kind.FUNC   hpet_poll
#                      Return type changed:
#                                          : {'kind': 'INT', 'name': 'unsigned int'}
#                                          ->{'kind': 'TYPEDEF', 'name': '__poll_t'}
# Kind.FUNC   display_to_var
#                      Param type changed:
#                                      disp: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'display'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fbcon_display'}}
# Kind.FUNC   ptrace_stop
#                      Param type changed:
#                                      info: {'kind': 'PTR', 'type': {'kind': 'TYPEDEF', 'name': 'siginfo_t'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'TYPEDEF', 'name': 'kernel_siginfo_t'}}
# Kind.FUNC   call_switchdev_notifiers
#                      Added params:
#                                    extack: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'netlink_ext_ack'}}
# Kind.FUNC   alloc_dax
#                      Added params:
#                                     flags: {'kind': 'INT', 'name': 'long unsigned int'}
# Kind.FUNC   security_load_policy
#                      Added params:
#                                     state: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'selinux_state'}}
# Kind.FUNC   do_mq_timedsend
#                      Param type changed:
#                                        ts: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}
# Kind.FUNC   show_status
#                      Added params:
#                                      kobj: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kobject'}}
#                      Removed params:
#                                       dev: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device'}}
#                      Param type changed:
#                                      attr: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device_attribute'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kobj_attribute'}}
# Kind.FUNC   do_timerfd_settime
#                      Param type changed:
#                                       new: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'itimerspec'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'itimerspec64'}}}
#                                       old: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'itimerspec'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'itimerspec64'}}
# Kind.FUNC   proc_map_files_instantiate
#                      Removed params:
#                                       dir: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'inode'}}
#                      Return type changed:
#                                          : {'kind': 'INT', 'name': 'int'}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'dentry'}}
# Kind.FUNC   xhci_endpoint_reset
#                      Added params:
#                                   host_ep: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'usb_host_endpoint'}}
#                      Removed params:
#                                        ep: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'usb_host_endpoint'}}
# Kind.FUNC   bpf_prog_load
#                      Added params:
#                                     uattr: {'kind': 'PTR', 'type': {'kind': 'UNION', 'name': 'bpf_attr'}}
# Kind.FUNC   ipmr_do_expire_process
#                      Param type changed:
#                                       mrt: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'mr6_table'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'mr_table'}}
# Kind.FUNC   ptype_get_idx
#                      Removed params:
#                                       seq: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'seq_file'}}
# Kind.FUNC   ata_scsi_ioctl
#                      Param type changed:
#                                       cmd: {'kind': 'INT', 'name': 'int'}
#                                          ->{'kind': 'INT', 'name': 'unsigned int'}
# Kind.FUNC   xen_swiotlb_sync_single_for_device
#                      Added params:
#                                       dev: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device'}}
#                                  dma_addr: {'kind': 'TYPEDEF', 'name': 'dma_addr_t'}
#                      Removed params:
#                                  dev_addr: {'kind': 'TYPEDEF', 'name': 'dma_addr_t'}
#                                     hwdev: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device'}}
# Kind.FUNC   reuseport_attach_prog
#                      Return type changed:
#                                          : {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'bpf_prog'}}
#                                          ->{'kind': 'INT', 'name': 'int'}
# Kind.FUNC   mm_fault_error
#                      Removed params:
#                                      pkey: {'kind': 'PTR', 'type': {'kind': 'TYPEDEF', 'name': 'u32'}}
#                      Param type changed:
#                                     fault: {'kind': 'INT', 'name': 'unsigned int'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'vm_fault_t'}
# ...
# Kind.FUNC   selinux_msg_queue_alloc_security
#                      Param type changed:
#                                       msq: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'msg_queue'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}
# Kind.FUNC   fib_sync_up
#                      Param type changed:
#                                  nh_flags: {'kind': 'INT', 'name': 'unsigned int'}
#                                          ->{'kind': 'INT', 'name': 'unsigned char'}
# Kind.FUNC   ata_host_release
#                      Added params:
#                                      kref: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kref'}}
#                      Removed params:
#                                       res: {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}
#                                    gendev: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device'}}
# Kind.FUNC   tcf_block_get
#                      Added params:
#                                    extack: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'netlink_ext_ack'}}
# Kind.FUNC   insert_pfn
#                      Return type changed:
#                                          : {'kind': 'INT', 'name': 'int'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'vm_fault_t'}
# Kind.FUNC   __skb_recv_udp
#                      Removed params:
#                                    peeked: {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'int'}}
# Kind.FUNC   rcu_exp_wait_wake
#                      Removed params:
#                                       rsp: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'rcu_state'}}
# Kind.FUNC   try_check_zero
#                      Added params:
#                                       ssp: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'srcu_struct'}}
#                      Removed params:
#                                        sp: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'srcu_struct'}}
# Kind.FUNC   scsi_dev_info_list_del_keyed
#                      Param type changed:
#                                       key: {'kind': 'INT', 'name': 'int'}
#                                          ->{'kind': 'ENUM', 'name': 'scsi_devinfo_key', 'size': 4}
# Kind.FUNC   proc_register
#                      Return type changed:
#                                          : {'kind': 'INT', 'name': 'int'}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'proc_dir_entry'}}
# Kind.FUNC   serial8250_get_divisor
#                      Added params:
#                                      port: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'uart_port'}}
#                      Removed params:
#                                        up: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'uart_8250_port'}}
# Kind.FUNC   swiotlb_tbl_unmap_single
#                      Added params:
#                              mapping_size: {'kind': 'TYPEDEF', 'name': 'size_t'}
#                                alloc_size: {'kind': 'TYPEDEF', 'name': 'size_t'}
#                      Removed params:
#                                      size: {'kind': 'TYPEDEF', 'name': 'size_t'}
# Kind.FUNC   rcu_barrier_func
#                      Added params:
#                                    unused: {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}
#                      Removed params:
#                                      type: {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}
# Kind.FUNC   kvm_set_wallclock
#                      Param type changed:
#                                       now: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'timespec64'}}}
# Kind.FUNC   mls_setup_user_range
#                      Added params:
#                                         p: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'policydb'}}
# Kind.FUNC   bpf_check
#                      Added params:
#                                     uattr: {'kind': 'PTR', 'type': {'kind': 'UNION', 'name': 'bpf_attr'}}
# Kind.FUNC   rcu_gp_kthread
#                      Added params:
#                                    unused: {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}
#                      Removed params:
#                                       arg: {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}
# Kind.FUNC   nohz_balance_exit_idle
#                      Added params:
#                                        rq: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'rq'}}
#                      Removed params:
#                                       cpu: {'kind': 'INT', 'name': 'unsigned int'}
# Kind.FUNC   scsi_end_request
#                      Removed params:
#                                bidi_bytes: {'kind': 'INT', 'name': 'unsigned int'}
# Kind.FUNC   init_memory_block
#                      Param type changed:
#                                  block_id: {'kind': 'INT', 'name': 'int'}
#                                          ->{'kind': 'INT', 'name': 'long unsigned int'}
# Kind.FUNC   cmp_name
#                      Added params:
#                                       sym: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'name': 'void', 'kind': 'VOID'}}}
#                                      name: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'name': 'void', 'kind': 'VOID'}}}
#                      Removed params:
#                                        vb: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'name': 'void', 'kind': 'VOID'}}}
#                                        va: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'name': 'void', 'kind': 'VOID'}}}
# Kind.FUNC   memblock_alloc_try_nid
#                      Added params:
#                                  min_addr: {'kind': 'TYPEDEF', 'name': 'phys_addr_t'}
#                                  max_addr: {'kind': 'TYPEDEF', 'name': 'phys_addr_t'}
#                      Return type changed:
#                                          : {'kind': 'TYPEDEF', 'name': 'phys_addr_t'}
#                                          ->{'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}
# Kind.FUNC   thermal_of_cooling_device_register
#                      Param type changed:
#                                      type: {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'char'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'INT', 'name': 'char'}}}
# Kind.FUNC   shrink_slab
#                      Added params:
#                                  priority: {'kind': 'INT', 'name': 'int'}
#                      Removed params:
#                               nr_eligible: {'kind': 'INT', 'name': 'long unsigned int'}
#                                nr_scanned: {'kind': 'INT', 'name': 'long unsigned int'}
# Kind.FUNC   vga_arb_fpoll
#                      Return type changed:
#                                          : {'kind': 'INT', 'name': 'unsigned int'}
#                                          ->{'kind': 'TYPEDEF', 'name': '__poll_t'}
# Kind.FUNC   create_boot_cache
#                      Added params:
#                                  usersize: {'kind': 'INT', 'name': 'unsigned int'}
#                                useroffset: {'kind': 'INT', 'name': 'unsigned int'}
#                      Param type changed:
#                                      size: {'kind': 'TYPEDEF', 'name': 'size_t'}
#                                          ->{'kind': 'INT', 'name': 'unsigned int'}
# Kind.FUNC   security_bounded_transition
#                      Added params:
#                                     state: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'selinux_state'}}
# Kind.FUNC   squashfs_read_xattr_id_table
#                      Param type changed:
#                                 xattr_ids: {'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'unsigned int'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'INT', 'name': 'int'}}
# Kind.FUNC   save_error_info
#                      Added params:
#                                     block: {'kind': 'TYPEDEF', 'name': '__u64'}
#                                     error: {'kind': 'INT', 'name': 'int'}
#                                       ino: {'kind': 'TYPEDEF', 'name': '__u32'}
# Kind.FUNC   fixup_exception
#                      Added params:
#                                error_code: {'kind': 'INT', 'name': 'long unsigned int'}
#                                fault_addr: {'kind': 'INT', 'name': 'long unsigned int'}
# Kind.FUNC   address_val
#                      Added params:
#                                      spec: {'kind': 'STRUCT', 'name': 'printf_spec'}
# Kind.FUNC   rt6_fill_node
#                      Added params:
#                                      dest: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'in6_addr'}}
#                      Param type changed:
#                                        rt: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'rt6_info'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fib6_info'}}
#                                       dst: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'in6_addr'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'dst_entry'}}
# Kind.FUNC   rcu_dump_cpu_stacks
#                      Removed params:
#                                       rsp: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'rcu_state'}}
# Kind.FUNC   update_fast_timekeeper
#                      Param type changed:
#                                       tkr: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'tk_read_base'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'tk_read_base'}}}
# Kind.FUNC   __pci_disable_link_state
#                      Return type changed:
#                                          : {'name': 'void', 'kind': 'VOID'}
#                                          ->{'kind': 'INT', 'name': 'int'}
# Kind.FUNC   __map_bio
#                      Return type changed:
#                                          : {'name': 'void', 'kind': 'VOID'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'blk_qc_t'}
# Kind.FUNC   mmap_vmcore_fault
#                      Return type changed:
#                                          : {'kind': 'INT', 'name': 'int'}
#                                          ->{'kind': 'TYPEDEF', 'name': 'vm_fault_t'}
# Kind.FUNC   radix_tree_lookup_slot
#                      Param type changed:
#                                      root: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'radix_tree_root'}}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'xarray'}}}
# Kind.FUNC   noqueue_init
#                      Added params:
#                                    extack: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'netlink_ext_ack'}}
# Kind.FUNC   intel_iommu_enable_pasid
#                      Added params:
#                                       dev: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'device'}}
#                      Removed params:
#                                      sdev: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'intel_svm_dev'}}
# Kind.FUNC   __dev_map_lookup_elem
#                      Return type changed:
#                                          : {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'net_device'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'bpf_dtab_netdev'}}
# Kind.FUNC   dev_validate_mtu
#                      Added params:
#                                    extack: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'netlink_ext_ack'}}
# Kind.FUNC   ghes_copy_tofrom_phys
#                      Added params:
#                                fixmap_idx: {'kind': 'ENUM', 'name': 'fixed_addresses', 'size': 4}
# Kind.FUNC   ip_rt_ioctl
#                      Added params:
#                                        rt: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'rtentry'}}
#                      Removed params:
#                                       arg: {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}
# Kind.FUNC   hist_field_s16
#                      Added params:
#                                       elt: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'tracing_map_elt'}}
#                                       rbe: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'ring_buffer_event'}}
# Kind.FUNC   selinux_shm_alloc_security
#                      Param type changed:
#                                       shp: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'shmid_kernel'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'kern_ipc_perm'}}
# Kind.FUNC   hugetlbfs_fill_super
#                      Added params:
#                                        fc: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fs_context'}}
#                      Removed params:
#                                      data: {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}
#                                    silent: {'kind': 'INT', 'name': 'int'}
# Kind.FUNC   security_load_policycaps
#                      Added params:
#                                     state: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'selinux_state'}}
# Kind.FUNC   crng_reseed
#                      Added params:
#                                      crng: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'crng_state'}}
#                                         r: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'entropy_store'}}
# Kind.FUNC   proc_reg_poll
#                      Return type changed:
#                                          : {'kind': 'INT', 'name': 'unsigned int'}
#                                          ->{'kind': 'TYPEDEF', 'name': '__poll_t'}
# Kind.FUNC   xen_online_page
#                      Added params:
#                                     order: {'kind': 'INT', 'name': 'unsigned int'}
# Kind.FUNC   fuse_ctl_fill_super
#                      Added params:
#                                      fctx: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'fs_context'}}
#                      Removed params:
#                                      data: {'kind': 'PTR', 'type': {'name': 'void', 'kind': 'VOID'}}
#                                    silent: {'kind': 'INT', 'name': 'int'}
# Kind.FUNC   delete_node
#                      Removed params:
#                               update_node: {'kind': 'TYPEDEF', 'name': 'radix_tree_update_node_t'}
#                      Param type changed:
#                                      root: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'radix_tree_root'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'xarray'}}
#                                      node: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'radix_tree_node'}}
#                                          ->{'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'xa_node'}}
# Kind.FUNC   avc_policy_seqno
#                      Added params:
#                                     state: {'kind': 'PTR', 'type': {'kind': 'STRUCT', 'name': 'selinux_state'}}
# Kind.FUNC   zap_vma_ptes
#                      Return type changed:
#                                          : {'kind': 'INT', 'name': 'int'}
#                                          ->{'name': 'void', 'kind': 'VOID'}
# Kind.FUNC   do_dentry_open
#                      Removed params:
#                                      cred: {'kind': 'PTR', 'type': {'kind': 'CONST', 'name': '(anon)', 'type': {'kind': 'STRUCT', 'name': 'cred'}}}

# %%
def diff_enum(old, new):
    result = ""

    old_values = {v['name']: v for v in old['values']}
    new_values = {v['name']: v for v in new['values']}

    # added value
    added_values = new_values.keys() - old_values.keys()
    if added_values:
        result += f"Added values:\n"
        for name in added_values:
            result += f"{'':8}{name:40}: {new_values[name]['val']}\n"

    # removed value
    removed_values = old_values.keys() - new_values.keys()
    if removed_values:
        result += f"Removed values:\n"
        for name in removed_values:
            result += f"{'':8}{name:40}: {old_values[name]['val']}\n"

    # values changed
    common = old_values.keys() & new_values.keys()
    changed_values = {
        name: (old_values[name]['val'], new_values[name]['val'])
        for name in common
        if old_values[name]['val'] != new_values[name]['val']
    }
    if changed_values:
        result += "Value changed:\n"
        for name, (old_val, new_val) in changed_values.items():
            result += f"{'':8}{name:40}: {old_val} -> {new_val}\n"

    assert result, f"\n{old}\n{new}"

    return result

check_diff(d1, d2, Kind.ENUM, diff_enum)
# Out:
# Old Kind.ENUM (979): ['system_states', 'timespec_type', 'x86_hardware_subarch', 'l1tf_mitigations', 'x86_legacy_i8042_state', 'xen_domain_type', 'fixed_addresses', 'apic_intr_mode_id', 'pcpu_fc', 'numa_stat_item']
# New Kind.ENUM (1178): ['system_states', 'timespec_type', 'x86_hardware_subarch', 'l1tf_mitigations', 'x86_legacy_i8042_state', 'fixed_addresses', 'uprobe_task_state', 'apic_intr_mode_id', 'pcpu_fc', 'numa_stat_item']
# Removed Kind.ENUM (35): ['smap_psock_state', 'move_type', 'skein_size', 'threefish_size', 'evdev_clock_type', 'retbleed_mitigation', 'rcu_sync_type', 'qlock_stats', 'wl_type_t', 'rdma_remove_reason']
# Added Kind.ENUM (234): ['opal_mbr_done_flag', 'devlink_dpipe_header_id', 'ioc_running', 'switch_power_state', 'backlight_scale', 'action_id', 'ib_uverbs_write_cmds', 'kernel_load_data_id', 'futex_access', 'hdmi_metadata_type']
# Common Kind.ENUM (944): ['audit_nlgrps', 'tg_state_flags', 'devkmsg_log_bits', 'cgroup_filetype', 'tcp_queue', 'ib_sig_type', 'ec_led_colors', 'req_opf', 'actions', 'tomoyo_memory_stat_type']
# Changed Kind.ENUM (130): ['ec_led_colors', 'req_opf', 'wbt_flags', 'cppc_regs', 'hash_algo', 'crypto_attr_type_t', 'iommu_resv_type', 'hwmon_power_attributes', 'of_gpio_flags', 'mf_action_page_type']
# Kind.ENUM   ec_led_colors
#                      Added values:
#                              EC_LED_COLOR_AMBER                      : 5
#                      Value changed:
#                              EC_LED_COLOR_COUNT                      : 5 -> 6
# Kind.ENUM   req_opf
#                      Added values:
#                              REQ_OP_ZONE_RESET_ALL                   : 8
#                      Removed values:
#                              REQ_OP_ZONE_REPORT                      : 4
# Kind.ENUM   wbt_flags
#                      Added values:
#                              WBT_DISCARD                             : 8
#                      Value changed:
#                              WBT_NR_BITS                             : 3 -> 4
# Kind.ENUM   cppc_regs
#                      Added values:
#                              LOWEST_FREQ                             : 19
#                              NOMINAL_FREQ                            : 20
# Kind.ENUM   hash_algo
#                      Added values:
#                              HASH_ALGO_STREEBOG_512                  : 19
#                              HASH_ALGO_STREEBOG_256                  : 18
#                      Value changed:
#                              HASH_ALGO__LAST                         : 18 -> 20
# Kind.ENUM   crypto_attr_type_t
#                      Added values:
#                              CRYPTOCFGA_STAT_HASH                    : 13
#                              CRYPTOCFGA_STAT_BLKCIPHER               : 14
#                              CRYPTOCFGA_STAT_ACOMP                   : 21
#                              CRYPTOCFGA_STAT_CIPHER                  : 18
#                              CRYPTOCFGA_STAT_KPP                     : 20
#                              CRYPTOCFGA_STAT_AEAD                    : 15
#                              CRYPTOCFGA_STAT_AKCIPHER                : 19
#                              CRYPTOCFGA_STAT_COMPRESS                : 16
#                              CRYPTOCFGA_STAT_LARVAL                  : 12
#                              CRYPTOCFGA_STAT_RNG                     : 17
#                      Value changed:
#                              __CRYPTOCFGA_MAX                        : 12 -> 22
# Kind.ENUM   iommu_resv_type
#                      Added values:
#                              IOMMU_RESV_DIRECT_RELAXABLE             : 1
#                      Value changed:
#                              IOMMU_RESV_SW_MSI                       : 3 -> 4
#                              IOMMU_RESV_RESERVED                     : 1 -> 2
#                              IOMMU_RESV_MSI                          : 2 -> 3
# Kind.ENUM   hwmon_power_attributes
#                      Added values:
#                              hwmon_power_lcrit                       : 20
#                              hwmon_power_min                         : 17
#                              hwmon_power_min_alarm                   : 24
#                              hwmon_power_lcrit_alarm                 : 26
#                      Value changed:
#                              hwmon_power_max_alarm                   : 22 -> 25
#                              hwmon_power_alarm                       : 20 -> 22
#                              hwmon_power_label                       : 19 -> 21
#                              hwmon_power_crit_alarm                  : 23 -> 27
#                              hwmon_power_max                         : 17 -> 18
#                              hwmon_power_cap_alarm                   : 21 -> 23
#                              hwmon_power_crit                        : 18 -> 19
# Kind.ENUM   of_gpio_flags
#                      Added values:
#                              OF_GPIO_TRANSITORY                      : 8
#                              OF_GPIO_PULL_UP                         : 16
#                              OF_GPIO_PULL_DOWN                       : 32
#                      Removed values:
#                              OF_GPIO_SLEEP_MAY_LOSE_VALUE            : 8
# Kind.ENUM   mf_action_page_type
#                      Added values:
#                              MF_MSG_DAX                              : 20
#                      Value changed:
#                              MF_MSG_UNKNOWN                          : 20 -> 21
# Kind.ENUM   netdev_priv_flags
#                      Added values:
#                              IFF_FAILOVER_SLAVE                      : 268435456
#                              IFF_NO_RX_HANDLER                       : 67108864
#                              IFF_FAILOVER                            : 134217728
#                              IFF_LIVE_RENAME_OK                      : 1073741824
#                      Removed values:
#                              IFF_IPVLAN_MASTER                       : 262144
#                              IFF_IPVLAN_SLAVE                        : 524288
#                      Value changed:
#                              IFF_MACSEC                              : 134217728 -> 33554432
#                              IFF_TEAM                                : 16777216 -> 4194304
#                              IFF_OPENVSWITCH                         : 4194304 -> 1048576
#                              IFF_NO_QUEUE                            : 2097152 -> 524288
#                              IFF_PHONY_HEADROOM                      : 67108864 -> 16777216
#                              IFF_RXFH_CONFIGURED                     : 33554432 -> 8388608
#                              IFF_L3MDEV_RX_HANDLER                   : 268435456 -> 536870912
#                              IFF_L3MDEV_MASTER                       : 1048576 -> 262144
#                              IFF_L3MDEV_SLAVE                        : 8388608 -> 2097152
# Kind.ENUM   blkif_state
#                      Removed values:
#                              BLKIF_STATE_ERROR                       : 3
# Kind.ENUM   ib_mr_type
#                      Added values:
#                              IB_MR_TYPE_INTEGRITY                    : 5
#                              IB_MR_TYPE_USER                         : 3
#                              IB_MR_TYPE_DMA                          : 4
#                              IB_MR_TYPE_DM                           : 2
#                      Removed values:
#                              IB_MR_TYPE_SIGNATURE                    : 1
#                      Value changed:
#                              IB_MR_TYPE_SG_GAPS                      : 2 -> 1
# Kind.ENUM   dax_device_flags
#                      Added values:
#                              DAXDEV_SYNC                             : 2
# Kind.ENUM   rcutorture_type
#                      Added values:
#                              RCU_TRIVIAL_FLAVOR                      : 2
#                      Removed values:
#                              RCU_BH_FLAVOR                           : 1
#                              RCU_SCHED_FLAVOR                        : 2
#                      Value changed:
#                              RCU_TASKS_FLAVOR                        : 3 -> 1
#                              SRCU_FLAVOR                             : 4 -> 3
#                              INVALID_RCU_FLAVOR                      : 5 -> 4
# Kind.ENUM   bpf_reg_type
#                      Added values:
#                              PTR_TO_SOCKET_OR_NULL                   : 12
#                              PTR_TO_XDP_SOCK                         : 18
#                              PTR_TO_TCP_SOCK                         : 15
#                              PTR_TO_SOCK_COMMON                      : 13
#                              PTR_TO_TP_BUFFER                        : 17
#                              PTR_TO_TCP_SOCK_OR_NULL                 : 16
#                              PTR_TO_FLOW_KEYS                        : 10
#                              PTR_TO_SOCK_COMMON_OR_NULL              : 14
#                              PTR_TO_SOCKET                           : 11
# Kind.ENUM   hwmon_chip_attributes
#                      Added values:
#                              hwmon_chip_samples                      : 7
#                              hwmon_chip_curr_samples                 : 8
#                              hwmon_chip_in_samples                   : 9
#                              hwmon_chip_temp_samples                 : 11
#                              hwmon_chip_power_samples                : 10
# Kind.ENUM   bpf_map_type
#                      Added values:
#                              BPF_MAP_TYPE_XSKMAP                     : 17
#                              BPF_MAP_TYPE_SOCKHASH                   : 18
#                              BPF_MAP_TYPE_PERCPU_CGROUP_STORAGE      : 21
#                              BPF_MAP_TYPE_CGROUP_STORAGE             : 19
#                              BPF_MAP_TYPE_SK_STORAGE                 : 24
#                              BPF_MAP_TYPE_STACK                      : 23
#                              BPF_MAP_TYPE_DEVMAP_HASH                : 25
#                              BPF_MAP_TYPE_QUEUE                      : 22
#                              BPF_MAP_TYPE_REUSEPORT_SOCKARRAY        : 20
# Kind.ENUM   blkg_rwstat_type
#                      Added values:
#                              BLKG_RWSTAT_DISCARD                     : 4
#                      Value changed:
#                              BLKG_RWSTAT_TOTAL                       : 4 -> 5
#                              BLKG_RWSTAT_NR                          : 4 -> 5
# Kind.ENUM   tpm_timeout
#                      Added values:
#                              TPM_TIMEOUT_USECS_MIN                   : 100
#                              TPM_TIMEOUT_USECS_MAX                   : 500
#                              TPM_TIMEOUT_POLL                        : 1
# Kind.ENUM   pid_type
#                      Added values:
#                              PIDTYPE_TGID                            : 1
#                      Removed values:
#                              __PIDTYPE_TGID                          : 4
#                      Value changed:
#                              PIDTYPE_PGID                            : 1 -> 2
#                              PIDTYPE_SID                             : 2 -> 3
#                              PIDTYPE_MAX                             : 3 -> 4
# Kind.ENUM   bpf_adj_room_mode
#                      Added values:
#                              BPF_ADJ_ROOM_MAC                        : 1
# Kind.ENUM   scan_result
#                      Added values:
#                              SCAN_PAGE_HAS_PRIVATE                   : 24
# Kind.ENUM   dm_queue_mode
#                      Added values:
#                              DM_TYPE_NVME_BIO_BASED                  : 4
#                      Removed values:
#                              DM_TYPE_MQ_REQUEST_BASED                : 3
#                      Value changed:
#                              DM_TYPE_DAX_BIO_BASED                   : 4 -> 3
# Kind.ENUM   pstore_type_id
#                      Added values:
#                              PSTORE_TYPE_MAX                         : 9
#                      Removed values:
#                              PSTORE_TYPE_UNKNOWN                     : 255
# Kind.ENUM   irq_domain_bus_token
#                      Added values:
#                              DOMAIN_BUS_TI_SCI_INTA_MSI              : 8
#                              DOMAIN_BUS_GENERIC_MSI                  : 2
#                      Value changed:
#                              DOMAIN_BUS_IPI                          : 5 -> 6
#                              DOMAIN_BUS_FSL_MC_MSI                   : 6 -> 7
#                              DOMAIN_BUS_NEXUS                        : 4 -> 5
#                              DOMAIN_BUS_PLATFORM_MSI                 : 3 -> 4
#                              DOMAIN_BUS_PCI_MSI                      : 2 -> 3
# Kind.ENUM   cpuid_leafs
#                      Added values:
#                              CPUID_7_1_EAX                           : 12
#                      Removed values:
#                              CPUID_DUMMY                             : 12
# Kind.ENUM   blk_req_status
#                      Removed values:
#                              REQ_PROCESSING                          : 0
#                      Value changed:
#                              REQ_DONE                                : 2 -> 1
#                              REQ_EOPNOTSUPP                          : 4 -> 3
#                              REQ_ERROR                               : 3 -> 2
#                              REQ_WAITING                             : 1 -> 0
# Kind.ENUM   kcore_type
#                      Added values:
#                              KCORE_REMAP                             : 6
# Kind.ENUM   opal_uid
#                      Added values:
#                              OPAL_TABLE_TABLE                        : 13
#                      Value changed:
#                              OPAL_C_PIN_SID                          : 23 -> 24
#                              OPAL_LOCKINGRANGE_GLOBAL                : 13 -> 14
#                              OPAL_C_PIN_TABLE                        : 19 -> 20
#                              OPAL_AUTHORITY_TABLE                    : 18 -> 19
#                              OPAL_UID_HEXFF                          : 27 -> 28
#                              OPAL_ENTERPRISE_LOCKING_INFO_TABLE      : 21 -> 22
#                              OPAL_LOCKING_INFO_TABLE                 : 20 -> 21
#                              OPAL_LOCKINGRANGE_ACE_RDLOCKED          : 14 -> 15
#                              OPAL_HALF_UID_AUTHORITY_OBJ_REF         : 25 -> 26
#                              OPAL_MBRCONTROL                         : 16 -> 17
#                              OPAL_HALF_UID_BOOLEAN_ACE               : 26 -> 27
#                              OPAL_MBR                                : 17 -> 18
#                              OPAL_C_PIN_MSID                         : 22 -> 23
#                              OPAL_C_PIN_ADMIN1                       : 24 -> 25
#                              OPAL_LOCKINGRANGE_ACE_WRLOCKED          : 15 -> 16
# Kind.ENUM   phy_tunable_id
#                      Added values:
#                              ETHTOOL_PHY_EDPD                        : 3
#                              ETHTOOL_PHY_FAST_LINK_DOWN              : 2
#                      Value changed:
#                              __ETHTOOL_PHY_TUNABLE_COUNT             : 2 -> 4
# Kind.ENUM   tc_setup_type
#                      Added values:
#                              TC_SETUP_QDISC_PRIO                     : 8
#                              TC_SETUP_QDISC_MQ                       : 9
#                              TC_SETUP_QDISC_TAPRIO                   : 13
#                              TC_SETUP_ROOT_QDISC                     : 11
#                              TC_SETUP_QDISC_ETF                      : 10
#                              TC_SETUP_QDISC_GRED                     : 12
# Kind.ENUM   bpf_reg_liveness
#                      Added values:
#                              REG_LIVE_READ64                         : 2
#                              REG_LIVE_DONE                           : 8
#                              REG_LIVE_READ32                         : 1
#                      Value changed:
#                              REG_LIVE_WRITTEN                        : 2 -> 4
#                              REG_LIVE_READ                           : 1 -> 3
# Kind.ENUM   bpf_cmd
#                      Added values:
#                              BPF_BTF_GET_FD_BY_ID                    : 19
#                              BPF_MAP_LOOKUP_AND_DELETE_ELEM          : 21
#                              BPF_TASK_FD_QUERY                       : 20
#                              BPF_BTF_LOAD                            : 18
#                              BPF_BTF_GET_NEXT_ID                     : 23
#                              BPF_MAP_FREEZE                          : 22
#                              BPF_RAW_TRACEPOINT_OPEN                 : 17
# Kind.ENUM   memcg_memory_event
#                      Added values:
#                              MEMCG_SWAP_MAX                          : 5
#                              MEMCG_SWAP_FAIL                         : 6
#                      Value changed:
#                              MEMCG_NR_MEMORY_EVENTS                  : 5 -> 7
# Kind.ENUM   perf_event_type
#                      Added values:
#                              PERF_RECORD_KSYMBOL                     : 17
#                              PERF_RECORD_BPF_EVENT                   : 18
#                      Value changed:
#                              PERF_RECORD_MAX                         : 17 -> 19
# Kind.ENUM   phy_mode
#                      Added values:
#                              PHY_MODE_USB_HOST_LS                    : 2
#                              PHY_MODE_USB_DEVICE_HS                  : 9
#                              PHY_MODE_ETHERNET                       : 15
#                              PHY_MODE_USB_DEVICE_LS                  : 7
#                              PHY_MODE_USB_DEVICE_FS                  : 8
#                              PHY_MODE_MIPI_DPHY                      : 16
#                              PHY_MODE_USB_DEVICE_SS                  : 10
#                              PHY_MODE_USB_HOST_FS                    : 3
#                              PHY_MODE_USB_HOST_HS                    : 4
#                              PHY_MODE_USB_HOST_SS                    : 5
#                              PHY_MODE_PCIE                           : 14
#                              PHY_MODE_SATA                           : 17
#                      Removed values:
#                              PHY_MODE_10GKR                          : 5
#                              PHY_MODE_SGMII                          : 4
#                      Value changed:
#                              PHY_MODE_USB_DEVICE                     : 2 -> 6
#                              PHY_MODE_UFS_HS_A                       : 6 -> 12
#                              PHY_MODE_USB_OTG                        : 3 -> 11
#                              PHY_MODE_UFS_HS_B                       : 7 -> 13
# Kind.ENUM   siginfo_layout
#                      Added values:
#                              SIL_FAULT_PKUERR                        : 6
#                              SIL_FAULT_BNDERR                        : 5
#                              SIL_FAULT_MCEERR                        : 4
#                      Value changed:
#                              SIL_RT                                  : 5 -> 8
#                              SIL_CHLD                                : 4 -> 7
#                              SIL_SYS                                 : 6 -> 9
# Kind.ENUM   nf_ip_hook_priorities
#                      Added values:
#                              NF_IP_PRI_RAW_BEFORE_DEFRAG             : 18446744073709551166
# Kind.ENUM   ethtool_link_mode_bit_indices
#                      Added values:
#                              ETHTOOL_LINK_MODE_100000baseDR2_Full_BIT: 61
#                              ETHTOOL_LINK_MODE_50000baseLR_ER_FR_Full_BIT: 55
#                              __ETHTOOL_LINK_MODE_MASK_NBITS          : 69
#                              ETHTOOL_LINK_MODE_1000baseT1_Full_BIT   : 68
#                              ETHTOOL_LINK_MODE_200000baseDR4_Full_BIT: 65
#                              ETHTOOL_LINK_MODE_200000baseCR4_Full_BIT: 66
#                              ETHTOOL_LINK_MODE_50000baseCR_Full_BIT  : 54
#                              ETHTOOL_LINK_MODE_200000baseSR4_Full_BIT: 63
#                              ETHTOOL_LINK_MODE_100000baseSR2_Full_BIT: 58
#                              ETHTOOL_LINK_MODE_50000baseSR_Full_BIT  : 53
#                              ETHTOOL_LINK_MODE_100000baseCR2_Full_BIT: 59
#                              ETHTOOL_LINK_MODE_50000baseDR_Full_BIT  : 56
#                              ETHTOOL_LINK_MODE_200000baseKR4_Full_BIT: 62
#                              ETHTOOL_LINK_MODE_100baseT1_Full_BIT    : 67
#                              ETHTOOL_LINK_MODE_200000baseLR4_ER4_FR4_Full_BIT: 64
#                              ETHTOOL_LINK_MODE_100000baseKR2_Full_BIT: 57
#                              ETHTOOL_LINK_MODE_100000baseLR2_ER2_FR2_Full_BIT: 60
#                              ETHTOOL_LINK_MODE_50000baseKR_Full_BIT  : 52
#                      Removed values:
#                              __ETHTOOL_LINK_MODE_LAST                : 51
# Kind.ENUM   switchdev_attr_id
#                      Added values:
#                              SWITCHDEV_ATTR_ID_PORT_PRE_BRIDGE_FLAGS : 3
#                      Removed values:
#                              SWITCHDEV_ATTR_ID_PORT_PARENT_ID        : 1
#                              SWITCHDEV_ATTR_ID_PORT_BRIDGE_FLAGS_SUPPORT: 4
#                      Value changed:
#                              SWITCHDEV_ATTR_ID_PORT_STP_STATE        : 2 -> 1
#                              SWITCHDEV_ATTR_ID_BRIDGE_MC_DISABLED    : 8 -> 7
#                              SWITCHDEV_ATTR_ID_BRIDGE_VLAN_FILTERING : 7 -> 6
#                              SWITCHDEV_ATTR_ID_PORT_BRIDGE_FLAGS     : 3 -> 2
#                              SWITCHDEV_ATTR_ID_BRIDGE_AGEING_TIME    : 6 -> 5
#                              SWITCHDEV_ATTR_ID_PORT_MROUTER          : 5 -> 4
#                              SWITCHDEV_ATTR_ID_BRIDGE_MROUTER        : 9 -> 8
# Kind.ENUM   hk_flags
#                      Added values:
#                              HK_FLAG_WQ                              : 64
# Kind.ENUM   bpf_return_type
#                      Added values:
#                              RET_PTR_TO_TCP_SOCK_OR_NULL             : 5
#                              RET_PTR_TO_MAP_VALUE                    : 2
#                              RET_PTR_TO_SOCKET_OR_NULL               : 4
#                              RET_PTR_TO_SOCK_COMMON_OR_NULL          : 6
#                      Value changed:
#                              RET_PTR_TO_MAP_VALUE_OR_NULL            : 2 -> 3
# Kind.ENUM   group_type
#                      Added values:
#                              group_misfit_task                       : 1
#                      Value changed:
#                              group_overloaded                        : 2 -> 3
#                              group_imbalanced                        : 1 -> 2
# Kind.ENUM   fuse_opcode
#                      Added values:
#                              FUSE_REMOVEMAPPING                      : 49
#                              FUSE_INIT_BSWAP_RESERVED                : 436207616
#                              FUSE_COPY_FILE_RANGE                    : 47
#                              FUSE_SETUPMAPPING                       : 48
#                              CUSE_INIT_BSWAP_RESERVED                : 1048576
# Kind.ENUM   pci_board_num_t
#                      Added values:
#                              pbn_fintek_F81504A                      : 99
#                              pbn_moxa8250_4p                         : 114
#                              pbn_fintek_F81512A                      : 101
#                              pbn_fintek_F81508A                      : 100
#                              pbn_moxa8250_8p                         : 115
#                              pbn_endrun_2_4000000                    : 71
#                              pbn_moxa8250_2p                         : 113
#                      Removed values:
#                              pbn_endrun_2_3906250                    : 71
#                      Value changed:
#                              pbn_pericom_PI7C9X7951                  : 101 -> 104
#                              pbn_sunix_pci_4s                        : 107 -> 110
#                              pbn_pericom_PI7C9X7952                  : 102 -> 105
#                              pbn_pericom_PI7C9X7958                  : 104 -> 107
#                              pbn_sunix_pci_8s                        : 108 -> 111
#                              pbn_wch384_4                            : 100 -> 103
#                              pbn_sunix_pci_2s                        : 106 -> 109
#                              pbn_wch382_2                            : 99 -> 102
#                              pbn_sunix_pci_16s                       : 109 -> 112
#                              pbn_sunix_pci_1s                        : 105 -> 108
#                              pbn_pericom_PI7C9X7954                  : 103 -> 106
# Kind.ENUM   ncsi_nl_commands
#                      Added values:
#                              NCSI_CMD_SEND_CMD                       : 4
#                              NCSI_CMD_SET_CHANNEL_MASK               : 6
#                              NCSI_CMD_SET_PACKAGE_MASK               : 5
#                      Value changed:
#                              NCSI_CMD_MAX                            : 3 -> 6
#                              __NCSI_CMD_AFTER_LAST                   : 4 -> 7
# Kind.ENUM   memcg_stat_item
#                      Value changed:
#                              MEMCG_RSS                               : 29 -> 33
#                              MEMCG_RSS_HUGE                          : 30 -> 34
#                              MEMCG_SWAP                              : 31 -> 35
#                              MEMCG_KERNEL_STACK_KB                   : 33 -> 37
#                              MEMCG_CACHE                             : 28 -> 32
#                              MEMCG_SOCK                              : 32 -> 36
#                              MEMCG_NR_STAT                           : 34 -> 38
# Kind.ENUM   hwmon_in_attributes
#                      Added values:
#                              hwmon_in_enable                         : 15
# Kind.ENUM   wb_reason
#                      Added values:
#                              WB_REASON_FOREIGN_FLUSH                 : 8
#                      Value changed:
#                              WB_REASON_MAX                           : 8 -> 9
# Kind.ENUM   vlan_flags
#                      Added values:
#                              VLAN_FLAG_BRIDGE_BINDING                : 16
# Kind.ENUM   bpf_func_id
#                      Added values:
#                              BPF_FUNC_map_push_elem                  : 87
#                              BPF_FUNC_map_pop_elem                   : 88
#                              BPF_FUNC_sysctl_get_new_value           : 103
#                              BPF_FUNC_get_stack                      : 67
#                              BPF_FUNC_sk_redirect_hash               : 72
#                              BPF_FUNC_lwt_push_encap                 : 73
#                              BPF_FUNC_sk_storage_delete              : 108
#                              BPF_FUNC_msg_apply_bytes                : 61
#                              BPF_FUNC_sk_fullsock                    : 95
#                              BPF_FUNC_spin_lock                      : 93
#                              BPF_FUNC_rc_pointer_rel                 : 92
#                              BPF_FUNC_spin_unlock                    : 94
#                              BPF_FUNC_msg_redirect_hash              : 71
#                              BPF_FUNC_sock_ops_cb_flags_set          : 59
#                              BPF_FUNC_tcp_gen_syncookie              : 110
#                              BPF_FUNC_override_return                : 58
#                              BPF_FUNC_tcp_sock                       : 96
#                              BPF_FUNC_sk_storage_get                 : 107
#                              BPF_FUNC_tcp_check_syncookie            : 100
#                              BPF_FUNC_skb_get_xfrm_state             : 66
#                              BPF_FUNC_sk_lookup_udp                  : 85
#                              BPF_FUNC_map_peek_elem                  : 89
#                              BPF_FUNC_skb_ecn_set_ce                 : 97
#                              BPF_FUNC_lwt_seg6_adjust_srh            : 75
#                              BPF_FUNC_msg_redirect_map               : 60
#                              BPF_FUNC_get_listener_sock              : 98
#                              BPF_FUNC_get_current_cgroup_id          : 80
#                              BPF_FUNC_xdp_adjust_tail                : 65
#                              BPF_FUNC_skc_lookup_tcp                 : 99
#                              BPF_FUNC_strtol                         : 105
#                              BPF_FUNC_sk_release                     : 86
#                              BPF_FUNC_send_signal                    : 109
#                              BPF_FUNC_strtoul                        : 106
#                              BPF_FUNC_sysctl_get_name                : 101
#                              BPF_FUNC_msg_pull_data                  : 63
#                              BPF_FUNC_msg_pop_data                   : 91
#                              BPF_FUNC_sysctl_get_current_value       : 102
#                              BPF_FUNC_sock_hash_update               : 70
#                              BPF_FUNC_lwt_seg6_store_bytes           : 74
#                              BPF_FUNC_rc_keydown                     : 78
#                              BPF_FUNC_bind                           : 64
#                              BPF_FUNC_skb_load_bytes_relative        : 68
#                              BPF_FUNC_skb_ancestor_cgroup_id         : 83
#                              BPF_FUNC_msg_cork_bytes                 : 62
#                              BPF_FUNC_lwt_seg6_action                : 76
#                              BPF_FUNC_skb_cgroup_id                  : 79
#                              BPF_FUNC_get_local_storage              : 81
#                              BPF_FUNC_rc_repeat                      : 77
#                              BPF_FUNC_sk_select_reuseport            : 82
#                              BPF_FUNC_sk_lookup_tcp                  : 84
#                              BPF_FUNC_msg_push_data                  : 90
#                              BPF_FUNC_sysctl_set_new_value           : 104
#                              BPF_FUNC_fib_lookup                     : 69
#                      Value changed:
#                              __BPF_FUNC_MAX_ID                       : 58 -> 111
# Kind.ENUM   gpio_lookup_flags
#                      Added values:
#                              GPIO_LOOKUP_FLAGS_DEFAULT               : 0
#                              GPIO_PULL_UP                            : 16
#                              GPIO_PERSISTENT                         : 0
#                              GPIO_TRANSITORY                         : 8
#                              GPIO_PULL_DOWN                          : 32
#                      Removed values:
#                              GPIO_SLEEP_MAINTAIN_VALUE               : 0
#                              GPIO_SLEEP_MAY_LOSE_VALUE               : 8
# Kind.ENUM   spectre_v2_mitigation
#                      Added values:
#                              SPECTRE_V2_IBRS_ENHANCED                : 3
#                              SPECTRE_V2_RETPOLINE_AMD                : 2
#                              SPECTRE_V2_RETPOLINE_GENERIC            : 1
#                      Removed values:
#                              SPECTRE_V2_EIBRS_RETPOLINE              : 4
#                              SPECTRE_V2_EIBRS                        : 3
#                              SPECTRE_V2_LFENCE                       : 2
#                              SPECTRE_V2_EIBRS_LFENCE                 : 5
#                              SPECTRE_V2_RETPOLINE                    : 1
#                              SPECTRE_V2_IBRS                         : 6
# Kind.ENUM   HV_GENERIC_SET_FORMAT
#                      Added values:
#                              HV_GENERIC_SET_SPARSE_4K                : 0
#                      Removed values:
#                              HV_GENERIC_SET_SPARCE_4K                : 0
# Kind.ENUM   nl80211_ext_feature_index
#                      Added values:
#                              NL80211_EXT_FEATURE_SCAN_MIN_PREQ_CONTENT: 30
#                              NL80211_EXT_FEATURE_LOW_SPAN_SCAN       : 22
#                              NL80211_EXT_FEATURE_CONTROL_PORT_OVER_NL80211: 26
#                              NL80211_EXT_FEATURE_STA_TX_PWR          : 37
#                              NL80211_EXT_FEATURE_CAN_REPLACE_PTK0    : 31
#                              NL80211_EXT_FEATURE_DATA_ACK_SIGNAL_SUPPORT: 27
#                              NL80211_EXT_FEATURE_AIRTIME_FAIRNESS    : 33
#                              NL80211_EXT_FEATURE_DFS_OFFLOAD         : 25
#                              NL80211_EXT_FEATURE_AP_PMKSA_CACHING    : 34
#                              NL80211_EXT_FEATURE_LOW_POWER_SCAN      : 23
#                              NL80211_EXT_FEATURE_HIGH_ACCURACY_SCAN  : 24
#                              NL80211_EXT_FEATURE_EXT_KEY_ID          : 36
#                              NL80211_EXT_FEATURE_SAE_OFFLOAD         : 38
#                              NL80211_EXT_FEATURE_ACK_SIGNAL_SUPPORT  : 27
#                              NL80211_EXT_FEATURE_SCAN_RANDOM_SN      : 29
#                              NL80211_EXT_FEATURE_TXQS                : 28
#                              NL80211_EXT_FEATURE_SCHED_SCAN_BAND_SPECIFIC_RSSI_THOLD: 35
#                              NL80211_EXT_FEATURE_ENABLE_FTM_RESPONDER: 32
#                      Value changed:
#                              NUM_NL80211_EXT_FEATURES                : 22 -> 39
#                              MAX_NL80211_EXT_FEATURES                : 21 -> 38
# Kind.ENUM   dsa_tag_protocol
#                      Added values:
#                              DSA_TAG_PROTO_SJA1105                   : 13
#                              DSA_TAG_PROTO_KSZ9893                   : 7
#                              DSA_TAG_PROTO_KSZ9477                   : 6
#                              DSA_TAG_PROTO_KSZ8795                   : 14
#                              DSA_TAG_PROTO_GSWIP                     : 5
#                              DSA_TAG_PROTO_8021Q                     : 12
#                      Removed values:
#                              DSA_TAG_PROTO_KSZ                       : 5
#                              DSA_TAG_LAST                            : 10
#                      Value changed:
#                              DSA_TAG_PROTO_LAN9303                   : 6 -> 8
#                              DSA_TAG_PROTO_TRAILER                   : 9 -> 11
#                              DSA_TAG_PROTO_QCA                       : 8 -> 10
#                              DSA_TAG_PROTO_MTK                       : 7 -> 9
# Kind.ENUM   system_states
#                      Added values:
#                              SYSTEM_SUSPEND                          : 6
# Kind.ENUM   membarrier_cmd
#                      Added values:
#                              MEMBARRIER_CMD_GLOBAL                   : 1
#                              MEMBARRIER_CMD_REGISTER_PRIVATE_EXPEDITED_SYNC_CORE: 64
#                              MEMBARRIER_CMD_GLOBAL_EXPEDITED         : 2
#                              MEMBARRIER_CMD_PRIVATE_EXPEDITED_SYNC_CORE: 32
#                              MEMBARRIER_CMD_REGISTER_GLOBAL_EXPEDITED: 4
# Kind.ENUM   qdisc_state_t
#                      Added values:
#                              __QDISC_STATE_MISSED                    : 2
# Kind.ENUM   hist_field_flags
#                      Added values:
#                              HIST_FIELD_FL_TIMESTAMP                 : 1024
#                              HIST_FIELD_FL_ALIAS                     : 65536
#                              HIST_FIELD_FL_VAR_REF                   : 16384
#                              HIST_FIELD_FL_EXPR                      : 8192
#                              HIST_FIELD_FL_CPU                       : 32768
#                              HIST_FIELD_FL_TIMESTAMP_USECS           : 2048
#                              HIST_FIELD_FL_VAR                       : 4096
# Kind.ENUM   tpm_pcrs
#                      Added values:
#                              TPM_PCR10                               : 10
# Kind.ENUM   tunable_id
#                      Added values:
#                              ETHTOOL_PFC_PREVENTION_TOUT             : 3
#                      Value changed:
#                              __ETHTOOL_TUNABLE_COUNT                 : 3 -> 4
# Kind.ENUM   recovery_flags
#                      Added values:
#                              MD_RESYNCING_REMOTE                     : 12
#                              MD_RECOVERY_WAIT                        : 11
# Kind.ENUM   ib_qp_type
#                      Added values:
#                              IB_QPT_DRIVER                           : 255
# Kind.ENUM   pt_capabilities
#                      Added values:
#                              PT_CAP_output_subsys                    : 10
#                      Value changed:
#                              PT_CAP_payloads_lip                     : 10 -> 11
#                              PT_CAP_cycle_thresholds                 : 13 -> 14
#                              PT_CAP_mtc_periods                      : 12 -> 13
#                              PT_CAP_num_address_ranges               : 11 -> 12
#                              PT_CAP_psb_periods                      : 14 -> 15
# Kind.ENUM   bpf_arg_type
#                      Added values:
#                              ARG_PTR_TO_LONG                         : 16
#                              ARG_PTR_TO_SOCKET                       : 17
#                              ARG_PTR_TO_SPIN_LOCK                    : 13
#                              ARG_PTR_TO_INT                          : 15
#                              ARG_PTR_TO_SOCK_COMMON                  : 14
#                              ARG_PTR_TO_UNINIT_MAP_VALUE             : 4
#                              ARG_PTR_TO_MAP_VALUE_OR_NULL            : 5
#                      Value changed:
#                              ARG_PTR_TO_MEM                          : 4 -> 6
#                              ARG_CONST_SIZE                          : 7 -> 9
#                              ARG_PTR_TO_CTX                          : 9 -> 11
#                              ARG_ANYTHING                            : 10 -> 12
#                              ARG_PTR_TO_MEM_OR_NULL                  : 5 -> 7
#                              ARG_PTR_TO_UNINIT_MEM                   : 6 -> 8
#                              ARG_CONST_SIZE_OR_ZERO                  : 8 -> 10
# Kind.ENUM   stack_type
#                      Value changed:
#                              STACK_TYPE_EXCEPTION_LAST               : 8 -> 10
# Kind.ENUM   smca_bank_types
#                      Added values:
#                              SMCA_PSP_V2                             : 15
#                              SMCA_CS_V2                              : 10
#                              SMCA_NBIO                               : 19
#                              SMCA_PCIE                               : 20
#                              SMCA_LS_V2                              : 1
#                              SMCA_MP5                                : 18
#                              SMCA_SMU_V2                             : 17
#                      Value changed:
#                              SMCA_RESERVED                           : 4 -> 5
#                              SMCA_PB                                 : 11 -> 13
#                              SMCA_IF                                 : 1 -> 2
#                              SMCA_CS                                 : 8 -> 9
#                              SMCA_L2_CACHE                           : 2 -> 3
#                              SMCA_DE                                 : 3 -> 4
#                              SMCA_UMC                                : 10 -> 12
#                              SMCA_PSP                                : 12 -> 14
#                              SMCA_EX                                 : 5 -> 6
#                              SMCA_PIE                                : 9 -> 11
#                              SMCA_SMU                                : 13 -> 16
#                              SMCA_L3_CACHE                           : 7 -> 8
#                              SMCA_FP                                 : 6 -> 7
#                              N_SMCA_BANK_TYPES                       : 14 -> 21
# Kind.ENUM   sock_flags
#                      Added values:
#                              SOCK_TXTIME                             : 25
#                              SOCK_XDP                                : 26
#                              SOCK_TSTAMP_NEW                         : 27
# Kind.ENUM   cpuhp_smt_control
#                      Added values:
#                              CPU_SMT_NOT_IMPLEMENTED                 : 4
# Kind.ENUM   cpuhp_state
#                      Added values:
#                              CPUHP_AP_X86_INTEL_EPB_ONLINE           : 144
#                              CPUHP_AP_ARM_CACHE_B15_RAC_DEAD         : 34
#                              CPUHP_AP_RISCV_TIMER_STARTING           : 124
#                              CPUHP_AP_CSKY_TIMER_STARTING            : 125
#                              CPUHP_AP_ARM_CACHE_B15_RAC_DYING        : 136
#                              CPUHP_AP_TEGRA_TIMER_STARTING           : 119
#                              CPUHP_AP_WATCHDOG_ONLINE                : 169
#                              CPUHP_AP_PERF_POWERPC_TRACE_IMC_ONLINE  : 168
#                              CPUHP_AP_ARM_MVEBU_SYNC_CLOCKS          : 143
#                              CPUHP_AP_PERF_ARM_APM_XGENE_ONLINE      : 163
#                              CPUHP_AP_OMAP_DM_TIMER_STARTING         : 114
#                      Removed values:
#                              CPUHP_RANDOM_PREPARE                    : 36
#                              CPUHP_AP_RANDOM_ONLINE                  : 164
#                              CPUHP_AP_PERF_METAG_STARTING            : 105
#                              CPUHP_AP_METAG_TIMER_STARTING           : 119
#                              CPUHP_PERF_BFIN                         : 5
#                      Value changed:
#                              CPUHP_POWERPC_PMAC_PREPARE              : 48 -> 47
#                              CPUHP_AP_QCOM_TIMER_STARTING            : 120 -> 118
#                              CPUHP_AP_PERF_ARM_HISI_HHA_ONLINE       : 154 -> 158
#                              CPUHP_AP_PERF_X86_UNCORE_ONLINE         : 143 -> 147
#                              CPUHP_AP_PERF_X86_STARTING              : 100 -> 99
#                              CPUHP_AP_PERF_S390_SF_ONLINE            : 150 -> 154
#                              CPUHP_AP_IRQ_HIP04_STARTING             : 93 -> 92
#                              CPUHP_PERF_SUPERH                       : 7 -> 6
#                              CPUHP_BLK_MQ_DEAD                       : 24 -> 23
#                              CPUHP_AP_ARM_SDEI_STARTING              : 107 -> 105
#                              CPUHP_X2APIC_PREPARE                    : 41 -> 40
#                              CPUHP_AP_PERF_X86_CSTATE_STARTING       : 103 -> 102
#                              CPUHP_AP_PERF_ARM_STARTING              : 112 -> 110
#                              CPUHP_AP_PERF_POWERPC_CORE_IMC_ONLINE   : 161 -> 166
#                              CPUHP_X86_MCE_DEAD                      : 10 -> 9
#                              CPUHP_AP_ARM_ARCH_TIMER_STARTING        : 115 -> 113
#                              CPUHP_AP_PERF_ARM_QCOM_L3_ONLINE        : 158 -> 162
#                              CPUHP_AP_PERF_POWERPC_NEST_IMC_ONLINE   : 160 -> 165
#                              CPUHP_AP_PERF_X86_ONLINE                : 142 -> 146
#                              CPUHP_PERF_POWER                        : 6 -> 5
#                              CPUHP_AP_OFFLINE                        : 89 -> 88
#                              CPUHP_NET_MVNETA_DEAD                   : 16 -> 15
#                              CPUHP_KVM_PPC_BOOK3S_PREPARE            : 62 -> 61
#                              CPUHP_AP_PERF_X86_RAPL_ONLINE           : 146 -> 150
#                              CPUHP_AP_PERF_ARM_HW_BREAKPOINT_STARTING: 110 -> 108
#                              CPUHP_ARM_BL_PREPARE                    : 57 -> 56
#                              CPUHP_S390_PFAULT_DEAD                  : 23 -> 22
#                              CPUHP_AP_SCHED_STARTING                 : 90 -> 89
#                              CPUHP_AP_ARM_MVEBU_COHERENCY            : 97 -> 96
#                              CPUHP_AP_PERF_X86_CQM_ONLINE            : 147 -> 151
#                              CPUHP_SH_SH3X_PREPARE                   : 53 -> 52
#                              CPUHP_LUSTRE_CFS_DEAD                   : 34 -> 33
#                              CPUHP_X86_APB_DEAD                      : 9 -> 8
#                              CPUHP_MM_ZSWP_POOL_PREPARE              : 61 -> 60
#                              CPUHP_AP_ARM_GLOBAL_TIMER_STARTING      : 116 -> 115
#                              CPUHP_AP_PERF_ARM_L2X0_ONLINE           : 156 -> 160
#                              CPUHP_VIRT_NET_DEAD                     : 11 -> 10
#                              CPUHP_AP_JCORE_TIMER_STARTING           : 117 -> 116
#                              CPUHP_AP_ARM_TWD_STARTING               : 118 -> 117
#                              CPUHP_SLAB_PREPARE                      : 44 -> 43
#                              CPUHP_AP_ARM_XEN_STARTING               : 130 -> 131
#                              CPUHP_AP_BASE_CACHEINFO_ONLINE          : 166 -> 172
#                              CPUHP_BP_PREPARE_DYN_END                : 86 -> 85
#                              CPUHP_AP_ARM_CORESIGHT_STARTING         : 131 -> 132
#                              CPUHP_WORKQUEUE_PREP                    : 37 -> 36
#                              CPUHP_AP_PERF_ONLINE                    : 141 -> 145
#                              CPUHP_AP_X86_TBOOT_DYING                : 134 -> 135
#                              CPUHP_FS_BUFF_DEAD                      : 25 -> 24
#                              CPUHP_AP_IRQ_GIC_STARTING               : 92 -> 91
#                              CPUHP_ACPI_CPUDRV_DEAD                  : 22 -> 21
#                              CPUHP_RADIX_DEAD                        : 29 -> 28
#                              CPUHP_AP_ONLINE                         : 135 -> 137
#                              CPUHP_TEARDOWN_CPU                      : 136 -> 138
#                              CPUHP_AP_ARM64_ISNDEP_STARTING          : 132 -> 133
#                              CPUHP_AP_ARMADA_TIMER_STARTING          : 121 -> 120
#                              CPUHP_RCUTREE_PREP                      : 46 -> 45
#                              CPUHP_AP_PERF_ARM_HISI_L3_ONLINE        : 155 -> 159
#                              CPUHP_AP_PERF_X86_CSTATE_ONLINE         : 148 -> 152
#                              CPUHP_AP_ARM_VFP_STARTING               : 108 -> 106
#                              CPUHP_MM_ZS_PREPARE                     : 59 -> 58
#                              CPUHP_AP_PERF_X86_AMD_POWER_ONLINE      : 145 -> 149
#                              CPUHP_XEN_PREPARE                       : 50 -> 49
#                              CPUHP_MM_ZSWP_MEM_PREPARE               : 60 -> 59
#                              CPUHP_AP_IRQ_MIPS_GIC_STARTING          : 96 -> 95
#                              CPUHP_HRTIMERS_PREPARE                  : 39 -> 38
#                              CPUHP_MM_VMSTAT_DEAD                    : 14 -> 13
# ...
#                              FLOW_DISSECTOR_KEY_CVLAN                : 22
#                              FLOW_DISSECTOR_KEY_ENC_OPTS             : 24
#                      Value changed:
#                              FLOW_DISSECTOR_KEY_ENC_CONTROL          : 16 -> 17
#                              FLOW_DISSECTOR_KEY_ARP                  : 8 -> 9
#                              FLOW_DISSECTOR_KEY_ETH_ADDRS            : 6 -> 7
#                              FLOW_DISSECTOR_KEY_FLOW_LABEL           : 10 -> 11
#                              FLOW_DISSECTOR_KEY_GRE_KEYID            : 11 -> 12
#                              FLOW_DISSECTOR_KEY_ENC_IPV6_ADDRS       : 15 -> 16
#                              FLOW_DISSECTOR_KEY_ENC_IPV4_ADDRS       : 14 -> 15
#                              FLOW_DISSECTOR_KEY_MPLS                 : 18 -> 19
#                              FLOW_DISSECTOR_KEY_MAX                  : 21 -> 27
#                              FLOW_DISSECTOR_KEY_TCP                  : 19 -> 20
#                              FLOW_DISSECTOR_KEY_MPLS_ENTROPY         : 12 -> 13
#                              FLOW_DISSECTOR_KEY_IP                   : 20 -> 21
#                              FLOW_DISSECTOR_KEY_ENC_PORTS            : 17 -> 18
#                              FLOW_DISSECTOR_KEY_VLAN                 : 9 -> 10
#                              FLOW_DISSECTOR_KEY_TIPC                 : 7 -> 8
#                              FLOW_DISSECTOR_KEY_ENC_KEYID            : 13 -> 14
#                              FLOW_DISSECTOR_KEY_ICMP                 : 5 -> 6
# Kind.ENUM   tpm2_const
#                      Removed values:
#                              TPM2_TIMEOUT_A                          : 750
#                              TPM2_TIMEOUT_D                          : 30
#                              TPM2_DURATION_SHORT                     : 20
#                              TPM2_TIMEOUT_B                          : 2000
#                              TPM2_DURATION_MEDIUM                    : 750
#                              TPM2_DURATION_LONG                      : 2000
#                              TPM2_TIMEOUT_C                          : 200
# Kind.ENUM   acpi_srat_type
#                      Added values:
#                              ACPI_SRAT_TYPE_GENERIC_AFFINITY         : 5
#                      Value changed:
#                              ACPI_SRAT_TYPE_RESERVED                 : 5 -> 6
# Kind.ENUM   rtattr_type_t
#                      Added values:
#                              RTA_IP_PROTO                            : 27
#                              RTA_NH_ID                               : 30
#                              RTA_DPORT                               : 29
#                              RTA_SPORT                               : 28
#                      Value changed:
#                              __RTA_MAX                               : 27 -> 31
# Kind.ENUM   ncsi_nl_attrs
#                      Added values:
#                              NCSI_ATTR_DATA                          : 5
#                              NCSI_ATTR_PACKAGE_MASK                  : 7
#                              NCSI_ATTR_MULTI_FLAG                    : 6
#                              NCSI_ATTR_CHANNEL_MASK                  : 8
#                      Value changed:
#                              NCSI_ATTR_MAX                           : 4 -> 8
#                              __NCSI_ATTR_AFTER_LAST                  : 5 -> 9
# Kind.ENUM   pin_config_param
#                      Added values:
#                              PIN_CONFIG_PERSIST_STATE                : 22
#                              PIN_CONFIG_DRIVE_STRENGTH_UA            : 10
#                      Value changed:
#                              PIN_CONFIG_SLEEP_HARDWARE_STATE         : 18 -> 19
#                              PIN_CONFIG_LOW_POWER_MODE               : 14 -> 15
#                              PIN_CONFIG_INPUT_ENABLE                 : 11 -> 12
#                              PIN_CONFIG_INPUT_SCHMITT                : 12 -> 13
#                              PIN_CONFIG_SKEW_DELAY                   : 20 -> 21
#                              PIN_CONFIG_OUTPUT                       : 16 -> 17
#                              PIN_CONFIG_OUTPUT_ENABLE                : 15 -> 16
#                              PIN_CONFIG_POWER_SOURCE                 : 17 -> 18
#                              PIN_CONFIG_SLEW_RATE                    : 19 -> 20
#                              PIN_CONFIG_INPUT_DEBOUNCE               : 10 -> 11
#                              PIN_CONFIG_INPUT_SCHMITT_ENABLE         : 13 -> 14
# Kind.ENUM   perf_event_x86_regs
#                      Added values:
#                              PERF_REG_X86_XMM13                      : 58
#                              PERF_REG_X86_XMM1                       : 34
#                              PERF_REG_X86_XMM11                      : 54
#                              PERF_REG_X86_XMM5                       : 42
#                              PERF_REG_X86_XMM12                      : 56
#                              PERF_REG_X86_XMM9                       : 50
#                              PERF_REG_X86_XMM_MAX                    : 64
#                              PERF_REG_X86_XMM4                       : 40
#                              PERF_REG_X86_XMM10                      : 52
#                              PERF_REG_X86_XMM15                      : 62
#                              PERF_REG_X86_XMM8                       : 48
#                              PERF_REG_X86_XMM7                       : 46
#                              PERF_REG_X86_XMM14                      : 60
#                              PERF_REG_X86_XMM6                       : 44
#                              PERF_REG_X86_XMM0                       : 32
#                              PERF_REG_X86_XMM2                       : 36
#                              PERF_REG_X86_XMM3                       : 38
# Kind.ENUM   __sk_action
#                      Added values:
#                              __SK_NONE                               : 3
# Kind.ENUM   bpf_attach_type
#                      Added values:
#                              BPF_CGROUP_INET6_BIND                   : 9
#                              BPF_LIRC_MODE2                          : 16
#                              BPF_CGROUP_UDP4_RECVMSG                 : 19
#                              BPF_CGROUP_INET6_POST_BIND              : 13
#                              BPF_CGROUP_UDP6_SENDMSG                 : 15
#                              BPF_SK_MSG_VERDICT                      : 7
#                              BPF_FLOW_DISSECTOR                      : 17
#                              BPF_CGROUP_SETSOCKOPT                   : 22
#                              BPF_CGROUP_SYSCTL                       : 18
#                              BPF_CGROUP_GETSOCKOPT                   : 21
#                              BPF_CGROUP_INET6_CONNECT                : 11
#                              BPF_CGROUP_INET4_POST_BIND              : 12
#                              BPF_CGROUP_INET4_CONNECT                : 10
#                              BPF_CGROUP_INET4_BIND                   : 8
#                              BPF_CGROUP_UDP4_SENDMSG                 : 14
#                              BPF_CGROUP_UDP6_RECVMSG                 : 20
#                      Value changed:
#                              __MAX_BPF_ATTACH_TYPE                   : 7 -> 23
# Kind.ENUM   power_supply_property
#                      Added values:
#                              POWER_SUPPLY_PROP_INPUT_POWER_LIMIT     : 39
#                              POWER_SUPPLY_PROP_INPUT_VOLTAGE_LIMIT   : 38
#                              POWER_SUPPLY_PROP_USB_TYPE              : 63
#                              POWER_SUPPLY_PROP_CHARGE_CONTROL_END_THRESHOLD: 36
#                              POWER_SUPPLY_PROP_CHARGE_CONTROL_START_THRESHOLD: 35
#                      Value changed:
#                              POWER_SUPPLY_PROP_TIME_TO_FULL_AVG      : 57 -> 61
#                              POWER_SUPPLY_PROP_ENERGY_EMPTY          : 39 -> 43
#                              POWER_SUPPLY_PROP_TYPE                  : 58 -> 62
#                              POWER_SUPPLY_PROP_TEMP_ALERT_MAX        : 50 -> 54
#                              POWER_SUPPLY_PROP_ENERGY_AVG            : 41 -> 45
#                              POWER_SUPPLY_PROP_ENERGY_FULL           : 38 -> 42
#                              POWER_SUPPLY_PROP_TEMP                  : 46 -> 50
#                              POWER_SUPPLY_PROP_TIME_TO_FULL_NOW      : 56 -> 60
#                              POWER_SUPPLY_PROP_TEMP_MAX              : 47 -> 51
#                              POWER_SUPPLY_PROP_INPUT_CURRENT_LIMIT   : 35 -> 37
#                              POWER_SUPPLY_PROP_TEMP_AMBIENT_ALERT_MAX: 53 -> 57
#                              POWER_SUPPLY_PROP_CHARGE_TERM_CURRENT   : 61 -> 66
#                              POWER_SUPPLY_PROP_CAPACITY              : 42 -> 46
#                              POWER_SUPPLY_PROP_SCOPE                 : 59 -> 64
#                              POWER_SUPPLY_PROP_MANUFACTURER          : 64 -> 69
#                              POWER_SUPPLY_PROP_TIME_TO_EMPTY_NOW     : 54 -> 58
#                              POWER_SUPPLY_PROP_TEMP_AMBIENT_ALERT_MIN: 52 -> 56
#                              POWER_SUPPLY_PROP_TEMP_ALERT_MIN        : 49 -> 53
#                              POWER_SUPPLY_PROP_CAPACITY_LEVEL        : 45 -> 49
#                              POWER_SUPPLY_PROP_MODEL_NAME            : 63 -> 68
#                              POWER_SUPPLY_PROP_ENERGY_EMPTY_DESIGN   : 37 -> 41
#                              POWER_SUPPLY_PROP_ENERGY_FULL_DESIGN    : 36 -> 40
#                              POWER_SUPPLY_PROP_PRECHARGE_CURRENT     : 60 -> 65
#                              POWER_SUPPLY_PROP_CALIBRATE             : 62 -> 67
#                              POWER_SUPPLY_PROP_TIME_TO_EMPTY_AVG     : 55 -> 59
#                              POWER_SUPPLY_PROP_ENERGY_NOW            : 40 -> 44
#                              POWER_SUPPLY_PROP_SERIAL_NUMBER         : 65 -> 70
#                              POWER_SUPPLY_PROP_CAPACITY_ALERT_MIN    : 43 -> 47
#                              POWER_SUPPLY_PROP_TEMP_AMBIENT          : 51 -> 55
#                              POWER_SUPPLY_PROP_CAPACITY_ALERT_MAX    : 44 -> 48
#                              POWER_SUPPLY_PROP_TEMP_MIN              : 48 -> 52
# Kind.ENUM   hdmi_infoframe_type
#                      Added values:
#                              HDMI_INFOFRAME_TYPE_DRM                 : 135
# Kind.ENUM   hrtimer_base_type
#                      Added values:
#                              HRTIMER_BASE_MONOTONIC_SOFT             : 4
#                              HRTIMER_BASE_BOOTTIME_SOFT              : 6
#                              HRTIMER_BASE_TAI_SOFT                   : 7
#                              HRTIMER_BASE_REALTIME_SOFT              : 5
#                      Value changed:
#                              HRTIMER_MAX_CLOCK_BASES                 : 4 -> 8
# Kind.ENUM   fuse_req_flag
#                      Added values:
#                              FR_ASYNC                                : 11
# Kind.ENUM   OID
#                      Added values:
#                              OID_gostTC26Sign256A                    : 67
#                              OID_gostTC26Sign256D                    : 70
#                              OID_gost2012PKey256                     : 61
#                              OID_gost2012Digest512                   : 64
#                              OID_gost2012Signature256                : 65
#                              OID_gostCPSignA                         : 58
#                              OID_gostTC26Sign512A                    : 71
#                              OID_gost2012Signature512                : 66
#                              OID_gostTC26Sign256B                    : 68
#                              OID_gostTC26Sign512B                    : 72
#                              OID_gostTC26Sign256C                    : 69
#                              OID_gostCPSignB                         : 59
#                              OID_gost2012Digest256                   : 63
#                              OID_gostTC26Sign512C                    : 73
#                              OID_gostCPSignC                         : 60
#                              OID_gost2012PKey512                     : 62
#                      Value changed:
#                              OID__NR                                 : 58 -> 74
# Kind.ENUM   tpm2_command_codes
#                      Added values:
#                              TPM2_CC_SEQUENCE_COMPLETE               : 318
#                              TPM2_CC_NV_READ                         : 334
#                              TPM2_CC_CREATE_LOADED                   : 401
#                              TPM2_CC_EVENT_SEQUENCE_COMPLETE         : 389
#                              TPM2_CC_VERIFY_SIGNATURE                : 375
#                              TPM2_CC_CREATE_PRIMARY                  : 305
#                              TPM2_CC_HASH_SEQUENCE_START             : 390
#                              TPM2_CC_HIERARCHY_CONTROL               : 289
#                              TPM2_CC_HIERARCHY_CHANGE_AUTH           : 297
#                              TPM2_CC_SEQUENCE_UPDATE                 : 348
#                      Value changed:
#                              TPM2_CC_LAST                            : 399 -> 403
# Kind.ENUM   hrtimer_mode
#                      Added values:
#                              HRTIMER_MODE_HARD                       : 8
#                              HRTIMER_MODE_ABS_PINNED_HARD            : 10
#                              HRTIMER_MODE_ABS_PINNED_SOFT            : 6
#                              HRTIMER_MODE_REL_PINNED_HARD            : 11
#                              HRTIMER_MODE_ABS_HARD                   : 8
#                              HRTIMER_MODE_REL_PINNED_SOFT            : 7
#                              HRTIMER_MODE_REL_HARD                   : 9
#                              HRTIMER_MODE_SOFT                       : 4
#                              HRTIMER_MODE_REL_SOFT                   : 5
#                              HRTIMER_MODE_ABS_SOFT                   : 4
# Kind.ENUM   memory_type
#                      Added values:
#                              MEMORY_DEVICE_FS_DAX                    : 2
#                              MEMORY_DEVICE_PCI_P2PDMA                : 4
#                              MEMORY_DEVICE_DEVDAX                    : 3
#                      Removed values:
#                              MEMORY_DEVICE_PUBLIC                    : 2
#                              MEMORY_DEVICE_HOST                      : 0
# Kind.ENUM   opal_token
#                      Added values:
#                              OPAL_TABLE_MIN                          : 11
#                              OPAL_TABLE_ROWS                         : 7
#                              OPAL_TABLE_ROW_BYTES                    : 9
#                              OPAL_TABLE_KIND                         : 4
#                              OPAL_TABLE_TEMPLATE                     : 3
#                              OPAL_TABLE_UID                          : 0
#                              OPAL_TABLE_ROWS_FREE                    : 8
#                              OPAL_TABLE_LASTID                       : 10
#                              OPAL_TABLE_COMMON                       : 2
#                              OPAL_TABLE_COLUMN                       : 5
#                              OPAL_TABLE_NAME                         : 1
#                              OPAL_TABLE_COLUMNS                      : 6
#                              OPAL_LIFECYCLE                          : 6
#                              OPAL_TABLE_MAX                          : 12
# Kind.ENUM   dev_pm_opp_event
#                      Removed values:
#                              OPP_EVENT_ADJUST_VOLTAGE                : 4
# Kind.ENUM   mem_type
#                      Added values:
#                              MEM_NVDIMM                              : 21
