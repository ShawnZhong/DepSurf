# %%
# for all files in btf/data/ubuntu-18.04-x86

import os
from pathlib import Path

data_path = Path("data/ubuntu-18.04-x86")

def system(cmd):
    print(cmd)
    os.system(cmd)

for file in data_path.iterdir():
    if file.endswith(".tar.xz"):
        system("tar -xf " + str(file))

# %%
import json
import numpy as np

# %%
# load file "5.4.0-26-generic.btf.json" and "5.8.0-23-generic.btf.json"
with open('5.4.0-26-generic.btf.json') as f:
    data_1 = json.load(f)['types']

with open('5.8.0-23-generic.btf.json') as f:
    data_2 = json.load(f)['types']

# %%
# All valid kind: INT CONST VOLATILE ARRAY PTR TYPEDEF ENUM FUNC_PROTO STRUCT UNION FWD FUNC VAR DATASEC



def proc(data):
    # structs is a set
    structs = set()
    
    for type in data:
        if type['name'] == "(anon)":
            continue

        # if type['kind'] == "FWD":
        #     print(type['name'], end=', ')

        if type['kind'] == "STRUCT":
            structs.add(type['name'])

            # print(type['name'], len(type['members']))

    return structs

s1 = proc(data_1)
s2 = proc(data_2)

# check the difference between two versions
print(s1 - s2)
# Out:
# list_head 2
# hlist_head 1
# hlist_node 2
# callback_head 2
# file_system_type 16
# jump_entry 3
# static_key 2
# static_key_true 1
# static_key_false 1
# file_operations 33
# atomic_notifier_head 2
# taint_flag 3
# __kernel_timespec 2
# timezone 2
# timespec64 2
# old_timespec32 2
# restart_block 2
# task_struct 213
# screen_info 36
# apm_bios_info 9
# apm_info 8
# edd_device_params 18
# edd_info 7
# edd 4
# ist_info 4
# edid_info 1
# setup_header 38
# sys_desc_table 2
# olpc_ofw_header 4
# efi_info 8
# boot_e820_entry 3
# boot_params 34
# range 2
# pt_regs 21
# desc_struct 13
# idt_bits 5
# gate_struct 6
# desc_ptr 2
# pgprot 1
# page 5
# paravirt_callee_save 1
# pv_info 4
# pv_init_ops 1
# pv_lazy_ops 3
# pv_time_ops 2
# pv_cpu_ops 32
# thread_struct 21
# pv_irq_ops 6
# pv_mmu_ops 39
# cpumask 1
# flush_tlb_info 6
# mm_struct 2
# vm_area_struct 20
# qspinlock 1
# qrwlock 2
# pv_lock_ops 5
# paravirt_patch_template 6
# paravirt_patch_site 3
# math_emu_info 2
# tracepoint_func 3
# ...
