# %%
# %load_ext autoreload
# %autoreload now

from utils import system
from btf_utils import get_bpftool_path

# %%
bpftool_path = get_bpftool_path()

# %%
system(f"sudo {bpftool_path} feature probe full")
# Out:
# Running command: "sudo /usr/lib/linux-tools/6.2.0-39-generic/bpftool feature probe full"
# Scanning system configuration...
# bpf() syscall restricted to privileged users (admin can change)
# Unable to retrieve JIT-compiler status
# Unable to retrieve JIT hardening status
# Unable to retrieve JIT kallsyms export status
# Unable to retrieve global memory limit for JIT compiler for unprivileged users
# CONFIG_BPF is not set
# CONFIG_BPF_SYSCALL is not set
# CONFIG_HAVE_EBPF_JIT is not set
# CONFIG_BPF_JIT is not set
# CONFIG_BPF_JIT_ALWAYS_ON is not set
# CONFIG_DEBUG_INFO_BTF is not set
# CONFIG_DEBUG_INFO_BTF_MODULES is not set
# CONFIG_CGROUPS is not set
# CONFIG_CGROUP_BPF is not set
# CONFIG_CGROUP_NET_CLASSID is not set
# CONFIG_SOCK_CGROUP_DATA is not set
# CONFIG_BPF_EVENTS is not set
# CONFIG_KPROBE_EVENTS is not set
# CONFIG_UPROBE_EVENTS is not set
# CONFIG_TRACING is not set
# CONFIG_FTRACE_SYSCALLS is not set
# CONFIG_FUNCTION_ERROR_INJECTION is not set
# ...
