# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import pandas as pd

from depsurf import OUTPUT_PATH


def read_data(kind):
    df = pd.read_pickle(OUTPUT_PATH / "diff.pkl")
    df = df.T

    if kind == "tracepoint":
        df1 = df["tp_event"]
        df2 = df["tp_func"]

        for col in ["Old", "Added", "Removed"]:
            assert df1[col].equals(df2[col])
            df2 = df2.drop(columns=col)

        df = pd.concat([df1, df2], axis=1)
    else:
        df = df[kind]

    return df


df = read_data("function")

df
# Out:
#                                                           Old  Added  Removed  \
# lts (4.4.0-21-generic-amd64, 4.15.0-20-generic-amd64)   36309   8600     2610
#     (4.15.0-20-generic-amd64, 5.4.0-26-generic-amd64)   42299   8929     3210
#     (5.4.0-26-generic-amd64, 5.15.0-25-generic-amd64)   48018  10771     4833
#     (5.15.0-25-generic-amd64, 6.8.0-22-generic-amd64)   53956  12139     4129
# all (4.4.0-21-generic-amd64, 4.8.0-22-generic-amd64)    36309   2849      947
#     (4.8.0-22-generic-amd64, 4.10.0-19-generic-amd64)   38211   1574      637
#     (4.10.0-19-generic-amd64, 4.13.0-16-generic-amd64)  39148   2662     1069
#     (4.13.0-16-generic-amd64, 4.15.0-20-generic-amd64)  40741   2118      560
#     (4.15.0-20-generic-amd64, 4.18.0-10-generic-amd64)  42299   3635     1446
#     (4.18.0-10-generic-amd64, 5.0.0-13-generic-amd64)   44488   1980     1191
#     (5.0.0-13-generic-amd64, 5.3.0-18-generic-amd64)    45277   2516      801
#     (5.3.0-18-generic-amd64, 5.4.0-26-generic-amd64)    46992   1382      356
#     (5.4.0-26-generic-amd64, 5.8.0-25-generic-amd64)    48018   6785     2867
#     (5.8.0-25-generic-amd64, 5.11.0-16-generic-amd64)   51936   3518     1152
#     (5.11.0-16-generic-amd64, 5.13.0-19-generic-amd64)  54302   1469     2578
#     (5.13.0-19-generic-amd64, 5.15.0-25-generic-amd64)  53193   1753      990
#     (5.15.0-25-generic-amd64, 5.19.0-21-generic-amd64)  53956   3525     1638
#     (5.19.0-21-generic-amd64, 6.2.0-20-generic-amd64)   55843   2622     1487
#     (6.2.0-20-generic-amd64, 6.5.0-9-generic-amd64)     56978   3196      809
#     (6.5.0-9-generic-amd64, 6.8.0-22-generic-amd64)     59365   3604     1003
# rev (5.4.0-26-generic-amd64, 5.4.0-51-generic-amd64)    48018    102       42
#     (5.4.0-51-generic-amd64, 5.4.0-75-generic-amd64)    48078    125       65
#     (5.4.0-75-generic-amd64, 5.4.0-100-generic-amd64)   48138     97       40
#     (5.4.0-100-generic-amd64, 5.4.0-125-generic-amd64)  48195     40       44
#     (5.4.0-125-generic-amd64, 5.4.0-175-generic-amd64)  48191    189      189
#
#                                                         Param added  \
# lts (4.4.0-21-generic-amd64, 4.15.0-20-generic-amd64)          1115
#     (4.15.0-20-generic-amd64, 5.4.0-26-generic-amd64)           963
#     (5.4.0-26-generic-amd64, 5.15.0-25-generic-amd64)          1316
#     (5.15.0-25-generic-amd64, 6.8.0-22-generic-amd64)          1533
# all (4.4.0-21-generic-amd64, 4.8.0-22-generic-amd64)            404
#     (4.8.0-22-generic-amd64, 4.10.0-19-generic-amd64)           221
#     (4.10.0-19-generic-amd64, 4.13.0-16-generic-amd64)          513
#     (4.13.0-16-generic-amd64, 4.15.0-20-generic-amd64)          300
#     (4.15.0-20-generic-amd64, 4.18.0-10-generic-amd64)          410
#     (4.18.0-10-generic-amd64, 5.0.0-13-generic-amd64)           342
#     (5.0.0-13-generic-amd64, 5.3.0-18-generic-amd64)            277
#     (5.3.0-18-generic-amd64, 5.4.0-26-generic-amd64)            446
#     (5.4.0-26-generic-amd64, 5.8.0-25-generic-amd64)            540
#     (5.8.0-25-generic-amd64, 5.11.0-16-generic-amd64)           530
#     (5.11.0-16-generic-amd64, 5.13.0-19-generic-amd64)          454
#     (5.13.0-19-generic-amd64, 5.15.0-25-generic-amd64)          264
#     (5.15.0-25-generic-amd64, 5.19.0-21-generic-amd64)          556
#     (5.19.0-21-generic-amd64, 6.2.0-20-generic-amd64)           449
#     (6.2.0-20-generic-amd64, 6.5.0-9-generic-amd64)             579
#     (6.5.0-9-generic-amd64, 6.8.0-22-generic-amd64)             351
# rev (5.4.0-26-generic-amd64, 5.4.0-51-generic-amd64)             22
#     (5.4.0-51-generic-amd64, 5.4.0-75-generic-amd64)            132
#     (5.4.0-75-generic-amd64, 5.4.0-100-generic-amd64)            20
#     (5.4.0-100-generic-amd64, 5.4.0-125-generic-amd64)           13
#     (5.4.0-125-generic-amd64, 5.4.0-175-generic-amd64)           38
#
#                                                         Param removed  \
# lts (4.4.0-21-generic-amd64, 4.15.0-20-generic-amd64)             800
#     (4.15.0-20-generic-amd64, 5.4.0-26-generic-amd64)             659
#     (5.4.0-26-generic-amd64, 5.15.0-25-generic-amd64)             967
#     (5.15.0-25-generic-amd64, 6.8.0-22-generic-amd64)            1424
# all (4.4.0-21-generic-amd64, 4.8.0-22-generic-amd64)              292
#     (4.8.0-22-generic-amd64, 4.10.0-19-generic-amd64)             178
#     (4.10.0-19-generic-amd64, 4.13.0-16-generic-amd64)            343
#     (4.13.0-16-generic-amd64, 4.15.0-20-generic-amd64)            206
#     (4.15.0-20-generic-amd64, 4.18.0-10-generic-amd64)            194
#     (4.18.0-10-generic-amd64, 5.0.0-13-generic-amd64)             303
#     (5.0.0-13-generic-amd64, 5.3.0-18-generic-amd64)              210
#     (5.3.0-18-generic-amd64, 5.4.0-26-generic-amd64)              384
#     (5.4.0-26-generic-amd64, 5.8.0-25-generic-amd64)              433
#     (5.8.0-25-generic-amd64, 5.11.0-16-generic-amd64)             485
#     (5.11.0-16-generic-amd64, 5.13.0-19-generic-amd64)            189
#     (5.13.0-19-generic-amd64, 5.15.0-25-generic-amd64)            172
#     (5.15.0-25-generic-amd64, 5.19.0-21-generic-amd64)            486
#     (5.19.0-21-generic-amd64, 6.2.0-20-generic-amd64)             347
#     (6.2.0-20-generic-amd64, 6.5.0-9-generic-amd64)               588
#     (6.5.0-9-generic-amd64, 6.8.0-22-generic-amd64)               302
# rev (5.4.0-26-generic-amd64, 5.4.0-51-generic-amd64)                8
#     (5.4.0-51-generic-amd64, 5.4.0-75-generic-amd64)              128
#     (5.4.0-75-generic-amd64, 5.4.0-100-generic-amd64)              11
#     (5.4.0-100-generic-amd64, 5.4.0-125-generic-amd64)              5
#     (5.4.0-125-generic-amd64, 5.4.0-175-generic-amd64)             20
#
#                                                         Param type changed  \
# lts (4.4.0-21-generic-amd64, 4.15.0-20-generic-amd64)                  508
#     (4.15.0-20-generic-amd64, 5.4.0-26-generic-amd64)                  421
#     (5.4.0-26-generic-amd64, 5.15.0-25-generic-amd64)                  572
#     (5.15.0-25-generic-amd64, 6.8.0-22-generic-amd64)                  751
# all (4.4.0-21-generic-amd64, 4.8.0-22-generic-amd64)                   212
#     (4.8.0-22-generic-amd64, 4.10.0-19-generic-amd64)                  107
#     (4.10.0-19-generic-amd64, 4.13.0-16-generic-amd64)                 166
#     (4.13.0-16-generic-amd64, 4.15.0-20-generic-amd64)                 159
#     (4.15.0-20-generic-amd64, 4.18.0-10-generic-amd64)                 216
#     (4.18.0-10-generic-amd64, 5.0.0-13-generic-amd64)                  175
#     (5.0.0-13-generic-amd64, 5.3.0-18-generic-amd64)                   101
#     (5.3.0-18-generic-amd64, 5.4.0-26-generic-amd64)                    28
#     (5.4.0-26-generic-amd64, 5.8.0-25-generic-amd64)                   173
#     (5.8.0-25-generic-amd64, 5.11.0-16-generic-amd64)                  260
#     (5.11.0-16-generic-amd64, 5.13.0-19-generic-amd64)                  71
#     (5.13.0-19-generic-amd64, 5.15.0-25-generic-amd64)                 193
#     (5.15.0-25-generic-amd64, 5.19.0-21-generic-amd64)                 141
#     (5.19.0-21-generic-amd64, 6.2.0-20-generic-amd64)                  253
#     (6.2.0-20-generic-amd64, 6.5.0-9-generic-amd64)                    199
#     (6.5.0-9-generic-amd64, 6.8.0-22-generic-amd64)                    288
# rev (5.4.0-26-generic-amd64, 5.4.0-51-generic-amd64)                     6
#     (5.4.0-51-generic-amd64, 5.4.0-75-generic-amd64)                   125
#     (5.4.0-75-generic-amd64, 5.4.0-100-generic-amd64)                   11
#     (5.4.0-100-generic-amd64, 5.4.0-125-generic-amd64)                   2
#     (5.4.0-125-generic-amd64, 5.4.0-175-generic-amd64)                  25
#
#                                                         Param reordered  \
# lts (4.4.0-21-generic-amd64, 4.15.0-20-generic-amd64)               375
#     (4.15.0-20-generic-amd64, 5.4.0-26-generic-amd64)               349
#     (5.4.0-26-generic-amd64, 5.15.0-25-generic-amd64)               556
#     (5.15.0-25-generic-amd64, 6.8.0-22-generic-amd64)               555
# all (4.4.0-21-generic-amd64, 4.8.0-22-generic-amd64)                173
#     (4.8.0-22-generic-amd64, 4.10.0-19-generic-amd64)                42
#     (4.10.0-19-generic-amd64, 4.13.0-16-generic-amd64)              183
#     (4.13.0-16-generic-amd64, 4.15.0-20-generic-amd64)               87
#     (4.15.0-20-generic-amd64, 4.18.0-10-generic-amd64)              203
#     (4.18.0-10-generic-amd64, 5.0.0-13-generic-amd64)                84
#     (5.0.0-13-generic-amd64, 5.3.0-18-generic-amd64)                101
#     (5.3.0-18-generic-amd64, 5.4.0-26-generic-amd64)                 27
#     (5.4.0-26-generic-amd64, 5.8.0-25-generic-amd64)                138
#     (5.8.0-25-generic-amd64, 5.11.0-16-generic-amd64)               189
#     (5.11.0-16-generic-amd64, 5.13.0-19-generic-amd64)              279
#     (5.13.0-19-generic-amd64, 5.15.0-25-generic-amd64)              101
#     (5.15.0-25-generic-amd64, 5.19.0-21-generic-amd64)              241
#     (5.19.0-21-generic-amd64, 6.2.0-20-generic-amd64)               217
#     (6.2.0-20-generic-amd64, 6.5.0-9-generic-amd64)                 148
#     (6.5.0-9-generic-amd64, 6.8.0-22-generic-amd64)                  98
# rev (5.4.0-26-generic-amd64, 5.4.0-51-generic-amd64)                  8
#     (5.4.0-51-generic-amd64, 5.4.0-75-generic-amd64)                 12
#     (5.4.0-75-generic-amd64, 5.4.0-100-generic-amd64)                12
#     (5.4.0-100-generic-amd64, 5.4.0-125-generic-amd64)                1
#     (5.4.0-125-generic-amd64, 5.4.0-175-generic-amd64)                4
#
#                                                         Return type changed
# lts (4.4.0-21-generic-amd64, 4.15.0-20-generic-amd64)                   292
#     (4.15.0-20-generic-amd64, 5.4.0-26-generic-amd64)                   380
#     (5.4.0-26-generic-amd64, 5.15.0-25-generic-amd64)                   288
#     (5.15.0-25-generic-amd64, 6.8.0-22-generic-amd64)                   507
# all (4.4.0-21-generic-amd64, 4.8.0-22-generic-amd64)                    114
#     (4.8.0-22-generic-amd64, 4.10.0-19-generic-amd64)                    54
#     (4.10.0-19-generic-amd64, 4.13.0-16-generic-amd64)                  114
#     (4.13.0-16-generic-amd64, 4.15.0-20-generic-amd64)                   59
#     (4.15.0-20-generic-amd64, 4.18.0-10-generic-amd64)                  179
#     (4.18.0-10-generic-amd64, 5.0.0-13-generic-amd64)                   140
#     (5.0.0-13-generic-amd64, 5.3.0-18-generic-amd64)                     75
#     (5.3.0-18-generic-amd64, 5.4.0-26-generic-amd64)                     23
#     (5.4.0-26-generic-amd64, 5.8.0-25-generic-amd64)                    120
#     (5.8.0-25-generic-amd64, 5.11.0-16-generic-amd64)                    91
#     (5.11.0-16-generic-amd64, 5.13.0-19-generic-amd64)                   52
#     (5.13.0-19-generic-amd64, 5.15.0-25-generic-amd64)                   94
#     (5.15.0-25-generic-amd64, 5.19.0-21-generic-amd64)                  127
#     (5.19.0-21-generic-amd64, 6.2.0-20-generic-amd64)                   146
#     (6.2.0-20-generic-amd64, 6.5.0-9-generic-amd64)                     158
#     (6.5.0-9-generic-amd64, 6.8.0-22-generic-amd64)                     151
# rev (5.4.0-26-generic-amd64, 5.4.0-51-generic-amd64)                      4
#     (5.4.0-51-generic-amd64, 5.4.0-75-generic-amd64)                     12
#     (5.4.0-75-generic-amd64, 5.4.0-100-generic-amd64)                     9
#     (5.4.0-100-generic-amd64, 5.4.0-125-generic-amd64)                    4
#     (5.4.0-125-generic-amd64, 5.4.0-175-generic-amd64)                   13

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.text import Text
from matplotlib import transforms

from depsurf import BuildVersion, FIG_PATH
from dataclasses import dataclass


def bold(text):
    return f"$\\mathbf{{{text}}}$"


def plot_legend(fig: plt.Figure):
    labels_handles = {
        label: handle
        for ax in fig.axes
        for handle, label in zip(*ax.get_legend_handles_labels())
    }.items()
    labels, handles = zip(*labels_handles)

    fig.legend(
        handles,
        labels,
        loc="upper center",
        ncol=len(labels) // 2,
        bbox_to_anchor=(0.5, 0.9375),
        frameon=False,
    )


group_labels = {
    "lts": "Kernel Versions w/ LTS (2 yr)",
    "all": "Kernel Versions w/ Regular Releases (6 mo)",
    "rev": f"Revisions for Kernel {bold(5.4)}",
}


@dataclass
class SubfigPlotter:
    ax: plt.Axes
    df: pd.DataFrame
    group: str
    show_xlabels: bool
    fontsize: int = 8

    @property
    def columns(self):
        return self.df.columns.drop("Old")

    @property
    def num_bars(self):
        return len(self.df.index)

    def plot(self):
        self.plot_bar()
        self.plot_xticks()
        self.plot_yticks()
        with plt.rc_context(
            {
                "font.family": "monospace",
                "font.size": self.fontsize,
                # "font.stretch": "condensed",
            }
        ):
            self.plot_val_labels()
            self.plot_top_labels()

        self.ax.spines[["top", "right"]].set_visible(False)

    def plot_bar(self, x_pad=0.5):
        bottom = np.zeros(self.num_bars)
        xs = np.arange(self.num_bars)
        for col in self.columns:
            self.ax.bar(xs, self.df[col], label=col, bottom=bottom, color=col.color)
            bottom += self.df[col].to_numpy()

        self.ax.set_xlim(-x_pad, self.num_bars - 1 + x_pad + 0.01)
        self.ax.set_ylim(0, bottom.max() * 1.15)

    @staticmethod
    def flatten_pairs(pairs):
        fst, snd = list(zip(*pairs))
        assert fst[1:] == snd[:-1]
        return fst + (snd[-1],)

    def plot_xticks(self):
        xs = np.arange(self.num_bars + 1) - 0.5

        pairs = self.flatten_pairs(self.df.index)
        versions = [BuildVersion.from_str(v) for v in pairs]
        if self.group == "rev":
            labels = [v.revision for v in versions]
            self.ax.set_xticks(xs, labels)
        elif self.group == "lts":
            labels = [v.short_version for v in versions]
            self.ax.set_xticks(xs, labels, fontweight="bold")
        elif self.group == "all":
            for lts in [True, False]:
                xs_labels = [
                    (x, v.short_version) for x, v in zip(xs, versions) if v.lts == lts
                ]
                self.ax.set_xticks(
                    *zip(*xs_labels),
                    minor=not lts,
                    fontweight="bold" if lts else "normal",
                )
            self.ax.grid(which="major", axis="x", linestyle="--", linewidth=1)

        self.ax.tick_params(axis="both", which="both", length=4, labelsize=9)

        if not self.show_xlabels:
            self.ax.set_xticklabels([])
            self.ax.set_xticklabels([], minor=True)
        else:
            self.ax.set_xlabel(group_labels[self.group])

    def plot_yticks(self):
        locator = plt.MaxNLocator(nbins="auto", steps=[1, 2, 4, 5, 10])
        self.ax.yaxis.set_major_locator(locator)
        yticks = self.ax.get_yticks()
        if all(y % 1000 == 0 for y in yticks):
            fn = lambda x, _: f"{x / 1000:.0f}k" if x != 0 else "0"
        elif all(y % 100 == 0 for y in yticks) and max(yticks) > 1000:
            fn = lambda x, _: f"{x / 1000:.1f}k" if x != 0 else "0"
        else:
            fn = lambda x, _: f"{x:.0f}"
        self.ax.yaxis.set_major_formatter(plt.FuncFormatter(fn))

    def plot_val_labels(self):
        text = Text(text="0", figure=self.ax.figure)
        text_height = text.get_window_extent().height

        def format_val(val):
            if val > 1000:
                return f"{val / 1000:.2g}k"
            return str(val)

        trans = self.ax.transData
        bottom = np.zeros(self.num_bars)
        for col in self.columns:
            for i, v in enumerate(self.df[col]):
                bar_height = (trans.transform((0, v)) - trans.transform((0, 0)))[1]
                if bar_height < text_height * 0.9:
                    continue
                h = v / 2 + bottom[i]
                self.ax.text(i, h, format_val(v), ha="center", va="center")
            bottom += self.df[col].to_numpy()

    def plot_top_labels(self):
        trans = self.ax.transData
        ymax = self.ax.get_ylim()[1]
        for i, (index, row) in enumerate(self.df.iterrows()):
            old = row["Old"]
            total = sum(row) - old

            # if total == 0:  # explicitly add 0 labels
            #     self.ax.text(i, 0, "0", ha="center", va="bottom")
            #     continue

            added = row["Added"]
            removed = row["Removed"]
            changed = total - added - removed

            if self.group == "rev":
                format_val = lambda v: f"{v:0.0f}"
            else:
                format_val = lambda v: f"{v / old:0.0%}"

            y = self.fontsize
            for k, v, c in [
                (r"\Delta", changed, "darkgreen"),
                (r"\minus", removed, "xkcd:dark orange"),
                (r"\plus", added, "blue"),
            ]:
                y -= self.fontsize
                if v == 0:
                    continue
                self.ax.text(
                    i,
                    ymax,
                    f"${k}${format_val(v)}",
                    ha="center",
                    va="top",
                    transform=transforms.offset_copy(trans, y=y, units="dots"),
                    color=c,
                )


fig, axs = plt.subplots(
    3,
    3,
    figsize=(12, 12),
    dpi=200,
    width_ratios=[4, 16, 5],
    gridspec_kw={"wspace": 0.15, "hspace": 0.075},
)

for row_idx, (ax_rows, kind) in enumerate(
    zip(axs, ["function", "struct", "tracepoint"])
):
    df = read_data(kind)
    for col_idx, (ax, group) in enumerate(zip(ax_rows, group_labels.keys())):
        df_group = df.loc[group]
        SubfigPlotter(
            ax=ax,
            df=df_group,
            group=group,
            show_xlabels=row_idx == len(axs) - 1,
        ).plot()

        if col_idx == 0:
            ax.set_ylabel(f"Number of {bold(kind.capitalize())} Changes")

plot_legend(fig)

fig.savefig(FIG_PATH / "diff.pdf", bbox_inches="tight")

plt.close(fig)

# %%
def dump_latex():
    df = pd.read_pickle("output/diff.pkl")
    df = df.astype(object)
    kinds = ["struct", "func", "tp_func", "lsm"]
    df = df.loc[kinds]

    for kind in kinds:
        for row in df.loc[kind].index:
            if row == "Old":
                continue
            for col in df.columns:
                val = df.loc[(kind, row), col]
                percentage = val / df.loc[(kind, "Old"), col] * 100
                df.loc[(kind, row), col] = f"\\val{{{val}}}{{{percentage:4.1f}}}"

    df = df.drop(index=["Old", "New", "Common"], level=1)

    df.to_latex("output/diff.tex")

    return df


# dump_latex()
