# %%
from depsurf.output import load_df

df_raw = load_df("config/summary")
# Out:
# [        utils.py:160] INFO: NumExpr defaulting to 8 threads.
# [           pd.py:53 ] INFO: Loaded df from /Users/szhong/Downloads/bpf-study/output/config/summary.pkl

# %%
from depsurf import ChangeEnum

d = {
    ChangeEnum.ADD: "$+$",
    ChangeEnum.REMOVE: "$-$",
    ChangeEnum.CHANGE: "$\Delta$",
    "New": "$\Sigma$",
}

row_selector = df_raw.index.get_level_values(-1).isin(d.keys())
col_selector = [(t, n) for (t, n) in df_raw.columns if "Oracle" not in n]


df = df_raw[col_selector].loc[row_selector]
df.index = df.index.map(lambda x: (x[0], d[x[1]]))
df.columns = df.columns.map(lambda x: (x[0], x[1].split("→")[-1]))
df
# Out:
#                       Arch                      Flavor
#                        arm  armhf    ppc  s390x    Lat    AWS    GCP  Azure
# Function   $\Sigma$  49362  48845  42826  33160  48034  46523  48149  45483
#            $+$        9216  12602   5444   3892     57    328    450    992
#            $-$        7872  11775  10636  18750     41   1823    319   3527
#            $\Delta$    120    106    137     78      0      2      1     10
# Struct     $\Sigma$   9075   8551   7368   6052   8425   8022   8367   7846
#            $+$        1659   1980    570    694      4     83     68    257
#            $-$        1006   1851   1624   3064      1    483    123    833
#            $\Delta$    309   4077    379    375      7    132     14     32
# Tracepoint $\Sigma$    685    690    648    559    752    747    752    739
#            $+$          45     70     25     61      0      4      0     26
#            $-$         112    132    129    254      0      9      0     39
#            $\Delta$      0    301      0     81      0      0      0      0
# LSM        $\Sigma$    189    189    189    189    189    189    189    189

# %%
print(df.to_latex(multicolumn_format="c"))
# Out:
# \begin{tabular}{llrrrrrrrr}
# \toprule
#  &  & \multicolumn{4}{c}{Arch} & \multicolumn{4}{c}{Flavor} \\
#  &  & arm & armhf & ppc & s390x & Lat & AWS & GCP & Azure \\
# \midrule
# \multirow[t]{4}{*}{Function} & $\Sigma$ & 49362 & 48845 & 42826 & 33160 & 48034 & 46523 & 48149 & 45483 \\
#  & $+$ & 9216 & 12602 & 5444 & 3892 & 57 & 328 & 450 & 992 \\
#  & $-$ & 7872 & 11775 & 10636 & 18750 & 41 & 1823 & 319 & 3527 \\
#  & $\Delta$ & 120 & 106 & 137 & 78 & 0 & 2 & 1 & 10 \\
# \cline{1-10}
# \multirow[t]{4}{*}{Struct} & $\Sigma$ & 9075 & 8551 & 7368 & 6052 & 8425 & 8022 & 8367 & 7846 \\
#  & $+$ & 1659 & 1980 & 570 & 694 & 4 & 83 & 68 & 257 \\
#  & $-$ & 1006 & 1851 & 1624 & 3064 & 1 & 483 & 123 & 833 \\
#  & $\Delta$ & 309 & 4077 & 379 & 375 & 7 & 132 & 14 & 32 \\
# \cline{1-10}
# \multirow[t]{4}{*}{Tracepoint} & $\Sigma$ & 685 & 690 & 648 & 559 & 752 & 747 & 752 & 739 \\
#  & $+$ & 45 & 70 & 25 & 61 & 0 & 4 & 0 & 26 \\
#  & $-$ & 112 & 132 & 129 & 254 & 0 & 9 & 0 & 39 \\
#  & $\Delta$ & 0 & 301 & 0 & 81 & 0 & 0 & 0 & 0 \\
# \cline{1-10}
# LSM & $\Sigma$ & 189 & 189 & 189 & 189 & 189 & 189 & 189 & 189 \\
# \cline{1-10}
# \bottomrule
# \end{tabular}
